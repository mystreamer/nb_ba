# %% [markdown]
# ## SMD
#
# Exploring the data downloaded from [Swissdox@LiRi](https://swissdox.linguistik.uzh.ch)
#
# Also remove duplicates in the content.
#
# **Load the data**

# %%
import pandas as pd

df = pd.read_csv("./data/tabakwerbung_ab_1980.tsv", sep="\t", index_col=0)

# %%
df.head()
# Out:
#                          pubtime medium_code           medium_name  \
# id
# 45099545  2022-01-11 11:30:00+01        SWII          swissinfo.ch
# 10918745  2006-01-05 00:00:00+01         NZZ  Neue Zürcher Zeitung
# 6501276   2009-10-31 00:00:00+01          TA        Tages-Anzeiger
# 27598133  2015-06-06 00:00:00+02          TA        Tages-Anzeiger
# 44353911  2021-10-26 00:00:00+02         NZZ  Neue Zürcher Zeitung
#
#               rubric    regional doctype       doctype_description language  \
# id
# 45099545  Gesundheit         NaN     WWE             Online medium       de
# 10918745         NaN  Feuilleton     PND  National daily newspaper       de
# 6501276   Leserforum         GES     PND  National daily newspaper       de
# 27598133     Schweiz         NaN     PND  National daily newspaper       de
# 44353911       Front         NaN     PND  National daily newspaper       de
#
#           char_count dateline  \
# id
# 45099545      6747.0      NaN
# 10918745      5741.0      NaN
# 6501276       1164.0      NaN
# 27598133      3002.0      NaN
# 44353911      4917.0      NaN
#
#                                                        head  \
# id
# 45099545  "Wir befürchten, dass die Tabakinitiative die ...
# 10918745                      Auf Spurensuche in der Südsee
# 6501276   Passivrauchen 6 Monate bis zum Rauchverbot, TA...
# 27598133                             Streit um Tabakwerbung
# 44353911                       Corona senkt Lebenserwartung
#
#                                                     subhead  \
# id
# 45099545                                                NaN
# 10918745     Alex Capus' Roman «Reisen im Licht der Sterne»
# 6501276                                                 NaN
# 27598133                                                NaN
# 44353911  Statistiker erwarten rasch wieder steigende We...
#
#                                     content_id  \
# id
# 45099545  0000fb10-e19a-a512-8948-0af65f56ff83
# 10918745  001d52e2-59bc-bf9e-c944-f06f353b8803
# 6501276   00286c8a-2d53-bcd0-af01-a0202565f727
# 27598133  003c9792-e58e-c541-cddc-c7eb82e39b54
# 44353911  0040996c-25d1-970e-b624-abe77a6046c2
#
#                                                     content
# id
# 45099545  <tx><ld><p>Wirtschaftskreise wehren sich gegen...
# 10918745  <tx><p>Robert Louis Stevenson auf Samoa - das ...
# 6501276   <tx><p>Volkswille lange nicht umgesetzt.</p><p...
# 27598133  <tx><ld><p>Der Bundesrat will trotz Widerstand...
# 44353911  <tx><ld><p>Im Corona-Jahr 2020 ist die statist...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9874 entries, 45099545 to 10118737
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pubtime              9874 non-null   object
#  1   medium_code          9874 non-null   object
#  2   medium_name          9874 non-null   object
#  3   rubric               6316 non-null   object
#  4   regional             2435 non-null   object
#  5   doctype              9874 non-null   object
#  6   doctype_description  9874 non-null   object
#  7   language             9874 non-null   object
#  8   char_count           9867 non-null   float64
#  9   dateline             1647 non-null   object
#  10  head                 9874 non-null   object
#  11  subhead              1729 non-null   object
#  12  content_id           9874 non-null   object
#  13  content              9874 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# **Available Sources**

# %%
print("Sources: ", "\n".join([s for s in set(df.medium_name.to_list())]))
# Out:
# Sources:  NZZ Folio
# Das Magazin
# Handelszeitung
# Neue Zürcher Zeitung
# fuw.ch
# Cashdaily
# Berner Zeitung
# Newsnet / Berner Zeitung
# Toggenburger Tagblatt
# Limmattaler Zeitung
# zsz.ch
# Aargauer Tagblatt
# St. Galler Tagblatt
# 20 minuten
# schweizer‐illustrierte.ch
# Zürcher Unterländer
# Finanz und Wirtschaft
# nzz.ch
# TV2
# srf Video
# Zürich Express
# derbund.ch
# Berner Oberländer
# Zürichsee Zeitung
# SonntagsZeitung
# limmattalerzeitung.ch
# Newsnetz
# Beobachter.ch
# Zugerbieter
# cash.ch
# luzernerzeitung.ch
# www.sf.tv
# aargauerzeitung.ch
# Urner  Zeitung
# solothurnerzeitung.ch
# Style
# bzbasel.ch
# bilanz.ch
# handelszeitung.ch
# Der Landbote
# Schweizer Versicherung
# tagblatt.ch
# Oltner Tagblatt / MLZ
# Aargauer Zeitung / MLZ
# Badener Tagblatt
# Grenchner Tagblatt / MLZ
# Ostschweiz am Sonntag
# srf Audio
# 20 Minuten Online
# Facts
# Grenchner Tagblatt
# thunertagblatt.ch
# Wiler Zeitung
# Luzerner Zeitung
# 20 Minuten
# tagesanzeiger.ch
# beobachter.ch
# Tele
# HandelsZeitung
# io new management
# Zürichsee-Zeitung
# Solothurner Zeitung
# BeobachterNatur
# SWI swissinfo.ch
# Obwaldner Zeitung
# züritipp (Tages-Anzeiger)
# grenchnertagblatt.ch
# Ernst (Tages-Anzeiger)
# Neue Luzerner Zeitung
# bazonline.ch
# Baslerstab
# blick.ch
# Thurgauer Zeitung
# Zuger Zeitung
# bz - Zeitung für die Region Basel
# Schweizer Familie
# www.swissinfo.ch
# Zentralschweiz am Sonntag
# Blick.ch
# Schweiz am Sonntag / MLZ
# Schweiz am Wochenende
# 20 minuten online
# Sonntag / MLZ
# Beobachter
# NEWS
# Aargauer Zeitung
# Limmattaler Zeitung / MLZ
# zuonline.ch
# AZ-Tabloid / MLZ
# Mittelland Zeitung
# Blick
# Newsnetz / Thurgauer Zeitung
# landbote.ch
# Tages-Anzeiger
# berneroberlaender.ch
# Werdenberger & Obertoggenburger
# Appenzeller Zeitung
# langenthalertagblatt.ch
# Glückspost
# Cash
# Schweizer Illustrierte
# srf.ch
# bernerzeitung.ch
# Limmattaler Tagblatt / MLZ
# NZZ Geschichte
# Der Bund
# Basellandschaftliche Zeitung / MLZ
# Der Sonntag / MLZ
# Thuner Tagblatt
# BZ - Langenthaler Tagblatt
# Zofinger Tagblatt / MLZ
# Berner Rundschau / MLZ
# Bilanz
# badenertagblatt.ch
# oltnertagblatt.ch
# CASHdaily
# Nidwaldner Zeitung
# NZZ am Sonntag
# Die Wochenzeitung
# heute
# Solothurner Zeitung / MLZ
# Basler Zeitung
# Sonntagsblick
# Blick am Abend
# Gesundheit-SprechStunde
# TV Star
# swissinfo.ch
# HZ Insurance

# %% [markdown]
# **Analysis of Duplicates**

# %%
df_dedup = df.drop_duplicates(subset=["content"])
print(f"DataFrame length after content duplicates removed: { len(df_dedup) } vs. { len(df) } before.")
# Out:
# DataFrame length after content duplicates removed: 7215 vs. 9874 before.

# %% [markdown]
# **Save deduplicated form**

# %%
df_dedup.to_csv("./data/tabakwerbung_ab_1980_dedup.tsv", sep="\t")
