# %% [markdown]
# ## ORL_RE_Inference
#
# Use the trained model to predict input sentences and bring them into a format accepted by the relation classifier.

# %%
import os
# DataSource in SSA-format
DATASOURCE="../../etl/data/processed/Perin_Preprocessing/01_test.json"
DATADEST="../../etl/data/processed/ORL_RE_Inference/01_test.json"

# DATASOURCE="../../etl/data/processed/Perin_Preprocessing/01_train.json"
# DATADEST="../../etl/data/processed/ORL_RE_Inference/01_train.json"

# DATASOURCE="../../etl/data/processed/Perin_Preprocessing/pro_con_500.json"
# DATADEST="../../etl/data/processed/ORL_RE_Inference/pro_con_500.json"

# DATASOURCE="../../etl/data/processed/REConverter/01_train_re.json"

VERIFY_RE_MODEL=False


# CONFIGS for NER
# CONFIG-VARIABLES
ORL_MODEL_PATH="../ORL/data/trained_model_german_bert"

# CONFIGS for RE
# GS_INPUT_DIR = "/content/drive/MyDrive/odsc-2022-data/NYT"
DATA_DIR = "../../etl/data/processed/REConverter"
splits = ["train", "test", "val"]
BASE_MODEL_NAME = "xlm-roberta-base"
# BASE_MODEL_NAME = "bert-base-cased"
MODEL_DIR = os.path.join("../RelationClassifier/data", "{:s}-re".format(BASE_MODEL_NAME))

# %% [markdown]
# ### Read-In the data
#
# Reading in the data so it can be processed. The format is SSA.

# %%
# makedirs if not exist
os.makedirs("../../etl/data/processed/ORL_RE_Inference", exist_ok=True)

# %%
opinion_interface = {'Source': [[], []], 
             'Target': [[], []], 
             'Polar_expression': [[], []], 
             'Polarity': None, 
             'Intensity': 'Average'}

# %%
import json
import copy

out_data = None
gold_polarities = []
def convert_ssa_to_sents(datasource):
    with open(datasource, "r", encoding="utf-8") as f:
        data = json.load(f)
    out_data = copy.deepcopy(data)
    sents = []
    for i, rec in enumerate(data):
        out_data[i]["opinions"] = [copy.deepcopy(opinion_interface)]
        # print(rec)
        sents.append(rec["text"])
        gold_polarities.append(rec["opinions"][0]["Polarity"])
    return sents, out_data

ssa_sents, out_data = convert_ssa_to_sents(DATASOURCE)

# %%
print(out_data)
# Out:
# [{'sent_id': '0', 'text': 'Finnland will sich dort auch für eine Verteuerung der Touristenvisa einsetzen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '1', 'text': '( sda ) Eishockey Ottawa entlässt seinen Headcoach Guy Boucher ( 47 ) .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '2', 'text': 'Bei den israelischen Siedlungen im Westjordanland pfeift US-Präsident Trump aufs Völkerrecht .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '3', 'text': 'Bei negativen Gedanken wie diesen wird die Personalfachfrau ständig von schlimmen Erinnerungen heimgesucht : « Denke ich daran , dass Nils sich infizieren könnte , sehe ich die schrecklichen Bilder vor mir , als er als Baby an der Herz-Lungen-Maschine angeschlossen war .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '4', 'text': 'Der Name verweist auf die Art , wie diese Temperatur bestimmt werden kann : indem man die Birne eines Thermometers ( bulb ) in ein nasses Tuch wickelt und dann schaut , welche Temperatur das Thermometer anzeigt .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '5', 'text': 'Sanders versuchte zwar , die Corona-Krise als Argument zu benutzen , dass seine Forderung nach einer allgemeinen , staatlichen Krankenversicherung richtig sei .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '6', 'text': 'Der Trainer der New Jersey Devils sagte , er sehe den jungen Oberwalliser als zukünftigen « franchise player » und er glaube , dass Hischier irgendwann die Selke Trophy gewinnen werde .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '7', 'text': 'Das Kuchi-Daaberettli mahnt aber \xad dennoch zur Vorsicht : Drotz Corona duen y hitte do my Schnitzelbangg singe und hoff , s däät glinge , eich zem Schmunzle z bringe .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '8', 'text': 'Labour-Abgeordnete standen der Reihe nach auf , um den Kreml zu schelten und Corbyn zwischen den Zeilen die Meinung zu sagen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '9', 'text': 'Pécresse will die 35-Stunden-Woche abschaffen , das reguläre Pensionsalter von 62 auf 65 erhöhen und 200 ’ 000 Beamtenposten streichen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '10', 'text': 'Mit einem Abseitsstehen zöge die Schweiz mit Ländern wie den USA , Ungarn oder Österreich gleich , wo Kanzler Sebastian Kurz unter Druck der rechtspopulistischen Koalitionspartnerin FPÖ agiert .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '11', 'text': 'Nachdem Indiens Luftwaffe in der Nacht zum Dienstag zum ersten Mal seit 1971 einen Angriff auf pakistanischem Gebiet geflogen hatte , schoss Pakistan nach eigenen Angaben am Mittwoch zwei indische Kampfflugzeuge ab .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '12', 'text': 'Daneben freut sich Charlene , der Kelch ist an ihr vorübergegangen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Pola ...

# %% [markdown]
# ### Target Holder PolarExpression Extraction
#
# **Extract Target-Holder-Expression-Pairs**

# %%
# Load the ORL model.
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

model_path = ORL_MODEL_PATH

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)

pipe = pipeline(task="token-classification",
                # model=trainer.model, -- in case freshly trained
                model=model,
                tokenizer=tokenizer,
                aggregation_strategy="first"
               )

classified = pipe("Der Mann erschiesst seine Frau.")

print(classified)
# Out:
# [{'entity_group': 'LABEL_0', 'score': 0.99897814, 'word': 'Der', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_1', 'score': 0.99242157, 'word': 'Mann', 'start': 4, 'end': 8}, {'entity_group': 'LABEL_3', 'score': 0.99666035, 'word': 'erschiesst', 'start': 9, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.9993655, 'word': 'seine', 'start': 20, 'end': 25}, {'entity_group': 'LABEL_2', 'score': 0.9913374, 'word': 'Frau', 'start': 26, 'end': 30}, {'entity_group': 'LABEL_0', 'score': 0.999114, 'word': '.', 'start': 30, 'end': 31}]

# %%
from typing import NamedTuple

class PAS(NamedTuple):
    arg1: str
    arg2: str
    pexp: str

# %%
label_mapper = {
    "LABEL_0": "NEUTRAL",
    "LABEL_1": "HOLDER",
    "LABEL_2": "TARGET",
    "LABEL_3": "PEXP",
}

def extract_args(bert_output):
    """Obtain arguments from a dict-list of a BERT model."""
    # the holder is the first argument, the target is the second argument
    arg1=None
    arg2=None
    pexp=None
    for c in bert_output:
        if label_mapper[c["entity_group"]] == "HOLDER":
            arg1=c["word"]
        elif label_mapper[c["entity_group"]] == "TARGET":
            arg2=c["word"]
        elif label_mapper[c["entity_group"]] == "PEXP":
            pexp=c["word"]
        else:
            pass
        
    # if one is none, fill it by using the highest probability overall.

    return arg1, arg2, pexp

# %%
# Function doing the heavy lifting, here we assume one relation per sentence (no compositionality).
def extract_pas(sentence_string):
    # sentence with holder / target labels
    labelled_sentence = pipe(sentence_string)
    # obtain arguments from labels
    arg1, arg2, pexp = extract_args(labelled_sentence)
    return PAS(arg1, arg2, pexp)

print(extract_pas("Die Berliner Morgenpost hat den Angriff auf die Ukraine kritisiert."))
# Out:
# PAS(arg1='Morgenpost', arg2='Angriff', pexp='kritisiert')

# %% [markdown]
# ### Generate unbreakable tokens based on input sentence + ORL inference
#
# **Important**: We make sure that every sentence contains a dot in the end that is separated from the last word in the sentence!

# %%
# simplified_training_data
import re
import copy
from tqdm import tqdm

def identify_from_base_sent(target_word, base_sent):
    res = re.search(target_word, base_sent)
    return res.span()

def generate_head_based_entity_sentences(sentences, out_data=[]):
    entified_list = []
    ret_od = []
    for i, sent in tqdm(enumerate(sentences)):
        pas = extract_pas(sent)
        od = copy.deepcopy(out_data[i])
        base_sent = copy.deepcopy(sent)
        # print(pas)
        try:
            if pas.arg1:
                res = re.search(pas.arg1, sent)
                e1_s, e1_e = res.span()
                # print(out_data[i]["opinions"][0]["Source"])
                sent = sent[0:max(0, e1_s - 1)] + " <eSOURCE> " + sent[e1_s:min(len(sent), e1_e)] + " </eSOURCE> " + sent[min(len(sent), e1_e + 1):]
                
                e1_s, e1_e = identify_from_base_sent(pas.arg1, base_sent)
                od["opinions"][0].update({ "Source": [[base_sent[e1_s:min(len(sent), e1_e)]], [f"{str(e1_s)}:{str(e1_e)}"]] })

            if pas.arg2:
                res = re.search(pas.arg2, sent)
                e2_s, e2_e = res.span()
                sent = sent[0:max(0, e2_s - 1)] + " <eTARGET> " + sent[e2_s:min(len(sent), e2_e)] + " </eTARGET> " + sent[min(len(sent), e2_e + 1):]
                
                e2_s, e2_e = identify_from_base_sent(pas.arg2, base_sent)
                od["opinions"][0]["Target"] = [[base_sent[e2_s:min(len(sent), e2_e)]], [f"{str(e2_s)}:{str(e2_e)}"]]

            if pas.pexp:
                res = re.search(pas.pexp, sent)
                e3_s, e3_e = res.span()
                sent = sent[0:max(0, e3_s - 1)] + " <ePEXP> " + sent[e3_s:min(len(sent), e3_e)] + " </ePEXP> " + sent[min(len(sent), e3_e + 1):]
                
                e3_s, e3_e = identify_from_base_sent(pas.pexp, base_sent)
                od["opinions"][0]["Polar_expression"] = [[base_sent[e3_s:min(len(sent), e3_e)]], [f"{str(e3_s)}:{str(e3_e)}"]]


            for tag, expression in [("SOURCE", pas.arg1), ("TARGET", pas.arg2), ("PEXP", pas.pexp)]:
                if expression is None:
                    # res = re.search("(\.|\!)\s*?(<\/.*>)?\s*?$", sent)
                    res = re.search("(\.|\!)", sent)
                    if res is None:
                        sent += " ."
                    res = re.search("(\.|\!)", sent)
                    e_nf_s, e_nf_e = res.span()
                    #print(f"{ e_nf_s} ; {e_nf_e}")
                    sent = sent[0:max(0, e_nf_s - 1)] + f" <e{tag}> " + sent[e_nf_s:min(len(sent), e_nf_e)] + f" </e{tag}> " + sent[min(len(sent), e_nf_e + 1):]
                    
            # print(od[i]["opinions"][0])
            
            assert all([tag in sent for tag in ["<eTARGET>", "</eTARGET>", "<eSOURCE>", "</eSOURCE>", "<ePEXP>", "</ePEXP>"]]), "Not all tags present in sentence, falling back to trivial."

        except Exception as e:
            print(f"Something went wrong with extraction, {str(e)}, \n with sent {str(sent)} and sample # {i}")
            print("Trivialised!")
            # spaceholder
            # entified_list.append("Neutral <eSOURCE> . </eSOURCE> <eTARGET> . </eTARGET> <ePEXP> . </ePEXP>")
            od["text"] = "Neutral . .. ..."
            entified_list.append("Neutral <eSOURCE> . </eSOURCE> <eTARGET> .. </eTARGET> <ePEXP> ... </ePEXP>")
            od["opinions"][0].update({ "Source": [["."], ["8:9"]] })
            od["opinions"][0].update({ "Target": [[".."], ["10:12"]] })
            od["opinions"][0].update({ "Polar_expression": [["..."], ["13:16"]] })
            ret_od.append(od)
            continue

        entified_list.append(sent)
        # print(od)
        ret_od.append(od)
    return entified_list, ret_od

test_sents = ["Macron hat die Frau geliebt!",
"Jakob liebt Brigitte .",
 "Der Mann weiss nicht mehr wo er ist .",
 "Viele Personen sind von Haifischen ermordet worden .",
 "Liebe .",
 "Peter greift Michaela auf .",]

# entified_list = generate_head_based_entity_sentences()

# print(entified_list)
# don't forget stripping!
# print("\n")
# X = {"tokens": [e.strip().split() for e in entified_list]}
# print(X)

# %%
tagged_ssa_sents, out_data_w_entities = generate_head_based_entity_sentences(ssa_sents, out_data)
# Out:
# 2912it [01:37, 28.31it/s]
# Something went wrong with extraction, 'NoneType' object has no attribute 'span',
#  with sent Nach 25 Minuten sche <eTARGET> ter </eTARGET>  der Dortmunder <eSOURCE> Captain </eSOURCE> erstmals an ter Stegen , aus fünf Metern nur . and sample # 2906
# Trivialised!
# 4814it [02:42, 28.91it/s]
# Something went wrong with extraction, Not all tags present in sentence, falling back to trivial.,
#  with sent  < <eTARGET> S </eTARGET> URCE> Ähnliches </eSOURCE> <ePEXP> gilt </ePEXP> für die S 24 , die von Zürich über den Flughafen stündlich bis nach Thayngen und nach Weinfelden verkehrt . and sample # 4809
# Trivialised!
# 5323it [02:59, 29.61it/s]

# %%
tokenized_ssa_sents = {"tokens": [e.strip().split() for e in tagged_ssa_sents]}

# %%
out_data_w_entities
# Out:
# [{'sent_id': '0',
#   'text': 'Finnland will sich dort auch für eine Verteuerung der Touristenvisa einsetzen .',
#   'opinions': [{'Source': [['Finnland'], ['0:8']],
#     'Target': [['Verteuerung'], ['38:49']],
#     'Polar_expression': [['einsetzen'], ['68:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': '( sda ) Eishockey Ottawa entlässt seinen Headcoach Guy Boucher ( 47 ) .',
#   'opinions': [{'Source': [['Eishockey'], ['8:17']],
#     'Target': [['Headcoach'], ['41:50']],
#     'Polar_expression': [['entlässt'], ['25:33']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Bei den israelischen Siedlungen im Westjordanland pfeift US-Präsident Trump aufs Völkerrecht .',
#   'opinions': [{'Source': [['Präsident'], ['60:69']],
#     'Target': [['Völkerrecht'], ['81:92']],
#     'Polar_expression': [['pfeift'], ['50:56']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Bei negativen Gedanken wie diesen wird die Personalfachfrau ständig von schlimmen Erinnerungen heimgesucht : « Denke ich daran , dass Nils sich infizieren könnte , sehe ich die schrecklichen Bilder vor mir , als er als Baby an der Herz-Lungen-Maschine angeschlossen war .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': 'Der Name verweist auf die Art , wie diese Temperatur bestimmt werden kann : indem man die Birne eines Thermometers ( bulb ) in ein nasses Tuch wickelt und dann schaut , welche Temperatur das Thermometer anzeigt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'Sanders versuchte zwar , die Corona-Krise als Argument zu benutzen , dass seine Forderung nach einer allgemeinen , staatlichen Krankenversicherung richtig sei .',
#   'opinions': [{'Source': [['Sanders'], ['0:7']],
#     'Target': [[], []],
#     'Polar_expression': [['benutzen'], ['58:66']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Der Trainer der New Jersey Devils sagte , er sehe den jungen Oberwalliser als zukünftigen « franchise player » und er glaube , dass Hischier irgendwann die Selke Trophy gewinnen werde .',
#   'opinions': [{'Source': [['Hischier'], ['132:140']],
#     'Target': [[], []],
#     'Polar_expression': [['gewinnen'], ['169:177']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Das Kuchi-Daaberettli mahnt aber \xad dennoch zur Vorsicht : Drotz Corona duen y hitte do my Schnitzelbangg singe und hoff , s däät glinge , eich zem Schmunzle z bringe .',
#   'opinions': [{'Source': [['Daaberettli'], ['10:21']],
#     'Target': [['Vorsicht'], ['47:55']],
#     'Polar_expression': [['mahnt'], ['22:27']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Labour-Abgeordnete standen der Reihe nach auf , um den Kreml zu schelten und Corbyn zwischen den Zeilen die Meinung zu sagen .',
#   'opinions': [{'Source': [['Abgeordnete'], ['7:18']],
#     'Target': [['Kreml'], ['55:60']],
#     'Polar_expression': [['schelten'], ['64:72']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Pécresse will die 35-Stunden-Woche abschaffen , das reguläre Pensionsalter von 62 auf 65 erhöhen und 200 ’ 000 Beamtenposten streichen .',
#   'opinions': [{'Source': [['Pécresse'], ['0:8']],
#     'Target': [[], []],
#     'Polar_expression': [['streichen'], ['125:134']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': 'Mit einem Abseitsstehen zöge die Schweiz mit Ländern wie den USA , Ungarn oder Österreich gleich , wo Kanzler Sebastian Kurz unter Druck der rechtspopulistischen Koalitionspartnerin FPÖ agiert .',
#   'opinions': [{'Source': [['Kanzler'], ['102:109']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': 'Nachdem Indiens Luftwaffe in der Nacht zum Dienstag zum ersten Mal seit 1971 einen Angriff auf pakistanischem Gebiet geflogen hatte , schoss Pakistan nach eigenen Angaben am Mittwoch zwei indische Kampfflugzeuge ab .',
#   'opinions': [{'Source': [['Pakistan'], ['141:149']],
#     'Target': [['Kampfflugzeuge'], ['197:211']],
#     'Polar_expression': [['schoss'], ['134:140']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Daneben freut sich Charlene , der Kelch ist an ihr vorübergegangen .',
#   'opinions': [{'Source': [['Kelch'], ['34:39']],
#     'Target': [[], []],
#     'Polar_expression': [['freut'], ['8:13']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Im Berufsauftrag hat die Bildungsdirektion pro Jahreslektion einen Faktor von 58 Arbeitsstunden für Vor- und Nachbereitung eingesetzt .',
#   'opinions': [{'Source': [['Bildungsdirektion'], ['25:42']],
#     'Target': [['Vor'], ['100:103']],
#     'Polar_expression': [['eingesetzt'], ['123:133']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Der schlaue Polit-Fuchs freute sich über seine Aufwertung auf der Weltbühne , machte aber weder in der Ukraine-Politik noch bei der Unterstützung der russischen Turk-Stream-Pipeline Konzessionen .',
#   'opinions': [{'Source': [['Fuchs'], ['18:23']],
#     'Target': [['Aufwertung'], ['47:57']],
#     'Polar_expression': [['freute'], ['24:30']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': '« Die Situation ist aussergewöhnlich , und es stellen sich viele neue Fragen » , sagt Robert Breiter , Generalsekretär des Schweizerischen Fussballverbands , « aber am Ende geht es auch bei diesem Wettbewerb um einen Pokal . » Das passt zu den Worten von Luzerns Sportchef Remo Meyer : « Es gibt keine optimale Lösung für alle .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Das BAG hat deshalb die Kantonsärzte angewiesen , die Teststrategie anzupassen .',
#   'opinions': [{'Source': [['BAG'], ['4:7']],
#     'Target': [['Teststrategie'], ['54:67']],
#     'Polar_expression': [['anzupassen'], ['68:78']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Und das tolle Ensemble haut mit seiner Spielfreude die Skepsis an dem Ding , das sie da spielen , weg .',
#   'opinions': [{'Source': [['Ensemble'], ['14:22']],
#     'Target': [['Skepsis'], ['55:62']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Die Polizei nutzte ein Mobilfunknetz , mit dem sie die Personen-ID per QR-Code auslesen konnte .',
#   'opinions': [{'Source': [['Polizei'], ['4:11']],
#     'Target': [['Personen'], ['55:63']],
#     'Polar_expression': [['nutzte'], ['12:18']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': 'Da würde auch die Europäische Union nicht immer gewinnen gegen die Schweiz .',
#   'opinions': [{'Source': [['Union'], ['30:35']],
#     'Target': [['Schweiz'], ['67:74']],
#     'Polar_expression': [['gewinnen'], ['48:56']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Gleiches gilt für die Ducati Multistrada Enduro , die sogar mit 158 PS aufwarten kann .',
#   'opinions': [{'Source': [['Gleiches'], ['0:8']],
#     'Target': [['Ducati'], ['22:28']],
#     'Polar_expression': [['gilt'], ['9:13']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Aus der Analyse der Tore und des Aushubs kommt das Center zum Schluss , die Tunnels könnten vermutlich sämtliche für Operationen benötigten Fahrzeuge der Basis aufnehmen , inklusive der mobilen Abschussrampen .',
#   'opinions': [{'Source': [['Tunnels'], ['76:83']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnehmen'], ['160:169']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Der Flughafen stellt sich im Weiteren auf den Standpunkt , dass der Bazl-Vorschlag eine massive Schwächung der Investitionskraft der Flughäfen Zürich und Genf zur Folge haben werde .',
#   'opinions': [{'Source': [['Vorschlag'], ['73:82']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Traumatisiert durch das Massaker vom August 2013 , bei dem Sicherheitskräfte auf dem Kairoer Rabaa-al-Adawiya-Platz weit über 800 Anhänger der Muslimbrüder töteten , und aufgerieben durch die Verhaftungen von Zehntausenden ihrer Mitglieder , sind die « ikhwan al-muslimin » in ihrem Mutterland heute politisch bedeutungslos .',
#   'opinions': [{'Source': [['Sicherheitskräfte'], ['59:76']],
#     'Target': [['Anhänger'], ['130:138']],
#     'Polar_expression': [['töteten'], ['156:163']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'Neun Tage zuvor hatte ein Amokläufer 1,4 Kilometer vom Stadion entfernt 58 Menschen ermordet .',
#   'opinions': [{'Source': [['Amokläufer'], ['26:36']],
#     'Target': [['Menschen'], ['75:83']],
#     'Polar_expression': [['ermordet'], ['84:92']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'US-Stars wie Rapperin Bhad Bhabie ( 18 ) jubeln über immer neue Einnahme-Rekorde : Die Rede ist von Millionenbeträgen innert weniger Stunden .',
#   'opinions': [{'Source': [['Stars'], ['3:8']],
#     'Target': [['Rekorde'], ['73:80']],
#     'Polar_expression': [['jubeln'], ['41:47']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': '« Das ist einfach nur geil » , freut sich Nelson Ferreira nach der Partie über den zweiten Finaleinzug in der Vereinsgeschichte des FC Thun .',
#   'opinions': [{'Source': [['Nelson'], ['42:48']],
#     'Target': [['Finaleinzug'], ['91:102']],
#     'Polar_expression': [['freut'], ['31:36']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Die einstige Regierungspartei Vereinigte Nationale Bewegung des früheren Präsidenten Micheil Saakaschwili und weitere Oppositionsparteien stellten sich auf die Seite der Protestierenden .',
#   'opinions': [{'Source': [['Regierungspartei'], ['13:29']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Maltas amtierender Premier Robert Abela , wie Muscat von der Labour Party , entschuldigte sich nun im Namen des Landes bei Daphnes Familie , bei ihrem Mann und ihren drei Söhnen , die alle um das Vermächtnis der Mutter kämpfen .',
#   'opinions': [{'Source': [['Premier'], ['19:26']],
#     'Target': [['Vermächtnis'], ['196:207']],
#     'Polar_expression': [['entschuldigte'], ['76:89']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'Es gebe für Bonuslandia keine Kosten-Nutzen-Rechnung , monierte denn auch der « Corriere » – um für eine generelle Steuersenkung zu plädieren .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Kein Ministerpräsident hat derartigen Druck aushalten müssen » , sagte Netanyahu .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['5:22']],
#     'Target': [['Druck'], ['38:43']],
#     'Polar_expression': [['aushalten'], ['44:53']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': 'In einer unberechenbaren , globalen Welt verspreche die Familie Sicherheit und Sinn .',
#   'opinions': [{'Source': [['Familie'], ['56:63']],
#     'Target': [['Sicherheit'], ['64:74']],
#     'Polar_expression': [['verspreche'], ['41:51']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'DUNJA MOUSTOPOULOS , MATTHIAS DUBACH Sie sagen Nein zu Tokio 2020 Mit Kanada und Australien haben die ersten zwei grossen Sommersport-Nationen wegen der Coronakrise den Olympia-Boykott angekündigt .',
#   'opinions': [{'Source': [['Sommersport'], ['122:133']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['185:196']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Zudem verfügten die Krankenversicherer über acht Milliarden Franken Reserven , falls die Zahl der Covid-19-Patienten nochmals stark ansteigen sollte .',
#   'opinions': [{'Source': [['Krankenversicherer'], ['20:38']],
#     'Target': [[], []],
#     'Polar_expression': [['verfügten'], ['6:15']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Die Wirte widersetzten sich den Massnahmen erneut .',
#   'opinions': [{'Source': [['Wirte'], ['4:9']],
#     'Target': [['Massnahmen'], ['32:42']],
#     'Polar_expression': [['widersetzten'], ['10:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Depardieus Anwalt hatte die Vorwürfe kurz nach deren Bekanntwerden zurückgewiesen .',
#   'opinions': [{'Source': [['Depardieus Anwalt'], ['0:17']],
#     'Target': [['Vorwürfe'], ['28:36']],
#     'Polar_expression': [['zurückgewiesen'], ['67:81']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Und Brandenburgs Ministerpräsident Dietmar Woidke ( SPD ) freute sich über die grösste private Investition in seinem Bundesland seit der Wiedervereinigung .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['17:34']],
#     'Target': [['Investition'], ['95:106']],
#     'Polar_expression': [['freute'], ['58:64']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'Und alle Gäste wussten Bescheid .',
#   'opinions': [{'Source': [['Gäste'], ['9:14']],
#     'Target': [['Bescheid'], ['23:31']],
#     'Polar_expression': [['wussten'], ['15:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Sein Vermögen verdiente der Unternehmer als Gründer und Lenker des Hörgeräteherstellers Phonak , der heute Sonova heisst .',
#   'opinions': [{'Source': [['Unternehmer'], ['28:39']],
#     'Target': [['Vermögen'], ['5:13']],
#     'Polar_expression': [['verdiente'], ['14:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Offensichtlich fürchten die Investoren , der sich ohnehin schon abzeichnende Ausschluss dieser speziellen Wertpapiere vom Handel in den USA könnte sich aufgrund der geopolitischen Spannungen noch beschleunigen .',
#   'opinions': [{'Source': [['Ausschluss'], ['77:87']],
#     'Target': [[], []],
#     'Polar_expression': [['fürchten'], ['15:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Die Grafik des Heftes entstand in Zusammenarbeit mit dem Zürcher Duo Hammer , das vor Ort ein Unterrichtsmodul zum Thema Layout durchführte .',
#   'opinions': [{'Source': [['Grafik'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [['entstand'], ['22:30']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Seither hat AUR laut Umfragen weiter an Zuspruch gewonnen .',
#   'opinions': [{'Source': [['AUR'], ['12:15']],
#     'Target': [['Zuspruch'], ['40:48']],
#     'Polar_expression': [['gewonnen'], ['49:57']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'So geht es jetzt aus dem Labor in die Welt hinaus , und die Menschen fürchten sich sehr vor seiner Gestalt .',
#   'opinions': [{'Source': [['Menschen'], ['60:68']],
#     'Target': [['Gestalt'], ['99:106']],
#     'Polar_expression': [['fürchten'], ['69:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Manafort stellte sich zugleich für die Mitarbeit mit dem Sonderermittler Robert Mueller zur Verfügung .',
#   'opinions': [{'Source': [['Manafort'], ['0:8']],
#     'Target': [['Mitarbeit'], ['39:48']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'Ende Mai hatte das Fedpol eine Niederlage einsteckten müssen : Damals hatte das Obergericht entschieden , nicht auf eine Beschwerde einzutreten , die sich gegen einen Rückweisungsentscheid des Berner Wirtschaftsgerichts « wegen schwerwiegender Verfahrensmängel » gerichtet hatte .',
#   'opinions': [{'Source': [['Obergericht'], ['80:91']],
#     'Target': [[], []],
#     'Polar_expression': [['einzutreten'], ['132:143']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Natürlich stellt das Coronavirus ein Risiko dar , wie auch die anhaltenden geopolitischen Spannungen .',
#   'opinions': [{'Source': [['Coronavirus'], ['21:32']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': '« Fake-News können hier in Kongo töten » , sagt der 27-jährige Mupfuni bestimmt .',
#   'opinions': [{'Source': [['Mupfuni'], ['63:70']],
#     'Target': [['Kongo'], ['27:32']],
#     'Polar_expression': [['töten'], ['33:38']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Musk war vom britischen Höhlentaucher Vernon Unsworth verklagt worden .',
#   'opinions': [{'Source': [['Höhlentaucher'], ['24:37']],
#     'Target': [[], []],
#     'Polar_expression': [['verklagt'], ['54:62']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'Die Händler von Ski , Snowboards und Schlitten freuen sich zwar ebenfalls über die frostigen Temperaturen , rechnen deswegen aber nicht mit einer deutlich höheren Nachfrage .',
#   'opinions': [{'Source': [['Händler'], ['4:11']],
#     'Target': [['Temperaturen'], ['93:105']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': '« Marini konnte seine Reifen besser schonen als ich » , sagte Lüthi .',
#   'opinions': [{'Source': [['Marini'], ['2:8']],
#     'Target': [['Reifen'], ['22:28']],
#     'Polar_expression': [['schonen'], ['36:43']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Das Gericht kommt zum Schluss , dass vier Artikel , die zwischen Dezember 2014 und September 2015 im « Blick » erschienen sind , die Persönlichkeit von Spiess-Hegglin verletzt haben .',
#   'opinions': [{'Source': [['Artikel'], ['42:49']],
#     'Target': [['Persönlichkeit'], ['133:147']],
#     'Polar_expression': [['verletzt'], ['167:175']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': 'Dass der Kanton keine genaueren Zahlen nennen kann , liegt an der Datenerfassung .',
#   'opinions': [{'Source': [['Kanton'], ['9:15']],
#     'Target': [['Zahlen'], ['32:38']],
#     'Polar_expression': [['nennen'], ['39:45']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Nachdem die Amerikaner neue Sanktionen angekündigt haben , schiesst Russland rhetorisch scharf zurück .',
#   'opinions': [{'Source': [['Russland'], ['68:76']],
#     'Target': [[], []],
#     'Polar_expression': [['schiesst'], ['59:67']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'In Baden-Württemberg hat die FDP mit 10,5 Prozent der Stimmen ihr bestes Wahlergebnis seit Jahrzehnten erreicht .',
#   'opinions': [{'Source': [['FDP'], ['29:32']],
#     'Target': [['Wahlergebnis'], ['73:85']],
#     'Polar_expression': [['erreicht'], ['103:111']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': 'Und die isländischen Fans sorgten mit ihrer Huh-Choreografie dafür , dass die Welt die Reykjavíker Skandale vergass .',
#   'opinions': [{'Source': [['Welt'], ['78:82']],
#     'Target': [['Reykjavíker'], ['87:98']],
#     'Polar_expression': [['vergass'], ['108:115']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Robert Payne widersetzte sich der Aufforderung .',
#   'opinions': [{'Source': [['Robert'], ['0:6']],
#     'Target': [['Aufforderung'], ['34:46']],
#     'Polar_expression': [['widersetzte'], ['13:24']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Der Faktor Mensch stellt die grösste Gefahrenquelle dar .',
#   'opinions': [{'Source': [['Faktor'], ['4:10']],
#     'Target': [['Gefahrenquelle'], ['37:51']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Zusammen mit zwei weiteren wichtigen kirchlichen Playern – der Römisch-Katholischen Zentralkonferenz und der Konferenz der Ordensgemeinschaften – hat sie an der Universität Zürich ein Forschungsprojekt zu Missbrauchsfällen seit 1950 in Auftrag gegeben : « Mit der Anerkennung des durch sexuelle Übergriffe im Kontext der römisch-katholischen Kirche in der Schweiz zugefügten Leids ist für die Kirche die Pflicht verbunden , das Geschehene aufzuarbeiten , seine Ursachen zu analysieren und daraus die Lehren für die Zukunft zu ziehen » , heisst es im Vertrag .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Für den Dienstag hatten die Oppositionsparteien gemeinsam mit Rebellen der Tories einen Vorstoss angekündigt , der ein ungeregeltes Ausscheiden aus der EU Ende Oktober verhindern soll .',
#   'opinions': [{'Source': [['Oppositionsparteien'], ['28:47']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['97:108']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Deshalb bricht der Vorsitzende die Befragung ab , kaum hat sie begonnen .',
#   'opinions': [{'Source': [['Vorsitzende'], ['19:30']],
#     'Target': [['Befragung'], ['35:44']],
#     'Polar_expression': [['bricht'], ['8:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Trump habe sich bei Maurer für die Rolle der Schweiz bei diplomatischen Beziehungen und bei der Vermittlung bei internationalen Konflikten bedankt .',
#   'opinions': [{'Source': [['Trump'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [['bedankt'], ['139:146']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'Das Verschwinden des lokalen Akutspitals löst vielerorts Unmut aus .',
#   'opinions': [{'Source': [['Verschwinden'], ['4:16']],
#     'Target': [['Unmut'], ['57:62']],
#     'Polar_expression': [['löst'], ['41:45']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Die jetzigen Protestaktionen finden in viel kleinerem und heterogenerem Rahmen statt , und da sie sich in unzähligen kleinen Städten im ganzen Land zutragen , sind sie nur schwer einzudämmen .',
#   'opinions': [{'Source': [['Protestaktionen'], ['13:28']],
#     'Target': [[], []],
#     'Polar_expression': [['finden'], ['29:35']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'In knapp acht Monaten wird das Vereinigte Königreich formal aus der EU austreten .',
#   'opinions': [{'Source': [['Königreich'], ['42:52']],
#     'Target': [['EU'], ['68:70']],
#     'Polar_expression': [['austreten'], ['71:80']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'Gekippt wurde neben dem von seiner islamisch-konservativen Regierung propagierten « Untreue-Artikel » auch die Todesstrafe .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'In den Sechzigern stellte sich auch der internationale Erfolg ein : Hugs Ölbilder wurden in die ganze Welt verkauft ; auch die britische Königin erstand zwei seiner Werke nach einer Ausstellung in London .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['erstand'], ['145:152']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Planung , Verhandlung , politische Plattform , runder Tisch – all diese Wörter benutzen Populisten nie .',
#   'opinions': [{'Source': [['Wörter'], ['72:78']],
#     'Target': [['Populisten'], ['88:98']],
#     'Polar_expression': [['benutzen'], ['79:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Nach vier Jahren als Präsident stellt sich Daniel Frutig an der Generalversammlung am 26. April nicht mehr zur Wahl .',
#   'opinions': [{'Source': [['Daniel'], ['43:49']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': 'Nicht einfach nach Isolationismus , denn Trump plädiert keineswegs für den Rückzug aus der Welt , sondern er will die international gültigen Spielregeln nach seinem Gusto umgestalten .',
#   'opinions': [{'Source': [['Trump'], ['41:46']],
#     'Target': [[], []],
#     'Polar_expression': [['plädiert'], ['47:55']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Die australische Regierung hat Nothilfen für die tägliche Versorgung von Bauernfamilien angekündigt , die um die Existenz ihrer Farmen kämpfen .',
#   'opinions': [{'Source': [['Regierung'], ['17:26']],
#     'Target': [['Nothilfen'], ['31:40']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'RED U21-Nati-Trainer Mauro Lustrinelli freut sich auf die EM .',
#   'opinions': [{'Source': [['Trainer'], ['13:20']],
#     'Target': [['EM'], ['58:60']],
#     'Polar_expression': [['freut'], ['39:44']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': 'Der Seitenhieb galt dem Führungsduo der Koalition : Calin Popescu Tariceanu , in Personalunion Vorsitzender der liberalen Kleinpartei Alde und Senatspräsident , steht wegen Meineids vor \xad Gericht .',
#   'opinions': [{'Source': [['Seitenhieb'], ['4:14']],
#     'Target': [['Führungsduo'], ['24:35']],
#     'Polar_expression': [['galt'], ['15:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Der jüngste Unternehmenszweig der Sportholding will sich der Planung von Eishockeykarrieren widmen und die Spieler auch darüber hinaus beratend begleiten .',
#   'opinions': [{'Source': [['Unternehmenszweig'], ['12:29']],
#     'Target': [['Planung'], ['61:68']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Die Hemmschwelle , mit den Lehrperson den Kontakt aufzunehmen , ist gesunken .',
#   'opinions': [{'Source': [['Hemmschwelle'], ['4:16']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'An der alljährlichen Entwicklerkonferenz , wegen Corona erstmals ein Online-Event , hat der Konzern daher die Abkehr von Intel angekündigt .',
#   'opinions': [{'Source': [['Konzern'], ['92:99']],
#     'Target': [['Abkehr'], ['110:116']],
#     'Polar_expression': [['angekündigt'], ['127:138']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'In den zehn ukrainischen Provinzen , die an Russland und die Moldau grenzen , gilt derzeit das Kriegsrecht .',
#   'opinions': [{'Source': [['Kriegsrecht'], ['95:106']],
#     'Target': [[], []],
#     'Polar_expression': [['gilt'], ['78:82']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'So gewinnt die Eigenverantwortung in der dritten Säule an Bedeutung und ruft nach verbesserten Anreizen und mehr Möglichkeiten .',
#   'opinions': [{'Source': [['Eigenverantwortung'], ['15:33']],
#     'Target': [['Bedeutung'], ['58:67']],
#     'Polar_expression': [['gewinnt'], ['3:10']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Allerdings stellen sich rechtliche Fragen bei der Umsetzung .',
#   'opinions': [{'Source': [['Fragen'], ['35:41']],
#     'Target': [['Umsetzung'], ['50:59']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Immer auch auf die Gefahr hin , dass Kritiker uns an den Öko-Pranger stellen und uns die liberale Gesinnung absprechen .',
#   'opinions': [{'Source': [['Kritiker'], ['37:45']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': 'Einerseits stellen sich Länder , die es selber mit den Menschenrechten nicht so genau nehmen , an Pekings Seite .',
#   'opinions': [{'Source': [['Länder'], ['24:30']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'Auch mit der Wahl von Ashraf Ghani zum Präsidenten Afghanistans im Jahr 2014 stellte sich Hoffnung auf Besserung ein .',
#   'opinions': [{'Source': [['Hoffnung'], ['90:98']],
#     'Target': [['Besserung'], ['103:112']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Inzwischen ist zumindest bekannt , dass die SPD den Minister stellen wird .',
#   'opinions': [{'Source': [['SPD'], ['44:47']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Seine Worte konnte man so interpretieren , dass dann der Entscheid über seine politische Zukunft fallen wird und sich beide Seiten bis dahin mit öffentlichen Äusserungen zurückhalten werden .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'Die Technologie werde somit die Funktionen der heutigen Intermediäre zu grossen Teilen übernehmen und zwingt damit bisherige Vermittler , ihr Geschäftsmodell anzupassen .',
#   'opinions': [{'Source': [['Technologie'], ['4:15']],
#     'Target': [['Geschäftsmodell'], ['142:157']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': 'Der Strassenhändler besorgte sich Benzin , stellte sich vor die Polizeipräfektur und steckte sich in Brand .',
#   'opinions': [{'Source': [['Strassenhändler'], ['4:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Madonna entschuldigt sich bei ihren Anhängern : « Ich muss mich erholen » , erklärt sie .',
#   'opinions': [{'Source': [['Madonna'], ['0:7']],
#     'Target': [['Anhängern'], ['36:45']],
#     'Polar_expression': [['entschuldigt'], ['8:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Die Schweizerin wehrt gegen Alizé Cornet zwei Matchbälle ab und dreht dann die Partie .',
#   'opinions': [{'Source': [['Schweizerin'], ['4:15']],
#     'Target': [['Alizé'], ['28:33']],
#     'Polar_expression': [['wehrt'], ['16:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Waffenlieferungen an Kriegsparteien verletzen grundsätzlich das Neutralitätsgebot nach Haager Kriegsrecht .',
#   'opinions': [{'Source': [['Waffenlieferungen'], ['0:17']],
#     'Target': [['Neutralitätsgebot'], ['64:81']],
#     'Polar_expression': [['verletzen'], ['36:45']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Villiger zog das Verteidigungsdispositiv auf .',
#   'opinions': [{'Source': [['Villiger'], ['0:8']],
#     'Target': [['Verteidigungsdispositiv'], ['17:40']],
#     'Polar_expression': [['zog'], ['9:12']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': 'Der Schweizer Verband widersetzte sich zuerst aus scheinformalen Gründen dem Transfer in den Profifussball , das italienische Parlament verfügte eine Importsperre , weil schon zu viele Ausländer im Land kickten , und als Vonlanthen 1955 doch in Mailand eintraf , hatten sie einen Bomber erwartet und nicht diesen schmalen , leichtfüssigen Artisten , der dann häufig auf der Ersatzbank sitzen blieb .',
#   'opinions': [{'Source': [['Parlament'], ['126:135']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Zudem stellen sich ethische Fragen .',
#   'opinions': [{'Source': [['Fragen'], ['28:34']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Das Neutralitätsprinzip habe die Schweizer Bevölkerung seit über 200 Jahren vor blutigen Konflikten bewahrt .',
#   'opinions': [{'Source': [['Neutralitätsprinzip'], ['4:23']],
#     'Target': [['Konflikten'], ['89:99']],
#     'Polar_expression': [['bewahrt'], ['100:107']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Die Wirtenfamilie Christen freut sich über die Wiedereröffnung : Angela ( l.',
#   'opinions': [{'Source': [['Wirtenfamilie'], ['4:17']],
#     'Target': [['Wiedereröffnung'], ['47:62']],
#     'Polar_expression': [['freut'], ['27:32']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Immobilien , wie der Name schon sagt , widersetzen sich dem fliessenden Wandel , also muss eine andere flexible Veränderungsmöglichkeit her , nämlich die Zwischennutzung .',
#   'opinions': [{'Source': [['Immobilien'], ['0:10']],
#     'Target': [['Wandel'], ['72:78']],
#     'Polar_expression': [['widersetzen'], ['39:50']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': 'Im Gegensatz zu den meisten anderen Krankenhäusern hat das Spital gar Boni abgeschafft , die sich an den Operationszahlen der Ärzte bemessen .',
#   'opinions': [{'Source': [['Spital'], ['59:65']],
#     'Target': [['Boni'], ['70:74']],
#     'Polar_expression': [['abgeschafft'], ['75:86']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Trump beschimpfte den 33-jährigen Taylor umgehend als einen « Niemand » sowie einen « Widerling , der nie im Weissen Haus gearbeitet hat » .',
#   'opinions': [{'Source': [['Trump'], ['0:5']],
#     'Target': [['Taylor'], ['34:40']],
#     'Polar_expression': [['beschimpfte'], ['6:17']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'Der hohe Feiertag findet immer am ersten Sonntag nach dem ersten Vollmond im Frühling statt .',
#   'opinions': [{'Source': [['Feiertag'], ['9:17']],
#     'Target': [['Frühling'], ['77:85']],
#     'Polar_expression': [['findet'], ['18:24']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': 'Am 9. Februar finden dazu in den beiden Kantonen zwei separate Volksabstimmungen statt .',
#   'opinions': [{'Source': [['Volksabstimmungen'], ['63:80']],
#     'Target': [[], []],
#     'Polar_expression': [['finden'], ['14:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Opfer Brigitte Peyer und ihr Lebenspartner Rudolf Naef wurden im Dezember vom Marokkaner Moestafa K. überfallen .',
#   'opinions': [{'Source': [['Marokkaner'], ['78:88']],
#     'Target': [[], []],
#     'Polar_expression': [['überfallen'], ['101:111']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': 'Brosi plädierte zuletzt für etwas mehr Management .',
#   'opinions': [{'Source': [['Brosi'], ['0:5']],
#     'Target': [['Management'], ['39:49']],
#     'Polar_expression': [['plädierte'], ['6:15']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Sobald die Briten aus der EU austreten , schrumpft nach der Wahl die Grösse des Parlaments auf 705 Abgeordnete .',
#   'opinions': [{'Source': [['Grösse'], ['69:75']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Als Qualitätsaktien gelten Valoren von Unternehmen mit einem geringen Verschuldungsgrad , die mit einer grossen Zuverlässigkeit solide Gewinne erzielen und sich auch in einem wirtschaftlich schwierigen Umfeld behaupten können .',
#   'opinions': [{'Source': [['Valoren'], ['27:34']],
#     'Target': [['Qualitätsaktien'], ['4:19']],
#     'Polar_expression': [['gelten'], ['20:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Das Trainingszentrum verfügt über Zimmer .',
#   'opinions': [{'Source': [['Trainingszentrum'], ['4:20']],
#     'Target': [['Zimmer'], ['34:40']],
#     'Polar_expression': [['verfügt'], ['21:28']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Lilian Carpenter , Zürich Im Kommentar stellt der Autor die Frage : « War es erweiterter Suizid ? » Ich finde es unsäglich , dass mit diesem Begriff immer noch so fahrlässig umgegangen wird !',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Begriff'], ['141:148']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': 'Darin soll auch die direkt betroffene Bevölkerung Gehör finden .',
#   'opinions': [{'Source': [['Bevölkerung'], ['38:49']],
#     'Target': [['Gehör'], ['50:55']],
#     'Polar_expression': [['finden'], ['56:62']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': '( sda ) Sozialhilfe Die Co-Präsidenten der Schweizerischen Konferenz für Sozialhilfe ( Skos ) , Therese Frösch und Felix Wolffers , haben nach fünf Jahren im Amt ihren Rücktritt auf Mai 2019 angekündigt .',
#   'opinions': [{'Source': [['Präsidenten'], ['27:38']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['191:202']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'Damit rückt der angekündigte , grund \xad - legende Strategiewechsel in weite Ferne : Ursprünglich wollte der Bundesrat im zweiten Teil der Energiewende die Förderbeiträge sukzessive abschaffen und stattdessen ein Lenkungssystem einführen .',
#   'opinions': [{'Source': [['Bundesrat'], ['107:116']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'Bolsonaro hat als eine seiner ersten Amtshandlungen das Kulturministerium abschaffen lassen , nicht , weil ihm Kultur unwichtig ist , im Gegenteil : Er und seine Regierung nutzen sie , um sich bei ihrer Wählerschaft zu profilieren .',
#   'opinions': [{'Source': [['Bolsonaro'], ['0:9']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Dieser Frau vertraut Macron nun seine Regierungskommunikation an .',
#   'opinions': [{'Source': [['Macron'], ['21:27']],
#     'Target': [['Frau'], ['7:11']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': '« Nachdem der Bundesrat den Lockdown angekündigt hatte , bestellten plötzlich so viele Leute bei uns wie noch nie » , sagt Vera Kessens .',
#   'opinions': [{'Source': [['Leute'], ['87:92']],
#     'Target': [['Lockdown'], ['28:36']],
#     'Polar_expression': [['bestellten'], ['57:67']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Für rasche Hilfe plädieren auch SP-Nationalrat Mathias Reynard und SVP-Ständerat Hannes Germann , die Präsidenten der Kulturkommissionen der Eidgenössischen Räte , die Parmelin am Dienstag trafen .',
#   'opinions': [{'Source': [['Nationalrat'], ['35:46']],
#     'Target': [['Hilfe'], ['11:16']],
#     'Polar_expression': [['plädieren'], ['17:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'Ab dato strich Depp astronomische Gagen ein und widmete sich Lieblingsprojekten wie etwa « Finding Neverland » von Marc Forster ( 2004 ) .',
#   'opinions': [{'Source': [['Depp'], ['15:19']],
#     'Target': [[], []],
#     'Polar_expression': [['widmete'], ['48:55']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Bern – Am Sonntagabend haben zwei Unbekannte einen Tankstellenshop an der Fellerstrasse überfallen .',
#   'opinions': [{'Source': [['Unbekannte'], ['34:44']],
#     'Target': [['Tankstellenshop'], ['51:66']],
#     'Polar_expression': [['überfallen'], ['88:98']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'Aryzta hat den Verkauf von Picard schon vor einiger Zeit angekündigt , den richtigen Zeitpunkt dafür aber noch nicht gefunden .',
#   'opinions': [{'Source': [['Aryzta'], ['0:6']],
#     'Target': [['Verkauf'], ['15:22']],
#     'Polar_expression': [['angekündigt'], ['57:68']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'Die Regierung mahnte Ende Juni bereits die an Erdbeben- , Flut- und Sturmkatastrophen gewöhnten Japaner , sich während der Regenzeit auf Überschwemmungen und Erdrutsche einzustellen .',
#   'opinions': [{'Source': [['Regierung'], ['4:13']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'Die Spitze der SP stellte sich zwar früh hinter den kompromisslosen Kurs der Gewerkschaften , hat sich inzwischen aber im Tonfall gemässigt .',
#   'opinions': [{'Source': [['Spitze'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Manche Dirigenten überrumpeln das Publikum , indem sie starten , sobald sie auf dem Podium angelangt sind ; andere zelebrieren eine feierliche Stille , bevor sie loslegen .',
#   'opinions': [{'Source': [['Dirigenten'], ['7:17']],
#     'Target': [['Publikum'], ['34:42']],
#     'Polar_expression': [['überrumpeln'], ['18:29']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Einige Firmen beschweren sich aber über eine falsche Einordnung , etwa der Süsswarenhersteller Storck , zu dessen Portfolio Marken wie Toffifee , Merci , Knoppers oder Nimm 2 gehören .',
#   'opinions': [{'Source': [['Firmen'], ['7:13']],
#     'Target': [['Einordnung'], ['53:63']],
#     'Polar_expression': [['beschweren'], ['14:24']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Brasilien Mitten in der Pandemie wollte der Präsident den Gesundheitsminister entlassen .',
#   'opinions': [{'Source': [['Präsident'], ['44:53']],
#     'Target': [['Gesundheitsminister'], ['58:77']],
#     'Polar_expression': [['entlassen'], ['78:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Denens VD – Eine Explosion hat am frühen Sonntagmorgen im Kanton Waadt eine von Swisscom und Salt genutzte Handy-Antenne zerstört .',
#   'opinions': [{'Source': [['Explosion'], ['17:26']],
#     'Target': [['Antenne'], ['113:120']],
#     'Polar_expression': [['zerstört'], ['121:129']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Das Gericht hat deshalb zu Recht von dieser extremen Massnahme abgesehen .',
#   'opinions': [{'Source': [['Gericht'], ['4:11']],
#     'Target': [['Massnahme'], ['53:62']],
#     'Polar_expression': [['abgesehen'], ['63:72']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Eine ausgeklügelte Lüftungstechnik sollte Ansteckungen verhindern .',
#   'opinions': [{'Source': [['Lüftungstechnik'], ['19:34']],
#     'Target': [['Ansteckungen'], ['42:54']],
#     'Polar_expression': [['verhindern'], ['55:65']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Die Justizdirektion stellte sich auf den Standpunkt , « angesichts des bisherigen Vollzugsverlaufs , der diagnostizierten Persönlichkeitsstörung und der Anlassdelikte » sei eine « möglichst enge Betreuung und Beobachtung » des Gefangenen unabdingbar .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Als er schliesslich zu seiner Gruppe stösst , hetzen die Schüler beinahe im Laufschritt in Richtung Bahnhofstrasse .',
#   'opinions': [{'Source': [['Schüler'], ['57:64']],
#     'Target': [[], []],
#     'Polar_expression': [['hetzen'], ['46:52']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'Das AMS-Management lässt jedoch durchblicken , dass man dies einfach auch so lösen könne , indem man sicherstellt , dass ein Käufer diese Konditionen einhält .',
#   'opinions': [{'Source': [['Käufer'], ['125:131']],
#     'Target': [['Konditionen'], ['138:149']],
#     'Polar_expression': [['einhält'], ['150:157']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Erfreulich : Im Vergleich mit der gesamten Schweiz achten in der Stadt Zürich prozentual mehr Menschen auf gesundes und ausgewogenes Essen .',
#   'opinions': [{'Source': [['Menschen'], ['94:102']],
#     'Target': [['Essen'], ['133:138']],
#     'Polar_expression': [['achten'], ['51:57']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '126',
#   'text': 'Mit seinem Charisma erreicht der Dirigent jedoch viel mehr als eine bloss « korrekte » Interpretation : Dieses Orchester ist hoch motiviert , spielt leidenschaftlich und identifiziert sich mit den Affekten der Protagonisten .',
#   'opinions': [{'Source': [['Orchester'], ['111:120']],
#     'Target': [['Interpretation'], ['87:101']],
#     'Polar_expression': [['erreicht'], ['20:28']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '127',
#   'text': 'Nun kommen mexikanische Forscher zu uns , um sich dem Schmuck zu widmen . » Die k. u. k. Monarchie liess sich die Sammlerstücke und Trophäen aus aller Welt etwas kosten .',
#   'opinions': [{'Source': [['Monarchie'], ['89:98']],
#     'Target': [['Schmuck'], ['54:61']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '128',
#   'text': 'Nach missglückten Aktionen von Jérôme Boateng und dem herauseilenden Neuer warf sich David Alaba in einen Schuss von Werner und verhinderte das 0 : 1 ( 49. ) .',
#   'opinions': [{'Source': [['David'], ['85:90']],
#     'Target': [[], []],
#     'Polar_expression': [['verhinderte'], ['128:139']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '129',
#   'text': '« Obwohl man im Gesundheitswesen der Maske immer zu hundert Prozent vertraute , wurde sie vom Bundesrat über Wochen verteufelt » , wundert sich Martullo gegenüber der NZZ : « Später fehlte den Leuten deshalb der Mut , freiwillig Masken zu tragen .',
#   'opinions': [{'Source': [['Mut'], ['212:215']],
#     'Target': [['Leuten'], ['193:199']],
#     'Polar_expression': [['fehlte'], ['182:188']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '130',
#   'text': 'In Deutschland hat das Bundesverfassungsgericht die Regierung im April angewiesen , das Klimaschutzgesetz zu verschärfen .',
#   'opinions': [{'Source': [['Bundesverfassungsgericht'], ['23:47']],
#     'Target': [['Klimaschutzgesetz'], ['88:105']],
#     'Polar_expression': [['verschärfen'], ['109:120']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '131',
#   'text': 'Geführt wird die Anklage vorrangig von Menschen , deren Moral über die ökonomische Urteilskraft triumphiert und die alles Geld verachten , das nicht ihr eigenes ist .',
#   'opinions': [{'Source': [['Moral'], ['56:61']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '132',
#   'text': 'Und Schulleiter Hannes Britschgi freute sich : « Von diesem Jahrgang wird man noch viel hören . » Absolventin Karin Frautschi ( 24 ) freut sich auf die Zukunft : « Es war eine mega spannende , vielschichtige Zeit .',
#   'opinions': [{'Source': [['Absolventin'], ['98:109']],
#     'Target': [['Zukunft'], ['152:159']],
#     'Polar_expression': [['freut'], ['33:38']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '133',
# ...
#   'opinions': [{'Source': [['Müller'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['entschuldigt'], ['45:57']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '955',
#   'text': 'Ein Zusammenschluss von « Revolutionären Organisationen und Einzelpersonen aus Zürich » ruft hingegen dazu auf , die Strassen nicht aufzugeben .',
#   'opinions': [{'Source': [['Zusammenschluss'], ['4:19']],
#     'Target': [['Strassen'], ['117:125']],
#     'Polar_expression': [['aufzugeben'], ['132:142']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '956',
#   'text': 'Die Klimatologen warnen vor den Auswirkungen solcher Luftströme auf das noch bestehende Larsen-C-Schelfeis , das grösste Eisschelf der Antarktischen Halbinsel .',
#   'opinions': [{'Source': [['Klimatologen'], ['4:16']],
#     'Target': [['Auswirkungen'], ['32:44']],
#     'Polar_expression': [['warnen'], ['17:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '957',
#   'text': 'Dabei fehlt ausgerechnet ihr erfahrenster Mann : Blerim Dzemaili ( 36 ) ist in Zürich geblieben , den Ex-Nati-Star plagen noch immer Wadenprobleme .',
#   'opinions': [{'Source': [['Wadenprobleme'], ['133:146']],
#     'Target': [[], []],
#     'Polar_expression': [['plagen'], ['115:121']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': 'Zudem würde sich für Bund , Parlament und Steuerzahlende eine Reihe von anspruchsvollen Fragen in Bezug auf Führung , Aufsicht und Finanzierung dieser neuen Staatsbank stellen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Bund'], ['21:25']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Begonnen hat alles vor gut einer Woche , als die grosse Supermarktkette Leclerc eine Senkung des Preises für eine Baguette ankündigte : auf 29 Cent , zurzeit etwa 30 Rappen .',
#   'opinions': [{'Source': [['Supermarktkette'], ['56:71']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Dieser Tage hat Präsident Aleksandar Vucic nun sogar finanzielle Anreize zur Immunisierung angekündigt .',
#   'opinions': [{'Source': [['Präsident'], ['16:25']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['91:102']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Die Affäre , die letztes Jahr zum Sturz des Präsidenten Gottfried Locher führte , hat die Evangelisch-reformierte Kirche der Schweiz ( EKS ) in eine tiefe Krise gestürzt und ihr einen gewaltigen Reputationsschaden eingebracht .',
#   'opinions': [{'Source': [['Affäre'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [['gestürzt'], ['161:169']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Er hatte Anfang November bei den ZSC Lions für die kommenden zwei Saisons als Nummer 2 neben Lukas Flüeler unterschrieben – sein Auftritt war vielleicht das Einzige , worüber sich die Lions-Fans heimlich freuen konnten .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['unterschrieben'], ['107:121']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'Analytiker fürchten sich vor einem Passus , der der Energieindustrie grossen Schaden zufügen könnte .',
#   'opinions': [{'Source': [['Analytiker'], ['0:10']],
#     'Target': [['Passus'], ['35:41']],
#     'Polar_expression': [['fürchten'], ['11:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Sieben Personen erlitten Rauchgasvergiftungen .',
#   'opinions': [{'Source': [['Personen'], ['7:15']],
#     'Target': [['Rauchgasvergiftungen'], ['25:45']],
#     'Polar_expression': [['erlitten'], ['16:24']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Im Nachwort des soeben erschienenen Fotobuches heisst es : « Ein Blick offenbart nur einen Bruchteil dessen , was zu sehen ist .',
#   'opinions': [{'Source': [['Blick'], ['65:70']],
#     'Target': [['Bruchteil'], ['91:100']],
#     'Polar_expression': [['offenbart'], ['71:80']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Ursula von der Leyen muss nun rasch Ersatz finden .',
#   'opinions': [{'Source': [['Ursula'], ['0:6']],
#     'Target': [['Ersatz'], ['36:42']],
#     'Polar_expression': [['finden'], ['43:49']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Beuys äusserte in diesem Kontext , er arbeite mit Tieren , um unsichtbare Kräfte erlebbar zu machen .',
#   'opinions': [{'Source': [['Beuys'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Fünftes Kind im Bauch : Brigitte Nielsen freut sich auf Nachwuchs .',
#   'opinions': [{'Source': [['Brigitte'], ['24:32']],
#     'Target': [['Nachwuchs'], ['56:65']],
#     'Polar_expression': [['freut'], ['41:46']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': 'Fussball Die Schweizer Marketingagentur Infront hat einen leitenden Angestellten entlassen , nachdem es bei Bandenwerbung bei deutschen Länderspielen zu Unregelmässigkeiten gekommen sein soll .',
#   'opinions': [{'Source': [['Marketingagentur'], ['23:39']],
#     'Target': [['Angestellten'], ['68:80']],
#     'Polar_expression': [['entlassen'], ['81:90']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Shaqiri entschuldigte sich Monate später ziemlich nonchalant für seine Geste – frei nach dem Motto : « Das gehört alles zu mir .',
#   'opinions': [{'Source': [['Shaqiri'], ['0:7']],
#     'Target': [['Geste'], ['71:76']],
#     'Polar_expression': [['entschuldigte'], ['8:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Dieser Krieg wurde geführt , um Dachau abzuschaffen und all die anderen Orte wie Dachau , alles , wofür Dachau steht .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Dachau'], ['32:38']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Das Treffen mit dem Insider zeigt , dass es in der Branche heikel sein kann , Kritik an China zu äussern .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Die Kaserne in Dübendorf erreichte das Virus vergangene Woche .',
#   'opinions': [{'Source': [['Kaserne'], ['4:11']],
#     'Target': [['Virus'], ['39:44']],
#     'Polar_expression': [['erreichte'], ['25:34']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Ein Zweitligist haut Österreichs Rekordmeister raus .',
#   'opinions': [{'Source': [['Zweitligist'], ['4:15']],
#     'Target': [['Rekordmeister'], ['33:46']],
#     'Polar_expression': [['haut'], ['16:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Das Bundesgericht hält fest , das Obergericht habe die Umstände der früheren Strafen und Zwangsmassnahmen nicht ausreichend aufgearbeitet .',
#   'opinions': [{'Source': [['Obergericht'], ['34:45']],
#     'Target': [['Umstände'], ['55:63']],
#     'Polar_expression': [['aufgearbeitet'], ['124:137']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Die Parlamentsdienste sorgen für Stunk in der Wandelhalle : Die Dienstleister der Bundesverwaltung verweigerten GLP-Nationalrat Martin Bäumle ( 55 ) die Annahme einer parlamentarischen Initiative .',
#   'opinions': [{'Source': [['Dienstleister'], ['64:77']],
#     'Target': [['Nationalrat'], ['116:127']],
#     'Polar_expression': [['verweigerten'], ['99:111']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Die Schuldenbremse gibt nun vor , dass der Bund innert 6 Jahren 25 bis 30 Mrd. Fr. tilgen muss .',
#   'opinions': [{'Source': [['Bund'], ['43:47']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Zudem wird das Land mit 282 Milliarden Euro eine rekordhohe Summe an neuen Krediten an den Märkten aufnehmen .',
#   'opinions': [{'Source': [['Land'], ['15:19']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnehmen'], ['99:108']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Auch verträgt sich eine zu schroffe Anti-Migrations-Politik nur schwer mit den humanitären Grundsätzen einer christlich-sozialen Partei .',
#   'opinions': [{'Source': [['Politik'], ['52:59']],
#     'Target': [[], []],
#     'Polar_expression': [['verträgt'], ['5:13']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Dabei gelangte sie zum Schluss , Lauber habe verschiedene Amtspflichten verletzt .',
#   'opinions': [{'Source': [['Lauber'], ['33:39']],
#     'Target': [['Amtspflichten'], ['58:71']],
#     'Polar_expression': [['verletzt'], ['72:80']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Die Türkei wiederum hat den deutschen Botschafter einbestellt , um sich über die Attacken gegen ihre Landsleute zu beschweren .',
#   'opinions': [{'Source': [['Türkei'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Fragen stellen sich eher hinsichtlich der Effektivität der Kontrolle .',
#   'opinions': [{'Source': [['Fragen'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Ein solches Niveau wie jetzt gab es vorher nicht . » Letzten Samstag aber stürzte Suter im Super-G-Training , erlitt schwere Knochenprellungen an den Schienbeinen und Schürfwunden im Gesicht .',
#   'opinions': [{'Source': [['Suter'], ['82:87']],
#     'Target': [['Knochenprellungen'], ['125:142']],
#     'Polar_expression': [['stürzte'], ['74:81']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Keine zwei Jahre später ging « Smokin ’ Joe » beim Titelkampf gegen den übermächtigen Herausforderer George Foreman gleich sechsmal zu Boden , ehe der Ringrichter das Gemetzel Mitte der zweiten Runde abbrach .',
#   'opinions': [{'Source': [['Ringrichter'], ['151:162']],
#     'Target': [['Gemetzel'], ['167:175']],
#     'Polar_expression': [['abbrach'], ['200:207']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Von Anfang an beharrt Bora Ćosić auf der Absurdität menschlicher Existenz ; Samuel Becketts als Clownerie getarnte Illusionslosigkeit und Freuds Tiefenpsychologie werden seine ständigen Begleiter .',
#   'opinions': [{'Source': [['Bora'], ['22:26']],
#     'Target': [['Absurdität'], ['41:51']],
#     'Polar_expression': [['beharrt'], ['14:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Ein Mann sticht die Oberbürgermeisterin an einem Info-Stand der CDU nieder und verletzt weitere umstehende Personen .',
#   'opinions': [{'Source': [['Mann'], ['4:8']],
#     'Target': [['Personen'], ['107:115']],
#     'Polar_expression': [['verletzt'], ['79:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Nach dem glimpflichen Ausgang dieses Dramas und der Rettungsaktion von noch nie gesehenem Ausmass stellt sich die Frage , wie solch ein Horrorszenario in Zukunft verhindert werden kann .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['verhindert'], ['162:172']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Nach Ansicht der Richter hat die Untersuchungshaft das Recht auf persönliche Freiheit und Sicherheit sowie das Recht auf Meinungs- und Pressefreiheit verletzt .',
#   'opinions': [{'Source': [['Untersuchungshaft'], ['33:50']],
#     'Target': [['Recht'], ['55:60']],
#     'Polar_expression': [['verletzt'], ['150:158']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'Syrien und sein Verbündeter Russland hatten die Vorwürfe stets zurückgewiesen und von einer « inszenierten Attacke » gesprochen .',
#   'opinions': [{'Source': [['Syrien'], ['0:6']],
#     'Target': [['Vorwürfe'], ['48:56']],
#     'Polar_expression': [['zurückgewiesen'], ['63:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Für die damalige Behandlung von Littlefeather hat sich die Oscar-Akademie nun entschuldigt – fast 50 Jahre nach dem Vorfall .',
#   'opinions': [{'Source': [['Akademie'], ['65:73']],
#     'Target': [['Behandlung'], ['17:27']],
#     'Polar_expression': [['entschuldigt'], ['78:90']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Für einigen Wirbel hatte kurz vor der Ernennung allerdings noch ein anonymes Schreiben gesorgt , in dem Bar berufliches Fehlverhalten in zwei Fällen vorgeworfen wurde .',
#   'opinions': [{'Source': [['Schreiben'], ['77:86']],
#     'Target': [['Wirbel'], ['12:18']],
#     'Polar_expression': [['gesorgt'], ['87:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Die Kantone stellten sich nicht gegen eine Umsetzung der Sanktionen , betont Tännler .',
#   'opinions': [{'Source': [['Kantone'], ['4:11']],
#     'Target': [['Umsetzung'], ['43:52']],
#     'Polar_expression': [['stellten'], ['12:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Der Tag war fast vorbei , und die Spieler von Real jubelten noch immer über einen Sieg , an den sie vielleicht nicht mal mehr selbst geglaubt hatten .',
#   'opinions': [{'Source': [['Spieler'], ['34:41']],
#     'Target': [['Sieg'], ['82:86']],
#     'Polar_expression': [['jubelten'], ['51:59']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Offiziell hat Donald Trump seine Kandidatur für 2024 nicht angekündigt .',
#   'opinions': [{'Source': [['Donald'], ['14:20']],
#     'Target': [['Kandidatur'], ['33:43']],
#     'Polar_expression': [['angekündigt'], ['59:70']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Doch die beiden Zürcher tun viel dafür , um öffentlich wie ein eingespieltes Team zu wirken .',
#   'opinions': [{'Source': [['Zürcher'], ['16:23']],
#     'Target': [[], []],
#     'Polar_expression': [['wirken'], ['85:91']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Buchs SG – Zwei Männer haben am Mittwochabend einen Tankstellen-Shop überfallen .',
#   'opinions': [{'Source': [['Männer'], ['16:22']],
#     'Target': [['Tankstellen'], ['52:63']],
#     'Polar_expression': [['überfallen'], ['69:79']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'Jetzt hat der Postauto-Skandal das Liechtensteiner Parlament erreicht .',
#   'opinions': [{'Source': [['Skandal'], ['23:30']],
#     'Target': [['Liechtensteiner Parlament'], ['35:60']],
#     'Polar_expression': [['erreicht'], ['61:69']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'Der Thurgauer kann sich trotz seines fünften Boston-Sieges nicht uneingeschränkt freuen .',
#   'opinions': [{'Source': [['Thurgauer'], ['4:13']],
#     'Target': [[], []],
#     'Polar_expression': [['freuen'], ['81:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': 'Ausser Werner vergab noch Captain Marcel Sabitzer eine Grosschance ( 46. ) .',
#   'opinions': [{'Source': [['Captain'], ['26:33']],
#     'Target': [['Grosschance'], ['55:66']],
#     'Polar_expression': [['vergab'], ['14:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  ...]

# %%
tokenized_ssa_sents
# Out:
# {'tokens': [['<eSOURCE>',
#    'Finnland',
#    '</eSOURCE>',
#    'will',
#    'sich',
#    'dort',
#    'auch',
#    'für',
#    'eine',
#    '<eTARGET>',
#    'Verteuerung',
#    '</eTARGET>',
#    'der',
#    'Touristenvisa',
#    '<ePEXP>',
#    'einsetzen',
#    '</ePEXP>',
#    '.'],
#   ['(',
#    'sda',
#    ')',
#    '<eSOURCE>',
#    'Eishockey',
#    '</eSOURCE>',
#    'Ottawa',
#    '<ePEXP>',
#    'entlässt',
#    '</ePEXP>',
#    'seinen',
#    '<eTARGET>',
#    'Headcoach',
#    '</eTARGET>',
#    'Guy',
#    'Boucher',
#    '(',
#    '47',
#    ')',
#    '.'],
#   ['Bei',
#    'den',
#    'israelischen',
#    'Siedlungen',
#    'im',
#    'Westjordanland',
#    '<ePEXP>',
#    'pfeift',
#    '</ePEXP>',
#    'US',
#    '<eSOURCE>',
#    'Präsident',
#    '</eSOURCE>',
#    'Trump',
#    'aufs',
#    '<eTARGET>',
#    'Völkerrecht',
#    '</eTARGET>',
#    '.'],
#   ['Bei',
#    'negativen',
#    'Gedanken',
#    'wie',
#    'diesen',
#    'wird',
#    'die',
#    'Personalfachfrau',
#    'ständig',
#    'von',
#    'schlimmen',
#    'Erinnerungen',
#    'heimgesucht',
#    ':',
#    '«',
#    'Denke',
#    'ich',
#    'daran',
#    ',',
#    'dass',
#    'Nils',
#    'sich',
#    'infizieren',
#    'könnte',
#    ',',
#    'sehe',
#    'ich',
#    'die',
#    'schrecklichen',
#    'Bilder',
#    'vor',
#    'mir',
#    ',',
#    'als',
#    'er',
#    'als',
#    'Baby',
#    'an',
#    'der',
#    'Herz-Lungen-Maschine',
#    'angeschlossen',
#    'war',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Der',
#    'Name',
#    'verweist',
#    'auf',
#    'die',
#    'Art',
#    ',',
#    'wie',
#    'diese',
#    'Temperatur',
#    'bestimmt',
#    'werden',
#    'kann',
#    ':',
#    'indem',
#    'man',
#    'die',
#    'Birne',
#    'eines',
#    'Thermometers',
#    '(',
#    'bulb',
#    ')',
#    'in',
#    'ein',
#    'nasses',
#    'Tuch',
#    'wickelt',
#    'und',
#    'dann',
#    'schaut',
#    ',',
#    'welche',
#    'Temperatur',
#    'das',
#    'Thermometer',
#    'anzeigt',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['<eSOURCE>',
#    'Sanders',
#    '</eSOURCE>',
#    'versuchte',
#    'zwar',
#    ',',
#    'die',
#    'Corona-Krise',
#    'als',
#    'Argument',
#    'zu',
#    '<ePEXP>',
#    'benutzen',
#    '</ePEXP>',
#    ',',
#    'dass',
#    'seine',
#    'Forderung',
#    'nach',
#    'einer',
#    'allgemeinen',
#    ',',
#    'staatlichen',
#    'Krankenversicherung',
#    'richtig',
#    'sei',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Der',
#    'Trainer',
#    'der',
#    'New',
#    'Jersey',
#    'Devils',
#    'sagte',
#    ',',
#    'er',
#    'sehe',
#    'den',
#    'jungen',
#    'Oberwalliser',
#    'als',
#    'zukünftigen',
#    '«',
#    'franchise',
#    'player',
#    '»',
#    'und',
#    'er',
#    'glaube',
#    ',',
#    'dass',
#    '<eSOURCE>',
#    'Hischier',
#    '</eSOURCE>',
#    'irgendwann',
#    'die',
#    'Selke',
#    'Trophy',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    'werde',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Das',
#    'Kuchi',
#    '<eSOURCE>',
#    'Daaberettli',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'mahnt',
#    '</ePEXP>',
#    'aber',
#    '\xad',
#    'dennoch',
#    'zur',
#    '<eTARGET>',
#    'Vorsicht',
#    '</eTARGET>',
#    ':',
#    'Drotz',
#    'Corona',
#    'duen',
#    'y',
#    'hitte',
#    'do',
#    'my',
#    'Schnitzelbangg',
#    'singe',
#    'und',
#    'hoff',
#    ',',
#    's',
#    'däät',
#    'glinge',
#    ',',
#    'eich',
#    'zem',
#    'Schmunzle',
#    'z',
#    'bringe',
#    '.'],
#   ['Labour',
#    '<eSOURCE>',
#    'Abgeordnete',
#    '</eSOURCE>',
#    'standen',
#    'der',
#    'Reihe',
#    'nach',
#    'auf',
#    ',',
#    'um',
#    'den',
#    '<eTARGET>',
#    'Kreml',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'schelten',
#    '</ePEXP>',
#    'und',
#    'Corbyn',
#    'zwischen',
#    'den',
#    'Zeilen',
#    'die',
#    'Meinung',
#    'zu',
#    'sagen',
#    '.'],
#   ['<eSOURCE>',
#    'Pécresse',
#    '</eSOURCE>',
#    'will',
#    'die',
#    '35-Stunden-Woche',
#    'abschaffen',
#    ',',
#    'das',
#    'reguläre',
#    'Pensionsalter',
#    'von',
#    '62',
#    'auf',
#    '65',
#    'erhöhen',
#    'und',
#    '200',
#    '’',
#    '000',
#    'Beamtenposten',
#    '<ePEXP>',
#    'streichen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Mit',
#    'einem',
#    'Abseitsstehen',
#    'zöge',
#    'die',
#    'Schweiz',
#    'mit',
#    'Ländern',
#    'wie',
#    'den',
#    'USA',
#    ',',
#    'Ungarn',
#    'oder',
#    'Österreich',
#    'gleich',
#    ',',
#    'wo',
#    '<eSOURCE>',
#    'Kanzler',
#    '</eSOURCE>',
#    'Sebastian',
#    'Kurz',
#    'unter',
#    'Druck',
#    'der',
#    'rechtspopulistischen',
#    'Koalitionspartnerin',
#    'FPÖ',
#    'agiert',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Nachdem',
#    'Indiens',
#    'Luftwaffe',
#    'in',
#    'der',
#    'Nacht',
#    'zum',
#    'Dienstag',
#    'zum',
#    'ersten',
#    'Mal',
#    'seit',
#    '1971',
#    'einen',
#    'Angriff',
#    'auf',
#    'pakistanischem',
#    'Gebiet',
#    'geflogen',
#    'hatte',
#    ',',
#    '<ePEXP>',
#    'schoss',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Pakistan',
#    '</eSOURCE>',
#    'nach',
#    'eigenen',
#    'Angaben',
#    'am',
#    'Mittwoch',
#    'zwei',
#    'indische',
#    '<eTARGET>',
#    'Kampfflugzeuge',
#    '</eTARGET>',
#    'ab',
#    '.'],
#   ['Daneben',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    'Charlene',
#    ',',
#    'der',
#    '<eSOURCE>',
#    'Kelch',
#    '</eSOURCE>',
#    'ist',
#    'an',
#    'ihr',
#    'vorübergegangen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Im',
#    'Berufsauftrag',
#    'hat',
#    'die',
#    '<eSOURCE>',
#    'Bildungsdirektion',
#    '</eSOURCE>',
#    'pro',
#    'Jahreslektion',
#    'einen',
#    'Faktor',
#    'von',
#    '58',
#    'Arbeitsstunden',
#    'für',
#    '<eTARGET>',
#    'Vor',
#    '</eTARGET>',
#    'und',
#    'Nachbereitung',
#    '<ePEXP>',
#    'eingesetzt',
#    '</ePEXP>',
#    '.'],
#   ['Der',
#    'schlaue',
#    'Polit',
#    '<eSOURCE>',
#    'Fuchs',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'freute',
#    '</ePEXP>',
#    'sich',
#    'über',
#    'seine',
#    '<eTARGET>',
#    'Aufwertung',
#    '</eTARGET>',
#    'auf',
#    'der',
#    'Weltbühne',
#    ',',
#    'machte',
#    'aber',
#    'weder',
#    'in',
#    'der',
#    'Ukraine-Politik',
#    'noch',
#    'bei',
#    'der',
#    'Unterstützung',
#    'der',
#    'russischen',
#    'Turk-Stream-Pipeline',
#    'Konzessionen',
#    '.'],
#   ['«',
#    'Die',
#    'Situation',
#    'ist',
#    'aussergewöhnlich',
#    ',',
#    'und',
#    'es',
#    'stellen',
#    'sich',
#    'viele',
#    'neue',
#    'Fragen',
#    '»',
#    ',',
#    'sagt',
#    'Robert',
#    'Breiter',
#    ',',
#    'Generalsekretär',
#    'des',
#    'Schweizerischen',
#    'Fussballverbands',
#    ',',
#    '«',
#    'aber',
#    'am',
#    'Ende',
#    'geht',
#    'es',
#    'auch',
#    'bei',
#    'diesem',
#    'Wettbewerb',
#    'um',
#    'einen',
#    'Pokal',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>',
#    '»',
#    'Das',
#    'passt',
#    'zu',
#    'den',
#    'Worten',
#    'von',
#    'Luzerns',
#    'Sportchef',
#    'Remo',
#    'Meyer',
#    ':',
#    '«',
#    'Es',
#    'gibt',
#    'keine',
#    'optimale',
#    'Lösung',
#    'für',
#    'alle',
#    '.'],
#   ['Das',
#    '<eSOURCE>',
#    'BAG',
#    '</eSOURCE>',
#    'hat',
#    'deshalb',
#    'die',
#    'Kantonsärzte',
#    'angewiesen',
#    ',',
#    'die',
#    '<eTARGET>',
#    'Teststrategie',
#    '</eTARGET>',
#    '<ePEXP>',
#    'anzupassen',
#    '</ePEXP>',
#    '.'],
#   ['Und',
#    'das',
#    'tolle',
#    '<eSOURCE>',
#    'Ensemble',
#    '</eSOURCE>',
#    'haut',
#    'mit',
#    'seiner',
#    'Spielfreude',
#    'die',
#    '<eTARGET>',
#    'Skepsis',
#    '</eTARGET>',
#    'an',
#    'dem',
#    'Ding',
#    ',',
#    'das',
#    'sie',
#    'da',
#    'spielen',
#    ',',
#    'weg',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Die',
#    '<eSOURCE>',
#    'Polizei',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'nutzte',
#    '</ePEXP>',
#    'ein',
#    'Mobilfunknetz',
#    ',',
#    'mit',
#    'dem',
#    'sie',
#    'die',
#    '<eTARGET>',
#    'Personen',
#    '</eTARGET>',
#    'ID',
#    'per',
#    'QR-Code',
#    'auslesen',
#    'konnte',
#    '.'],
#   ['Da',
#    'würde',
#    'auch',
#    'die',
#    'Europäische',
#    '<eSOURCE>',
#    'Union',
#    '</eSOURCE>',
#    'nicht',
#    'immer',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    'gegen',
#    'die',
#    '<eTARGET>',
#    'Schweiz',
#    '</eTARGET>',
#    '.'],
#   ['<eSOURCE>',
#    'Gleiches',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'gilt',
#    '</ePEXP>',
#    'für',
#    'die',
#    '<eTARGET>',
#    'Ducati',
#    '</eTARGET>',
#    'Multistrada',
#    'Enduro',
#    ',',
#    'die',
#    'sogar',
#    'mit',
#    '158',
#    'PS',
#    'aufwarten',
#    'kann',
#    '.'],
#   ['Aus',
#    'der',
#    'Analyse',
#    'der',
#    'Tore',
#    'und',
#    'des',
#    'Aushubs',
#    'kommt',
#    'das',
#    'Center',
#    'zum',
#    'Schluss',
#    ',',
#    'die',
#    '<eSOURCE>',
#    'Tunnels',
#    '</eSOURCE>',
#    'könnten',
#    'vermutlich',
#    'sämtliche',
#    'für',
#    'Operationen',
#    'benötigten',
#    'Fahrzeuge',
#    'der',
#    'Basis',
#    '<ePEXP>',
#    'aufnehmen',
#    '</ePEXP>',
#    ',',
#    'inklusive',
#    'der',
#    'mobilen',
#    'Abschussrampen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Der',
#    'Flughafen',
#    'stellt',
#    'sich',
#    'im',
#    'Weiteren',
#    'auf',
#    'den',
#    'Standpunkt',
#    ',',
#    'dass',
#    'der',
#    'Bazl',
#    '<eSOURCE>',
#    'Vorschlag',
#    '</eSOURCE>',
#    'eine',
#    'massive',
#    'Schwächung',
#    'der',
#    'Investitionskraft',
#    'der',
#    'Flughäfen',
#    'Zürich',
#    'und',
#    'Genf',
#    'zur',
#    'Folge',
#    'haben',
#    'werde',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Traumatisiert',
#    'durch',
#    'das',
#    'Massaker',
#    'vom',
#    'August',
#    '2013',
#    ',',
#    'bei',
#    'dem',
#    '<eSOURCE>',
#    'Sicherheitskräfte',
#    '</eSOURCE>',
#    'auf',
#    'dem',
#    'Kairoer',
#    'Rabaa-al-Adawiya-Platz',
#    'weit',
#    'über',
#    '800',
#    '<eTARGET>',
#    'Anhänger',
#    '</eTARGET>',
#    'der',
#    'Muslimbrüder',
#    '<ePEXP>',
#    'töteten',
#    '</ePEXP>',
#    ',',
#    'und',
#    'aufgerieben',
#    'durch',
#    'die',
#    'Verhaftungen',
#    'von',
#    'Zehntausenden',
#    'ihrer',
#    'Mitglieder',
#    ',',
#    'sind',
#    'die',
#    '«',
#    'ikhwan',
#    'al-muslimin',
#    '»',
#    'in',
#    'ihrem',
#    'Mutterland',
#    'heute',
#    'politisch',
#    'bedeutungslos',
#    '.'],
#   ['Neun',
#    'Tage',
#    'zuvor',
#    'hatte',
#    'ein',
#    '<eSOURCE>',
#    'Amokläufer',
#    '</eSOURCE>',
#    '1,4',
#    'Kilometer',
#    'vom',
#    'Stadion',
#    'entfernt',
#    '58',
#    '<eTARGET>',
#    'Menschen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'ermordet',
#    '</ePEXP>',
#    '.'],
#   ['US',
#    '<eSOURCE>',
#    'Stars',
#    '</eSOURCE>',
#    'wie',
#    'Rapperin',
#    'Bhad',
#    'Bhabie',
#    '(',
#    '18',
#    ')',
#    '<ePEXP>',
#    'jubeln',
#    '</ePEXP>',
#    'über',
#    'immer',
#    'neue',
#    'Einnahme',
#    '<eTARGET>',
#    'Rekorde',
#    '</eTARGET>',
#    ':',
#    'Die',
#    'Rede',
#    'ist',
#    'von',
#    'Millionenbeträgen',
#    'innert',
#    'weniger',
#    'Stunden',
#    '.'],
#   ['«',
#    'Das',
#    'ist',
#    'einfach',
#    'nur',
#    'geil',
#    '»',
#    ',',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Nelson',
#    '</eSOURCE>',
#    'Ferreira',
#    'nach',
#    'der',
#    'Partie',
#    'über',
#    'den',
#    'zweiten',
#    '<eTARGET>',
#    'Finaleinzug',
#    '</eTARGET>',
#    'in',
#    'der',
#    'Vereinsgeschichte',
#    'des',
#    'FC',
#    'Thun',
#    '.'],
#   ['Die',
#    'einstige',
#    '<eSOURCE>',
#    'Regierungspartei',
#    '</eSOURCE>',
#    'Vereinigte',
#    'Nationale',
#    'Bewegung',
#    'des',
#    'früheren',
#    'Präsidenten',
#    'Micheil',
#    'Saakaschwili',
#    'und',
#    'weitere',
#    'Oppositionsparteien',
#    'stellten',
#    'sich',
#    'auf',
#    'die',
#    'Seite',
#    'der',
#    'Protestierenden',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Maltas',
#    'amtierender',
#    '<eSOURCE>',
#    'Premier',
#    '</eSOURCE>',
#    'Robert',
#    'Abela',
#    ',',
#    'wie',
#    'Muscat',
#    'von',
#    'der',
#    'Labour',
#    'Party',
#    ',',
#    '<ePEXP>',
#    'entschuldigte',
#    '</ePEXP>',
#    'sich',
#    'nun',
#    'im',
#    'Namen',
#    'des',
#    'Landes',
#    'bei',
#    'Daphnes',
#    'Familie',
#    ',',
#    'bei',
#    'ihrem',
#    'Mann',
#    'und',
#    'ihren',
#    'drei',
#    'Söhnen',
#    ',',
#    'die',
#    'alle',
#    'um',
#    'das',
#    '<eTARGET>',
#    'Vermächtnis',
#    '</eTARGET>',
#    'der',
#    'Mutter',
#    'kämpfen',
#    '.'],
#   ['Es',
#    'gebe',
#    'für',
#    'Bonuslandia',
#    'keine',
#    'Kosten-Nutzen-Rechnung',
#    ',',
#    'monierte',
#    'denn',
#    'auch',
#    'der',
#    '«',
#    'Corriere',
#    '»',
#    '–',
#    'um',
#    'für',
#    'eine',
#    'generelle',
#    'Steuersenkung',
#    'zu',
#    'plädieren',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Kein',
#    '<eSOURCE>',
#    'Ministerpräsident',
#    '</eSOURCE>',
#    'hat',
#    'derartigen',
#    '<eTARGET>',
#    'Druck',
#    '</eTARGET>',
#    '<ePEXP>',
#    'aushalten',
#    '</ePEXP>',
#    'müssen',
#    '»',
#    ',',
#    'sagte',
#    'Netanyahu',
#    '.'],
#   ['In',
#    'einer',
#    'unberechenbaren',
#    ',',
#    'globalen',
#    'Welt',
#    '<ePEXP>',
#    'verspreche',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Familie',
#    '</eSOURCE>',
#    '<eTARGET>',
#    'Sicherheit',
#    '</eTARGET>',
#    'und',
#    'Sinn',
#    '.'],
#   ['DUNJA',
#    'MOUSTOPOULOS',
#    ',',
#    'MATTHIAS',
#    'DUBACH',
#    'Sie',
#    'sagen',
#    'Nein',
#    'zu',
#    'Tokio',
#    '2020',
#    'Mit',
#    'Kanada',
#    'und',
#    'Australien',
#    'haben',
#    'die',
#    'ersten',
#    'zwei',
#    'grossen',
#    '<eSOURCE>',
#    'Sommersport',
#    '</eSOURCE>',
#    'Nationen',
#    'wegen',
#    'der',
#    'Coronakrise',
#    'den',
#    'Olympia-Boykott',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Zudem',
#    '<ePEXP>',
#    'verfügten',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Krankenversicherer',
#    '</eSOURCE>',
#    'über',
#    'acht',
#    'Milliarden',
#    'Franken',
#    'Reserven',
#    ',',
#    'falls',
#    'die',
#    'Zahl',
#    'der',
#    'Covid-19-Patienten',
#    'nochmals',
#    'stark',
#    'ansteigen',
#    'sollte',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Wirte',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'widersetzten',
#    '</ePEXP>',
#    'sich',
#    'den',
#    '<eTARGET>',
#    'Massnahmen',
#    '</eTARGET>',
#    'erneut',
#    '.'],
#   ['<eSOURCE>',
#    'Depardieus',
#    'Anwalt',
#    '</eSOURCE>',
#    'hatte',
#    'die',
#    '<eTARGET>',
#    'Vorwürfe',
#    '</eTARGET>',
#    'kurz',
#    'nach',
#    'deren',
#    'Bekanntwerden',
#    '<ePEXP>',
#    'zurückgewiesen',
#    '</ePEXP>',
#    '.'],
#   ['Und',
#    'Brandenburgs',
#    '<eSOURCE>',
#    'Ministerpräsident',
#    '</eSOURCE>',
#    'Dietmar',
#    'Woidke',
#    '(',
#    'SPD',
#    ')',
#    '<ePEXP>',
#    'freute',
#    '</ePEXP>',
#    'sich',
#    'über',
#    'die',
#    'grösste',
#    'private',
#    '<eTARGET>',
#    'Investition',
#    '</eTARGET>',
#    'in',
#    'seinem',
#    'Bundesland',
#    'seit',
#    'der',
#    'Wiedervereinigung',
#    '.'],
#   ['Und',
#    'alle',
#    '<eSOURCE>',
#    'Gäste',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'wussten',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Bescheid',
#    '</eTARGET>',
#    '.'],
#   ['Sein',
#    '<eTARGET>',
#    'Vermögen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'verdiente',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Unternehmer',
#    '</eSOURCE>',
#    'als',
#    'Gründer',
#    'und',
#    'Lenker',
#    'des',
#    'Hörgeräteherstellers',
#    'Phonak',
#    ',',
#    'der',
#    'heute',
#    'Sonova',
#    'heisst',
#    '.'],
#   ['Offensichtlich',
#    '<ePEXP>',
#    'fürchten',
#    '</ePEXP>',
#    'die',
#    'Investoren',
#    ',',
#    'der',
#    'sich',
#    'ohnehin',
#    'schon',
#    'abzeichnende',
#    '<eSOURCE>',
#    'Ausschluss',
#    '</eSOURCE>',
#    'dieser',
#    'speziellen',
#    'Wertpapiere',
#    'vom',
#    'Handel',
#    'in',
#    'den',
#    'USA',
#    'könnte',
#    'sich',
#    'aufgrund',
#    'der',
#    'geopolitischen',
#    'Spannungen',
#    'noch',
#    'beschleunigen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Grafik',
#    '</eSOURCE>',
#    'des',
#    'Heftes',
#    '<ePEXP>',
#    'entstand',
#    '</ePEXP>',
#    'in',
#    'Zusammenarbeit',
#    'mit',
#    'dem',
#    'Zürcher',
#    'Duo',
#    'Hammer',
#    ',',
#    'das',
#    'vor',
#    'Ort',
#    'ein',
#    'Unterrichtsmodul',
#    'zum',
#    'Thema',
#    'Layout',
#    'durchführte',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Seither',
#    'hat',
#    '<eSOURCE>',
#    'AUR',
#    '</eSOURCE>',
#    'laut',
#    'Umfragen',
#    'weiter',
#    'an',
#    '<eTARGET>',
#    'Zuspruch',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    '.'],
#   ['So',
#    'geht',
#    'es',
#    'jetzt',
#    'aus',
#    'dem',
#    'Labor',
#    'in',
#    'die',
#    'Welt',
#    'hinaus',
#    ',',
#    'und',
#    'die',
#    '<eSOURCE>',
#    'Menschen',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'fürchten',
#    '</ePEXP>',
#    'sich',
#    'sehr',
#    'vor',
#    'seiner',
#    '<eTARGET>',
#    'Gestalt',
#    '</eTARGET>',
#    '.'],
#   ['<eSOURCE>',
#    'Manafort',
#    '</eSOURCE>',
#    'stellte',
#    'sich',
#    'zugleich',
#    'für',
#    'die',
#    '<eTARGET>',
#    'Mitarbeit',
#    '</eTARGET>',
#    'mit',
#    'dem',
#    'Sonderermittler',
#    'Robert',
#    'Mueller',
#    'zur',
#    'Verfügung',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Ende',
#    'Mai',
#    'hatte',
#    'das',
#    'Fedpol',
#    'eine',
#    'Niederlage',
#    'einsteckten',
#    'müssen',
#    ':',
#    'Damals',
#    'hatte',
#    'das',
#    '<eSOURCE>',
#    'Obergericht',
#    '</eSOURCE>',
#    'entschieden',
#    ',',
#    'nicht',
#    'auf',
#    'eine',
#    'Beschwerde',
#    '<ePEXP>',
#    'einzutreten',
#    '</ePEXP>',
#    ',',
#    'die',
#    'sich',
#    'gegen',
#    'einen',
#    'Rückweisungsentscheid',
#    'des',
#    'Berner',
#    'Wirtschaftsgerichts',
#    '«',
#    'wegen',
#    'schwerwiegender',
#    'Verfahrensmängel',
#    '»',
#    'gerichtet',
#    'hatte',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Natürlich',
#    'stellt',
#    'das',
#    '<eSOURCE>',
#    'Coronavirus',
#    '</eSOURCE>',
#    'ein',
#    'Risiko',
#    'dar',
#    ',',
#    'wie',
#    'auch',
#    'die',
#    'anhaltenden',
#    'geopolitischen',
#    'Spannungen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['«',
#    'Fake-News',
#    'können',
#    'hier',
#    'in',
#    '<eTARGET>',
#    'Kongo',
#    '</eTARGET>',
#    '<ePEXP>',
#    'töten',
#    '</ePEXP>',
#    '»',
#    ',',
#    'sagt',
#    'der',
#    '27-jährige',
#    '<eSOURCE>',
#    'Mupfuni',
#    '</eSOURCE>',
#    'bestimmt',
#    '.'],
#   ['Musk',
#    'war',
#    'vom',
#    'britischen',
#    '<eSOURCE>',
#    'Höhlentaucher',
#    '</eSOURCE>',
#    'Vernon',
#    'Unsworth',
#    '<ePEXP>',
#    'verklagt',
#    '</ePEXP>',
#    'worden',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Händler',
#    '</eSOURCE>',
#    'von',
#    'Ski',
#    ',',
#    'Snowboards',
#    'und',
#    'Schlitten',
#    'freuen',
#    'sich',
#    'zwar',
#    'ebenfalls',
#    'über',
#    'die',
#    'frostigen',
#    '<eTARGET>',
#    'Temperaturen',
#    '</eTARGET>',
#    ',',
#    'rechnen',
#    'deswegen',
#    'aber',
#    'nicht',
#    'mit',
#    'einer',
#    'deutlich',
#    'höheren',
#    'Nachfrage',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['«',
#    '<eSOURCE>',
#    'Marini',
#    '</eSOURCE>',
#    'konnte',
#    'seine',
#    '<eTARGET>',
#    'Reifen',
#    '</eTARGET>',
#    'besser',
#    '<ePEXP>',
#    'schonen',
#    '</ePEXP>',
#    'als',
#    'ich',
#    '»',
#    ',',
#    'sagte',
#    'Lüthi',
#    '.'],
#   ['Das',
#    'Gericht',
#    'kommt',
#    'zum',
#    'Schluss',
#    ',',
#    'dass',
#    'vier',
#    '<eSOURCE>',
#    'Artikel',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'zwischen',
#    'Dezember',
#    '2014',
#    'und',
#    'September',
#    '2015',
#    'im',
#    '«',
#    'Blick',
#    '»',
#    'erschienen',
#    'sind',
#    ',',
#    'die',
#    '<eTARGET>',
#    'Persönlichkeit',
#    '</eTARGET>',
#    'von',
#    'Spiess-Hegglin',
#    '<ePEXP>',
#    'verletzt',
#    '</ePEXP>',
#    'haben',
#    '.'],
#   ['Dass',
#    'der',
#    '<eSOURCE>',
#    'Kanton',
#    '</eSOURCE>',
#    'keine',
#    'genaueren',
#    '<eTARGET>',
#    'Zahlen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'nennen',
#    '</ePEXP>',
#    'kann',
#    ',',
#    'liegt',
#    'an',
#    'der',
#    'Datenerfassung',
#    '.'],
#   ['Nachdem',
#    'die',
#    'Amerikaner',
#    'neue',
#    'Sanktionen',
#    'angekündigt',
#    'haben',
#    ',',
#    '<ePEXP>',
#    'schiesst',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Russland',
#    '</eSOURCE>',
#    'rhetorisch',
#    'scharf',
#    'zurück',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['In',
#    'Baden-Württemberg',
#    'hat',
#    'die',
#    '<eSOURCE>',
#    'FDP',
#    '</eSOURCE>',
#    'mit',
#    '10,5',
#    'Prozent',
#    'der',
#    'Stimmen',
#    'ihr',
#    'bestes',
#    '<eTARGET>',
#    'Wahlergebnis',
#    '</eTARGET>',
#    'seit',
#    'Jahrzehnten',
#    '<ePEXP>',
#    'erreicht',
#    '</ePEXP>',
#    '.'],
#   ['Und',
#    'die',
#    'isländischen',
#    'Fans',
#    'sorgten',
#    'mit',
#    'ihrer',
#    'Huh-Choreografie',
#    'dafür',
#    ',',
#    'dass',
#    'die',
#    '<eSOURCE>',
#    'Welt',
#    '</eSOURCE>',
#    'die',
#    '<eTARGET>',
#    'Reykjavíker',
#    '</eTARGET>',
#    'Skandale',
#    '<ePEXP>',
#    'vergass',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Robert',
#    '</eSOURCE>',
#    'Payne',
#    '<ePEXP>',
#    'widersetzte',
#    '</ePEXP>',
#    'sich',
#    'der',
#    '<eTARGET>',
#    'Aufforderung',
#    '</eTARGET>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Faktor',
#    '</eSOURCE>',
#    'Mensch',
#    'stellt',
#    'die',
#    'grösste',
#    '<eTARGET>',
#    'Gefahrenquelle',
#    '</eTARGET>',
#    'dar',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Zusammen',
#    'mit',
#    'zwei',
#    'weiteren',
#    'wichtigen',
#    'kirchlichen',
#    'Playern',
#    '–',
#    'der',
#    'Römisch-Katholischen',
#    'Zentralkonferenz',
#    'und',
#    'der',
#    'Konferenz',
#    'der',
#    'Ordensgemeinschaften',
#    '–',
#    'hat',
#    'sie',
#    'an',
#    'der',
#    'Universität',
#    'Zürich',
#    'ein',
#    'Forschungsprojekt',
#    'zu',
#    'Missbrauchsfällen',
#    'seit',
#    '1950',
#    'in',
#    'Auftrag',
#    'gegeben',
#    ':',
#    '«',
#    'Mit',
#    'der',
#    'Anerkennung',
#    'des',
#    'durch',
#    'sexuelle',
#    'Übergriffe',
#    'im',
#    'Kontext',
#    'der',
#    'römisch-katholischen',
#    'Kirche',
#    'in',
#    'der',
#    'Schweiz',
#    'zugefügten',
#    'Leids',
#    'ist',
#    'für',
#    'die',
#    'Kirche',
#    'die',
#    'Pflicht',
#    'verbunden',
#    ',',
#    'das',
#    'Geschehene',
#    'aufzuarbeiten',
#    ',',
#    'seine',
#    'Ursachen',
#    'zu',
#    'analysieren',
#    'und',
#    'daraus',
#    'die',
#    'Lehren',
#    'für',
#    'die',
#    'Zukunft',
#    'zu',
#    'ziehen',
#    '»',
#    ',',
#    'heisst',
#    'es',
#    'im',
#    'Vertrag',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Für',
#    'den',
#    'Dienstag',
#    'hatten',
#    'die',
#    '<eSOURCE>',
#    'Oppositionsparteien',
#    '</eSOURCE>',
#    'gemeinsam',
#    'mit',
#    'Rebellen',
#    'der',
#    'Tories',
#    'einen',
#    'Vorstoss',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    ',',
#    'der',
#    'ein',
#    'ungeregeltes',
#    'Ausscheiden',
#    'aus',
#    'der',
#    'EU',
#    'Ende',
#    'Oktober',
#    'verhindern',
#    'soll',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Deshalb',
#    '<ePEXP>',
#    'bricht',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Vorsitzende',
#    '</eSOURCE>',
#    'die',
#    '<eTARGET>',
#    'Befragung',
#    '</eTARGET>',
#    'ab',
#    ',',
#    'kaum',
#    'hat',
#    'sie',
#    'begonnen',
#    '.'],
#   ['<eSOURCE>',
#    'Trump',
#    '</eSOURCE>',
#    'habe',
#    'sich',
#    'bei',
#    'Maurer',
#    'für',
#    'die',
#    'Rolle',
#    'der',
#    'Schweiz',
#    'bei',
#    'diplomatischen',
#    'Beziehungen',
#    'und',
#    'bei',
#    'der',
#    'Vermittlung',
#    'bei',
#    'internationalen',
#    'Konflikten',
#    '<ePEXP>',
#    'bedankt',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Das',
#    '<eSOURCE>',
#    'Verschwinden',
#    '</eSOURCE>',
#    'des',
#    'lokalen',
#    'Akutspitals',
#    '<ePEXP>',
#    'löst',
#    '</ePEXP>',
#    'vielerorts',
#    '<eTARGET>',
#    'Unmut',
#    '</eTARGET>',
#    'aus',
#    '.'],
#   ['Die',
#    'jetzigen',
#    '<eSOURCE>',
#    'Protestaktionen',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'finden',
#    '</ePEXP>',
#    'in',
#    'viel',
#    'kleinerem',
#    'und',
#    'heterogenerem',
#    'Rahmen',
#    'statt',
#    ',',
#    'und',
#    'da',
#    'sie',
#    'sich',
#    'in',
#    'unzähligen',
#    'kleinen',
#    'Städten',
#    'im',
#    'ganzen',
#    'Land',
#    'zutragen',
#    ',',
#    'sind',
#    'sie',
#    'nur',
#    'schwer',
#    'einzudämmen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['In',
#    'knapp',
#    'acht',
#    'Monaten',
#    'wird',
#    'das',
#    'Vereinigte',
#    '<eSOURCE>',
#    'Königreich',
#    '</eSOURCE>',
#    'formal',
#    'aus',
#    'der',
#    '<eTARGET>',
#    'EU',
#    '</eTARGET>',
#    '<ePEXP>',
#    'austreten',
#    '</ePEXP>',
#    '.'],
#   ['Gekippt',
#    'wurde',
#    'neben',
#    'dem',
#    'von',
#    'seiner',
#    'islamisch-konservativen',
#    'Regierung',
#    'propagierten',
#    '«',
#    'Untreue-Artikel',
#    '»',
#    'auch',
#    'die',
#    'Todesstrafe',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['In',
#    'den',
#    'Sechzigern',
#    'stellte',
#    'sich',
#    'auch',
#    'der',
#    'internationale',
#    'Erfolg',
#    'ein',
#    ':',
#    'Hugs',
#    'Ölbilder',
#    'wurden',
#    'in',
#    'die',
#    'ganze',
#    'Welt',
#    'verkauft',
#    ';',
#    'auch',
#    'die',
#    'britische',
#    'Königin',
#    '<ePEXP>',
#    'erstand',
#    '</ePEXP>',
#    'zwei',
#    'seiner',
#    'Werke',
#    'nach',
#    'einer',
#    'Ausstellung',
#    'in',
#    'London',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Planung',
#    ',',
#    'Verhandlung',
#    ',',
#    'politische',
#    'Plattform',
#    ',',
#    'runder',
#    'Tisch',
#    '–',
#    'all',
#    'diese',
#    '<eSOURCE>',
#    'Wörter',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'benutzen',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Populisten',
#    '</eTARGET>',
#    'nie',
#    '.'],
#   ['Nach',
#    'vier',
#    'Jahren',
#    'als',
#    'Präsident',
#    'stellt',
#    'sich',
#    '<eSOURCE>',
#    'Daniel',
#    '</eSOURCE>',
#    'Frutig',
#    'an',
#    'der',
#    'Generalversammlung',
#    'am',
#    '2',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    'April',
#    'nicht',
#    'mehr',
#    'zur',
#    'Wahl',
#    '.'],
#   ['Nicht',
#    'einfach',
#    'nach',
#    'Isolationismus',
#    ',',
#    'denn',
#    '<eSOURCE>',
#    'Trump',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'plädiert',
#    '</ePEXP>',
#    'keineswegs',
#    'für',
#    'den',
#    'Rückzug',
#    'aus',
#    'der',
#    'Welt',
#    ',',
#    'sondern',
#    'er',
#    'will',
#    'die',
#    'international',
#    'gültigen',
#    'Spielregeln',
#    'nach',
#    'seinem',
#    'Gusto',
#    'umgestalten',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    'australische',
#    '<eSOURCE>',
#    'Regierung',
#    '</eSOURCE>',
#    'hat',
#    '<eTARGET>',
#    'Nothilfen',
#    '</eTARGET>',
#    'für',
#    'die',
#    'tägliche',
#    'Versorgung',
#    'von',
#    'Bauernfamilien',
#    'angekündigt',
#    ',',
#    'die',
#    'um',
#    'die',
#    'Existenz',
#    'ihrer',
#    'Farmen',
#    'kämpfen',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['RED',
#    'U21-Nati',
#    '<eSOURCE>',
#    'Trainer',
#    '</eSOURCE>',
#    'Mauro',
#    'Lustrinelli',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    'auf',
#    'die',
#    '<eTARGET>',
#    'EM',
#    '</eTARGET>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Seitenhieb',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'galt',
#    '</ePEXP>',
#    'dem',
#    '<eTARGET>',
#    'Führungsduo',
#    '</eTARGET>',
#    'der',
#    'Koalition',
#    ':',
#    'Calin',
#    'Popescu',
#    'Tariceanu',
#    ',',
#    'in',
#    'Personalunion',
#    'Vorsitzender',
#    'der',
#    'liberalen',
#    'Kleinpartei',
#    'Alde',
#    'und',
#    'Senatspräsident',
#    ',',
#    'steht',
#    'wegen',
#    'Meineids',
#    'vor',
#    '\xad',
#    'Gericht',
#    '.'],
#   ['Der',
#    'jüngste',
#    '<eSOURCE>',
#    'Unternehmenszweig',
#    '</eSOURCE>',
#    'der',
#    'Sportholding',
#    'will',
#    'sich',
#    'der',
#    '<eTARGET>',
#    'Planung',
#    '</eTARGET>',
#    'von',
#    'Eishockeykarrieren',
#    'widmen',
#    'und',
#    'die',
#    'Spieler',
#    'auch',
#    'darüber',
#    'hinaus',
#    'beratend',
#    'begleiten',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Die',
#    '<eSOURCE>',
#    'Hemmschwelle',
#    '</eSOURCE>',
#    ',',
#    'mit',
#    'den',
#    'Lehrperson',
#    'den',
#    'Kontakt',
#    'aufzunehmen',
#    ',',
#    'ist',
#    'gesunken',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['An',
#    'der',
#    'alljährlichen',
#    'Entwicklerkonferenz',
#    ',',
#    'wegen',
#    'Corona',
#    'erstmals',
#    'ein',
#    'Online-Event',
#    ',',
#    'hat',
#    'der',
#    '<eSOURCE>',
#    'Konzern',
#    '</eSOURCE>',
#    'daher',
#    'die',
#    '<eTARGET>',
#    'Abkehr',
#    '</eTARGET>',
#    'von',
#    'Intel',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '.'],
#   ['In',
#    'den',
#    'zehn',
#    'ukrainischen',
#    'Provinzen',
#    ',',
#    'die',
#    'an',
#    'Russland',
#    'und',
#    'die',
#    'Moldau',
#    'grenzen',
#    ',',
#    '<ePEXP>',
#    'gilt',
#    '</ePEXP>',
#    'derzeit',
#    'das',
#    '<eSOURCE>',
#    'Kriegsrecht',
#    '</eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['So',
#    '<ePEXP>',
#    'gewinnt',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Eigenverantwortung',
#    '</eSOURCE>',
#    'in',
#    'der',
#    'dritten',
#    'Säule',
#    'an',
#    '<eTARGET>',
#    'Bedeutung',
#    '</eTARGET>',
#    'und',
#    'ruft',
#    'nach',
#    'verbesserten',
#    'Anreizen',
#    'und',
#    'mehr',
#    'Möglichkeiten',
#    '.'],
#   ['Allerdings',
#    'stellen',
#    'sich',
#    'rechtliche',
#    '<eSOURCE>',
#    'Fragen',
#    '</eSOURCE>',
#    'bei',
#    'der',
#    '<eTARGET>',
#    'Umsetzung',
#    '</eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Immer',
#    'auch',
#    'auf',
#    'die',
#    'Gefahr',
#    'hin',
#    ',',
#    'dass',
#    '<eSOURCE>',
#    'Kritiker',
#    '</eSOURCE>',
#    'uns',
#    'an',
#    'den',
#    'Öko-Pranger',
#    'stellen',
#    'und',
#    'uns',
#    'die',
#    'liberale',
#    'Gesinnung',
#    'absprechen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Einerseits',
#    'stellen',
#    'sich',
#    '<eSOURCE>',
#    'Länder',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'es',
#    'selber',
#    'mit',
#    'den',
#    'Menschenrechten',
#    'nicht',
#    'so',
#    'genau',
#    'nehmen',
#    ',',
#    'an',
#    'Pekings',
#    'Seite',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Auch',
#    'mit',
#    'der',
#    'Wahl',
#    'von',
#    'Ashraf',
#    'Ghani',
#    'zum',
#    'Präsidenten',
#    'Afghanistans',
#    'im',
#    'Jahr',
#    '2014',
#    'stellte',
#    'sich',
#    '<eSOURCE>',
#    'Hoffnung',
#    '</eSOURCE>',
#    'auf',
#    '<eTARGET>',
#    'Besserung',
#    '</eTARGET>',
#    'ein',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Inzwischen',
#    'ist',
#    'zumindest',
#    'bekannt',
#    ',',
#    'dass',
#    'die',
#    '<eSOURCE>',
#    'SPD',
#    '</eSOURCE>',
#    'den',
#    'Minister',
#    'stellen',
#    'wird',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Seine',
#    'Worte',
#    'konnte',
#    'man',
#    'so',
#    'interpretieren',
#    ',',
#    'dass',
#    'dann',
#    'der',
#    'Entscheid',
#    'über',
#    'seine',
#    'politische',
#    'Zukunft',
#    'fallen',
#    'wird',
#    'und',
#    'sich',
#    'beide',
#    'Seiten',
#    'bis',
#    'dahin',
#    'mit',
#    'öffentlichen',
#    'Äusserungen',
#    'zurückhalten',
#    'werden',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Die',
#    '<eSOURCE>',
#    'Technologie',
#    '</eSOURCE>',
#    'werde',
#    'somit',
#    'die',
#    'Funktionen',
#    'der',
#    'heutigen',
#    'Intermediäre',
#    'zu',
#    'grossen',
#    'Teilen',
#    'übernehmen',
#    'und',
#    'zwingt',
#    'damit',
#    'bisherige',
#    'Vermittler',
#    ',',
#    'ihr',
#    '<eTARGET>',
#    'Geschäftsmodell',
#    '</eTARGET>',
#    'anzupassen',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Der',
#    '<eSOURCE>',
#    'Strassenhändler',
#    '</eSOURCE>',
#    'besorgte',
#    'sich',
#    'Benzin',
#    ',',
#    'stellte',
#    'sich',
#    'vor',
#    'die',
#    'Polizeipräfektur',
#    'und',
#    'steckte',
#    'sich',
#    'in',
#    'Brand',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Madonna',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'entschuldigt',
#    '</ePEXP>',
#    'sich',
#    'bei',
#    'ihren',
#    '<eTARGET>',
#    'Anhängern',
#    '</eTARGET>',
#    ':',
#    '«',
#    'Ich',
#    'muss',
#    'mich',
#    'erholen',
#    '»',
#    ',',
#    'erklärt',
#    'sie',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Schweizerin',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'wehrt',
#    '</ePEXP>',
#    'gegen',
#    '<eTARGET>',
#    'Alizé',
#    '</eTARGET>',
#    'Cornet',
#    'zwei',
#    'Matchbälle',
#    'ab',
#    'und',
#    'dreht',
#    'dann',
#    'die',
#    'Partie',
#    '.'],
#   ['<eSOURCE>',
#    'Waffenlieferungen',
#    '</eSOURCE>',
#    'an',
#    'Kriegsparteien',
#    '<ePEXP>',
#    'verletzen',
#    '</ePEXP>',
#    'grundsätzlich',
#    'das',
#    '<eTARGET>',
#    'Neutralitätsgebot',
#    '</eTARGET>',
#    'nach',
#    'Haager',
#    'Kriegsrecht',
#    '.'],
#   ['<eSOURCE>',
#    'Villiger',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'zog',
#    '</ePEXP>',
#    'das',
#    '<eTARGET>',
#    'Verteidigungsdispositiv',
#    '</eTARGET>',
#    'auf',
#    '.'],
#   ['Der',
#    'Schweizer',
#    'Verband',
#    'widersetzte',
#    'sich',
#    'zuerst',
#    'aus',
#    'scheinformalen',
#    'Gründen',
#    'dem',
#    'Transfer',
#    'in',
#    'den',
#    'Profifussball',
#    ',',
#    'das',
#    'italienische',
#    '<eSOURCE>',
#    'Parlament',
#    '</eSOURCE>',
#    'verfügte',
#    'eine',
#    'Importsperre',
#    ',',
#    'weil',
#    'schon',
#    'zu',
#    'viele',
#    'Ausländer',
#    'im',
#    'Land',
#    'kickten',
#    ',',
#    'und',
#    'als',
#    'Vonlanthen',
#    '1955',
#    'doch',
#    'in',
#    'Mailand',
#    'eintraf',
#    ',',
#    'hatten',
#    'sie',
#    'einen',
#    'Bomber',
#    'erwartet',
#    'und',
#    'nicht',
#    'diesen',
#    'schmalen',
#    ',',
#    'leichtfüssigen',
#    'Artisten',
#    ',',
#    'der',
#    'dann',
#    'häufig',
#    'auf',
#    'der',
#    'Ersatzbank',
#    'sitzen',
#    'blieb',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Zudem',
#    'stellen',
#    'sich',
#    'ethische',
#    '<eSOURCE>',
#    'Fragen',
#    '</eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Das',
#    '<eSOURCE>',
#    'Neutralitätsprinzip',
#    '</eSOURCE>',
#    'habe',
#    'die',
#    'Schweizer',
#    'Bevölkerung',
#    'seit',
#    'über',
#    '200',
#    'Jahren',
#    'vor',
#    'blutigen',
#    '<eTARGET>',
#    'Konflikten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'bewahrt',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Wirtenfamilie',
#    '</eSOURCE>',
#    'Christen',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    'über',
#    'die',
#    '<eTARGET>',
#    'Wiedereröffnung',
#    '</eTARGET>',
#    ':',
#    'Angela',
#    '(',
#    'l.'],
#   ['<eSOURCE>',
#    'Immobilien',
#    '</eSOURCE>',
#    ',',
#    'wie',
#    'der',
#    'Name',
#    'schon',
#    'sagt',
#    ',',
#    '<ePEXP>',
#    'widersetzen',
#    '</ePEXP>',
#    'sich',
#    'dem',
#    'fliessenden',
#    '<eTARGET>',
#    'Wandel',
#    '</eTARGET>',
#    ',',
#    'also',
#    'muss',
#    'eine',
#    'andere',
#    'flexible',
#    'Veränderungsmöglichkeit',
#    'her',
#    ',',
#    'nämlich',
#    'die',
#    'Zwischennutzung',
#    '.'],
#   ['Im',
#    'Gegensatz',
#    'zu',
#    'den',
#    'meisten',
#    'anderen',
#    'Krankenhäusern',
#    'hat',
#    'das',
#    '<eSOURCE>',
#    'Spital',
#    '</eSOURCE>',
#    'gar',
#    '<eTARGET>',
#    'Boni',
#    '</eTARGET>',
#    '<ePEXP>',
#    'abgeschafft',
#    '</ePEXP>',
#    ',',
#    'die',
#    'sich',
#    'an',
#    'den',
#    'Operationszahlen',
#    'der',
#    'Ärzte',
#    'bemessen',
#    '.'],
#   ['<eSOURCE>',
#    'Trump',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'beschimpfte',
#    '</ePEXP>',
#    'den',
#    '33-jährigen',
#    '<eTARGET>',
#    'Taylor',
#    '</eTARGET>',
#    'umgehend',
#    'als',
#    'einen',
#    '«',
#    'Niemand',
#    '»',
#    'sowie',
#    'einen',
#    '«',
#    'Widerling',
#    ',',
#    'der',
#    'nie',
#    'im',
#    'Weissen',
#    'Haus',
#    'gearbeitet',
#    'hat',
#    '»',
#    '.'],
#   ['Der',
#    'hohe',
#    '<eSOURCE>',
#    'Feiertag',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'findet',
#    '</ePEXP>',
#    'immer',
#    'am',
#    'ersten',
#    'Sonntag',
#    'nach',
#    'dem',
#    'ersten',
#    'Vollmond',
#    'im',
#    '<eTARGET>',
#    'Frühling',
#    '</eTARGET>',
#    'statt',
#    '.'],
#   ['Am',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    'Februar',
#    '<ePEXP>',
#    'finden',
#    '</ePEXP>',
#    'dazu',
#    'in',
#    'den',
#    'beiden',
#    'Kantonen',
#    'zwei',
#    'separate',
#    '<eSOURCE>',
#    'Volksabstimmungen',
#    '</eSOURCE>',
#    'statt',
#    '.'],
#   ['Opfer',
#    'Brigitte',
#    'Peyer',
#    'und',
#    'ihr',
#    'Lebenspartner',
#    'Rudolf',
#    'Naef',
#    'wurden',
#    'im',
#    'Dezember',
#    'vom',
#    '<eSOURCE>',
#    'Marokkaner',
#    '</eSOURCE>',
#    'Moestafa',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '<ePEXP>',
#    'überfallen',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Brosi',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'plädierte',
#    '</ePEXP>',
#    'zuletzt',
#    'für',
#    'etwas',
#    'mehr',
#    '<eTARGET>',
#    'Management',
#    '</eTARGET>',
#    '.'],
#   ['Sobald',
#    'die',
#    'Briten',
#    'aus',
#    'der',
#    'EU',
#    'austreten',
#    ',',
#    'schrumpft',
#    'nach',
#    'der',
#    'Wahl',
#    'die',
#    '<eSOURCE>',
#    'Grösse',
#    '</eSOURCE>',
#    'des',
#    'Parlaments',
#    'auf',
#    '705',
#    'Abgeordnete',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Als',
#    '<eTARGET>',
#    'Qualitätsaktien',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gelten',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Valoren',
#    '</eSOURCE>',
#    'von',
#    'Unternehmen',
#    'mit',
#    'einem',
#    'geringen',
#    'Verschuldungsgrad',
#    ',',
#    'die',
#    'mit',
#    'einer',
#    'grossen',
#    'Zuverlässigkeit',
#    'solide',
#    'Gewinne',
#    'erzielen',
#    'und',
#    'sich',
#    'auch',
#    'in',
#    'einem',
#    'wirtschaftlich',
#    'schwierigen',
#    'Umfeld',
#    'behaupten',
#    'können',
#    '.'],
#   ['Das',
#    '<eSOURCE>',
#    'Trainingszentrum',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'verfügt',
#    '</ePEXP>',
#    'über',
#    '<eTARGET>',
#    'Zimmer',
#    '</eTARGET>',
#    '.'],
#   ['Lilian',
#    'Carpenter',
#    ',',
#    'Zürich',
#    'Im',
#    'Kommentar',
#    'stellt',
#    'der',
#    'Autor',
#    'die',
#    'Frage',
#    ':',
#    '«',
#    'War',
#    'es',
#    'erweiterter',
#    'Suizid',
#    '?',
#    '»',
#    'Ich',
#    'finde',
#    'es',
#    'unsäglich',
#    ',',
#    'dass',
#    'mit',
#    'diesem',
#    '<eTARGET>',
#    'Begriff',
#    '</eTARGET>',
#    'immer',
#    'noch',
#    'so',
#    'fahrlässig',
#    'umgegangen',
#    'wird',
#    '<eSOURCE>',
#    '<ePEXP>',
#    '!',
#    '</ePEXP>',
#    '</eSOURCE>'],
#   ['Darin',
#    'soll',
#    'auch',
#    'die',
#    'direkt',
#    'betroffene',
#    '<eSOURCE>',
#    'Bevölkerung',
#    '</eSOURCE>',
#    '<eTARGET>',
#    'Gehör',
#    '</eTARGET>',
#    '<ePEXP>',
#    'finden',
#    '</ePEXP>',
#    '.'],
#   ['(',
#    'sda',
#    ')',
#    'Sozialhilfe',
#    'Die',
#    'Co',
#    '<eSOURCE>',
#    'Präsidenten',
#    '</eSOURCE>',
#    'der',
#    'Schweizerischen',
#    'Konferenz',
#    'für',
#    'Sozialhilfe',
#    '(',
#    'Skos',
#    ')',
#    ',',
#    'Therese',
#    'Frösch',
#    'und',
#    'Felix',
#    'Wolffers',
#    ',',
#    'haben',
#    'nach',
#    'fünf',
#    'Jahren',
#    'im',
#    'Amt',
#    'ihren',
#    'Rücktritt',
#    'auf',
#    'Mai',
#    '2019',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Damit',
#    'rückt',
#    'der',
#    'angekündigte',
#    ',',
#    'grund',
#    '\xad',
#    '-',
#    'legende',
#    'Strategiewechsel',
#    'in',
#    'weite',
#    'Ferne',
#    ':',
#    'Ursprünglich',
#    'wollte',
#    'der',
#    '<eSOURCE>',
#    'Bundesrat',
#    '</eSOURCE>',
#    'im',
#    'zweiten',
#    'Teil',
#    'der',
#    'Energiewende',
#    'die',
#    'Förderbeiträge',
#    'sukzessive',
#    'abschaffen',
#    'und',
#    'stattdessen',
#    'ein',
#    'Lenkungssystem',
#    'einführen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Bolsonaro',
#    '</eSOURCE>',
#    'hat',
#    'als',
#    'eine',
#    'seiner',
#    'ersten',
#    'Amtshandlungen',
#    'das',
#    'Kulturministerium',
#    'abschaffen',
#    'lassen',
#    ',',
#    'nicht',
#    ',',
#    'weil',
#    'ihm',
#    'Kultur',
#    'unwichtig',
#    'ist',
#    ',',
#    'im',
#    'Gegenteil',
#    ':',
#    'Er',
#    'und',
#    'seine',
#    'Regierung',
#    'nutzen',
#    'sie',
#    ',',
#    'um',
#    'sich',
#    'bei',
#    'ihrer',
#    'Wählerschaft',
#    'zu',
#    'profilieren',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Dieser',
#    '<eTARGET>',
#    'Frau',
#    '</eTARGET>',
#    'vertraut',
#    '<eSOURCE>',
#    'Macron',
#    '</eSOURCE>',
#    'nun',
#    'seine',
#    'Regierungskommunikation',
#    'an',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['«',
#    'Nachdem',
#    'der',
#    'Bundesrat',
#    'den',
#    '<eTARGET>',
#    'Lockdown',
#    '</eTARGET>',
#    'angekündigt',
#    'hatte',
#    ',',
#    '<ePEXP>',
#    'bestellten',
#    '</ePEXP>',
#    'plötzlich',
#    'so',
#    'viele',
#    '<eSOURCE>',
#    'Leute',
#    '</eSOURCE>',
#    'bei',
#    'uns',
#    'wie',
#    'noch',
#    'nie',
#    '»',
#    ',',
#    'sagt',
#    'Vera',
#    'Kessens',
#    '.'],
#   ['Für',
#    'rasche',
#    '<eTARGET>',
#    'Hilfe',
#    '</eTARGET>',
#    '<ePEXP>',
#    'plädieren',
#    '</ePEXP>',
#    'auch',
#    'SP',
#    '<eSOURCE>',
#    'Nationalrat',
#    '</eSOURCE>',
#    'Mathias',
#    'Reynard',
#    'und',
#    'SVP-Ständerat',
#    'Hannes',
#    'Germann',
#    ',',
#    'die',
#    'Präsidenten',
#    'der',
#    'Kulturkommissionen',
#    'der',
#    'Eidgenössischen',
#    'Räte',
#    ',',
#    'die',
#    'Parmelin',
#    'am',
#    'Dienstag',
#    'trafen',
#    '.'],
#   ['Ab',
#    'dato',
#    'strich',
#    '<eSOURCE>',
#    'Depp',
#    '</eSOURCE>',
#    'astronomische',
#    'Gagen',
#    'ein',
#    'und',
#    '<ePEXP>',
#    'widmete',
#    '</ePEXP>',
#    'sich',
#    'Lieblingsprojekten',
#    'wie',
#    'etwa',
#    '«',
#    'Finding',
#    'Neverland',
#    '»',
#    'von',
#    'Marc',
#    'Forster',
#    '(',
#    '2004',
#    ')',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Bern',
#    '–',
#    'Am',
#    'Sonntagabend',
#    'haben',
#    'zwei',
#    '<eSOURCE>',
#    'Unbekannte',
#    '</eSOURCE>',
#    'einen',
#    '<eTARGET>',
#    'Tankstellenshop',
#    '</eTARGET>',
#    'an',
#    'der',
#    'Fellerstrasse',
#    '<ePEXP>',
#    'überfallen',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Aryzta',
#    '</eSOURCE>',
#    'hat',
#    'den',
#    '<eTARGET>',
#    'Verkauf',
#    '</eTARGET>',
#    'von',
#    'Picard',
#    'schon',
#    'vor',
#    'einiger',
#    'Zeit',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    ',',
#    'den',
#    'richtigen',
#    'Zeitpunkt',
#    'dafür',
#    'aber',
#    'noch',
#    'nicht',
#    'gefunden',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Regierung',
#    '</eSOURCE>',
#    'mahnte',
#    'Ende',
#    'Juni',
#    'bereits',
#    'die',
#    'an',
#    'Erdbeben-',
#    ',',
#    'Flut-',
#    'und',
#    'Sturmkatastrophen',
#    'gewöhnten',
#    'Japaner',
#    ',',
#    'sich',
#    'während',
#    'der',
#    'Regenzeit',
#    'auf',
#    'Überschwemmungen',
#    'und',
#    'Erdrutsche',
#    'einzustellen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Spitze',
#    '</eSOURCE>',
#    'der',
#    'SP',
#    'stellte',
#    'sich',
#    'zwar',
#    'früh',
#    'hinter',
#    'den',
#    'kompromisslosen',
#    'Kurs',
#    'der',
#    'Gewerkschaften',
#    ',',
#    'hat',
#    'sich',
#    'inzwischen',
#    'aber',
#    'im',
#    'Tonfall',
#    'gemässigt',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Manche',
#    '<eSOURCE>',
#    'Dirigenten',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'überrumpeln',
#    '</ePEXP>',
#    'das',
#    '<eTARGET>',
#    'Publikum',
#    '</eTARGET>',
#    ',',
#    'indem',
#    'sie',
#    'starten',
#    ',',
#    'sobald',
#    'sie',
#    'auf',
#    'dem',
#    'Podium',
#    'angelangt',
#    'sind',
#    ';',
#    'andere',
#    'zelebrieren',
#    'eine',
#    'feierliche',
#    'Stille',
#    ',',
#    'bevor',
#    'sie',
#    'loslegen',
#    '.'],
#   ['Einige',
#    '<eSOURCE>',
#    'Firmen',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'beschweren',
#    '</ePEXP>',
#    'sich',
#    'aber',
#    'über',
#    'eine',
#    'falsche',
#    '<eTARGET>',
#    'Einordnung',
#    '</eTARGET>',
#    ',',
#    'etwa',
#    'der',
#    'Süsswarenhersteller',
#    'Storck',
#    ',',
#    'zu',
#    'dessen',
#    'Portfolio',
#    'Marken',
#    'wie',
#    'Toffifee',
#    ',',
#    'Merci',
#    ',',
#    'Knoppers',
#    'oder',
#    'Nimm',
#    '2',
#    'gehören',
#    '.'],
#   ['Brasilien',
#    'Mitten',
#    'in',
#    'der',
#    'Pandemie',
#    'wollte',
#    'der',
#    '<eSOURCE>',
#    'Präsident',
#    '</eSOURCE>',
#    'den',
#    '<eTARGET>',
#    'Gesundheitsminister',
#    '</eTARGET>',
#    '<ePEXP>',
#    'entlassen',
#    '</ePEXP>',
#    '.'],
#   ['Denens',
#    'VD',
#    '–',
#    'Eine',
#    '<eSOURCE>',
#    'Explosion',
#    '</eSOURCE>',
#    'hat',
#    'am',
#    'frühen',
#    'Sonntagmorgen',
#    'im',
#    'Kanton',
#    'Waadt',
#    'eine',
#    'von',
#    'Swisscom',
#    'und',
#    'Salt',
#    'genutzte',
#    'Handy',
#    '<eTARGET>',
#    'Antenne',
#    '</eTARGET>',
#    '<ePEXP>',
#    'zerstört',
#    '</ePEXP>',
#    '.'],
#   ['Das',
#    '<eSOURCE>',
#    'Gericht',
#    '</eSOURCE>',
#    'hat',
#    'deshalb',
#    'zu',
#    'Recht',
#    'von',
#    'dieser',
#    'extremen',
#    '<eTARGET>',
#    'Massnahme',
#    '</eTARGET>',
#    '<ePEXP>',
#    'abgesehen',
#    '</ePEXP>',
#    '.'],
#   ['Eine',
#    'ausgeklügelte',
#    '<eSOURCE>',
#    'Lüftungstechnik',
#    '</eSOURCE>',
#    'sollte',
#    '<eTARGET>',
#    'Ansteckungen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'verhindern',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    'Justizdirektion',
#    'stellte',
#    'sich',
#    'auf',
#    'den',
#    'Standpunkt',
#    ',',
#    '«',
#    'angesichts',
#    'des',
#    'bisherigen',
#    'Vollzugsverlaufs',
#    ',',
#    'der',
#    'diagnostizierten',
#    'Persönlichkeitsstörung',
#    'und',
#    'der',
#    'Anlassdelikte',
#    '»',
#    'sei',
#    'eine',
#    '«',
#    'möglichst',
#    'enge',
#    'Betreuung',
#    'und',
#    'Beobachtung',
#    '»',
#    'des',
#    'Gefangenen',
#    'unabdingbar',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Als',
#    'er',
#    'schliesslich',
#    'zu',
#    'seiner',
#    'Gruppe',
#    'stösst',
#    ',',
#    '<ePEXP>',
#    'hetzen',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Schüler',
#    '</eSOURCE>',
#    'beinahe',
#    'im',
#    'Laufschritt',
#    'in',
#    'Richtung',
#    'Bahnhofstrasse',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Das',
#    'AMS-Management',
#    'lässt',
#    'jedoch',
#    'durchblicken',
#    ',',
#    'dass',
#    'man',
#    'dies',
#    'einfach',
#    'auch',
#    'so',
#    'lösen',
#    'könne',
#    ',',
#    'indem',
#    'man',
#    'sicherstellt',
#    ',',
#    'dass',
#    'ein',
#    '<eSOURCE>',
#    'Käufer',
#    '</eSOURCE>',
#    'diese',
#    '<eTARGET>',
#    'Konditionen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'einhält',
#    '</ePEXP>',
#    '.'],
#   ['Erfreulich',
#    ':',
#    'Im',
#    'Vergleich',
#    'mit',
#    'der',
#    'gesamten',
#    'Schweiz',
#    '<ePEXP>',
#    'achten',
#    '</ePEXP>',
#    'in',
#    'der',
#    'Stadt',
#    'Zürich',
#    'prozentual',
#    'mehr',
#    '<eSOURCE>',
#    'Menschen',
#    '</eSOURCE>',
#    'auf',
#    'gesundes',
#    'und',
#    'ausgewogenes',
#    '<eTARGET>',
#    'Essen',
#    '</eTARGET>',
#    '.'],
#   ['Mit',
#    'seinem',
#    'Charisma',
#    '<ePEXP>',
#    'erreicht',
#    '</ePEXP>',
#    'der',
#    'Dirigent',
#    'jedoch',
#    'viel',
#    'mehr',
#    'als',
#    'eine',
#    'bloss',
#    '«',
#    'korrekte',
#    '»',
#    '<eTARGET>',
#    'Interpretation',
#    '</eTARGET>',
#    ':',
#    'Dieses',
#    '<eSOURCE>',
#    'Orchester',
#    '</eSOURCE>',
#    'ist',
#    'hoch',
#    'motiviert',
#    ',',
#    'spielt',
#    'leidenschaftlich',
#    'und',
#    'identifiziert',
#    'sich',
#    'mit',
#    'den',
#    'Affekten',
#    'der',
#    'Protagonisten',
#    '.'],
#   ['Nun',
#    'kommen',
#    'mexikanische',
#    'Forscher',
#    'zu',
#    'uns',
#    ',',
#    'um',
#    'sich',
#    'dem',
#    '<eTARGET>',
#    'Schmuck',
#    '</eTARGET>',
#    'zu',
#    'widmen',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '»',
#    'Die',
#    'k.',
#    'u.',
#    'k.',
#    '<eSOURCE>',
#    'Monarchie',
#    '</eSOURCE>',
#    'liess',
#    'sich',
#    'die',
#    'Sammlerstücke',
#    'und',
#    'Trophäen',
#    'aus',
#    'aller',
#    'Welt',
#    'etwas',
#    'kosten',
#    '.'],
#   ['Nach',
#    'missglückten',
#    'Aktionen',
#    'von',
#    'Jérôme',
#    'Boateng',
#    'und',
#    'dem',
#    'herauseilenden',
#    'Neuer',
#    'warf',
#    'sich',
#    '<eSOURCE>',
#    'David',
#    '</eSOURCE>',
#    'Alaba',
#    'in',
#    'einen',
#    'Schuss',
#    'von',
#    'Werner',
#    'und',
#    '<ePEXP>',
#    'verhinderte',
#    '</ePEXP>',
#    'das',
#    '0',
#    ':',
#    '1',
#    '(',
#    '4',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    ')',
#    '.'],
#   ['«',
#    'Obwohl',
#    'man',
#    'im',
#    'Gesundheitswesen',
#    'der',
#    'Maske',
#    'immer',
#    'zu',
#    'hundert',
#    'Prozent',
#    'vertraute',
#    ',',
#    'wurde',
#    'sie',
#    'vom',
#    'Bundesrat',
#    'über',
#    'Wochen',
#    'verteufelt',
#    '»',
#    ',',
#    'wundert',
#    'sich',
#    'Martullo',
#    'gegenüber',
#    'der',
#    'NZZ',
#    ':',
#    '«',
#    'Später',
#    '<ePEXP>',
#    'fehlte',
#    '</ePEXP>',
#    'den',
#    '<eTARGET>',
#    'Leuten',
#    '</eTARGET>',
#    'deshalb',
#    'der',
#    '<eSOURCE>',
#    'Mut',
#    '</eSOURCE>',
#    ',',
#    'freiwillig',
#    'Masken',
#    'zu',
#    'tragen',
#    '.'],
#   ['In',
#    'Deutschland',
#    'hat',
#    'das',
#    '<eSOURCE>',
#    'Bundesverfassungsgericht',
# ...
#    'zu',
#    'einem',
#    'Zeitpunkt',
#    'also',
#    ',',
#    'an',
#    'dem',
#    'der',
#    '<eSOURCE>',
#    'Innenminister',
#    '</eSOURCE>',
#    'von',
#    'Georgia',
#    'das',
#    'bereits',
#    'beglaubigte',
#    '<eTARGET>',
#    'Ergebnis',
#    '</eTARGET>',
#    'gar',
#    'nicht',
#    'mehr',
#    'hätte',
#    'nachträglich',
#    'ändern',
#    'können',
#    '.'],
#   ['<eSOURCE>',
#    'Müller',
#    '</eSOURCE>',
#    'hat',
#    'eine',
#    'Aussage',
#    'gemacht',
#    ',',
#    'sich',
#    'dafür',
#    '<ePEXP>',
#    'entschuldigt',
#    '</ePEXP>',
#    'und',
#    'eine',
#    'Busse',
#    'erhalten',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Ein',
#    '<eSOURCE>',
#    'Zusammenschluss',
#    '</eSOURCE>',
#    'von',
#    '«',
#    'Revolutionären',
#    'Organisationen',
#    'und',
#    'Einzelpersonen',
#    'aus',
#    'Zürich',
#    '»',
#    'ruft',
#    'hingegen',
#    'dazu',
#    'auf',
#    ',',
#    'die',
#    '<eTARGET>',
#    'Strassen',
#    '</eTARGET>',
#    'nicht',
#    '<ePEXP>',
#    'aufzugeben',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Klimatologen',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'warnen',
#    '</ePEXP>',
#    'vor',
#    'den',
#    '<eTARGET>',
#    'Auswirkungen',
#    '</eTARGET>',
#    'solcher',
#    'Luftströme',
#    'auf',
#    'das',
#    'noch',
#    'bestehende',
#    'Larsen-C-Schelfeis',
#    ',',
#    'das',
#    'grösste',
#    'Eisschelf',
#    'der',
#    'Antarktischen',
#    'Halbinsel',
#    '.'],
#   ['Dabei',
#    'fehlt',
#    'ausgerechnet',
#    'ihr',
#    'erfahrenster',
#    'Mann',
#    ':',
#    'Blerim',
#    'Dzemaili',
#    '(',
#    '36',
#    ')',
#    'ist',
#    'in',
#    'Zürich',
#    'geblieben',
#    ',',
#    'den',
#    'Ex-Nati-Star',
#    '<ePEXP>',
#    'plagen',
#    '</ePEXP>',
#    'noch',
#    'immer',
#    '<eSOURCE>',
#    'Wadenprobleme',
#    '</eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Zudem',
#    'würde',
#    'sich',
#    'für',
#    '<eTARGET>',
#    'Bund',
#    '</eTARGET>',
#    ',',
#    'Parlament',
#    'und',
#    'Steuerzahlende',
#    'eine',
#    'Reihe',
#    'von',
#    'anspruchsvollen',
#    'Fragen',
#    'in',
#    'Bezug',
#    'auf',
#    'Führung',
#    ',',
#    'Aufsicht',
#    'und',
#    'Finanzierung',
#    'dieser',
#    'neuen',
#    'Staatsbank',
#    'stellen',
#    '<eSOURCE>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eSOURCE>'],
#   ['Begonnen',
#    'hat',
#    'alles',
#    'vor',
#    'gut',
#    'einer',
#    'Woche',
#    ',',
#    'als',
#    'die',
#    'grosse',
#    '<eSOURCE>',
#    'Supermarktkette',
#    '</eSOURCE>',
#    'Leclerc',
#    'eine',
#    'Senkung',
#    'des',
#    'Preises',
#    'für',
#    'eine',
#    'Baguette',
#    'ankündigte',
#    ':',
#    'auf',
#    '29',
#    'Cent',
#    ',',
#    'zurzeit',
#    'etwa',
#    '30',
#    'Rappen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Dieser',
#    'Tage',
#    'hat',
#    '<eSOURCE>',
#    'Präsident',
#    '</eSOURCE>',
#    'Aleksandar',
#    'Vucic',
#    'nun',
#    'sogar',
#    'finanzielle',
#    'Anreize',
#    'zur',
#    'Immunisierung',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Affäre',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'letztes',
#    'Jahr',
#    'zum',
#    'Sturz',
#    'des',
#    'Präsidenten',
#    'Gottfried',
#    'Locher',
#    'führte',
#    ',',
#    'hat',
#    'die',
#    'Evangelisch-reformierte',
#    'Kirche',
#    'der',
#    'Schweiz',
#    '(',
#    'EKS',
#    ')',
#    'in',
#    'eine',
#    'tiefe',
#    'Krise',
#    '<ePEXP>',
#    'gestürzt',
#    '</ePEXP>',
#    'und',
#    'ihr',
#    'einen',
#    'gewaltigen',
#    'Reputationsschaden',
#    'eingebracht',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Er',
#    'hatte',
#    'Anfang',
#    'November',
#    'bei',
#    'den',
#    'ZSC',
#    'Lions',
#    'für',
#    'die',
#    'kommenden',
#    'zwei',
#    'Saisons',
#    'als',
#    'Nummer',
#    '2',
#    'neben',
#    'Lukas',
#    'Flüeler',
#    '<ePEXP>',
#    'unterschrieben',
#    '</ePEXP>',
#    '–',
#    'sein',
#    'Auftritt',
#    'war',
#    'vielleicht',
#    'das',
#    'Einzige',
#    ',',
#    'worüber',
#    'sich',
#    'die',
#    'Lions-Fans',
#    'heimlich',
#    'freuen',
#    'konnten',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['<eSOURCE>',
#    'Analytiker',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'fürchten',
#    '</ePEXP>',
#    'sich',
#    'vor',
#    'einem',
#    '<eTARGET>',
#    'Passus',
#    '</eTARGET>',
#    ',',
#    'der',
#    'der',
#    'Energieindustrie',
#    'grossen',
#    'Schaden',
#    'zufügen',
#    'könnte',
#    '.'],
#   ['Sieben',
#    '<eSOURCE>',
#    'Personen',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'erlitten',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Rauchgasvergiftungen',
#    '</eTARGET>',
#    '.'],
#   ['Im',
#    'Nachwort',
#    'des',
#    'soeben',
#    'erschienenen',
#    'Fotobuches',
#    'heisst',
#    'es',
#    ':',
#    '«',
#    'Ein',
#    '<eSOURCE>',
#    'Blick',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'offenbart',
#    '</ePEXP>',
#    'nur',
#    'einen',
#    '<eTARGET>',
#    'Bruchteil',
#    '</eTARGET>',
#    'dessen',
#    ',',
#    'was',
#    'zu',
#    'sehen',
#    'ist',
#    '.'],
#   ['<eSOURCE>',
#    'Ursula',
#    '</eSOURCE>',
#    'von',
#    'der',
#    'Leyen',
#    'muss',
#    'nun',
#    'rasch',
#    '<eTARGET>',
#    'Ersatz',
#    '</eTARGET>',
#    '<ePEXP>',
#    'finden',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Beuys',
#    '</eSOURCE>',
#    'äusserte',
#    'in',
#    'diesem',
#    'Kontext',
#    ',',
#    'er',
#    'arbeite',
#    'mit',
#    'Tieren',
#    ',',
#    'um',
#    'unsichtbare',
#    'Kräfte',
#    'erlebbar',
#    'zu',
#    'machen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Fünftes',
#    'Kind',
#    'im',
#    'Bauch',
#    ':',
#    '<eSOURCE>',
#    'Brigitte',
#    '</eSOURCE>',
#    'Nielsen',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    'auf',
#    '<eTARGET>',
#    'Nachwuchs',
#    '</eTARGET>',
#    '.'],
#   ['Fussball',
#    'Die',
#    'Schweizer',
#    '<eSOURCE>',
#    'Marketingagentur',
#    '</eSOURCE>',
#    'Infront',
#    'hat',
#    'einen',
#    'leitenden',
#    '<eTARGET>',
#    'Angestellten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'entlassen',
#    '</ePEXP>',
#    ',',
#    'nachdem',
#    'es',
#    'bei',
#    'Bandenwerbung',
#    'bei',
#    'deutschen',
#    'Länderspielen',
#    'zu',
#    'Unregelmässigkeiten',
#    'gekommen',
#    'sein',
#    'soll',
#    '.'],
#   ['<eSOURCE>',
#    'Shaqiri',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'entschuldigte',
#    '</ePEXP>',
#    'sich',
#    'Monate',
#    'später',
#    'ziemlich',
#    'nonchalant',
#    'für',
#    'seine',
#    '<eTARGET>',
#    'Geste',
#    '</eTARGET>',
#    '–',
#    'frei',
#    'nach',
#    'dem',
#    'Motto',
#    ':',
#    '«',
#    'Das',
#    'gehört',
#    'alles',
#    'zu',
#    'mir',
#    '.'],
#   ['Dieser',
#    'Krieg',
#    'wurde',
#    'geführt',
#    ',',
#    'um',
#    '<eTARGET>',
#    'Dachau',
#    '</eTARGET>',
#    'abzuschaffen',
#    'und',
#    'all',
#    'die',
#    'anderen',
#    'Orte',
#    'wie',
#    'Dachau',
#    ',',
#    'alles',
#    ',',
#    'wofür',
#    'Dachau',
#    'steht',
#    '<eSOURCE>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eSOURCE>'],
#   ['Das',
#    'Treffen',
#    'mit',
#    'dem',
#    'Insider',
#    'zeigt',
#    ',',
#    'dass',
#    'es',
#    'in',
#    'der',
#    'Branche',
#    'heikel',
#    'sein',
#    'kann',
#    ',',
#    'Kritik',
#    'an',
#    'China',
#    'zu',
#    'äussern',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Die',
#    '<eSOURCE>',
#    'Kaserne',
#    '</eSOURCE>',
#    'in',
#    'Dübendorf',
#    '<ePEXP>',
#    'erreichte',
#    '</ePEXP>',
#    'das',
#    '<eTARGET>',
#    'Virus',
#    '</eTARGET>',
#    'vergangene',
#    'Woche',
#    '.'],
#   ['Ein',
#    '<eSOURCE>',
#    'Zweitligist',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'haut',
#    '</ePEXP>',
#    'Österreichs',
#    '<eTARGET>',
#    'Rekordmeister',
#    '</eTARGET>',
#    'raus',
#    '.'],
#   ['Das',
#    'Bundesgericht',
#    'hält',
#    'fest',
#    ',',
#    'das',
#    '<eSOURCE>',
#    'Obergericht',
#    '</eSOURCE>',
#    'habe',
#    'die',
#    '<eTARGET>',
#    'Umstände',
#    '</eTARGET>',
#    'der',
#    'früheren',
#    'Strafen',
#    'und',
#    'Zwangsmassnahmen',
#    'nicht',
#    'ausreichend',
#    '<ePEXP>',
#    'aufgearbeitet',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    'Parlamentsdienste',
#    'sorgen',
#    'für',
#    'Stunk',
#    'in',
#    'der',
#    'Wandelhalle',
#    ':',
#    'Die',
#    '<eSOURCE>',
#    'Dienstleister',
#    '</eSOURCE>',
#    'der',
#    'Bundesverwaltung',
#    '<ePEXP>',
#    'verweigerten',
#    '</ePEXP>',
#    'GLP',
#    '<eTARGET>',
#    'Nationalrat',
#    '</eTARGET>',
#    'Martin',
#    'Bäumle',
#    '(',
#    '55',
#    ')',
#    'die',
#    'Annahme',
#    'einer',
#    'parlamentarischen',
#    'Initiative',
#    '.'],
#   ['Die',
#    'Schuldenbremse',
#    'gibt',
#    'nun',
#    'vor',
#    ',',
#    'dass',
#    'der',
#    '<eSOURCE>',
#    'Bund',
#    '</eSOURCE>',
#    'innert',
#    '6',
#    'Jahren',
#    '25',
#    'bis',
#    '30',
#    'Mr',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    'Fr.',
#    'tilgen',
#    'muss',
#    '.'],
#   ['Zudem',
#    'wird',
#    'das',
#    '<eSOURCE>',
#    'Land',
#    '</eSOURCE>',
#    'mit',
#    '282',
#    'Milliarden',
#    'Euro',
#    'eine',
#    'rekordhohe',
#    'Summe',
#    'an',
#    'neuen',
#    'Krediten',
#    'an',
#    'den',
#    'Märkten',
#    '<ePEXP>',
#    'aufnehmen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Auch',
#    '<ePEXP>',
#    'verträgt',
#    '</ePEXP>',
#    'sich',
#    'eine',
#    'zu',
#    'schroffe',
#    'Anti-Migrations',
#    '<eSOURCE>',
#    'Politik',
#    '</eSOURCE>',
#    'nur',
#    'schwer',
#    'mit',
#    'den',
#    'humanitären',
#    'Grundsätzen',
#    'einer',
#    'christlich-sozialen',
#    'Partei',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Dabei',
#    'gelangte',
#    'sie',
#    'zum',
#    'Schluss',
#    ',',
#    '<eSOURCE>',
#    'Lauber',
#    '</eSOURCE>',
#    'habe',
#    'verschiedene',
#    '<eTARGET>',
#    'Amtspflichten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'verletzt',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Türkei',
#    '</eSOURCE>',
#    'wiederum',
#    'hat',
#    'den',
#    'deutschen',
#    'Botschafter',
#    'einbestellt',
#    ',',
#    'um',
#    'sich',
#    'über',
#    'die',
#    'Attacken',
#    'gegen',
#    'ihre',
#    'Landsleute',
#    'zu',
#    'beschweren',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Fragen',
#    '</eSOURCE>',
#    'stellen',
#    'sich',
#    'eher',
#    'hinsichtlich',
#    'der',
#    'Effektivität',
#    'der',
#    'Kontrolle',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Ein',
#    'solches',
#    'Niveau',
#    'wie',
#    'jetzt',
#    'gab',
#    'es',
#    'vorher',
#    'nicht',
#    '.',
#    '»',
#    'Letzten',
#    'Samstag',
#    'aber',
#    '<ePEXP>',
#    'stürzte',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Suter',
#    '</eSOURCE>',
#    'im',
#    'Super-G-Training',
#    ',',
#    'erlitt',
#    'schwere',
#    '<eTARGET>',
#    'Knochenprellungen',
#    '</eTARGET>',
#    'an',
#    'den',
#    'Schienbeinen',
#    'und',
#    'Schürfwunden',
#    'im',
#    'Gesicht',
#    '.'],
#   ['Keine',
#    'zwei',
#    'Jahre',
#    'später',
#    'ging',
#    '«',
#    'Smokin',
#    '’',
#    'Joe',
#    '»',
#    'beim',
#    'Titelkampf',
#    'gegen',
#    'den',
#    'übermächtigen',
#    'Herausforderer',
#    'George',
#    'Foreman',
#    'gleich',
#    'sechsmal',
#    'zu',
#    'Boden',
#    ',',
#    'ehe',
#    'der',
#    '<eSOURCE>',
#    'Ringrichter',
#    '</eSOURCE>',
#    'das',
#    '<eTARGET>',
#    'Gemetzel',
#    '</eTARGET>',
#    'Mitte',
#    'der',
#    'zweiten',
#    'Runde',
#    '<ePEXP>',
#    'abbrach',
#    '</ePEXP>',
#    '.'],
#   ['Von',
#    'Anfang',
#    'an',
#    '<ePEXP>',
#    'beharrt',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Bora',
#    '</eSOURCE>',
#    'Ćosić',
#    'auf',
#    'der',
#    '<eTARGET>',
#    'Absurdität',
#    '</eTARGET>',
#    'menschlicher',
#    'Existenz',
#    ';',
#    'Samuel',
#    'Becketts',
#    'als',
#    'Clownerie',
#    'getarnte',
#    'Illusionslosigkeit',
#    'und',
#    'Freuds',
#    'Tiefenpsychologie',
#    'werden',
#    'seine',
#    'ständigen',
#    'Begleiter',
#    '.'],
#   ['Ein',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'sticht',
#    'die',
#    'Oberbürgermeisterin',
#    'an',
#    'einem',
#    'Info-Stand',
#    'der',
#    'CDU',
#    'nieder',
#    'und',
#    '<ePEXP>',
#    'verletzt',
#    '</ePEXP>',
#    'weitere',
#    'umstehende',
#    '<eTARGET>',
#    'Personen',
#    '</eTARGET>',
#    '.'],
#   ['Nach',
#    'dem',
#    'glimpflichen',
#    'Ausgang',
#    'dieses',
#    'Dramas',
#    'und',
#    'der',
#    'Rettungsaktion',
#    'von',
#    'noch',
#    'nie',
#    'gesehenem',
#    'Ausmass',
#    'stellt',
#    'sich',
#    'die',
#    'Frage',
#    ',',
#    'wie',
#    'solch',
#    'ein',
#    'Horrorszenario',
#    'in',
#    'Zukunft',
#    '<ePEXP>',
#    'verhindert',
#    '</ePEXP>',
#    'werden',
#    'kann',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Nach',
#    'Ansicht',
#    'der',
#    'Richter',
#    'hat',
#    'die',
#    '<eSOURCE>',
#    'Untersuchungshaft',
#    '</eSOURCE>',
#    'das',
#    '<eTARGET>',
#    'Recht',
#    '</eTARGET>',
#    'auf',
#    'persönliche',
#    'Freiheit',
#    'und',
#    'Sicherheit',
#    'sowie',
#    'das',
#    'Recht',
#    'auf',
#    'Meinungs-',
#    'und',
#    'Pressefreiheit',
#    '<ePEXP>',
#    'verletzt',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Syrien',
#    '</eSOURCE>',
#    'und',
#    'sein',
#    'Verbündeter',
#    'Russland',
#    'hatten',
#    'die',
#    '<eTARGET>',
#    'Vorwürfe',
#    '</eTARGET>',
#    'stets',
#    '<ePEXP>',
#    'zurückgewiesen',
#    '</ePEXP>',
#    'und',
#    'von',
#    'einer',
#    '«',
#    'inszenierten',
#    'Attacke',
#    '»',
#    'gesprochen',
#    '.'],
#   ['Für',
#    'die',
#    'damalige',
#    '<eTARGET>',
#    'Behandlung',
#    '</eTARGET>',
#    'von',
#    'Littlefeather',
#    'hat',
#    'sich',
#    'die',
#    'Oscar',
#    '<eSOURCE>',
#    'Akademie',
#    '</eSOURCE>',
#    'nun',
#    '<ePEXP>',
#    'entschuldigt',
#    '</ePEXP>',
#    '–',
#    'fast',
#    '50',
#    'Jahre',
#    'nach',
#    'dem',
#    'Vorfall',
#    '.'],
#   ['Für',
#    'einigen',
#    '<eTARGET>',
#    'Wirbel',
#    '</eTARGET>',
#    'hatte',
#    'kurz',
#    'vor',
#    'der',
#    'Ernennung',
#    'allerdings',
#    'noch',
#    'ein',
#    'anonymes',
#    '<eSOURCE>',
#    'Schreiben',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'gesorgt',
#    '</ePEXP>',
#    ',',
#    'in',
#    'dem',
#    'Bar',
#    'berufliches',
#    'Fehlverhalten',
#    'in',
#    'zwei',
#    'Fällen',
#    'vorgeworfen',
#    'wurde',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Kantone',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'stellten',
#    '</ePEXP>',
#    'sich',
#    'nicht',
#    'gegen',
#    'eine',
#    '<eTARGET>',
#    'Umsetzung',
#    '</eTARGET>',
#    'der',
#    'Sanktionen',
#    ',',
#    'betont',
#    'Tännler',
#    '.'],
#   ['Der',
#    'Tag',
#    'war',
#    'fast',
#    'vorbei',
#    ',',
#    'und',
#    'die',
#    '<eSOURCE>',
#    'Spieler',
#    '</eSOURCE>',
#    'von',
#    'Real',
#    '<ePEXP>',
#    'jubelten',
#    '</ePEXP>',
#    'noch',
#    'immer',
#    'über',
#    'einen',
#    '<eTARGET>',
#    'Sieg',
#    '</eTARGET>',
#    ',',
#    'an',
#    'den',
#    'sie',
#    'vielleicht',
#    'nicht',
#    'mal',
#    'mehr',
#    'selbst',
#    'geglaubt',
#    'hatten',
#    '.'],
#   ['Offiziell',
#    'hat',
#    '<eSOURCE>',
#    'Donald',
#    '</eSOURCE>',
#    'Trump',
#    'seine',
#    '<eTARGET>',
#    'Kandidatur',
#    '</eTARGET>',
#    'für',
#    '2024',
#    'nicht',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '.'],
#   ['Doch',
#    'die',
#    'beiden',
#    '<eSOURCE>',
#    'Zürcher',
#    '</eSOURCE>',
#    'tun',
#    'viel',
#    'dafür',
#    ',',
#    'um',
#    'öffentlich',
#    'wie',
#    'ein',
#    'eingespieltes',
#    'Team',
#    'zu',
#    '<ePEXP>',
#    'wirken',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Buchs',
#    'SG',
#    '–',
#    'Zwei',
#    '<eSOURCE>',
#    'Männer',
#    '</eSOURCE>',
#    'haben',
#    'am',
#    'Mittwochabend',
#    'einen',
#    '<eTARGET>',
#    'Tankstellen',
#    '</eTARGET>',
#    'Shop',
#    '<ePEXP>',
#    'überfallen',
#    '</ePEXP>',
#    '.'],
#   ['Jetzt',
#    'hat',
#    'der',
#    'Postauto',
#    '<eSOURCE>',
#    'Skandal',
#    '</eSOURCE>',
#    'das',
#    '<eTARGET>',
#    'Liechtensteiner',
#    'Parlament',
#    '</eTARGET>',
#    '<ePEXP>',
#    'erreicht',
#    '</ePEXP>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Thurgauer',
#    '</eSOURCE>',
#    'kann',
#    'sich',
#    'trotz',
#    'seines',
#    'fünften',
#    'Boston-Sieges',
#    'nicht',
#    'uneingeschränkt',
#    '<ePEXP>',
#    'freuen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Ausser',
#    'Werner',
#    '<ePEXP>',
#    'vergab',
#    '</ePEXP>',
#    'noch',
#    '<eSOURCE>',
#    'Captain',
#    '</eSOURCE>',
#    'Marcel',
#    'Sabitzer',
#    'eine',
#    '<eTARGET>',
#    'Grosschance',
#    '</eTARGET>',
#    '(',
#    '46.',
#    ')',
#    '.'],
#   ...]}

# %% [markdown]
# ### Delete this later!
#
# Just for a test on the RE Model performance!

# %%
if VERIFY_RE_MODEL:
    with open(DATASOURCE, "r", encoding="utf-8") as f:
        tokenized_ssa_sents = {"tokens": [], "labels": []}
        for line in f:
            #print(line)
            ds = json.loads(line)
            tokenized_ssa_sents["tokens"].append(ds["tokens"])
            tokenized_ssa_sents["labels"].append(ds["label"])

    gold_polarities = [lbl for lbl in tokenized_ssa_sents["labels"]]

# %% [markdown]
# ### Generate unbreakable tokens based on original dataframe
#
# **Important**: We make sure that every sentence contains a dot in the end that is separated from the last word in the sentence!

# %%
import collections
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import random
import re
import shutil
import torch
import torch.nn as nn

from collections import Counter, defaultdict
from datasets import load_dataset, ClassLabel
from sklearn.metrics import (
    ConfusionMatrixDisplay, confusion_matrix, 
    classification_report, accuracy_score
)
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch.optim import AdamW

from transformers import (
    BertTokenizerFast, BertModel, BertForPreTraining, BertConfig, BertPreTrainedModel,
    DataCollatorWithPadding,
    get_scheduler
)
from transformers.modeling_outputs import SequenceClassifierOutput

# %%
class BertForRelationExtraction(BertPreTrainedModel):
  def __init__(self, config, num_labels):
    super(BertForRelationExtraction, self).__init__(config)
    self.num_labels = num_labels
    # body
    self.bert = BertModel(config)
    # head
    self.dropout = nn.Dropout(config.hidden_dropout_prob)
    #self.layer_norm = nn.LayerNorm(config.hidden_size * 2)
    #self.linear = nn.Linear(config.hidden_size * 2, self.num_labels)
    self.init_weights()
    
    self.layer_norm = nn.LayerNorm(config.hidden_size * 3)
    self.linear = nn.Linear(config.hidden_size * 3, self.num_labels)

  def forward(self, input_ids, token_type_ids, attention_mask,
              span_idxs, labels=None):
    outputs = (
        self.bert(input_ids, token_type_ids=token_type_ids,
                  attention_mask=attention_mask,
                  output_hidden_states=False)
            .last_hidden_state)
            
    sub_maxpool, obj_maxpool, pexp_maxpool = [], [], []
    #sub_maxpool, obj_maxpool = [], []
    for bid in range(outputs.size(0)):
      # span includes entity markers, maxpool across span
      sub_span = torch.max(outputs[bid, span_idxs[bid, 0]:span_idxs[bid, 1]+1, :], 
                           dim=0, keepdim=True).values
      obj_span = torch.max(outputs[bid, span_idxs[bid, 2]:span_idxs[bid, 3]+1, :],
                           dim=0, keepdim=True).values
      pexp_span = torch.max(outputs[bid, span_idxs[bid, 4]:span_idxs[bid, 5]+1, :], dim=0, keepdim=True).values
      sub_maxpool.append(sub_span)
      obj_maxpool.append(obj_span)
      pexp_maxpool.append(pexp_span)

    sub_emb = torch.cat(sub_maxpool, dim=0)
    obj_emb = torch.cat(obj_maxpool, dim=0)
    pexp_emb = torch.cat(pexp_maxpool, dim=0)
    rel_input = torch.cat((sub_emb, obj_emb, pexp_emb), dim=-1)
    #rel_input = torch.cat((sub_emb, obj_emb), dim=-1)

    rel_input = self.layer_norm(rel_input)
    rel_input = self.dropout(rel_input)
    logits = self.linear(rel_input)

    if labels is not None:
      loss_fn = nn.CrossEntropyLoss()
      loss = loss_fn(logits.view(-1, self.num_labels), labels.view(-1))
      return SequenceClassifierOutput(loss, logits)
    else:
      return SequenceClassifierOutput(None, logits)


# config = BertConfig.from_pretrained(BASE_MODEL_NAME)
# model = BertForRelationExtraction.from_pretrained(BASE_MODEL_NAME, 
#                                                   config=config,
#                                                   num_labels=len(valid_relations))
# model.bert.resize_token_embeddings(len(tokenizer.vocab))
# for batch in train_dl:
#   outputs = model(**batch)
#   break
# print("loss:", outputs.loss, "logits.size:", outputs.logits.size())

# %%
tokenizer = BertTokenizerFast.from_pretrained(BASE_MODEL_NAME)

vocab_size_orig = len(tokenizer.vocab)

marker_tokens = []
entity_types = ["eSOURCE", "eTARGET", "ePEXP"]
for entity_type in entity_types:
  marker_tokens.append("<{:s}>".format(entity_type))
  marker_tokens.append("</{:s}>".format(entity_type))

tokenizer.add_tokens(marker_tokens)
vocab_size_new = len(tokenizer.vocab)

print("original vocab size:", vocab_size_orig)
print("new vocab size:", vocab_size_new)

def encode_data(examples):
  tokenized_inputs = tokenizer(examples["tokens"],
                               is_split_into_words=True,
                               truncation=True)
  span_idxs = []
  for input_id in tokenized_inputs.input_ids:
    tokens = tokenizer.convert_ids_to_tokens(input_id)
    try:
        span_idxs.append([
          [idx for idx, token in enumerate(tokens) if token.startswith("<eS")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eS")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("<eT")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eT")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("<eP")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eP")][0],
        ])
    except Exception as e:
        print(f"Encountered error because of: { str(e) }, { str(tokens) }")
        # from IPython.core.debugger import Pdb; Pdb().set_trace()
        # print(f"Tokens of sentence: { str(examples['tokens']) }")

  tokenized_inputs["span_idxs"] = span_idxs
  # tokenized_inputs["labels"] = [label2id[label] for label in examples["label"]]
  return tokenized_inputs

#print(X)
#encoded = encode_data(X)
#encoded.keys()
#print(encoded)
# Out:
# original vocab size: 30000
# new vocab size: 30006

# %%
encoded = encode_data(tokenized_ssa_sents)
# encoded

# %%
from datasets import Dataset
BATCH_SIZE = 4
collate_fn = DataCollatorWithPadding(tokenizer, padding="longest", return_tensors="pt")
test_dl = DataLoader(Dataset.from_dict(encoded),
                      # shuffle=True, 
                      batch_size=BATCH_SIZE, 
                      collate_fn=collate_fn)

# print([x for x in test_dl])

# %%
valid_relations = ["Positive", "Neutral", "Negative"]
valid_relations = sorted(list(valid_relations))

# %%
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_file = os.path.join(MODEL_DIR, "ckpt-{:d}".format(3))

print("=> Loading checkpoint")
# checkpoint = model.from_pretrained(checkpoint_file)
config = BertConfig.from_pretrained(checkpoint_file)
model = BertForRelationExtraction.from_pretrained(checkpoint_file, 
                      config=config,
                      num_labels=len(valid_relations))
# model.load_state_dict(checkpoint["state_dict"])
model.bert.resize_token_embeddings(len(tokenizer.vocab))
model.eval()
model = model.to(device)
# Out:
# => Loading checkpoint

# %%
# confirm the model is not in training
model.training
# Out:
# False

# %%
ytrue, ypred = [], []
with tqdm(test_dl, unit="batch") as tepoch:
    for batch in tepoch:
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
          outputs = model(**batch)
          predictions = torch.argmax(outputs.logits, dim=-1).cpu().numpy()
          #labels = batch["labels"].cpu().numpy()
          #ytrue.extend(labels)
          ypred.extend(predictions)

#print("test accuracy: {:.3f}".format(accuracy_score(ytrue, ypred)))

#print(classification_report(ytrue, ypred, target_names=valid_relations))
# Out:
#   0%|                                                                                                     | 0/1331 [00:00<?, ?batch/s]You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 1331/1331 [51:53<00:00,  2.34s/batch]

# %%
preds_full_label_text = [valid_relations[i] for i in ypred]

# %%
preds_full_label_text
# Out:
# ['Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  ...]

# %%
valid_relations
# Out:
# ['Negative', 'Neutral', 'Positive']

# %% [markdown]
# ### Save the data
#
# Reading in the data so it can be processed. The format is SSA.

# %%
def construct_ssa_dataset(preds, out_data_w_ents):
    new_out_struct = []
    for pred, out_ds in zip(preds, out_data_w_ents):
        od = copy.deepcopy(out_ds)
        od["opinions"][0]["Polarity"] = pred
        new_out_struct.append(od)
    return new_out_struct

out_data_w_entities_and_rel = construct_ssa_dataset(preds_full_label_text, out_data_w_entities)

# %%
out_data_w_entities_and_rel
# Out:
# [{'sent_id': '0',
#   'text': 'Finnland will sich dort auch für eine Verteuerung der Touristenvisa einsetzen .',
#   'opinions': [{'Source': [['Finnland'], ['0:8']],
#     'Target': [['Verteuerung'], ['38:49']],
#     'Polar_expression': [['einsetzen'], ['68:77']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': '( sda ) Eishockey Ottawa entlässt seinen Headcoach Guy Boucher ( 47 ) .',
#   'opinions': [{'Source': [['Eishockey'], ['8:17']],
#     'Target': [['Headcoach'], ['41:50']],
#     'Polar_expression': [['entlässt'], ['25:33']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Bei den israelischen Siedlungen im Westjordanland pfeift US-Präsident Trump aufs Völkerrecht .',
#   'opinions': [{'Source': [['Präsident'], ['60:69']],
#     'Target': [['Völkerrecht'], ['81:92']],
#     'Polar_expression': [['pfeift'], ['50:56']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Bei negativen Gedanken wie diesen wird die Personalfachfrau ständig von schlimmen Erinnerungen heimgesucht : « Denke ich daran , dass Nils sich infizieren könnte , sehe ich die schrecklichen Bilder vor mir , als er als Baby an der Herz-Lungen-Maschine angeschlossen war .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': 'Der Name verweist auf die Art , wie diese Temperatur bestimmt werden kann : indem man die Birne eines Thermometers ( bulb ) in ein nasses Tuch wickelt und dann schaut , welche Temperatur das Thermometer anzeigt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'Sanders versuchte zwar , die Corona-Krise als Argument zu benutzen , dass seine Forderung nach einer allgemeinen , staatlichen Krankenversicherung richtig sei .',
#   'opinions': [{'Source': [['Sanders'], ['0:7']],
#     'Target': [[], []],
#     'Polar_expression': [['benutzen'], ['58:66']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Der Trainer der New Jersey Devils sagte , er sehe den jungen Oberwalliser als zukünftigen « franchise player » und er glaube , dass Hischier irgendwann die Selke Trophy gewinnen werde .',
#   'opinions': [{'Source': [['Hischier'], ['132:140']],
#     'Target': [[], []],
#     'Polar_expression': [['gewinnen'], ['169:177']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Das Kuchi-Daaberettli mahnt aber \xad dennoch zur Vorsicht : Drotz Corona duen y hitte do my Schnitzelbangg singe und hoff , s däät glinge , eich zem Schmunzle z bringe .',
#   'opinions': [{'Source': [['Daaberettli'], ['10:21']],
#     'Target': [['Vorsicht'], ['47:55']],
#     'Polar_expression': [['mahnt'], ['22:27']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Labour-Abgeordnete standen der Reihe nach auf , um den Kreml zu schelten und Corbyn zwischen den Zeilen die Meinung zu sagen .',
#   'opinions': [{'Source': [['Abgeordnete'], ['7:18']],
#     'Target': [['Kreml'], ['55:60']],
#     'Polar_expression': [['schelten'], ['64:72']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Pécresse will die 35-Stunden-Woche abschaffen , das reguläre Pensionsalter von 62 auf 65 erhöhen und 200 ’ 000 Beamtenposten streichen .',
#   'opinions': [{'Source': [['Pécresse'], ['0:8']],
#     'Target': [[], []],
#     'Polar_expression': [['streichen'], ['125:134']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': 'Mit einem Abseitsstehen zöge die Schweiz mit Ländern wie den USA , Ungarn oder Österreich gleich , wo Kanzler Sebastian Kurz unter Druck der rechtspopulistischen Koalitionspartnerin FPÖ agiert .',
#   'opinions': [{'Source': [['Kanzler'], ['102:109']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': 'Nachdem Indiens Luftwaffe in der Nacht zum Dienstag zum ersten Mal seit 1971 einen Angriff auf pakistanischem Gebiet geflogen hatte , schoss Pakistan nach eigenen Angaben am Mittwoch zwei indische Kampfflugzeuge ab .',
#   'opinions': [{'Source': [['Pakistan'], ['141:149']],
#     'Target': [['Kampfflugzeuge'], ['197:211']],
#     'Polar_expression': [['schoss'], ['134:140']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Daneben freut sich Charlene , der Kelch ist an ihr vorübergegangen .',
#   'opinions': [{'Source': [['Kelch'], ['34:39']],
#     'Target': [[], []],
#     'Polar_expression': [['freut'], ['8:13']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Im Berufsauftrag hat die Bildungsdirektion pro Jahreslektion einen Faktor von 58 Arbeitsstunden für Vor- und Nachbereitung eingesetzt .',
#   'opinions': [{'Source': [['Bildungsdirektion'], ['25:42']],
#     'Target': [['Vor'], ['100:103']],
#     'Polar_expression': [['eingesetzt'], ['123:133']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Der schlaue Polit-Fuchs freute sich über seine Aufwertung auf der Weltbühne , machte aber weder in der Ukraine-Politik noch bei der Unterstützung der russischen Turk-Stream-Pipeline Konzessionen .',
#   'opinions': [{'Source': [['Fuchs'], ['18:23']],
#     'Target': [['Aufwertung'], ['47:57']],
#     'Polar_expression': [['freute'], ['24:30']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': '« Die Situation ist aussergewöhnlich , und es stellen sich viele neue Fragen » , sagt Robert Breiter , Generalsekretär des Schweizerischen Fussballverbands , « aber am Ende geht es auch bei diesem Wettbewerb um einen Pokal . » Das passt zu den Worten von Luzerns Sportchef Remo Meyer : « Es gibt keine optimale Lösung für alle .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Das BAG hat deshalb die Kantonsärzte angewiesen , die Teststrategie anzupassen .',
#   'opinions': [{'Source': [['BAG'], ['4:7']],
#     'Target': [['Teststrategie'], ['54:67']],
#     'Polar_expression': [['anzupassen'], ['68:78']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Und das tolle Ensemble haut mit seiner Spielfreude die Skepsis an dem Ding , das sie da spielen , weg .',
#   'opinions': [{'Source': [['Ensemble'], ['14:22']],
#     'Target': [['Skepsis'], ['55:62']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Die Polizei nutzte ein Mobilfunknetz , mit dem sie die Personen-ID per QR-Code auslesen konnte .',
#   'opinions': [{'Source': [['Polizei'], ['4:11']],
#     'Target': [['Personen'], ['55:63']],
#     'Polar_expression': [['nutzte'], ['12:18']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': 'Da würde auch die Europäische Union nicht immer gewinnen gegen die Schweiz .',
#   'opinions': [{'Source': [['Union'], ['30:35']],
#     'Target': [['Schweiz'], ['67:74']],
#     'Polar_expression': [['gewinnen'], ['48:56']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Gleiches gilt für die Ducati Multistrada Enduro , die sogar mit 158 PS aufwarten kann .',
#   'opinions': [{'Source': [['Gleiches'], ['0:8']],
#     'Target': [['Ducati'], ['22:28']],
#     'Polar_expression': [['gilt'], ['9:13']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Aus der Analyse der Tore und des Aushubs kommt das Center zum Schluss , die Tunnels könnten vermutlich sämtliche für Operationen benötigten Fahrzeuge der Basis aufnehmen , inklusive der mobilen Abschussrampen .',
#   'opinions': [{'Source': [['Tunnels'], ['76:83']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnehmen'], ['160:169']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Der Flughafen stellt sich im Weiteren auf den Standpunkt , dass der Bazl-Vorschlag eine massive Schwächung der Investitionskraft der Flughäfen Zürich und Genf zur Folge haben werde .',
#   'opinions': [{'Source': [['Vorschlag'], ['73:82']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Traumatisiert durch das Massaker vom August 2013 , bei dem Sicherheitskräfte auf dem Kairoer Rabaa-al-Adawiya-Platz weit über 800 Anhänger der Muslimbrüder töteten , und aufgerieben durch die Verhaftungen von Zehntausenden ihrer Mitglieder , sind die « ikhwan al-muslimin » in ihrem Mutterland heute politisch bedeutungslos .',
#   'opinions': [{'Source': [['Sicherheitskräfte'], ['59:76']],
#     'Target': [['Anhänger'], ['130:138']],
#     'Polar_expression': [['töteten'], ['156:163']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'Neun Tage zuvor hatte ein Amokläufer 1,4 Kilometer vom Stadion entfernt 58 Menschen ermordet .',
#   'opinions': [{'Source': [['Amokläufer'], ['26:36']],
#     'Target': [['Menschen'], ['75:83']],
#     'Polar_expression': [['ermordet'], ['84:92']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'US-Stars wie Rapperin Bhad Bhabie ( 18 ) jubeln über immer neue Einnahme-Rekorde : Die Rede ist von Millionenbeträgen innert weniger Stunden .',
#   'opinions': [{'Source': [['Stars'], ['3:8']],
#     'Target': [['Rekorde'], ['73:80']],
#     'Polar_expression': [['jubeln'], ['41:47']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': '« Das ist einfach nur geil » , freut sich Nelson Ferreira nach der Partie über den zweiten Finaleinzug in der Vereinsgeschichte des FC Thun .',
#   'opinions': [{'Source': [['Nelson'], ['42:48']],
#     'Target': [['Finaleinzug'], ['91:102']],
#     'Polar_expression': [['freut'], ['31:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Die einstige Regierungspartei Vereinigte Nationale Bewegung des früheren Präsidenten Micheil Saakaschwili und weitere Oppositionsparteien stellten sich auf die Seite der Protestierenden .',
#   'opinions': [{'Source': [['Regierungspartei'], ['13:29']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Maltas amtierender Premier Robert Abela , wie Muscat von der Labour Party , entschuldigte sich nun im Namen des Landes bei Daphnes Familie , bei ihrem Mann und ihren drei Söhnen , die alle um das Vermächtnis der Mutter kämpfen .',
#   'opinions': [{'Source': [['Premier'], ['19:26']],
#     'Target': [['Vermächtnis'], ['196:207']],
#     'Polar_expression': [['entschuldigte'], ['76:89']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'Es gebe für Bonuslandia keine Kosten-Nutzen-Rechnung , monierte denn auch der « Corriere » – um für eine generelle Steuersenkung zu plädieren .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Kein Ministerpräsident hat derartigen Druck aushalten müssen » , sagte Netanyahu .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['5:22']],
#     'Target': [['Druck'], ['38:43']],
#     'Polar_expression': [['aushalten'], ['44:53']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': 'In einer unberechenbaren , globalen Welt verspreche die Familie Sicherheit und Sinn .',
#   'opinions': [{'Source': [['Familie'], ['56:63']],
#     'Target': [['Sicherheit'], ['64:74']],
#     'Polar_expression': [['verspreche'], ['41:51']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'DUNJA MOUSTOPOULOS , MATTHIAS DUBACH Sie sagen Nein zu Tokio 2020 Mit Kanada und Australien haben die ersten zwei grossen Sommersport-Nationen wegen der Coronakrise den Olympia-Boykott angekündigt .',
#   'opinions': [{'Source': [['Sommersport'], ['122:133']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['185:196']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Zudem verfügten die Krankenversicherer über acht Milliarden Franken Reserven , falls die Zahl der Covid-19-Patienten nochmals stark ansteigen sollte .',
#   'opinions': [{'Source': [['Krankenversicherer'], ['20:38']],
#     'Target': [[], []],
#     'Polar_expression': [['verfügten'], ['6:15']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Die Wirte widersetzten sich den Massnahmen erneut .',
#   'opinions': [{'Source': [['Wirte'], ['4:9']],
#     'Target': [['Massnahmen'], ['32:42']],
#     'Polar_expression': [['widersetzten'], ['10:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Depardieus Anwalt hatte die Vorwürfe kurz nach deren Bekanntwerden zurückgewiesen .',
#   'opinions': [{'Source': [['Depardieus Anwalt'], ['0:17']],
#     'Target': [['Vorwürfe'], ['28:36']],
#     'Polar_expression': [['zurückgewiesen'], ['67:81']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Und Brandenburgs Ministerpräsident Dietmar Woidke ( SPD ) freute sich über die grösste private Investition in seinem Bundesland seit der Wiedervereinigung .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['17:34']],
#     'Target': [['Investition'], ['95:106']],
#     'Polar_expression': [['freute'], ['58:64']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'Und alle Gäste wussten Bescheid .',
#   'opinions': [{'Source': [['Gäste'], ['9:14']],
#     'Target': [['Bescheid'], ['23:31']],
#     'Polar_expression': [['wussten'], ['15:22']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Sein Vermögen verdiente der Unternehmer als Gründer und Lenker des Hörgeräteherstellers Phonak , der heute Sonova heisst .',
#   'opinions': [{'Source': [['Unternehmer'], ['28:39']],
#     'Target': [['Vermögen'], ['5:13']],
#     'Polar_expression': [['verdiente'], ['14:23']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Offensichtlich fürchten die Investoren , der sich ohnehin schon abzeichnende Ausschluss dieser speziellen Wertpapiere vom Handel in den USA könnte sich aufgrund der geopolitischen Spannungen noch beschleunigen .',
#   'opinions': [{'Source': [['Ausschluss'], ['77:87']],
#     'Target': [[], []],
#     'Polar_expression': [['fürchten'], ['15:23']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Die Grafik des Heftes entstand in Zusammenarbeit mit dem Zürcher Duo Hammer , das vor Ort ein Unterrichtsmodul zum Thema Layout durchführte .',
#   'opinions': [{'Source': [['Grafik'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [['entstand'], ['22:30']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Seither hat AUR laut Umfragen weiter an Zuspruch gewonnen .',
#   'opinions': [{'Source': [['AUR'], ['12:15']],
#     'Target': [['Zuspruch'], ['40:48']],
#     'Polar_expression': [['gewonnen'], ['49:57']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'So geht es jetzt aus dem Labor in die Welt hinaus , und die Menschen fürchten sich sehr vor seiner Gestalt .',
#   'opinions': [{'Source': [['Menschen'], ['60:68']],
#     'Target': [['Gestalt'], ['99:106']],
#     'Polar_expression': [['fürchten'], ['69:77']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Manafort stellte sich zugleich für die Mitarbeit mit dem Sonderermittler Robert Mueller zur Verfügung .',
#   'opinions': [{'Source': [['Manafort'], ['0:8']],
#     'Target': [['Mitarbeit'], ['39:48']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'Ende Mai hatte das Fedpol eine Niederlage einsteckten müssen : Damals hatte das Obergericht entschieden , nicht auf eine Beschwerde einzutreten , die sich gegen einen Rückweisungsentscheid des Berner Wirtschaftsgerichts « wegen schwerwiegender Verfahrensmängel » gerichtet hatte .',
#   'opinions': [{'Source': [['Obergericht'], ['80:91']],
#     'Target': [[], []],
#     'Polar_expression': [['einzutreten'], ['132:143']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Natürlich stellt das Coronavirus ein Risiko dar , wie auch die anhaltenden geopolitischen Spannungen .',
#   'opinions': [{'Source': [['Coronavirus'], ['21:32']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': '« Fake-News können hier in Kongo töten » , sagt der 27-jährige Mupfuni bestimmt .',
#   'opinions': [{'Source': [['Mupfuni'], ['63:70']],
#     'Target': [['Kongo'], ['27:32']],
#     'Polar_expression': [['töten'], ['33:38']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Musk war vom britischen Höhlentaucher Vernon Unsworth verklagt worden .',
#   'opinions': [{'Source': [['Höhlentaucher'], ['24:37']],
#     'Target': [[], []],
#     'Polar_expression': [['verklagt'], ['54:62']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'Die Händler von Ski , Snowboards und Schlitten freuen sich zwar ebenfalls über die frostigen Temperaturen , rechnen deswegen aber nicht mit einer deutlich höheren Nachfrage .',
#   'opinions': [{'Source': [['Händler'], ['4:11']],
#     'Target': [['Temperaturen'], ['93:105']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': '« Marini konnte seine Reifen besser schonen als ich » , sagte Lüthi .',
#   'opinions': [{'Source': [['Marini'], ['2:8']],
#     'Target': [['Reifen'], ['22:28']],
#     'Polar_expression': [['schonen'], ['36:43']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Das Gericht kommt zum Schluss , dass vier Artikel , die zwischen Dezember 2014 und September 2015 im « Blick » erschienen sind , die Persönlichkeit von Spiess-Hegglin verletzt haben .',
#   'opinions': [{'Source': [['Artikel'], ['42:49']],
#     'Target': [['Persönlichkeit'], ['133:147']],
#     'Polar_expression': [['verletzt'], ['167:175']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': 'Dass der Kanton keine genaueren Zahlen nennen kann , liegt an der Datenerfassung .',
#   'opinions': [{'Source': [['Kanton'], ['9:15']],
#     'Target': [['Zahlen'], ['32:38']],
#     'Polar_expression': [['nennen'], ['39:45']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Nachdem die Amerikaner neue Sanktionen angekündigt haben , schiesst Russland rhetorisch scharf zurück .',
#   'opinions': [{'Source': [['Russland'], ['68:76']],
#     'Target': [[], []],
#     'Polar_expression': [['schiesst'], ['59:67']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'In Baden-Württemberg hat die FDP mit 10,5 Prozent der Stimmen ihr bestes Wahlergebnis seit Jahrzehnten erreicht .',
#   'opinions': [{'Source': [['FDP'], ['29:32']],
#     'Target': [['Wahlergebnis'], ['73:85']],
#     'Polar_expression': [['erreicht'], ['103:111']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': 'Und die isländischen Fans sorgten mit ihrer Huh-Choreografie dafür , dass die Welt die Reykjavíker Skandale vergass .',
#   'opinions': [{'Source': [['Welt'], ['78:82']],
#     'Target': [['Reykjavíker'], ['87:98']],
#     'Polar_expression': [['vergass'], ['108:115']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Robert Payne widersetzte sich der Aufforderung .',
#   'opinions': [{'Source': [['Robert'], ['0:6']],
#     'Target': [['Aufforderung'], ['34:46']],
#     'Polar_expression': [['widersetzte'], ['13:24']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Der Faktor Mensch stellt die grösste Gefahrenquelle dar .',
#   'opinions': [{'Source': [['Faktor'], ['4:10']],
#     'Target': [['Gefahrenquelle'], ['37:51']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Zusammen mit zwei weiteren wichtigen kirchlichen Playern – der Römisch-Katholischen Zentralkonferenz und der Konferenz der Ordensgemeinschaften – hat sie an der Universität Zürich ein Forschungsprojekt zu Missbrauchsfällen seit 1950 in Auftrag gegeben : « Mit der Anerkennung des durch sexuelle Übergriffe im Kontext der römisch-katholischen Kirche in der Schweiz zugefügten Leids ist für die Kirche die Pflicht verbunden , das Geschehene aufzuarbeiten , seine Ursachen zu analysieren und daraus die Lehren für die Zukunft zu ziehen » , heisst es im Vertrag .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Für den Dienstag hatten die Oppositionsparteien gemeinsam mit Rebellen der Tories einen Vorstoss angekündigt , der ein ungeregeltes Ausscheiden aus der EU Ende Oktober verhindern soll .',
#   'opinions': [{'Source': [['Oppositionsparteien'], ['28:47']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['97:108']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Deshalb bricht der Vorsitzende die Befragung ab , kaum hat sie begonnen .',
#   'opinions': [{'Source': [['Vorsitzende'], ['19:30']],
#     'Target': [['Befragung'], ['35:44']],
#     'Polar_expression': [['bricht'], ['8:14']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Trump habe sich bei Maurer für die Rolle der Schweiz bei diplomatischen Beziehungen und bei der Vermittlung bei internationalen Konflikten bedankt .',
#   'opinions': [{'Source': [['Trump'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [['bedankt'], ['139:146']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'Das Verschwinden des lokalen Akutspitals löst vielerorts Unmut aus .',
#   'opinions': [{'Source': [['Verschwinden'], ['4:16']],
#     'Target': [['Unmut'], ['57:62']],
#     'Polar_expression': [['löst'], ['41:45']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Die jetzigen Protestaktionen finden in viel kleinerem und heterogenerem Rahmen statt , und da sie sich in unzähligen kleinen Städten im ganzen Land zutragen , sind sie nur schwer einzudämmen .',
#   'opinions': [{'Source': [['Protestaktionen'], ['13:28']],
#     'Target': [[], []],
#     'Polar_expression': [['finden'], ['29:35']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'In knapp acht Monaten wird das Vereinigte Königreich formal aus der EU austreten .',
#   'opinions': [{'Source': [['Königreich'], ['42:52']],
#     'Target': [['EU'], ['68:70']],
#     'Polar_expression': [['austreten'], ['71:80']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'Gekippt wurde neben dem von seiner islamisch-konservativen Regierung propagierten « Untreue-Artikel » auch die Todesstrafe .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'In den Sechzigern stellte sich auch der internationale Erfolg ein : Hugs Ölbilder wurden in die ganze Welt verkauft ; auch die britische Königin erstand zwei seiner Werke nach einer Ausstellung in London .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['erstand'], ['145:152']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Planung , Verhandlung , politische Plattform , runder Tisch – all diese Wörter benutzen Populisten nie .',
#   'opinions': [{'Source': [['Wörter'], ['72:78']],
#     'Target': [['Populisten'], ['88:98']],
#     'Polar_expression': [['benutzen'], ['79:87']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Nach vier Jahren als Präsident stellt sich Daniel Frutig an der Generalversammlung am 26. April nicht mehr zur Wahl .',
#   'opinions': [{'Source': [['Daniel'], ['43:49']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': 'Nicht einfach nach Isolationismus , denn Trump plädiert keineswegs für den Rückzug aus der Welt , sondern er will die international gültigen Spielregeln nach seinem Gusto umgestalten .',
#   'opinions': [{'Source': [['Trump'], ['41:46']],
#     'Target': [[], []],
#     'Polar_expression': [['plädiert'], ['47:55']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Die australische Regierung hat Nothilfen für die tägliche Versorgung von Bauernfamilien angekündigt , die um die Existenz ihrer Farmen kämpfen .',
#   'opinions': [{'Source': [['Regierung'], ['17:26']],
#     'Target': [['Nothilfen'], ['31:40']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'RED U21-Nati-Trainer Mauro Lustrinelli freut sich auf die EM .',
#   'opinions': [{'Source': [['Trainer'], ['13:20']],
#     'Target': [['EM'], ['58:60']],
#     'Polar_expression': [['freut'], ['39:44']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': 'Der Seitenhieb galt dem Führungsduo der Koalition : Calin Popescu Tariceanu , in Personalunion Vorsitzender der liberalen Kleinpartei Alde und Senatspräsident , steht wegen Meineids vor \xad Gericht .',
#   'opinions': [{'Source': [['Seitenhieb'], ['4:14']],
#     'Target': [['Führungsduo'], ['24:35']],
#     'Polar_expression': [['galt'], ['15:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Der jüngste Unternehmenszweig der Sportholding will sich der Planung von Eishockeykarrieren widmen und die Spieler auch darüber hinaus beratend begleiten .',
#   'opinions': [{'Source': [['Unternehmenszweig'], ['12:29']],
#     'Target': [['Planung'], ['61:68']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Die Hemmschwelle , mit den Lehrperson den Kontakt aufzunehmen , ist gesunken .',
#   'opinions': [{'Source': [['Hemmschwelle'], ['4:16']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'An der alljährlichen Entwicklerkonferenz , wegen Corona erstmals ein Online-Event , hat der Konzern daher die Abkehr von Intel angekündigt .',
#   'opinions': [{'Source': [['Konzern'], ['92:99']],
#     'Target': [['Abkehr'], ['110:116']],
#     'Polar_expression': [['angekündigt'], ['127:138']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'In den zehn ukrainischen Provinzen , die an Russland und die Moldau grenzen , gilt derzeit das Kriegsrecht .',
#   'opinions': [{'Source': [['Kriegsrecht'], ['95:106']],
#     'Target': [[], []],
#     'Polar_expression': [['gilt'], ['78:82']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'So gewinnt die Eigenverantwortung in der dritten Säule an Bedeutung und ruft nach verbesserten Anreizen und mehr Möglichkeiten .',
#   'opinions': [{'Source': [['Eigenverantwortung'], ['15:33']],
#     'Target': [['Bedeutung'], ['58:67']],
#     'Polar_expression': [['gewinnt'], ['3:10']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Allerdings stellen sich rechtliche Fragen bei der Umsetzung .',
#   'opinions': [{'Source': [['Fragen'], ['35:41']],
#     'Target': [['Umsetzung'], ['50:59']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Immer auch auf die Gefahr hin , dass Kritiker uns an den Öko-Pranger stellen und uns die liberale Gesinnung absprechen .',
#   'opinions': [{'Source': [['Kritiker'], ['37:45']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': 'Einerseits stellen sich Länder , die es selber mit den Menschenrechten nicht so genau nehmen , an Pekings Seite .',
#   'opinions': [{'Source': [['Länder'], ['24:30']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'Auch mit der Wahl von Ashraf Ghani zum Präsidenten Afghanistans im Jahr 2014 stellte sich Hoffnung auf Besserung ein .',
#   'opinions': [{'Source': [['Hoffnung'], ['90:98']],
#     'Target': [['Besserung'], ['103:112']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Inzwischen ist zumindest bekannt , dass die SPD den Minister stellen wird .',
#   'opinions': [{'Source': [['SPD'], ['44:47']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Seine Worte konnte man so interpretieren , dass dann der Entscheid über seine politische Zukunft fallen wird und sich beide Seiten bis dahin mit öffentlichen Äusserungen zurückhalten werden .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'Die Technologie werde somit die Funktionen der heutigen Intermediäre zu grossen Teilen übernehmen und zwingt damit bisherige Vermittler , ihr Geschäftsmodell anzupassen .',
#   'opinions': [{'Source': [['Technologie'], ['4:15']],
#     'Target': [['Geschäftsmodell'], ['142:157']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': 'Der Strassenhändler besorgte sich Benzin , stellte sich vor die Polizeipräfektur und steckte sich in Brand .',
#   'opinions': [{'Source': [['Strassenhändler'], ['4:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Madonna entschuldigt sich bei ihren Anhängern : « Ich muss mich erholen » , erklärt sie .',
#   'opinions': [{'Source': [['Madonna'], ['0:7']],
#     'Target': [['Anhängern'], ['36:45']],
#     'Polar_expression': [['entschuldigt'], ['8:20']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Die Schweizerin wehrt gegen Alizé Cornet zwei Matchbälle ab und dreht dann die Partie .',
#   'opinions': [{'Source': [['Schweizerin'], ['4:15']],
#     'Target': [['Alizé'], ['28:33']],
#     'Polar_expression': [['wehrt'], ['16:21']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Waffenlieferungen an Kriegsparteien verletzen grundsätzlich das Neutralitätsgebot nach Haager Kriegsrecht .',
#   'opinions': [{'Source': [['Waffenlieferungen'], ['0:17']],
#     'Target': [['Neutralitätsgebot'], ['64:81']],
#     'Polar_expression': [['verletzen'], ['36:45']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Villiger zog das Verteidigungsdispositiv auf .',
#   'opinions': [{'Source': [['Villiger'], ['0:8']],
#     'Target': [['Verteidigungsdispositiv'], ['17:40']],
#     'Polar_expression': [['zog'], ['9:12']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': 'Der Schweizer Verband widersetzte sich zuerst aus scheinformalen Gründen dem Transfer in den Profifussball , das italienische Parlament verfügte eine Importsperre , weil schon zu viele Ausländer im Land kickten , und als Vonlanthen 1955 doch in Mailand eintraf , hatten sie einen Bomber erwartet und nicht diesen schmalen , leichtfüssigen Artisten , der dann häufig auf der Ersatzbank sitzen blieb .',
#   'opinions': [{'Source': [['Parlament'], ['126:135']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Zudem stellen sich ethische Fragen .',
#   'opinions': [{'Source': [['Fragen'], ['28:34']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Das Neutralitätsprinzip habe die Schweizer Bevölkerung seit über 200 Jahren vor blutigen Konflikten bewahrt .',
#   'opinions': [{'Source': [['Neutralitätsprinzip'], ['4:23']],
#     'Target': [['Konflikten'], ['89:99']],
#     'Polar_expression': [['bewahrt'], ['100:107']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Die Wirtenfamilie Christen freut sich über die Wiedereröffnung : Angela ( l.',
#   'opinions': [{'Source': [['Wirtenfamilie'], ['4:17']],
#     'Target': [['Wiedereröffnung'], ['47:62']],
#     'Polar_expression': [['freut'], ['27:32']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Immobilien , wie der Name schon sagt , widersetzen sich dem fliessenden Wandel , also muss eine andere flexible Veränderungsmöglichkeit her , nämlich die Zwischennutzung .',
#   'opinions': [{'Source': [['Immobilien'], ['0:10']],
#     'Target': [['Wandel'], ['72:78']],
#     'Polar_expression': [['widersetzen'], ['39:50']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': 'Im Gegensatz zu den meisten anderen Krankenhäusern hat das Spital gar Boni abgeschafft , die sich an den Operationszahlen der Ärzte bemessen .',
#   'opinions': [{'Source': [['Spital'], ['59:65']],
#     'Target': [['Boni'], ['70:74']],
#     'Polar_expression': [['abgeschafft'], ['75:86']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Trump beschimpfte den 33-jährigen Taylor umgehend als einen « Niemand » sowie einen « Widerling , der nie im Weissen Haus gearbeitet hat » .',
#   'opinions': [{'Source': [['Trump'], ['0:5']],
#     'Target': [['Taylor'], ['34:40']],
#     'Polar_expression': [['beschimpfte'], ['6:17']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'Der hohe Feiertag findet immer am ersten Sonntag nach dem ersten Vollmond im Frühling statt .',
#   'opinions': [{'Source': [['Feiertag'], ['9:17']],
#     'Target': [['Frühling'], ['77:85']],
#     'Polar_expression': [['findet'], ['18:24']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': 'Am 9. Februar finden dazu in den beiden Kantonen zwei separate Volksabstimmungen statt .',
#   'opinions': [{'Source': [['Volksabstimmungen'], ['63:80']],
#     'Target': [[], []],
#     'Polar_expression': [['finden'], ['14:20']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Opfer Brigitte Peyer und ihr Lebenspartner Rudolf Naef wurden im Dezember vom Marokkaner Moestafa K. überfallen .',
#   'opinions': [{'Source': [['Marokkaner'], ['78:88']],
#     'Target': [[], []],
#     'Polar_expression': [['überfallen'], ['101:111']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': 'Brosi plädierte zuletzt für etwas mehr Management .',
#   'opinions': [{'Source': [['Brosi'], ['0:5']],
#     'Target': [['Management'], ['39:49']],
#     'Polar_expression': [['plädierte'], ['6:15']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Sobald die Briten aus der EU austreten , schrumpft nach der Wahl die Grösse des Parlaments auf 705 Abgeordnete .',
#   'opinions': [{'Source': [['Grösse'], ['69:75']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Als Qualitätsaktien gelten Valoren von Unternehmen mit einem geringen Verschuldungsgrad , die mit einer grossen Zuverlässigkeit solide Gewinne erzielen und sich auch in einem wirtschaftlich schwierigen Umfeld behaupten können .',
#   'opinions': [{'Source': [['Valoren'], ['27:34']],
#     'Target': [['Qualitätsaktien'], ['4:19']],
#     'Polar_expression': [['gelten'], ['20:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Das Trainingszentrum verfügt über Zimmer .',
#   'opinions': [{'Source': [['Trainingszentrum'], ['4:20']],
#     'Target': [['Zimmer'], ['34:40']],
#     'Polar_expression': [['verfügt'], ['21:28']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Lilian Carpenter , Zürich Im Kommentar stellt der Autor die Frage : « War es erweiterter Suizid ? » Ich finde es unsäglich , dass mit diesem Begriff immer noch so fahrlässig umgegangen wird !',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Begriff'], ['141:148']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': 'Darin soll auch die direkt betroffene Bevölkerung Gehör finden .',
#   'opinions': [{'Source': [['Bevölkerung'], ['38:49']],
#     'Target': [['Gehör'], ['50:55']],
#     'Polar_expression': [['finden'], ['56:62']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': '( sda ) Sozialhilfe Die Co-Präsidenten der Schweizerischen Konferenz für Sozialhilfe ( Skos ) , Therese Frösch und Felix Wolffers , haben nach fünf Jahren im Amt ihren Rücktritt auf Mai 2019 angekündigt .',
#   'opinions': [{'Source': [['Präsidenten'], ['27:38']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['191:202']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'Damit rückt der angekündigte , grund \xad - legende Strategiewechsel in weite Ferne : Ursprünglich wollte der Bundesrat im zweiten Teil der Energiewende die Förderbeiträge sukzessive abschaffen und stattdessen ein Lenkungssystem einführen .',
#   'opinions': [{'Source': [['Bundesrat'], ['107:116']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'Bolsonaro hat als eine seiner ersten Amtshandlungen das Kulturministerium abschaffen lassen , nicht , weil ihm Kultur unwichtig ist , im Gegenteil : Er und seine Regierung nutzen sie , um sich bei ihrer Wählerschaft zu profilieren .',
#   'opinions': [{'Source': [['Bolsonaro'], ['0:9']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Dieser Frau vertraut Macron nun seine Regierungskommunikation an .',
#   'opinions': [{'Source': [['Macron'], ['21:27']],
#     'Target': [['Frau'], ['7:11']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': '« Nachdem der Bundesrat den Lockdown angekündigt hatte , bestellten plötzlich so viele Leute bei uns wie noch nie » , sagt Vera Kessens .',
#   'opinions': [{'Source': [['Leute'], ['87:92']],
#     'Target': [['Lockdown'], ['28:36']],
#     'Polar_expression': [['bestellten'], ['57:67']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Für rasche Hilfe plädieren auch SP-Nationalrat Mathias Reynard und SVP-Ständerat Hannes Germann , die Präsidenten der Kulturkommissionen der Eidgenössischen Räte , die Parmelin am Dienstag trafen .',
#   'opinions': [{'Source': [['Nationalrat'], ['35:46']],
#     'Target': [['Hilfe'], ['11:16']],
#     'Polar_expression': [['plädieren'], ['17:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'Ab dato strich Depp astronomische Gagen ein und widmete sich Lieblingsprojekten wie etwa « Finding Neverland » von Marc Forster ( 2004 ) .',
#   'opinions': [{'Source': [['Depp'], ['15:19']],
#     'Target': [[], []],
#     'Polar_expression': [['widmete'], ['48:55']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Bern – Am Sonntagabend haben zwei Unbekannte einen Tankstellenshop an der Fellerstrasse überfallen .',
#   'opinions': [{'Source': [['Unbekannte'], ['34:44']],
#     'Target': [['Tankstellenshop'], ['51:66']],
#     'Polar_expression': [['überfallen'], ['88:98']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'Aryzta hat den Verkauf von Picard schon vor einiger Zeit angekündigt , den richtigen Zeitpunkt dafür aber noch nicht gefunden .',
#   'opinions': [{'Source': [['Aryzta'], ['0:6']],
#     'Target': [['Verkauf'], ['15:22']],
#     'Polar_expression': [['angekündigt'], ['57:68']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'Die Regierung mahnte Ende Juni bereits die an Erdbeben- , Flut- und Sturmkatastrophen gewöhnten Japaner , sich während der Regenzeit auf Überschwemmungen und Erdrutsche einzustellen .',
#   'opinions': [{'Source': [['Regierung'], ['4:13']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'Die Spitze der SP stellte sich zwar früh hinter den kompromisslosen Kurs der Gewerkschaften , hat sich inzwischen aber im Tonfall gemässigt .',
#   'opinions': [{'Source': [['Spitze'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Manche Dirigenten überrumpeln das Publikum , indem sie starten , sobald sie auf dem Podium angelangt sind ; andere zelebrieren eine feierliche Stille , bevor sie loslegen .',
#   'opinions': [{'Source': [['Dirigenten'], ['7:17']],
#     'Target': [['Publikum'], ['34:42']],
#     'Polar_expression': [['überrumpeln'], ['18:29']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Einige Firmen beschweren sich aber über eine falsche Einordnung , etwa der Süsswarenhersteller Storck , zu dessen Portfolio Marken wie Toffifee , Merci , Knoppers oder Nimm 2 gehören .',
#   'opinions': [{'Source': [['Firmen'], ['7:13']],
#     'Target': [['Einordnung'], ['53:63']],
#     'Polar_expression': [['beschweren'], ['14:24']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Brasilien Mitten in der Pandemie wollte der Präsident den Gesundheitsminister entlassen .',
#   'opinions': [{'Source': [['Präsident'], ['44:53']],
#     'Target': [['Gesundheitsminister'], ['58:77']],
#     'Polar_expression': [['entlassen'], ['78:87']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Denens VD – Eine Explosion hat am frühen Sonntagmorgen im Kanton Waadt eine von Swisscom und Salt genutzte Handy-Antenne zerstört .',
#   'opinions': [{'Source': [['Explosion'], ['17:26']],
#     'Target': [['Antenne'], ['113:120']],
#     'Polar_expression': [['zerstört'], ['121:129']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Das Gericht hat deshalb zu Recht von dieser extremen Massnahme abgesehen .',
#   'opinions': [{'Source': [['Gericht'], ['4:11']],
#     'Target': [['Massnahme'], ['53:62']],
#     'Polar_expression': [['abgesehen'], ['63:72']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Eine ausgeklügelte Lüftungstechnik sollte Ansteckungen verhindern .',
#   'opinions': [{'Source': [['Lüftungstechnik'], ['19:34']],
#     'Target': [['Ansteckungen'], ['42:54']],
#     'Polar_expression': [['verhindern'], ['55:65']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Die Justizdirektion stellte sich auf den Standpunkt , « angesichts des bisherigen Vollzugsverlaufs , der diagnostizierten Persönlichkeitsstörung und der Anlassdelikte » sei eine « möglichst enge Betreuung und Beobachtung » des Gefangenen unabdingbar .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Als er schliesslich zu seiner Gruppe stösst , hetzen die Schüler beinahe im Laufschritt in Richtung Bahnhofstrasse .',
#   'opinions': [{'Source': [['Schüler'], ['57:64']],
#     'Target': [[], []],
#     'Polar_expression': [['hetzen'], ['46:52']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'Das AMS-Management lässt jedoch durchblicken , dass man dies einfach auch so lösen könne , indem man sicherstellt , dass ein Käufer diese Konditionen einhält .',
#   'opinions': [{'Source': [['Käufer'], ['125:131']],
#     'Target': [['Konditionen'], ['138:149']],
#     'Polar_expression': [['einhält'], ['150:157']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Erfreulich : Im Vergleich mit der gesamten Schweiz achten in der Stadt Zürich prozentual mehr Menschen auf gesundes und ausgewogenes Essen .',
#   'opinions': [{'Source': [['Menschen'], ['94:102']],
#     'Target': [['Essen'], ['133:138']],
#     'Polar_expression': [['achten'], ['51:57']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '126',
#   'text': 'Mit seinem Charisma erreicht der Dirigent jedoch viel mehr als eine bloss « korrekte » Interpretation : Dieses Orchester ist hoch motiviert , spielt leidenschaftlich und identifiziert sich mit den Affekten der Protagonisten .',
#   'opinions': [{'Source': [['Orchester'], ['111:120']],
#     'Target': [['Interpretation'], ['87:101']],
#     'Polar_expression': [['erreicht'], ['20:28']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '127',
#   'text': 'Nun kommen mexikanische Forscher zu uns , um sich dem Schmuck zu widmen . » Die k. u. k. Monarchie liess sich die Sammlerstücke und Trophäen aus aller Welt etwas kosten .',
#   'opinions': [{'Source': [['Monarchie'], ['89:98']],
#     'Target': [['Schmuck'], ['54:61']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '128',
#   'text': 'Nach missglückten Aktionen von Jérôme Boateng und dem herauseilenden Neuer warf sich David Alaba in einen Schuss von Werner und verhinderte das 0 : 1 ( 49. ) .',
#   'opinions': [{'Source': [['David'], ['85:90']],
#     'Target': [[], []],
#     'Polar_expression': [['verhinderte'], ['128:139']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '129',
#   'text': '« Obwohl man im Gesundheitswesen der Maske immer zu hundert Prozent vertraute , wurde sie vom Bundesrat über Wochen verteufelt » , wundert sich Martullo gegenüber der NZZ : « Später fehlte den Leuten deshalb der Mut , freiwillig Masken zu tragen .',
#   'opinions': [{'Source': [['Mut'], ['212:215']],
#     'Target': [['Leuten'], ['193:199']],
#     'Polar_expression': [['fehlte'], ['182:188']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '130',
#   'text': 'In Deutschland hat das Bundesverfassungsgericht die Regierung im April angewiesen , das Klimaschutzgesetz zu verschärfen .',
#   'opinions': [{'Source': [['Bundesverfassungsgericht'], ['23:47']],
#     'Target': [['Klimaschutzgesetz'], ['88:105']],
#     'Polar_expression': [['verschärfen'], ['109:120']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '131',
# ...
#  {'sent_id': '955',
#   'text': 'Ein Zusammenschluss von « Revolutionären Organisationen und Einzelpersonen aus Zürich » ruft hingegen dazu auf , die Strassen nicht aufzugeben .',
#   'opinions': [{'Source': [['Zusammenschluss'], ['4:19']],
#     'Target': [['Strassen'], ['117:125']],
#     'Polar_expression': [['aufzugeben'], ['132:142']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '956',
#   'text': 'Die Klimatologen warnen vor den Auswirkungen solcher Luftströme auf das noch bestehende Larsen-C-Schelfeis , das grösste Eisschelf der Antarktischen Halbinsel .',
#   'opinions': [{'Source': [['Klimatologen'], ['4:16']],
#     'Target': [['Auswirkungen'], ['32:44']],
#     'Polar_expression': [['warnen'], ['17:23']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '957',
#   'text': 'Dabei fehlt ausgerechnet ihr erfahrenster Mann : Blerim Dzemaili ( 36 ) ist in Zürich geblieben , den Ex-Nati-Star plagen noch immer Wadenprobleme .',
#   'opinions': [{'Source': [['Wadenprobleme'], ['133:146']],
#     'Target': [[], []],
#     'Polar_expression': [['plagen'], ['115:121']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': 'Zudem würde sich für Bund , Parlament und Steuerzahlende eine Reihe von anspruchsvollen Fragen in Bezug auf Führung , Aufsicht und Finanzierung dieser neuen Staatsbank stellen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Bund'], ['21:25']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Begonnen hat alles vor gut einer Woche , als die grosse Supermarktkette Leclerc eine Senkung des Preises für eine Baguette ankündigte : auf 29 Cent , zurzeit etwa 30 Rappen .',
#   'opinions': [{'Source': [['Supermarktkette'], ['56:71']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Dieser Tage hat Präsident Aleksandar Vucic nun sogar finanzielle Anreize zur Immunisierung angekündigt .',
#   'opinions': [{'Source': [['Präsident'], ['16:25']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['91:102']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Die Affäre , die letztes Jahr zum Sturz des Präsidenten Gottfried Locher führte , hat die Evangelisch-reformierte Kirche der Schweiz ( EKS ) in eine tiefe Krise gestürzt und ihr einen gewaltigen Reputationsschaden eingebracht .',
#   'opinions': [{'Source': [['Affäre'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [['gestürzt'], ['161:169']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Er hatte Anfang November bei den ZSC Lions für die kommenden zwei Saisons als Nummer 2 neben Lukas Flüeler unterschrieben – sein Auftritt war vielleicht das Einzige , worüber sich die Lions-Fans heimlich freuen konnten .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['unterschrieben'], ['107:121']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'Analytiker fürchten sich vor einem Passus , der der Energieindustrie grossen Schaden zufügen könnte .',
#   'opinions': [{'Source': [['Analytiker'], ['0:10']],
#     'Target': [['Passus'], ['35:41']],
#     'Polar_expression': [['fürchten'], ['11:19']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Sieben Personen erlitten Rauchgasvergiftungen .',
#   'opinions': [{'Source': [['Personen'], ['7:15']],
#     'Target': [['Rauchgasvergiftungen'], ['25:45']],
#     'Polar_expression': [['erlitten'], ['16:24']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Im Nachwort des soeben erschienenen Fotobuches heisst es : « Ein Blick offenbart nur einen Bruchteil dessen , was zu sehen ist .',
#   'opinions': [{'Source': [['Blick'], ['65:70']],
#     'Target': [['Bruchteil'], ['91:100']],
#     'Polar_expression': [['offenbart'], ['71:80']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Ursula von der Leyen muss nun rasch Ersatz finden .',
#   'opinions': [{'Source': [['Ursula'], ['0:6']],
#     'Target': [['Ersatz'], ['36:42']],
#     'Polar_expression': [['finden'], ['43:49']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Beuys äusserte in diesem Kontext , er arbeite mit Tieren , um unsichtbare Kräfte erlebbar zu machen .',
#   'opinions': [{'Source': [['Beuys'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Fünftes Kind im Bauch : Brigitte Nielsen freut sich auf Nachwuchs .',
#   'opinions': [{'Source': [['Brigitte'], ['24:32']],
#     'Target': [['Nachwuchs'], ['56:65']],
#     'Polar_expression': [['freut'], ['41:46']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': 'Fussball Die Schweizer Marketingagentur Infront hat einen leitenden Angestellten entlassen , nachdem es bei Bandenwerbung bei deutschen Länderspielen zu Unregelmässigkeiten gekommen sein soll .',
#   'opinions': [{'Source': [['Marketingagentur'], ['23:39']],
#     'Target': [['Angestellten'], ['68:80']],
#     'Polar_expression': [['entlassen'], ['81:90']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Shaqiri entschuldigte sich Monate später ziemlich nonchalant für seine Geste – frei nach dem Motto : « Das gehört alles zu mir .',
#   'opinions': [{'Source': [['Shaqiri'], ['0:7']],
#     'Target': [['Geste'], ['71:76']],
#     'Polar_expression': [['entschuldigte'], ['8:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Dieser Krieg wurde geführt , um Dachau abzuschaffen und all die anderen Orte wie Dachau , alles , wofür Dachau steht .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Dachau'], ['32:38']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Das Treffen mit dem Insider zeigt , dass es in der Branche heikel sein kann , Kritik an China zu äussern .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Die Kaserne in Dübendorf erreichte das Virus vergangene Woche .',
#   'opinions': [{'Source': [['Kaserne'], ['4:11']],
#     'Target': [['Virus'], ['39:44']],
#     'Polar_expression': [['erreichte'], ['25:34']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Ein Zweitligist haut Österreichs Rekordmeister raus .',
#   'opinions': [{'Source': [['Zweitligist'], ['4:15']],
#     'Target': [['Rekordmeister'], ['33:46']],
#     'Polar_expression': [['haut'], ['16:20']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Das Bundesgericht hält fest , das Obergericht habe die Umstände der früheren Strafen und Zwangsmassnahmen nicht ausreichend aufgearbeitet .',
#   'opinions': [{'Source': [['Obergericht'], ['34:45']],
#     'Target': [['Umstände'], ['55:63']],
#     'Polar_expression': [['aufgearbeitet'], ['124:137']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Die Parlamentsdienste sorgen für Stunk in der Wandelhalle : Die Dienstleister der Bundesverwaltung verweigerten GLP-Nationalrat Martin Bäumle ( 55 ) die Annahme einer parlamentarischen Initiative .',
#   'opinions': [{'Source': [['Dienstleister'], ['64:77']],
#     'Target': [['Nationalrat'], ['116:127']],
#     'Polar_expression': [['verweigerten'], ['99:111']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Die Schuldenbremse gibt nun vor , dass der Bund innert 6 Jahren 25 bis 30 Mrd. Fr. tilgen muss .',
#   'opinions': [{'Source': [['Bund'], ['43:47']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Zudem wird das Land mit 282 Milliarden Euro eine rekordhohe Summe an neuen Krediten an den Märkten aufnehmen .',
#   'opinions': [{'Source': [['Land'], ['15:19']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnehmen'], ['99:108']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Auch verträgt sich eine zu schroffe Anti-Migrations-Politik nur schwer mit den humanitären Grundsätzen einer christlich-sozialen Partei .',
#   'opinions': [{'Source': [['Politik'], ['52:59']],
#     'Target': [[], []],
#     'Polar_expression': [['verträgt'], ['5:13']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Dabei gelangte sie zum Schluss , Lauber habe verschiedene Amtspflichten verletzt .',
#   'opinions': [{'Source': [['Lauber'], ['33:39']],
#     'Target': [['Amtspflichten'], ['58:71']],
#     'Polar_expression': [['verletzt'], ['72:80']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Die Türkei wiederum hat den deutschen Botschafter einbestellt , um sich über die Attacken gegen ihre Landsleute zu beschweren .',
#   'opinions': [{'Source': [['Türkei'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Fragen stellen sich eher hinsichtlich der Effektivität der Kontrolle .',
#   'opinions': [{'Source': [['Fragen'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Ein solches Niveau wie jetzt gab es vorher nicht . » Letzten Samstag aber stürzte Suter im Super-G-Training , erlitt schwere Knochenprellungen an den Schienbeinen und Schürfwunden im Gesicht .',
#   'opinions': [{'Source': [['Suter'], ['82:87']],
#     'Target': [['Knochenprellungen'], ['125:142']],
#     'Polar_expression': [['stürzte'], ['74:81']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Keine zwei Jahre später ging « Smokin ’ Joe » beim Titelkampf gegen den übermächtigen Herausforderer George Foreman gleich sechsmal zu Boden , ehe der Ringrichter das Gemetzel Mitte der zweiten Runde abbrach .',
#   'opinions': [{'Source': [['Ringrichter'], ['151:162']],
#     'Target': [['Gemetzel'], ['167:175']],
#     'Polar_expression': [['abbrach'], ['200:207']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Von Anfang an beharrt Bora Ćosić auf der Absurdität menschlicher Existenz ; Samuel Becketts als Clownerie getarnte Illusionslosigkeit und Freuds Tiefenpsychologie werden seine ständigen Begleiter .',
#   'opinions': [{'Source': [['Bora'], ['22:26']],
#     'Target': [['Absurdität'], ['41:51']],
#     'Polar_expression': [['beharrt'], ['14:21']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Ein Mann sticht die Oberbürgermeisterin an einem Info-Stand der CDU nieder und verletzt weitere umstehende Personen .',
#   'opinions': [{'Source': [['Mann'], ['4:8']],
#     'Target': [['Personen'], ['107:115']],
#     'Polar_expression': [['verletzt'], ['79:87']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Nach dem glimpflichen Ausgang dieses Dramas und der Rettungsaktion von noch nie gesehenem Ausmass stellt sich die Frage , wie solch ein Horrorszenario in Zukunft verhindert werden kann .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['verhindert'], ['162:172']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Nach Ansicht der Richter hat die Untersuchungshaft das Recht auf persönliche Freiheit und Sicherheit sowie das Recht auf Meinungs- und Pressefreiheit verletzt .',
#   'opinions': [{'Source': [['Untersuchungshaft'], ['33:50']],
#     'Target': [['Recht'], ['55:60']],
#     'Polar_expression': [['verletzt'], ['150:158']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'Syrien und sein Verbündeter Russland hatten die Vorwürfe stets zurückgewiesen und von einer « inszenierten Attacke » gesprochen .',
#   'opinions': [{'Source': [['Syrien'], ['0:6']],
#     'Target': [['Vorwürfe'], ['48:56']],
#     'Polar_expression': [['zurückgewiesen'], ['63:77']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Für die damalige Behandlung von Littlefeather hat sich die Oscar-Akademie nun entschuldigt – fast 50 Jahre nach dem Vorfall .',
#   'opinions': [{'Source': [['Akademie'], ['65:73']],
#     'Target': [['Behandlung'], ['17:27']],
#     'Polar_expression': [['entschuldigt'], ['78:90']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Für einigen Wirbel hatte kurz vor der Ernennung allerdings noch ein anonymes Schreiben gesorgt , in dem Bar berufliches Fehlverhalten in zwei Fällen vorgeworfen wurde .',
#   'opinions': [{'Source': [['Schreiben'], ['77:86']],
#     'Target': [['Wirbel'], ['12:18']],
#     'Polar_expression': [['gesorgt'], ['87:94']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Die Kantone stellten sich nicht gegen eine Umsetzung der Sanktionen , betont Tännler .',
#   'opinions': [{'Source': [['Kantone'], ['4:11']],
#     'Target': [['Umsetzung'], ['43:52']],
#     'Polar_expression': [['stellten'], ['12:20']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Der Tag war fast vorbei , und die Spieler von Real jubelten noch immer über einen Sieg , an den sie vielleicht nicht mal mehr selbst geglaubt hatten .',
#   'opinions': [{'Source': [['Spieler'], ['34:41']],
#     'Target': [['Sieg'], ['82:86']],
#     'Polar_expression': [['jubelten'], ['51:59']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Offiziell hat Donald Trump seine Kandidatur für 2024 nicht angekündigt .',
#   'opinions': [{'Source': [['Donald'], ['14:20']],
#     'Target': [['Kandidatur'], ['33:43']],
#     'Polar_expression': [['angekündigt'], ['59:70']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Doch die beiden Zürcher tun viel dafür , um öffentlich wie ein eingespieltes Team zu wirken .',
#   'opinions': [{'Source': [['Zürcher'], ['16:23']],
#     'Target': [[], []],
#     'Polar_expression': [['wirken'], ['85:91']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Buchs SG – Zwei Männer haben am Mittwochabend einen Tankstellen-Shop überfallen .',
#   'opinions': [{'Source': [['Männer'], ['16:22']],
#     'Target': [['Tankstellen'], ['52:63']],
#     'Polar_expression': [['überfallen'], ['69:79']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'Jetzt hat der Postauto-Skandal das Liechtensteiner Parlament erreicht .',
#   'opinions': [{'Source': [['Skandal'], ['23:30']],
#     'Target': [['Liechtensteiner Parlament'], ['35:60']],
#     'Polar_expression': [['erreicht'], ['61:69']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'Der Thurgauer kann sich trotz seines fünften Boston-Sieges nicht uneingeschränkt freuen .',
#   'opinions': [{'Source': [['Thurgauer'], ['4:13']],
#     'Target': [[], []],
#     'Polar_expression': [['freuen'], ['81:87']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': 'Ausser Werner vergab noch Captain Marcel Sabitzer eine Grosschance ( 46. ) .',
#   'opinions': [{'Source': [['Captain'], ['26:33']],
#     'Target': [['Grosschance'], ['55:66']],
#     'Polar_expression': [['vergab'], ['14:20']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  ...]

# %%
# evaluate the polar expression performance
print("test accuracy: {:.3f}".format(accuracy_score(gold_polarities, preds_full_label_text)))

print(classification_report(gold_polarities, preds_full_label_text))
# Out:
# test accuracy: 0.577
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.48      0.60      1774
#      Neutral       0.48      0.89      0.62      1792
#     Positive       0.67      0.36      0.47      1757
#
#     accuracy                           0.58      5323
#    macro avg       0.65      0.57      0.56      5323
# weighted avg       0.65      0.58      0.56      5323

# %%
with open(DATADEST, "w", encoding="utf-8") as f:
    json.dump(out_data_w_entities_and_rel, f)

# %%
# evaluation of the test set
!(source ~/envs/perin-venv/bin/activate && cd ../../external_repos/direct_parsing_to_sent_graph/evaluation && python evaluate_single_dataset.py ../../../etl/data/processed/Perin_Preprocessing/01_test.json ../../../etl/data/processed/ORL_RE_Inference/01_test.json)
# Out:
# 209.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Source F1: 0.731
# Target F1: 0.604
# Expression F1: 0.800
# Unlabeled Sentiment Tuple F1: 0.406
# Sentiment Tuple F1: 0.283
# {
#   "source/f1": 0.7309854154541209,
#   "target/f1": 0.6041468349975422,
#   "expression/f1": 0.8002938109452079,
#   "sentiment_tuple/unlabeled_f1": 0.4057627563970956,
#   "sentiment_tuple/precision": 0.28181078986745617,
#   "sentiment_tuple/recall": 0.2840651103970956,
#   "sentiment_tuple/f1": 0.28293345978284773
# }
#
# [0.7309854154541209, 0.6041468349975422, 0.8002938109452079, 0.4057627563970956, 0.28181078986745617, 0.2840651103970956, 0.28293345978284773]

# %%
#evaluation of the gold standard
!(source ~/envs/perin-venv/bin/activate && cd ../../external_repos/direct_parsing_to_sent_graph/evaluation && python evaluate_single_dataset.py --relaxed ../../../etl/data/processed/Perin_Preprocessing/pro_con_500.json ../../../etl/data/processed/ORL_RE_Inference/pro_con_500.json)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Source F1: 0.719
# Target F1: 0.637
# Expression F1: 1.000
# Unlabeled Sentiment Tuple F1: 0.469
# Sentiment Tuple F1: 0.300
# {
#   "source/f1": 0.7194239589827968,
#   "target/f1": 0.636655466300335,
#   "expression/f1": 0.9999994932888406,
#   "sentiment_tuple/unlabeled_f1": 0.4686239051670324,
#   "sentiment_tuple/precision": 0.3324805068226121,
#   "sentiment_tuple/recall": 0.2736842105263158,
#   "sentiment_tuple/f1": 0.30023081984415956
# }
#
# [0.7194239589827968, 0.636655466300335, 0.9999994932888406, 0.4686239051670324, 0.3324805068226121, 0.2736842105263158, 0.30023081984415956]
