# %% [markdown]
# ## ORL_RE_Inference
#
# Use the trained model to predict input sentences and bring them into a format accepted by the relation classifier.

# %%
import os
# DataSource in SSA-format
DATASOURCE="../../etl/data/processed/Perin_Preprocessing/01_test.json"
DATADEST="../../etl/data/processed/ORL_RE_Inference/01_test.json"

# DATASOURCE="../../etl/data/processed/Perin_Preprocessing/01_train.json"
# DATADEST="../../etl/data/processed/ORL_RE_Inference/01_train.json"

# DATASOURCE="../../etl/data/processed/REConverter/01_train_re.json"

VERIFY_RE_MODEL=False

# CONFIGS for NER
# CONFIG-VARIABLES
ORL_MODEL_PATH="../ORL/data/trained_model_german_bert"

# CONFIGS for RE
# GS_INPUT_DIR = "/content/drive/MyDrive/odsc-2022-data/NYT"
DATA_DIR = "../../etl/data/processed/REConverter"
splits = ["train", "test", "val"]
BASE_MODEL_NAME = "bert-base-german-cased"
# BASE_MODEL_NAME = "bert-base-cased"
MODEL_DIR = os.path.join("../RelationClassifier/data", "{:s}-re".format(BASE_MODEL_NAME))

# %% [markdown]
# ### Read-In the data
#
# Reading in the data so it can be processed. The format is SSA.

# %%
# makedirs if not exist
os.makedirs("../../etl/data/processed/ORL_RE_Inference", exist_ok=True)

# %%
opinion_interface = {'Source': [[], []], 
             'Target': [[], []], 
             'Polar_expression': [[], []], 
             'Polarity': None, 
             'Intensity': 'Average'}

# %%
import json
import copy

out_data = None
gold_polarities = []
def convert_ssa_to_sents(datasource):
    with open(datasource, "r", encoding="utf-8") as f:
        data = json.load(f)
    out_data = copy.deepcopy(data)
    sents = []
    for i, rec in enumerate(data):
        out_data[i]["opinions"] = [copy.deepcopy(opinion_interface)]
        # print(rec)
        sents.append(rec["text"])
        gold_polarities.append(rec["opinions"][0]["Polarity"])
    return sents, out_data

ssa_sents, out_data = convert_ssa_to_sents(DATASOURCE)

# %%
print(out_data)
# Out:
# [{'sent_id': '0', 'text': 'Der Mann soll mehrfach auf die Frau geschossen und sich dann selbst gerichtet haben .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '1', 'text': 'Die Mehrheit der republikanischen wie der demokratischen Senatoren und Abgeordneten ist China-kritisch , und das Weisse Haus geniesst Unterstützung , wenn es Chinas Wiederaufstieg zur Weltmacht als gefährlichste Herausforderung des 21. Jahrhunderts bezeichnet und seine Aussen- und Sicherheitspolitik dementsprechend frisch fokussiert .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '2', 'text': 'Eine Geschichte , deutlich geprägt von – doch nicht deckungsgleich mit – der Liaison zwischen Halliday und dem im Mai dieses Jahres verstorbenen Philip Roth .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '3', 'text': 'Die ersten betroffenen Spiele finden am Donnerstag statt , darunter die Partie von Chelsea bei Norwich City .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '4', 'text': '« Die Russen schiessen auf alles , auch auf zivile Ziele .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '5', 'text': 'Aber viel später , während der Unruhen in den 1970er Jahren , benutzte die Irish Republican Army ( IRA ) die Ruine , um auf britische Sicherheitskräfte zu schiessen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '6', 'text': 'Wie im echten Fussballbusiness hat auch im Game der Markt die Preise in die Höhe schiessen lassen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '7', 'text': 'Die Schweizer Ratingagentur Independent Credit View warnte ihre Kunden bereits 2019 davor , Papiere der nun zusammengebrochenen Greensill-Bank zu kaufen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '8', 'text': 'Die vierte Generation des Erfolgsmodells überzeugt durch ausdrucksstarkes Design und vereint sportlich-direktes Handling durch die variable Progressivlenkung und Toptraktion durch den Quattro-Antrieb .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '9', 'text': 'Zwingli sah sich schon 1523 / 24 mit einem Problem vieler Revolutionen konfrontiert – mit « Abweichlern » in den eigenen Reihen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '10', 'text': '« Inzwischen haben die Lichtemissionen und die Qualität des Lichts mehr Gewicht gewonnen . » Die neuen intelligenten LED-Leuchten lassen sich wesentlich präziser einsetzen als die früheren Natriumdampflampen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '11', 'text': 'Seither haftet der kalten Fusion ein Schmuddelimage an .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '12', 'text': 'Genau eine solche Konstellation könne im Sommer eintreten , wenn die Covid-19-Impfungen im grossen Stil verabreicht werden .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '13', 'text': 'Mit dieser Erfahrung konnte Ber ...

# %% [markdown]
# ### Target Holder PolarExpression Extraction
#
# **Extract Target-Holder-Expression-Pairs**

# %%
# Load the ORL model.
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

model_path = ORL_MODEL_PATH

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)

pipe = pipeline(task="token-classification",
                # model=trainer.model, -- in case freshly trained
                model=model,
                tokenizer=tokenizer,
                aggregation_strategy="first"
               )

classified = pipe("Der Mann erschiesst seine Frau.")

print(classified)
# Out:
# [{'entity_group': 'LABEL_0', 'score': 0.9995009, 'word': 'Der', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_1', 'score': 0.98678166, 'word': 'Mann', 'start': 4, 'end': 8}, {'entity_group': 'LABEL_3', 'score': 0.9874593, 'word': 'erschiesst', 'start': 9, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.9993839, 'word': 'seine', 'start': 20, 'end': 25}, {'entity_group': 'LABEL_2', 'score': 0.9727228, 'word': 'Frau', 'start': 26, 'end': 30}, {'entity_group': 'LABEL_0', 'score': 0.99930334, 'word': '.', 'start': 30, 'end': 31}]

# %%
from typing import NamedTuple

class PAS(NamedTuple):
    arg1: str
    arg2: str
    pexp: str

# %%
label_mapper = {
    "LABEL_0": "NEUTRAL",
    "LABEL_1": "HOLDER",
    "LABEL_2": "TARGET",
    "LABEL_3": "PEXP",
}

def extract_args(bert_output):
    """Obtain arguments from a dict-list of a BERT model."""
    # the holder is the first argument, the target is the second argument
    arg1=None
    arg2=None
    pexp=None
    for c in bert_output:
        if label_mapper[c["entity_group"]] == "HOLDER":
            arg1=c["word"]
        elif label_mapper[c["entity_group"]] == "TARGET":
            arg2=c["word"]
        elif label_mapper[c["entity_group"]] == "PEXP":
            pexp=c["word"]
        else:
            pass
        
    # if one is none, fill it by using the highest probability overall.

    return arg1, arg2, pexp

# %%
# Function doing the heavy lifting, here we assume one relation per sentence (no compositionality).
def extract_pas(sentence_string):
    # sentence with holder / target labels
    labelled_sentence = pipe(sentence_string)
    # obtain arguments from labels
    arg1, arg2, pexp = extract_args(labelled_sentence)
    return PAS(arg1, arg2, pexp)

print(extract_pas("Die Berliner Morgenpost hat den Angriff auf die Ukraine kritisiert."))
# Out:
# PAS(arg1='Morgenpost', arg2='Angriff', pexp='kritisiert')

# %% [markdown]
# ### Generate unbreakable tokens based on input sentence + ORL inference
#
# **Important**: We make sure that every sentence contains a dot in the end that is separated from the last word in the sentence!

# %%
# simplified_training_data
import re
import copy
from tqdm import tqdm

def identify_from_base_sent(target_word, base_sent):
    res = re.search(target_word, base_sent)
    return res.span()

def generate_head_based_entity_sentences(sentences, out_data=[]):
    entified_list = []
    ret_od = []
    for i, sent in tqdm(enumerate(sentences)):
        pas = extract_pas(sent)
        od = copy.deepcopy(out_data[i])
        base_sent = copy.deepcopy(sent)
        # print(pas)
        try:
            if pas.arg1:
                res = re.search(pas.arg1, sent)
                e1_s, e1_e = res.span()
                # print(out_data[i]["opinions"][0]["Source"])
                sent = sent[0:max(0, e1_s - 1)] + " <eSOURCE> " + sent[e1_s:min(len(sent), e1_e)] + " </eSOURCE> " + sent[min(len(sent), e1_e + 1):]
                
                e1_s, e1_e = identify_from_base_sent(pas.arg1, base_sent)
                od["opinions"][0].update({ "Source": [[base_sent[e1_s:min(len(sent), e1_e)]], [f"{str(e1_s)}:{str(e1_e)}"]] })

            if pas.arg2:
                res = re.search(pas.arg2, sent)
                e2_s, e2_e = res.span()
                sent = sent[0:max(0, e2_s - 1)] + " <eTARGET> " + sent[e2_s:min(len(sent), e2_e)] + " </eTARGET> " + sent[min(len(sent), e2_e + 1):]
                
                e2_s, e2_e = identify_from_base_sent(pas.arg2, base_sent)
                od["opinions"][0]["Target"] = [[base_sent[e2_s:min(len(sent), e2_e)]], [f"{str(e2_s)}:{str(e2_e)}"]]

            if pas.pexp:
                res = re.search(pas.pexp, sent)
                e3_s, e3_e = res.span()
                sent = sent[0:max(0, e3_s - 1)] + " <ePEXP> " + sent[e3_s:min(len(sent), e3_e)] + " </ePEXP> " + sent[min(len(sent), e3_e + 1):]
                
                e3_s, e3_e = identify_from_base_sent(pas.pexp, base_sent)
                od["opinions"][0]["Polar_expression"] = [[base_sent[e3_s:min(len(sent), e3_e)]], [f"{str(e3_s)}:{str(e3_e)}"]]


            for tag, expression in [("SOURCE", pas.arg1), ("TARGET", pas.arg2), ("PEXP", pas.pexp)]:
                if expression is None:
                    # res = re.search("(\.|\!)\s*?(<\/.*>)?\s*?$", sent)
                    res = re.search("(\.|\!)", sent)
                    if res is None:
                        sent += " ."
                    res = re.search("(\.|\!)", sent)
                    e_nf_s, e_nf_e = res.span()
                    #print(f"{ e_nf_s} ; {e_nf_e}")
                    sent = sent[0:max(0, e_nf_s - 1)] + f" <e{tag}> " + sent[e_nf_s:min(len(sent), e_nf_e)] + f" </e{tag}> " + sent[min(len(sent), e_nf_e + 1):]
                    
            # print(od[i]["opinions"][0])
            
            assert all([tag in sent for tag in ["<eTARGET>", "</eTARGET>", "<eSOURCE>", "</eSOURCE>", "<ePEXP>", "</ePEXP>"]]), "Not all tags present in sentence, falling back to trivial."

        except Exception as e:
            print(f"Something went wrong with extraction, {str(e)}, \n with sent {str(sent)} and sample # {i}")
            print("Trivialised!")
            # spaceholder
            # entified_list.append("Neutral <eSOURCE> . </eSOURCE> <eTARGET> . </eTARGET> <ePEXP> . </ePEXP>")
            od["text"] = "Neutral . .. ..."
            entified_list.append("Neutral <eSOURCE> . </eSOURCE> <eTARGET> .. </eTARGET> <ePEXP> ... </ePEXP>")
            od["opinions"][0].update({ "Source": [["."], ["8:9"]] })
            od["opinions"][0].update({ "Target": [[".."], ["10:12"]] })
            od["opinions"][0].update({ "Polar_expression": [["..."], ["13:16"]] })
            ret_od.append(od)
            continue

        entified_list.append(sent)
        # print(od)
        ret_od.append(od)
    return entified_list, ret_od

test_sents = ["Macron hat die Frau geliebt!",
"Jakob liebt Brigitte .",
 "Der Mann weiss nicht mehr wo er ist .",
 "Viele Personen sind von Haifischen ermordet worden .",
 "Liebe .",
 "Peter greift Michaela auf .",]

# entified_list = generate_head_based_entity_sentences()

# print(entified_list)
# don't forget stripping!
# print("\n")
# X = {"tokens": [e.strip().split() for e in entified_list]}
# print(X)

# %%
tagged_ssa_sents, out_data_w_entities = generate_head_based_entity_sentences(ssa_sents, out_data)
# Out:
# 1212it [00:40, 29.87it/s]

# %%
tokenized_ssa_sents = {"tokens": [e.strip().split() for e in tagged_ssa_sents]}

# %%
out_data_w_entities
# Out:
# [{'sent_id': '0',
#   'text': 'Der Mann soll mehrfach auf die Frau geschossen und sich dann selbst gerichtet haben .',
#   'opinions': [{'Source': [['Mann'], ['4:8']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': 'Die Mehrheit der republikanischen wie der demokratischen Senatoren und Abgeordneten ist China-kritisch , und das Weisse Haus geniesst Unterstützung , wenn es Chinas Wiederaufstieg zur Weltmacht als gefährlichste Herausforderung des 21. Jahrhunderts bezeichnet und seine Aussen- und Sicherheitspolitik dementsprechend frisch fokussiert .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Eine Geschichte , deutlich geprägt von – doch nicht deckungsgleich mit – der Liaison zwischen Halliday und dem im Mai dieses Jahres verstorbenen Philip Roth .',
#   'opinions': [{'Source': [['Geschichte'], ['5:15']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Die ersten betroffenen Spiele finden am Donnerstag statt , darunter die Partie von Chelsea bei Norwich City .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': '« Die Russen schiessen auf alles , auch auf zivile Ziele .',
#   'opinions': [{'Source': [['Russen'], ['6:12']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'Aber viel später , während der Unruhen in den 1970er Jahren , benutzte die Irish Republican Army ( IRA ) die Ruine , um auf britische Sicherheitskräfte zu schiessen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Ruine'], ['109:114']],
#     'Polar_expression': [['benutzte'], ['62:70']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Wie im echten Fussballbusiness hat auch im Game der Markt die Preise in die Höhe schiessen lassen .',
#   'opinions': [{'Source': [['Markt'], ['52:57']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Die Schweizer Ratingagentur Independent Credit View warnte ihre Kunden bereits 2019 davor , Papiere der nun zusammengebrochenen Greensill-Bank zu kaufen .',
#   'opinions': [{'Source': [['Ratingagentur'], ['14:27']],
#     'Target': [['Kunden'], ['64:70']],
#     'Polar_expression': [['warnte'], ['52:58']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Die vierte Generation des Erfolgsmodells überzeugt durch ausdrucksstarkes Design und vereint sportlich-direktes Handling durch die variable Progressivlenkung und Toptraktion durch den Quattro-Antrieb .',
#   'opinions': [{'Source': [['Generation'], ['11:21']],
#     'Target': [['Design'], ['74:80']],
#     'Polar_expression': [['überzeugt'], ['41:50']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Zwingli sah sich schon 1523 / 24 mit einem Problem vieler Revolutionen konfrontiert – mit « Abweichlern » in den eigenen Reihen .',
#   'opinions': [{'Source': [['Zwingli'], ['0:7']],
#     'Target': [['Problem'], ['43:50']],
#     'Polar_expression': [['konfrontiert'], ['71:83']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': '« Inzwischen haben die Lichtemissionen und die Qualität des Lichts mehr Gewicht gewonnen . » Die neuen intelligenten LED-Leuchten lassen sich wesentlich präziser einsetzen als die früheren Natriumdampflampen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Gewicht'], ['72:79']],
#     'Polar_expression': [['einsetzen'], ['162:171']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': 'Seither haftet der kalten Fusion ein Schmuddelimage an .',
#   'opinions': [{'Source': [['Schmuddelimage'], ['37:51']],
#     'Target': [['Fusion'], ['26:32']],
#     'Polar_expression': [['haftet'], ['8:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Genau eine solche Konstellation könne im Sommer eintreten , wenn die Covid-19-Impfungen im grossen Stil verabreicht werden .',
#   'opinions': [{'Source': [['Konstellation'], ['18:31']],
#     'Target': [[], []],
#     'Polar_expression': [['verabreicht'], ['104:115']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Mit dieser Erfahrung konnte Berset den Bundesrat vom Sinn schnellen Handelns überzeugen .',
#   'opinions': [{'Source': [['Berset'], ['28:34']],
#     'Target': [['Sinn'], ['53:57']],
#     'Polar_expression': [['überzeugen'], ['77:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Das Mitglied des britischen Oberhauses warnt die westlichen Länder auch davor , aus wirtschaftlichen Ängsten vor Peking zu kuschen .',
#   'opinions': [{'Source': [['Länder'], ['60:66']],
#     'Target': [[], []],
#     'Polar_expression': [['warnt'], ['39:44']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': 'Podcasts wie das unaufgeregt packende Format « Zeit Verbrechen » der grossartigen Sabine Rückert sind überaus erfolgreich sowie Fernsehserien wie « Aktenzeichen XY » Evergreens ; und namentlich bei Streamingdiensten florieren True-Crime-Serien .',
#   'opinions': [{'Source': [['True'], ['226:230']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Ihre Sorgen um die Gefährdung ihrer Dörfer , des Wassers und der Umwelt werden von Recon übergangen .',
#   'opinions': [{'Source': [['Recon'], ['83:88']],
#     'Target': [[], []],
#     'Polar_expression': [['übergangen'], ['89:99']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Bezos hat es von Anfang an geschafft , die Investoren von seiner Vision zu überzeugen .',
#   'opinions': [{'Source': [['Bezos'], ['0:5']],
#     'Target': [['Vision'], ['65:71']],
#     'Polar_expression': [['überzeugen'], ['75:85']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Die Bauernvertreter äussern aber Zweifel , ob der Kanton sich an Abmachungen halte .',
#   'opinions': [{'Source': [['Kanton'], ['50:56']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': '« Zuerst gab es einen Riesenknall , dann hat der Mann mit einer Schrotflinte auf die Tür geschossen » , sagte ein Zeuge .',
#   'opinions': [{'Source': [['Mann'], ['49:53']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Der Nidwaldner hatte gerade sein erstes Weltcuprennen gewonnen , einen Super-G , etwas für die Erfahrenen , heisst es , auf der Birds of Prey , der Raubvogelpiste , es ist eine der grössten Aufgaben des Winters .',
#   'opinions': [{'Source': [['Nidwaldner'], ['4:14']],
#     'Target': [['Weltcuprennen'], ['40:53']],
#     'Polar_expression': [['gewonnen'], ['54:62']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Von dort stieg der Mann offenbar Treppen hinab Richtung Donaukanal , schoss weiter auf Passanten und auf einen Polizisten , den er schwer verletzte .',
#   'opinions': [{'Source': [['Mann'], ['19:23']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Vor einer Woche warnte beispielsweise die Führung des Zuger Schraubenhändlers Bossard die Aktionäre davor , dass die Situation an den Beschaffungsmärkten auch in der zweiten Jahreshälfte angespannt bleiben dürfte und mit « weiteren Preiserhöhungen und längeren Lieferfristen » zu rechnen sei .',
#   'opinions': [{'Source': [['Führung'], ['42:49']],
#     'Target': [[], []],
#     'Polar_expression': [['warnte'], ['16:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Parallel dazu zog der Bund eine Finanzierung für Projekte auf , die nicht mehr mit Geld aus Brüssel rechnen konnten .',
#   'opinions': [{'Source': [['Bund'], ['22:26']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'Die hoffnungsvollen Trump-Stürzer übersehen , dass es – abgesehen von einem Rücktritt – vielleicht in der Theorie Wege gibt , einen Präsidenten loszuwerden , aber kaum in der Praxis .',
#   'opinions': [{'Source': [['Trump'], ['20:25']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'Vermutlich hatte aber der Mann zuerst auf die Frauen geschossen und sich dann selber gerichtet .',
#   'opinions': [{'Source': [['Mann'], ['26:30']],
#     'Target': [[], []],
#     'Polar_expression': [['geschossen'], ['53:63']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': 'Zwar konnte der Kabelnetzbetreiber unter ihrer Ägide , die im Herbst 2018 begann , gut 50 000 Neukunden für sein Mobilfunkangebot gewinnen .',
#   'opinions': [{'Source': [['Kabelnetzbetreiber'], ['16:34']],
#     'Target': [['Mobilfunkangebot'], ['113:129']],
#     'Polar_expression': [['gewinnen'], ['130:138']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Doch die Ansammlung Ausnahmefussballer schleppte sich durch die Vorrunde , siegte gegen Australien ( 2 : 1 ) und Peru ( 1 : 0 ) beinahe glückhaft – und hinterliess auch gestern phasenweise den Eindruck , zufällig im gleichen Trikot zu stecken .',
#   'opinions': [{'Source': [['Ansammlung'], ['9:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Tsai hält eine gewisse Distanz zu Peking , ohne allerdings für eine Unabhängigkeit der Inselrepublik einzutreten .',
#   'opinions': [{'Source': [['Tsai'], ['0:4']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'Humanistisches Denken , wohltätiges Wirken und eine starke Gemeinschaft : Diese Werte hätten ihn von den Odd Fellows überzeugt , als er vor zwölf Jahren zum ersten Mal eine Loge besucht habe , erzählt Egli .',
#   'opinions': [{'Source': [['Werte'], ['80:85']],
#     'Target': [[], []],
#     'Polar_expression': [['überzeugt'], ['117:126']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Luftfahrt Der renommierte Thinktank ICCT warnt vor den geplanten Überschallflugzeugen .',
#   'opinions': [{'Source': [['Thinktank'], ['26:35']],
#     'Target': [['Überschallflugzeugen'], ['65:85']],
#     'Polar_expression': [['warnt'], ['41:46']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': 'Der Pass dazu kommt von Jan Kovar und verdient das Prädikat Weltklasse .',
#   'opinions': [{'Source': [['Pass'], ['4:8']],
#     'Target': [['Prädikat'], ['51:59']],
#     'Polar_expression': [['verdient'], ['38:46']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'Zuvor will Labour jedoch versuchen , die Regierung von den eigenen Brexit-Plänen zu überzeugen .',
#   'opinions': [{'Source': [['Labour'], ['11:17']],
#     'Target': [['Regierung'], ['41:50']],
#     'Polar_expression': [['überzeugen'], ['84:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Die AL weist darauf hin , dass die Wertberichtigung zur langfristigen Stabilisierung des Stadtspitals beitrage .',
#   'opinions': [{'Source': [['Wertberichtigung'], ['35:51']],
#     'Target': [['Stabilisierung'], ['70:84']],
#     'Polar_expression': [['beitrage'], ['102:110']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Weil Kohlekraftwerke gutes Geld einbringen , fehlen künftig die Einnahmen bei Alpiq ( im ersten Semester 24 Mio. Fr . ) .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Geld'], ['27:31']],
#     'Polar_expression': [['fehlen'], ['45:51']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Meteorologen warnten vor Sturzfluten .',
#   'opinions': [{'Source': [['Meteorologen'], ['0:12']],
#     'Target': [['Sturzfluten'], ['25:36']],
#     'Polar_expression': [['warnten'], ['13:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Nur weil der EU griffige Massnahmen bei der Terrorbekämpfung fehlen .',
#   'opinions': [{'Source': [['Massnahmen'], ['25:35']],
#     'Target': [['Terrorbekämpfung'], ['44:60']],
#     'Polar_expression': [['fehlen'], ['61:67']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'Das zuletzt schwächelnde Team von Domenico Tedesco siegte gegen Augsburg 4 : 0 und kletterte in der Tabelle auf Rang 4 und hat die Qualifikation für die Champions League vor dem letzten Spiel bei Arminia Bielefeld nun wieder selbst in der Hand .',
#   'opinions': [{'Source': [['Team'], ['25:29']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Eine gewisse Ursula Koch schlich sich in die Versammlung ein und versuchte , die Aktivisten von einem SP-Beitritt zu überzeugen .',
#   'opinions': [{'Source': [['Ursula'], ['13:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Auch wurde das Ziel , die öffentliche Meinung im Ausland zu beeinflussen , in einer Konzeption Russlands aus dem Jahr 2013 offiziell genannt .',
#   'opinions': [{'Source': [['Ziel'], ['15:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Gerade schrieb er mir : « Die erste Runde ist nie einfach . » ( Bencic hat gerade gegen Andrea Petkovic gewonnen .',
#   'opinions': [{'Source': [['Bencic'], ['64:70']],
#     'Target': [['Andrea'], ['88:94']],
#     'Polar_expression': [['gewonnen'], ['104:112']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Als die Bancomaten-Diebe flüchteten , zückten die Ordnungshüter ihre Pistole und schossen auf die Männer .',
#   'opinions': [{'Source': [['Ordnungshüter'], ['50:63']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'Ein bisschen näher wäre ihr Sofia Goggia gekommen , doch die Siegerin der beiden Abfahrten blieb vor dem Zielsprung an einem Tor hängen und verpasste das nächste .',
#   'opinions': [{'Source': [['Siegerin'], ['61:69']],
#     'Target': [[], []],
#     'Polar_expression': [['verpasste'], ['140:149']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Der Finne zeigt mit Stolz , was die von ihm gegründete Firma Rovio Entertainment erfunden hat : Das Computerspiel Angry Birds ( « zornige Vögel » ) , bei dem rote Vögel mit Schleudern auf diebische Schweine schiessen .',
#   'opinions': [{'Source': [['Firma'], ['55:60']],
#     'Target': [[], []],
#     'Polar_expression': [['erfunden'], ['81:89']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'Ulf Berg wiederum , seit 2007 Verwaltungsratspräsident der Ems-Chemie , nennt Magdalena Martullo gerne « das Orakel von Delphi » .',
#   'opinions': [{'Source': [['Ulf'], ['0:3']],
#     'Target': [[], []],
#     'Polar_expression': [['nennt'], ['72:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Die Gendarmerie habe auf die Reifen eines verdächtigen Fahrzeugs geschossen , nachdem der Fahrer die Aufforderung , sofort anzuhalten , ignoriert habe .',
#   'opinions': [{'Source': [['Fahrer'], ['90:96']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': 'Die Bayern zogen ihr Tempospiel auf , kombinierten die Moskauer schwindelig .',
#   'opinions': [{'Source': [['Bayern'], ['4:10']],
#     'Target': [['Tempospiel'], ['21:31']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Aber was soll ’ s – es sind erst sieben Runden gespielt , die Rangliste wirkt chaotisch , St. Gallen hat als einziges Team keine Partie verpasst , Servette und Sitten spielten erst vier Mal .',
#   'opinions': [{'Source': [['Rangliste'], ['62:71']],
#     'Target': [[], []],
#     'Polar_expression': [['wirkt'], ['72:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'In der Anklageschrift geht die Staatsanwaltschaft aufs Ganze , klagt Vincenz und Beat Stocker ( 61 ) wegen Betruges an .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['klagt'], ['63:68']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': 'Gleich zweimal konnte Emmerton nach Querpass aufs offene Tor schiessen – beim ersten Mal traf er das Gehäuse , beim zweiten Mal zum 1 : 0 ( 7. ) .',
#   'opinions': [{'Source': [['Emmerton'], ['22:30']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Zum Abschluss der Gruppenphase des Gold-Cups gewann Honduras gegen El Salvador 4 : 0 .',
#   'opinions': [{'Source': [['Honduras'], ['52:60']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['45:51']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': '« Männer müssen den Mut haben , zu ihrer Verletzlichkeit zu stehen und Gefühle zu zeigen . » Wichtig für sie : « Männer und Frauen sollten sich auf Augenhöhe begegnen und einen Schritt aufeinander zugehen . » Caroline Fux ( 37 ) , Psychologin und Sexberaterin bei BLICK , warnte vor Pauschalisierungen : « Viele Männer bemühen sich , alles richtig zu machen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Die ersten drei Wochen eines vierwöchigen Trainingsblocks werden intensiver sein als bisher , die letzte Woche dient der aktiven Erholung .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Erholung'], ['129:137']],
#     'Polar_expression': [['dient'], ['111:116']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'Von 1946 bis 1971 fanden im Park auch Vorführungen im Rahmen des Filmfestivals statt .',
#   'opinions': [{'Source': [['Vorführungen'], ['38:50']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': '« In den entscheidenden Momenten waren sie ein bisschen stärker . » Das Ziel bleibe , den Fed-Cup einmal zu gewinnen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Fed'], ['90:93']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Busse und Barrikaden brennen , Polizisten schiessen auf Demonstranten , eine Katastrophe für ein ohnehin gebeuteltes Land , aber auch ein düsteres Omen für die ganze Region .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['brennen'], ['21:28']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Allerdings fehlt dem Land ein mutiger Reformer wie Deng Xiaoping oder der einstige Regierungschef Zhu Rongji , der in den Neunzigern den schmerzhaften Umbau der Staatsbetriebe vorantrieb .',
#   'opinions': [{'Source': [['Reformer'], ['38:46']],
#     'Target': [['Land'], ['21:25']],
#     'Polar_expression': [['fehlt'], ['11:16']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Die Strafverfolger klagen zudem Zieglers Helfer an , der den Käufer beraten hatte .',
#   'opinions': [{'Source': [['Strafverfolger'], ['4:18']],
#     'Target': [['Zieglers Helfer'], ['32:47']],
#     'Polar_expression': [['klagen'], ['19:25']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Vor einem Jahr hat er ja schon einmal in Syrien bombardieren lassen , nachdem die Regierungsarmee mit Giftgas auf Zivilisten geschossen hatte .',
#   'opinions': [{'Source': [['Regierungsarmee'], ['82:97']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Die Emirate wiederum hoffen , in Damaskus an Einfluss zu gewinnen und so die Macht Irans zu schwächen , mit dem sie in der Region um Einfluss ringen .',
#   'opinions': [{'Source': [['Emirate'], ['4:11']],
#     'Target': [['Macht'], ['77:82']],
#     'Polar_expression': [['gewinnen'], ['57:65']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Frau Leuthard verkennt weiterhin die Notwendigkeit , zuverlässige und stets verfügbare AKW auf der Basis neuster Technologie zu erstellen , um dauerhaft zu unserer Stromversorgung beizutragen ( auch für die zunehmende Elektromobilität ) .',
#   'opinions': [{'Source': [['Frau'], ['0:4']],
#     'Target': [['Stromversorgung'], ['164:179']],
#     'Polar_expression': [['beizutragen'], ['180:191']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'Fussball – Die Schweizer U21-Nati siegt im Test gegen Irland 2 : 0 .',
#   'opinions': [{'Source': [['Nati'], ['29:33']],
#     'Target': [[], []],
#     'Polar_expression': [['siegt'], ['34:39']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Müller und 99 weitere Glückliche haben eine Zypern-Rundreise für zwei Personen gewonnen .',
#   'opinions': [{'Source': [['Glückliche'], ['22:32']],
#     'Target': [['Zypern'], ['44:50']],
#     'Polar_expression': [['gewonnen'], ['79:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'Gleichzeitig gewann der Walliser die kleine Kristallkugel für den Gewinn des Disziplinen-Weltcups , der erstmals vergeben wurde .',
#   'opinions': [{'Source': [['Walliser'], ['24:32']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['13:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'In der Meisterschaft hat das Stadion dem LHC mit zwei Niederlagen keine Fortune gebracht , doch gegen Philadelphia siegte der Gastgeber 4 : 3.',
#   'opinions': [{'Source': [['Gastgeber'], ['126:135']],
#     'Target': [['LHC'], ['41:44']],
#     'Polar_expression': [['siegte'], ['115:121']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'Immerhin aber finden in den Salons und Sanatorien die Gespräche noch statt !',
#   'opinions': [{'Source': [['Gespräche'], ['54:63']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Tini nennt Benzodiazepine wie Xanax , aber auch Ecstasy , Alkohol oder Cannabis .',
#   'opinions': [{'Source': [['Tini'], ['0:4']],
#     'Target': [['Benzodiazepine'], ['11:25']],
#     'Polar_expression': [['nennt'], ['5:10']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Im Clip wird dargestellt , wie ein Mann mit einer automatischen Waffe auf Besucher eines Tanzclubs schiesst .',
#   'opinions': [{'Source': [['Mann'], ['35:39']],
#     'Target': [['Besucher'], ['74:82']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': '« Schwangere , die mich engagieren , haben vielleicht bereits ein Geburtstrauma erlitten und grosse Ängste » , sagt Brenneisen .',
#   'opinions': [{'Source': [['Schwangere'], ['2:12']],
#     'Target': [['Geburtstrauma'], ['66:79']],
#     'Polar_expression': [['erlitten'], ['80:88']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Die erneute Wertberichtigung auf dem Goodwill bedeutet vereinfacht gesagt , dass Lafarge tendenziell mehr « wacklige » Vermögenswerte eingebracht hat als bisher gedacht .',
#   'opinions': [{'Source': [['Lafarge'], ['81:88']],
#     'Target': [['Vermögenswerte'], ['119:133']],
#     'Polar_expression': [['eingebracht'], ['134:145']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'Fachleute attestieren ihr das Talent , um Grand-Slam-Titel zu gewinnen .',
#   'opinions': [{'Source': [['Fachleute'], ['0:9']],
#     'Target': [['Titel'], ['53:58']],
#     'Polar_expression': [['gewinnen'], ['62:70']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': '« Aufgestanden ! » , ruft der sportliche Erweckungprediger seinen lethargischen Patienten gleich am Anfang zu , um sie mit Rezepten für Besserung förmlich zu überschütten : Frühaufstehen , kalte Bäder , weg vom Ofen an die frische Luft , festes Schuhwerk , ein ordentlicher Bart als Schutz für die Kehle und vor allem gesunde Diät , denn « wir schaufeln uns unser Grab mit den Zähnen » .',
#   'opinions': [{'Source': [['Erweckungprediger'], ['41:58']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Gut-Behrami gewann die kleine Kristallkugel für die saisonbeste Super-G-Fahrerin 2014 und 2016 , Suter im vergangenen Winter .',
#   'opinions': [{'Source': [['Behrami'], ['4:11']],
#     'Target': [['Kristallkugel'], ['30:43']],
#     'Polar_expression': [['gewann'], ['12:18']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Ganz nach Bersets Motto : « Jede Impfung zählt ! » Neben den gängigen Angeboten wie Spontanimpfungen in Impfzentren oder zusätzlichen Impfmobilen und Beratungsmöglichkeiten haben sich manche Kantone weitere originelle Möglichkeiten ausgedacht , um die Bevölkerung vom Piks zu überzeugen .',
#   'opinions': [{'Source': [['Kantone'], ['191:198']],
#     'Target': [[], []],
#     'Polar_expression': [['überzeugen'], ['276:286']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'Nischni Nowgorod – In Russland hat ein 18-Jähriger auf Passanten geschossen und dabei mindestens drei Männer getötet .',
#   'opinions': [{'Source': [['Jähriger'], ['42:50']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'Cannabisproduzenten schiessen auf Eindringlinge .',
#   'opinions': [{'Source': [['Cannabisproduzenten'], ['0:19']],
#     'Target': [['Eindringlinge'], ['34:47']],
#     'Polar_expression': [['schiessen'], ['20:29']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'Bei den Älteren siegte hingegen die SPD deutlich .',
#   'opinions': [{'Source': [['SPD'], ['36:39']],
#     'Target': [['Älteren'], ['8:15']],
#     'Polar_expression': [['siegte'], ['16:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Mit Lasse Sobiech verletzte sich die Stütze in der Abwehr ein zweites Mal , die Balance zwischen Mittelfeld und Sturm geriet durcheinander ; Blaz Kramer und Assan Ceesay fehlt die Qualität im Sturm .',
#   'opinions': [{'Source': [['Stütze'], ['37:43']],
#     'Target': [[], []],
#     'Polar_expression': [['verletzte'], ['18:27']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Steuerfragen liegen indessen in der Kompetenz des sozialdemokratischen Finanzministers Olaf Scholz , den der CDU-Minster Altmaier erst noch für seine Pläne gewinnen müsste .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': 'Abstimmung Zu grosse Befugnisse für Polizei : Experten warnen vor dem Antiterrorgesetz .',
#   'opinions': [{'Source': [['Experten'], ['46:54']],
#     'Target': [['Antiterrorgesetz'], ['70:86']],
#     'Polar_expression': [['warnen'], ['55:61']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'Meistens dienen ihre Reisen dem guten Zweck und stehen im Zeichen des karitativen Geistes .',
#   'opinions': [{'Source': [['Reisen'], ['21:27']],
#     'Target': [['Zweck'], ['38:43']],
#     'Polar_expression': [['dienen'], ['9:15']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Laut der IMF-Chefökonomin Gita Gopinath ist es einmalig , dass alle Weltregionen gleichzeitig negative Wachstumsraten aufweisen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Wachstumsraten'], ['103:117']],
#     'Polar_expression': [['aufweisen'], ['118:127']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Der Flawiler Spezialist für industrielle Röntgentechnologie und Hersteller von Vakuumkondensatoren gewann vor zehn Jahren für seine Weiterentwicklung den Swiss Technology Award .',
#   'opinions': [{'Source': [['Spezialist'], ['13:23']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['99:105']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'Während der Nati-Vorbereitung in Bad Ragaz fehlte ein prominenter Name : Xherdan Shaqiri ( 30 ) .',
#   'opinions': [{'Source': [['Name'], ['66:70']],
#     'Target': [[], []],
#     'Polar_expression': [['fehlte'], ['43:49']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': 'Seit über sechs Jahren hat keine europäische Gastmannschaft mehr im Camp Nou gewonnen , aber dem BVB fehlte das Selbstvertrauen selbst für einen Versuch – sei es mit Abenteuerlust , sei es mit taktischer Stringenz , sei es mit purer Rebellion .',
#   'opinions': [{'Source': [['Gastmannschaft'], ['45:59']],
#     'Target': [['Versuch'], ['145:152']],
#     'Polar_expression': [['gewonnen'], ['77:85']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Intendant Andreas Beck und der designierte Operndirektor Pavel B. Jiracek konnten sie für diese Position gewinnen , welche sie bis zum Ende der Intendanz von Beck am Theater Basel ausüben wird .',
#   'opinions': [{'Source': [['Intendant'], ['0:9']],
#     'Target': [['Position'], ['96:104']],
#     'Polar_expression': [['gewinnen'], ['105:113']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Die beiden Initiatoren Giorgio Pace und Nicolas Bellavance-Lecompte nennen ihren Event « The Travelling Showcase for Collectable Design » ; dieses neue Format testeten sie bereits letztes Jahr in einer Villa in Monaco .',
#   'opinions': [{'Source': [['Initiatoren'], ['11:22']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Oder anders ausgedrückt : Die Staatsanwaltschaft schiesse mit Kanonen auf Spatzen , indem sie unverhältnismässig viele Kleinkriminelle in Untersuchungshaft setze , so lautet der Vorwurf .',
#   'opinions': [{'Source': [['Staatsanwaltschaft'], ['30:48']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Die Männer mit Skip Peter de Cruz siegen im fünften Spiel erst zum zweiten Mal ( 9 : 7 gegen Finnland ) .',
#   'opinions': [{'Source': [['Männer'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [['siegen'], ['34:40']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': '22 Eishockeyspiele fanden ohne Publikum statt .',
#   'opinions': [{'Source': [['Eishockeyspiele'], ['3:18']],
#     'Target': [['Publikum'], ['31:39']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Die Türken , die sich resolut gegen die Einstufung der Ereignisse als Völkermord wehren , intervenierten auf höchster Ebene – und hatten Erfolg : Der damalige Aussenminister Didier Burkhalter warnte den Genfer Regierungsrat in einem Brief eindringlich davor , die Baubewilligung zu erteilen .',
#   'opinions': [{'Source': [['Türken'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Nachdem diese Raketen auf die Hauptstadt Eritreas geschossen haben , könnte der Konflikt das ganze Horn von Afrika destabilisieren .',
#   'opinions': [{'Source': [['Konflikt'], ['80:88']],
#     'Target': [['Horn'], ['99:103']],
#     'Polar_expression': [['destabilisieren'], ['115:130']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Nach Maos Tod schossen seine Nachfolger 1989 auf das eigene Volk .',
#   'opinions': [{'Source': [['Nachfolger'], ['29:39']],
#     'Target': [['Volk'], ['60:64']],
#     'Polar_expression': [['schossen'], ['14:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Dann zog eine riesige Staubwolke durchs Tal .',
#   'opinions': [{'Source': [['Staubwolke'], ['22:32']],
#     'Target': [['Tal'], ['40:43']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': 'Und dazu der letzte Vergleich : Der Deutsche brachte 72 Erfolge nach Maranello – der Brite gewann bisher 69 Mal für Mercedes .',
#   'opinions': [{'Source': [['Brite'], ['85:90']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Das meiste Geld fliesst in Marketing , um neue zahlende Kunden zu gewinnen .',
#   'opinions': [{'Source': [['Geld'], ['11:15']],
#     'Target': [['Kunden'], ['56:62']],
#     'Polar_expression': [['gewinnen'], ['66:74']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'Lange Zeit hätten tamilische Politiker versucht , die muslimischen Gemeinschaften für die « Sache der Tamilischsprechenden » zu gewinnen , sagt Benedikt Korf , Professor für politische Geografie an der Universität Zürich .',
#   'opinions': [{'Source': [['Politiker'], ['29:38']],
#     'Target': [['Gemeinschaften'], ['67:81']],
#     'Polar_expression': [['gewinnen'], ['128:136']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': 'Im August findet die Übergabe an die Polizei statt , die danach ihr Provisorium im Tiefenbrunnen verlassen und den Neubau in Betrieb nehmen kann .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Mit einer 9-mm-Pistole schoss Nasim Aghdam auf drei Angestellte , dann nahm sie sich selbst das Leben .',
#   'opinions': [{'Source': [['Nasim'], ['30:35']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': '« Die Frau zog die Tiere auf und hatte eine enge Beziehung zu ihnen .',
#   'opinions': [{'Source': [['Frau'], ['6:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Weil die Schweizer Delegation über eigene Messdaten verfügt ( siehe Haupttext ) , arbeitet die Servicecrew von Dario Cologna und Kollegen mit Exklusivinformationen .',
#   'opinions': [{'Source': [['Servicecrew'], ['95:106']],
#     'Target': [['Exklusivinformationen'], ['142:163']],
#     'Polar_expression': [['arbeitet'], ['82:90']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Natürlich würde auch Liverpool gern die Champions League gewinnen .',
#   'opinions': [{'Source': [['Liverpool'], ['21:30']],
#     'Target': [['Champions'], ['40:49']],
#     'Polar_expression': [['gewinnen'], ['57:65']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Kein Gegner findet Mittel , um dem Mallorquiner die « Coupe des Mousquetaires » streitig zu machen .',
#   'opinions': [{'Source': [['Gegner'], ['5:11']],
#     'Target': [['Mallorquiner'], ['35:47']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Vor allem die Version einer Win-win-Situation darf bei chinesischen Vorträgen nicht fehlen .',
#   'opinions': [{'Source': [['Version'], ['14:21']],
#     'Target': [['Vorträgen'], ['68:77']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': 'Söder hat für die kommende Woche einen runden Tisch einberufen , um eine parteienübergreifende Lösung zu finden .',
#   'opinions': [{'Source': [['Söder'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': 'Die Staatsanwaltschaft von New York klagte den 29 Jahre alten Mann am Montag an , 2016 eine Fülle von geheimem Material gestohlen und dann der Enthüllungsplattform Wikileaks zugespielt zu haben .',
#   'opinions': [{'Source': [['Staatsanwaltschaft'], ['4:22']],
#     'Target': [['Mann'], ['62:66']],
#     'Polar_expression': [['klagte'], ['36:42']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'An seiner Stelle gewann sein früherer Vizepräsident Lenín Moreno die Wahl für die Regierungspartei .',
#   'opinions': [{'Source': [['Vizepräsident'], ['38:51']],
#     'Target': [['Wahl'], ['69:73']],
#     'Polar_expression': [['gewann'], ['17:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'So wirkt der kuriose Turniersieg in Schweden , nunmehr unter dem Coach Richard Møller Nielsen , wie eine besondere Pointe : Michael Laudrup , inzwischen in Barcelona , zog die Sommerferien der Turnierteilnahme auch wegen eines Konflikts mit Møller Nielsen vor , zumal er sich nach dem Gewinn des Europacups der Landesmeister mit Barça erschöpft wähnte .',
#   'opinions': [{'Source': [['Turniersieg'], ['21:32']],
#     'Target': [[], []],
#     'Polar_expression': [['wirkt'], ['3:8']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Der Banker machte sich selbständig , zog in Singapur einen Whiskyhandel auf , bevor er sieben Jahre später in die Schweiz zurückkehrte .',
#   'opinions': [{'Source': [['Banker'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': 'Über dem Golf schiesst ein US-Kriegsschiff ein iranisches Linienflugzeug ab .',
#   'opinions': [{'Source': [['Kriegsschiff'], ['30:42']],
#     'Target': [['Linienflugzeug'], ['58:72']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Vor drei Jahren gewann Pawlikowski für « Ida » , die Geschichte einer Nonne im Polen der sechziger Jahre , neben zahlreichen anderen Preisen den Oscar für den besten fremdsprachigen Film .',
#   'opinions': [{'Source': [['Pawlikowski'], ['23:34']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['16:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'Djibril Diani ( 21 ) und Morandi ( 20 ) vor ihm fehlt in den entscheidenden Momenten oft die nötige Ruhe .',
#   'opinions': [{'Source': [['Ruhe'], ['100:104']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Diese Sicherheit fehlt den Österreichern im Wettkampf . » Allzu früh sollten wir Schweizer uns aber nicht über die Probleme unserer Erz-Rivalen freuen .',
#   'opinions': [{'Source': [['Sicherheit'], ['6:16']],
#     'Target': [['Österreichern'], ['27:40']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'Der Liga-Topskorer schiesst den starken FCZ im Alleingang ab .',
#   'opinions': [{'Source': [['Topskorer'], ['9:18']],
#     'Target': [['FCZ'], ['40:43']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'Schon vor dem Spiel um 01.00 Uhr Schweizer Zeit in der Nacht von Samstag auf Sonntag zogen dunkle Wolken über dem Lambeau Field auf , das Spiel wurde zunächst mit 15 Minuten Verspätung angepfiffen und musste nach dem Haaland-Treffer ein weiteres Mal für rund 60 Minuten unterbrochen werden .',
#   'opinions': [{'Source': [['Wolken'], ['98:104']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'MARCO GARCIA , BUBIKON ZH Diesen Jugendlichen fehlt die führende Hand der Eltern und des Staats .',
#   'opinions': [{'Source': [['Hand'], ['65:69']],
#     'Target': [['Jugendlichen'], ['33:45']],
#     'Polar_expression': [['fehlt'], ['46:51']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Nach Aussage der israelischen Armee haben die Soldaten gezielt auf Rädelsführer geschossen .',
#   'opinions': [{'Source': [['Soldaten'], ['46:54']],
#     'Target': [['Rädelsführer'], ['67:79']],
#     'Polar_expression': [['geschossen'], ['80:90']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Traugott Vöhringer ist erstaunt , dass das Projekt so grossen Anklang fand .',
#   'opinions': [{'Source': [['Traugott'], ['0:8']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Fussball – Liverpool siegt gegen CF Monterrey 2 : 1 ( mit Shaqiri bis zur 68.',
#   'opinions': [{'Source': [['Liverpool'], ['11:20']],
#     'Target': [[], []],
#     'Polar_expression': [['siegt'], ['21:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Von einer Hochhaus-Baustelle hätten Scharfschützen auf die Protestierenden geschossen , erzählen viele .',
#   'opinions': [{'Source': [['Scharfschützen'], ['36:50']],
#     'Target': [['Protestierenden'], ['59:74']],
#     'Polar_expression': [['geschossen'], ['75:85']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Mit einer eigenen Website , Broschüren und Roadshows versucht das Bundesamt für Energie ( BFE ) seit 2015 , Autokäufer für klimaschonendere Fahrzeuge zu gewinnen – weitgehend erfolglos .',
#   'opinions': [{'Source': [['Bundesamt'], ['66:75']],
#     'Target': [[], []],
#     'Polar_expression': [['gewinnen'], ['153:161']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Daraufhin schoss die Armee ohne Vorwarnung in die Menge .',
#   'opinions': [{'Source': [['Armee'], ['21:26']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Der Freiburger hat sich zur valablen Alternative zu Flüeler entwickelt , gewann seine ersten fünf Starts und 11 von 16 Spielen .',
#   'opinions': [{'Source': [['Freiburger'], ['4:14']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Cavusoglu warnte die USA auch davor , die Türkei vor die Wahl zu stellen , entweder gute Beziehungen zu Russland oder zu den USA zu haben .',
#   'opinions': [{'Source': [['Cavusoglu'], ['0:9']],
#     'Target': [['USA'], ['21:24']],
#     'Polar_expression': [['warnte'], ['10:16']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'In einem anderen Fall , bei dem um einen vergleichsweise geringen Betrag gestritten wurde , hat Implenia am Ende gegen die Stadt gewonnen .',
#   'opinions': [{'Source': [['Implenia'], ['96:104']],
#     'Target': [['Stadt'], ['123:128']],
#     'Polar_expression': [['gewonnen'], ['129:137']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Über eine mit dem Westen vergleichbare Kaufkraft verfügt in Indien weiterhin nur ein Bruchteil der Bevölkerung ; bereits ab einem Einkommen von 10 $ pro Tag zählt man hier zur Mittelschicht .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Kaufkraft'], ['39:48']],
#     'Polar_expression': [['verfügt'], ['49:56']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '126',
#   'text': 'Brüssel warnt aber gleichzeitig vor zu hohen Erwartungen .',
#   'opinions': [{'Source': [['Brüssel'], ['0:7']],
#     'Target': [['Erwartungen'], ['45:56']],
#     'Polar_expression': [['warnt'], ['8:13']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '127',
#   'text': 'Das eindrückliche Abschneiden der Sika-Gruppe an der Börse war indes auch die zentrale Voraussetzung dafür , dass die Streithähne nun doch noch eine einvernehmlichen Lösung gefunden haben .',
#   'opinions': [{'Source': [['Streithähne'], ['118:129']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '128',
#   'text': '« Das Feuer ist hier für den Täter kein Mittel zum Zweck , sondern dient bloss der eigenen Befriedigung . » Für den typischen Feuerteufel ist der Brandstifter von Merenschwand schon fast zu alt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Befriedigung'], ['91:103']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '129',
#   'text': 'Um ihre Vorgesetzten vom Jobsharing zu überzeugen , haben Christiane Haasis und Angela Nelissen die Kunstfigur « Chan » kreiert , gebildet aus den zwei Anfangsbuchstaben ihrer Vornamen .',
#   'opinions': [{'Source': [['Christiane'], ['58:68']],
#     'Target': [['Jobsharing'], ['25:35']],
#     'Polar_expression': [['überzeugen'], ['39:49']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '130',
#   'text': 'Die Spice Girls versuchen nach den Worten von Sängerin Mel C weiterhin , Victoria Beckham für ein Band-Comeback zu gewinnen .',
#   'opinions': [{'Source': [['Spice'], ['4:9']],
#     'Target': [['Comeback'], ['103:111']],
#     'Polar_expression': [['gewinnen'], ['115:123']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '131',
#   'text': 'Auch sonst treue Anhänger äusserten Zweifel , kritisierten das Papier als nutzlos , kleinmütig .',
#   'opinions': [{'Source': [['Anhänger'], ['17:25']],
#     'Target': [['Papier'], ['63:69']],
#     'Polar_expression': [['kritisierten'], ['46:58']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '132',
#   'text': 'Bei der Durchsetzung einer UNO-Flugverbotszone über Bosnien schiesst die Nato vier serbische Militärjets ab .',
#   'opinions': [{'Source': [['Nato'], ['73:77']],
#     'Target': [['Militärjets'], ['93:104']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '133',
#   'text': 'Er habe alle Parteien gedrängt , « auf verantwortungsvolle Weise eine angemessene Lösung der Ukraine-Krise » zu finden .',
#   'opinions': [{'Source': [['Parteien'], ['13:21']],
#     'Target': [[], []],
#     'Polar_expression': [['gedrängt'], ['22:30']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '134',
#   'text': 'Der Langzeit-SVP-Präsident ( 1996 bis 2008 ) gewann mehr als jede vierte Volksabstimmung gegen die « Classe politique » : acht von 29 Urnengängen .',
#   'opinions': [{'Source': [['Präsident'], ['17:26']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['45:51']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '135',
# ...
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '954',
#   'text': 'Noch 2016 hatte Graham das Justizministerium unter Präsident Barack Obama davor gewarnt , Apple dazu zu zwingen , das Handy des Terroristen zu entsperren .',
#   'opinions': [{'Source': [['Justizministerium'], ['27:44']],
#     'Target': [[], []],
#     'Polar_expression': [['gewarnt'], ['80:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '955',
#   'text': 'EU-Binnenmarkt-Kommissar Thierry Breton sagte am Montag , er sei « perplex » darüber , dass die Online-Plattformen Trump den Stecker gezogen hätten .',
#   'opinions': [{'Source': [['Plattformen'], ['103:114']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '956',
#   'text': 'Ein Beamter zieht schliesslich die Waffe und schiesst auf den irren Angreifer .',
#   'opinions': [{'Source': [['Beamter'], ['4:11']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '957',
#   'text': 'Den Fans ihrerseits fehlten mit den traditionellen Tonträgern plötzlich die kultischen Objekte ihrer Passion .',
#   'opinions': [{'Source': [['Objekte'], ['87:94']],
#     'Target': [['Fans'], ['4:8']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': 'Im Kanton Waadt warnte die Polizei Wanderer davor , in schneebedeckte Wälder zu gehen .',
#   'opinions': [{'Source': [['Polizei'], ['27:34']],
#     'Target': [[], []],
#     'Polar_expression': [['warnte'], ['16:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Aktivisten dementierten dies , allerdings gab es in der Vergangenheit mehrfach Vorfälle , in denen Rebellen auf Zivilisten schossen , um sie an der Flucht zu hindern .',
#   'opinions': [{'Source': [['Rebellen'], ['99:107']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Für seine Rolle als Hannibal Lecter in « Das Schweigen der Lämmer » gewann Hopkins seinen ersten Oscar als bester Schauspieler .',
#   'opinions': [{'Source': [['Hopkins'], ['75:82']],
#     'Target': [['Oscar'], ['97:102']],
#     'Polar_expression': [['gewann'], ['68:74']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Luna Rossa hat das Rendez-vous mit der Geschichte souverän bestanden : Genau 21 Jahre nach dem Sieg im Final der Herausforderer in Auckland gewannen die Italiener an gleicher Stätte erneut den Pokal für den besten Challenger .',
#   'opinions': [{'Source': [['Italiener'], ['153:162']],
#     'Target': [['Rendez'], ['19:25']],
#     'Polar_expression': [['bestanden'], ['59:68']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Im Tiebreak müssen Hüberli / Betschart die letztjährigen Gstaad-Siegerinnen etwas ziehen lassen , kämpfen aber heroisch – und wehren sechs Matchbälle ab !',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['wehren'], ['126:132']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'Die Kandidatur hat einen sehr guten Ansatz eingebracht .',
#   'opinions': [{'Source': [['Kandidatur'], ['4:14']],
#     'Target': [['Ansatz'], ['36:42']],
#     'Polar_expression': [['eingebracht'], ['43:54']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Russische Panzer schiessen auf Zivilisten .',
#   'opinions': [{'Source': [['Panzer'], ['10:16']],
#     'Target': [['Zivilisten'], ['31:41']],
#     'Polar_expression': [['schiessen'], ['17:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Dabei klagt die Regierungsbeauftragte auch eine Kultur des Machismus in der spanischen Gesellschaft an : « Unter der Covid-19-Pandemie versteckte sich eine andere Pandemie , nämlich die des Machismus , der jetzt wieder zutage tritt . » Davon bleibt keine Altersgruppe verschont .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Dann überzeugte der ehemalige IIHF-Präsident René Fasel den NHL-Commissioner Gary Bettman von der Werbewirksamkeit der olympischen Bühne .',
#   'opinions': [{'Source': [['Präsident'], ['35:44']],
#     'Target': [['NHL'], ['60:63']],
#     'Polar_expression': [['überzeugte'], ['5:15']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Auch dort fehle Frauen oft noch der Mut , den Mund aufzumachen und sich zu wehren .',
#   'opinions': [{'Source': [['Frauen'], ['16:22']],
#     'Target': [[], []],
#     'Polar_expression': [['aufzumachen'], ['51:62']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Rilke überging den Tod der Freundin mit Schweigen .',
#   'opinions': [{'Source': [['Rilke'], ['0:5']],
#     'Target': [['Tod'], ['19:22']],
#     'Polar_expression': [['überging'], ['6:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': 'Daniel Betschart ( 32 ) , Medienexperte bei der Stiftung Pro Juventute , warnt vor der gekauften Gefälligkeit : « Speziell Minderjährige lassen sich von der Aufmerksamkeit ihrer Idole rasch blenden und verteilen die Gifts , ohne an die Kosten zu denken . » Er rät : « Um nicht in die Kostenfalle zu tappen , deaktiviert man am besten die In-App-Käufe . » Weil schon 13-jährige Hunderte von Franken an ihre Stars verschenkten , erhöhte Tiktok die Altersbeschränkung für diese Funktion auf 18 Jahre .',
#   'opinions': [{'Source': [['Minderjährige'], ['123:136']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Mélenchon hat versucht , den Rest der linken Parteienlandschaft für eine Allianz zu gewinnen .',
#   'opinions': [{'Source': [['Mélenchon'], ['0:9']],
#     'Target': [['Rest'], ['29:33']],
#     'Polar_expression': [['gewinnen'], ['84:92']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Mueller klagte Manafort trotzdem an .',
#   'opinions': [{'Source': [['Mueller'], ['0:7']],
#     'Target': [['Manafort'], ['15:23']],
#     'Polar_expression': [['klagte'], ['8:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Sie bietet Studienwochen für Hochbegabte an , und im Projekt « ETH unterwegs » besuchen ETH-Professoren und Studierende Gymnasien und versuchen , die Schüler mit Vorträgen , Experimenten und Wettbewerben von der ETH zu überzeugen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['überzeugen'], ['219:229']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Genauso wie den Patienten fehlen den medizinischen Fachleuten echte Anreize , das Dossier zu nutzen .',
#   'opinions': [{'Source': [['Anreize'], ['68:75']],
#     'Target': [['Dossier'], ['82:89']],
#     'Polar_expression': [['nutzen'], ['93:99']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Noch fehlt Vinfast der Mut für etwas richtig Neues .',
#   'opinions': [{'Source': [['Mut'], ['23:26']],
#     'Target': [['Vinfast'], ['11:18']],
#     'Polar_expression': [['fehlt'], ['5:10']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Viele Preise hat Keller für ihre Entdeckungen gewonnen , darunter 2005 den Philip-Morris-Forschungspreis und kürzlich den Europäischen Erfinderpreis .',
#   'opinions': [{'Source': [['Keller'], ['17:23']],
#     'Target': [['Entdeckungen'], ['33:45']],
#     'Polar_expression': [['gewonnen'], ['46:54']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Die US-Justiz will möglichst viele Zeugen für das Strafverfahren gegen Assange gewinnen .',
#   'opinions': [{'Source': [['Justiz'], ['7:13']],
#     'Target': [['Zeugen'], ['35:41']],
#     'Polar_expression': [['gewinnen'], ['79:87']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Am liebsten würde Abascal den nach Unabhängigkeit strebenden Katalanen ihren Autonomiestatut aberkennen und die dortige Landespolizei auflösen .',
#   'opinions': [{'Source': [['Abascal'], ['18:25']],
#     'Target': [['Katalanen'], ['61:70']],
#     'Polar_expression': [['aberkennen'], ['93:103']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Trotzdem warnte Maurer den Ständerat davor , den Bundesrat auf eine « Mission impossible » zu schicken .',
#   'opinions': [{'Source': [['Maurer'], ['16:22']],
#     'Target': [['Ständerat'], ['27:36']],
#     'Polar_expression': [['warnte'], ['9:15']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Der EU-Hintern im SVP-Sujet müsste sich also nicht erheben – sondern abspecken.GIANNA BLUM Mit diesem Kampagnensujet will die SVP die Schweizer von der Begrenzungs-Initiative überzeugen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Begrenzungs'], ['152:163']],
#     'Polar_expression': [['überzeugen'], ['175:185']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Fussball Der FC Basel gewinnt gegen die Young Boys 3 : 0 .',
#   'opinions': [{'Source': [['FC'], ['13:15']],
#     'Target': [[], []],
#     'Polar_expression': [['gewinnt'], ['22:29']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Denn diese Definition könnte dazu führen , dass praktisch alle Fälle von Profiling ein hohes Risiko aufweisen würden .',
#   'opinions': [{'Source': [['Fälle'], ['63:68']],
#     'Target': [['Risiko'], ['93:99']],
#     'Polar_expression': [['aufweisen'], ['100:109']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Und die Fussballer der beiden Stadtklubs hätten schon lange vorher dort gekickt , wo die Brachennutzer heute ihre Pflänzchen zögen .',
#   'opinions': [{'Source': [['Fussballer'], ['8:18']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Seeler zog Heimat und Familie vor .',
#   'opinions': [{'Source': [['Seeler'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['zog'], ['7:10']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Was Russland betrifft , gaben sich Laschet und Scholz kompromissbereit , während Baerbock für ein härteres Vorgehen eintrat .',
#   'opinions': [{'Source': [['Laschet'], ['35:42']],
#     'Target': [['Vorgehen'], ['107:115']],
#     'Polar_expression': [['eintrat'], ['116:123']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Ein Grossteil dieser Beträge diente der Wiedergutmachung an Kunden , die aber nicht immer ausgezahlt werden musste .',
#   'opinions': [{'Source': [['Grossteil'], ['4:13']],
#     'Target': [['Wiedergutmachung'], ['40:56']],
#     'Polar_expression': [['diente'], ['29:35']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Denn die ausgefallenen Klassiker , die Flandernrundfahrt , Gent – Wevelgem und Paris – Roubaix , Sagans wichtigste Rennen im Kalender , finden nun parallel zum Giro und deshalb ohne den Slowenen statt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Gegen Schaffhausen siegen die Basler 3 : 0 , gegen GC verlieren sie 2 : 3.',
#   'opinions': [{'Source': [['Basler'], ['30:36']],
#     'Target': [[], []],
#     'Polar_expression': [['verlieren'], ['54:63']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Offenbar konnten auch die Kirchen mit ihrem ungewöhnlichen Positionsbezug die Landbevölkerung nicht vom Volksbegehren überzeugen .',
#   'opinions': [{'Source': [['Kirchen'], ['26:33']],
#     'Target': [['Volksbegehren'], ['104:117']],
#     'Polar_expression': [['überzeugen'], ['118:128']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'Sullivan hat Jiechi am Montag bei dem Treffen davor gewarnt , Russland zu helfen .',
#   'opinions': [{'Source': [['Sullivan'], ['0:8']],
#     'Target': [['Russland'], ['62:70']],
#     'Polar_expression': [['gewarnt'], ['52:59']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Bereits gestern Nachmittag fand die erste Sitzung des neuen Verwaltungsrats statt – inklusive des unterlegenen Kutter , der die Wahl ins Gremium geschafft hatte .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Bei der Regierungssuche appelliert der Staatspräsident Italiens ein letztes Mal an die Parteien – und sucht wohl schon einen Kundschafter .',
#   'opinions': [{'Source': [['Staatspräsident'], ['39:54']],
#     'Target': [['Parteien'], ['87:95']],
#     'Polar_expression': [['appelliert'], ['24:34']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Erst im August finden die Hearings mit den interessierten Kreisen statt .',
#   'opinions': [{'Source': [['Hearings'], ['26:34']],
#     'Target': [['Kreisen'], ['58:65']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Blöd nur , dass auch die Wiler über einen solchen Super-Joker verfügen .',
#   'opinions': [{'Source': [['Wiler'], ['25:30']],
#     'Target': [['Joker'], ['56:61']],
#     'Polar_expression': [['verfügen'], ['62:70']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Obwohl die Angestellten auf den Flugplätzen von Stockholm und Göteborg Überstunden schoben , schossen die Wartezeiten zeitweise auf bis zu 60 Stunden hoch .',
#   'opinions': [{'Source': [['Wartezeiten'], ['106:117']],
#     'Target': [[], []],
#     'Polar_expression': [['schoben'], ['83:90']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Vor einem Jahr konnte der Genfer Regierungsrat Pierre Maudet viele Parlamentarier von seinen Fähigkeiten überzeugen .',
#   'opinions': [{'Source': [['Regierungsrat'], ['33:46']],
#     'Target': [['Fähigkeiten'], ['93:104']],
#     'Polar_expression': [['überzeugen'], ['105:115']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Nein , den Tieren würden der Stolz und die Kraft fehlen .',
#   'opinions': [{'Source': [['Stolz'], ['29:34']],
#     'Target': [['Tieren'], ['11:17']],
#     'Polar_expression': [['fehlen'], ['49:55']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'Der Mobilfunkbetreiber Sunrise will seine Aktionäre mit einem neuen Vorschlag von der Übernahme des Kabelnetzbetreibers UPC überzeugen .',
#   'opinions': [{'Source': [['Mobilfunkbetreiber'], ['4:22']],
#     'Target': [['Übernahme'], ['86:95']],
#     'Polar_expression': [['überzeugen'], ['124:134']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'Ski alpin Bei der Ski-Weltmeisterschaft im chilenischen Portillo gewann Erika Schinegger 1966 Abfahrtsgold für Österreich .',
#   'opinions': [{'Source': [['Erika'], ['72:77']],
#     'Target': [['Abfahrtsgold'], ['94:106']],
#     'Polar_expression': [['gewann'], ['65:71']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': '2002 und 2016 hatte der heute 73-jährige Jurassier jeweils den Schweizer Filmpreis für den besten Animationsfilm gewonnen .',
#   'opinions': [{'Source': [['Jurassier'], ['41:50']],
#     'Target': [['Filmpreis'], ['73:82']],
#     'Polar_expression': [['gewonnen'], ['113:121']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  ...]

# %%
tokenized_ssa_sents
# Out:
# {'tokens': [['Der',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'soll',
#    'mehrfach',
#    'auf',
#    'die',
#    'Frau',
#    'geschossen',
#    'und',
#    'sich',
#    'dann',
#    'selbst',
#    'gerichtet',
#    'haben',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'Mehrheit',
#    'der',
#    'republikanischen',
#    'wie',
#    'der',
#    'demokratischen',
#    'Senatoren',
#    'und',
#    'Abgeordneten',
#    'ist',
#    'China-kritisch',
#    ',',
#    'und',
#    'das',
#    'Weisse',
#    'Haus',
#    'geniesst',
#    'Unterstützung',
#    ',',
#    'wenn',
#    'es',
#    'Chinas',
#    'Wiederaufstieg',
#    'zur',
#    'Weltmacht',
#    'als',
#    'gefährlichste',
#    'Herausforderung',
#    'des',
#    '2',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>',
#    'Jahrhunderts',
#    'bezeichnet',
#    'und',
#    'seine',
#    'Aussen-',
#    'und',
#    'Sicherheitspolitik',
#    'dementsprechend',
#    'frisch',
#    'fokussiert',
#    '.'],
#   ['Eine',
#    '<eSOURCE>',
#    'Geschichte',
#    '</eSOURCE>',
#    ',',
#    'deutlich',
#    'geprägt',
#    'von',
#    '–',
#    'doch',
#    'nicht',
#    'deckungsgleich',
#    'mit',
#    '–',
#    'der',
#    'Liaison',
#    'zwischen',
#    'Halliday',
#    'und',
#    'dem',
#    'im',
#    'Mai',
#    'dieses',
#    'Jahres',
#    'verstorbenen',
#    'Philip',
#    'Roth',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'ersten',
#    'betroffenen',
#    'Spiele',
#    'finden',
#    'am',
#    'Donnerstag',
#    'statt',
#    ',',
#    'darunter',
#    'die',
#    'Partie',
#    'von',
#    'Chelsea',
#    'bei',
#    'Norwich',
#    'City',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['«',
#    'Die',
#    '<eSOURCE>',
#    'Russen',
#    '</eSOURCE>',
#    'schiessen',
#    'auf',
#    'alles',
#    ',',
#    'auch',
#    'auf',
#    'zivile',
#    'Ziele',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Aber',
#    'viel',
#    'später',
#    ',',
#    'während',
#    'der',
#    'Unruhen',
#    'in',
#    'den',
#    '1970er',
#    'Jahren',
#    ',',
#    '<ePEXP>',
#    'benutzte',
#    '</ePEXP>',
#    'die',
#    'Irish',
#    'Republican',
#    'Army',
#    '(',
#    'IRA',
#    ')',
#    'die',
#    '<eTARGET>',
#    'Ruine',
#    '</eTARGET>',
#    ',',
#    'um',
#    'auf',
#    'britische',
#    'Sicherheitskräfte',
#    'zu',
#    'schiessen',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Wie',
#    'im',
#    'echten',
#    'Fussballbusiness',
#    'hat',
#    'auch',
#    'im',
#    'Game',
#    'der',
#    '<eSOURCE>',
#    'Markt',
#    '</eSOURCE>',
#    'die',
#    'Preise',
#    'in',
#    'die',
#    'Höhe',
#    'schiessen',
#    'lassen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'Schweizer',
#    '<eSOURCE>',
#    'Ratingagentur',
#    '</eSOURCE>',
#    'Independent',
#    'Credit',
#    'View',
#    '<ePEXP>',
#    'warnte',
#    '</ePEXP>',
#    'ihre',
#    '<eTARGET>',
#    'Kunden',
#    '</eTARGET>',
#    'bereits',
#    '2019',
#    'davor',
#    ',',
#    'Papiere',
#    'der',
#    'nun',
#    'zusammengebrochenen',
#    'Greensill-Bank',
#    'zu',
#    'kaufen',
#    '.'],
#   ['Die',
#    'vierte',
#    '<eSOURCE>',
#    'Generation',
#    '</eSOURCE>',
#    'des',
#    'Erfolgsmodells',
#    '<ePEXP>',
#    'überzeugt',
#    '</ePEXP>',
#    'durch',
#    'ausdrucksstarkes',
#    '<eTARGET>',
#    'Design',
#    '</eTARGET>',
#    'und',
#    'vereint',
#    'sportlich-direktes',
#    'Handling',
#    'durch',
#    'die',
#    'variable',
#    'Progressivlenkung',
#    'und',
#    'Toptraktion',
#    'durch',
#    'den',
#    'Quattro-Antrieb',
#    '.'],
#   ['<eSOURCE>',
#    'Zwingli',
#    '</eSOURCE>',
#    'sah',
#    'sich',
#    'schon',
#    '1523',
#    '/',
#    '24',
#    'mit',
#    'einem',
#    '<eTARGET>',
#    'Problem',
#    '</eTARGET>',
#    'vieler',
#    'Revolutionen',
#    '<ePEXP>',
#    'konfrontiert',
#    '</ePEXP>',
#    '–',
#    'mit',
#    '«',
#    'Abweichlern',
#    '»',
#    'in',
#    'den',
#    'eigenen',
#    'Reihen',
#    '.'],
#   ['«',
#    'Inzwischen',
#    'haben',
#    'die',
#    'Lichtemissionen',
#    'und',
#    'die',
#    'Qualität',
#    'des',
#    'Lichts',
#    'mehr',
#    '<eTARGET>',
#    'Gewicht',
#    '</eTARGET>',
#    'gewonnen',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>',
#    '»',
#    'Die',
#    'neuen',
#    'intelligenten',
#    'LED-Leuchten',
#    'lassen',
#    'sich',
#    'wesentlich',
#    'präziser',
#    '<ePEXP>',
#    'einsetzen',
#    '</ePEXP>',
#    'als',
#    'die',
#    'früheren',
#    'Natriumdampflampen',
#    '.'],
#   ['Seither',
#    '<ePEXP>',
#    'haftet',
#    '</ePEXP>',
#    'der',
#    'kalten',
#    '<eTARGET>',
#    'Fusion',
#    '</eTARGET>',
#    'ein',
#    '<eSOURCE>',
#    'Schmuddelimage',
#    '</eSOURCE>',
#    'an',
#    '.'],
#   ['Genau',
#    'eine',
#    'solche',
#    '<eSOURCE>',
#    'Konstellation',
#    '</eSOURCE>',
#    'könne',
#    'im',
#    'Sommer',
#    'eintreten',
#    ',',
#    'wenn',
#    'die',
#    'Covid-19-Impfungen',
#    'im',
#    'grossen',
#    'Stil',
#    '<ePEXP>',
#    'verabreicht',
#    '</ePEXP>',
#    'werden',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Mit',
#    'dieser',
#    'Erfahrung',
#    'konnte',
#    '<eSOURCE>',
#    'Berset',
#    '</eSOURCE>',
#    'den',
#    'Bundesrat',
#    'vom',
#    '<eTARGET>',
#    'Sinn',
#    '</eTARGET>',
#    'schnellen',
#    'Handelns',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Das',
#    'Mitglied',
#    'des',
#    'britischen',
#    'Oberhauses',
#    '<ePEXP>',
#    'warnt',
#    '</ePEXP>',
#    'die',
#    'westlichen',
#    '<eSOURCE>',
#    'Länder',
#    '</eSOURCE>',
#    'auch',
#    'davor',
#    ',',
#    'aus',
#    'wirtschaftlichen',
#    'Ängsten',
#    'vor',
#    'Peking',
#    'zu',
#    'kuschen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Podcasts',
#    'wie',
#    'das',
#    'unaufgeregt',
#    'packende',
#    'Format',
#    '«',
#    'Zeit',
#    'Verbrechen',
#    '»',
#    'der',
#    'grossartigen',
#    'Sabine',
#    'Rückert',
#    'sind',
#    'überaus',
#    'erfolgreich',
#    'sowie',
#    'Fernsehserien',
#    'wie',
#    '«',
#    'Aktenzeichen',
#    'XY',
#    '»',
#    'Evergreens',
#    ';',
#    'und',
#    'namentlich',
#    'bei',
#    'Streamingdiensten',
#    'florieren',
#    '<eSOURCE>',
#    'True',
#    '</eSOURCE>',
#    'Crime-Serien',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Ihre',
#    'Sorgen',
#    'um',
#    'die',
#    'Gefährdung',
#    'ihrer',
#    'Dörfer',
#    ',',
#    'des',
#    'Wassers',
#    'und',
#    'der',
#    'Umwelt',
#    'werden',
#    'von',
#    '<eSOURCE>',
#    'Recon',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'übergangen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Bezos',
#    '</eSOURCE>',
#    'hat',
#    'es',
#    'von',
#    'Anfang',
#    'an',
#    'geschafft',
#    ',',
#    'die',
#    'Investoren',
#    'von',
#    'seiner',
#    '<eTARGET>',
#    'Vision',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    'Bauernvertreter',
#    'äussern',
#    'aber',
#    'Zweifel',
#    ',',
#    'ob',
#    'der',
#    '<eSOURCE>',
#    'Kanton',
#    '</eSOURCE>',
#    'sich',
#    'an',
#    'Abmachungen',
#    'halte',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['«',
#    'Zuerst',
#    'gab',
#    'es',
#    'einen',
#    'Riesenknall',
#    ',',
#    'dann',
#    'hat',
#    'der',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'mit',
#    'einer',
#    'Schrotflinte',
#    'auf',
#    'die',
#    'Tür',
#    'geschossen',
#    '»',
#    ',',
#    'sagte',
#    'ein',
#    'Zeuge',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Der',
#    '<eSOURCE>',
#    'Nidwaldner',
#    '</eSOURCE>',
#    'hatte',
#    'gerade',
#    'sein',
#    'erstes',
#    '<eTARGET>',
#    'Weltcuprennen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    ',',
#    'einen',
#    'Super-G',
#    ',',
#    'etwas',
#    'für',
#    'die',
#    'Erfahrenen',
#    ',',
#    'heisst',
#    'es',
#    ',',
#    'auf',
#    'der',
#    'Birds',
#    'of',
#    'Prey',
#    ',',
#    'der',
#    'Raubvogelpiste',
#    ',',
#    'es',
#    'ist',
#    'eine',
#    'der',
#    'grössten',
#    'Aufgaben',
#    'des',
#    'Winters',
#    '.'],
#   ['Von',
#    'dort',
#    'stieg',
#    'der',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'offenbar',
#    'Treppen',
#    'hinab',
#    'Richtung',
#    'Donaukanal',
#    ',',
#    'schoss',
#    'weiter',
#    'auf',
#    'Passanten',
#    'und',
#    'auf',
#    'einen',
#    'Polizisten',
#    ',',
#    'den',
#    'er',
#    'schwer',
#    'verletzte',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Vor',
#    'einer',
#    'Woche',
#    '<ePEXP>',
#    'warnte',
#    '</ePEXP>',
#    'beispielsweise',
#    'die',
#    '<eSOURCE>',
#    'Führung',
#    '</eSOURCE>',
#    'des',
#    'Zuger',
#    'Schraubenhändlers',
#    'Bossard',
#    'die',
#    'Aktionäre',
#    'davor',
#    ',',
#    'dass',
#    'die',
#    'Situation',
#    'an',
#    'den',
#    'Beschaffungsmärkten',
#    'auch',
#    'in',
#    'der',
#    'zweiten',
#    'Jahreshälfte',
#    'angespannt',
#    'bleiben',
#    'dürfte',
#    'und',
#    'mit',
#    '«',
#    'weiteren',
#    'Preiserhöhungen',
#    'und',
#    'längeren',
#    'Lieferfristen',
#    '»',
#    'zu',
#    'rechnen',
#    'sei',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Parallel',
#    'dazu',
#    'zog',
#    'der',
#    '<eSOURCE>',
#    'Bund',
#    '</eSOURCE>',
#    'eine',
#    'Finanzierung',
#    'für',
#    'Projekte',
#    'auf',
#    ',',
#    'die',
#    'nicht',
#    'mehr',
#    'mit',
#    'Geld',
#    'aus',
#    'Brüssel',
#    'rechnen',
#    'konnten',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'hoffnungsvollen',
#    '<eSOURCE>',
#    'Trump',
#    '</eSOURCE>',
#    'Stürzer',
#    'übersehen',
#    ',',
#    'dass',
#    'es',
#    '–',
#    'abgesehen',
#    'von',
#    'einem',
#    'Rücktritt',
#    '–',
#    'vielleicht',
#    'in',
#    'der',
#    'Theorie',
#    'Wege',
#    'gibt',
#    ',',
#    'einen',
#    'Präsidenten',
#    'loszuwerden',
#    ',',
#    'aber',
#    'kaum',
#    'in',
#    'der',
#    'Praxis',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Vermutlich',
#    'hatte',
#    'aber',
#    'der',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'zuerst',
#    'auf',
#    'die',
#    'Frauen',
#    '<ePEXP>',
#    'geschossen',
#    '</ePEXP>',
#    'und',
#    'sich',
#    'dann',
#    'selber',
#    'gerichtet',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Zwar',
#    'konnte',
#    'der',
#    '<eSOURCE>',
#    'Kabelnetzbetreiber',
#    '</eSOURCE>',
#    'unter',
#    'ihrer',
#    'Ägide',
#    ',',
#    'die',
#    'im',
#    'Herbst',
#    '2018',
#    'begann',
#    ',',
#    'gut',
#    '50',
#    '000',
#    'Neukunden',
#    'für',
#    'sein',
#    '<eTARGET>',
#    'Mobilfunkangebot',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '.'],
#   ['Doch',
#    'die',
#    '<eSOURCE>',
#    'Ansammlung',
#    '</eSOURCE>',
#    'Ausnahmefussballer',
#    'schleppte',
#    'sich',
#    'durch',
#    'die',
#    'Vorrunde',
#    ',',
#    'siegte',
#    'gegen',
#    'Australien',
#    '(',
#    '2',
#    ':',
#    '1',
#    ')',
#    'und',
#    'Peru',
#    '(',
#    '1',
#    ':',
#    '0',
#    ')',
#    'beinahe',
#    'glückhaft',
#    '–',
#    'und',
#    'hinterliess',
#    'auch',
#    'gestern',
#    'phasenweise',
#    'den',
#    'Eindruck',
#    ',',
#    'zufällig',
#    'im',
#    'gleichen',
#    'Trikot',
#    'zu',
#    'stecken',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Tsai',
#    '</eSOURCE>',
#    'hält',
#    'eine',
#    'gewisse',
#    'Distanz',
#    'zu',
#    'Peking',
#    ',',
#    'ohne',
#    'allerdings',
#    'für',
#    'eine',
#    'Unabhängigkeit',
#    'der',
#    'Inselrepublik',
#    'einzutreten',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Humanistisches',
#    'Denken',
#    ',',
#    'wohltätiges',
#    'Wirken',
#    'und',
#    'eine',
#    'starke',
#    'Gemeinschaft',
#    ':',
#    'Diese',
#    '<eSOURCE>',
#    'Werte',
#    '</eSOURCE>',
#    'hätten',
#    'ihn',
#    'von',
#    'den',
#    'Odd',
#    'Fellows',
#    '<ePEXP>',
#    'überzeugt',
#    '</ePEXP>',
#    ',',
#    'als',
#    'er',
#    'vor',
#    'zwölf',
#    'Jahren',
#    'zum',
#    'ersten',
#    'Mal',
#    'eine',
#    'Loge',
#    'besucht',
#    'habe',
#    ',',
#    'erzählt',
#    'Egli',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Luftfahrt',
#    'Der',
#    'renommierte',
#    '<eSOURCE>',
#    'Thinktank',
#    '</eSOURCE>',
#    'ICCT',
#    '<ePEXP>',
#    'warnt',
#    '</ePEXP>',
#    'vor',
#    'den',
#    'geplanten',
#    '<eTARGET>',
#    'Überschallflugzeugen',
#    '</eTARGET>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Pass',
#    '</eSOURCE>',
#    'dazu',
#    'kommt',
#    'von',
#    'Jan',
#    'Kovar',
#    'und',
#    '<ePEXP>',
#    'verdient',
#    '</ePEXP>',
#    'das',
#    '<eTARGET>',
#    'Prädikat',
#    '</eTARGET>',
#    'Weltklasse',
#    '.'],
#   ['Zuvor',
#    'will',
#    '<eSOURCE>',
#    'Labour',
#    '</eSOURCE>',
#    'jedoch',
#    'versuchen',
#    ',',
#    'die',
#    '<eTARGET>',
#    'Regierung',
#    '</eTARGET>',
#    'von',
#    'den',
#    'eigenen',
#    'Brexit-Plänen',
#    'zu',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    'AL',
#    'weist',
#    'darauf',
#    'hin',
#    ',',
#    'dass',
#    'die',
#    '<eSOURCE>',
#    'Wertberichtigung',
#    '</eSOURCE>',
#    'zur',
#    'langfristigen',
#    '<eTARGET>',
#    'Stabilisierung',
#    '</eTARGET>',
#    'des',
#    'Stadtspitals',
#    '<ePEXP>',
#    'beitrage',
#    '</ePEXP>',
#    '.'],
#   ['Weil',
#    'Kohlekraftwerke',
#    'gutes',
#    '<eTARGET>',
#    'Geld',
#    '</eTARGET>',
#    'einbringen',
#    ',',
#    '<ePEXP>',
#    'fehlen',
#    '</ePEXP>',
#    'künftig',
#    'die',
#    'Einnahmen',
#    'bei',
#    'Alpiq',
#    '(',
#    'im',
#    'ersten',
#    'Semester',
#    '24',
#    'Mi',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>',
#    'Fr',
#    '.',
#    ')',
#    '.'],
#   ['<eSOURCE>',
#    'Meteorologen',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'warnten',
#    '</ePEXP>',
#    'vor',
#    '<eTARGET>',
#    'Sturzfluten',
#    '</eTARGET>',
#    '.'],
#   ['Nur',
#    'weil',
#    'der',
#    'EU',
#    'griffige',
#    '<eSOURCE>',
#    'Massnahmen',
#    '</eSOURCE>',
#    'bei',
#    'der',
#    '<eTARGET>',
#    'Terrorbekämpfung',
#    '</eTARGET>',
#    '<ePEXP>',
#    'fehlen',
#    '</ePEXP>',
#    '.'],
#   ['Das',
#    'zuletzt',
#    'schwächelnde',
#    '<eSOURCE>',
#    'Team',
#    '</eSOURCE>',
#    'von',
#    'Domenico',
#    'Tedesco',
#    'siegte',
#    'gegen',
#    'Augsburg',
#    '4',
#    ':',
#    '0',
#    'und',
#    'kletterte',
#    'in',
#    'der',
#    'Tabelle',
#    'auf',
#    'Rang',
#    '4',
#    'und',
#    'hat',
#    'die',
#    'Qualifikation',
#    'für',
#    'die',
#    'Champions',
#    'League',
#    'vor',
#    'dem',
#    'letzten',
#    'Spiel',
#    'bei',
#    'Arminia',
#    'Bielefeld',
#    'nun',
#    'wieder',
#    'selbst',
#    'in',
#    'der',
#    'Hand',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Eine',
#    'gewisse',
#    '<eSOURCE>',
#    'Ursula',
#    '</eSOURCE>',
#    'Koch',
#    'schlich',
#    'sich',
#    'in',
#    'die',
#    'Versammlung',
#    'ein',
#    'und',
#    'versuchte',
#    ',',
#    'die',
#    'Aktivisten',
#    'von',
#    'einem',
#    'SP-Beitritt',
#    'zu',
#    'überzeugen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Auch',
#    'wurde',
#    'das',
#    '<eSOURCE>',
#    'Ziel',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'öffentliche',
#    'Meinung',
#    'im',
#    'Ausland',
#    'zu',
#    'beeinflussen',
#    ',',
#    'in',
#    'einer',
#    'Konzeption',
#    'Russlands',
#    'aus',
#    'dem',
#    'Jahr',
#    '2013',
#    'offiziell',
#    'genannt',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Gerade',
#    'schrieb',
#    'er',
#    'mir',
#    ':',
#    '«',
#    'Die',
#    'erste',
#    'Runde',
#    'ist',
#    'nie',
#    'einfach',
#    '.',
#    '»',
#    '(',
#    '<eSOURCE>',
#    'Bencic',
#    '</eSOURCE>',
#    'hat',
#    'gerade',
#    'gegen',
#    '<eTARGET>',
#    'Andrea',
#    '</eTARGET>',
#    'Petkovic',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    '.'],
#   ['Als',
#    'die',
#    'Bancomaten-Diebe',
#    'flüchteten',
#    ',',
#    'zückten',
#    'die',
#    '<eSOURCE>',
#    'Ordnungshüter',
#    '</eSOURCE>',
#    'ihre',
#    'Pistole',
#    'und',
#    'schossen',
#    'auf',
#    'die',
#    'Männer',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Ein',
#    'bisschen',
#    'näher',
#    'wäre',
#    'ihr',
#    'Sofia',
#    'Goggia',
#    'gekommen',
#    ',',
#    'doch',
#    'die',
#    '<eSOURCE>',
#    'Siegerin',
#    '</eSOURCE>',
#    'der',
#    'beiden',
#    'Abfahrten',
#    'blieb',
#    'vor',
#    'dem',
#    'Zielsprung',
#    'an',
#    'einem',
#    'Tor',
#    'hängen',
#    'und',
#    '<ePEXP>',
#    'verpasste',
#    '</ePEXP>',
#    'das',
#    'nächste',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Der',
#    'Finne',
#    'zeigt',
#    'mit',
#    'Stolz',
#    ',',
#    'was',
#    'die',
#    'von',
#    'ihm',
#    'gegründete',
#    '<eSOURCE>',
#    'Firma',
#    '</eSOURCE>',
#    'Rovio',
#    'Entertainment',
#    '<ePEXP>',
#    'erfunden',
#    '</ePEXP>',
#    'hat',
#    ':',
#    'Das',
#    'Computerspiel',
#    'Angry',
#    'Birds',
#    '(',
#    '«',
#    'zornige',
#    'Vögel',
#    '»',
#    ')',
#    ',',
#    'bei',
#    'dem',
#    'rote',
#    'Vögel',
#    'mit',
#    'Schleudern',
#    'auf',
#    'diebische',
#    'Schweine',
#    'schiessen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Ulf',
#    '</eSOURCE>',
#    'Berg',
#    'wiederum',
#    ',',
#    'seit',
#    '2007',
#    'Verwaltungsratspräsident',
#    'der',
#    'Ems-Chemie',
#    ',',
#    '<ePEXP>',
#    'nennt',
#    '</ePEXP>',
#    'Magdalena',
#    'Martullo',
#    'gerne',
#    '«',
#    'das',
#    'Orakel',
#    'von',
#    'Delphi',
#    '»',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    'Gendarmerie',
#    'habe',
#    'auf',
#    'die',
#    'Reifen',
#    'eines',
#    'verdächtigen',
#    'Fahrzeugs',
#    'geschossen',
#    ',',
#    'nachdem',
#    'der',
#    '<eSOURCE>',
#    'Fahrer',
#    '</eSOURCE>',
#    'die',
#    'Aufforderung',
#    ',',
#    'sofort',
#    'anzuhalten',
#    ',',
#    'ignoriert',
#    'habe',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Bayern',
#    '</eSOURCE>',
#    'zogen',
#    'ihr',
#    '<eTARGET>',
#    'Tempospiel',
#    '</eTARGET>',
#    'auf',
#    ',',
#    'kombinierten',
#    'die',
#    'Moskauer',
#    'schwindelig',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Aber',
#    'was',
#    'soll',
#    '’',
#    's',
#    '–',
#    'es',
#    'sind',
#    'erst',
#    'sieben',
#    'Runden',
#    'gespielt',
#    ',',
#    'die',
#    '<eSOURCE>',
#    'Rangliste',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'wirkt',
#    '</ePEXP>',
#    'chaotisch',
#    ',',
#    'S',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    'Gallen',
#    'hat',
#    'als',
#    'einziges',
#    'Team',
#    'keine',
#    'Partie',
#    'verpasst',
#    ',',
#    'Servette',
#    'und',
#    'Sitten',
#    'spielten',
#    'erst',
#    'vier',
#    'Mal',
#    '.'],
#   ['In',
#    'der',
#    'Anklageschrift',
#    'geht',
#    'die',
#    'Staatsanwaltschaft',
#    'aufs',
#    'Ganze',
#    ',',
#    '<ePEXP>',
#    'klagt',
#    '</ePEXP>',
#    'Vincenz',
#    'und',
#    'Beat',
#    'Stocker',
#    '(',
#    '61',
#    ')',
#    'wegen',
#    'Betruges',
#    'an',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Gleich',
#    'zweimal',
#    'konnte',
#    '<eSOURCE>',
#    'Emmerton',
#    '</eSOURCE>',
#    'nach',
#    'Querpass',
#    'aufs',
#    'offene',
#    'Tor',
#    'schiessen',
#    '–',
#    'beim',
#    'ersten',
#    'Mal',
#    'traf',
#    'er',
#    'das',
#    'Gehäuse',
#    ',',
#    'beim',
#    'zweiten',
#    'Mal',
#    'zum',
#    '1',
#    ':',
#    '0',
#    '(',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    ')',
#    '.'],
#   ['Zum',
#    'Abschluss',
#    'der',
#    'Gruppenphase',
#    'des',
#    'Gold-Cups',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Honduras',
#    '</eSOURCE>',
#    'gegen',
#    'El',
#    'Salvador',
#    '4',
#    ':',
#    '0',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['«',
#    'Männer',
#    'müssen',
#    'den',
#    'Mut',
#    'haben',
#    ',',
#    'zu',
#    'ihrer',
#    'Verletzlichkeit',
#    'zu',
#    'stehen',
#    'und',
#    'Gefühle',
#    'zu',
#    'zeigen',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>',
#    '»',
#    'Wichtig',
#    'für',
#    'sie',
#    ':',
#    '«',
#    'Männer',
#    'und',
#    'Frauen',
#    'sollten',
#    'sich',
#    'auf',
#    'Augenhöhe',
#    'begegnen',
#    'und',
#    'einen',
#    'Schritt',
#    'aufeinander',
#    'zugehen',
#    '.',
#    '»',
#    'Caroline',
#    'Fux',
#    '(',
#    '37',
#    ')',
#    ',',
#    'Psychologin',
#    'und',
#    'Sexberaterin',
#    'bei',
#    'BLICK',
#    ',',
#    'warnte',
#    'vor',
#    'Pauschalisierungen',
#    ':',
#    '«',
#    'Viele',
#    'Männer',
#    'bemühen',
#    'sich',
#    ',',
#    'alles',
#    'richtig',
#    'zu',
#    'machen',
#    '.'],
#   ['Die',
#    'ersten',
#    'drei',
#    'Wochen',
#    'eines',
#    'vierwöchigen',
#    'Trainingsblocks',
#    'werden',
#    'intensiver',
#    'sein',
#    'als',
#    'bisher',
#    ',',
#    'die',
#    'letzte',
#    'Woche',
#    '<ePEXP>',
#    'dient',
#    '</ePEXP>',
#    'der',
#    'aktiven',
#    '<eTARGET>',
#    'Erholung',
#    '</eTARGET>',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Von',
#    '1946',
#    'bis',
#    '1971',
#    'fanden',
#    'im',
#    'Park',
#    'auch',
#    '<eSOURCE>',
#    'Vorführungen',
#    '</eSOURCE>',
#    'im',
#    'Rahmen',
#    'des',
#    'Filmfestivals',
#    'statt',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['«',
#    'In',
#    'den',
#    'entscheidenden',
#    'Momenten',
#    'waren',
#    'sie',
#    'ein',
#    'bisschen',
#    'stärker',
#    '<eSOURCE>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eSOURCE>',
#    '»',
#    'Das',
#    'Ziel',
#    'bleibe',
#    ',',
#    'den',
#    '<eTARGET>',
#    'Fed',
#    '</eTARGET>',
#    'Cup',
#    'einmal',
#    'zu',
#    'gewinnen',
#    '.'],
#   ['Busse',
#    'und',
#    'Barrikaden',
#    '<ePEXP>',
#    'brennen',
#    '</ePEXP>',
#    ',',
#    'Polizisten',
#    'schiessen',
#    'auf',
#    'Demonstranten',
#    ',',
#    'eine',
#    'Katastrophe',
#    'für',
#    'ein',
#    'ohnehin',
#    'gebeuteltes',
#    'Land',
#    ',',
#    'aber',
#    'auch',
#    'ein',
#    'düsteres',
#    'Omen',
#    'für',
#    'die',
#    'ganze',
#    'Region',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Allerdings',
#    '<ePEXP>',
#    'fehlt',
#    '</ePEXP>',
#    'dem',
#    '<eTARGET>',
#    'Land',
#    '</eTARGET>',
#    'ein',
#    'mutiger',
#    '<eSOURCE>',
#    'Reformer',
#    '</eSOURCE>',
#    'wie',
#    'Deng',
#    'Xiaoping',
#    'oder',
#    'der',
#    'einstige',
#    'Regierungschef',
#    'Zhu',
#    'Rongji',
#    ',',
#    'der',
#    'in',
#    'den',
#    'Neunzigern',
#    'den',
#    'schmerzhaften',
#    'Umbau',
#    'der',
#    'Staatsbetriebe',
#    'vorantrieb',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Strafverfolger',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'klagen',
#    '</ePEXP>',
#    'zudem',
#    '<eTARGET>',
#    'Zieglers',
#    'Helfer',
#    '</eTARGET>',
#    'an',
#    ',',
#    'der',
#    'den',
#    'Käufer',
#    'beraten',
#    'hatte',
#    '.'],
#   ['Vor',
#    'einem',
#    'Jahr',
#    'hat',
#    'er',
#    'ja',
#    'schon',
#    'einmal',
#    'in',
#    'Syrien',
#    'bombardieren',
#    'lassen',
#    ',',
#    'nachdem',
#    'die',
#    '<eSOURCE>',
#    'Regierungsarmee',
#    '</eSOURCE>',
#    'mit',
#    'Giftgas',
#    'auf',
#    'Zivilisten',
#    'geschossen',
#    'hatte',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Emirate',
#    '</eSOURCE>',
#    'wiederum',
#    'hoffen',
#    ',',
#    'in',
#    'Damaskus',
#    'an',
#    'Einfluss',
#    'zu',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    'und',
#    'so',
#    'die',
#    '<eTARGET>',
#    'Macht',
#    '</eTARGET>',
#    'Irans',
#    'zu',
#    'schwächen',
#    ',',
#    'mit',
#    'dem',
#    'sie',
#    'in',
#    'der',
#    'Region',
#    'um',
#    'Einfluss',
#    'ringen',
#    '.'],
#   ['<eSOURCE>',
#    'Frau',
#    '</eSOURCE>',
#    'Leuthard',
#    'verkennt',
#    'weiterhin',
#    'die',
#    'Notwendigkeit',
#    ',',
#    'zuverlässige',
#    'und',
#    'stets',
#    'verfügbare',
#    'AKW',
#    'auf',
#    'der',
#    'Basis',
#    'neuster',
#    'Technologie',
#    'zu',
#    'erstellen',
#    ',',
#    'um',
#    'dauerhaft',
#    'zu',
#    'unserer',
#    '<eTARGET>',
#    'Stromversorgung',
#    '</eTARGET>',
#    '<ePEXP>',
#    'beizutragen',
#    '</ePEXP>',
#    '(',
#    'auch',
#    'für',
#    'die',
#    'zunehmende',
#    'Elektromobilität',
#    ')',
#    '.'],
#   ['Fussball',
#    '–',
#    'Die',
#    'Schweizer',
#    'U21',
#    '<eSOURCE>',
#    'Nati',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'siegt',
#    '</ePEXP>',
#    'im',
#    'Test',
#    'gegen',
#    'Irland',
#    '2',
#    ':',
#    '0',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Müller',
#    'und',
#    '99',
#    'weitere',
#    '<eSOURCE>',
#    'Glückliche',
#    '</eSOURCE>',
#    'haben',
#    'eine',
#    '<eTARGET>',
#    'Zypern',
#    '</eTARGET>',
#    'Rundreise',
#    'für',
#    'zwei',
#    'Personen',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    '.'],
#   ['Gleichzeitig',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Walliser',
#    '</eSOURCE>',
#    'die',
#    'kleine',
#    'Kristallkugel',
#    'für',
#    'den',
#    'Gewinn',
#    'des',
#    'Disziplinen-Weltcups',
#    ',',
#    'der',
#    'erstmals',
#    'vergeben',
#    'wurde',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['In',
#    'der',
#    'Meisterschaft',
#    'hat',
#    'das',
#    'Stadion',
#    'dem',
#    '<eTARGET>',
#    'LHC',
#    '</eTARGET>',
#    'mit',
#    'zwei',
#    'Niederlagen',
#    'keine',
#    'Fortune',
#    'gebracht',
#    ',',
#    'doch',
#    'gegen',
#    'Philadelphia',
#    '<ePEXP>',
#    'siegte',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Gastgeber',
#    '</eSOURCE>',
#    '4',
#    ':',
#    '3.'],
#   ['Immerhin',
#    'aber',
#    'finden',
#    'in',
#    'den',
#    'Salons',
#    'und',
#    'Sanatorien',
#    'die',
#    '<eSOURCE>',
#    'Gespräche',
#    '</eSOURCE>',
#    'noch',
#    'statt',
#    '<eTARGET>',
#    '<ePEXP>',
#    '!',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Tini',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'nennt',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Benzodiazepine',
#    '</eTARGET>',
#    'wie',
#    'Xanax',
#    ',',
#    'aber',
#    'auch',
#    'Ecstasy',
#    ',',
#    'Alkohol',
#    'oder',
#    'Cannabis',
#    '.'],
#   ['Im',
#    'Clip',
#    'wird',
#    'dargestellt',
#    ',',
#    'wie',
#    'ein',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'mit',
#    'einer',
#    'automatischen',
#    'Waffe',
#    'auf',
#    '<eTARGET>',
#    'Besucher',
#    '</eTARGET>',
#    'eines',
#    'Tanzclubs',
#    'schiesst',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['«',
#    '<eSOURCE>',
#    'Schwangere',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'mich',
#    'engagieren',
#    ',',
#    'haben',
#    'vielleicht',
#    'bereits',
#    'ein',
#    '<eTARGET>',
#    'Geburtstrauma',
#    '</eTARGET>',
#    '<ePEXP>',
#    'erlitten',
#    '</ePEXP>',
#    'und',
#    'grosse',
#    'Ängste',
#    '»',
#    ',',
#    'sagt',
#    'Brenneisen',
#    '.'],
#   ['Die',
#    'erneute',
#    'Wertberichtigung',
#    'auf',
#    'dem',
#    'Goodwill',
#    'bedeutet',
#    'vereinfacht',
#    'gesagt',
#    ',',
#    'dass',
#    '<eSOURCE>',
#    'Lafarge',
#    '</eSOURCE>',
#    'tendenziell',
#    'mehr',
#    '«',
#    'wacklige',
#    '»',
#    '<eTARGET>',
#    'Vermögenswerte',
#    '</eTARGET>',
#    '<ePEXP>',
#    'eingebracht',
#    '</ePEXP>',
#    'hat',
#    'als',
#    'bisher',
#    'gedacht',
#    '.'],
#   ['<eSOURCE>',
#    'Fachleute',
#    '</eSOURCE>',
#    'attestieren',
#    'ihr',
#    'das',
#    'Talent',
#    ',',
#    'um',
#    'Grand-Slam',
#    '<eTARGET>',
#    'Titel',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '.'],
#   ['«',
#    'Aufgestanden',
#    '<eTARGET>',
#    '<ePEXP>',
#    '!',
#    '</ePEXP>',
#    '</eTARGET>',
#    '»',
#    ',',
#    'ruft',
#    'der',
#    'sportliche',
#    '<eSOURCE>',
#    'Erweckungprediger',
#    '</eSOURCE>',
#    'seinen',
#    'lethargischen',
#    'Patienten',
#    'gleich',
#    'am',
#    'Anfang',
#    'zu',
#    ',',
#    'um',
#    'sie',
#    'mit',
#    'Rezepten',
#    'für',
#    'Besserung',
#    'förmlich',
#    'zu',
#    'überschütten',
#    ':',
#    'Frühaufstehen',
#    ',',
#    'kalte',
#    'Bäder',
#    ',',
#    'weg',
#    'vom',
#    'Ofen',
#    'an',
#    'die',
#    'frische',
#    'Luft',
#    ',',
#    'festes',
#    'Schuhwerk',
#    ',',
#    'ein',
#    'ordentlicher',
#    'Bart',
#    'als',
#    'Schutz',
#    'für',
#    'die',
#    'Kehle',
#    'und',
#    'vor',
#    'allem',
#    'gesunde',
#    'Diät',
#    ',',
#    'denn',
#    '«',
#    'wir',
#    'schaufeln',
#    'uns',
#    'unser',
#    'Grab',
#    'mit',
#    'den',
#    'Zähnen',
#    '»',
#    '.'],
#   ['Gut',
#    '<eSOURCE>',
#    'Behrami',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    'die',
#    'kleine',
#    '<eTARGET>',
#    'Kristallkugel',
#    '</eTARGET>',
#    'für',
#    'die',
#    'saisonbeste',
#    'Super-G-Fahrerin',
#    '2014',
#    'und',
#    '2016',
#    ',',
#    'Suter',
#    'im',
#    'vergangenen',
#    'Winter',
#    '.'],
#   ['Ganz',
#    'nach',
#    'Bersets',
#    'Motto',
#    ':',
#    '«',
#    'Jede',
#    'Impfung',
#    'zählt',
#    '<eTARGET>',
#    '!',
#    '</eTARGET>',
#    '»',
#    'Neben',
#    'den',
#    'gängigen',
#    'Angeboten',
#    'wie',
#    'Spontanimpfungen',
#    'in',
#    'Impfzentren',
#    'oder',
#    'zusätzlichen',
#    'Impfmobilen',
#    'und',
#    'Beratungsmöglichkeiten',
#    'haben',
#    'sich',
#    'manche',
#    '<eSOURCE>',
#    'Kantone',
#    '</eSOURCE>',
#    'weitere',
#    'originelle',
#    'Möglichkeiten',
#    'ausgedacht',
#    ',',
#    'um',
#    'die',
#    'Bevölkerung',
#    'vom',
#    'Piks',
#    'zu',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Nischni',
#    'Nowgorod',
#    '–',
#    'In',
#    'Russland',
#    'hat',
#    'ein',
#    '18',
#    '<eSOURCE>',
#    'Jähriger',
#    '</eSOURCE>',
#    'auf',
#    'Passanten',
#    'geschossen',
#    'und',
#    'dabei',
#    'mindestens',
#    'drei',
#    'Männer',
#    'getötet',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Cannabisproduzenten',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'schiessen',
#    '</ePEXP>',
#    'auf',
#    '<eTARGET>',
#    'Eindringlinge',
#    '</eTARGET>',
#    '.'],
#   ['Bei',
#    'den',
#    '<eTARGET>',
#    'Älteren',
#    '</eTARGET>',
#    '<ePEXP>',
#    'siegte',
#    '</ePEXP>',
#    'hingegen',
#    'die',
#    '<eSOURCE>',
#    'SPD',
#    '</eSOURCE>',
#    'deutlich',
#    '.'],
#   ['Mit',
#    'Lasse',
#    'Sobiech',
#    '<ePEXP>',
#    'verletzte',
#    '</ePEXP>',
#    'sich',
#    'die',
#    '<eSOURCE>',
#    'Stütze',
#    '</eSOURCE>',
#    'in',
#    'der',
#    'Abwehr',
#    'ein',
#    'zweites',
#    'Mal',
#    ',',
#    'die',
#    'Balance',
#    'zwischen',
#    'Mittelfeld',
#    'und',
#    'Sturm',
#    'geriet',
#    'durcheinander',
#    ';',
#    'Blaz',
#    'Kramer',
#    'und',
#    'Assan',
#    'Ceesay',
#    'fehlt',
#    'die',
#    'Qualität',
#    'im',
#    'Sturm',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Steuerfragen',
#    'liegen',
#    'indessen',
#    'in',
#    'der',
#    'Kompetenz',
#    'des',
#    'sozialdemokratischen',
#    'Finanzministers',
#    'Olaf',
#    'Scholz',
#    ',',
#    'den',
#    'der',
#    'CDU-Minster',
#    'Altmaier',
#    'erst',
#    'noch',
#    'für',
#    'seine',
#    'Pläne',
#    'gewinnen',
#    'müsste',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Abstimmung',
#    'Zu',
#    'grosse',
#    'Befugnisse',
#    'für',
#    'Polizei',
#    ':',
#    '<eSOURCE>',
#    'Experten',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'warnen',
#    '</ePEXP>',
#    'vor',
#    'dem',
#    '<eTARGET>',
#    'Antiterrorgesetz',
#    '</eTARGET>',
#    '.'],
#   ['Meistens',
#    '<ePEXP>',
#    'dienen',
#    '</ePEXP>',
#    'ihre',
#    '<eSOURCE>',
#    'Reisen',
#    '</eSOURCE>',
#    'dem',
#    'guten',
#    '<eTARGET>',
#    'Zweck',
#    '</eTARGET>',
#    'und',
#    'stehen',
#    'im',
#    'Zeichen',
#    'des',
#    'karitativen',
#    'Geistes',
#    '.'],
#   ['Laut',
#    'der',
#    'IMF-Chefökonomin',
#    'Gita',
#    'Gopinath',
#    'ist',
#    'es',
#    'einmalig',
#    ',',
#    'dass',
#    'alle',
#    'Weltregionen',
#    'gleichzeitig',
#    'negative',
#    '<eTARGET>',
#    'Wachstumsraten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'aufweisen',
#    '</ePEXP>',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Der',
#    'Flawiler',
#    '<eSOURCE>',
#    'Spezialist',
#    '</eSOURCE>',
#    'für',
#    'industrielle',
#    'Röntgentechnologie',
#    'und',
#    'Hersteller',
#    'von',
#    'Vakuumkondensatoren',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    'vor',
#    'zehn',
#    'Jahren',
#    'für',
#    'seine',
#    'Weiterentwicklung',
#    'den',
#    'Swiss',
#    'Technology',
#    'Award',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Während',
#    'der',
#    'Nati-Vorbereitung',
#    'in',
#    'Bad',
#    'Ragaz',
#    '<ePEXP>',
#    'fehlte',
#    '</ePEXP>',
#    'ein',
#    'prominenter',
#    '<eSOURCE>',
#    'Name',
#    '</eSOURCE>',
#    ':',
#    'Xherdan',
#    'Shaqiri',
#    '(',
#    '30',
#    ')',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Seit',
#    'über',
#    'sechs',
#    'Jahren',
#    'hat',
#    'keine',
#    'europäische',
#    '<eSOURCE>',
#    'Gastmannschaft',
#    '</eSOURCE>',
#    'mehr',
#    'im',
#    'Camp',
#    'Nou',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    ',',
#    'aber',
#    'dem',
#    'BVB',
#    'fehlte',
#    'das',
#    'Selbstvertrauen',
#    'selbst',
#    'für',
#    'einen',
#    '<eTARGET>',
#    'Versuch',
#    '</eTARGET>',
#    '–',
#    'sei',
#    'es',
#    'mit',
#    'Abenteuerlust',
#    ',',
#    'sei',
#    'es',
#    'mit',
#    'taktischer',
#    'Stringenz',
#    ',',
#    'sei',
#    'es',
#    'mit',
#    'purer',
#    'Rebellion',
#    '.'],
#   ['<eSOURCE>',
#    'Intendant',
#    '</eSOURCE>',
#    'Andreas',
#    'Beck',
#    'und',
#    'der',
#    'designierte',
#    'Operndirektor',
#    'Pavel',
#    'B.',
#    'Jiracek',
#    'konnten',
#    'sie',
#    'für',
#    'diese',
#    '<eTARGET>',
#    'Position',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    ',',
#    'welche',
#    'sie',
#    'bis',
#    'zum',
#    'Ende',
#    'der',
#    'Intendanz',
#    'von',
#    'Beck',
#    'am',
#    'Theater',
#    'Basel',
#    'ausüben',
#    'wird',
#    '.'],
#   ['Die',
#    'beiden',
#    '<eSOURCE>',
#    'Initiatoren',
#    '</eSOURCE>',
#    'Giorgio',
#    'Pace',
#    'und',
#    'Nicolas',
#    'Bellavance-Lecompte',
#    'nennen',
#    'ihren',
#    'Event',
#    '«',
#    'The',
#    'Travelling',
#    'Showcase',
#    'for',
#    'Collectable',
#    'Design',
#    '»',
#    ';',
#    'dieses',
#    'neue',
#    'Format',
#    'testeten',
#    'sie',
#    'bereits',
#    'letztes',
#    'Jahr',
#    'in',
#    'einer',
#    'Villa',
#    'in',
#    'Monaco',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Oder',
#    'anders',
#    'ausgedrückt',
#    ':',
#    'Die',
#    '<eSOURCE>',
#    'Staatsanwaltschaft',
#    '</eSOURCE>',
#    'schiesse',
#    'mit',
#    'Kanonen',
#    'auf',
#    'Spatzen',
#    ',',
#    'indem',
#    'sie',
#    'unverhältnismässig',
#    'viele',
#    'Kleinkriminelle',
#    'in',
#    'Untersuchungshaft',
#    'setze',
#    ',',
#    'so',
#    'lautet',
#    'der',
#    'Vorwurf',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Männer',
#    '</eSOURCE>',
#    'mit',
#    'Skip',
#    'Peter',
#    'de',
#    'Cruz',
#    '<ePEXP>',
#    'siegen',
#    '</ePEXP>',
#    'im',
#    'fünften',
#    'Spiel',
#    'erst',
#    'zum',
#    'zweiten',
#    'Mal',
#    '(',
#    '9',
#    ':',
#    '7',
#    'gegen',
#    'Finnland',
#    ')',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['22',
#    '<eSOURCE>',
#    'Eishockeyspiele',
#    '</eSOURCE>',
#    'fanden',
#    'ohne',
#    '<eTARGET>',
#    'Publikum',
#    '</eTARGET>',
#    'statt',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Die',
#    '<eSOURCE>',
#    'Türken',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'sich',
#    'resolut',
#    'gegen',
#    'die',
#    'Einstufung',
#    'der',
#    'Ereignisse',
#    'als',
#    'Völkermord',
#    'wehren',
#    ',',
#    'intervenierten',
#    'auf',
#    'höchster',
#    'Ebene',
#    '–',
#    'und',
#    'hatten',
#    'Erfolg',
#    ':',
#    'Der',
#    'damalige',
#    'Aussenminister',
#    'Didier',
#    'Burkhalter',
#    'warnte',
#    'den',
#    'Genfer',
#    'Regierungsrat',
#    'in',
#    'einem',
#    'Brief',
#    'eindringlich',
#    'davor',
#    ',',
#    'die',
#    'Baubewilligung',
#    'zu',
#    'erteilen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Nachdem',
#    'diese',
#    'Raketen',
#    'auf',
#    'die',
#    'Hauptstadt',
#    'Eritreas',
#    'geschossen',
#    'haben',
#    ',',
#    'könnte',
#    'der',
#    '<eSOURCE>',
#    'Konflikt',
#    '</eSOURCE>',
#    'das',
#    'ganze',
#    '<eTARGET>',
#    'Horn',
#    '</eTARGET>',
#    'von',
#    'Afrika',
#    '<ePEXP>',
#    'destabilisieren',
#    '</ePEXP>',
#    '.'],
#   ['Nach',
#    'Maos',
#    'Tod',
#    '<ePEXP>',
#    'schossen',
#    '</ePEXP>',
#    'seine',
#    '<eSOURCE>',
#    'Nachfolger',
#    '</eSOURCE>',
#    '1989',
#    'auf',
#    'das',
#    'eigene',
#    '<eTARGET>',
#    'Volk',
#    '</eTARGET>',
#    '.'],
#   ['Dann',
#    'zog',
#    'eine',
#    'riesige',
#    '<eSOURCE>',
#    'Staubwolke',
#    '</eSOURCE>',
#    'durchs',
#    '<eTARGET>',
#    'Tal',
#    '</eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Und',
#    'dazu',
#    'der',
#    'letzte',
#    'Vergleich',
#    ':',
#    'Der',
#    'Deutsche',
#    'brachte',
#    '72',
#    'Erfolge',
#    'nach',
#    'Maranello',
#    '–',
#    'der',
#    '<eSOURCE>',
#    'Brite',
#    '</eSOURCE>',
#    'gewann',
#    'bisher',
#    '69',
#    'Mal',
#    'für',
#    'Mercedes',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Das',
#    'meiste',
#    '<eSOURCE>',
#    'Geld',
#    '</eSOURCE>',
#    'fliesst',
#    'in',
#    'Marketing',
#    ',',
#    'um',
#    'neue',
#    'zahlende',
#    '<eTARGET>',
#    'Kunden',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '.'],
#   ['Lange',
#    'Zeit',
#    'hätten',
#    'tamilische',
#    '<eSOURCE>',
#    'Politiker',
#    '</eSOURCE>',
#    'versucht',
#    ',',
#    'die',
#    'muslimischen',
#    '<eTARGET>',
#    'Gemeinschaften',
#    '</eTARGET>',
#    'für',
#    'die',
#    '«',
#    'Sache',
#    'der',
#    'Tamilischsprechenden',
#    '»',
#    'zu',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    ',',
#    'sagt',
#    'Benedikt',
#    'Korf',
#    ',',
#    'Professor',
#    'für',
#    'politische',
#    'Geografie',
#    'an',
#    'der',
#    'Universität',
#    'Zürich',
#    '.'],
#   ['Im',
#    'August',
#    'findet',
#    'die',
#    'Übergabe',
#    'an',
#    'die',
#    'Polizei',
#    'statt',
#    ',',
#    'die',
#    'danach',
#    'ihr',
#    'Provisorium',
#    'im',
#    'Tiefenbrunnen',
#    'verlassen',
#    'und',
#    'den',
#    'Neubau',
#    'in',
#    'Betrieb',
#    'nehmen',
#    'kann',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Mit',
#    'einer',
#    '9-mm-Pistole',
#    'schoss',
#    '<eSOURCE>',
#    'Nasim',
#    '</eSOURCE>',
#    'Aghdam',
#    'auf',
#    'drei',
#    'Angestellte',
#    ',',
#    'dann',
#    'nahm',
#    'sie',
#    'sich',
#    'selbst',
#    'das',
#    'Leben',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['«',
#    'Die',
#    '<eSOURCE>',
#    'Frau',
#    '</eSOURCE>',
#    'zog',
#    'die',
#    'Tiere',
#    'auf',
#    'und',
#    'hatte',
#    'eine',
#    'enge',
#    'Beziehung',
#    'zu',
#    'ihnen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Weil',
#    'die',
#    'Schweizer',
#    'Delegation',
#    'über',
#    'eigene',
#    'Messdaten',
#    'verfügt',
#    '(',
#    'siehe',
#    'Haupttext',
#    ')',
#    ',',
#    '<ePEXP>',
#    'arbeitet',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Servicecrew',
#    '</eSOURCE>',
#    'von',
#    'Dario',
#    'Cologna',
#    'und',
#    'Kollegen',
#    'mit',
#    '<eTARGET>',
#    'Exklusivinformationen',
#    '</eTARGET>',
#    '.'],
#   ['Natürlich',
#    'würde',
#    'auch',
#    '<eSOURCE>',
#    'Liverpool',
#    '</eSOURCE>',
#    'gern',
#    'die',
#    '<eTARGET>',
#    'Champions',
#    '</eTARGET>',
#    'League',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '.'],
#   ['Kein',
#    '<eSOURCE>',
#    'Gegner',
#    '</eSOURCE>',
#    'findet',
#    'Mittel',
#    ',',
#    'um',
#    'dem',
#    '<eTARGET>',
#    'Mallorquiner',
#    '</eTARGET>',
#    'die',
#    '«',
#    'Coupe',
#    'des',
#    'Mousquetaires',
#    '»',
#    'streitig',
#    'zu',
#    'machen',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Vor',
#    'allem',
#    'die',
#    '<eSOURCE>',
#    'Version',
#    '</eSOURCE>',
#    'einer',
#    'Win-win-Situation',
#    'darf',
#    'bei',
#    'chinesischen',
#    '<eTARGET>',
#    'Vorträgen',
#    '</eTARGET>',
#    'nicht',
#    'fehlen',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['<eSOURCE>',
#    'Söder',
#    '</eSOURCE>',
#    'hat',
#    'für',
#    'die',
#    'kommende',
#    'Woche',
#    'einen',
#    'runden',
#    'Tisch',
#    'einberufen',
#    ',',
#    'um',
#    'eine',
#    'parteienübergreifende',
#    'Lösung',
#    'zu',
#    'finden',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Staatsanwaltschaft',
#    '</eSOURCE>',
#    'von',
#    'New',
#    'York',
#    '<ePEXP>',
#    'klagte',
#    '</ePEXP>',
#    'den',
#    '29',
#    'Jahre',
#    'alten',
#    '<eTARGET>',
#    'Mann',
#    '</eTARGET>',
#    'am',
#    'Montag',
#    'an',
#    ',',
#    '2016',
#    'eine',
#    'Fülle',
#    'von',
#    'geheimem',
#    'Material',
#    'gestohlen',
#    'und',
#    'dann',
#    'der',
#    'Enthüllungsplattform',
#    'Wikileaks',
#    'zugespielt',
#    'zu',
#    'haben',
#    '.'],
#   ['An',
#    'seiner',
#    'Stelle',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    'sein',
#    'früherer',
#    '<eSOURCE>',
#    'Vizepräsident',
#    '</eSOURCE>',
#    'Lenín',
#    'Moreno',
#    'die',
#    '<eTARGET>',
#    'Wahl',
#    '</eTARGET>',
#    'für',
#    'die',
#    'Regierungspartei',
#    '.'],
#   ['So',
#    '<ePEXP>',
#    'wirkt',
#    '</ePEXP>',
#    'der',
#    'kuriose',
#    '<eSOURCE>',
#    'Turniersieg',
#    '</eSOURCE>',
#    'in',
#    'Schweden',
#    ',',
#    'nunmehr',
#    'unter',
#    'dem',
#    'Coach',
#    'Richard',
#    'Møller',
#    'Nielsen',
#    ',',
#    'wie',
#    'eine',
#    'besondere',
#    'Pointe',
#    ':',
#    'Michael',
#    'Laudrup',
#    ',',
#    'inzwischen',
#    'in',
#    'Barcelona',
#    ',',
#    'zog',
#    'die',
#    'Sommerferien',
#    'der',
#    'Turnierteilnahme',
#    'auch',
#    'wegen',
#    'eines',
#    'Konflikts',
#    'mit',
#    'Møller',
#    'Nielsen',
#    'vor',
#    ',',
#    'zumal',
#    'er',
#    'sich',
#    'nach',
#    'dem',
#    'Gewinn',
#    'des',
#    'Europacups',
#    'der',
#    'Landesmeister',
#    'mit',
#    'Barça',
#    'erschöpft',
#    'wähnte',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Der',
#    '<eSOURCE>',
#    'Banker',
#    '</eSOURCE>',
#    'machte',
#    'sich',
#    'selbständig',
#    ',',
#    'zog',
#    'in',
#    'Singapur',
#    'einen',
#    'Whiskyhandel',
#    'auf',
#    ',',
#    'bevor',
#    'er',
#    'sieben',
#    'Jahre',
#    'später',
#    'in',
#    'die',
#    'Schweiz',
#    'zurückkehrte',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Über',
#    'dem',
#    'Golf',
#    'schiesst',
#    'ein',
#    'US',
#    '<eSOURCE>',
#    'Kriegsschiff',
#    '</eSOURCE>',
#    'ein',
#    'iranisches',
#    '<eTARGET>',
#    'Linienflugzeug',
#    '</eTARGET>',
#    'ab',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Vor',
#    'drei',
#    'Jahren',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Pawlikowski',
#    '</eSOURCE>',
#    'für',
#    '«',
#    'Ida',
#    '»',
#    ',',
#    'die',
#    'Geschichte',
#    'einer',
#    'Nonne',
#    'im',
#    'Polen',
#    'der',
#    'sechziger',
#    'Jahre',
#    ',',
#    'neben',
#    'zahlreichen',
#    'anderen',
#    'Preisen',
#    'den',
#    'Oscar',
#    'für',
#    'den',
#    'besten',
#    'fremdsprachigen',
#    'Film',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Djibril',
#    'Diani',
#    '(',
#    '21',
#    ')',
#    'und',
#    'Morandi',
#    '(',
#    '20',
#    ')',
#    'vor',
#    'ihm',
#    'fehlt',
#    'in',
#    'den',
#    'entscheidenden',
#    'Momenten',
#    'oft',
#    'die',
#    'nötige',
#    '<eSOURCE>',
#    'Ruhe',
#    '</eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Diese',
#    '<eSOURCE>',
#    'Sicherheit',
#    '</eSOURCE>',
#    'fehlt',
#    'den',
#    '<eTARGET>',
#    'Österreichern',
#    '</eTARGET>',
#    'im',
#    'Wettkampf',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '»',
#    'Allzu',
#    'früh',
#    'sollten',
#    'wir',
#    'Schweizer',
#    'uns',
#    'aber',
#    'nicht',
#    'über',
#    'die',
#    'Probleme',
#    'unserer',
#    'Erz-Rivalen',
#    'freuen',
#    '.'],
#   ['Der',
#    'Liga',
#    '<eSOURCE>',
#    'Topskorer',
#    '</eSOURCE>',
#    'schiesst',
#    'den',
#    'starken',
#    '<eTARGET>',
#    'FCZ',
#    '</eTARGET>',
#    'im',
#    'Alleingang',
#    'ab',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Schon',
#    'vor',
#    'dem',
#    'Spiel',
#    'um',
#    '0',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '0',
#    'Uhr',
#    'Schweizer',
#    'Zeit',
#    'in',
#    'der',
#    'Nacht',
#    'von',
#    'Samstag',
#    'auf',
#    'Sonntag',
#    'zogen',
#    'dunkle',
#    '<eSOURCE>',
#    'Wolken',
#    '</eSOURCE>',
#    'über',
#    'dem',
#    'Lambeau',
#    'Field',
#    'auf',
#    ',',
#    'das',
#    'Spiel',
#    'wurde',
#    'zunächst',
#    'mit',
#    '15',
#    'Minuten',
#    'Verspätung',
#    'angepfiffen',
#    'und',
#    'musste',
#    'nach',
#    'dem',
#    'Haaland-Treffer',
#    'ein',
#    'weiteres',
#    'Mal',
#    'für',
#    'rund',
#    '60',
#    'Minuten',
#    'unterbrochen',
#    'werden',
#    '.'],
#   ['MARCO',
#    'GARCIA',
#    ',',
#    'BUBIKON',
#    'ZH',
#    'Diesen',
#    '<eTARGET>',
#    'Jugendlichen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'fehlt',
#    '</ePEXP>',
#    'die',
#    'führende',
#    '<eSOURCE>',
#    'Hand',
#    '</eSOURCE>',
#    'der',
#    'Eltern',
#    'und',
#    'des',
#    'Staats',
#    '.'],
#   ['Nach',
#    'Aussage',
#    'der',
#    'israelischen',
#    'Armee',
#    'haben',
#    'die',
#    '<eSOURCE>',
#    'Soldaten',
#    '</eSOURCE>',
#    'gezielt',
#    'auf',
#    '<eTARGET>',
#    'Rädelsführer',
#    '</eTARGET>',
#    '<ePEXP>',
#    'geschossen',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Traugott',
#    '</eSOURCE>',
#    'Vöhringer',
#    'ist',
#    'erstaunt',
#    ',',
#    'dass',
#    'das',
#    'Projekt',
#    'so',
#    'grossen',
#    'Anklang',
#    'fand',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Fussball',
#    '–',
#    '<eSOURCE>',
#    'Liverpool',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'siegt',
#    '</ePEXP>',
#    'gegen',
#    'CF',
#    'Monterrey',
#    '2',
#    ':',
#    '1',
#    '(',
#    'mit',
#    'Shaqiri',
#    'bis',
#    'zur',
#    '6',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Von',
#    'einer',
#    'Hochhaus-Baustelle',
#    'hätten',
#    '<eSOURCE>',
#    'Scharfschützen',
#    '</eSOURCE>',
#    'auf',
#    'die',
#    '<eTARGET>',
#    'Protestierenden',
#    '</eTARGET>',
#    '<ePEXP>',
#    'geschossen',
#    '</ePEXP>',
#    ',',
#    'erzählen',
#    'viele',
#    '.'],
#   ['Mit',
#    'einer',
#    'eigenen',
#    'Website',
#    ',',
#    'Broschüren',
#    'und',
#    'Roadshows',
#    'versucht',
#    'das',
#    '<eSOURCE>',
#    'Bundesamt',
#    '</eSOURCE>',
#    'für',
#    'Energie',
#    '(',
#    'BFE',
#    ')',
#    'seit',
#    '2015',
#    ',',
#    'Autokäufer',
#    'für',
#    'klimaschonendere',
#    'Fahrzeuge',
#    'zu',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '–',
#    'weitgehend',
#    'erfolglos',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Daraufhin',
#    'schoss',
#    'die',
#    '<eSOURCE>',
#    'Armee',
#    '</eSOURCE>',
#    'ohne',
#    'Vorwarnung',
#    'in',
#    'die',
#    'Menge',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Der',
#    '<eSOURCE>',
#    'Freiburger',
#    '</eSOURCE>',
#    'hat',
#    'sich',
#    'zur',
#    'valablen',
#    'Alternative',
#    'zu',
#    'Flüeler',
#    'entwickelt',
#    ',',
#    'gewann',
#    'seine',
#    'ersten',
#    'fünf',
#    'Starts',
#    'und',
#    '11',
#    'von',
#    '16',
#    'Spielen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Cavusoglu',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'warnte',
#    '</ePEXP>',
#    'die',
#    '<eTARGET>',
#    'USA',
#    '</eTARGET>',
#    'auch',
#    'davor',
#    ',',
#    'die',
#    'Türkei',
#    'vor',
#    'die',
#    'Wahl',
#    'zu',
#    'stellen',
#    ',',
#    'entweder',
#    'gute',
#    'Beziehungen',
#    'zu',
#    'Russland',
#    'oder',
#    'zu',
#    'den',
#    'USA',
#    'zu',
#    'haben',
#    '.'],
#   ['In',
#    'einem',
#    'anderen',
#    'Fall',
#    ',',
#    'bei',
#    'dem',
#    'um',
#    'einen',
#    'vergleichsweise',
#    'geringen',
#    'Betrag',
#    'gestritten',
#    'wurde',
#    ',',
#    'hat',
#    '<eSOURCE>',
#    'Implenia',
#    '</eSOURCE>',
#    'am',
#    'Ende',
#    'gegen',
#    'die',
#    '<eTARGET>',
#    'Stadt',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    '.'],
#   ['Über',
#    'eine',
#    'mit',
#    'dem',
#    'Westen',
#    'vergleichbare',
#    '<eTARGET>',
#    'Kaufkraft',
#    '</eTARGET>',
#    '<ePEXP>',
#    'verfügt',
#    '</ePEXP>',
#    'in',
#    'Indien',
#    'weiterhin',
#    'nur',
#    'ein',
#    'Bruchteil',
#    'der',
#    'Bevölkerung',
#    ';',
#    'bereits',
#    'ab',
#    'einem',
#    'Einkommen',
#    'von',
#    '10',
#    '$',
#    'pro',
#    'Tag',
#    'zählt',
#    'man',
#    'hier',
#    'zur',
#    'Mittelschicht',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['<eSOURCE>',
#    'Brüssel',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'warnt',
#    '</ePEXP>',
#    'aber',
#    'gleichzeitig',
#    'vor',
#    'zu',
#    'hohen',
#    '<eTARGET>',
#    'Erwartungen',
#    '</eTARGET>',
#    '.'],
#   ['Das',
#    'eindrückliche',
#    'Abschneiden',
#    'der',
#    'Sika-Gruppe',
#    'an',
#    'der',
#    'Börse',
#    'war',
#    'indes',
#    'auch',
#    'die',
#    'zentrale',
#    'Voraussetzung',
#    'dafür',
#    ',',
#    'dass',
#    'die',
#    '<eSOURCE>',
#    'Streithähne',
#    '</eSOURCE>',
#    'nun',
#    'doch',
#    'noch',
#    'eine',
#    'einvernehmlichen',
#    'Lösung',
#    'gefunden',
#    'haben',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['«',
#    'Das',
#    'Feuer',
#    'ist',
#    'hier',
#    'für',
#    'den',
#    'Täter',
#    'kein',
#    'Mittel',
#    'zum',
#    'Zweck',
#    ',',
#    'sondern',
#    'dient',
#    'bloss',
#    'der',
#    'eigenen',
#    '<eTARGET>',
#    'Befriedigung',
#    '</eTARGET>',
#    '<eSOURCE>',
# ...
#    'wegen',
#    'versuchten',
#    'Mordes',
#    'an',
#    ',',
#    'den',
#    'Bruder',
#    'wegen',
#    'versuchter',
#    'Tötung',
#    '.'],
#   ['Noch',
#    '2016',
#    'hatte',
#    'Graham',
#    'das',
#    '<eSOURCE>',
#    'Justizministerium',
#    '</eSOURCE>',
#    'unter',
#    'Präsident',
#    'Barack',
#    'Obama',
#    'davor',
#    '<ePEXP>',
#    'gewarnt',
#    '</ePEXP>',
#    ',',
#    'Apple',
#    'dazu',
#    'zu',
#    'zwingen',
#    ',',
#    'das',
#    'Handy',
#    'des',
#    'Terroristen',
#    'zu',
#    'entsperren',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['EU-Binnenmarkt-Kommissar',
#    'Thierry',
#    'Breton',
#    'sagte',
#    'am',
#    'Montag',
#    ',',
#    'er',
#    'sei',
#    '«',
#    'perplex',
#    '»',
#    'darüber',
#    ',',
#    'dass',
#    'die',
#    'Online',
#    '<eSOURCE>',
#    'Plattformen',
#    '</eSOURCE>',
#    'Trump',
#    'den',
#    'Stecker',
#    'gezogen',
#    'hätten',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Ein',
#    '<eSOURCE>',
#    'Beamter',
#    '</eSOURCE>',
#    'zieht',
#    'schliesslich',
#    'die',
#    'Waffe',
#    'und',
#    'schiesst',
#    'auf',
#    'den',
#    'irren',
#    'Angreifer',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Den',
#    '<eTARGET>',
#    'Fans',
#    '</eTARGET>',
#    'ihrerseits',
#    'fehlten',
#    'mit',
#    'den',
#    'traditionellen',
#    'Tonträgern',
#    'plötzlich',
#    'die',
#    'kultischen',
#    '<eSOURCE>',
#    'Objekte',
#    '</eSOURCE>',
#    'ihrer',
#    'Passion',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Im',
#    'Kanton',
#    'Waadt',
#    '<ePEXP>',
#    'warnte',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Polizei',
#    '</eSOURCE>',
#    'Wanderer',
#    'davor',
#    ',',
#    'in',
#    'schneebedeckte',
#    'Wälder',
#    'zu',
#    'gehen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Aktivisten',
#    'dementierten',
#    'dies',
#    ',',
#    'allerdings',
#    'gab',
#    'es',
#    'in',
#    'der',
#    'Vergangenheit',
#    'mehrfach',
#    'Vorfälle',
#    ',',
#    'in',
#    'denen',
#    '<eSOURCE>',
#    'Rebellen',
#    '</eSOURCE>',
#    'auf',
#    'Zivilisten',
#    'schossen',
#    ',',
#    'um',
#    'sie',
#    'an',
#    'der',
#    'Flucht',
#    'zu',
#    'hindern',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Für',
#    'seine',
#    'Rolle',
#    'als',
#    'Hannibal',
#    'Lecter',
#    'in',
#    '«',
#    'Das',
#    'Schweigen',
#    'der',
#    'Lämmer',
#    '»',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Hopkins',
#    '</eSOURCE>',
#    'seinen',
#    'ersten',
#    '<eTARGET>',
#    'Oscar',
#    '</eTARGET>',
#    'als',
#    'bester',
#    'Schauspieler',
#    '.'],
#   ['Luna',
#    'Rossa',
#    'hat',
#    'das',
#    '<eTARGET>',
#    'Rendez',
#    '</eTARGET>',
#    'vous',
#    'mit',
#    'der',
#    'Geschichte',
#    'souverän',
#    '<ePEXP>',
#    'bestanden',
#    '</ePEXP>',
#    ':',
#    'Genau',
#    '21',
#    'Jahre',
#    'nach',
#    'dem',
#    'Sieg',
#    'im',
#    'Final',
#    'der',
#    'Herausforderer',
#    'in',
#    'Auckland',
#    'gewannen',
#    'die',
#    '<eSOURCE>',
#    'Italiener',
#    '</eSOURCE>',
#    'an',
#    'gleicher',
#    'Stätte',
#    'erneut',
#    'den',
#    'Pokal',
#    'für',
#    'den',
#    'besten',
#    'Challenger',
#    '.'],
#   ['Im',
#    'Tiebreak',
#    'müssen',
#    'Hüberli',
#    '/',
#    'Betschart',
#    'die',
#    'letztjährigen',
#    'Gstaad-Siegerinnen',
#    'etwas',
#    'ziehen',
#    'lassen',
#    ',',
#    'kämpfen',
#    'aber',
#    'heroisch',
#    '–',
#    'und',
#    '<ePEXP>',
#    'wehren',
#    '</ePEXP>',
#    'sechs',
#    'Matchbälle',
#    'ab',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '!',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Die',
#    '<eSOURCE>',
#    'Kandidatur',
#    '</eSOURCE>',
#    'hat',
#    'einen',
#    'sehr',
#    'guten',
#    '<eTARGET>',
#    'Ansatz',
#    '</eTARGET>',
#    '<ePEXP>',
#    'eingebracht',
#    '</ePEXP>',
#    '.'],
#   ['Russische',
#    '<eSOURCE>',
#    'Panzer',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'schiessen',
#    '</ePEXP>',
#    'auf',
#    '<eTARGET>',
#    'Zivilisten',
#    '</eTARGET>',
#    '.'],
#   ['Dabei',
#    'klagt',
#    'die',
#    'Regierungsbeauftragte',
#    'auch',
#    'eine',
#    'Kultur',
#    'des',
#    'Machismus',
#    'in',
#    'der',
#    'spanischen',
#    'Gesellschaft',
#    'an',
#    ':',
#    '«',
#    'Unter',
#    'der',
#    'Covid-19-Pandemie',
#    'versteckte',
#    'sich',
#    'eine',
#    'andere',
#    'Pandemie',
#    ',',
#    'nämlich',
#    'die',
#    'des',
#    'Machismus',
#    ',',
#    'der',
#    'jetzt',
#    'wieder',
#    'zutage',
#    'tritt',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>',
#    '»',
#    'Davon',
#    'bleibt',
#    'keine',
#    'Altersgruppe',
#    'verschont',
#    '.'],
#   ['Dann',
#    '<ePEXP>',
#    'überzeugte',
#    '</ePEXP>',
#    'der',
#    'ehemalige',
#    'IIHF',
#    '<eSOURCE>',
#    'Präsident',
#    '</eSOURCE>',
#    'René',
#    'Fasel',
#    'den',
#    '<eTARGET>',
#    'NHL',
#    '</eTARGET>',
#    'Commissioner',
#    'Gary',
#    'Bettman',
#    'von',
#    'der',
#    'Werbewirksamkeit',
#    'der',
#    'olympischen',
#    'Bühne',
#    '.'],
#   ['Auch',
#    'dort',
#    'fehle',
#    '<eSOURCE>',
#    'Frauen',
#    '</eSOURCE>',
#    'oft',
#    'noch',
#    'der',
#    'Mut',
#    ',',
#    'den',
#    'Mund',
#    '<ePEXP>',
#    'aufzumachen',
#    '</ePEXP>',
#    'und',
#    'sich',
#    'zu',
#    'wehren',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Rilke',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'überging',
#    '</ePEXP>',
#    'den',
#    '<eTARGET>',
#    'Tod',
#    '</eTARGET>',
#    'der',
#    'Freundin',
#    'mit',
#    'Schweigen',
#    '.'],
#   ['Daniel',
#    'Betschart',
#    '(',
#    '32',
#    ')',
#    ',',
#    'Medienexperte',
#    'bei',
#    'der',
#    'Stiftung',
#    'Pro',
#    'Juventute',
#    ',',
#    'warnt',
#    'vor',
#    'der',
#    'gekauften',
#    'Gefälligkeit',
#    ':',
#    '«',
#    'Speziell',
#    '<eSOURCE>',
#    'Minderjährige',
#    '</eSOURCE>',
#    'lassen',
#    'sich',
#    'von',
#    'der',
#    'Aufmerksamkeit',
#    'ihrer',
#    'Idole',
#    'rasch',
#    'blenden',
#    'und',
#    'verteilen',
#    'die',
#    'Gifts',
#    ',',
#    'ohne',
#    'an',
#    'die',
#    'Kosten',
#    'zu',
#    'denken',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '»',
#    'Er',
#    'rät',
#    ':',
#    '«',
#    'Um',
#    'nicht',
#    'in',
#    'die',
#    'Kostenfalle',
#    'zu',
#    'tappen',
#    ',',
#    'deaktiviert',
#    'man',
#    'am',
#    'besten',
#    'die',
#    'In-App-Käufe',
#    '.',
#    '»',
#    'Weil',
#    'schon',
#    '13-jährige',
#    'Hunderte',
#    'von',
#    'Franken',
#    'an',
#    'ihre',
#    'Stars',
#    'verschenkten',
#    ',',
#    'erhöhte',
#    'Tiktok',
#    'die',
#    'Altersbeschränkung',
#    'für',
#    'diese',
#    'Funktion',
#    'auf',
#    '18',
#    'Jahre',
#    '.'],
#   ['<eSOURCE>',
#    'Mélenchon',
#    '</eSOURCE>',
#    'hat',
#    'versucht',
#    ',',
#    'den',
#    '<eTARGET>',
#    'Rest',
#    '</eTARGET>',
#    'der',
#    'linken',
#    'Parteienlandschaft',
#    'für',
#    'eine',
#    'Allianz',
#    'zu',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Mueller',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'klagte',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Manafort',
#    '</eTARGET>',
#    'trotzdem',
#    'an',
#    '.'],
#   ['Sie',
#    'bietet',
#    'Studienwochen',
#    'für',
#    'Hochbegabte',
#    'an',
#    ',',
#    'und',
#    'im',
#    'Projekt',
#    '«',
#    'ETH',
#    'unterwegs',
#    '»',
#    'besuchen',
#    'ETH-Professoren',
#    'und',
#    'Studierende',
#    'Gymnasien',
#    'und',
#    'versuchen',
#    ',',
#    'die',
#    'Schüler',
#    'mit',
#    'Vorträgen',
#    ',',
#    'Experimenten',
#    'und',
#    'Wettbewerben',
#    'von',
#    'der',
#    'ETH',
#    'zu',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Genauso',
#    'wie',
#    'den',
#    'Patienten',
#    'fehlen',
#    'den',
#    'medizinischen',
#    'Fachleuten',
#    'echte',
#    '<eSOURCE>',
#    'Anreize',
#    '</eSOURCE>',
#    ',',
#    'das',
#    '<eTARGET>',
#    'Dossier',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'nutzen',
#    '</ePEXP>',
#    '.'],
#   ['Noch',
#    '<ePEXP>',
#    'fehlt',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Vinfast',
#    '</eTARGET>',
#    'der',
#    '<eSOURCE>',
#    'Mut',
#    '</eSOURCE>',
#    'für',
#    'etwas',
#    'richtig',
#    'Neues',
#    '.'],
#   ['Viele',
#    'Preise',
#    'hat',
#    '<eSOURCE>',
#    'Keller',
#    '</eSOURCE>',
#    'für',
#    'ihre',
#    '<eTARGET>',
#    'Entdeckungen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    ',',
#    'darunter',
#    '2005',
#    'den',
#    'Philip-Morris-Forschungspreis',
#    'und',
#    'kürzlich',
#    'den',
#    'Europäischen',
#    'Erfinderpreis',
#    '.'],
#   ['Die',
#    'US',
#    '<eSOURCE>',
#    'Justiz',
#    '</eSOURCE>',
#    'will',
#    'möglichst',
#    'viele',
#    '<eTARGET>',
#    'Zeugen',
#    '</eTARGET>',
#    'für',
#    'das',
#    'Strafverfahren',
#    'gegen',
#    'Assange',
#    '<ePEXP>',
#    'gewinnen',
#    '</ePEXP>',
#    '.'],
#   ['Am',
#    'liebsten',
#    'würde',
#    '<eSOURCE>',
#    'Abascal',
#    '</eSOURCE>',
#    'den',
#    'nach',
#    'Unabhängigkeit',
#    'strebenden',
#    '<eTARGET>',
#    'Katalanen',
#    '</eTARGET>',
#    'ihren',
#    'Autonomiestatut',
#    '<ePEXP>',
#    'aberkennen',
#    '</ePEXP>',
#    'und',
#    'die',
#    'dortige',
#    'Landespolizei',
#    'auflösen',
#    '.'],
#   ['Trotzdem',
#    '<ePEXP>',
#    'warnte',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Maurer',
#    '</eSOURCE>',
#    'den',
#    '<eTARGET>',
#    'Ständerat',
#    '</eTARGET>',
#    'davor',
#    ',',
#    'den',
#    'Bundesrat',
#    'auf',
#    'eine',
#    '«',
#    'Mission',
#    'impossible',
#    '»',
#    'zu',
#    'schicken',
#    '.'],
#   ['Der',
#    'EU-Hintern',
#    'im',
#    'SVP-Sujet',
#    'müsste',
#    'sich',
#    'also',
#    'nicht',
#    'erheben',
#    '–',
#    'sondern',
#    'abspecke',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>',
#    'IANNA',
#    'BLUM',
#    'Mit',
#    'diesem',
#    'Kampagnensujet',
#    'will',
#    'die',
#    'SVP',
#    'die',
#    'Schweizer',
#    'von',
#    'der',
#    '<eTARGET>',
#    'Begrenzungs',
#    '</eTARGET>',
#    'Initiative',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Fussball',
#    'Der',
#    '<eSOURCE>',
#    'FC',
#    '</eSOURCE>',
#    'Basel',
#    '<ePEXP>',
#    'gewinnt',
#    '</ePEXP>',
#    'gegen',
#    'die',
#    'Young',
#    'Boys',
#    '3',
#    ':',
#    '0',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Denn',
#    'diese',
#    'Definition',
#    'könnte',
#    'dazu',
#    'führen',
#    ',',
#    'dass',
#    'praktisch',
#    'alle',
#    '<eSOURCE>',
#    'Fälle',
#    '</eSOURCE>',
#    'von',
#    'Profiling',
#    'ein',
#    'hohes',
#    '<eTARGET>',
#    'Risiko',
#    '</eTARGET>',
#    '<ePEXP>',
#    'aufweisen',
#    '</ePEXP>',
#    'würden',
#    '.'],
#   ['Und',
#    'die',
#    '<eSOURCE>',
#    'Fussballer',
#    '</eSOURCE>',
#    'der',
#    'beiden',
#    'Stadtklubs',
#    'hätten',
#    'schon',
#    'lange',
#    'vorher',
#    'dort',
#    'gekickt',
#    ',',
#    'wo',
#    'die',
#    'Brachennutzer',
#    'heute',
#    'ihre',
#    'Pflänzchen',
#    'zögen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Seeler',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'zog',
#    '</ePEXP>',
#    'Heimat',
#    'und',
#    'Familie',
#    'vor',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Was',
#    'Russland',
#    'betrifft',
#    ',',
#    'gaben',
#    'sich',
#    '<eSOURCE>',
#    'Laschet',
#    '</eSOURCE>',
#    'und',
#    'Scholz',
#    'kompromissbereit',
#    ',',
#    'während',
#    'Baerbock',
#    'für',
#    'ein',
#    'härteres',
#    '<eTARGET>',
#    'Vorgehen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'eintrat',
#    '</ePEXP>',
#    '.'],
#   ['Ein',
#    '<eSOURCE>',
#    'Grossteil',
#    '</eSOURCE>',
#    'dieser',
#    'Beträge',
#    '<ePEXP>',
#    'diente',
#    '</ePEXP>',
#    'der',
#    '<eTARGET>',
#    'Wiedergutmachung',
#    '</eTARGET>',
#    'an',
#    'Kunden',
#    ',',
#    'die',
#    'aber',
#    'nicht',
#    'immer',
#    'ausgezahlt',
#    'werden',
#    'musste',
#    '.'],
#   ['Denn',
#    'die',
#    'ausgefallenen',
#    'Klassiker',
#    ',',
#    'die',
#    'Flandernrundfahrt',
#    ',',
#    'Gent',
#    '–',
#    'Wevelgem',
#    'und',
#    'Paris',
#    '–',
#    'Roubaix',
#    ',',
#    'Sagans',
#    'wichtigste',
#    'Rennen',
#    'im',
#    'Kalender',
#    ',',
#    'finden',
#    'nun',
#    'parallel',
#    'zum',
#    'Giro',
#    'und',
#    'deshalb',
#    'ohne',
#    'den',
#    'Slowenen',
#    'statt',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Gegen',
#    'Schaffhausen',
#    'siegen',
#    'die',
#    '<eSOURCE>',
#    'Basler',
#    '</eSOURCE>',
#    '3',
#    ':',
#    '0',
#    ',',
#    'gegen',
#    'GC',
#    '<ePEXP>',
#    'verlieren',
#    '</ePEXP>',
#    'sie',
#    '2',
#    ':',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Offenbar',
#    'konnten',
#    'auch',
#    'die',
#    '<eSOURCE>',
#    'Kirchen',
#    '</eSOURCE>',
#    'mit',
#    'ihrem',
#    'ungewöhnlichen',
#    'Positionsbezug',
#    'die',
#    'Landbevölkerung',
#    'nicht',
#    'vom',
#    '<eTARGET>',
#    'Volksbegehren',
#    '</eTARGET>',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Sullivan',
#    '</eSOURCE>',
#    'hat',
#    'Jiechi',
#    'am',
#    'Montag',
#    'bei',
#    'dem',
#    'Treffen',
#    'davor',
#    '<ePEXP>',
#    'gewarnt',
#    '</ePEXP>',
#    ',',
#    '<eTARGET>',
#    'Russland',
#    '</eTARGET>',
#    'zu',
#    'helfen',
#    '.'],
#   ['Bereits',
#    'gestern',
#    'Nachmittag',
#    'fand',
#    'die',
#    'erste',
#    'Sitzung',
#    'des',
#    'neuen',
#    'Verwaltungsrats',
#    'statt',
#    '–',
#    'inklusive',
#    'des',
#    'unterlegenen',
#    'Kutter',
#    ',',
#    'der',
#    'die',
#    'Wahl',
#    'ins',
#    'Gremium',
#    'geschafft',
#    'hatte',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Bei',
#    'der',
#    'Regierungssuche',
#    '<ePEXP>',
#    'appelliert',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Staatspräsident',
#    '</eSOURCE>',
#    'Italiens',
#    'ein',
#    'letztes',
#    'Mal',
#    'an',
#    'die',
#    '<eTARGET>',
#    'Parteien',
#    '</eTARGET>',
#    '–',
#    'und',
#    'sucht',
#    'wohl',
#    'schon',
#    'einen',
#    'Kundschafter',
#    '.'],
#   ['Erst',
#    'im',
#    'August',
#    'finden',
#    'die',
#    '<eSOURCE>',
#    'Hearings',
#    '</eSOURCE>',
#    'mit',
#    'den',
#    'interessierten',
#    '<eTARGET>',
#    'Kreisen',
#    '</eTARGET>',
#    'statt',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Blöd',
#    'nur',
#    ',',
#    'dass',
#    'auch',
#    'die',
#    '<eSOURCE>',
#    'Wiler',
#    '</eSOURCE>',
#    'über',
#    'einen',
#    'solchen',
#    'Super',
#    '<eTARGET>',
#    'Joker',
#    '</eTARGET>',
#    '<ePEXP>',
#    'verfügen',
#    '</ePEXP>',
#    '.'],
#   ['Obwohl',
#    'die',
#    'Angestellten',
#    'auf',
#    'den',
#    'Flugplätzen',
#    'von',
#    'Stockholm',
#    'und',
#    'Göteborg',
#    'Überstunden',
#    '<ePEXP>',
#    'schoben',
#    '</ePEXP>',
#    ',',
#    'schossen',
#    'die',
#    '<eSOURCE>',
#    'Wartezeiten',
#    '</eSOURCE>',
#    'zeitweise',
#    'auf',
#    'bis',
#    'zu',
#    '60',
#    'Stunden',
#    'hoch',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Vor',
#    'einem',
#    'Jahr',
#    'konnte',
#    'der',
#    'Genfer',
#    '<eSOURCE>',
#    'Regierungsrat',
#    '</eSOURCE>',
#    'Pierre',
#    'Maudet',
#    'viele',
#    'Parlamentarier',
#    'von',
#    'seinen',
#    '<eTARGET>',
#    'Fähigkeiten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Nein',
#    ',',
#    'den',
#    '<eTARGET>',
#    'Tieren',
#    '</eTARGET>',
#    'würden',
#    'der',
#    '<eSOURCE>',
#    'Stolz',
#    '</eSOURCE>',
#    'und',
#    'die',
#    'Kraft',
#    '<ePEXP>',
#    'fehlen',
#    '</ePEXP>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Mobilfunkbetreiber',
#    '</eSOURCE>',
#    'Sunrise',
#    'will',
#    'seine',
#    'Aktionäre',
#    'mit',
#    'einem',
#    'neuen',
#    'Vorschlag',
#    'von',
#    'der',
#    '<eTARGET>',
#    'Übernahme',
#    '</eTARGET>',
#    'des',
#    'Kabelnetzbetreibers',
#    'UPC',
#    '<ePEXP>',
#    'überzeugen',
#    '</ePEXP>',
#    '.'],
#   ['Ski',
#    'alpin',
#    'Bei',
#    'der',
#    'Ski-Weltmeisterschaft',
#    'im',
#    'chilenischen',
#    'Portillo',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Erika',
#    '</eSOURCE>',
#    'Schinegger',
#    '1966',
#    '<eTARGET>',
#    'Abfahrtsgold',
#    '</eTARGET>',
#    'für',
#    'Österreich',
#    '.'],
#   ['2002',
#    'und',
#    '2016',
#    'hatte',
#    'der',
#    'heute',
#    '73-jährige',
#    '<eSOURCE>',
#    'Jurassier',
#    '</eSOURCE>',
#    'jeweils',
#    'den',
#    'Schweizer',
#    '<eTARGET>',
#    'Filmpreis',
#    '</eTARGET>',
#    'für',
#    'den',
#    'besten',
#    'Animationsfilm',
#    '<ePEXP>',
#    'gewonnen',
#    '</ePEXP>',
#    '.'],
#   ...]}

# %% [markdown]
# ### Delete this later!
#
# Just for a test on the RE Model performance!

# %%
if VERIFY_RE_MODEL:
    with open(DATASOURCE, "r", encoding="utf-8") as f:
        tokenized_ssa_sents = {"tokens": [], "labels": []}
        for line in f:
            #print(line)
            ds = json.loads(line)
            tokenized_ssa_sents["tokens"].append(ds["tokens"])
            tokenized_ssa_sents["labels"].append(ds["label"])

    gold_polarities = [lbl for lbl in tokenized_ssa_sents["labels"]]

# %% [markdown]
# ### Generate unbreakable tokens based on original dataframe
#
# **Important**: We make sure that every sentence contains a dot in the end that is separated from the last word in the sentence!

# %%
import collections
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import random
import re
import shutil
import torch
import torch.nn as nn

from collections import Counter, defaultdict
from datasets import load_dataset, ClassLabel
from sklearn.metrics import (
    ConfusionMatrixDisplay, confusion_matrix, 
    classification_report, accuracy_score
)
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch.optim import AdamW

from transformers import (
    BertTokenizerFast, BertModel, BertForPreTraining, BertConfig, BertPreTrainedModel,
    DataCollatorWithPadding,
    get_scheduler
)
from transformers.modeling_outputs import SequenceClassifierOutput

# %%
class BertForRelationExtraction(BertPreTrainedModel):
  def __init__(self, config, num_labels):
    super(BertForRelationExtraction, self).__init__(config)
    self.num_labels = num_labels
    # body
    self.bert = BertModel(config)
    # head
    self.dropout = nn.Dropout(config.hidden_dropout_prob)
    #self.layer_norm = nn.LayerNorm(config.hidden_size * 2)
    #self.linear = nn.Linear(config.hidden_size * 2, self.num_labels)
    self.init_weights()
    
    self.layer_norm = nn.LayerNorm(config.hidden_size * 3)
    self.linear = nn.Linear(config.hidden_size * 3, self.num_labels)

  def forward(self, input_ids, token_type_ids, attention_mask,
              span_idxs, labels=None):
    outputs = (
        self.bert(input_ids, token_type_ids=token_type_ids,
                  attention_mask=attention_mask,
                  output_hidden_states=False)
            .last_hidden_state)
            
    sub_maxpool, obj_maxpool, pexp_maxpool = [], [], []
    #sub_maxpool, obj_maxpool = [], []
    for bid in range(outputs.size(0)):
      # span includes entity markers, maxpool across span
      sub_span = torch.max(outputs[bid, span_idxs[bid, 0]:span_idxs[bid, 1]+1, :], 
                           dim=0, keepdim=True).values
      obj_span = torch.max(outputs[bid, span_idxs[bid, 2]:span_idxs[bid, 3]+1, :],
                           dim=0, keepdim=True).values
      pexp_span = torch.max(outputs[bid, span_idxs[bid, 4]:span_idxs[bid, 5]+1, :], dim=0, keepdim=True).values
      sub_maxpool.append(sub_span)
      obj_maxpool.append(obj_span)
      pexp_maxpool.append(pexp_span)

    sub_emb = torch.cat(sub_maxpool, dim=0)
    obj_emb = torch.cat(obj_maxpool, dim=0)
    pexp_emb = torch.cat(pexp_maxpool, dim=0)
    rel_input = torch.cat((sub_emb, obj_emb, pexp_emb), dim=-1)
    #rel_input = torch.cat((sub_emb, obj_emb), dim=-1)

    rel_input = self.layer_norm(rel_input)
    rel_input = self.dropout(rel_input)
    logits = self.linear(rel_input)

    if labels is not None:
      loss_fn = nn.CrossEntropyLoss()
      loss = loss_fn(logits.view(-1, self.num_labels), labels.view(-1))
      return SequenceClassifierOutput(loss, logits)
    else:
      return SequenceClassifierOutput(None, logits)


# config = BertConfig.from_pretrained(BASE_MODEL_NAME)
# model = BertForRelationExtraction.from_pretrained(BASE_MODEL_NAME, 
#                                                   config=config,
#                                                   num_labels=len(valid_relations))
# model.bert.resize_token_embeddings(len(tokenizer.vocab))
# for batch in train_dl:
#   outputs = model(**batch)
#   break
# print("loss:", outputs.loss, "logits.size:", outputs.logits.size())

# %%
tokenizer = BertTokenizerFast.from_pretrained(BASE_MODEL_NAME)

vocab_size_orig = len(tokenizer.vocab)

marker_tokens = []
entity_types = ["eSOURCE", "eTARGET", "ePEXP"]
for entity_type in entity_types:
  marker_tokens.append("<{:s}>".format(entity_type))
  marker_tokens.append("</{:s}>".format(entity_type))

tokenizer.add_tokens(marker_tokens)
vocab_size_new = len(tokenizer.vocab)

print("original vocab size:", vocab_size_orig)
print("new vocab size:", vocab_size_new)

def encode_data(examples):
  tokenized_inputs = tokenizer(examples["tokens"],
                               is_split_into_words=True,
                               truncation=True)
  span_idxs = []
  for input_id in tokenized_inputs.input_ids:
    tokens = tokenizer.convert_ids_to_tokens(input_id)
    try:
        span_idxs.append([
          [idx for idx, token in enumerate(tokens) if token.startswith("<eS")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eS")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("<eT")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eT")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("<eP")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eP")][0],
        ])
    except Exception as e:
        print(f"Encountered error because of: { str(e) }, { str(tokens) }")
        # from IPython.core.debugger import Pdb; Pdb().set_trace()
        # print(f"Tokens of sentence: { str(examples['tokens']) }")

  tokenized_inputs["span_idxs"] = span_idxs
  # tokenized_inputs["labels"] = [label2id[label] for label in examples["label"]]
  return tokenized_inputs

#print(X)
#encoded = encode_data(X)
#encoded.keys()
#print(encoded)
# Out:
# original vocab size: 30000
# new vocab size: 30006

# %%
encoded = encode_data(tokenized_ssa_sents)
# encoded

# %%
from datasets import Dataset
BATCH_SIZE = 4
collate_fn = DataCollatorWithPadding(tokenizer, padding="longest", return_tensors="pt")
test_dl = DataLoader(Dataset.from_dict(encoded),
                      # shuffle=True, 
                      batch_size=BATCH_SIZE, 
                      collate_fn=collate_fn)

# print([x for x in test_dl])

# %%
valid_relations = ["Positive", "Neutral", "Negative"]
valid_relations = sorted(list(valid_relations))

# %%
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_file = os.path.join(MODEL_DIR, "ckpt-{:d}".format(2))

print("=> Loading checkpoint")
# checkpoint = model.from_pretrained(checkpoint_file)
config = BertConfig.from_pretrained(checkpoint_file)
model = BertForRelationExtraction.from_pretrained(checkpoint_file, 
                      config=config,
                      num_labels=len(valid_relations))
# model.load_state_dict(checkpoint["state_dict"])
model.bert.resize_token_embeddings(len(tokenizer.vocab))
model.eval()
model = model.to(device)
# Out:
# => Loading checkpoint

# %%
# confirm the model is not in training
model.training
# Out:
# False

# %%
ytrue, ypred = [], []
with tqdm(test_dl, unit="batch") as tepoch:
    for batch in tepoch:
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
          outputs = model(**batch)
          predictions = torch.argmax(outputs.logits, dim=-1).cpu().numpy()
          #labels = batch["labels"].cpu().numpy()
          #ytrue.extend(labels)
          ypred.extend(predictions)

#print("test accuracy: {:.3f}".format(accuracy_score(ytrue, ypred)))

#print(classification_report(ytrue, ypred, target_names=valid_relations))
# Out:
# 100%|█████████████████████████████████████████████████████████████| 303/303 [01:23<00:00,  3.63batch/s]

# %%
preds_full_label_text = [valid_relations[i] for i in ypred]

# %%
preds_full_label_text
# Out:
# ['Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  ...]

# %%
valid_relations
# Out:
# ['Negative', 'Neutral', 'Positive']

# %% [markdown]
# ### Save the data
#
# Reading in the data so it can be processed. The format is SSA.

# %%
def construct_ssa_dataset(preds, out_data_w_ents):
    new_out_struct = []
    for pred, out_ds in zip(preds, out_data_w_ents):
        od = copy.deepcopy(out_ds)
        od["opinions"][0]["Polarity"] = pred
        new_out_struct.append(od)
    return new_out_struct

out_data_w_entities_and_rel = construct_ssa_dataset(preds_full_label_text, out_data_w_entities)

# %%
out_data_w_entities_and_rel
# Out:
# [{'sent_id': '0',
#   'text': 'Der Mann soll mehrfach auf die Frau geschossen und sich dann selbst gerichtet haben .',
#   'opinions': [{'Source': [['Mann'], ['4:8']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': 'Die Mehrheit der republikanischen wie der demokratischen Senatoren und Abgeordneten ist China-kritisch , und das Weisse Haus geniesst Unterstützung , wenn es Chinas Wiederaufstieg zur Weltmacht als gefährlichste Herausforderung des 21. Jahrhunderts bezeichnet und seine Aussen- und Sicherheitspolitik dementsprechend frisch fokussiert .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Eine Geschichte , deutlich geprägt von – doch nicht deckungsgleich mit – der Liaison zwischen Halliday und dem im Mai dieses Jahres verstorbenen Philip Roth .',
#   'opinions': [{'Source': [['Geschichte'], ['5:15']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Die ersten betroffenen Spiele finden am Donnerstag statt , darunter die Partie von Chelsea bei Norwich City .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': '« Die Russen schiessen auf alles , auch auf zivile Ziele .',
#   'opinions': [{'Source': [['Russen'], ['6:12']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'Aber viel später , während der Unruhen in den 1970er Jahren , benutzte die Irish Republican Army ( IRA ) die Ruine , um auf britische Sicherheitskräfte zu schiessen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Ruine'], ['109:114']],
#     'Polar_expression': [['benutzte'], ['62:70']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Wie im echten Fussballbusiness hat auch im Game der Markt die Preise in die Höhe schiessen lassen .',
#   'opinions': [{'Source': [['Markt'], ['52:57']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Die Schweizer Ratingagentur Independent Credit View warnte ihre Kunden bereits 2019 davor , Papiere der nun zusammengebrochenen Greensill-Bank zu kaufen .',
#   'opinions': [{'Source': [['Ratingagentur'], ['14:27']],
#     'Target': [['Kunden'], ['64:70']],
#     'Polar_expression': [['warnte'], ['52:58']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Die vierte Generation des Erfolgsmodells überzeugt durch ausdrucksstarkes Design und vereint sportlich-direktes Handling durch die variable Progressivlenkung und Toptraktion durch den Quattro-Antrieb .',
#   'opinions': [{'Source': [['Generation'], ['11:21']],
#     'Target': [['Design'], ['74:80']],
#     'Polar_expression': [['überzeugt'], ['41:50']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Zwingli sah sich schon 1523 / 24 mit einem Problem vieler Revolutionen konfrontiert – mit « Abweichlern » in den eigenen Reihen .',
#   'opinions': [{'Source': [['Zwingli'], ['0:7']],
#     'Target': [['Problem'], ['43:50']],
#     'Polar_expression': [['konfrontiert'], ['71:83']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': '« Inzwischen haben die Lichtemissionen und die Qualität des Lichts mehr Gewicht gewonnen . » Die neuen intelligenten LED-Leuchten lassen sich wesentlich präziser einsetzen als die früheren Natriumdampflampen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Gewicht'], ['72:79']],
#     'Polar_expression': [['einsetzen'], ['162:171']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': 'Seither haftet der kalten Fusion ein Schmuddelimage an .',
#   'opinions': [{'Source': [['Schmuddelimage'], ['37:51']],
#     'Target': [['Fusion'], ['26:32']],
#     'Polar_expression': [['haftet'], ['8:14']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Genau eine solche Konstellation könne im Sommer eintreten , wenn die Covid-19-Impfungen im grossen Stil verabreicht werden .',
#   'opinions': [{'Source': [['Konstellation'], ['18:31']],
#     'Target': [[], []],
#     'Polar_expression': [['verabreicht'], ['104:115']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Mit dieser Erfahrung konnte Berset den Bundesrat vom Sinn schnellen Handelns überzeugen .',
#   'opinions': [{'Source': [['Berset'], ['28:34']],
#     'Target': [['Sinn'], ['53:57']],
#     'Polar_expression': [['überzeugen'], ['77:87']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Das Mitglied des britischen Oberhauses warnt die westlichen Länder auch davor , aus wirtschaftlichen Ängsten vor Peking zu kuschen .',
#   'opinions': [{'Source': [['Länder'], ['60:66']],
#     'Target': [[], []],
#     'Polar_expression': [['warnt'], ['39:44']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': 'Podcasts wie das unaufgeregt packende Format « Zeit Verbrechen » der grossartigen Sabine Rückert sind überaus erfolgreich sowie Fernsehserien wie « Aktenzeichen XY » Evergreens ; und namentlich bei Streamingdiensten florieren True-Crime-Serien .',
#   'opinions': [{'Source': [['True'], ['226:230']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Ihre Sorgen um die Gefährdung ihrer Dörfer , des Wassers und der Umwelt werden von Recon übergangen .',
#   'opinions': [{'Source': [['Recon'], ['83:88']],
#     'Target': [[], []],
#     'Polar_expression': [['übergangen'], ['89:99']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Bezos hat es von Anfang an geschafft , die Investoren von seiner Vision zu überzeugen .',
#   'opinions': [{'Source': [['Bezos'], ['0:5']],
#     'Target': [['Vision'], ['65:71']],
#     'Polar_expression': [['überzeugen'], ['75:85']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Die Bauernvertreter äussern aber Zweifel , ob der Kanton sich an Abmachungen halte .',
#   'opinions': [{'Source': [['Kanton'], ['50:56']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': '« Zuerst gab es einen Riesenknall , dann hat der Mann mit einer Schrotflinte auf die Tür geschossen » , sagte ein Zeuge .',
#   'opinions': [{'Source': [['Mann'], ['49:53']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Der Nidwaldner hatte gerade sein erstes Weltcuprennen gewonnen , einen Super-G , etwas für die Erfahrenen , heisst es , auf der Birds of Prey , der Raubvogelpiste , es ist eine der grössten Aufgaben des Winters .',
#   'opinions': [{'Source': [['Nidwaldner'], ['4:14']],
#     'Target': [['Weltcuprennen'], ['40:53']],
#     'Polar_expression': [['gewonnen'], ['54:62']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Von dort stieg der Mann offenbar Treppen hinab Richtung Donaukanal , schoss weiter auf Passanten und auf einen Polizisten , den er schwer verletzte .',
#   'opinions': [{'Source': [['Mann'], ['19:23']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Vor einer Woche warnte beispielsweise die Führung des Zuger Schraubenhändlers Bossard die Aktionäre davor , dass die Situation an den Beschaffungsmärkten auch in der zweiten Jahreshälfte angespannt bleiben dürfte und mit « weiteren Preiserhöhungen und längeren Lieferfristen » zu rechnen sei .',
#   'opinions': [{'Source': [['Führung'], ['42:49']],
#     'Target': [[], []],
#     'Polar_expression': [['warnte'], ['16:22']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Parallel dazu zog der Bund eine Finanzierung für Projekte auf , die nicht mehr mit Geld aus Brüssel rechnen konnten .',
#   'opinions': [{'Source': [['Bund'], ['22:26']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'Die hoffnungsvollen Trump-Stürzer übersehen , dass es – abgesehen von einem Rücktritt – vielleicht in der Theorie Wege gibt , einen Präsidenten loszuwerden , aber kaum in der Praxis .',
#   'opinions': [{'Source': [['Trump'], ['20:25']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'Vermutlich hatte aber der Mann zuerst auf die Frauen geschossen und sich dann selber gerichtet .',
#   'opinions': [{'Source': [['Mann'], ['26:30']],
#     'Target': [[], []],
#     'Polar_expression': [['geschossen'], ['53:63']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': 'Zwar konnte der Kabelnetzbetreiber unter ihrer Ägide , die im Herbst 2018 begann , gut 50 000 Neukunden für sein Mobilfunkangebot gewinnen .',
#   'opinions': [{'Source': [['Kabelnetzbetreiber'], ['16:34']],
#     'Target': [['Mobilfunkangebot'], ['113:129']],
#     'Polar_expression': [['gewinnen'], ['130:138']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Doch die Ansammlung Ausnahmefussballer schleppte sich durch die Vorrunde , siegte gegen Australien ( 2 : 1 ) und Peru ( 1 : 0 ) beinahe glückhaft – und hinterliess auch gestern phasenweise den Eindruck , zufällig im gleichen Trikot zu stecken .',
#   'opinions': [{'Source': [['Ansammlung'], ['9:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Tsai hält eine gewisse Distanz zu Peking , ohne allerdings für eine Unabhängigkeit der Inselrepublik einzutreten .',
#   'opinions': [{'Source': [['Tsai'], ['0:4']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'Humanistisches Denken , wohltätiges Wirken und eine starke Gemeinschaft : Diese Werte hätten ihn von den Odd Fellows überzeugt , als er vor zwölf Jahren zum ersten Mal eine Loge besucht habe , erzählt Egli .',
#   'opinions': [{'Source': [['Werte'], ['80:85']],
#     'Target': [[], []],
#     'Polar_expression': [['überzeugt'], ['117:126']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Luftfahrt Der renommierte Thinktank ICCT warnt vor den geplanten Überschallflugzeugen .',
#   'opinions': [{'Source': [['Thinktank'], ['26:35']],
#     'Target': [['Überschallflugzeugen'], ['65:85']],
#     'Polar_expression': [['warnt'], ['41:46']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': 'Der Pass dazu kommt von Jan Kovar und verdient das Prädikat Weltklasse .',
#   'opinions': [{'Source': [['Pass'], ['4:8']],
#     'Target': [['Prädikat'], ['51:59']],
#     'Polar_expression': [['verdient'], ['38:46']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'Zuvor will Labour jedoch versuchen , die Regierung von den eigenen Brexit-Plänen zu überzeugen .',
#   'opinions': [{'Source': [['Labour'], ['11:17']],
#     'Target': [['Regierung'], ['41:50']],
#     'Polar_expression': [['überzeugen'], ['84:94']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Die AL weist darauf hin , dass die Wertberichtigung zur langfristigen Stabilisierung des Stadtspitals beitrage .',
#   'opinions': [{'Source': [['Wertberichtigung'], ['35:51']],
#     'Target': [['Stabilisierung'], ['70:84']],
#     'Polar_expression': [['beitrage'], ['102:110']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Weil Kohlekraftwerke gutes Geld einbringen , fehlen künftig die Einnahmen bei Alpiq ( im ersten Semester 24 Mio. Fr . ) .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Geld'], ['27:31']],
#     'Polar_expression': [['fehlen'], ['45:51']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Meteorologen warnten vor Sturzfluten .',
#   'opinions': [{'Source': [['Meteorologen'], ['0:12']],
#     'Target': [['Sturzfluten'], ['25:36']],
#     'Polar_expression': [['warnten'], ['13:20']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Nur weil der EU griffige Massnahmen bei der Terrorbekämpfung fehlen .',
#   'opinions': [{'Source': [['Massnahmen'], ['25:35']],
#     'Target': [['Terrorbekämpfung'], ['44:60']],
#     'Polar_expression': [['fehlen'], ['61:67']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'Das zuletzt schwächelnde Team von Domenico Tedesco siegte gegen Augsburg 4 : 0 und kletterte in der Tabelle auf Rang 4 und hat die Qualifikation für die Champions League vor dem letzten Spiel bei Arminia Bielefeld nun wieder selbst in der Hand .',
#   'opinions': [{'Source': [['Team'], ['25:29']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Eine gewisse Ursula Koch schlich sich in die Versammlung ein und versuchte , die Aktivisten von einem SP-Beitritt zu überzeugen .',
#   'opinions': [{'Source': [['Ursula'], ['13:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Auch wurde das Ziel , die öffentliche Meinung im Ausland zu beeinflussen , in einer Konzeption Russlands aus dem Jahr 2013 offiziell genannt .',
#   'opinions': [{'Source': [['Ziel'], ['15:19']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Gerade schrieb er mir : « Die erste Runde ist nie einfach . » ( Bencic hat gerade gegen Andrea Petkovic gewonnen .',
#   'opinions': [{'Source': [['Bencic'], ['64:70']],
#     'Target': [['Andrea'], ['88:94']],
#     'Polar_expression': [['gewonnen'], ['104:112']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Als die Bancomaten-Diebe flüchteten , zückten die Ordnungshüter ihre Pistole und schossen auf die Männer .',
#   'opinions': [{'Source': [['Ordnungshüter'], ['50:63']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'Ein bisschen näher wäre ihr Sofia Goggia gekommen , doch die Siegerin der beiden Abfahrten blieb vor dem Zielsprung an einem Tor hängen und verpasste das nächste .',
#   'opinions': [{'Source': [['Siegerin'], ['61:69']],
#     'Target': [[], []],
#     'Polar_expression': [['verpasste'], ['140:149']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Der Finne zeigt mit Stolz , was die von ihm gegründete Firma Rovio Entertainment erfunden hat : Das Computerspiel Angry Birds ( « zornige Vögel » ) , bei dem rote Vögel mit Schleudern auf diebische Schweine schiessen .',
#   'opinions': [{'Source': [['Firma'], ['55:60']],
#     'Target': [[], []],
#     'Polar_expression': [['erfunden'], ['81:89']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'Ulf Berg wiederum , seit 2007 Verwaltungsratspräsident der Ems-Chemie , nennt Magdalena Martullo gerne « das Orakel von Delphi » .',
#   'opinions': [{'Source': [['Ulf'], ['0:3']],
#     'Target': [[], []],
#     'Polar_expression': [['nennt'], ['72:77']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Die Gendarmerie habe auf die Reifen eines verdächtigen Fahrzeugs geschossen , nachdem der Fahrer die Aufforderung , sofort anzuhalten , ignoriert habe .',
#   'opinions': [{'Source': [['Fahrer'], ['90:96']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': 'Die Bayern zogen ihr Tempospiel auf , kombinierten die Moskauer schwindelig .',
#   'opinions': [{'Source': [['Bayern'], ['4:10']],
#     'Target': [['Tempospiel'], ['21:31']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Aber was soll ’ s – es sind erst sieben Runden gespielt , die Rangliste wirkt chaotisch , St. Gallen hat als einziges Team keine Partie verpasst , Servette und Sitten spielten erst vier Mal .',
#   'opinions': [{'Source': [['Rangliste'], ['62:71']],
#     'Target': [[], []],
#     'Polar_expression': [['wirkt'], ['72:77']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'In der Anklageschrift geht die Staatsanwaltschaft aufs Ganze , klagt Vincenz und Beat Stocker ( 61 ) wegen Betruges an .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['klagt'], ['63:68']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': 'Gleich zweimal konnte Emmerton nach Querpass aufs offene Tor schiessen – beim ersten Mal traf er das Gehäuse , beim zweiten Mal zum 1 : 0 ( 7. ) .',
#   'opinions': [{'Source': [['Emmerton'], ['22:30']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Zum Abschluss der Gruppenphase des Gold-Cups gewann Honduras gegen El Salvador 4 : 0 .',
#   'opinions': [{'Source': [['Honduras'], ['52:60']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['45:51']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': '« Männer müssen den Mut haben , zu ihrer Verletzlichkeit zu stehen und Gefühle zu zeigen . » Wichtig für sie : « Männer und Frauen sollten sich auf Augenhöhe begegnen und einen Schritt aufeinander zugehen . » Caroline Fux ( 37 ) , Psychologin und Sexberaterin bei BLICK , warnte vor Pauschalisierungen : « Viele Männer bemühen sich , alles richtig zu machen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Die ersten drei Wochen eines vierwöchigen Trainingsblocks werden intensiver sein als bisher , die letzte Woche dient der aktiven Erholung .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Erholung'], ['129:137']],
#     'Polar_expression': [['dient'], ['111:116']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'Von 1946 bis 1971 fanden im Park auch Vorführungen im Rahmen des Filmfestivals statt .',
#   'opinions': [{'Source': [['Vorführungen'], ['38:50']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': '« In den entscheidenden Momenten waren sie ein bisschen stärker . » Das Ziel bleibe , den Fed-Cup einmal zu gewinnen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Fed'], ['90:93']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Busse und Barrikaden brennen , Polizisten schiessen auf Demonstranten , eine Katastrophe für ein ohnehin gebeuteltes Land , aber auch ein düsteres Omen für die ganze Region .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['brennen'], ['21:28']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Allerdings fehlt dem Land ein mutiger Reformer wie Deng Xiaoping oder der einstige Regierungschef Zhu Rongji , der in den Neunzigern den schmerzhaften Umbau der Staatsbetriebe vorantrieb .',
#   'opinions': [{'Source': [['Reformer'], ['38:46']],
#     'Target': [['Land'], ['21:25']],
#     'Polar_expression': [['fehlt'], ['11:16']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Die Strafverfolger klagen zudem Zieglers Helfer an , der den Käufer beraten hatte .',
#   'opinions': [{'Source': [['Strafverfolger'], ['4:18']],
#     'Target': [['Zieglers Helfer'], ['32:47']],
#     'Polar_expression': [['klagen'], ['19:25']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Vor einem Jahr hat er ja schon einmal in Syrien bombardieren lassen , nachdem die Regierungsarmee mit Giftgas auf Zivilisten geschossen hatte .',
#   'opinions': [{'Source': [['Regierungsarmee'], ['82:97']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Die Emirate wiederum hoffen , in Damaskus an Einfluss zu gewinnen und so die Macht Irans zu schwächen , mit dem sie in der Region um Einfluss ringen .',
#   'opinions': [{'Source': [['Emirate'], ['4:11']],
#     'Target': [['Macht'], ['77:82']],
#     'Polar_expression': [['gewinnen'], ['57:65']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Frau Leuthard verkennt weiterhin die Notwendigkeit , zuverlässige und stets verfügbare AKW auf der Basis neuster Technologie zu erstellen , um dauerhaft zu unserer Stromversorgung beizutragen ( auch für die zunehmende Elektromobilität ) .',
#   'opinions': [{'Source': [['Frau'], ['0:4']],
#     'Target': [['Stromversorgung'], ['164:179']],
#     'Polar_expression': [['beizutragen'], ['180:191']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'Fussball – Die Schweizer U21-Nati siegt im Test gegen Irland 2 : 0 .',
#   'opinions': [{'Source': [['Nati'], ['29:33']],
#     'Target': [[], []],
#     'Polar_expression': [['siegt'], ['34:39']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Müller und 99 weitere Glückliche haben eine Zypern-Rundreise für zwei Personen gewonnen .',
#   'opinions': [{'Source': [['Glückliche'], ['22:32']],
#     'Target': [['Zypern'], ['44:50']],
#     'Polar_expression': [['gewonnen'], ['79:87']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'Gleichzeitig gewann der Walliser die kleine Kristallkugel für den Gewinn des Disziplinen-Weltcups , der erstmals vergeben wurde .',
#   'opinions': [{'Source': [['Walliser'], ['24:32']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['13:19']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'In der Meisterschaft hat das Stadion dem LHC mit zwei Niederlagen keine Fortune gebracht , doch gegen Philadelphia siegte der Gastgeber 4 : 3.',
#   'opinions': [{'Source': [['Gastgeber'], ['126:135']],
#     'Target': [['LHC'], ['41:44']],
#     'Polar_expression': [['siegte'], ['115:121']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'Immerhin aber finden in den Salons und Sanatorien die Gespräche noch statt !',
#   'opinions': [{'Source': [['Gespräche'], ['54:63']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Tini nennt Benzodiazepine wie Xanax , aber auch Ecstasy , Alkohol oder Cannabis .',
#   'opinions': [{'Source': [['Tini'], ['0:4']],
#     'Target': [['Benzodiazepine'], ['11:25']],
#     'Polar_expression': [['nennt'], ['5:10']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Im Clip wird dargestellt , wie ein Mann mit einer automatischen Waffe auf Besucher eines Tanzclubs schiesst .',
#   'opinions': [{'Source': [['Mann'], ['35:39']],
#     'Target': [['Besucher'], ['74:82']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': '« Schwangere , die mich engagieren , haben vielleicht bereits ein Geburtstrauma erlitten und grosse Ängste » , sagt Brenneisen .',
#   'opinions': [{'Source': [['Schwangere'], ['2:12']],
#     'Target': [['Geburtstrauma'], ['66:79']],
#     'Polar_expression': [['erlitten'], ['80:88']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Die erneute Wertberichtigung auf dem Goodwill bedeutet vereinfacht gesagt , dass Lafarge tendenziell mehr « wacklige » Vermögenswerte eingebracht hat als bisher gedacht .',
#   'opinions': [{'Source': [['Lafarge'], ['81:88']],
#     'Target': [['Vermögenswerte'], ['119:133']],
#     'Polar_expression': [['eingebracht'], ['134:145']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'Fachleute attestieren ihr das Talent , um Grand-Slam-Titel zu gewinnen .',
#   'opinions': [{'Source': [['Fachleute'], ['0:9']],
#     'Target': [['Titel'], ['53:58']],
#     'Polar_expression': [['gewinnen'], ['62:70']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': '« Aufgestanden ! » , ruft der sportliche Erweckungprediger seinen lethargischen Patienten gleich am Anfang zu , um sie mit Rezepten für Besserung förmlich zu überschütten : Frühaufstehen , kalte Bäder , weg vom Ofen an die frische Luft , festes Schuhwerk , ein ordentlicher Bart als Schutz für die Kehle und vor allem gesunde Diät , denn « wir schaufeln uns unser Grab mit den Zähnen » .',
#   'opinions': [{'Source': [['Erweckungprediger'], ['41:58']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Gut-Behrami gewann die kleine Kristallkugel für die saisonbeste Super-G-Fahrerin 2014 und 2016 , Suter im vergangenen Winter .',
#   'opinions': [{'Source': [['Behrami'], ['4:11']],
#     'Target': [['Kristallkugel'], ['30:43']],
#     'Polar_expression': [['gewann'], ['12:18']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Ganz nach Bersets Motto : « Jede Impfung zählt ! » Neben den gängigen Angeboten wie Spontanimpfungen in Impfzentren oder zusätzlichen Impfmobilen und Beratungsmöglichkeiten haben sich manche Kantone weitere originelle Möglichkeiten ausgedacht , um die Bevölkerung vom Piks zu überzeugen .',
#   'opinions': [{'Source': [['Kantone'], ['191:198']],
#     'Target': [[], []],
#     'Polar_expression': [['überzeugen'], ['276:286']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'Nischni Nowgorod – In Russland hat ein 18-Jähriger auf Passanten geschossen und dabei mindestens drei Männer getötet .',
#   'opinions': [{'Source': [['Jähriger'], ['42:50']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'Cannabisproduzenten schiessen auf Eindringlinge .',
#   'opinions': [{'Source': [['Cannabisproduzenten'], ['0:19']],
#     'Target': [['Eindringlinge'], ['34:47']],
#     'Polar_expression': [['schiessen'], ['20:29']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'Bei den Älteren siegte hingegen die SPD deutlich .',
#   'opinions': [{'Source': [['SPD'], ['36:39']],
#     'Target': [['Älteren'], ['8:15']],
#     'Polar_expression': [['siegte'], ['16:22']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Mit Lasse Sobiech verletzte sich die Stütze in der Abwehr ein zweites Mal , die Balance zwischen Mittelfeld und Sturm geriet durcheinander ; Blaz Kramer und Assan Ceesay fehlt die Qualität im Sturm .',
#   'opinions': [{'Source': [['Stütze'], ['37:43']],
#     'Target': [[], []],
#     'Polar_expression': [['verletzte'], ['18:27']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Steuerfragen liegen indessen in der Kompetenz des sozialdemokratischen Finanzministers Olaf Scholz , den der CDU-Minster Altmaier erst noch für seine Pläne gewinnen müsste .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': 'Abstimmung Zu grosse Befugnisse für Polizei : Experten warnen vor dem Antiterrorgesetz .',
#   'opinions': [{'Source': [['Experten'], ['46:54']],
#     'Target': [['Antiterrorgesetz'], ['70:86']],
#     'Polar_expression': [['warnen'], ['55:61']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'Meistens dienen ihre Reisen dem guten Zweck und stehen im Zeichen des karitativen Geistes .',
#   'opinions': [{'Source': [['Reisen'], ['21:27']],
#     'Target': [['Zweck'], ['38:43']],
#     'Polar_expression': [['dienen'], ['9:15']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Laut der IMF-Chefökonomin Gita Gopinath ist es einmalig , dass alle Weltregionen gleichzeitig negative Wachstumsraten aufweisen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Wachstumsraten'], ['103:117']],
#     'Polar_expression': [['aufweisen'], ['118:127']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Der Flawiler Spezialist für industrielle Röntgentechnologie und Hersteller von Vakuumkondensatoren gewann vor zehn Jahren für seine Weiterentwicklung den Swiss Technology Award .',
#   'opinions': [{'Source': [['Spezialist'], ['13:23']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['99:105']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'Während der Nati-Vorbereitung in Bad Ragaz fehlte ein prominenter Name : Xherdan Shaqiri ( 30 ) .',
#   'opinions': [{'Source': [['Name'], ['66:70']],
#     'Target': [[], []],
#     'Polar_expression': [['fehlte'], ['43:49']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': 'Seit über sechs Jahren hat keine europäische Gastmannschaft mehr im Camp Nou gewonnen , aber dem BVB fehlte das Selbstvertrauen selbst für einen Versuch – sei es mit Abenteuerlust , sei es mit taktischer Stringenz , sei es mit purer Rebellion .',
#   'opinions': [{'Source': [['Gastmannschaft'], ['45:59']],
#     'Target': [['Versuch'], ['145:152']],
#     'Polar_expression': [['gewonnen'], ['77:85']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Intendant Andreas Beck und der designierte Operndirektor Pavel B. Jiracek konnten sie für diese Position gewinnen , welche sie bis zum Ende der Intendanz von Beck am Theater Basel ausüben wird .',
#   'opinions': [{'Source': [['Intendant'], ['0:9']],
#     'Target': [['Position'], ['96:104']],
#     'Polar_expression': [['gewinnen'], ['105:113']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Die beiden Initiatoren Giorgio Pace und Nicolas Bellavance-Lecompte nennen ihren Event « The Travelling Showcase for Collectable Design » ; dieses neue Format testeten sie bereits letztes Jahr in einer Villa in Monaco .',
#   'opinions': [{'Source': [['Initiatoren'], ['11:22']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Oder anders ausgedrückt : Die Staatsanwaltschaft schiesse mit Kanonen auf Spatzen , indem sie unverhältnismässig viele Kleinkriminelle in Untersuchungshaft setze , so lautet der Vorwurf .',
#   'opinions': [{'Source': [['Staatsanwaltschaft'], ['30:48']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Die Männer mit Skip Peter de Cruz siegen im fünften Spiel erst zum zweiten Mal ( 9 : 7 gegen Finnland ) .',
#   'opinions': [{'Source': [['Männer'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [['siegen'], ['34:40']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': '22 Eishockeyspiele fanden ohne Publikum statt .',
#   'opinions': [{'Source': [['Eishockeyspiele'], ['3:18']],
#     'Target': [['Publikum'], ['31:39']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Die Türken , die sich resolut gegen die Einstufung der Ereignisse als Völkermord wehren , intervenierten auf höchster Ebene – und hatten Erfolg : Der damalige Aussenminister Didier Burkhalter warnte den Genfer Regierungsrat in einem Brief eindringlich davor , die Baubewilligung zu erteilen .',
#   'opinions': [{'Source': [['Türken'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Nachdem diese Raketen auf die Hauptstadt Eritreas geschossen haben , könnte der Konflikt das ganze Horn von Afrika destabilisieren .',
#   'opinions': [{'Source': [['Konflikt'], ['80:88']],
#     'Target': [['Horn'], ['99:103']],
#     'Polar_expression': [['destabilisieren'], ['115:130']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Nach Maos Tod schossen seine Nachfolger 1989 auf das eigene Volk .',
#   'opinions': [{'Source': [['Nachfolger'], ['29:39']],
#     'Target': [['Volk'], ['60:64']],
#     'Polar_expression': [['schossen'], ['14:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Dann zog eine riesige Staubwolke durchs Tal .',
#   'opinions': [{'Source': [['Staubwolke'], ['22:32']],
#     'Target': [['Tal'], ['40:43']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': 'Und dazu der letzte Vergleich : Der Deutsche brachte 72 Erfolge nach Maranello – der Brite gewann bisher 69 Mal für Mercedes .',
#   'opinions': [{'Source': [['Brite'], ['85:90']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Das meiste Geld fliesst in Marketing , um neue zahlende Kunden zu gewinnen .',
#   'opinions': [{'Source': [['Geld'], ['11:15']],
#     'Target': [['Kunden'], ['56:62']],
#     'Polar_expression': [['gewinnen'], ['66:74']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'Lange Zeit hätten tamilische Politiker versucht , die muslimischen Gemeinschaften für die « Sache der Tamilischsprechenden » zu gewinnen , sagt Benedikt Korf , Professor für politische Geografie an der Universität Zürich .',
#   'opinions': [{'Source': [['Politiker'], ['29:38']],
#     'Target': [['Gemeinschaften'], ['67:81']],
#     'Polar_expression': [['gewinnen'], ['128:136']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': 'Im August findet die Übergabe an die Polizei statt , die danach ihr Provisorium im Tiefenbrunnen verlassen und den Neubau in Betrieb nehmen kann .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Mit einer 9-mm-Pistole schoss Nasim Aghdam auf drei Angestellte , dann nahm sie sich selbst das Leben .',
#   'opinions': [{'Source': [['Nasim'], ['30:35']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': '« Die Frau zog die Tiere auf und hatte eine enge Beziehung zu ihnen .',
#   'opinions': [{'Source': [['Frau'], ['6:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Weil die Schweizer Delegation über eigene Messdaten verfügt ( siehe Haupttext ) , arbeitet die Servicecrew von Dario Cologna und Kollegen mit Exklusivinformationen .',
#   'opinions': [{'Source': [['Servicecrew'], ['95:106']],
#     'Target': [['Exklusivinformationen'], ['142:163']],
#     'Polar_expression': [['arbeitet'], ['82:90']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Natürlich würde auch Liverpool gern die Champions League gewinnen .',
#   'opinions': [{'Source': [['Liverpool'], ['21:30']],
#     'Target': [['Champions'], ['40:49']],
#     'Polar_expression': [['gewinnen'], ['57:65']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Kein Gegner findet Mittel , um dem Mallorquiner die « Coupe des Mousquetaires » streitig zu machen .',
#   'opinions': [{'Source': [['Gegner'], ['5:11']],
#     'Target': [['Mallorquiner'], ['35:47']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Vor allem die Version einer Win-win-Situation darf bei chinesischen Vorträgen nicht fehlen .',
#   'opinions': [{'Source': [['Version'], ['14:21']],
#     'Target': [['Vorträgen'], ['68:77']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': 'Söder hat für die kommende Woche einen runden Tisch einberufen , um eine parteienübergreifende Lösung zu finden .',
#   'opinions': [{'Source': [['Söder'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': 'Die Staatsanwaltschaft von New York klagte den 29 Jahre alten Mann am Montag an , 2016 eine Fülle von geheimem Material gestohlen und dann der Enthüllungsplattform Wikileaks zugespielt zu haben .',
#   'opinions': [{'Source': [['Staatsanwaltschaft'], ['4:22']],
#     'Target': [['Mann'], ['62:66']],
#     'Polar_expression': [['klagte'], ['36:42']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'An seiner Stelle gewann sein früherer Vizepräsident Lenín Moreno die Wahl für die Regierungspartei .',
#   'opinions': [{'Source': [['Vizepräsident'], ['38:51']],
#     'Target': [['Wahl'], ['69:73']],
#     'Polar_expression': [['gewann'], ['17:23']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'So wirkt der kuriose Turniersieg in Schweden , nunmehr unter dem Coach Richard Møller Nielsen , wie eine besondere Pointe : Michael Laudrup , inzwischen in Barcelona , zog die Sommerferien der Turnierteilnahme auch wegen eines Konflikts mit Møller Nielsen vor , zumal er sich nach dem Gewinn des Europacups der Landesmeister mit Barça erschöpft wähnte .',
#   'opinions': [{'Source': [['Turniersieg'], ['21:32']],
#     'Target': [[], []],
#     'Polar_expression': [['wirkt'], ['3:8']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Der Banker machte sich selbständig , zog in Singapur einen Whiskyhandel auf , bevor er sieben Jahre später in die Schweiz zurückkehrte .',
#   'opinions': [{'Source': [['Banker'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': 'Über dem Golf schiesst ein US-Kriegsschiff ein iranisches Linienflugzeug ab .',
#   'opinions': [{'Source': [['Kriegsschiff'], ['30:42']],
#     'Target': [['Linienflugzeug'], ['58:72']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Vor drei Jahren gewann Pawlikowski für « Ida » , die Geschichte einer Nonne im Polen der sechziger Jahre , neben zahlreichen anderen Preisen den Oscar für den besten fremdsprachigen Film .',
#   'opinions': [{'Source': [['Pawlikowski'], ['23:34']],
#     'Target': [[], []],
#     'Polar_expression': [['gewann'], ['16:22']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'Djibril Diani ( 21 ) und Morandi ( 20 ) vor ihm fehlt in den entscheidenden Momenten oft die nötige Ruhe .',
#   'opinions': [{'Source': [['Ruhe'], ['100:104']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Diese Sicherheit fehlt den Österreichern im Wettkampf . » Allzu früh sollten wir Schweizer uns aber nicht über die Probleme unserer Erz-Rivalen freuen .',
#   'opinions': [{'Source': [['Sicherheit'], ['6:16']],
#     'Target': [['Österreichern'], ['27:40']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'Der Liga-Topskorer schiesst den starken FCZ im Alleingang ab .',
#   'opinions': [{'Source': [['Topskorer'], ['9:18']],
#     'Target': [['FCZ'], ['40:43']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'Schon vor dem Spiel um 01.00 Uhr Schweizer Zeit in der Nacht von Samstag auf Sonntag zogen dunkle Wolken über dem Lambeau Field auf , das Spiel wurde zunächst mit 15 Minuten Verspätung angepfiffen und musste nach dem Haaland-Treffer ein weiteres Mal für rund 60 Minuten unterbrochen werden .',
#   'opinions': [{'Source': [['Wolken'], ['98:104']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'MARCO GARCIA , BUBIKON ZH Diesen Jugendlichen fehlt die führende Hand der Eltern und des Staats .',
#   'opinions': [{'Source': [['Hand'], ['65:69']],
#     'Target': [['Jugendlichen'], ['33:45']],
#     'Polar_expression': [['fehlt'], ['46:51']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Nach Aussage der israelischen Armee haben die Soldaten gezielt auf Rädelsführer geschossen .',
#   'opinions': [{'Source': [['Soldaten'], ['46:54']],
#     'Target': [['Rädelsführer'], ['67:79']],
#     'Polar_expression': [['geschossen'], ['80:90']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Traugott Vöhringer ist erstaunt , dass das Projekt so grossen Anklang fand .',
#   'opinions': [{'Source': [['Traugott'], ['0:8']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Fussball – Liverpool siegt gegen CF Monterrey 2 : 1 ( mit Shaqiri bis zur 68.',
#   'opinions': [{'Source': [['Liverpool'], ['11:20']],
#     'Target': [[], []],
#     'Polar_expression': [['siegt'], ['21:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Von einer Hochhaus-Baustelle hätten Scharfschützen auf die Protestierenden geschossen , erzählen viele .',
#   'opinions': [{'Source': [['Scharfschützen'], ['36:50']],
#     'Target': [['Protestierenden'], ['59:74']],
#     'Polar_expression': [['geschossen'], ['75:85']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Mit einer eigenen Website , Broschüren und Roadshows versucht das Bundesamt für Energie ( BFE ) seit 2015 , Autokäufer für klimaschonendere Fahrzeuge zu gewinnen – weitgehend erfolglos .',
#   'opinions': [{'Source': [['Bundesamt'], ['66:75']],
#     'Target': [[], []],
#     'Polar_expression': [['gewinnen'], ['153:161']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Daraufhin schoss die Armee ohne Vorwarnung in die Menge .',
#   'opinions': [{'Source': [['Armee'], ['21:26']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Der Freiburger hat sich zur valablen Alternative zu Flüeler entwickelt , gewann seine ersten fünf Starts und 11 von 16 Spielen .',
#   'opinions': [{'Source': [['Freiburger'], ['4:14']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Cavusoglu warnte die USA auch davor , die Türkei vor die Wahl zu stellen , entweder gute Beziehungen zu Russland oder zu den USA zu haben .',
#   'opinions': [{'Source': [['Cavusoglu'], ['0:9']],
#     'Target': [['USA'], ['21:24']],
#     'Polar_expression': [['warnte'], ['10:16']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'In einem anderen Fall , bei dem um einen vergleichsweise geringen Betrag gestritten wurde , hat Implenia am Ende gegen die Stadt gewonnen .',
#   'opinions': [{'Source': [['Implenia'], ['96:104']],
#     'Target': [['Stadt'], ['123:128']],
#     'Polar_expression': [['gewonnen'], ['129:137']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Über eine mit dem Westen vergleichbare Kaufkraft verfügt in Indien weiterhin nur ein Bruchteil der Bevölkerung ; bereits ab einem Einkommen von 10 $ pro Tag zählt man hier zur Mittelschicht .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Kaufkraft'], ['39:48']],
#     'Polar_expression': [['verfügt'], ['49:56']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '126',
#   'text': 'Brüssel warnt aber gleichzeitig vor zu hohen Erwartungen .',
#   'opinions': [{'Source': [['Brüssel'], ['0:7']],
#     'Target': [['Erwartungen'], ['45:56']],
#     'Polar_expression': [['warnt'], ['8:13']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '127',
#   'text': 'Das eindrückliche Abschneiden der Sika-Gruppe an der Börse war indes auch die zentrale Voraussetzung dafür , dass die Streithähne nun doch noch eine einvernehmlichen Lösung gefunden haben .',
#   'opinions': [{'Source': [['Streithähne'], ['118:129']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '128',
#   'text': '« Das Feuer ist hier für den Täter kein Mittel zum Zweck , sondern dient bloss der eigenen Befriedigung . » Für den typischen Feuerteufel ist der Brandstifter von Merenschwand schon fast zu alt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Befriedigung'], ['91:103']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '129',
#   'text': 'Um ihre Vorgesetzten vom Jobsharing zu überzeugen , haben Christiane Haasis und Angela Nelissen die Kunstfigur « Chan » kreiert , gebildet aus den zwei Anfangsbuchstaben ihrer Vornamen .',
#   'opinions': [{'Source': [['Christiane'], ['58:68']],
#     'Target': [['Jobsharing'], ['25:35']],
#     'Polar_expression': [['überzeugen'], ['39:49']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '130',
#   'text': 'Die Spice Girls versuchen nach den Worten von Sängerin Mel C weiterhin , Victoria Beckham für ein Band-Comeback zu gewinnen .',
#   'opinions': [{'Source': [['Spice'], ['4:9']],
#     'Target': [['Comeback'], ['103:111']],
#     'Polar_expression': [['gewinnen'], ['115:123']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '131',
#   'text': 'Auch sonst treue Anhänger äusserten Zweifel , kritisierten das Papier als nutzlos , kleinmütig .',
#   'opinions': [{'Source': [['Anhänger'], ['17:25']],
#     'Target': [['Papier'], ['63:69']],
#     'Polar_expression': [['kritisierten'], ['46:58']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '132',
#   'text': 'Bei der Durchsetzung einer UNO-Flugverbotszone über Bosnien schiesst die Nato vier serbische Militärjets ab .',
#   'opinions': [{'Source': [['Nato'], ['73:77']],
#     'Target': [['Militärjets'], ['93:104']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '133',
#   'text': 'Er habe alle Parteien gedrängt , « auf verantwortungsvolle Weise eine angemessene Lösung der Ukraine-Krise » zu finden .',
#   'opinions': [{'Source': [['Parteien'], ['13:21']],
# ...
#     'Target': [[], []],
#     'Polar_expression': [['gewarnt'], ['80:87']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '955',
#   'text': 'EU-Binnenmarkt-Kommissar Thierry Breton sagte am Montag , er sei « perplex » darüber , dass die Online-Plattformen Trump den Stecker gezogen hätten .',
#   'opinions': [{'Source': [['Plattformen'], ['103:114']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '956',
#   'text': 'Ein Beamter zieht schliesslich die Waffe und schiesst auf den irren Angreifer .',
#   'opinions': [{'Source': [['Beamter'], ['4:11']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '957',
#   'text': 'Den Fans ihrerseits fehlten mit den traditionellen Tonträgern plötzlich die kultischen Objekte ihrer Passion .',
#   'opinions': [{'Source': [['Objekte'], ['87:94']],
#     'Target': [['Fans'], ['4:8']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': 'Im Kanton Waadt warnte die Polizei Wanderer davor , in schneebedeckte Wälder zu gehen .',
#   'opinions': [{'Source': [['Polizei'], ['27:34']],
#     'Target': [[], []],
#     'Polar_expression': [['warnte'], ['16:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Aktivisten dementierten dies , allerdings gab es in der Vergangenheit mehrfach Vorfälle , in denen Rebellen auf Zivilisten schossen , um sie an der Flucht zu hindern .',
#   'opinions': [{'Source': [['Rebellen'], ['99:107']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Für seine Rolle als Hannibal Lecter in « Das Schweigen der Lämmer » gewann Hopkins seinen ersten Oscar als bester Schauspieler .',
#   'opinions': [{'Source': [['Hopkins'], ['75:82']],
#     'Target': [['Oscar'], ['97:102']],
#     'Polar_expression': [['gewann'], ['68:74']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Luna Rossa hat das Rendez-vous mit der Geschichte souverän bestanden : Genau 21 Jahre nach dem Sieg im Final der Herausforderer in Auckland gewannen die Italiener an gleicher Stätte erneut den Pokal für den besten Challenger .',
#   'opinions': [{'Source': [['Italiener'], ['153:162']],
#     'Target': [['Rendez'], ['19:25']],
#     'Polar_expression': [['bestanden'], ['59:68']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Im Tiebreak müssen Hüberli / Betschart die letztjährigen Gstaad-Siegerinnen etwas ziehen lassen , kämpfen aber heroisch – und wehren sechs Matchbälle ab !',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['wehren'], ['126:132']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'Die Kandidatur hat einen sehr guten Ansatz eingebracht .',
#   'opinions': [{'Source': [['Kandidatur'], ['4:14']],
#     'Target': [['Ansatz'], ['36:42']],
#     'Polar_expression': [['eingebracht'], ['43:54']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Russische Panzer schiessen auf Zivilisten .',
#   'opinions': [{'Source': [['Panzer'], ['10:16']],
#     'Target': [['Zivilisten'], ['31:41']],
#     'Polar_expression': [['schiessen'], ['17:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Dabei klagt die Regierungsbeauftragte auch eine Kultur des Machismus in der spanischen Gesellschaft an : « Unter der Covid-19-Pandemie versteckte sich eine andere Pandemie , nämlich die des Machismus , der jetzt wieder zutage tritt . » Davon bleibt keine Altersgruppe verschont .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Dann überzeugte der ehemalige IIHF-Präsident René Fasel den NHL-Commissioner Gary Bettman von der Werbewirksamkeit der olympischen Bühne .',
#   'opinions': [{'Source': [['Präsident'], ['35:44']],
#     'Target': [['NHL'], ['60:63']],
#     'Polar_expression': [['überzeugte'], ['5:15']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Auch dort fehle Frauen oft noch der Mut , den Mund aufzumachen und sich zu wehren .',
#   'opinions': [{'Source': [['Frauen'], ['16:22']],
#     'Target': [[], []],
#     'Polar_expression': [['aufzumachen'], ['51:62']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Rilke überging den Tod der Freundin mit Schweigen .',
#   'opinions': [{'Source': [['Rilke'], ['0:5']],
#     'Target': [['Tod'], ['19:22']],
#     'Polar_expression': [['überging'], ['6:14']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': 'Daniel Betschart ( 32 ) , Medienexperte bei der Stiftung Pro Juventute , warnt vor der gekauften Gefälligkeit : « Speziell Minderjährige lassen sich von der Aufmerksamkeit ihrer Idole rasch blenden und verteilen die Gifts , ohne an die Kosten zu denken . » Er rät : « Um nicht in die Kostenfalle zu tappen , deaktiviert man am besten die In-App-Käufe . » Weil schon 13-jährige Hunderte von Franken an ihre Stars verschenkten , erhöhte Tiktok die Altersbeschränkung für diese Funktion auf 18 Jahre .',
#   'opinions': [{'Source': [['Minderjährige'], ['123:136']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Mélenchon hat versucht , den Rest der linken Parteienlandschaft für eine Allianz zu gewinnen .',
#   'opinions': [{'Source': [['Mélenchon'], ['0:9']],
#     'Target': [['Rest'], ['29:33']],
#     'Polar_expression': [['gewinnen'], ['84:92']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Mueller klagte Manafort trotzdem an .',
#   'opinions': [{'Source': [['Mueller'], ['0:7']],
#     'Target': [['Manafort'], ['15:23']],
#     'Polar_expression': [['klagte'], ['8:14']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Sie bietet Studienwochen für Hochbegabte an , und im Projekt « ETH unterwegs » besuchen ETH-Professoren und Studierende Gymnasien und versuchen , die Schüler mit Vorträgen , Experimenten und Wettbewerben von der ETH zu überzeugen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['überzeugen'], ['219:229']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Genauso wie den Patienten fehlen den medizinischen Fachleuten echte Anreize , das Dossier zu nutzen .',
#   'opinions': [{'Source': [['Anreize'], ['68:75']],
#     'Target': [['Dossier'], ['82:89']],
#     'Polar_expression': [['nutzen'], ['93:99']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Noch fehlt Vinfast der Mut für etwas richtig Neues .',
#   'opinions': [{'Source': [['Mut'], ['23:26']],
#     'Target': [['Vinfast'], ['11:18']],
#     'Polar_expression': [['fehlt'], ['5:10']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Viele Preise hat Keller für ihre Entdeckungen gewonnen , darunter 2005 den Philip-Morris-Forschungspreis und kürzlich den Europäischen Erfinderpreis .',
#   'opinions': [{'Source': [['Keller'], ['17:23']],
#     'Target': [['Entdeckungen'], ['33:45']],
#     'Polar_expression': [['gewonnen'], ['46:54']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Die US-Justiz will möglichst viele Zeugen für das Strafverfahren gegen Assange gewinnen .',
#   'opinions': [{'Source': [['Justiz'], ['7:13']],
#     'Target': [['Zeugen'], ['35:41']],
#     'Polar_expression': [['gewinnen'], ['79:87']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Am liebsten würde Abascal den nach Unabhängigkeit strebenden Katalanen ihren Autonomiestatut aberkennen und die dortige Landespolizei auflösen .',
#   'opinions': [{'Source': [['Abascal'], ['18:25']],
#     'Target': [['Katalanen'], ['61:70']],
#     'Polar_expression': [['aberkennen'], ['93:103']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Trotzdem warnte Maurer den Ständerat davor , den Bundesrat auf eine « Mission impossible » zu schicken .',
#   'opinions': [{'Source': [['Maurer'], ['16:22']],
#     'Target': [['Ständerat'], ['27:36']],
#     'Polar_expression': [['warnte'], ['9:15']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Der EU-Hintern im SVP-Sujet müsste sich also nicht erheben – sondern abspecken.GIANNA BLUM Mit diesem Kampagnensujet will die SVP die Schweizer von der Begrenzungs-Initiative überzeugen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Begrenzungs'], ['152:163']],
#     'Polar_expression': [['überzeugen'], ['175:185']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Fussball Der FC Basel gewinnt gegen die Young Boys 3 : 0 .',
#   'opinions': [{'Source': [['FC'], ['13:15']],
#     'Target': [[], []],
#     'Polar_expression': [['gewinnt'], ['22:29']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Denn diese Definition könnte dazu führen , dass praktisch alle Fälle von Profiling ein hohes Risiko aufweisen würden .',
#   'opinions': [{'Source': [['Fälle'], ['63:68']],
#     'Target': [['Risiko'], ['93:99']],
#     'Polar_expression': [['aufweisen'], ['100:109']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Und die Fussballer der beiden Stadtklubs hätten schon lange vorher dort gekickt , wo die Brachennutzer heute ihre Pflänzchen zögen .',
#   'opinions': [{'Source': [['Fussballer'], ['8:18']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Seeler zog Heimat und Familie vor .',
#   'opinions': [{'Source': [['Seeler'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['zog'], ['7:10']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Was Russland betrifft , gaben sich Laschet und Scholz kompromissbereit , während Baerbock für ein härteres Vorgehen eintrat .',
#   'opinions': [{'Source': [['Laschet'], ['35:42']],
#     'Target': [['Vorgehen'], ['107:115']],
#     'Polar_expression': [['eintrat'], ['116:123']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Ein Grossteil dieser Beträge diente der Wiedergutmachung an Kunden , die aber nicht immer ausgezahlt werden musste .',
#   'opinions': [{'Source': [['Grossteil'], ['4:13']],
#     'Target': [['Wiedergutmachung'], ['40:56']],
#     'Polar_expression': [['diente'], ['29:35']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Denn die ausgefallenen Klassiker , die Flandernrundfahrt , Gent – Wevelgem und Paris – Roubaix , Sagans wichtigste Rennen im Kalender , finden nun parallel zum Giro und deshalb ohne den Slowenen statt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Gegen Schaffhausen siegen die Basler 3 : 0 , gegen GC verlieren sie 2 : 3.',
#   'opinions': [{'Source': [['Basler'], ['30:36']],
#     'Target': [[], []],
#     'Polar_expression': [['verlieren'], ['54:63']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Offenbar konnten auch die Kirchen mit ihrem ungewöhnlichen Positionsbezug die Landbevölkerung nicht vom Volksbegehren überzeugen .',
#   'opinions': [{'Source': [['Kirchen'], ['26:33']],
#     'Target': [['Volksbegehren'], ['104:117']],
#     'Polar_expression': [['überzeugen'], ['118:128']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'Sullivan hat Jiechi am Montag bei dem Treffen davor gewarnt , Russland zu helfen .',
#   'opinions': [{'Source': [['Sullivan'], ['0:8']],
#     'Target': [['Russland'], ['62:70']],
#     'Polar_expression': [['gewarnt'], ['52:59']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Bereits gestern Nachmittag fand die erste Sitzung des neuen Verwaltungsrats statt – inklusive des unterlegenen Kutter , der die Wahl ins Gremium geschafft hatte .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Bei der Regierungssuche appelliert der Staatspräsident Italiens ein letztes Mal an die Parteien – und sucht wohl schon einen Kundschafter .',
#   'opinions': [{'Source': [['Staatspräsident'], ['39:54']],
#     'Target': [['Parteien'], ['87:95']],
#     'Polar_expression': [['appelliert'], ['24:34']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Erst im August finden die Hearings mit den interessierten Kreisen statt .',
#   'opinions': [{'Source': [['Hearings'], ['26:34']],
#     'Target': [['Kreisen'], ['58:65']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Blöd nur , dass auch die Wiler über einen solchen Super-Joker verfügen .',
#   'opinions': [{'Source': [['Wiler'], ['25:30']],
#     'Target': [['Joker'], ['56:61']],
#     'Polar_expression': [['verfügen'], ['62:70']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Obwohl die Angestellten auf den Flugplätzen von Stockholm und Göteborg Überstunden schoben , schossen die Wartezeiten zeitweise auf bis zu 60 Stunden hoch .',
#   'opinions': [{'Source': [['Wartezeiten'], ['106:117']],
#     'Target': [[], []],
#     'Polar_expression': [['schoben'], ['83:90']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Vor einem Jahr konnte der Genfer Regierungsrat Pierre Maudet viele Parlamentarier von seinen Fähigkeiten überzeugen .',
#   'opinions': [{'Source': [['Regierungsrat'], ['33:46']],
#     'Target': [['Fähigkeiten'], ['93:104']],
#     'Polar_expression': [['überzeugen'], ['105:115']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Nein , den Tieren würden der Stolz und die Kraft fehlen .',
#   'opinions': [{'Source': [['Stolz'], ['29:34']],
#     'Target': [['Tieren'], ['11:17']],
#     'Polar_expression': [['fehlen'], ['49:55']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'Der Mobilfunkbetreiber Sunrise will seine Aktionäre mit einem neuen Vorschlag von der Übernahme des Kabelnetzbetreibers UPC überzeugen .',
#   'opinions': [{'Source': [['Mobilfunkbetreiber'], ['4:22']],
#     'Target': [['Übernahme'], ['86:95']],
#     'Polar_expression': [['überzeugen'], ['124:134']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'Ski alpin Bei der Ski-Weltmeisterschaft im chilenischen Portillo gewann Erika Schinegger 1966 Abfahrtsgold für Österreich .',
#   'opinions': [{'Source': [['Erika'], ['72:77']],
#     'Target': [['Abfahrtsgold'], ['94:106']],
#     'Polar_expression': [['gewann'], ['65:71']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': '2002 und 2016 hatte der heute 73-jährige Jurassier jeweils den Schweizer Filmpreis für den besten Animationsfilm gewonnen .',
#   'opinions': [{'Source': [['Jurassier'], ['41:50']],
#     'Target': [['Filmpreis'], ['73:82']],
#     'Polar_expression': [['gewonnen'], ['113:121']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  ...]

# %%
# evaluate the polar expression performance
print("test accuracy: {:.3f}".format(accuracy_score(gold_polarities, preds_full_label_text)))

print(classification_report(gold_polarities, preds_full_label_text))
# Out:
# test accuracy: 0.515
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.27      0.41       502
#      Neutral       0.42      0.91      0.57       402
#     Positive       0.65      0.41      0.50       308
#
#     accuracy                           0.51      1212
#    macro avg       0.67      0.53      0.50      1212
# weighted avg       0.69      0.51      0.49      1212

# %%
with open(DATADEST, "w", encoding="utf-8") as f:
    json.dump(out_data_w_entities_and_rel, f)

# %%
!(source ~/envs/perin-venv/bin/activate && cd ../../external_repos/direct_parsing_to_sent_graph/evaluation && python evaluate_single_dataset.py ../../../etl/data/processed/Perin_Preprocessing/01_test.json ../../../etl/data/processed/ORL_RE_Inference/01_test.json)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Source F1: 0.663
# Target F1: 0.416
# Expression F1: 0.677
# Unlabeled Sentiment Tuple F1: 0.232
# Sentiment Tuple F1: 0.147
# {
#   "source/f1": 0.6629039393384962,
#   "target/f1": 0.41608692302001826,
#   "expression/f1": 0.6773864577746334,
#   "sentiment_tuple/unlabeled_f1": 0.2318920429611943,
#   "sentiment_tuple/precision": 0.14664691615360367,
#   "sentiment_tuple/recall": 0.14742014742014742,
#   "sentiment_tuple/f1": 0.14703251520483418
# }
#
# [0.6629039393384962, 0.41608692302001826, 0.6773864577746334, 0.2318920429611943, 0.14664691615360367, 0.14742014742014742, 0.14703251520483418]
