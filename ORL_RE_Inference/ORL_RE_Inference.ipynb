# %% [markdown]
# ## ORL_RE_Inference
#
# Use the trained model to predict input sentences and bring them into a format accepted by the relation classifier.

# %%
import os
# DataSource in SSA-format
DATASOURCE="../../etl/data/processed/Perin_Preprocessing/01_test.json"
DATADEST="../../etl/data/processed/ORL_RE_Inference/01_test.json"

# DATASOURCE="../../etl/data/processed/Perin_Preprocessing/01_train.json"
# DATADEST="../../etl/data/processed/ORL_RE_Inference/01_train.json"

# DATASOURCE="../../etl/data/processed/REConverter/01_train_re.json"

VERIFY_RE_MODEL=False

# CONFIGS for NER
# CONFIG-VARIABLES
ORL_MODEL_PATH="../ORL/data/trained_model_german_bert"

# CONFIGS for RE
# GS_INPUT_DIR = "/content/drive/MyDrive/odsc-2022-data/NYT"
DATA_DIR = "../../etl/data/processed/REConverter"
splits = ["train", "test", "val"]
BASE_MODEL_NAME = "bert-base-german-cased"
# BASE_MODEL_NAME = "bert-base-cased"
MODEL_DIR = os.path.join("../RelationClassifier/data", "{:s}-re".format(BASE_MODEL_NAME))

# %% [markdown]
# ### Read-In the data
#
# Reading in the data so it can be processed. The format is SSA.

# %%
# makedirs if not exist
os.makedirs("../../etl/data/processed/ORL_RE_Inference", exist_ok=True)

# %%
opinion_interface = {'Source': [[], []], 
             'Target': [[], []], 
             'Polar_expression': [[], []], 
             'Polarity': None, 
             'Intensity': 'Average'}

# %%
import json
import copy

out_data = None
gold_polarities = []
def convert_ssa_to_sents(datasource):
    with open(datasource, "r", encoding="utf-8") as f:
        data = json.load(f)
    out_data = copy.deepcopy(data)
    sents = []
    for i, rec in enumerate(data):
        out_data[i]["opinions"] = [copy.deepcopy(opinion_interface)]
        # print(rec)
        sents.append(rec["text"])
        gold_polarities.append(rec["opinions"][0]["Polarity"])
    return sents, out_data

ssa_sents, out_data = convert_ssa_to_sents(DATASOURCE)

# %%
print(out_data)
# Out:
# [{'sent_id': '0', 'text': 'Andere Proteste entstanden wegen der seit Jahren miserablen Wirtschaftslage und der allumfassenden Korruption im Land und blieben meist regional .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '1', 'text': 'Flavia Schlittler Im Frühling 2015 wurde Nepal von verheerenden Erdbeben heimgesucht .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '2', 'text': 'Der Konflikt sorgte innerhalb der CVP , in der man in normalen Zeiten ungern öffentlich streitet , für erheblichen Ärger .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '3', 'text': 'Damals zerstörte ein Feuer das historische Gipfelhotel aus dem Jahr 1893 – ein grosser Verlust .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '4', 'text': 'Vor zehn Jahren scheiterte ein Freihandelsabkommen mit den USA am Widerstand der Landwirtschaft .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '5', 'text': 'Die Besinnung auf das Einzigartige der eigenen Bestände gab die Richtung vor : Keine andere Bibliothek widmet sich so gezielt und umfassend der Schnittstelle von Religion und Gesellschaft , Glaube und Philosophie , interreligiösem Gespräch , Kunst , Kultur und Themen der Zivilgesellschaft .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '6', 'text': 'Die Regulierungsbehörden sorgen sich über die enormen Summen , die von den Stablecoin-Anbietern eingesammelt wurden und werden , ohne dass das amerikanische Bankensystem involviert ist .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '7', 'text': 'Der Verteidiger des Beschuldigten , der während der Verhandlung von seinem Aussageverweigerungsrecht Gebrauch machte , plädierte auf Freispruch .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '8', 'text': 'Ein Streichelzoo sorgt für Abwechslung bei den Kleinsten .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '9', 'text': 'Zweimal stimmten die Freisinnigen geschlossen dagegen , abgesehen von einer Handvoll Enthaltungen .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '10', 'text': 'Die grösste Demokratie der Welt muss aber auch die lauten und unangenehmen Stimmen aushalten können .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '11', 'text': 'Eine ähnliche Frage stellte sich bei Alexis Sánchez , dem wirbligen chilenischen Stürmer , den man mit allen Mitteln der Überredungskunst Arsenal abgeworben hatte .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '12', 'text': 'Die Gesichtszüge sind unter der Maske nicht zu erkennen , die Gestik verrät aber den Gemütszustand : Jeannine Gmelin freut sich über die Bronzemedaille und schwenkt die Schweizer Fahne .', 'opinions': [{'Source': [[], []], 'Target': [[], []], 'Polar_expression': [[], []], 'Polarity': None, 'Intensity': 'Average'}]}, {'sent_id': '13', 'text': 'Immer auch auf die Gefahr hin , dass Kritiker uns an den Öko-Pranger stellen und uns die liberale Gesinnung absprechen .', 'opinions': [{' ...

# %% [markdown]
# ### Target Holder PolarExpression Extraction
#
# **Extract Target-Holder-Expression-Pairs**

# %%
# Load the ORL model.
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

model_path = ORL_MODEL_PATH

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)

pipe = pipeline(task="token-classification",
                # model=trainer.model, -- in case freshly trained
                model=model,
                tokenizer=tokenizer,
                aggregation_strategy="first"
               )

classified = pipe("Der Mann erschiesst seine Frau.")

print(classified)
# Out:
# [{'entity_group': 'LABEL_0', 'score': 0.99897814, 'word': 'Der', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_1', 'score': 0.99242157, 'word': 'Mann', 'start': 4, 'end': 8}, {'entity_group': 'LABEL_3', 'score': 0.99666035, 'word': 'erschiesst', 'start': 9, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.9993655, 'word': 'seine', 'start': 20, 'end': 25}, {'entity_group': 'LABEL_2', 'score': 0.9913374, 'word': 'Frau', 'start': 26, 'end': 30}, {'entity_group': 'LABEL_0', 'score': 0.999114, 'word': '.', 'start': 30, 'end': 31}]

# %%
from typing import NamedTuple

class PAS(NamedTuple):
    arg1: str
    arg2: str
    pexp: str

# %%
label_mapper = {
    "LABEL_0": "NEUTRAL",
    "LABEL_1": "HOLDER",
    "LABEL_2": "TARGET",
    "LABEL_3": "PEXP",
}

def extract_args(bert_output):
    """Obtain arguments from a dict-list of a BERT model."""
    # the holder is the first argument, the target is the second argument
    arg1=None
    arg2=None
    pexp=None
    for c in bert_output:
        if label_mapper[c["entity_group"]] == "HOLDER":
            arg1=c["word"]
        elif label_mapper[c["entity_group"]] == "TARGET":
            arg2=c["word"]
        elif label_mapper[c["entity_group"]] == "PEXP":
            pexp=c["word"]
        else:
            pass
        
    # if one is none, fill it by using the highest probability overall.

    return arg1, arg2, pexp

# %%
# Function doing the heavy lifting, here we assume one relation per sentence (no compositionality).
def extract_pas(sentence_string):
    # sentence with holder / target labels
    labelled_sentence = pipe(sentence_string)
    # obtain arguments from labels
    arg1, arg2, pexp = extract_args(labelled_sentence)
    return PAS(arg1, arg2, pexp)

print(extract_pas("Die Berliner Morgenpost hat den Angriff auf die Ukraine kritisiert."))
# Out:
# PAS(arg1='Morgenpost', arg2='Angriff', pexp='kritisiert')

# %% [markdown]
# ### Generate unbreakable tokens based on input sentence + ORL inference
#
# **Important**: We make sure that every sentence contains a dot in the end that is separated from the last word in the sentence!

# %%
# simplified_training_data
import re
import copy
from tqdm import tqdm

def identify_from_base_sent(target_word, base_sent):
    res = re.search(target_word, base_sent)
    return res.span()

def generate_head_based_entity_sentences(sentences, out_data=[]):
    entified_list = []
    ret_od = []
    for i, sent in tqdm(enumerate(sentences)):
        pas = extract_pas(sent)
        od = copy.deepcopy(out_data[i])
        base_sent = copy.deepcopy(sent)
        # print(pas)
        try:
            if pas.arg1:
                res = re.search(pas.arg1, sent)
                e1_s, e1_e = res.span()
                # print(out_data[i]["opinions"][0]["Source"])
                sent = sent[0:max(0, e1_s - 1)] + " <eSOURCE> " + sent[e1_s:min(len(sent), e1_e)] + " </eSOURCE> " + sent[min(len(sent), e1_e + 1):]
                
                e1_s, e1_e = identify_from_base_sent(pas.arg1, base_sent)
                od["opinions"][0].update({ "Source": [[base_sent[e1_s:min(len(sent), e1_e)]], [f"{str(e1_s)}:{str(e1_e)}"]] })

            if pas.arg2:
                res = re.search(pas.arg2, sent)
                e2_s, e2_e = res.span()
                sent = sent[0:max(0, e2_s - 1)] + " <eTARGET> " + sent[e2_s:min(len(sent), e2_e)] + " </eTARGET> " + sent[min(len(sent), e2_e + 1):]
                
                e2_s, e2_e = identify_from_base_sent(pas.arg2, base_sent)
                od["opinions"][0]["Target"] = [[base_sent[e2_s:min(len(sent), e2_e)]], [f"{str(e2_s)}:{str(e2_e)}"]]

            if pas.pexp:
                res = re.search(pas.pexp, sent)
                e3_s, e3_e = res.span()
                sent = sent[0:max(0, e3_s - 1)] + " <ePEXP> " + sent[e3_s:min(len(sent), e3_e)] + " </ePEXP> " + sent[min(len(sent), e3_e + 1):]
                
                e3_s, e3_e = identify_from_base_sent(pas.pexp, base_sent)
                od["opinions"][0]["Polar_expression"] = [[base_sent[e3_s:min(len(sent), e3_e)]], [f"{str(e3_s)}:{str(e3_e)}"]]


            for tag, expression in [("SOURCE", pas.arg1), ("TARGET", pas.arg2), ("PEXP", pas.pexp)]:
                if expression is None:
                    # res = re.search("(\.|\!)\s*?(<\/.*>)?\s*?$", sent)
                    res = re.search("(\.|\!)", sent)
                    if res is None:
                        sent += " ."
                    res = re.search("(\.|\!)", sent)
                    e_nf_s, e_nf_e = res.span()
                    #print(f"{ e_nf_s} ; {e_nf_e}")
                    sent = sent[0:max(0, e_nf_s - 1)] + f" <e{tag}> " + sent[e_nf_s:min(len(sent), e_nf_e)] + f" </e{tag}> " + sent[min(len(sent), e_nf_e + 1):]
                    
            # print(od[i]["opinions"][0])
            
            assert all([tag in sent for tag in ["<eTARGET>", "</eTARGET>", "<eSOURCE>", "</eSOURCE>", "<ePEXP>", "</ePEXP>"]]), "Not all tags present in sentence, falling back to trivial."

        except Exception as e:
            print(f"Something went wrong with extraction, {str(e)}, \n with sent {str(sent)} and sample # {i}")
            print("Trivialised!")
            # spaceholder
            # entified_list.append("Neutral <eSOURCE> . </eSOURCE> <eTARGET> . </eTARGET> <ePEXP> . </ePEXP>")
            od["text"] = "Neutral . .. ..."
            entified_list.append("Neutral <eSOURCE> . </eSOURCE> <eTARGET> .. </eTARGET> <ePEXP> ... </ePEXP>")
            od["opinions"][0].update({ "Source": [["."], ["8:9"]] })
            od["opinions"][0].update({ "Target": [[".."], ["10:12"]] })
            od["opinions"][0].update({ "Polar_expression": [["..."], ["13:16"]] })
            ret_od.append(od)
            continue

        entified_list.append(sent)
        # print(od)
        ret_od.append(od)
    return entified_list, ret_od

test_sents = ["Macron hat die Frau geliebt!",
"Jakob liebt Brigitte .",
 "Der Mann weiss nicht mehr wo er ist .",
 "Viele Personen sind von Haifischen ermordet worden .",
 "Liebe .",
 "Peter greift Michaela auf .",]

# entified_list = generate_head_based_entity_sentences()

# print(entified_list)
# don't forget stripping!
# print("\n")
# X = {"tokens": [e.strip().split() for e in entified_list]}
# print(X)

# %%
tagged_ssa_sents, out_data_w_entities = generate_head_based_entity_sentences(ssa_sents, out_data)
# Out:
# 872it [00:27, 29.73it/s]
# Something went wrong with extraction, Not all tags present in sentence, falling back to trivial.,
#  with sent  < <eTARGET> S </eTARGET> URCE> Ähnliches </eSOURCE> <ePEXP> gilt </ePEXP> für die S 24 , die von Zürich über den Flughafen stündlich bis nach Thayngen und nach Weinfelden verkehrt . and sample # 866
# Trivialised!
# 3775it [02:03, 32.30it/s]
# Something went wrong with extraction, 'NoneType' object has no attribute 'span',
#  with sent Nach 25 Minuten sche <eTARGET> ter </eTARGET>  der Dortmunder <eSOURCE> Captain </eSOURCE> erstmals an ter Stegen , aus fünf Metern nur . and sample # 3769
# Trivialised!
# 5323it [02:55, 30.40it/s]

# %%
tokenized_ssa_sents = {"tokens": [e.strip().split() for e in tagged_ssa_sents]}

# %%
out_data_w_entities
# Out:
# [{'sent_id': '0',
#   'text': 'Andere Proteste entstanden wegen der seit Jahren miserablen Wirtschaftslage und der allumfassenden Korruption im Land und blieben meist regional .',
#   'opinions': [{'Source': [['Proteste'], ['7:15']],
#     'Target': [[], []],
#     'Polar_expression': [['entstanden'], ['16:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': 'Flavia Schlittler Im Frühling 2015 wurde Nepal von verheerenden Erdbeben heimgesucht .',
#   'opinions': [{'Source': [['Nepal'], ['41:46']],
#     'Target': [['Erdbeben'], ['64:72']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Der Konflikt sorgte innerhalb der CVP , in der man in normalen Zeiten ungern öffentlich streitet , für erheblichen Ärger .',
#   'opinions': [{'Source': [['Konflikt'], ['4:12']],
#     'Target': [['Ärger'], ['115:120']],
#     'Polar_expression': [['sorgte'], ['13:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Damals zerstörte ein Feuer das historische Gipfelhotel aus dem Jahr 1893 – ein grosser Verlust .',
#   'opinions': [{'Source': [['Feuer'], ['21:26']],
#     'Target': [['Gipfelhotel'], ['43:54']],
#     'Polar_expression': [['zerstörte'], ['7:16']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': 'Vor zehn Jahren scheiterte ein Freihandelsabkommen mit den USA am Widerstand der Landwirtschaft .',
#   'opinions': [{'Source': [['Freihandelsabkommen'], ['31:50']],
#     'Target': [['Widerstand'], ['66:76']],
#     'Polar_expression': [['scheiterte'], ['16:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'Die Besinnung auf das Einzigartige der eigenen Bestände gab die Richtung vor : Keine andere Bibliothek widmet sich so gezielt und umfassend der Schnittstelle von Religion und Gesellschaft , Glaube und Philosophie , interreligiösem Gespräch , Kunst , Kultur und Themen der Zivilgesellschaft .',
#   'opinions': [{'Source': [['Bibliothek'], ['92:102']],
#     'Target': [['Schnittstelle'], ['144:157']],
#     'Polar_expression': [['widmet'], ['103:109']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Die Regulierungsbehörden sorgen sich über die enormen Summen , die von den Stablecoin-Anbietern eingesammelt wurden und werden , ohne dass das amerikanische Bankensystem involviert ist .',
#   'opinions': [{'Source': [['Regulierungsbehörden'], ['4:24']],
#     'Target': [['Summen'], ['54:60']],
#     'Polar_expression': [['sorgen'], ['25:31']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Der Verteidiger des Beschuldigten , der während der Verhandlung von seinem Aussageverweigerungsrecht Gebrauch machte , plädierte auf Freispruch .',
#   'opinions': [{'Source': [['Verteidiger'], ['4:15']],
#     'Target': [['Freispruch'], ['133:143']],
#     'Polar_expression': [['plädierte'], ['119:128']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Ein Streichelzoo sorgt für Abwechslung bei den Kleinsten .',
#   'opinions': [{'Source': [['Streichelzoo'], ['4:16']],
#     'Target': [['Kleinsten'], ['47:56']],
#     'Polar_expression': [['sorgt'], ['17:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Zweimal stimmten die Freisinnigen geschlossen dagegen , abgesehen von einer Handvoll Enthaltungen .',
#   'opinions': [{'Source': [['Freisinnigen'], ['21:33']],
#     'Target': [[], []],
#     'Polar_expression': [['stimmten'], ['8:16']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': 'Die grösste Demokratie der Welt muss aber auch die lauten und unangenehmen Stimmen aushalten können .',
#   'opinions': [{'Source': [['Demokratie'], ['12:22']],
#     'Target': [['Stimmen'], ['75:82']],
#     'Polar_expression': [['aushalten'], ['83:92']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': 'Eine ähnliche Frage stellte sich bei Alexis Sánchez , dem wirbligen chilenischen Stürmer , den man mit allen Mitteln der Überredungskunst Arsenal abgeworben hatte .',
#   'opinions': [{'Source': [['Frage'], ['14:19']],
#     'Target': [['Alexis'], ['37:43']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Die Gesichtszüge sind unter der Maske nicht zu erkennen , die Gestik verrät aber den Gemütszustand : Jeannine Gmelin freut sich über die Bronzemedaille und schwenkt die Schweizer Fahne .',
#   'opinions': [{'Source': [['Jeannine'], ['101:109']],
#     'Target': [['Bronzemedaille'], ['137:151']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Immer auch auf die Gefahr hin , dass Kritiker uns an den Öko-Pranger stellen und uns die liberale Gesinnung absprechen .',
#   'opinions': [{'Source': [['Kritiker'], ['37:45']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Die Nationalrätin nennt ein Beispiel : Wenn sich der Grundstückpreis einer Liegenschaft bei einer Neubewertung verdoppelt , müssen sich auch die Mieten verdoppeln .',
#   'opinions': [{'Source': [['Grundstückpreis'], ['53:68']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': 'Madonna entschuldigt sich bei ihren Anhängern : « Ich muss mich erholen » , erklärt sie .',
#   'opinions': [{'Source': [['Madonna'], ['0:7']],
#     'Target': [['Anhängern'], ['36:45']],
#     'Polar_expression': [['entschuldigt'], ['8:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Das bis heute aufgrund seiner repräsentativen Bürger- und Gasthäuser städtisch wirkende Dorf Einsiedeln wurde von Hugo Kopp noch vor dem in den 1960er Jahren einsetzenden Wachstumsschub so aus dem Flugzeug aufgenommen , dass es präzise von seinen beiden wichtigsten Baukomplexen gefasst wird .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Sofort stellte sich der mächtige Generalsekretär Toshihiro Nikai ( 81 ) auf Sugas Seite .',
#   'opinions': [{'Source': [['Generalsekretär'], ['33:48']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Eine Millionärsgattin verliebte sich vor 26 Jahren in einen Polizisten der Kantonspolizei St. Gallen .',
#   'opinions': [{'Source': [['Millionärsgattin'], ['5:21']],
#     'Target': [['Polizisten'], ['60:70']],
#     'Polar_expression': [['verliebte'], ['22:31']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': 'Nach dem Match entschuldigte sich Shapovalov für seine vorwurfsvolle Formulierung , er hielt aber an seiner grundsätzlichen Kritik fest .',
#   'opinions': [{'Source': [['Shapovalov'], ['34:44']],
#     'Target': [['Formulierung'], ['69:81']],
#     'Polar_expression': [['entschuldigte'], ['15:28']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Doch auch in diesem Fall stellen sich heikle rechtliche und vollzugstechnische Herausforderungen .',
#   'opinions': [{'Source': [['Herausforderungen'], ['79:96']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Israel hatte dagegen mit einem Kampfhelikopter eine Drohne abgeschossen , die gemäss Israel von Revolutionsgardisten in Syrien gestartet worden war .',
#   'opinions': [{'Source': [['Israel'], ['0:6']],
#     'Target': [['Drohne'], ['52:58']],
#     'Polar_expression': [['abgeschossen'], ['59:71']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Frankfurts Daichi Kamada trifft zweimal und schiesst Arsenal ab .',
#   'opinions': [{'Source': [['Daichi'], ['11:17']],
#     'Target': [['Arsenal'], ['53:60']],
#     'Polar_expression': [['schiesst'], ['44:52']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Das unterste Segment leidet derweil unter der Konkurrenz der Smartwatches .',
#   'opinions': [{'Source': [['Segment'], ['13:20']],
#     'Target': [['Konkurrenz'], ['46:56']],
#     'Polar_expression': [['leidet'], ['21:27']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'In Biel stellt sich die Frage nicht .',
#   'opinions': [{'Source': [['Frage'], ['24:29']],
#     'Target': [['Biel'], ['3:7']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'Weber achtet auf gute Unternehmensführung .',
#   'opinions': [{'Source': [['Weber'], ['0:5']],
#     'Target': [['Unternehmensführung'], ['22:41']],
#     'Polar_expression': [['achtet'], ['6:12']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': 'Als im Juli das viel zu langsam gestartete Impfprogramm endlich Tempo aufnahm und sie einen Termin bekam , dokumentierte Samuels ihre erste Impfung auf Facebook .',
#   'opinions': [{'Source': [['Samuels'], ['121:128']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnahm'], ['70:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Theater Christoph Marthaler hat für ein Bühnenstück Zitate von Christa Rigozzi zum Thema Apéro benutzt , ohne sie zu deklarieren .',
#   'opinions': [{'Source': [['Theater'], ['0:7']],
#     'Target': [[], []],
#     'Polar_expression': [['benutzt'], ['95:102']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Juan Carbuccia hat mit seinem Handy eine Stunde vor Eintreffen des Besuchers ein Video aufgenommen .',
#   'opinions': [{'Source': [['Juan'], ['0:4']],
#     'Target': [[], []],
#     'Polar_expression': [['aufgenommen'], ['87:98']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'In ersten Reaktionen plädierten am Sonntag allerdings auch die Gegner von « 7 statt 9 » für Effizienzverbesserungen in der Stadtverwaltung .',
#   'opinions': [{'Source': [['Gegner'], ['63:69']],
#     'Target': [['Effizienzverbesserungen'], ['92:115']],
#     'Polar_expression': [['plädierten'], ['21:31']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Schulden seien « gratis » , also dürfe der Staat bedenkenlos Geld für Hilfen und Investitionen aufnehmen .',
#   'opinions': [{'Source': [['Staat'], ['43:48']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': '( red ) Corona Japans Ministerpräsident Shinzo Abe hat zinslose Kredite für Firmen angekündigt , die von der Coronavirus-Epidemie betroffen sind .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['22:39']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['83:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'Die Frau habe gezielt auf den am Boden liegenden , wehrlosen Mann geschossen .',
#   'opinions': [{'Source': [['Frau'], ['4:8']],
#     'Target': [['Mann'], ['61:65']],
#     'Polar_expression': [['geschossen'], ['66:76']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Journalisten schliesslich überschätzen die Rhetorik notorisch .',
#   'opinions': [{'Source': [['Journalisten'], ['0:12']],
#     'Target': [['Rhetorik'], ['43:51']],
#     'Polar_expression': [['überschätzen'], ['26:38']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Nun , im zweiten Teil , widmet sich das Gericht den sieben Privatklägern und den Zeugen .',
#   'opinions': [{'Source': [['Gericht'], ['40:47']],
#     'Target': [['Privatklägern'], ['59:72']],
#     'Polar_expression': [['widmet'], ['24:30']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Und schliesslich stellen sich bei Negativzinsen ungewöhnliche Rechtsfragen .',
#   'opinions': [{'Source': [['Rechtsfragen'], ['62:74']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Mirko Salvi , der Mann aus Yverdon , stellt sich seit letztem Donnerstag einer neuen Herausforderung .',
#   'opinions': [{'Source': [['Mirko'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'Obergösgen SO – Am Donnerstagabend überfiel ein 49-jähriger Italiener mit einem gezückten Messer ein Detailhandelsgeschäft und erbeutete mehrere Hundert Franken .',
#   'opinions': [{'Source': [['Italiener'], ['60:69']],
#     'Target': [['Detailhandelsgeschäft'], ['101:122']],
#     'Polar_expression': [['überfiel'], ['35:43']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Thomas Bach , der Chef des Internationalen Olympischen Komitees , hat sich bei einem Mann ganz besonders für die Siege bei den Olympischen Spielen zu bedanken : bei Japans Ministerpräsidenten Yoshihide Suga .',
#   'opinions': [{'Source': [['Thomas'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['bedanken'], ['150:158']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Insgesamt hat die iranische Regierung in der vergangenen Woche rund 85 000 Gefangene vorübergehend aus den Gefängnissen entlassen .',
#   'opinions': [{'Source': [['Regierung'], ['28:37']],
#     'Target': [[], []],
#     'Polar_expression': [['entlassen'], ['120:129']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Die Zürcher Volkswirtschaftsdirektorin sorgt sich aber nicht in erster Linie um die Touristen , sondern um die Zürcher Geschäfte , denen wegen des Sonntagsverkaufsverbots Einnahmen entgehen .',
#   'opinions': [{'Source': [['Volkswirtschaftsdirektorin'], ['12:38']],
#     'Target': [['Touristen'], ['84:93']],
#     'Polar_expression': [['sorgt'], ['39:44']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Damit diskreditiert Fasel den ganzen Eishockey-Sport .',
#   'opinions': [{'Source': [['Fasel'], ['20:25']],
#     'Target': [['Eishockey'], ['37:46']],
#     'Polar_expression': [['diskreditiert'], ['6:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'Nach dem Treffen am vergangenen Dienstag wurden die vier Menschenrechtler zunächst von der regimetreuen Presse als « Verräter » oder « ausländische Agenten » beschimpft .',
#   'opinions': [{'Source': [['Menschenrechtler'], ['57:73']],
#     'Target': [[], []],
#     'Polar_expression': [['beschimpft'], ['158:168']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Der pakistanische Ministerpräsident Imran Khan hatte die Freilassung am Donnerstag in einer Rede vor dem Parlament in Islamabad angekündigt .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['18:35']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['128:139']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'Stephanie Erne ... spielt ebenfalls in Luzern und hat eine 80-Prozent-Stelle als Spezialistin für Bewegungs- und Gesundheitsförderung – daneben gilt ihr Engagement dem FI9-Verein .',
#   'opinions': [{'Source': [['Engagement'], ['153:163']],
#     'Target': [['Verein'], ['172:178']],
#     'Polar_expression': [['gilt'], ['144:148']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Der Kanton hat eine Untersuchung angekündigt .',
#   'opinions': [{'Source': [['Kanton'], ['4:10']],
#     'Target': [['Untersuchung'], ['20:32']],
#     'Polar_expression': [['angekündigt'], ['33:44']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': 'Zwar ist im Gesetzestext nirgendwo von Impfungen die Rede , und der Bund hat die Verdächtigungen immer zurückgewiesen .',
#   'opinions': [{'Source': [['Bund'], ['68:72']],
#     'Target': [['Verdächtigungen'], ['81:96']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Gemäss Informationen der Tessiner Kantonspolizei stürzte die 30-Jährige mehrere Meter in die Tiefe .',
#   'opinions': [{'Source': [['Jährige'], ['64:71']],
#     'Target': [[], []],
#     'Polar_expression': [['stürzte'], ['49:56']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'Polemik Am 6. Juni will die Schweizer Kulturszene den Neustart wagen .',
#   'opinions': [{'Source': [['Kulturszene'], ['38:49']],
#     'Target': [['Neustart'], ['54:62']],
#     'Polar_expression': [['wagen'], ['63:68']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': 'Eine unabhängige Aufsichtskommission ; schärfere Datenschutzbestimmung ; die Möglichkeit für den Bund , sich an Anbietern eines digitalen Passes zu beteiligen – immer zeigte sich dasselbe Muster : Eine klare bürgerliche Mehrheit stellte sich gegen die Empfehlung Keller-Sutters , die zusammen mit den Linken die Variante des Ständerats unterstützte .',
#   'opinions': [{'Source': [['Mehrheit'], ['220:228']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Bei den Männern triumphiert Rudy von Berg ( USA ) in 3 : 42 : 17 ähnlich überlegen wie Ryf .',
#   'opinions': [{'Source': [['Rudy'], ['28:32']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': 'Die Walliser jubeln im Cornaredo nach den beiden Lugano-Schockern .',
#   'opinions': [{'Source': [['Walliser'], ['4:12']],
#     'Target': [['Lugano'], ['49:55']],
#     'Polar_expression': [['jubeln'], ['13:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Die grösste Partei im Parlament , Ennahda , warf dem Präsidenten einen « Putsch gegen die Revolution und die Verfassung » vor – eine Referenz auf den Arabischen Frühling 2011 , als die Tunesier den langjährigen Diktator Zine al-Abedine Ben Ali gestürzt hatten .',
#   'opinions': [{'Source': [['Tunesier'], ['185:193']],
#     'Target': [['Präsidenten'], ['53:64']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'Er sprach von der Enttäuschung über die Niederlage , YB habe zwei Unaufmerksamkeiten ausgenutzt , aber Klose fand , dass es der FCB « nicht so schlecht gemacht und gut verteidigt » habe .',
#   'opinions': [{'Source': [['YB'], ['53:55']],
#     'Target': [['Unaufmerksamkeiten'], ['66:84']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': '« Interventionen beim Umweltminister führten lediglich zu netten Floskeln . » Man gewinnt den Eindruck , selbst von Helfern versuche die Regierung möglichst viel Geld abzupressen .',
#   'opinions': [{'Source': [['Regierung'], ['137:146']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Der Betrieb musste , abgesehen vom Gastrobereich , ohnehin aufrechterhalten bleiben .',
#   'opinions': [{'Source': [['Betrieb'], ['4:11']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Obschon ihre Schönheit wie eh und je betört : In den riesigen Sälen der stilvollen alten Hotelpaläste und stuckübersäten Villen stellt sich statt des früheren Schwelgens immer öfter die bange Frage ein , wer für die Bewahrung all der historischen Pracht aufkommen kann .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Bewahrung'], ['216:225']],
#     'Polar_expression': [['aufkommen'], ['254:263']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Thelesklaf nennt ein Beispiel : Eine Bank dürfe einen Verdacht zwar an die MROS weiterleiten , nicht aber an eine andere Bank .',
#   'opinions': [{'Source': [['Bank'], ['37:41']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Daraufhin beschwerte sich die Frau beim Presserat .',
#   'opinions': [{'Source': [['Frau'], ['30:34']],
#     'Target': [['Presserat'], ['40:49']],
#     'Polar_expression': [['beschwerte'], ['10:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Thomas Fuster · Das World Economic Forum ( WEF ) sorgt sich um Davos .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Davos'], ['63:68']],
#     'Polar_expression': [['sorgt'], ['49:54']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Anscheinend will oder kann der Casino-Boss das Thema doch nicht ganz totschweigen .',
#   'opinions': [{'Source': [['Boss'], ['38:42']],
#     'Target': [['Thema'], ['47:52']],
#     'Polar_expression': [['totschweigen'], ['69:81']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'Schliesslich hat Netflix für dieses Jahr bereits achtzig Eigenproduktionen angekündigt , die meisten davon werden in dem mit Amerika und Asien vergleichsweise weniger starken Markt Europa nicht die Lichtspielhäuser erreichen .',
#   'opinions': [{'Source': [['Netflix'], ['17:24']],
#     'Target': [['Lichtspielhäuser'], ['198:214']],
#     'Polar_expression': [['erreichen'], ['215:224']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Mit ihrem Positionsbezug stellt sich die Bundesrätin auch gegen eine Aufforderung von Donald Trump .',
#   'opinions': [{'Source': [['Bundesrätin'], ['41:52']],
#     'Target': [['Aufforderung'], ['69:81']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'Aber in einer Zeit , in der Medien unter dem Druck stehen , Nachrichten möglichst rasch online zu veröffentlichen , und keine Zeit für tiefgreifendere Analysen bleibt , führt eine schönfärberische Kommunikationspolitik zu Verzerrungen – in der Öffentlichkeit entsteht ein Bild , das die Realität nur ungenau spiegelt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['entsteht'], ['259:267']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'Und für einmal übertreibt der Präsident mit dieser Aussage nicht .',
#   'opinions': [{'Source': [['Präsident'], ['30:39']],
#     'Target': [['Aussage'], ['51:58']],
#     'Polar_expression': [['übertreibt'], ['15:25']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'Gemäss ersten Erkenntnissen brach auch der Funkkontakt ab .',
#   'opinions': [{'Source': [['Funkkontakt'], ['43:54']],
#     'Target': [[], []],
#     'Polar_expression': [['brach'], ['28:33']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Auf der anderen Seite freut sich Federer bei der ganzen Routine im Tour-Kalender auf ein neues Kapitel : « Key Biscayne war schön , lässig , hatte Geschichte .',
#   'opinions': [{'Source': [['Federer'], ['33:40']],
#     'Target': [['Kapitel'], ['95:102']],
#     'Polar_expression': [['freut'], ['22:27']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Auf Dauer könne Russland die internationale Isolation aber nicht durchhalten .',
#   'opinions': [{'Source': [['Russland'], ['16:24']],
#     'Target': [['Isolation'], ['44:53']],
#     'Polar_expression': [['durchhalten'], ['65:76']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': 'Einsichtig : FCB-Youngster Sebastiano Esposito hat sich vor versammelter Mannschaft für sein Verhalten entschuldigt .',
#   'opinions': [{'Source': [['Youngster'], ['17:26']],
#     'Target': [['Verhalten'], ['93:102']],
#     'Polar_expression': [['entschuldigt'], ['103:115']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Dass sich Cesla Amarelle und Silvia Steiner für den Austausch einsetzen , hat auch persönliche Gründe .',
#   'opinions': [{'Source': [['Cesla'], ['10:15']],
#     'Target': [['Austausch'], ['52:61']],
#     'Polar_expression': [['einsetzen'], ['62:71']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'Auch weil London Steuerprivilegien abschafft , zieht es vermögende Russen in die Schweiz .',
#   'opinions': [{'Source': [['London'], ['10:16']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': 'In der vergangenen Woche hatten Exxon-Mobil und Chevron deutliche Produktionssteigerungen im texanischen Permian Basin angekündigt .',
#   'opinions': [{'Source': [['Mobil'], ['38:43']],
#     'Target': [['Produktionssteigerungen'], ['66:89']],
#     'Polar_expression': [['angekündigt'], ['119:130']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Die vom Bankier Claudio Segré gegründete Stiftung widmet sich dem Schutz der Biodiversität .',
#   'opinions': [{'Source': [['Stiftung'], ['41:49']],
#     'Target': [['Schutz'], ['66:72']],
#     'Polar_expression': [['widmet'], ['50:56']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Der grosse Handelsbilanzüberschuss der Schweiz bei Medikamenten missfällt der Administration von Donald Trump .',
#   'opinions': [{'Source': [['Handelsbilanzüberschuss'], ['11:34']],
#     'Target': [['Administration'], ['78:92']],
#     'Polar_expression': [['missfällt'], ['64:73']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'Langsam aber stellte sich im Land der Durchhalteparolen eine neue Lust am Essen – und an dessen Zubereitung – ein : ein Prozess , der in den fünfziger Jahren begann und in den Achtzigern so richtig in Schwung kam .',
#   'opinions': [{'Source': [['Lust'], ['66:70']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'Bisher hatten sich die Vereinigten Staaten mit Verkäufen von Angriffswaffen zurückgehalten , um China nicht zu reizen .',
#   'opinions': [{'Source': [['Vereinigten Staaten'], ['23:42']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'Chefärzte nutzen ihre Position aus , um sich zu bereichern .',
#   'opinions': [{'Source': [['Chefärzte'], ['0:9']],
#     'Target': [['Position'], ['22:30']],
#     'Polar_expression': [['nutzen'], ['10:16']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Damit verfügen die Konservativen seit anderthalb Jahren über eine klarere Mehrheit im neunköpfigen Gremium , weil Kavanaugh den moderaten Konservativen Anthony Kennedy ersetzte , der als Zünglein an der Waage oft auch den progressiven Richtern zu einer Mehrheit verholfen hatte .',
#   'opinions': [{'Source': [['Kavanaugh'], ['114:123']],
#     'Target': [[], []],
#     'Polar_expression': [['ersetzte'], ['168:176']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Diesem Trend scheint sich jetzt der Verlegerverband zusehends anzupassen , gemäss dem Motto : Wenn schon gefördert wird , dann wollen wir auch teilhaben .',
#   'opinions': [{'Source': [['Verlegerverband'], ['36:51']],
#     'Target': [['Trend'], ['7:12']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': '« Wir haben ihn mithilfe eines Defibrillator-Einsatzes zurückbekommen » , sagte Boesen , « und das relativ schnell . » Offenbar genügte eine einzige Defibrillation , um den Sportler vor dem Tod zu bewahren .',
#   'opinions': [{'Source': [['Defibrillation'], ['149:163']],
#     'Target': [['Tod'], ['190:193']],
#     'Polar_expression': [['bewahren'], ['197:205']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'Nur dem Vater fehlte immer noch das begehrte rote Büchlein .',
#   'opinions': [{'Source': [['Büchlein'], ['50:58']],
#     'Target': [['Vater'], ['8:13']],
#     'Polar_expression': [['fehlte'], ['14:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Mehrere Regionalspitäler haben die monetären Fehlanreize bereits aus ihren Vergütungssystemen entfernt .',
#   'opinions': [{'Source': [['Regionalspitäler'], ['8:24']],
#     'Target': [['Vergütungssystemen'], ['75:93']],
#     'Polar_expression': [['entfernt'], ['94:102']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Der Code wird zu einer Sprachgewalt , deren Grammatik unseren Alltag prägt .',
#   'opinions': [{'Source': [['Code'], ['4:8']],
#     'Target': [['Alltag'], ['62:68']],
#     'Polar_expression': [['prägt'], ['69:74']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'sak . · Zwischen 1998 und 2001 ermordete die weissrussische Spezialeinheit Sobr rund dreissig Menschen .',
#   'opinions': [{'Source': [['Spezialeinheit'], ['60:74']],
#     'Target': [['Menschen'], ['94:102']],
#     'Polar_expression': [['ermordete'], ['31:40']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': '100000 zusätzliche Menschen soll die Stadt Zürich in den nächsten gut zwanzig Jahren aufnehmen .',
#   'opinions': [{'Source': [['Stadt'], ['37:42']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnehmen'], ['85:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Damit ist La Scintilla das einzige Originalklang-Ensemble , dessen Mitglieder sich nicht ausschliesslich der historisch informierten Musizierpraxis widmen , sondern auch im « normalen » Opernbetrieb mitmachen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Musizierpraxis'], ['133:147']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Für ein Ja plädierte in Bern dann allerdings einzig die an der Universität Zürich lehrende Politologin Elham Manea .',
#   'opinions': [{'Source': [['Politologin'], ['91:102']],
#     'Target': [['Ja'], ['8:10']],
#     'Polar_expression': [['plädierte'], ['11:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Der Aktienkurs schoss bis Mitte Juni auf mehr als 400 Pence .',
#   'opinions': [{'Source': [['Aktienkurs'], ['4:14']],
#     'Target': [['Pence'], ['54:59']],
#     'Polar_expression': [['schoss'], ['15:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Eben wurde von der Wohngemeinschaft erwogen , das freie Zimmer einem Flüchtling zu vermieten , da stellt sich Doro , die Pragmatikerin , in der Mitte der Küche auf und feuert : « Ich hasse arabische Männer !',
#   'opinions': [{'Source': [['Doro'], ['110:114']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': 'Nun , nach seiner Verurteilung und dem Bekanntwerden der Grüsel-Vorwürfe , sorgt sich Fäh um die Zukunft des Sternen : « Ich befürchte , wir verkraften das nicht .',
#   'opinions': [{'Source': [['Fäh'], ['86:89']],
#     'Target': [['Zukunft'], ['97:104']],
#     'Polar_expression': [['sorgt'], ['75:80']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Damit rückt der angekündigte , grund \xad - legende Strategiewechsel in weite Ferne : Ursprünglich wollte der Bundesrat im zweiten Teil der Energiewende die Förderbeiträge sukzessive abschaffen und stattdessen ein Lenkungssystem einführen .',
#   'opinions': [{'Source': [['Bundesrat'], ['107:116']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Alfredo Binda dominierte in den 1920er-Jahren den Giro derart , dass die Organisatoren ihren eigenen Landsmann bestachen .',
#   'opinions': [{'Source': [['Organisatoren'], ['73:86']],
#     'Target': [['Landsmann'], ['101:110']],
#     'Polar_expression': [['bestachen'], ['111:120']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Ich kann Ihnen versichern , dass Roche immer mit hohem Augenmass Medikamentenpreise festlegt .',
#   'opinions': [{'Source': [['Roche'], ['33:38']],
#     'Target': [['Medikamentenpreise'], ['65:83']],
#     'Polar_expression': [['festlegt'], ['84:92']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Seit Anfang des Jahres haben die Behörden weitere 13 Versuche registriert , 7 Boote erreichten die englische Küste .',
#   'opinions': [{'Source': [['Boote'], ['78:83']],
#     'Target': [['Küste'], ['109:114']],
#     'Polar_expression': [['erreichten'], ['84:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': '( sda / afp ) · Das Parlament in Rumänien hat der Minderheitsregierung des neuen rumänischen Ministerpräsidenten Ludovic Orban am Montag das Vertrauen ausgesprochen .',
#   'opinions': [{'Source': [['Parlament'], ['20:29']],
#     'Target': [['Minderheitsregierung'], ['50:70']],
#     'Polar_expression': [['ausgesprochen'], ['151:164']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Andere Gespräche widmen sich der Pandemie , Krankheit und Körper oder der Berührbarkeit durch klassische Musik .',
#   'opinions': [{'Source': [['Gespräche'], ['7:16']],
#     'Target': [['Pandemie'], ['33:41']],
#     'Polar_expression': [['widmen'], ['17:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'So hat Mueller herausgefunden , dass Trumps ehemaliger Wahlkampfleiter Paul Manafort als Lobbyist früher zig Millionen Dollar verdient , aber nicht versteuert hat .',
#   'opinions': [{'Source': [['Wahlkampfleiter'], ['55:70']],
#     'Target': [[], []],
#     'Polar_expression': [['verdient'], ['126:134']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': 'Deshalb nutzen viele Mediziner 5-ALA , das kaum Nebenwirkungen hat , zum Beispiel auch am Berner Inselspital – jedoch einzig bei höchstgradig bösartigen Hirntumoren ( Glioblastom ) .',
#   'opinions': [{'Source': [['Mediziner'], ['21:30']],
#     'Target': [['ALA'], ['33:36']],
#     'Polar_expression': [['nutzen'], ['8:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Macron hatte eine Million Corona-Tests pro Woche angekündigt .',
#   'opinions': [{'Source': [['Macron'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['49:60']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': 'Kein Wunder , widmete sich Charles Darwin der Tiergruppe wähend acht Jahren seines Forscherlebens .',
#   'opinions': [{'Source': [['Charles'], ['27:34']],
#     'Target': [['Tiergruppe'], ['46:56']],
#     'Polar_expression': [['widmete'], ['14:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Sondern : In der komplexen Sportart Eishockey stellen sich viele Automatismen , die perfekte Abstimmung beispielsweise im Power- und Boxplay , hauptsächlich mit vielen Spieleinsätzen ein .',
#   'opinions': [{'Source': [['Automatismen'], ['65:77']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Einen Tag nach der Kabinenpredigt siegt Bern gegen Servette ( 3 : 2 n. V. ) erstmals nach drei Pleiten .',
#   'opinions': [{'Source': [['Bern'], ['40:44']],
#     'Target': [['Servette'], ['51:59']],
#     'Polar_expression': [['siegt'], ['34:39']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Auch Becir Omeragic fehlte mit einer Knieverletzung am Anfang der Saison .',
#   'opinions': [{'Source': [['Becir'], ['5:10']],
#     'Target': [['Anfang'], ['55:61']],
#     'Polar_expression': [['fehlte'], ['20:26']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Nicht nur Boris Becker traut Nadal zu , dass er den Rekord bald allein hält .',
#   'opinions': [{'Source': [['Boris'], ['10:15']],
#     'Target': [['Nadal'], ['29:34']],
#     'Polar_expression': [['traut'], ['23:28']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': '« Eine hundertprozentige Garantie gibt es nie . » Auch flächendeckendes Testen werde das Virus nicht zum Aussterben bringen , mahnt Krismer .',
#   'opinions': [{'Source': [['Testen'], ['72:78']],
#     'Target': [[], []],
#     'Polar_expression': [['bringen'], ['116:123']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': 'Bei fairen Präsidentschafts- und Parlamentswahlen muss der Staatschef um den Sieg fürchten .',
#   'opinions': [{'Source': [['Staatschef'], ['59:69']],
#     'Target': [['Sieg'], ['77:81']],
#     'Polar_expression': [['fürchten'], ['82:90']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'Doch nun wachsen die Zweifel , nachdem das saudische Regime die Tötung des Journalisten Jamal Khashoggi eingeräumt hat .',
#   'opinions': [{'Source': [['Regime'], ['53:59']],
#     'Target': [['Tötung'], ['64:70']],
#     'Polar_expression': [['eingeräumt'], ['104:114']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'Die SBB entschuldigen sich für die Umstände .',
#   'opinions': [{'Source': [['SBB'], ['4:7']],
#     'Target': [['Umstände'], ['35:43']],
#     'Polar_expression': [['entschuldigen'], ['8:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Zwar hat Easyjet Flüge nach Berlin aufgenommen und fliegt die Strecke bis zu sechsmal täglich .',
#   'opinions': [{'Source': [['Easyjet'], ['9:16']],
#     'Target': [[], []],
#     'Polar_expression': [['aufgenommen'], ['35:46']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': 'Der Ausdruck « Negrita » ( « kleiner schwarzer Mensch » ) hatte dem uruguayischen Fussballstar Edison Cavani kürzlich eine Geldstrafe wegen Rassismus eingebracht .',
#   'opinions': [{'Source': [['Ausdruck'], ['4:12']],
#     'Target': [['Fussballstar'], ['82:94']],
#     'Polar_expression': [['eingebracht'], ['150:161']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Sie ergänzt : « Ein Körper muss nicht perfekt sein , um schön zu sein . » Hochschwanger freute sich Sara Leutenegger im Oktober auf die Geburt .',
#   'opinions': [{'Source': [['Sara'], ['100:104']],
#     'Target': [['Geburt'], ['136:142']],
#     'Polar_expression': [['freute'], ['88:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'Ghosn hat über seinen Anwalt einen Medienbericht zurückgewiesen , wonach er 2008 einen Verlust aus Wertpapiergeschäften auf Nissan übertragen haben soll .',
#   'opinions': [{'Source': [['Ghosn'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [['zurückgewiesen'], ['49:63']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Drei Tage später entliess YB den CEO Niedermaier , es gab Parolen des Aufbruchs .',
#   'opinions': [{'Source': [['YB'], ['26:28']],
#     'Target': [['CEO'], ['33:36']],
#     'Polar_expression': [['entliess'], ['17:25']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'sho . · 2017 entliess der Gemeinderat Maschwanden gleichzeitig mit der Baubewilligung für zwei Ersatzbauten und einen Neubau ein Gehöft aus dem 19. Jahrhundert am Dorfrand aus dem kommunalen Schutzinventar .',
#   'opinions': [{'Source': [['Gemeinderat'], ['26:37']],
#     'Target': [[], []],
#     'Polar_expression': [['entliess'], ['13:21']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'Bei diesem Training orientiere man sich am Militär , das solche Übungen einsetze , damit die Soldaten besser mit schwierigen Situationen umgehen könnten .',
#   'opinions': [{'Source': [['Soldaten'], ['93:101']],
#     'Target': [['Situationen'], ['125:136']],
#     'Polar_expression': [['umgehen'], ['137:144']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'Im « Goldenen Handschuh » tut ein Mann alles , um Frauen zu zerstören .',
#   'opinions': [{'Source': [['Mann'], ['34:38']],
#     'Target': [['Frauen'], ['50:56']],
#     'Polar_expression': [['zerstören'], ['60:69']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Agnes Merz , Goldau Sehr gut , dass sich jetzt auch Petra Gössi als FDP-Chefin für den Klimaschutz einsetzt .',
#   'opinions': [{'Source': [['Petra'], ['52:57']],
#     'Target': [['Klimaschutz'], ['87:98']],
#     'Polar_expression': [['einsetzt'], ['99:107']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Die Unternehmen suchen nach Wegen , um sich für den demografischen Wandel zu wappnen , und stellen sich auf die veränderten Anforderungen der nachrückenden Generation ein .',
#   'opinions': [{'Source': [['Unternehmen'], ['4:15']],
#     'Target': [['Wandel'], ['67:73']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Während es bei den Offsets also eine « Kantonsrebellion » gab , hat sich die ständerätliche Kommission beim Rest der Vorlage hinter den Bundesrat gestellt .',
#   'opinions': [{'Source': [['Kommission'], ['92:102']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Janssen lässt denn auch seine Studenten nichts am Zeichentisch entwerfen , sondern stellt Fragen nach der gesellschaftlichen Relevanz der Architektur .',
#   'opinions': [{'Source': [['Janssen'], ['0:7']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Die Operation dauerte laut amerikanischen Medien acht Stunden , das transplantierte Herz habe seitdem seine Arbeit aufgenommen , dem Patienten gehe es gut .',
#   'opinions': [{'Source': [['Herz'], ['84:88']],
#     'Target': [['Arbeit'], ['108:114']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Darin verliebt sich ein 16-Jähriger in einen Rockmusiker , dem er bis zur Selbstaufgabe folgt .',
#   'opinions': [{'Source': [['Jähriger'], ['27:35']],
#     'Target': [['Rockmusiker'], ['45:56']],
#     'Polar_expression': [['verliebt'], ['6:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Yvonne Bozdag , Waltershausen ( D ) Trump wird Europa noch ins Chaos stürzen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['stürzen'], ['69:76']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Es lief erst die fünfte Minute , Englands Coach Gareth Southgate ballte kurz die Faust und stellte sich wieder unter das Dach der Spielerbank .',
#   'opinions': [{'Source': [['Coach'], ['42:47']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'Solothurn und Basel hatten am Dienstag ebenfalls schärfere Regeln angekündigt .',
#   'opinions': [{'Source': [['Solothurn'], ['0:9']],
#     'Target': [['Regeln'], ['59:65']],
#     'Polar_expression': [['angekündigt'], ['66:77']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Chinesische Staatsmedien haben Vorwürfe der US-Regierung über eine Vertuschung in der Corona-Krise und den Ursprung des Virus als « grundlose Beschuldigungen » zurückgewiesen .',
#   'opinions': [{'Source': [['Staatsmedien'], ['12:24']],
#     'Target': [[], []],
#     'Polar_expression': [['zurückgewiesen'], ['160:174']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '126',
#   'text': 'Doch die langwierige Jagd nach der Krone prägte seine Karriere .',
#   'opinions': [{'Source': [['Jagd'], ['21:25']],
#     'Target': [['Karriere'], ['54:62']],
#     'Polar_expression': [['prägte'], ['41:47']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '127',
#   'text': 'Vergleicht man nur die Zahl der Neuimmatrikulationen , so ist der Rückgang noch viel stärker : Diesen Herbst haben 43 % weniger Ausländer neu ein Studium in den USA aufgenommen als im Vorjahr .',
#   'opinions': [{'Source': [['Ausländer'], ['128:137']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '128',
#   'text': 'Die bedrängten Juden hätten sich der Zwangstaufe widersetzt und so ein leuchtendes Beispiel für die Heiligung des göttlichen Namens gegeben .',
#   'opinions': [{'Source': [['Juden'], ['15:20']],
#     'Target': [['Zwangstaufe'], ['37:48']],
#     'Polar_expression': [['widersetzt'], ['49:59']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '129',
#   'text': 'Zahlreiche Staaten , darunter die USA , aber auch die EU haben nun Sanktionen gegen Russland angekündigt oder schon verhängt .',
#   'opinions': [{'Source': [['Staaten'], ['11:18']],
#     'Target': [['Sanktionen'], ['67:77']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '130',
#   'text': 'Das Attentat galt laut Wasiri einem Stützpunkt der 111 .',
#   'opinions': [{'Source': [['Attentat'], ['4:12']],
#     'Target': [['Stützpunkt'], ['36:46']],
#     'Polar_expression': [['galt'], ['13:17']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '131',
#   'text': 'Und viele Frauenrechtlerinnen stellen sich trotz der Unterdrückung Andersdenkender hinter den Kurs des Kronprinzen .',
#   'opinions': [{'Source': [['Frauenrechtlerinnen'], ['10:29']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '132',
#   'text': 'Viktor Orban aus Ungarn freut sich auch sehr über Meloni , weil sich ja jetzt mit Freunden in Rom die Europäische Union verändern lasse .',
#   'opinions': [{'Source': [['Viktor'], ['0:6']],
#     'Target': [['Meloni'], ['50:56']],
#     'Polar_expression': [['freut'], ['24:29']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '133',
#   'text': 'Ein amerikanischer Vergeltungsschlag mit Drohnen tötete wiederum 150 Al-Shabab-Kämpfer .',
#   'opinions': [{'Source': [['Vergeltungsschlag'], ['19:36']],
#     'Target': [['Kämpfer'], ['79:86']],
#     'Polar_expression': [['tötete'], ['49:55']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '134',
#   'text': 'Dieser eindeutige Machtmissbrauch galt damals ohne Zweifel als Impeachment-würdig .',
#   'opinions': [{'Source': [['Machtmissbrauch'], ['18:33']],
#     'Target': [[], []],
#     'Polar_expression': [['galt'], ['34:38']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '135',
#   'text': 'In Jerusalem haben die griechisch-orthodoxe und die armenische Kirche sowie die Kustodie des Heiligen Landes gestern die unbefristete Schliessung der Grabeskirche in der Altstadt angekündigt – aus Protest .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Schliessung'], ['134:145']],
#     'Polar_expression': [['angekündigt'], ['179:190']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '136',
#   'text': 'Erfreulich : Im Vergleich mit der gesamten Schweiz achten in der Stadt Zürich prozentual mehr Menschen auf gesundes und ausgewogenes Essen .',
#   'opinions': [{'Source': [['Menschen'], ['94:102']],
#     'Target': [['Essen'], ['133:138']],
#     'Polar_expression': [['achten'], ['51:57']],
#     'Polarity': None,
# ...
#     'Target': [[], []],
#     'Polar_expression': [['stellen'], ['7:14']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '957',
#   'text': 'Vergleichbare Regeln gelten in manchen Spitälern : Wenn zum Beispiel in der Orthopädie die Zahl der operierten Knochenbrüche höher ausfällt , erhält der Chefarzt einen Bonus .',
#   'opinions': [{'Source': [['Chefarzt'], ['153:161']],
#     'Target': [['Spitälern'], ['39:48']],
#     'Polar_expression': [['gelten'], ['21:27']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': '« Das ist einfach nur geil » , freut sich Nelson Ferreira nach der Partie über den zweiten Finaleinzug in der Vereinsgeschichte des FC Thun .',
#   'opinions': [{'Source': [['Nelson'], ['42:48']],
#     'Target': [['Finaleinzug'], ['91:102']],
#     'Polar_expression': [['freut'], ['31:36']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Das WM-Quartier der Nationalmannschaft musste er einen Tag vor WM-Beginn durch die Hintertür verlassen , weil dem Verbandschef Luis Rubiales seine ungeschickt mitgeteilte Einigung mit Real Madrid für die Zeit nach dem Turnier missfiel .',
#   'opinions': [{'Source': [['Einigung'], ['171:179']],
#     'Target': [['Verbandschef'], ['114:126']],
#     'Polar_expression': [['missfiel'], ['226:234']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Ausser dem republikanischen Senator Ted Cruz solidarisierte sich kaum eine bekannte Persönlichkeit mit den Truckern .',
#   'opinions': [{'Source': [['Persönlichkeit'], ['84:98']],
#     'Target': [['Truckern'], ['107:115']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Der Wirtschaftsverband Economiesuisse stellt sich auf spürbare Auswirkungen ein , auch für die Schweiz .',
#   'opinions': [{'Source': [['Wirtschaftsverband'], ['4:22']],
#     'Target': [['Auswirkungen'], ['63:75']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Für jede Generation stellt sich aufs Neue die Herausforderung , herauszufinden , welches Spiel gerade gespielt wird .',
#   'opinions': [{'Source': [['Herausforderung'], ['46:61']],
#     'Target': [['Generation'], ['9:19']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'In der gegenwärtigen Diskurs-Unkultur diffamieren kulturell orientierungslose Linksliberale gern um die Bewahrung der Freiheit kämpfende Liberal-Konservative .',
#   'opinions': [{'Source': [['Liberal'], ['137:144']],
#     'Target': [['Bewahrung'], ['104:113']],
#     'Polar_expression': [['kämpfende'], ['127:136']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Einige Kirchenleute fürchten sich offenbar vor einer Gestalt wie Locher – sie werfen ihm vor , dass er seinen Laden nicht im Griff habe oder dass er machtbesessen und narzisstisch sei .',
#   'opinions': [{'Source': [['Kirchenleute'], ['7:19']],
#     'Target': [['Gestalt'], ['53:60']],
#     'Polar_expression': [['fürchten'], ['20:28']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Das Obergericht stellt sich in seinem schriftlichen Urteil zunächst gegen die Ansicht der Verteidigung , wonach keine verwertbaren Beweise vorlägen .',
#   'opinions': [{'Source': [['Obergericht'], ['4:15']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Das Trauma von München Vor 50 Jahren spazierten acht Terroristen ins olympische Dorf , um Juden zu ermorden .',
#   'opinions': [{'Source': [['Trauma'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Vor zweieinhalb Wochen aber stürzte Becciu über die vielen Ungereimtheiten seines Handelns – etwa beim Kauf einer Luxusimmobilie in London , bei seinen üppigen Zuwendungen für seine drei Brüder und für eine mysteriöse 39 Jahre alte Sardin .',
#   'opinions': [{'Source': [['Becciu'], ['36:42']],
#     'Target': [['Ungereimtheiten'], ['59:74']],
#     'Polar_expression': [['stürzte'], ['28:35']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Das Departement von Umweltministerin Simonetta Sommaruga will die Berechnungsmethodik so anpassen , dass das Problem der Verzerrungen verschwindet und sicher keine Autos mehr in der Kategorie A sind , deren Ausstoss höher ist als der CO2-Zielwert des Bundes .',
#   'opinions': [{'Source': [['Problem'], ['109:116']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': 'Die Spanier verhafteten sechs Chinesen , drei Spanier und drei Marokkaner .',
#   'opinions': [{'Source': [['Spanier'], ['4:11']],
#     'Target': [['Chinesen'], ['30:38']],
#     'Polar_expression': [['verhafteten'], ['12:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Der Australier stellt sich zum Aufschlag bereit , hat dabei zwei Bälle in der Hand – wie es Tennisprofis oft tun , bevor sie sich für einen der beiden entscheiden , der dann auf die andere Netzseite gepeitscht werden soll .',
#   'opinions': [{'Source': [['Australier'], ['4:14']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Pa Modou hatte fast die ganze Rückrunde verletzt gefehlt , ihn plagten Rückenprobleme , der FCZ glaubte , es gehe nicht mehr weiter mit ihm .',
#   'opinions': [{'Source': [['Pa'], ['0:2']],
#     'Target': [['Rückrunde'], ['30:39']],
#     'Polar_expression': [['verletzt'], ['40:48']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Berlin treibt mit aller Macht das Projekt der russisch-deutschen Gaspipeline Nord Stream 2 durch die Ostsee voran , obwohl die direkt betroffenen Anrainer wie die baltischen Staaten und Polen , aber auch Frankreich und die USA dagegen opponieren .',
#   'opinions': [{'Source': [['Anrainer'], ['146:154']],
#     'Target': [[], []],
#     'Polar_expression': [['opponieren'], ['235:245']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Als Star wurde Manson mehrfach verklagt , von früheren Bandmitgliedern und Hotelbesitzern .',
#   'opinions': [{'Source': [['Manson'], ['15:21']],
#     'Target': [[], []],
#     'Polar_expression': [['verklagt'], ['31:39']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Vor allem der Umstand , dass der Vertreter der Volksrepublik China , Botschafter Zhang Jun , ebenfalls klare Worte fand , ist bemerkenswert : « Es ist nun Zeit für eine Entspannung , für diplomatische Aktivitäten und für einen Dialog » , wird Zhang Jun zitiert .',
#   'opinions': [{'Source': [['Vertreter'], ['33:42']],
#     'Target': [[], []],
#     'Polar_expression': [['fand'], ['115:119']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Zweitens konnten Firmen zur Sicherung ihrer Liquidität ( nicht ihrer Solvenz ) bereits günstige , staatlich garantierte Covid-19-Kredite aufnehmen , die bei Bedarf neu aufgelegt werden könnten .',
#   'opinions': [{'Source': [['Firmen'], ['17:23']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Michelle Hunziker hat sich für einen rassistischen Auftritt in einer italienischen Satireshow entschuldigt .',
#   'opinions': [{'Source': [['Michelle'], ['0:8']],
#     'Target': [['Auftritt'], ['51:59']],
#     'Polar_expression': [['entschuldigt'], ['94:106']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Insgesamt stellen sich am Sonntag , 4. März , 1054 Zürcherinnen und Zürcher zur Wahl in den Gemeinderat .',
#   'opinions': [{'Source': [['Zürcherinnen'], ['51:63']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Deshalb überfällt Sali Hafez nun eine Bank .',
#   'opinions': [{'Source': [['Sali'], ['18:22']],
#     'Target': [['Bank'], ['38:42']],
#     'Polar_expression': [['überfällt'], ['8:17']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Zwei Mittzwanziger stellen sich vorne an den Bühnenrand und machen genau das , was ihr « Medium » nicht wollte : Sie zeigen Schritte vor und versuchen die Zuschauer zu animieren , ihnen nachzutanzen .',
#   'opinions': [{'Source': [['Mittzwanziger'], ['5:18']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Spätere Sultane lösten dieses Problem , indem sie in vielen Tavernen einen Mitarbeiter des Geheimdiensts postierten .',
#   'opinions': [{'Source': [['Sultane'], ['8:15']],
#     'Target': [['Problem'], ['30:37']],
#     'Polar_expression': [['lösten'], ['16:22']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Und es ist auch klar , dass eine Neubaustrecke zwischen Lausanne und Genf viele Probleme lösen würde .',
#   'opinions': [{'Source': [['Neubaustrecke'], ['33:46']],
#     'Target': [['Probleme'], ['80:88']],
#     'Polar_expression': [['lösen'], ['89:94']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Die dann aber nach wenigen Monaten resigniert die Kündigung eingereicht hätten .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Kündigung'], ['50:59']],
#     'Polar_expression': [['eingereicht'], ['60:71']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Schliesslich hat das Parlament erstmals eine Spezialkommission eingesetzt , die sich nur mit dem Flugplatz Dübendorf befasst .',
#   'opinions': [{'Source': [['Parlament'], ['21:30']],
#     'Target': [['Spezialkommission'], ['45:62']],
#     'Polar_expression': [['eingesetzt'], ['63:73']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Jüngst verdeutlichte Scania seine Abkehr vom derzeitigen Wasserstoff-Hype und gab Gründe für die Strategieverschiebung an .',
#   'opinions': [{'Source': [['Scania'], ['21:27']],
#     'Target': [['Abkehr'], ['34:40']],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Freiwilligenarbeit findet Zulauf , wo Freiwillige ihre eigenen Ideen einbringen und selbst gestaltend aktiv werden können – also nicht mehr zwingend in organisatorischen Struktur von Nonprofitorganisationen .',
#   'opinions': [{'Source': [['Freiwillige'], ['0:11']],
#     'Target': [['Ideen'], ['63:68']],
#     'Polar_expression': [['einbringen'], ['69:79']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Qiaos schwedischer Verteidiger , Henrik Olsson Lilja , schloss jedoch einen fairen Prozess a priori aus , weil sein Mandant im chinesischen Fernsehen bereits vorverurteilt worden sei .',
#   'opinions': [{'Source': [['Verteidiger'], ['19:30']],
#     'Target': [['Prozess'], ['83:90']],
#     'Polar_expression': [['schloss'], ['55:62']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Dieser Fund löste einen längeren Austausch zwischen der Bundesregierung und Vertretern des ehemaligen Präsidenten aus .',
#   'opinions': [{'Source': [['Fund'], ['7:11']],
#     'Target': [['Austausch'], ['33:42']],
#     'Polar_expression': [['löste'], ['12:17']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Auch die Ärztekammer , das Parlament der Schweizer Ärzteschaft , hat es kürzlich abgelehnt , liberalisierte Richtlinien zur Suizidhilfe in ihre Standesordnung aufzunehmen .',
#   'opinions': [{'Source': [['Ärztekammer'], ['9:20']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'Im Jahr 2010 gewann Bridges einen Oscar als bester Hauptdarsteller für « Crazy Heart » .',
#   'opinions': [{'Source': [['Bridges'], ['20:27']],
#     'Target': [['Crazy'], ['73:78']],
#     'Polar_expression': [['gewann'], ['13:19']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Gottstein musste sich später für den Wutausbruch entschuldigen .',
#   'opinions': [{'Source': [['Gottstein'], ['0:9']],
#     'Target': [['Wutausbruch'], ['37:48']],
#     'Polar_expression': [['entschuldigen'], ['49:62']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Von 1932 bis 1934 gings plötzlich in die entgegengesetzte Richtung , da machte die Raubkatze immer angsteinflössendere Fratzen , gab immer noch wildere Geräusche von sich ... was dann 1935 ironisch gebrochen wurde , indem man Groucho , Chico und Harpo Marx den Löwen nachahmen liess ( wobei Harpo dafür eine Hupe benutzte ) .',
#   'opinions': [{'Source': [['Raubkatze'], ['83:92']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Spieler wurden unlängst getauscht , ein zusätzlicher Ausländer eben erst verpflichtet , Etienne Froidevaux , dem ehemaligen Captain , wurde beschieden , er könne sich einen neuen Arbeitgeber suchen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Viele Arbeiter fürchten sich vor Kürzungen und einer Privatisierung .',
#   'opinions': [{'Source': [['Arbeiter'], ['6:14']],
#     'Target': [['Kürzungen'], ['33:42']],
#     'Polar_expression': [['fürchten'], ['15:23']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Diesen Anhängern eines harten Brexit missfällt vor allem der Backstop im EU-Austrittsvertrag .',
#   'opinions': [{'Source': [['Backstop'], ['61:69']],
#     'Target': [['Anhängern'], ['7:16']],
#     'Polar_expression': [['missfällt'], ['37:46']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Sanktionen gegen Russen Die Kantone haben sich bei Wirtschaftsminister Guy Parmelin beschwert , sie seien nicht gut genug darüber informiert worden , welche Rolle sie bei den Sanktionen zu spielen haben .',
#   'opinions': [{'Source': [['Kantone'], ['28:35']],
#     'Target': [[], []],
#     'Polar_expression': [['beschwert'], ['84:93']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Soll der Arbeiter die Weiche so stellen , dass fünf Menschen sterben , oder so , dass einer stirbt ?',
#   'opinions': [{'Source': [['Arbeiter'], ['9:17']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'Aber dann kam uns in den Sinn , dass in den letzten Monaten am Morgen häufig unsere Zeitung im Briefkasten fehlte .',
#   'opinions': [{'Source': [['Zeitung'], ['84:91']],
#     'Target': [['Briefkasten'], ['95:106']],
#     'Polar_expression': [['fehlte'], ['107:113']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'MARCO GARCIA , BUBIKON ZH Diesen Jugendlichen fehlt die führende Hand der Eltern und des Staats .',
#   'opinions': [{'Source': [['Hand'], ['65:69']],
#     'Target': [['Jugendlichen'], ['33:45']],
#     'Polar_expression': [['fehlt'], ['46:51']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': 'Die Täter überfielen dort ein Pokerturnier und erbeuteten rund 250 000 Euro .',
#   'opinions': [{'Source': [['Täter'], ['4:9']],
#     'Target': [['Pokerturnier'], ['30:42']],
#     'Polar_expression': [['überfielen'], ['10:20']],
#     'Polarity': None,
#     'Intensity': 'Average'}]},
#  ...]

# %%
tokenized_ssa_sents
# Out:
# {'tokens': [['Andere',
#    '<eSOURCE>',
#    'Proteste',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'entstanden',
#    '</ePEXP>',
#    'wegen',
#    'der',
#    'seit',
#    'Jahren',
#    'miserablen',
#    'Wirtschaftslage',
#    'und',
#    'der',
#    'allumfassenden',
#    'Korruption',
#    'im',
#    'Land',
#    'und',
#    'blieben',
#    'meist',
#    'regional',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Flavia',
#    'Schlittler',
#    'Im',
#    'Frühling',
#    '2015',
#    'wurde',
#    '<eSOURCE>',
#    'Nepal',
#    '</eSOURCE>',
#    'von',
#    'verheerenden',
#    '<eTARGET>',
#    'Erdbeben',
#    '</eTARGET>',
#    'heimgesucht',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Der',
#    '<eSOURCE>',
#    'Konflikt',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'sorgte',
#    '</ePEXP>',
#    'innerhalb',
#    'der',
#    'CVP',
#    ',',
#    'in',
#    'der',
#    'man',
#    'in',
#    'normalen',
#    'Zeiten',
#    'ungern',
#    'öffentlich',
#    'streitet',
#    ',',
#    'für',
#    'erheblichen',
#    '<eTARGET>',
#    'Ärger',
#    '</eTARGET>',
#    '.'],
#   ['Damals',
#    '<ePEXP>',
#    'zerstörte',
#    '</ePEXP>',
#    'ein',
#    '<eSOURCE>',
#    'Feuer',
#    '</eSOURCE>',
#    'das',
#    'historische',
#    '<eTARGET>',
#    'Gipfelhotel',
#    '</eTARGET>',
#    'aus',
#    'dem',
#    'Jahr',
#    '1893',
#    '–',
#    'ein',
#    'grosser',
#    'Verlust',
#    '.'],
#   ['Vor',
#    'zehn',
#    'Jahren',
#    '<ePEXP>',
#    'scheiterte',
#    '</ePEXP>',
#    'ein',
#    '<eSOURCE>',
#    'Freihandelsabkommen',
#    '</eSOURCE>',
#    'mit',
#    'den',
#    'USA',
#    'am',
#    '<eTARGET>',
#    'Widerstand',
#    '</eTARGET>',
#    'der',
#    'Landwirtschaft',
#    '.'],
#   ['Die',
#    'Besinnung',
#    'auf',
#    'das',
#    'Einzigartige',
#    'der',
#    'eigenen',
#    'Bestände',
#    'gab',
#    'die',
#    'Richtung',
#    'vor',
#    ':',
#    'Keine',
#    'andere',
#    '<eSOURCE>',
#    'Bibliothek',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'widmet',
#    '</ePEXP>',
#    'sich',
#    'so',
#    'gezielt',
#    'und',
#    'umfassend',
#    'der',
#    '<eTARGET>',
#    'Schnittstelle',
#    '</eTARGET>',
#    'von',
#    'Religion',
#    'und',
#    'Gesellschaft',
#    ',',
#    'Glaube',
#    'und',
#    'Philosophie',
#    ',',
#    'interreligiösem',
#    'Gespräch',
#    ',',
#    'Kunst',
#    ',',
#    'Kultur',
#    'und',
#    'Themen',
#    'der',
#    'Zivilgesellschaft',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Regulierungsbehörden',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'sorgen',
#    '</ePEXP>',
#    'sich',
#    'über',
#    'die',
#    'enormen',
#    '<eTARGET>',
#    'Summen',
#    '</eTARGET>',
#    ',',
#    'die',
#    'von',
#    'den',
#    'Stablecoin-Anbietern',
#    'eingesammelt',
#    'wurden',
#    'und',
#    'werden',
#    ',',
#    'ohne',
#    'dass',
#    'das',
#    'amerikanische',
#    'Bankensystem',
#    'involviert',
#    'ist',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Verteidiger',
#    '</eSOURCE>',
#    'des',
#    'Beschuldigten',
#    ',',
#    'der',
#    'während',
#    'der',
#    'Verhandlung',
#    'von',
#    'seinem',
#    'Aussageverweigerungsrecht',
#    'Gebrauch',
#    'machte',
#    ',',
#    '<ePEXP>',
#    'plädierte',
#    '</ePEXP>',
#    'auf',
#    '<eTARGET>',
#    'Freispruch',
#    '</eTARGET>',
#    '.'],
#   ['Ein',
#    '<eSOURCE>',
#    'Streichelzoo',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'sorgt',
#    '</ePEXP>',
#    'für',
#    'Abwechslung',
#    'bei',
#    'den',
#    '<eTARGET>',
#    'Kleinsten',
#    '</eTARGET>',
#    '.'],
#   ['Zweimal',
#    '<ePEXP>',
#    'stimmten',
#    '</ePEXP>',
#    'die',
#    '<eSOURCE>',
#    'Freisinnigen',
#    '</eSOURCE>',
#    'geschlossen',
#    'dagegen',
#    ',',
#    'abgesehen',
#    'von',
#    'einer',
#    'Handvoll',
#    'Enthaltungen',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    'grösste',
#    '<eSOURCE>',
#    'Demokratie',
#    '</eSOURCE>',
#    'der',
#    'Welt',
#    'muss',
#    'aber',
#    'auch',
#    'die',
#    'lauten',
#    'und',
#    'unangenehmen',
#    '<eTARGET>',
#    'Stimmen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'aushalten',
#    '</ePEXP>',
#    'können',
#    '.'],
#   ['Eine',
#    'ähnliche',
#    '<eSOURCE>',
#    'Frage',
#    '</eSOURCE>',
#    'stellte',
#    'sich',
#    'bei',
#    '<eTARGET>',
#    'Alexis',
#    '</eTARGET>',
#    'Sánchez',
#    ',',
#    'dem',
#    'wirbligen',
#    'chilenischen',
#    'Stürmer',
#    ',',
#    'den',
#    'man',
#    'mit',
#    'allen',
#    'Mitteln',
#    'der',
#    'Überredungskunst',
#    'Arsenal',
#    'abgeworben',
#    'hatte',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Die',
#    'Gesichtszüge',
#    'sind',
#    'unter',
#    'der',
#    'Maske',
#    'nicht',
#    'zu',
#    'erkennen',
#    ',',
#    'die',
#    'Gestik',
#    'verrät',
#    'aber',
#    'den',
#    'Gemütszustand',
#    ':',
#    '<eSOURCE>',
#    'Jeannine',
#    '</eSOURCE>',
#    'Gmelin',
#    'freut',
#    'sich',
#    'über',
#    'die',
#    '<eTARGET>',
#    'Bronzemedaille',
#    '</eTARGET>',
#    'und',
#    'schwenkt',
#    'die',
#    'Schweizer',
#    'Fahne',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Immer',
#    'auch',
#    'auf',
#    'die',
#    'Gefahr',
#    'hin',
#    ',',
#    'dass',
#    '<eSOURCE>',
#    'Kritiker',
#    '</eSOURCE>',
#    'uns',
#    'an',
#    'den',
#    'Öko-Pranger',
#    'stellen',
#    'und',
#    'uns',
#    'die',
#    'liberale',
#    'Gesinnung',
#    'absprechen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'Nationalrätin',
#    'nennt',
#    'ein',
#    'Beispiel',
#    ':',
#    'Wenn',
#    'sich',
#    'der',
#    '<eSOURCE>',
#    'Grundstückpreis',
#    '</eSOURCE>',
#    'einer',
#    'Liegenschaft',
#    'bei',
#    'einer',
#    'Neubewertung',
#    'verdoppelt',
#    ',',
#    'müssen',
#    'sich',
#    'auch',
#    'die',
#    'Mieten',
#    'verdoppeln',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Madonna',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'entschuldigt',
#    '</ePEXP>',
#    'sich',
#    'bei',
#    'ihren',
#    '<eTARGET>',
#    'Anhängern',
#    '</eTARGET>',
#    ':',
#    '«',
#    'Ich',
#    'muss',
#    'mich',
#    'erholen',
#    '»',
#    ',',
#    'erklärt',
#    'sie',
#    '.'],
#   ['Das',
#    'bis',
#    'heute',
#    'aufgrund',
#    'seiner',
#    'repräsentativen',
#    'Bürger-',
#    'und',
#    'Gasthäuser',
#    'städtisch',
#    'wirkende',
#    'Dorf',
#    'Einsiedeln',
#    'wurde',
#    'von',
#    'Hugo',
#    'Kopp',
#    'noch',
#    'vor',
#    'dem',
#    'in',
#    'den',
#    '1960er',
#    'Jahren',
#    'einsetzenden',
#    'Wachstumsschub',
#    'so',
#    'aus',
#    'dem',
#    'Flugzeug',
#    'aufgenommen',
#    ',',
#    'dass',
#    'es',
#    'präzise',
#    'von',
#    'seinen',
#    'beiden',
#    'wichtigsten',
#    'Baukomplexen',
#    'gefasst',
#    'wird',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Sofort',
#    'stellte',
#    'sich',
#    'der',
#    'mächtige',
#    '<eSOURCE>',
#    'Generalsekretär',
#    '</eSOURCE>',
#    'Toshihiro',
#    'Nikai',
#    '(',
#    '81',
#    ')',
#    'auf',
#    'Sugas',
#    'Seite',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Eine',
#    '<eSOURCE>',
#    'Millionärsgattin',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'verliebte',
#    '</ePEXP>',
#    'sich',
#    'vor',
#    '26',
#    'Jahren',
#    'in',
#    'einen',
#    '<eTARGET>',
#    'Polizisten',
#    '</eTARGET>',
#    'der',
#    'Kantonspolizei',
#    'St.',
#    'Gallen',
#    '.'],
#   ['Nach',
#    'dem',
#    'Match',
#    '<ePEXP>',
#    'entschuldigte',
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Shapovalov',
#    '</eSOURCE>',
#    'für',
#    'seine',
#    'vorwurfsvolle',
#    '<eTARGET>',
#    'Formulierung',
#    '</eTARGET>',
#    ',',
#    'er',
#    'hielt',
#    'aber',
#    'an',
#    'seiner',
#    'grundsätzlichen',
#    'Kritik',
#    'fest',
#    '.'],
#   ['Doch',
#    'auch',
#    'in',
#    'diesem',
#    'Fall',
#    'stellen',
#    'sich',
#    'heikle',
#    'rechtliche',
#    'und',
#    'vollzugstechnische',
#    '<eSOURCE>',
#    'Herausforderungen',
#    '</eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Israel',
#    '</eSOURCE>',
#    'hatte',
#    'dagegen',
#    'mit',
#    'einem',
#    'Kampfhelikopter',
#    'eine',
#    '<eTARGET>',
#    'Drohne',
#    '</eTARGET>',
#    '<ePEXP>',
#    'abgeschossen',
#    '</ePEXP>',
#    ',',
#    'die',
#    'gemäss',
#    'Israel',
#    'von',
#    'Revolutionsgardisten',
#    'in',
#    'Syrien',
#    'gestartet',
#    'worden',
#    'war',
#    '.'],
#   ['Frankfurts',
#    '<eSOURCE>',
#    'Daichi',
#    '</eSOURCE>',
#    'Kamada',
#    'trifft',
#    'zweimal',
#    'und',
#    '<ePEXP>',
#    'schiesst',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Arsenal',
#    '</eTARGET>',
#    'ab',
#    '.'],
#   ['Das',
#    'unterste',
#    '<eSOURCE>',
#    'Segment',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'leidet',
#    '</ePEXP>',
#    'derweil',
#    'unter',
#    'der',
#    '<eTARGET>',
#    'Konkurrenz',
#    '</eTARGET>',
#    'der',
#    'Smartwatches',
#    '.'],
#   ['In',
#    '<eTARGET>',
#    'Biel',
#    '</eTARGET>',
#    'stellt',
#    'sich',
#    'die',
#    '<eSOURCE>',
#    'Frage',
#    '</eSOURCE>',
#    'nicht',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['<eSOURCE>',
#    'Weber',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'achtet',
#    '</ePEXP>',
#    'auf',
#    'gute',
#    '<eTARGET>',
#    'Unternehmensführung',
#    '</eTARGET>',
#    '.'],
#   ['Als',
#    'im',
#    'Juli',
#    'das',
#    'viel',
#    'zu',
#    'langsam',
#    'gestartete',
#    'Impfprogramm',
#    'endlich',
#    'Tempo',
#    '<ePEXP>',
#    'aufnahm',
#    '</ePEXP>',
#    'und',
#    'sie',
#    'einen',
#    'Termin',
#    'bekam',
#    ',',
#    'dokumentierte',
#    '<eSOURCE>',
#    'Samuels',
#    '</eSOURCE>',
#    'ihre',
#    'erste',
#    'Impfung',
#    'auf',
#    'Facebook',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Theater',
#    '</eSOURCE>',
#    'Christoph',
#    'Marthaler',
#    'hat',
#    'für',
#    'ein',
#    'Bühnenstück',
#    'Zitate',
#    'von',
#    'Christa',
#    'Rigozzi',
#    'zum',
#    'Thema',
#    'Apéro',
#    '<ePEXP>',
#    'benutzt',
#    '</ePEXP>',
#    ',',
#    'ohne',
#    'sie',
#    'zu',
#    'deklarieren',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Juan',
#    '</eSOURCE>',
#    'Carbuccia',
#    'hat',
#    'mit',
#    'seinem',
#    'Handy',
#    'eine',
#    'Stunde',
#    'vor',
#    'Eintreffen',
#    'des',
#    'Besuchers',
#    'ein',
#    'Video',
#    '<ePEXP>',
#    'aufgenommen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['In',
#    'ersten',
#    'Reaktionen',
#    '<ePEXP>',
#    'plädierten',
#    '</ePEXP>',
#    'am',
#    'Sonntag',
#    'allerdings',
#    'auch',
#    'die',
#    '<eSOURCE>',
#    'Gegner',
#    '</eSOURCE>',
#    'von',
#    '«',
#    '7',
#    'statt',
#    '9',
#    '»',
#    'für',
#    '<eTARGET>',
#    'Effizienzverbesserungen',
#    '</eTARGET>',
#    'in',
#    'der',
#    'Stadtverwaltung',
#    '.'],
#   ['Schulden',
#    'seien',
#    '«',
#    'gratis',
#    '»',
#    ',',
#    'also',
#    'dürfe',
#    'der',
#    '<eSOURCE>',
#    'Staat',
#    '</eSOURCE>',
#    'bedenkenlos',
#    'Geld',
#    'für',
#    'Hilfen',
#    'und',
#    'Investitionen',
#    'aufnehmen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['(',
#    'red',
#    ')',
#    'Corona',
#    'Japans',
#    '<eSOURCE>',
#    'Ministerpräsident',
#    '</eSOURCE>',
#    'Shinzo',
#    'Abe',
#    'hat',
#    'zinslose',
#    'Kredite',
#    'für',
#    'Firmen',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    ',',
#    'die',
#    'von',
#    'der',
#    'Coronavirus-Epidemie',
#    'betroffen',
#    'sind',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Frau',
#    '</eSOURCE>',
#    'habe',
#    'gezielt',
#    'auf',
#    'den',
#    'am',
#    'Boden',
#    'liegenden',
#    ',',
#    'wehrlosen',
#    '<eTARGET>',
#    'Mann',
#    '</eTARGET>',
#    '<ePEXP>',
#    'geschossen',
#    '</ePEXP>',
#    '.'],
#   ['<eSOURCE>',
#    'Journalisten',
#    '</eSOURCE>',
#    'schliesslich',
#    '<ePEXP>',
#    'überschätzen',
#    '</ePEXP>',
#    'die',
#    '<eTARGET>',
#    'Rhetorik',
#    '</eTARGET>',
#    'notorisch',
#    '.'],
#   ['Nun',
#    ',',
#    'im',
#    'zweiten',
#    'Teil',
#    ',',
#    '<ePEXP>',
#    'widmet',
#    '</ePEXP>',
#    'sich',
#    'das',
#    '<eSOURCE>',
#    'Gericht',
#    '</eSOURCE>',
#    'den',
#    'sieben',
#    '<eTARGET>',
#    'Privatklägern',
#    '</eTARGET>',
#    'und',
#    'den',
#    'Zeugen',
#    '.'],
#   ['Und',
#    'schliesslich',
#    'stellen',
#    'sich',
#    'bei',
#    'Negativzinsen',
#    'ungewöhnliche',
#    '<eSOURCE>',
#    'Rechtsfragen',
#    '</eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Mirko',
#    '</eSOURCE>',
#    'Salvi',
#    ',',
#    'der',
#    'Mann',
#    'aus',
#    'Yverdon',
#    ',',
#    'stellt',
#    'sich',
#    'seit',
#    'letztem',
#    'Donnerstag',
#    'einer',
#    'neuen',
#    'Herausforderung',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Obergösgen',
#    'SO',
#    '–',
#    'Am',
#    'Donnerstagabend',
#    '<ePEXP>',
#    'überfiel',
#    '</ePEXP>',
#    'ein',
#    '49-jähriger',
#    '<eSOURCE>',
#    'Italiener',
#    '</eSOURCE>',
#    'mit',
#    'einem',
#    'gezückten',
#    'Messer',
#    'ein',
#    '<eTARGET>',
#    'Detailhandelsgeschäft',
#    '</eTARGET>',
#    'und',
#    'erbeutete',
#    'mehrere',
#    'Hundert',
#    'Franken',
#    '.'],
#   ['<eSOURCE>',
#    'Thomas',
#    '</eSOURCE>',
#    'Bach',
#    ',',
#    'der',
#    'Chef',
#    'des',
#    'Internationalen',
#    'Olympischen',
#    'Komitees',
#    ',',
#    'hat',
#    'sich',
#    'bei',
#    'einem',
#    'Mann',
#    'ganz',
#    'besonders',
#    'für',
#    'die',
#    'Siege',
#    'bei',
#    'den',
#    'Olympischen',
#    'Spielen',
#    'zu',
#    '<ePEXP>',
#    'bedanken',
#    '</ePEXP>',
#    ':',
#    'bei',
#    'Japans',
#    'Ministerpräsidenten',
#    'Yoshihide',
#    'Suga',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Insgesamt',
#    'hat',
#    'die',
#    'iranische',
#    '<eSOURCE>',
#    'Regierung',
#    '</eSOURCE>',
#    'in',
#    'der',
#    'vergangenen',
#    'Woche',
#    'rund',
#    '85',
#    '000',
#    'Gefangene',
#    'vorübergehend',
#    'aus',
#    'den',
#    'Gefängnissen',
#    '<ePEXP>',
#    'entlassen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Die',
#    'Zürcher',
#    '<eSOURCE>',
#    'Volkswirtschaftsdirektorin',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'sorgt',
#    '</ePEXP>',
#    'sich',
#    'aber',
#    'nicht',
#    'in',
#    'erster',
#    'Linie',
#    'um',
#    'die',
#    '<eTARGET>',
#    'Touristen',
#    '</eTARGET>',
#    ',',
#    'sondern',
#    'um',
#    'die',
#    'Zürcher',
#    'Geschäfte',
#    ',',
#    'denen',
#    'wegen',
#    'des',
#    'Sonntagsverkaufsverbots',
#    'Einnahmen',
#    'entgehen',
#    '.'],
#   ['Damit',
#    '<ePEXP>',
#    'diskreditiert',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Fasel',
#    '</eSOURCE>',
#    'den',
#    'ganzen',
#    '<eTARGET>',
#    'Eishockey',
#    '</eTARGET>',
#    'Sport',
#    '.'],
#   ['Nach',
#    'dem',
#    'Treffen',
#    'am',
#    'vergangenen',
#    'Dienstag',
#    'wurden',
#    'die',
#    'vier',
#    '<eSOURCE>',
#    'Menschenrechtler',
#    '</eSOURCE>',
#    'zunächst',
#    'von',
#    'der',
#    'regimetreuen',
#    'Presse',
#    'als',
#    '«',
#    'Verräter',
#    '»',
#    'oder',
#    '«',
#    'ausländische',
#    'Agenten',
#    '»',
#    '<ePEXP>',
#    'beschimpft',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Der',
#    'pakistanische',
#    '<eSOURCE>',
#    'Ministerpräsident',
#    '</eSOURCE>',
#    'Imran',
#    'Khan',
#    'hatte',
#    'die',
#    'Freilassung',
#    'am',
#    'Donnerstag',
#    'in',
#    'einer',
#    'Rede',
#    'vor',
#    'dem',
#    'Parlament',
#    'in',
#    'Islamabad',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Stephanie',
#    'Erne',
#    '...',
#    'spielt',
#    'ebenfalls',
#    'in',
#    'Luzern',
#    'und',
#    'hat',
#    'eine',
#    '80-Prozent-Stelle',
#    'als',
#    'Spezialistin',
#    'für',
#    'Bewegungs-',
#    'und',
#    'Gesundheitsförderung',
#    '–',
#    'daneben',
#    '<ePEXP>',
#    'gilt',
#    '</ePEXP>',
#    'ihr',
#    '<eSOURCE>',
#    'Engagement',
#    '</eSOURCE>',
#    'dem',
#    'FI9',
#    '<eTARGET>',
#    'Verein',
#    '</eTARGET>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Kanton',
#    '</eSOURCE>',
#    'hat',
#    'eine',
#    '<eTARGET>',
#    'Untersuchung',
#    '</eTARGET>',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '.'],
#   ['Zwar',
#    'ist',
#    'im',
#    'Gesetzestext',
#    'nirgendwo',
#    'von',
#    'Impfungen',
#    'die',
#    'Rede',
#    ',',
#    'und',
#    'der',
#    '<eSOURCE>',
#    'Bund',
#    '</eSOURCE>',
#    'hat',
#    'die',
#    '<eTARGET>',
#    'Verdächtigungen',
#    '</eTARGET>',
#    'immer',
#    'zurückgewiesen',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Gemäss',
#    'Informationen',
#    'der',
#    'Tessiner',
#    'Kantonspolizei',
#    '<ePEXP>',
#    'stürzte',
#    '</ePEXP>',
#    'die',
#    '30',
#    '<eSOURCE>',
#    'Jährige',
#    '</eSOURCE>',
#    'mehrere',
#    'Meter',
#    'in',
#    'die',
#    'Tiefe',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Polemik',
#    'Am',
#    '6.',
#    'Juni',
#    'will',
#    'die',
#    'Schweizer',
#    '<eSOURCE>',
#    'Kulturszene',
#    '</eSOURCE>',
#    'den',
#    '<eTARGET>',
#    'Neustart',
#    '</eTARGET>',
#    '<ePEXP>',
#    'wagen',
#    '</ePEXP>',
#    '.'],
#   ['Eine',
#    'unabhängige',
#    'Aufsichtskommission',
#    ';',
#    'schärfere',
#    'Datenschutzbestimmung',
#    ';',
#    'die',
#    'Möglichkeit',
#    'für',
#    'den',
#    'Bund',
#    ',',
#    'sich',
#    'an',
#    'Anbietern',
#    'eines',
#    'digitalen',
#    'Passes',
#    'zu',
#    'beteiligen',
#    '–',
#    'immer',
#    'zeigte',
#    'sich',
#    'dasselbe',
#    'Muster',
#    ':',
#    'Eine',
#    'klare',
#    'bürgerliche',
#    '<eSOURCE>',
#    'Mehrheit',
#    '</eSOURCE>',
#    'stellte',
#    'sich',
#    'gegen',
#    'die',
#    'Empfehlung',
#    'Keller-Sutters',
#    ',',
#    'die',
#    'zusammen',
#    'mit',
#    'den',
#    'Linken',
#    'die',
#    'Variante',
#    'des',
#    'Ständerats',
#    'unterstützte',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Bei',
#    'den',
#    'Männern',
#    'triumphiert',
#    '<eSOURCE>',
#    'Rudy',
#    '</eSOURCE>',
#    'von',
#    'Berg',
#    '(',
#    'USA',
#    ')',
#    'in',
#    '3',
#    ':',
#    '42',
#    ':',
#    '17',
#    'ähnlich',
#    'überlegen',
#    'wie',
#    'Ryf',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Walliser',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'jubeln',
#    '</ePEXP>',
#    'im',
#    'Cornaredo',
#    'nach',
#    'den',
#    'beiden',
#    '<eTARGET>',
#    'Lugano',
#    '</eTARGET>',
#    'Schockern',
#    '.'],
#   ['Die',
#    'grösste',
#    'Partei',
#    'im',
#    'Parlament',
#    ',',
#    'Ennahda',
#    ',',
#    'warf',
#    'dem',
#    '<eTARGET>',
#    'Präsidenten',
#    '</eTARGET>',
#    'einen',
#    '«',
#    'Putsch',
#    'gegen',
#    'die',
#    'Revolution',
#    'und',
#    'die',
#    'Verfassung',
#    '»',
#    'vor',
#    '–',
#    'eine',
#    'Referenz',
#    'auf',
#    'den',
#    'Arabischen',
#    'Frühling',
#    '2011',
#    ',',
#    'als',
#    'die',
#    '<eSOURCE>',
#    'Tunesier',
#    '</eSOURCE>',
#    'den',
#    'langjährigen',
#    'Diktator',
#    'Zine',
#    'al-Abedine',
#    'Ben',
#    'Ali',
#    'gestürzt',
#    'hatten',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Er',
#    'sprach',
#    'von',
#    'der',
#    'Enttäuschung',
#    'über',
#    'die',
#    'Niederlage',
#    ',',
#    '<eSOURCE>',
#    'YB',
#    '</eSOURCE>',
#    'habe',
#    'zwei',
#    '<eTARGET>',
#    'Unaufmerksamkeiten',
#    '</eTARGET>',
#    'ausgenutzt',
#    ',',
#    'aber',
#    'Klose',
#    'fand',
#    ',',
#    'dass',
#    'es',
#    'der',
#    'FCB',
#    '«',
#    'nicht',
#    'so',
#    'schlecht',
#    'gemacht',
#    'und',
#    'gut',
#    'verteidigt',
#    '»',
#    'habe',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['«',
#    'Interventionen',
#    'beim',
#    'Umweltminister',
#    'führten',
#    'lediglich',
#    'zu',
#    'netten',
#    'Floskeln',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '»',
#    'Man',
#    'gewinnt',
#    'den',
#    'Eindruck',
#    ',',
#    'selbst',
#    'von',
#    'Helfern',
#    'versuche',
#    'die',
#    '<eSOURCE>',
#    'Regierung',
#    '</eSOURCE>',
#    'möglichst',
#    'viel',
#    'Geld',
#    'abzupressen',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Betrieb',
#    '</eSOURCE>',
#    'musste',
#    ',',
#    'abgesehen',
#    'vom',
#    'Gastrobereich',
#    ',',
#    'ohnehin',
#    'aufrechterhalten',
#    'bleiben',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Obschon',
#    'ihre',
#    'Schönheit',
#    'wie',
#    'eh',
#    'und',
#    'je',
#    'betört',
#    ':',
#    'In',
#    'den',
#    'riesigen',
#    'Sälen',
#    'der',
#    'stilvollen',
#    'alten',
#    'Hotelpaläste',
#    'und',
#    'stuckübersäten',
#    'Villen',
#    'stellt',
#    'sich',
#    'statt',
#    'des',
#    'früheren',
#    'Schwelgens',
#    'immer',
#    'öfter',
#    'die',
#    'bange',
#    'Frage',
#    'ein',
#    ',',
#    'wer',
#    'für',
#    'die',
#    '<eTARGET>',
#    'Bewahrung',
#    '</eTARGET>',
#    'all',
#    'der',
#    'historischen',
#    'Pracht',
#    '<ePEXP>',
#    'aufkommen',
#    '</ePEXP>',
#    'kann',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Thelesklaf',
#    'nennt',
#    'ein',
#    'Beispiel',
#    ':',
#    'Eine',
#    '<eSOURCE>',
#    'Bank',
#    '</eSOURCE>',
#    'dürfe',
#    'einen',
#    'Verdacht',
#    'zwar',
#    'an',
#    'die',
#    'MROS',
#    'weiterleiten',
#    ',',
#    'nicht',
#    'aber',
#    'an',
#    'eine',
#    'andere',
#    'Bank',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Daraufhin',
#    '<ePEXP>',
#    'beschwerte',
#    '</ePEXP>',
#    'sich',
#    'die',
#    '<eSOURCE>',
#    'Frau',
#    '</eSOURCE>',
#    'beim',
#    '<eTARGET>',
#    'Presserat',
#    '</eTARGET>',
#    '.'],
#   ['Thomas',
#    'Fuster',
#    '·',
#    'Das',
#    'World',
#    'Economic',
#    'Forum',
#    '(',
#    'WEF',
#    ')',
#    '<ePEXP>',
#    'sorgt',
#    '</ePEXP>',
#    'sich',
#    'um',
#    '<eTARGET>',
#    'Davos',
#    '</eTARGET>',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Anscheinend',
#    'will',
#    'oder',
#    'kann',
#    'der',
#    'Casino',
#    '<eSOURCE>',
#    'Boss',
#    '</eSOURCE>',
#    'das',
#    '<eTARGET>',
#    'Thema',
#    '</eTARGET>',
#    'doch',
#    'nicht',
#    'ganz',
#    '<ePEXP>',
#    'totschweigen',
#    '</ePEXP>',
#    '.'],
#   ['Schliesslich',
#    'hat',
#    '<eSOURCE>',
#    'Netflix',
#    '</eSOURCE>',
#    'für',
#    'dieses',
#    'Jahr',
#    'bereits',
#    'achtzig',
#    'Eigenproduktionen',
#    'angekündigt',
#    ',',
#    'die',
#    'meisten',
#    'davon',
#    'werden',
#    'in',
#    'dem',
#    'mit',
#    'Amerika',
#    'und',
#    'Asien',
#    'vergleichsweise',
#    'weniger',
#    'starken',
#    'Markt',
#    'Europa',
#    'nicht',
#    'die',
#    '<eTARGET>',
#    'Lichtspielhäuser',
#    '</eTARGET>',
#    '<ePEXP>',
#    'erreichen',
#    '</ePEXP>',
#    '.'],
#   ['Mit',
#    'ihrem',
#    'Positionsbezug',
#    'stellt',
#    'sich',
#    'die',
#    '<eSOURCE>',
#    'Bundesrätin',
#    '</eSOURCE>',
#    'auch',
#    'gegen',
#    'eine',
#    '<eTARGET>',
#    'Aufforderung',
#    '</eTARGET>',
#    'von',
#    'Donald',
#    'Trump',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Aber',
#    'in',
#    'einer',
#    'Zeit',
#    ',',
#    'in',
#    'der',
#    'Medien',
#    'unter',
#    'dem',
#    'Druck',
#    'stehen',
#    ',',
#    'Nachrichten',
#    'möglichst',
#    'rasch',
#    'online',
#    'zu',
#    'veröffentlichen',
#    ',',
#    'und',
#    'keine',
#    'Zeit',
#    'für',
#    'tiefgreifendere',
#    'Analysen',
#    'bleibt',
#    ',',
#    'führt',
#    'eine',
#    'schönfärberische',
#    'Kommunikationspolitik',
#    'zu',
#    'Verzerrungen',
#    '–',
#    'in',
#    'der',
#    'Öffentlichkeit',
#    '<ePEXP>',
#    'entsteht',
#    '</ePEXP>',
#    'ein',
#    'Bild',
#    ',',
#    'das',
#    'die',
#    'Realität',
#    'nur',
#    'ungenau',
#    'spiegelt',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Und',
#    'für',
#    'einmal',
#    '<ePEXP>',
#    'übertreibt',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Präsident',
#    '</eSOURCE>',
#    'mit',
#    'dieser',
#    '<eTARGET>',
#    'Aussage',
#    '</eTARGET>',
#    'nicht',
#    '.'],
#   ['Gemäss',
#    'ersten',
#    'Erkenntnissen',
#    '<ePEXP>',
#    'brach',
#    '</ePEXP>',
#    'auch',
#    'der',
#    '<eSOURCE>',
#    'Funkkontakt',
#    '</eSOURCE>',
#    'ab',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Auf',
#    'der',
#    'anderen',
#    'Seite',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Federer',
#    '</eSOURCE>',
#    'bei',
#    'der',
#    'ganzen',
#    'Routine',
#    'im',
#    'Tour-Kalender',
#    'auf',
#    'ein',
#    'neues',
#    '<eTARGET>',
#    'Kapitel',
#    '</eTARGET>',
#    ':',
#    '«',
#    'Key',
#    'Biscayne',
#    'war',
#    'schön',
#    ',',
#    'lässig',
#    ',',
#    'hatte',
#    'Geschichte',
#    '.'],
#   ['Auf',
#    'Dauer',
#    'könne',
#    '<eSOURCE>',
#    'Russland',
#    '</eSOURCE>',
#    'die',
#    'internationale',
#    '<eTARGET>',
#    'Isolation',
#    '</eTARGET>',
#    'aber',
#    'nicht',
#    '<ePEXP>',
#    'durchhalten',
#    '</ePEXP>',
#    '.'],
#   ['Einsichtig',
#    ':',
#    'FCB',
#    '<eSOURCE>',
#    'Youngster',
#    '</eSOURCE>',
#    'Sebastiano',
#    'Esposito',
#    'hat',
#    'sich',
#    'vor',
#    'versammelter',
#    'Mannschaft',
#    'für',
#    'sein',
#    '<eTARGET>',
#    'Verhalten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'entschuldigt',
#    '</ePEXP>',
#    '.'],
#   ['Dass',
#    'sich',
#    '<eSOURCE>',
#    'Cesla',
#    '</eSOURCE>',
#    'Amarelle',
#    'und',
#    'Silvia',
#    'Steiner',
#    'für',
#    'den',
#    '<eTARGET>',
#    'Austausch',
#    '</eTARGET>',
#    '<ePEXP>',
#    'einsetzen',
#    '</ePEXP>',
#    ',',
#    'hat',
#    'auch',
#    'persönliche',
#    'Gründe',
#    '.'],
#   ['Auch',
#    'weil',
#    '<eSOURCE>',
#    'London',
#    '</eSOURCE>',
#    'Steuerprivilegien',
#    'abschafft',
#    ',',
#    'zieht',
#    'es',
#    'vermögende',
#    'Russen',
#    'in',
#    'die',
#    'Schweiz',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['In',
#    'der',
#    'vergangenen',
#    'Woche',
#    'hatten',
#    'Exxon',
#    '<eSOURCE>',
#    'Mobil',
#    '</eSOURCE>',
#    'und',
#    'Chevron',
#    'deutliche',
#    '<eTARGET>',
#    'Produktionssteigerungen',
#    '</eTARGET>',
#    'im',
#    'texanischen',
#    'Permian',
#    'Basin',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    'vom',
#    'Bankier',
#    'Claudio',
#    'Segré',
#    'gegründete',
#    '<eSOURCE>',
#    'Stiftung',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'widmet',
#    '</ePEXP>',
#    'sich',
#    'dem',
#    '<eTARGET>',
#    'Schutz',
#    '</eTARGET>',
#    'der',
#    'Biodiversität',
#    '.'],
#   ['Der',
#    'grosse',
#    '<eSOURCE>',
#    'Handelsbilanzüberschuss',
#    '</eSOURCE>',
#    'der',
#    'Schweiz',
#    'bei',
#    'Medikamenten',
#    '<ePEXP>',
#    'missfällt',
#    '</ePEXP>',
#    'der',
#    '<eTARGET>',
#    'Administration',
#    '</eTARGET>',
#    'von',
#    'Donald',
#    'Trump',
#    '.'],
#   ['Langsam',
#    'aber',
#    'stellte',
#    'sich',
#    'im',
#    'Land',
#    'der',
#    'Durchhalteparolen',
#    'eine',
#    'neue',
#    '<eSOURCE>',
#    'Lust',
#    '</eSOURCE>',
#    'am',
#    'Essen',
#    '–',
#    'und',
#    'an',
#    'dessen',
#    'Zubereitung',
#    '–',
#    'ein',
#    ':',
#    'ein',
#    'Prozess',
#    ',',
#    'der',
#    'in',
#    'den',
#    'fünfziger',
#    'Jahren',
#    'begann',
#    'und',
#    'in',
#    'den',
#    'Achtzigern',
#    'so',
#    'richtig',
#    'in',
#    'Schwung',
#    'kam',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Bisher',
#    'hatten',
#    'sich',
#    'die',
#    '<eSOURCE>',
#    'Vereinigten',
#    'Staaten',
#    '</eSOURCE>',
#    'mit',
#    'Verkäufen',
#    'von',
#    'Angriffswaffen',
#    'zurückgehalten',
#    ',',
#    'um',
#    'China',
#    'nicht',
#    'zu',
#    'reizen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Chefärzte',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'nutzen',
#    '</ePEXP>',
#    'ihre',
#    '<eTARGET>',
#    'Position',
#    '</eTARGET>',
#    'aus',
#    ',',
#    'um',
#    'sich',
#    'zu',
#    'bereichern',
#    '.'],
#   ['Damit',
#    'verfügen',
#    'die',
#    'Konservativen',
#    'seit',
#    'anderthalb',
#    'Jahren',
#    'über',
#    'eine',
#    'klarere',
#    'Mehrheit',
#    'im',
#    'neunköpfigen',
#    'Gremium',
#    ',',
#    'weil',
#    '<eSOURCE>',
#    'Kavanaugh',
#    '</eSOURCE>',
#    'den',
#    'moderaten',
#    'Konservativen',
#    'Anthony',
#    'Kennedy',
#    '<ePEXP>',
#    'ersetzte',
#    '</ePEXP>',
#    ',',
#    'der',
#    'als',
#    'Zünglein',
#    'an',
#    'der',
#    'Waage',
#    'oft',
#    'auch',
#    'den',
#    'progressiven',
#    'Richtern',
#    'zu',
#    'einer',
#    'Mehrheit',
#    'verholfen',
#    'hatte',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Diesem',
#    '<eTARGET>',
#    'Trend',
#    '</eTARGET>',
#    'scheint',
#    'sich',
#    'jetzt',
#    'der',
#    '<eSOURCE>',
#    'Verlegerverband',
#    '</eSOURCE>',
#    'zusehends',
#    'anzupassen',
#    ',',
#    'gemäss',
#    'dem',
#    'Motto',
#    ':',
#    'Wenn',
#    'schon',
#    'gefördert',
#    'wird',
#    ',',
#    'dann',
#    'wollen',
#    'wir',
#    'auch',
#    'teilhaben',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['«',
#    'Wir',
#    'haben',
#    'ihn',
#    'mithilfe',
#    'eines',
#    'Defibrillator-Einsatzes',
#    'zurückbekommen',
#    '»',
#    ',',
#    'sagte',
#    'Boesen',
#    ',',
#    '«',
#    'und',
#    'das',
#    'relativ',
#    'schnell',
#    '.',
#    '»',
#    'Offenbar',
#    'genügte',
#    'eine',
#    'einzige',
#    '<eSOURCE>',
#    'Defibrillation',
#    '</eSOURCE>',
#    ',',
#    'um',
#    'den',
#    'Sportler',
#    'vor',
#    'dem',
#    '<eTARGET>',
#    'Tod',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'bewahren',
#    '</ePEXP>',
#    '.'],
#   ['Nur',
#    'dem',
#    '<eTARGET>',
#    'Vater',
#    '</eTARGET>',
#    '<ePEXP>',
#    'fehlte',
#    '</ePEXP>',
#    'immer',
#    'noch',
#    'das',
#    'begehrte',
#    'rote',
#    '<eSOURCE>',
#    'Büchlein',
#    '</eSOURCE>',
#    '.'],
#   ['Mehrere',
#    '<eSOURCE>',
#    'Regionalspitäler',
#    '</eSOURCE>',
#    'haben',
#    'die',
#    'monetären',
#    'Fehlanreize',
#    'bereits',
#    'aus',
#    'ihren',
#    '<eTARGET>',
#    'Vergütungssystemen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'entfernt',
#    '</ePEXP>',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Code',
#    '</eSOURCE>',
#    'wird',
#    'zu',
#    'einer',
#    'Sprachgewalt',
#    ',',
#    'deren',
#    'Grammatik',
#    'unseren',
#    '<eTARGET>',
#    'Alltag',
#    '</eTARGET>',
#    '<ePEXP>',
#    'prägt',
#    '</ePEXP>',
#    '.'],
#   ['sak',
#    '.',
#    '·',
#    'Zwischen',
#    '1998',
#    'und',
#    '2001',
#    '<ePEXP>',
#    'ermordete',
#    '</ePEXP>',
#    'die',
#    'weissrussische',
#    '<eSOURCE>',
#    'Spezialeinheit',
#    '</eSOURCE>',
#    'Sobr',
#    'rund',
#    'dreissig',
#    '<eTARGET>',
#    'Menschen',
#    '</eTARGET>',
#    '.'],
#   ['100000',
#    'zusätzliche',
#    'Menschen',
#    'soll',
#    'die',
#    '<eSOURCE>',
#    'Stadt',
#    '</eSOURCE>',
#    'Zürich',
#    'in',
#    'den',
#    'nächsten',
#    'gut',
#    'zwanzig',
#    'Jahren',
#    '<ePEXP>',
#    'aufnehmen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Damit',
#    'ist',
#    'La',
#    'Scintilla',
#    'das',
#    'einzige',
#    'Originalklang-Ensemble',
#    ',',
#    'dessen',
#    'Mitglieder',
#    'sich',
#    'nicht',
#    'ausschliesslich',
#    'der',
#    'historisch',
#    'informierten',
#    '<eTARGET>',
#    'Musizierpraxis',
#    '</eTARGET>',
#    'widmen',
#    ',',
#    'sondern',
#    'auch',
#    'im',
#    '«',
#    'normalen',
#    '»',
#    'Opernbetrieb',
#    'mitmachen',
#    '<eSOURCE>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eSOURCE>'],
#   ['Für',
#    'ein',
#    '<eTARGET>',
#    'Ja',
#    '</eTARGET>',
#    '<ePEXP>',
#    'plädierte',
#    '</ePEXP>',
#    'in',
#    'Bern',
#    'dann',
#    'allerdings',
#    'einzig',
#    'die',
#    'an',
#    'der',
#    'Universität',
#    'Zürich',
#    'lehrende',
#    '<eSOURCE>',
#    'Politologin',
#    '</eSOURCE>',
#    'Elham',
#    'Manea',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Aktienkurs',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'schoss',
#    '</ePEXP>',
#    'bis',
#    'Mitte',
#    'Juni',
#    'auf',
#    'mehr',
#    'als',
#    '400',
#    '<eTARGET>',
#    'Pence',
#    '</eTARGET>',
#    '.'],
#   ['Eben',
#    'wurde',
#    'von',
#    'der',
#    'Wohngemeinschaft',
#    'erwogen',
#    ',',
#    'das',
#    'freie',
#    'Zimmer',
#    'einem',
#    'Flüchtling',
#    'zu',
#    'vermieten',
#    ',',
#    'da',
#    'stellt',
#    'sich',
#    '<eSOURCE>',
#    'Doro',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'Pragmatikerin',
#    ',',
#    'in',
#    'der',
#    'Mitte',
#    'der',
#    'Küche',
#    'auf',
#    'und',
#    'feuert',
#    ':',
#    '«',
#    'Ich',
#    'hasse',
#    'arabische',
#    'Männer',
#    '<eTARGET>',
#    '<ePEXP>',
#    '!',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Nun',
#    ',',
#    'nach',
#    'seiner',
#    'Verurteilung',
#    'und',
#    'dem',
#    'Bekanntwerden',
#    'der',
#    'Grüsel-Vorwürfe',
#    ',',
#    '<ePEXP>',
#    'sorgt',
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Fäh',
#    '</eSOURCE>',
#    'um',
#    'die',
#    '<eTARGET>',
#    'Zukunft',
#    '</eTARGET>',
#    'des',
#    'Sternen',
#    ':',
#    '«',
#    'Ich',
#    'befürchte',
#    ',',
#    'wir',
#    'verkraften',
#    'das',
#    'nicht',
#    '.'],
#   ['Damit',
#    'rückt',
#    'der',
#    'angekündigte',
#    ',',
#    'grund',
#    '\xad',
#    '-',
#    'legende',
#    'Strategiewechsel',
#    'in',
#    'weite',
#    'Ferne',
#    ':',
#    'Ursprünglich',
#    'wollte',
#    'der',
#    '<eSOURCE>',
#    'Bundesrat',
#    '</eSOURCE>',
#    'im',
#    'zweiten',
#    'Teil',
#    'der',
#    'Energiewende',
#    'die',
#    'Förderbeiträge',
#    'sukzessive',
#    'abschaffen',
#    'und',
#    'stattdessen',
#    'ein',
#    'Lenkungssystem',
#    'einführen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Alfredo',
#    'Binda',
#    'dominierte',
#    'in',
#    'den',
#    '1920er-Jahren',
#    'den',
#    'Giro',
#    'derart',
#    ',',
#    'dass',
#    'die',
#    '<eSOURCE>',
#    'Organisatoren',
#    '</eSOURCE>',
#    'ihren',
#    'eigenen',
#    '<eTARGET>',
#    'Landsmann',
#    '</eTARGET>',
#    '<ePEXP>',
#    'bestachen',
#    '</ePEXP>',
#    '.'],
#   ['Ich',
#    'kann',
#    'Ihnen',
#    'versichern',
#    ',',
#    'dass',
#    '<eSOURCE>',
#    'Roche',
#    '</eSOURCE>',
#    'immer',
#    'mit',
#    'hohem',
#    'Augenmass',
#    '<eTARGET>',
#    'Medikamentenpreise',
#    '</eTARGET>',
#    '<ePEXP>',
#    'festlegt',
#    '</ePEXP>',
#    '.'],
#   ['Seit',
#    'Anfang',
#    'des',
#    'Jahres',
#    'haben',
#    'die',
#    'Behörden',
#    'weitere',
#    '13',
#    'Versuche',
#    'registriert',
#    ',',
#    '7',
#    '<eSOURCE>',
#    'Boote',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'erreichten',
#    '</ePEXP>',
#    'die',
#    'englische',
#    '<eTARGET>',
#    'Küste',
#    '</eTARGET>',
#    '.'],
#   ['(',
#    'sda',
#    '/',
#    'afp',
#    ')',
#    '·',
#    'Das',
#    '<eSOURCE>',
#    'Parlament',
#    '</eSOURCE>',
#    'in',
#    'Rumänien',
#    'hat',
#    'der',
#    '<eTARGET>',
#    'Minderheitsregierung',
#    '</eTARGET>',
#    'des',
#    'neuen',
#    'rumänischen',
#    'Ministerpräsidenten',
#    'Ludovic',
#    'Orban',
#    'am',
#    'Montag',
#    'das',
#    'Vertrauen',
#    '<ePEXP>',
#    'ausgesprochen',
#    '</ePEXP>',
#    '.'],
#   ['Andere',
#    '<eSOURCE>',
#    'Gespräche',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'widmen',
#    '</ePEXP>',
#    'sich',
#    'der',
#    '<eTARGET>',
#    'Pandemie',
#    '</eTARGET>',
#    ',',
#    'Krankheit',
#    'und',
#    'Körper',
#    'oder',
#    'der',
#    'Berührbarkeit',
#    'durch',
#    'klassische',
#    'Musik',
#    '.'],
#   ['So',
#    'hat',
#    'Mueller',
#    'herausgefunden',
#    ',',
#    'dass',
#    'Trumps',
#    'ehemaliger',
#    '<eSOURCE>',
#    'Wahlkampfleiter',
#    '</eSOURCE>',
#    'Paul',
#    'Manafort',
#    'als',
#    'Lobbyist',
#    'früher',
#    'zig',
#    'Millionen',
#    'Dollar',
#    '<ePEXP>',
#    'verdient',
#    '</ePEXP>',
#    ',',
#    'aber',
#    'nicht',
#    'versteuert',
#    'hat',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Deshalb',
#    '<ePEXP>',
#    'nutzen',
#    '</ePEXP>',
#    'viele',
#    '<eSOURCE>',
#    'Mediziner',
#    '</eSOURCE>',
#    '5',
#    '<eTARGET>',
#    'ALA',
#    '</eTARGET>',
#    ',',
#    'das',
#    'kaum',
#    'Nebenwirkungen',
#    'hat',
#    ',',
#    'zum',
#    'Beispiel',
#    'auch',
#    'am',
#    'Berner',
#    'Inselspital',
#    '–',
#    'jedoch',
#    'einzig',
#    'bei',
#    'höchstgradig',
#    'bösartigen',
#    'Hirntumoren',
#    '(',
#    'Glioblastom',
#    ')',
#    '.'],
#   ['<eSOURCE>',
#    'Macron',
#    '</eSOURCE>',
#    'hatte',
#    'eine',
#    'Million',
#    'Corona-Tests',
#    'pro',
#    'Woche',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Kein',
#    'Wunder',
#    ',',
#    '<ePEXP>',
#    'widmete',
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Charles',
#    '</eSOURCE>',
#    'Darwin',
#    'der',
#    '<eTARGET>',
#    'Tiergruppe',
#    '</eTARGET>',
#    'wähend',
#    'acht',
#    'Jahren',
#    'seines',
#    'Forscherlebens',
#    '.'],
#   ['Sondern',
#    ':',
#    'In',
#    'der',
#    'komplexen',
#    'Sportart',
#    'Eishockey',
#    'stellen',
#    'sich',
#    'viele',
#    '<eSOURCE>',
#    'Automatismen',
#    '</eSOURCE>',
#    ',',
#    'die',
#    'perfekte',
#    'Abstimmung',
#    'beispielsweise',
#    'im',
#    'Power-',
#    'und',
#    'Boxplay',
#    ',',
#    'hauptsächlich',
#    'mit',
#    'vielen',
#    'Spieleinsätzen',
#    'ein',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Einen',
#    'Tag',
#    'nach',
#    'der',
#    'Kabinenpredigt',
#    '<ePEXP>',
#    'siegt',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Bern',
#    '</eSOURCE>',
#    'gegen',
#    '<eTARGET>',
#    'Servette',
#    '</eTARGET>',
#    '(',
#    '3',
#    ':',
#    '2',
#    'n.',
#    'V.',
#    ')',
#    'erstmals',
#    'nach',
#    'drei',
#    'Pleiten',
#    '.'],
#   ['Auch',
#    '<eSOURCE>',
#    'Becir',
#    '</eSOURCE>',
#    'Omeragic',
#    '<ePEXP>',
#    'fehlte',
#    '</ePEXP>',
#    'mit',
#    'einer',
#    'Knieverletzung',
#    'am',
#    '<eTARGET>',
#    'Anfang',
#    '</eTARGET>',
#    'der',
#    'Saison',
#    '.'],
#   ['Nicht',
#    'nur',
#    '<eSOURCE>',
#    'Boris',
#    '</eSOURCE>',
#    'Becker',
#    '<ePEXP>',
#    'traut',
#    '</ePEXP>',
#    '<eTARGET>',
#    'Nadal',
#    '</eTARGET>',
#    'zu',
#    ',',
#    'dass',
#    'er',
#    'den',
#    'Rekord',
#    'bald',
#    'allein',
#    'hält',
#    '.'],
#   ['«',
#    'Eine',
#    'hundertprozentige',
#    'Garantie',
#    'gibt',
#    'es',
#    'nie',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '»',
#    'Auch',
#    'flächendeckendes',
#    '<eSOURCE>',
#    'Testen',
#    '</eSOURCE>',
#    'werde',
#    'das',
#    'Virus',
#    'nicht',
#    'zum',
#    'Aussterben',
#    '<ePEXP>',
#    'bringen',
#    '</ePEXP>',
#    ',',
#    'mahnt',
#    'Krismer',
#    '.'],
#   ['Bei',
#    'fairen',
#    'Präsidentschafts-',
#    'und',
#    'Parlamentswahlen',
#    'muss',
#    'der',
#    '<eSOURCE>',
#    'Staatschef',
#    '</eSOURCE>',
#    'um',
#    'den',
#    '<eTARGET>',
#    'Sieg',
#    '</eTARGET>',
#    '<ePEXP>',
#    'fürchten',
#    '</ePEXP>',
#    '.'],
#   ['Doch',
#    'nun',
#    'wachsen',
#    'die',
#    'Zweifel',
#    ',',
#    'nachdem',
#    'das',
#    'saudische',
#    '<eSOURCE>',
#    'Regime',
#    '</eSOURCE>',
#    'die',
#    '<eTARGET>',
#    'Tötung',
#    '</eTARGET>',
#    'des',
#    'Journalisten',
#    'Jamal',
#    'Khashoggi',
#    '<ePEXP>',
#    'eingeräumt',
#    '</ePEXP>',
#    'hat',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'SBB',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'entschuldigen',
#    '</ePEXP>',
#    'sich',
#    'für',
#    'die',
#    '<eTARGET>',
#    'Umstände',
#    '</eTARGET>',
#    '.'],
#   ['Zwar',
#    'hat',
#    '<eSOURCE>',
#    'Easyjet',
#    '</eSOURCE>',
#    'Flüge',
#    'nach',
#    'Berlin',
#    '<ePEXP>',
#    'aufgenommen',
#    '</ePEXP>',
#    'und',
#    'fliegt',
#    'die',
#    'Strecke',
#    'bis',
#    'zu',
#    'sechsmal',
#    'täglich',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Der',
#    '<eSOURCE>',
#    'Ausdruck',
#    '</eSOURCE>',
#    '«',
#    'Negrita',
#    '»',
#    '(',
#    '«',
#    'kleiner',
#    'schwarzer',
#    'Mensch',
#    '»',
#    ')',
#    'hatte',
#    'dem',
#    'uruguayischen',
#    '<eTARGET>',
#    'Fussballstar',
#    '</eTARGET>',
#    'Edison',
#    'Cavani',
#    'kürzlich',
#    'eine',
#    'Geldstrafe',
#    'wegen',
#    'Rassismus',
#    '<ePEXP>',
#    'eingebracht',
#    '</ePEXP>',
#    '.'],
#   ['Sie',
#    'ergänzt',
#    ':',
#    '«',
#    'Ein',
#    'Körper',
#    'muss',
#    'nicht',
#    'perfekt',
#    'sein',
#    ',',
#    'um',
#    'schön',
#    'zu',
#    'sein',
#    '.',
#    '»',
#    'Hochschwanger',
#    '<ePEXP>',
#    'freute',
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Sara',
#    '</eSOURCE>',
#    'Leutenegger',
#    'im',
#    'Oktober',
#    'auf',
#    'die',
#    '<eTARGET>',
#    'Geburt',
#    '</eTARGET>',
#    '.'],
#   ['<eSOURCE>',
#    'Ghosn',
#    '</eSOURCE>',
#    'hat',
#    'über',
#    'seinen',
#    'Anwalt',
#    'einen',
#    'Medienbericht',
#    '<ePEXP>',
#    'zurückgewiesen',
#    '</ePEXP>',
#    ',',
#    'wonach',
#    'er',
#    '2008',
#    'einen',
#    'Verlust',
#    'aus',
#    'Wertpapiergeschäften',
#    'auf',
#    'Nissan',
#    'übertragen',
#    'haben',
#    'soll',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Drei',
#    'Tage',
#    'später',
#    '<ePEXP>',
#    'entliess',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'YB',
#    '</eSOURCE>',
#    'den',
#    '<eTARGET>',
#    'CEO',
#    '</eTARGET>',
#    'Niedermaier',
#    ',',
#    'es',
#    'gab',
#    'Parolen',
#    'des',
#    'Aufbruchs',
#    '.'],
#   ['sho',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '·',
#    '2017',
#    '<ePEXP>',
#    'entliess',
#    '</ePEXP>',
#    'der',
#    '<eSOURCE>',
#    'Gemeinderat',
#    '</eSOURCE>',
#    'Maschwanden',
#    'gleichzeitig',
#    'mit',
#    'der',
#    'Baubewilligung',
#    'für',
#    'zwei',
#    'Ersatzbauten',
#    'und',
#    'einen',
#    'Neubau',
#    'ein',
#    'Gehöft',
#    'aus',
#    'dem',
#    '19.',
#    'Jahrhundert',
#    'am',
#    'Dorfrand',
#    'aus',
#    'dem',
#    'kommunalen',
#    'Schutzinventar',
#    '.'],
#   ['Bei',
#    'diesem',
#    'Training',
#    'orientiere',
#    'man',
#    'sich',
#    'am',
#    'Militär',
#    ',',
#    'das',
#    'solche',
#    'Übungen',
#    'einsetze',
#    ',',
#    'damit',
#    'die',
#    '<eSOURCE>',
#    'Soldaten',
#    '</eSOURCE>',
#    'besser',
#    'mit',
#    'schwierigen',
#    '<eTARGET>',
#    'Situationen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'umgehen',
#    '</ePEXP>',
#    'könnten',
#    '.'],
#   ['Im',
#    '«',
#    'Goldenen',
#    'Handschuh',
#    '»',
#    'tut',
#    'ein',
#    '<eSOURCE>',
#    'Mann',
#    '</eSOURCE>',
#    'alles',
#    ',',
#    'um',
#    '<eTARGET>',
#    'Frauen',
#    '</eTARGET>',
#    'zu',
#    '<ePEXP>',
#    'zerstören',
#    '</ePEXP>',
#    '.'],
#   ['Agnes',
#    'Merz',
#    ',',
#    'Goldau',
#    'Sehr',
#    'gut',
#    ',',
#    'dass',
#    'sich',
#    'jetzt',
#    'auch',
#    '<eSOURCE>',
#    'Petra',
#    '</eSOURCE>',
#    'Gössi',
#    'als',
#    'FDP-Chefin',
#    'für',
#    'den',
#    '<eTARGET>',
#    'Klimaschutz',
#    '</eTARGET>',
#    '<ePEXP>',
#    'einsetzt',
#    '</ePEXP>',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Unternehmen',
#    '</eSOURCE>',
#    'suchen',
#    'nach',
#    'Wegen',
#    ',',
#    'um',
#    'sich',
#    'für',
#    'den',
#    'demografischen',
#    '<eTARGET>',
#    'Wandel',
#    '</eTARGET>',
#    'zu',
#    'wappnen',
#    ',',
#    'und',
#    'stellen',
#    'sich',
#    'auf',
#    'die',
#    'veränderten',
#    'Anforderungen',
#    'der',
#    'nachrückenden',
#    'Generation',
#    'ein',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Während',
#    'es',
#    'bei',
#    'den',
#    'Offsets',
#    'also',
#    'eine',
#    '«',
#    'Kantonsrebellion',
#    '»',
#    'gab',
#    ',',
#    'hat',
#    'sich',
#    'die',
#    'ständerätliche',
#    '<eSOURCE>',
#    'Kommission',
#    '</eSOURCE>',
#    'beim',
#    'Rest',
#    'der',
#    'Vorlage',
#    'hinter',
#    'den',
#    'Bundesrat',
#    'gestellt',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Janssen',
#    '</eSOURCE>',
#    'lässt',
#    'denn',
#    'auch',
#    'seine',
#    'Studenten',
#    'nichts',
#    'am',
#    'Zeichentisch',
#    'entwerfen',
#    ',',
#    'sondern',
#    'stellt',
#    'Fragen',
#    'nach',
#    'der',
#    'gesellschaftlichen',
#    'Relevanz',
#    'der',
#    'Architektur',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'Operation',
#    'dauerte',
#    'laut',
#    'amerikanischen',
#    'Medien',
#    'acht',
#    'Stunden',
#    ',',
#    'das',
#    'transplantierte',
#    '<eSOURCE>',
#    'Herz',
#    '</eSOURCE>',
#    'habe',
#    'seitdem',
#    'seine',
#    '<eTARGET>',
#    'Arbeit',
#    '</eTARGET>',
#    'aufgenommen',
#    ',',
#    'dem',
#    'Patienten',
#    'gehe',
#    'es',
#    'gut',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Darin',
#    '<ePEXP>',
#    'verliebt',
#    '</ePEXP>',
#    'sich',
#    'ein',
#    '16',
#    '<eSOURCE>',
#    'Jähriger',
#    '</eSOURCE>',
#    'in',
#    'einen',
#    '<eTARGET>',
#    'Rockmusiker',
#    '</eTARGET>',
#    ',',
#    'dem',
#    'er',
#    'bis',
#    'zur',
#    'Selbstaufgabe',
#    'folgt',
#    '.'],
#   ['Yvonne',
#    'Bozdag',
#    ',',
#    'Waltershausen',
#    '(',
#    'D',
#    ')',
#    'Trump',
#    'wird',
#    'Europa',
#    'noch',
#    'ins',
#    'Chaos',
#    '<ePEXP>',
#    'stürzen',
#    '</ePEXP>',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Es',
#    'lief',
#    'erst',
#    'die',
#    'fünfte',
#    'Minute',
#    ',',
#    'Englands',
#    '<eSOURCE>',
#    'Coach',
#    '</eSOURCE>',
#    'Gareth',
#    'Southgate',
#    'ballte',
#    'kurz',
#    'die',
#    'Faust',
#    'und',
#    'stellte',
#    'sich',
#    'wieder',
#    'unter',
#    'das',
#    'Dach',
#    'der',
#    'Spielerbank',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Solothurn',
#    '</eSOURCE>',
#    'und',
#    'Basel',
#    'hatten',
#    'am',
#    'Dienstag',
#    'ebenfalls',
#    'schärfere',
#    '<eTARGET>',
#    'Regeln',
#    '</eTARGET>',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '.'],
#   ['Chinesische',
#    '<eSOURCE>',
#    'Staatsmedien',
#    '</eSOURCE>',
#    'haben',
#    'Vorwürfe',
#    'der',
#    'US-Regierung',
#    'über',
#    'eine',
#    'Vertuschung',
#    'in',
#    'der',
#    'Corona-Krise',
#    'und',
#    'den',
#    'Ursprung',
#    'des',
#    'Virus',
#    'als',
#    '«',
#    'grundlose',
#    'Beschuldigungen',
#    '»',
#    '<ePEXP>',
#    'zurückgewiesen',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Doch',
#    'die',
#    'langwierige',
#    '<eSOURCE>',
#    'Jagd',
#    '</eSOURCE>',
#    'nach',
#    'der',
#    'Krone',
#    '<ePEXP>',
#    'prägte',
#    '</ePEXP>',
#    'seine',
#    '<eTARGET>',
#    'Karriere',
#    '</eTARGET>',
#    '.'],
#   ['Vergleicht',
#    'man',
#    'nur',
#    'die',
#    'Zahl',
#    'der',
#    'Neuimmatrikulationen',
#    ',',
#    'so',
#    'ist',
#    'der',
#    'Rückgang',
#    'noch',
#    'viel',
#    'stärker',
#    ':',
#    'Diesen',
#    'Herbst',
#    'haben',
#    '43',
#    '%',
#    'weniger',
#    '<eSOURCE>',
#    'Ausländer',
#    '</eSOURCE>',
#    'neu',
#    'ein',
#    'Studium',
#    'in',
#    'den',
#    'USA',
#    'aufgenommen',
#    'als',
#    'im',
#    'Vorjahr',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    'bedrängten',
#    '<eSOURCE>',
#    'Juden',
#    '</eSOURCE>',
#    'hätten',
#    'sich',
#    'der',
#    '<eTARGET>',
#    'Zwangstaufe',
#    '</eTARGET>',
#    '<ePEXP>',
#    'widersetzt',
#    '</ePEXP>',
#    'und',
#    'so',
#    'ein',
#    'leuchtendes',
#    'Beispiel',
#    'für',
#    'die',
#    'Heiligung',
#    'des',
#    'göttlichen',
#    'Namens',
#    'gegeben',
#    '.'],
#   ['Zahlreiche',
#    '<eSOURCE>',
#    'Staaten',
#    '</eSOURCE>',
#    ',',
#    'darunter',
#    'die',
#    'USA',
#    ',',
#    'aber',
#    'auch',
#    'die',
#    'EU',
#    'haben',
#    'nun',
#    '<eTARGET>',
#    'Sanktionen',
#    '</eTARGET>',
#    'gegen',
#    'Russland',
#    'angekündigt',
#    'oder',
#    'schon',
#    'verhängt',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Das',
#    '<eSOURCE>',
#    'Attentat',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'galt',
#    '</ePEXP>',
#    'laut',
#    'Wasiri',
#    'einem',
#    '<eTARGET>',
#    'Stützpunkt',
#    '</eTARGET>',
#    'der',
#    '111',
#    '.'],
#   ['Und',
#    'viele',
#    '<eSOURCE>',
#    'Frauenrechtlerinnen',
#    '</eSOURCE>',
#    'stellen',
#    'sich',
#    'trotz',
#    'der',
#    'Unterdrückung',
#    'Andersdenkender',
#    'hinter',
#    'den',
#    'Kurs',
#    'des',
#    'Kronprinzen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Viktor',
#    '</eSOURCE>',
#    'Orban',
#    'aus',
#    'Ungarn',
#    '<ePEXP>',
#    'freut',
#    '</ePEXP>',
#    'sich',
#    'auch',
#    'sehr',
#    'über',
#    '<eTARGET>',
#    'Meloni',
#    '</eTARGET>',
#    ',',
#    'weil',
#    'sich',
#    'ja',
#    'jetzt',
#    'mit',
#    'Freunden',
#    'in',
#    'Rom',
#    'die',
#    'Europäische',
#    'Union',
#    'verändern',
#    'lasse',
#    '.'],
#   ['Ein',
#    'amerikanischer',
#    '<eSOURCE>',
#    'Vergeltungsschlag',
#    '</eSOURCE>',
#    'mit',
#    'Drohnen',
#    '<ePEXP>',
#    'tötete',
#    '</ePEXP>',
#    'wiederum',
#    '150',
#    'Al-Shabab',
#    '<eTARGET>',
#    'Kämpfer',
#    '</eTARGET>',
#    '.'],
#   ['Dieser',
#    'eindeutige',
#    '<eSOURCE>',
#    'Machtmissbrauch',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'galt',
#    '</ePEXP>',
#    'damals',
#    'ohne',
#    'Zweifel',
#    'als',
#    'Impeachment-würdig',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['In',
#    'Jerusalem',
#    'haben',
#    'die',
#    'griechisch-orthodoxe',
#    'und',
#    'die',
#    'armenische',
#    'Kirche',
#    'sowie',
#    'die',
#    'Kustodie',
#    'des',
#    'Heiligen',
#    'Landes',
#    'gestern',
#    'die',
#    'unbefristete',
#    '<eTARGET>',
#    'Schliessung',
#    '</eTARGET>',
#    'der',
#    'Grabeskirche',
#    'in',
#    'der',
#    'Altstadt',
#    '<ePEXP>',
#    'angekündigt',
#    '</ePEXP>',
#    '–',
#    'aus',
#    'Protest',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Erfreulich',
#    ':',
#    'Im',
#    'Vergleich',
#    'mit',
#    'der',
#    'gesamten',
#    'Schweiz',
#    '<ePEXP>',
#    'achten',
#    '</ePEXP>',
#    'in',
#    'der',
#    'Stadt',
#    'Zürich',
#    'prozentual',
#    'mehr',
#    '<eSOURCE>',
#    'Menschen',
#    '</eSOURCE>',
#    'auf',
#    'gesundes',
#    'und',
#    'ausgewogenes',
#    '<eTARGET>',
#    'Essen',
#    '</eTARGET>',
#    '.'],
#   ['Der',
#    'Zahlungsverkehr',
#    'stellt',
#    'kein',
#    'Problem',
#    'dar',
#    ',',
#    'solange',
#    'nicht',
#    'alle',
#    'russischen',
#    '<eSOURCE>',
#    'Banken',
#    '</eSOURCE>',
#    'vom',
#    'globalen',
#    '<eTARGET>',
#    'Finanztransaktionssystem',
#    '</eTARGET>',
#    'Swift',
#    'ausgeschlossen',
#    'sind',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Saison',
#    '<eSOURCE>',
#    'Komiker',
#    '</eSOURCE>',
#    'und',
#    'Künstler',
#    ',',
#    'Komponisten',
#    'und',
#    'Dichter',
# ...
#    '</ePEXP>',
#    'sich',
#    '<eSOURCE>',
#    'Nelson',
#    '</eSOURCE>',
#    'Ferreira',
#    'nach',
#    'der',
#    'Partie',
#    'über',
#    'den',
#    'zweiten',
#    '<eTARGET>',
#    'Finaleinzug',
#    '</eTARGET>',
#    'in',
#    'der',
#    'Vereinsgeschichte',
#    'des',
#    'FC',
#    'Thun',
#    '.'],
#   ['Das',
#    'WM-Quartier',
#    'der',
#    'Nationalmannschaft',
#    'musste',
#    'er',
#    'einen',
#    'Tag',
#    'vor',
#    'WM-Beginn',
#    'durch',
#    'die',
#    'Hintertür',
#    'verlassen',
#    ',',
#    'weil',
#    'dem',
#    '<eTARGET>',
#    'Verbandschef',
#    '</eTARGET>',
#    'Luis',
#    'Rubiales',
#    'seine',
#    'ungeschickt',
#    'mitgeteilte',
#    '<eSOURCE>',
#    'Einigung',
#    '</eSOURCE>',
#    'mit',
#    'Real',
#    'Madrid',
#    'für',
#    'die',
#    'Zeit',
#    'nach',
#    'dem',
#    'Turnier',
#    '<ePEXP>',
#    'missfiel',
#    '</ePEXP>',
#    '.'],
#   ['Ausser',
#    'dem',
#    'republikanischen',
#    'Senator',
#    'Ted',
#    'Cruz',
#    'solidarisierte',
#    'sich',
#    'kaum',
#    'eine',
#    'bekannte',
#    '<eSOURCE>',
#    'Persönlichkeit',
#    '</eSOURCE>',
#    'mit',
#    'den',
#    '<eTARGET>',
#    'Truckern',
#    '</eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Der',
#    '<eSOURCE>',
#    'Wirtschaftsverband',
#    '</eSOURCE>',
#    'Economiesuisse',
#    'stellt',
#    'sich',
#    'auf',
#    'spürbare',
#    '<eTARGET>',
#    'Auswirkungen',
#    '</eTARGET>',
#    'ein',
#    ',',
#    'auch',
#    'für',
#    'die',
#    'Schweiz',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['Für',
#    'jede',
#    '<eTARGET>',
#    'Generation',
#    '</eTARGET>',
#    'stellt',
#    'sich',
#    'aufs',
#    'Neue',
#    'die',
#    '<eSOURCE>',
#    'Herausforderung',
#    '</eSOURCE>',
#    ',',
#    'herauszufinden',
#    ',',
#    'welches',
#    'Spiel',
#    'gerade',
#    'gespielt',
#    'wird',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['In',
#    'der',
#    'gegenwärtigen',
#    'Diskurs-Unkultur',
#    'diffamieren',
#    'kulturell',
#    'orientierungslose',
#    'Linksliberale',
#    'gern',
#    'um',
#    'die',
#    '<eTARGET>',
#    'Bewahrung',
#    '</eTARGET>',
#    'der',
#    'Freiheit',
#    '<ePEXP>',
#    'kämpfende',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Liberal',
#    '</eSOURCE>',
#    'Konservative',
#    '.'],
#   ['Einige',
#    '<eSOURCE>',
#    'Kirchenleute',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'fürchten',
#    '</ePEXP>',
#    'sich',
#    'offenbar',
#    'vor',
#    'einer',
#    '<eTARGET>',
#    'Gestalt',
#    '</eTARGET>',
#    'wie',
#    'Locher',
#    '–',
#    'sie',
#    'werfen',
#    'ihm',
#    'vor',
#    ',',
#    'dass',
#    'er',
#    'seinen',
#    'Laden',
#    'nicht',
#    'im',
#    'Griff',
#    'habe',
#    'oder',
#    'dass',
#    'er',
#    'machtbesessen',
#    'und',
#    'narzisstisch',
#    'sei',
#    '.'],
#   ['Das',
#    '<eSOURCE>',
#    'Obergericht',
#    '</eSOURCE>',
#    'stellt',
#    'sich',
#    'in',
#    'seinem',
#    'schriftlichen',
#    'Urteil',
#    'zunächst',
#    'gegen',
#    'die',
#    'Ansicht',
#    'der',
#    'Verteidigung',
#    ',',
#    'wonach',
#    'keine',
#    'verwertbaren',
#    'Beweise',
#    'vorlägen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Das',
#    '<eSOURCE>',
#    'Trauma',
#    '</eSOURCE>',
#    'von',
#    'München',
#    'Vor',
#    '50',
#    'Jahren',
#    'spazierten',
#    'acht',
#    'Terroristen',
#    'ins',
#    'olympische',
#    'Dorf',
#    ',',
#    'um',
#    'Juden',
#    'zu',
#    'ermorden',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Vor',
#    'zweieinhalb',
#    'Wochen',
#    'aber',
#    '<ePEXP>',
#    'stürzte',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Becciu',
#    '</eSOURCE>',
#    'über',
#    'die',
#    'vielen',
#    '<eTARGET>',
#    'Ungereimtheiten',
#    '</eTARGET>',
#    'seines',
#    'Handelns',
#    '–',
#    'etwa',
#    'beim',
#    'Kauf',
#    'einer',
#    'Luxusimmobilie',
#    'in',
#    'London',
#    ',',
#    'bei',
#    'seinen',
#    'üppigen',
#    'Zuwendungen',
#    'für',
#    'seine',
#    'drei',
#    'Brüder',
#    'und',
#    'für',
#    'eine',
#    'mysteriöse',
#    '39',
#    'Jahre',
#    'alte',
#    'Sardin',
#    '.'],
#   ['Das',
#    'Departement',
#    'von',
#    'Umweltministerin',
#    'Simonetta',
#    'Sommaruga',
#    'will',
#    'die',
#    'Berechnungsmethodik',
#    'so',
#    'anpassen',
#    ',',
#    'dass',
#    'das',
#    '<eSOURCE>',
#    'Problem',
#    '</eSOURCE>',
#    'der',
#    'Verzerrungen',
#    'verschwindet',
#    'und',
#    'sicher',
#    'keine',
#    'Autos',
#    'mehr',
#    'in',
#    'der',
#    'Kategorie',
#    'A',
#    'sind',
#    ',',
#    'deren',
#    'Ausstoss',
#    'höher',
#    'ist',
#    'als',
#    'der',
#    'CO2-Zielwert',
#    'des',
#    'Bundes',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Die',
#    '<eSOURCE>',
#    'Spanier',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'verhafteten',
#    '</ePEXP>',
#    'sechs',
#    '<eTARGET>',
#    'Chinesen',
#    '</eTARGET>',
#    ',',
#    'drei',
#    'Spanier',
#    'und',
#    'drei',
#    'Marokkaner',
#    '.'],
#   ['Der',
#    '<eSOURCE>',
#    'Australier',
#    '</eSOURCE>',
#    'stellt',
#    'sich',
#    'zum',
#    'Aufschlag',
#    'bereit',
#    ',',
#    'hat',
#    'dabei',
#    'zwei',
#    'Bälle',
#    'in',
#    'der',
#    'Hand',
#    '–',
#    'wie',
#    'es',
#    'Tennisprofis',
#    'oft',
#    'tun',
#    ',',
#    'bevor',
#    'sie',
#    'sich',
#    'für',
#    'einen',
#    'der',
#    'beiden',
#    'entscheiden',
#    ',',
#    'der',
#    'dann',
#    'auf',
#    'die',
#    'andere',
#    'Netzseite',
#    'gepeitscht',
#    'werden',
#    'soll',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Pa',
#    '</eSOURCE>',
#    'Modou',
#    'hatte',
#    'fast',
#    'die',
#    'ganze',
#    '<eTARGET>',
#    'Rückrunde',
#    '</eTARGET>',
#    '<ePEXP>',
#    'verletzt',
#    '</ePEXP>',
#    'gefehlt',
#    ',',
#    'ihn',
#    'plagten',
#    'Rückenprobleme',
#    ',',
#    'der',
#    'FCZ',
#    'glaubte',
#    ',',
#    'es',
#    'gehe',
#    'nicht',
#    'mehr',
#    'weiter',
#    'mit',
#    'ihm',
#    '.'],
#   ['Berlin',
#    'treibt',
#    'mit',
#    'aller',
#    'Macht',
#    'das',
#    'Projekt',
#    'der',
#    'russisch-deutschen',
#    'Gaspipeline',
#    'Nord',
#    'Stream',
#    '2',
#    'durch',
#    'die',
#    'Ostsee',
#    'voran',
#    ',',
#    'obwohl',
#    'die',
#    'direkt',
#    'betroffenen',
#    '<eSOURCE>',
#    'Anrainer',
#    '</eSOURCE>',
#    'wie',
#    'die',
#    'baltischen',
#    'Staaten',
#    'und',
#    'Polen',
#    ',',
#    'aber',
#    'auch',
#    'Frankreich',
#    'und',
#    'die',
#    'USA',
#    'dagegen',
#    '<ePEXP>',
#    'opponieren',
#    '</ePEXP>',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Als',
#    'Star',
#    'wurde',
#    '<eSOURCE>',
#    'Manson',
#    '</eSOURCE>',
#    'mehrfach',
#    '<ePEXP>',
#    'verklagt',
#    '</ePEXP>',
#    ',',
#    'von',
#    'früheren',
#    'Bandmitgliedern',
#    'und',
#    'Hotelbesitzern',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Vor',
#    'allem',
#    'der',
#    'Umstand',
#    ',',
#    'dass',
#    'der',
#    '<eSOURCE>',
#    'Vertreter',
#    '</eSOURCE>',
#    'der',
#    'Volksrepublik',
#    'China',
#    ',',
#    'Botschafter',
#    'Zhang',
#    'Jun',
#    ',',
#    'ebenfalls',
#    'klare',
#    'Worte',
#    '<ePEXP>',
#    'fand',
#    '</ePEXP>',
#    ',',
#    'ist',
#    'bemerkenswert',
#    ':',
#    '«',
#    'Es',
#    'ist',
#    'nun',
#    'Zeit',
#    'für',
#    'eine',
#    'Entspannung',
#    ',',
#    'für',
#    'diplomatische',
#    'Aktivitäten',
#    'und',
#    'für',
#    'einen',
#    'Dialog',
#    '»',
#    ',',
#    'wird',
#    'Zhang',
#    'Jun',
#    'zitiert',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Zweitens',
#    'konnten',
#    '<eSOURCE>',
#    'Firmen',
#    '</eSOURCE>',
#    'zur',
#    'Sicherung',
#    'ihrer',
#    'Liquidität',
#    '(',
#    'nicht',
#    'ihrer',
#    'Solvenz',
#    ')',
#    'bereits',
#    'günstige',
#    ',',
#    'staatlich',
#    'garantierte',
#    'Covid-19-Kredite',
#    'aufnehmen',
#    ',',
#    'die',
#    'bei',
#    'Bedarf',
#    'neu',
#    'aufgelegt',
#    'werden',
#    'könnten',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['<eSOURCE>',
#    'Michelle',
#    '</eSOURCE>',
#    'Hunziker',
#    'hat',
#    'sich',
#    'für',
#    'einen',
#    'rassistischen',
#    '<eTARGET>',
#    'Auftritt',
#    '</eTARGET>',
#    'in',
#    'einer',
#    'italienischen',
#    'Satireshow',
#    '<ePEXP>',
#    'entschuldigt',
#    '</ePEXP>',
#    '.'],
#   ['Insgesamt',
#    'stellen',
#    'sich',
#    'am',
#    'Sonntag',
#    ',',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    'März',
#    ',',
#    '1054',
#    '<eSOURCE>',
#    'Zürcherinnen',
#    '</eSOURCE>',
#    'und',
#    'Zürcher',
#    'zur',
#    'Wahl',
#    'in',
#    'den',
#    'Gemeinderat',
#    '.'],
#   ['Deshalb',
#    '<ePEXP>',
#    'überfällt',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Sali',
#    '</eSOURCE>',
#    'Hafez',
#    'nun',
#    'eine',
#    '<eTARGET>',
#    'Bank',
#    '</eTARGET>',
#    '.'],
#   ['Zwei',
#    '<eSOURCE>',
#    'Mittzwanziger',
#    '</eSOURCE>',
#    'stellen',
#    'sich',
#    'vorne',
#    'an',
#    'den',
#    'Bühnenrand',
#    'und',
#    'machen',
#    'genau',
#    'das',
#    ',',
#    'was',
#    'ihr',
#    '«',
#    'Medium',
#    '»',
#    'nicht',
#    'wollte',
#    ':',
#    'Sie',
#    'zeigen',
#    'Schritte',
#    'vor',
#    'und',
#    'versuchen',
#    'die',
#    'Zuschauer',
#    'zu',
#    'animieren',
#    ',',
#    'ihnen',
#    'nachzutanzen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Spätere',
#    '<eSOURCE>',
#    'Sultane',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'lösten',
#    '</ePEXP>',
#    'dieses',
#    '<eTARGET>',
#    'Problem',
#    '</eTARGET>',
#    ',',
#    'indem',
#    'sie',
#    'in',
#    'vielen',
#    'Tavernen',
#    'einen',
#    'Mitarbeiter',
#    'des',
#    'Geheimdiensts',
#    'postierten',
#    '.'],
#   ['Und',
#    'es',
#    'ist',
#    'auch',
#    'klar',
#    ',',
#    'dass',
#    'eine',
#    '<eSOURCE>',
#    'Neubaustrecke',
#    '</eSOURCE>',
#    'zwischen',
#    'Lausanne',
#    'und',
#    'Genf',
#    'viele',
#    '<eTARGET>',
#    'Probleme',
#    '</eTARGET>',
#    '<ePEXP>',
#    'lösen',
#    '</ePEXP>',
#    'würde',
#    '.'],
#   ['Die',
#    'dann',
#    'aber',
#    'nach',
#    'wenigen',
#    'Monaten',
#    'resigniert',
#    'die',
#    '<eTARGET>',
#    'Kündigung',
#    '</eTARGET>',
#    '<ePEXP>',
#    'eingereicht',
#    '</ePEXP>',
#    'hätten',
#    '<eSOURCE>',
#    '.',
#    '</eSOURCE>'],
#   ['Schliesslich',
#    'hat',
#    'das',
#    '<eSOURCE>',
#    'Parlament',
#    '</eSOURCE>',
#    'erstmals',
#    'eine',
#    '<eTARGET>',
#    'Spezialkommission',
#    '</eTARGET>',
#    '<ePEXP>',
#    'eingesetzt',
#    '</ePEXP>',
#    ',',
#    'die',
#    'sich',
#    'nur',
#    'mit',
#    'dem',
#    'Flugplatz',
#    'Dübendorf',
#    'befasst',
#    '.'],
#   ['Jüngst',
#    'verdeutlichte',
#    '<eSOURCE>',
#    'Scania',
#    '</eSOURCE>',
#    'seine',
#    '<eTARGET>',
#    'Abkehr',
#    '</eTARGET>',
#    'vom',
#    'derzeitigen',
#    'Wasserstoff-Hype',
#    'und',
#    'gab',
#    'Gründe',
#    'für',
#    'die',
#    'Strategieverschiebung',
#    'an',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>'],
#   ['<eSOURCE>',
#    'Freiwillige',
#    '</eSOURCE>',
#    'arbeit',
#    'findet',
#    'Zulauf',
#    ',',
#    'wo',
#    'Freiwillige',
#    'ihre',
#    'eigenen',
#    '<eTARGET>',
#    'Ideen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'einbringen',
#    '</ePEXP>',
#    'und',
#    'selbst',
#    'gestaltend',
#    'aktiv',
#    'werden',
#    'können',
#    '–',
#    'also',
#    'nicht',
#    'mehr',
#    'zwingend',
#    'in',
#    'organisatorischen',
#    'Struktur',
#    'von',
#    'Nonprofitorganisationen',
#    '.'],
#   ['Qiaos',
#    'schwedischer',
#    '<eSOURCE>',
#    'Verteidiger',
#    '</eSOURCE>',
#    ',',
#    'Henrik',
#    'Olsson',
#    'Lilja',
#    ',',
#    '<ePEXP>',
#    'schloss',
#    '</ePEXP>',
#    'jedoch',
#    'einen',
#    'fairen',
#    '<eTARGET>',
#    'Prozess',
#    '</eTARGET>',
#    'a',
#    'priori',
#    'aus',
#    ',',
#    'weil',
#    'sein',
#    'Mandant',
#    'im',
#    'chinesischen',
#    'Fernsehen',
#    'bereits',
#    'vorverurteilt',
#    'worden',
#    'sei',
#    '.'],
#   ['Dieser',
#    '<eSOURCE>',
#    'Fund',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'löste',
#    '</ePEXP>',
#    'einen',
#    'längeren',
#    '<eTARGET>',
#    'Austausch',
#    '</eTARGET>',
#    'zwischen',
#    'der',
#    'Bundesregierung',
#    'und',
#    'Vertretern',
#    'des',
#    'ehemaligen',
#    'Präsidenten',
#    'aus',
#    '.'],
#   ['Auch',
#    'die',
#    '<eSOURCE>',
#    'Ärztekammer',
#    '</eSOURCE>',
#    ',',
#    'das',
#    'Parlament',
#    'der',
#    'Schweizer',
#    'Ärzteschaft',
#    ',',
#    'hat',
#    'es',
#    'kürzlich',
#    'abgelehnt',
#    ',',
#    'liberalisierte',
#    'Richtlinien',
#    'zur',
#    'Suizidhilfe',
#    'in',
#    'ihre',
#    'Standesordnung',
#    'aufzunehmen',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Im',
#    'Jahr',
#    '2010',
#    '<ePEXP>',
#    'gewann',
#    '</ePEXP>',
#    '<eSOURCE>',
#    'Bridges',
#    '</eSOURCE>',
#    'einen',
#    'Oscar',
#    'als',
#    'bester',
#    'Hauptdarsteller',
#    'für',
#    '«',
#    '<eTARGET>',
#    'Crazy',
#    '</eTARGET>',
#    'Heart',
#    '»',
#    '.'],
#   ['<eSOURCE>',
#    'Gottstein',
#    '</eSOURCE>',
#    'musste',
#    'sich',
#    'später',
#    'für',
#    'den',
#    '<eTARGET>',
#    'Wutausbruch',
#    '</eTARGET>',
#    '<ePEXP>',
#    'entschuldigen',
#    '</ePEXP>',
#    '.'],
#   ['Von',
#    '1932',
#    'bis',
#    '1934',
#    'gings',
#    'plötzlich',
#    'in',
#    'die',
#    'entgegengesetzte',
#    'Richtung',
#    ',',
#    'da',
#    'machte',
#    'die',
#    '<eSOURCE>',
#    'Raubkatze',
#    '</eSOURCE>',
#    'immer',
#    'angsteinflössendere',
#    'Fratzen',
#    ',',
#    'gab',
#    'immer',
#    'noch',
#    'wildere',
#    'Geräusche',
#    'von',
#    'sich',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '.',
#    'was',
#    'dann',
#    '1935',
#    'ironisch',
#    'gebrochen',
#    'wurde',
#    ',',
#    'indem',
#    'man',
#    'Groucho',
#    ',',
#    'Chico',
#    'und',
#    'Harpo',
#    'Marx',
#    'den',
#    'Löwen',
#    'nachahmen',
#    'liess',
#    '(',
#    'wobei',
#    'Harpo',
#    'dafür',
#    'eine',
#    'Hupe',
#    'benutzte',
#    ')',
#    '.'],
#   ['Spieler',
#    'wurden',
#    'unlängst',
#    'getauscht',
#    ',',
#    'ein',
#    'zusätzlicher',
#    'Ausländer',
#    'eben',
#    'erst',
#    'verpflichtet',
#    ',',
#    'Etienne',
#    'Froidevaux',
#    ',',
#    'dem',
#    'ehemaligen',
#    'Captain',
#    ',',
#    'wurde',
#    'beschieden',
#    ',',
#    'er',
#    'könne',
#    'sich',
#    'einen',
#    'neuen',
#    'Arbeitgeber',
#    'suchen',
#    '<eSOURCE>',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>',
#    '</eSOURCE>'],
#   ['Viele',
#    '<eSOURCE>',
#    'Arbeiter',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'fürchten',
#    '</ePEXP>',
#    'sich',
#    'vor',
#    '<eTARGET>',
#    'Kürzungen',
#    '</eTARGET>',
#    'und',
#    'einer',
#    'Privatisierung',
#    '.'],
#   ['Diesen',
#    '<eTARGET>',
#    'Anhängern',
#    '</eTARGET>',
#    'eines',
#    'harten',
#    'Brexit',
#    '<ePEXP>',
#    'missfällt',
#    '</ePEXP>',
#    'vor',
#    'allem',
#    'der',
#    '<eSOURCE>',
#    'Backstop',
#    '</eSOURCE>',
#    'im',
#    'EU-Austrittsvertrag',
#    '.'],
#   ['Sanktionen',
#    'gegen',
#    'Russen',
#    'Die',
#    '<eSOURCE>',
#    'Kantone',
#    '</eSOURCE>',
#    'haben',
#    'sich',
#    'bei',
#    'Wirtschaftsminister',
#    'Guy',
#    'Parmelin',
#    '<ePEXP>',
#    'beschwert',
#    '</ePEXP>',
#    ',',
#    'sie',
#    'seien',
#    'nicht',
#    'gut',
#    'genug',
#    'darüber',
#    'informiert',
#    'worden',
#    ',',
#    'welche',
#    'Rolle',
#    'sie',
#    'bei',
#    'den',
#    'Sanktionen',
#    'zu',
#    'spielen',
#    'haben',
#    '<eTARGET>',
#    '.',
#    '</eTARGET>'],
#   ['Soll',
#    'der',
#    '<eSOURCE>',
#    'Arbeiter',
#    '</eSOURCE>',
#    'die',
#    'Weiche',
#    'so',
#    'stellen',
#    ',',
#    'dass',
#    'fünf',
#    'Menschen',
#    'sterben',
#    ',',
#    'oder',
#    'so',
#    ',',
#    'dass',
#    'einer',
#    'stirbt',
#    '?',
#    '<eTARGET>',
#    '<ePEXP>',
#    '.',
#    '</ePEXP>',
#    '</eTARGET>'],
#   ['Aber',
#    'dann',
#    'kam',
#    'uns',
#    'in',
#    'den',
#    'Sinn',
#    ',',
#    'dass',
#    'in',
#    'den',
#    'letzten',
#    'Monaten',
#    'am',
#    'Morgen',
#    'häufig',
#    'unsere',
#    '<eSOURCE>',
#    'Zeitung',
#    '</eSOURCE>',
#    'im',
#    '<eTARGET>',
#    'Briefkasten',
#    '</eTARGET>',
#    '<ePEXP>',
#    'fehlte',
#    '</ePEXP>',
#    '.'],
#   ['MARCO',
#    'GARCIA',
#    ',',
#    'BUBIKON',
#    'ZH',
#    'Diesen',
#    '<eTARGET>',
#    'Jugendlichen',
#    '</eTARGET>',
#    '<ePEXP>',
#    'fehlt',
#    '</ePEXP>',
#    'die',
#    'führende',
#    '<eSOURCE>',
#    'Hand',
#    '</eSOURCE>',
#    'der',
#    'Eltern',
#    'und',
#    'des',
#    'Staats',
#    '.'],
#   ['Die',
#    '<eSOURCE>',
#    'Täter',
#    '</eSOURCE>',
#    '<ePEXP>',
#    'überfielen',
#    '</ePEXP>',
#    'dort',
#    'ein',
#    '<eTARGET>',
#    'Pokerturnier',
#    '</eTARGET>',
#    'und',
#    'erbeuteten',
#    'rund',
#    '250',
#    '000',
#    'Euro',
#    '.'],
#   ...]}

# %% [markdown]
# ### Delete this later!
#
# Just for a test on the RE Model performance!

# %%
if VERIFY_RE_MODEL:
    with open(DATASOURCE, "r", encoding="utf-8") as f:
        tokenized_ssa_sents = {"tokens": [], "labels": []}
        for line in f:
            #print(line)
            ds = json.loads(line)
            tokenized_ssa_sents["tokens"].append(ds["tokens"])
            tokenized_ssa_sents["labels"].append(ds["label"])

    gold_polarities = [lbl for lbl in tokenized_ssa_sents["labels"]]

# %% [markdown]
# ### Generate unbreakable tokens based on original dataframe
#
# **Important**: We make sure that every sentence contains a dot in the end that is separated from the last word in the sentence!

# %%
import collections
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import random
import re
import shutil
import torch
import torch.nn as nn

from collections import Counter, defaultdict
from datasets import load_dataset, ClassLabel
from sklearn.metrics import (
    ConfusionMatrixDisplay, confusion_matrix, 
    classification_report, accuracy_score
)
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch.optim import AdamW

from transformers import (
    BertTokenizerFast, BertModel, BertForPreTraining, BertConfig, BertPreTrainedModel,
    DataCollatorWithPadding,
    get_scheduler
)
from transformers.modeling_outputs import SequenceClassifierOutput

# %%
class BertForRelationExtraction(BertPreTrainedModel):
  def __init__(self, config, num_labels):
    super(BertForRelationExtraction, self).__init__(config)
    self.num_labels = num_labels
    # body
    self.bert = BertModel(config)
    # head
    self.dropout = nn.Dropout(config.hidden_dropout_prob)
    #self.layer_norm = nn.LayerNorm(config.hidden_size * 2)
    #self.linear = nn.Linear(config.hidden_size * 2, self.num_labels)
    self.init_weights()
    
    self.layer_norm = nn.LayerNorm(config.hidden_size * 3)
    self.linear = nn.Linear(config.hidden_size * 3, self.num_labels)

  def forward(self, input_ids, token_type_ids, attention_mask,
              span_idxs, labels=None):
    outputs = (
        self.bert(input_ids, token_type_ids=token_type_ids,
                  attention_mask=attention_mask,
                  output_hidden_states=False)
            .last_hidden_state)
            
    sub_maxpool, obj_maxpool, pexp_maxpool = [], [], []
    #sub_maxpool, obj_maxpool = [], []
    for bid in range(outputs.size(0)):
      # span includes entity markers, maxpool across span
      sub_span = torch.max(outputs[bid, span_idxs[bid, 0]:span_idxs[bid, 1]+1, :], 
                           dim=0, keepdim=True).values
      obj_span = torch.max(outputs[bid, span_idxs[bid, 2]:span_idxs[bid, 3]+1, :],
                           dim=0, keepdim=True).values
      pexp_span = torch.max(outputs[bid, span_idxs[bid, 4]:span_idxs[bid, 5]+1, :], dim=0, keepdim=True).values
      sub_maxpool.append(sub_span)
      obj_maxpool.append(obj_span)
      pexp_maxpool.append(pexp_span)

    sub_emb = torch.cat(sub_maxpool, dim=0)
    obj_emb = torch.cat(obj_maxpool, dim=0)
    pexp_emb = torch.cat(pexp_maxpool, dim=0)
    rel_input = torch.cat((sub_emb, obj_emb, pexp_emb), dim=-1)
    #rel_input = torch.cat((sub_emb, obj_emb), dim=-1)

    rel_input = self.layer_norm(rel_input)
    rel_input = self.dropout(rel_input)
    logits = self.linear(rel_input)

    if labels is not None:
      loss_fn = nn.CrossEntropyLoss()
      loss = loss_fn(logits.view(-1, self.num_labels), labels.view(-1))
      return SequenceClassifierOutput(loss, logits)
    else:
      return SequenceClassifierOutput(None, logits)


# config = BertConfig.from_pretrained(BASE_MODEL_NAME)
# model = BertForRelationExtraction.from_pretrained(BASE_MODEL_NAME, 
#                                                   config=config,
#                                                   num_labels=len(valid_relations))
# model.bert.resize_token_embeddings(len(tokenizer.vocab))
# for batch in train_dl:
#   outputs = model(**batch)
#   break
# print("loss:", outputs.loss, "logits.size:", outputs.logits.size())

# %%
tokenizer = BertTokenizerFast.from_pretrained(BASE_MODEL_NAME)

vocab_size_orig = len(tokenizer.vocab)

marker_tokens = []
entity_types = ["eSOURCE", "eTARGET", "ePEXP"]
for entity_type in entity_types:
  marker_tokens.append("<{:s}>".format(entity_type))
  marker_tokens.append("</{:s}>".format(entity_type))

tokenizer.add_tokens(marker_tokens)
vocab_size_new = len(tokenizer.vocab)

print("original vocab size:", vocab_size_orig)
print("new vocab size:", vocab_size_new)

def encode_data(examples):
  tokenized_inputs = tokenizer(examples["tokens"],
                               is_split_into_words=True,
                               truncation=True)
  span_idxs = []
  for input_id in tokenized_inputs.input_ids:
    tokens = tokenizer.convert_ids_to_tokens(input_id)
    try:
        span_idxs.append([
          [idx for idx, token in enumerate(tokens) if token.startswith("<eS")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eS")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("<eT")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eT")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("<eP")][0],
          [idx for idx, token in enumerate(tokens) if token.startswith("</eP")][0],
        ])
    except Exception as e:
        print(f"Encountered error because of: { str(e) }, { str(tokens) }")
        # from IPython.core.debugger import Pdb; Pdb().set_trace()
        # print(f"Tokens of sentence: { str(examples['tokens']) }")

  tokenized_inputs["span_idxs"] = span_idxs
  # tokenized_inputs["labels"] = [label2id[label] for label in examples["label"]]
  return tokenized_inputs

#print(X)
#encoded = encode_data(X)
#encoded.keys()
#print(encoded)
# Out:
# original vocab size: 30000
# new vocab size: 30006

# %%
encoded = encode_data(tokenized_ssa_sents)
# encoded

# %%
from datasets import Dataset
BATCH_SIZE = 4
collate_fn = DataCollatorWithPadding(tokenizer, padding="longest", return_tensors="pt")
test_dl = DataLoader(Dataset.from_dict(encoded),
                      # shuffle=True, 
                      batch_size=BATCH_SIZE, 
                      collate_fn=collate_fn)

# print([x for x in test_dl])

# %%
valid_relations = ["Positive", "Neutral", "Negative"]
valid_relations = sorted(list(valid_relations))

# %%
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_file = os.path.join(MODEL_DIR, "ckpt-{:d}".format(3))

print("=> Loading checkpoint")
# checkpoint = model.from_pretrained(checkpoint_file)
config = BertConfig.from_pretrained(checkpoint_file)
model = BertForRelationExtraction.from_pretrained(checkpoint_file, 
                      config=config,
                      num_labels=len(valid_relations))
# model.load_state_dict(checkpoint["state_dict"])
model.bert.resize_token_embeddings(len(tokenizer.vocab))
model.eval()
model = model.to(device)
# Out:
# => Loading checkpoint

# %%
# confirm the model is not in training
model.training
# Out:
# False

# %%
ytrue, ypred = [], []
with tqdm(test_dl, unit="batch") as tepoch:
    for batch in tepoch:
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
          outputs = model(**batch)
          predictions = torch.argmax(outputs.logits, dim=-1).cpu().numpy()
          #labels = batch["labels"].cpu().numpy()
          #ytrue.extend(labels)
          ypred.extend(predictions)

#print("test accuracy: {:.3f}".format(accuracy_score(ytrue, ypred)))

#print(classification_report(ytrue, ypred, target_names=valid_relations))
# Out:
#   0%|                                                                     | 0/1331 [00:00<?, ?batch/s]You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 100%|██████████████████████████████████████████████████████████| 1331/1331 [06:01<00:00,  3.68batch/s]

# %%
preds_full_label_text = [valid_relations[i] for i in ypred]

# %%
preds_full_label_text
# Out:
# ['Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  ...]

# %%
valid_relations
# Out:
# ['Negative', 'Neutral', 'Positive']

# %% [markdown]
# ### Save the data
#
# Reading in the data so it can be processed. The format is SSA.

# %%
def construct_ssa_dataset(preds, out_data_w_ents):
    new_out_struct = []
    for pred, out_ds in zip(preds, out_data_w_ents):
        od = copy.deepcopy(out_ds)
        od["opinions"][0]["Polarity"] = pred
        new_out_struct.append(od)
    return new_out_struct

out_data_w_entities_and_rel = construct_ssa_dataset(preds_full_label_text, out_data_w_entities)

# %%
out_data_w_entities_and_rel
# Out:
# [{'sent_id': '0',
#   'text': 'Andere Proteste entstanden wegen der seit Jahren miserablen Wirtschaftslage und der allumfassenden Korruption im Land und blieben meist regional .',
#   'opinions': [{'Source': [['Proteste'], ['7:15']],
#     'Target': [[], []],
#     'Polar_expression': [['entstanden'], ['16:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': 'Flavia Schlittler Im Frühling 2015 wurde Nepal von verheerenden Erdbeben heimgesucht .',
#   'opinions': [{'Source': [['Nepal'], ['41:46']],
#     'Target': [['Erdbeben'], ['64:72']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Der Konflikt sorgte innerhalb der CVP , in der man in normalen Zeiten ungern öffentlich streitet , für erheblichen Ärger .',
#   'opinions': [{'Source': [['Konflikt'], ['4:12']],
#     'Target': [['Ärger'], ['115:120']],
#     'Polar_expression': [['sorgte'], ['13:19']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Damals zerstörte ein Feuer das historische Gipfelhotel aus dem Jahr 1893 – ein grosser Verlust .',
#   'opinions': [{'Source': [['Feuer'], ['21:26']],
#     'Target': [['Gipfelhotel'], ['43:54']],
#     'Polar_expression': [['zerstörte'], ['7:16']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': 'Vor zehn Jahren scheiterte ein Freihandelsabkommen mit den USA am Widerstand der Landwirtschaft .',
#   'opinions': [{'Source': [['Freihandelsabkommen'], ['31:50']],
#     'Target': [['Widerstand'], ['66:76']],
#     'Polar_expression': [['scheiterte'], ['16:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'Die Besinnung auf das Einzigartige der eigenen Bestände gab die Richtung vor : Keine andere Bibliothek widmet sich so gezielt und umfassend der Schnittstelle von Religion und Gesellschaft , Glaube und Philosophie , interreligiösem Gespräch , Kunst , Kultur und Themen der Zivilgesellschaft .',
#   'opinions': [{'Source': [['Bibliothek'], ['92:102']],
#     'Target': [['Schnittstelle'], ['144:157']],
#     'Polar_expression': [['widmet'], ['103:109']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Die Regulierungsbehörden sorgen sich über die enormen Summen , die von den Stablecoin-Anbietern eingesammelt wurden und werden , ohne dass das amerikanische Bankensystem involviert ist .',
#   'opinions': [{'Source': [['Regulierungsbehörden'], ['4:24']],
#     'Target': [['Summen'], ['54:60']],
#     'Polar_expression': [['sorgen'], ['25:31']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Der Verteidiger des Beschuldigten , der während der Verhandlung von seinem Aussageverweigerungsrecht Gebrauch machte , plädierte auf Freispruch .',
#   'opinions': [{'Source': [['Verteidiger'], ['4:15']],
#     'Target': [['Freispruch'], ['133:143']],
#     'Polar_expression': [['plädierte'], ['119:128']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Ein Streichelzoo sorgt für Abwechslung bei den Kleinsten .',
#   'opinions': [{'Source': [['Streichelzoo'], ['4:16']],
#     'Target': [['Kleinsten'], ['47:56']],
#     'Polar_expression': [['sorgt'], ['17:22']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Zweimal stimmten die Freisinnigen geschlossen dagegen , abgesehen von einer Handvoll Enthaltungen .',
#   'opinions': [{'Source': [['Freisinnigen'], ['21:33']],
#     'Target': [[], []],
#     'Polar_expression': [['stimmten'], ['8:16']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': 'Die grösste Demokratie der Welt muss aber auch die lauten und unangenehmen Stimmen aushalten können .',
#   'opinions': [{'Source': [['Demokratie'], ['12:22']],
#     'Target': [['Stimmen'], ['75:82']],
#     'Polar_expression': [['aushalten'], ['83:92']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': 'Eine ähnliche Frage stellte sich bei Alexis Sánchez , dem wirbligen chilenischen Stürmer , den man mit allen Mitteln der Überredungskunst Arsenal abgeworben hatte .',
#   'opinions': [{'Source': [['Frage'], ['14:19']],
#     'Target': [['Alexis'], ['37:43']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Die Gesichtszüge sind unter der Maske nicht zu erkennen , die Gestik verrät aber den Gemütszustand : Jeannine Gmelin freut sich über die Bronzemedaille und schwenkt die Schweizer Fahne .',
#   'opinions': [{'Source': [['Jeannine'], ['101:109']],
#     'Target': [['Bronzemedaille'], ['137:151']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Immer auch auf die Gefahr hin , dass Kritiker uns an den Öko-Pranger stellen und uns die liberale Gesinnung absprechen .',
#   'opinions': [{'Source': [['Kritiker'], ['37:45']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Die Nationalrätin nennt ein Beispiel : Wenn sich der Grundstückpreis einer Liegenschaft bei einer Neubewertung verdoppelt , müssen sich auch die Mieten verdoppeln .',
#   'opinions': [{'Source': [['Grundstückpreis'], ['53:68']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': 'Madonna entschuldigt sich bei ihren Anhängern : « Ich muss mich erholen » , erklärt sie .',
#   'opinions': [{'Source': [['Madonna'], ['0:7']],
#     'Target': [['Anhängern'], ['36:45']],
#     'Polar_expression': [['entschuldigt'], ['8:20']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Das bis heute aufgrund seiner repräsentativen Bürger- und Gasthäuser städtisch wirkende Dorf Einsiedeln wurde von Hugo Kopp noch vor dem in den 1960er Jahren einsetzenden Wachstumsschub so aus dem Flugzeug aufgenommen , dass es präzise von seinen beiden wichtigsten Baukomplexen gefasst wird .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Sofort stellte sich der mächtige Generalsekretär Toshihiro Nikai ( 81 ) auf Sugas Seite .',
#   'opinions': [{'Source': [['Generalsekretär'], ['33:48']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Eine Millionärsgattin verliebte sich vor 26 Jahren in einen Polizisten der Kantonspolizei St. Gallen .',
#   'opinions': [{'Source': [['Millionärsgattin'], ['5:21']],
#     'Target': [['Polizisten'], ['60:70']],
#     'Polar_expression': [['verliebte'], ['22:31']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': 'Nach dem Match entschuldigte sich Shapovalov für seine vorwurfsvolle Formulierung , er hielt aber an seiner grundsätzlichen Kritik fest .',
#   'opinions': [{'Source': [['Shapovalov'], ['34:44']],
#     'Target': [['Formulierung'], ['69:81']],
#     'Polar_expression': [['entschuldigte'], ['15:28']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Doch auch in diesem Fall stellen sich heikle rechtliche und vollzugstechnische Herausforderungen .',
#   'opinions': [{'Source': [['Herausforderungen'], ['79:96']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Israel hatte dagegen mit einem Kampfhelikopter eine Drohne abgeschossen , die gemäss Israel von Revolutionsgardisten in Syrien gestartet worden war .',
#   'opinions': [{'Source': [['Israel'], ['0:6']],
#     'Target': [['Drohne'], ['52:58']],
#     'Polar_expression': [['abgeschossen'], ['59:71']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Frankfurts Daichi Kamada trifft zweimal und schiesst Arsenal ab .',
#   'opinions': [{'Source': [['Daichi'], ['11:17']],
#     'Target': [['Arsenal'], ['53:60']],
#     'Polar_expression': [['schiesst'], ['44:52']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Das unterste Segment leidet derweil unter der Konkurrenz der Smartwatches .',
#   'opinions': [{'Source': [['Segment'], ['13:20']],
#     'Target': [['Konkurrenz'], ['46:56']],
#     'Polar_expression': [['leidet'], ['21:27']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'In Biel stellt sich die Frage nicht .',
#   'opinions': [{'Source': [['Frage'], ['24:29']],
#     'Target': [['Biel'], ['3:7']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'Weber achtet auf gute Unternehmensführung .',
#   'opinions': [{'Source': [['Weber'], ['0:5']],
#     'Target': [['Unternehmensführung'], ['22:41']],
#     'Polar_expression': [['achtet'], ['6:12']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': 'Als im Juli das viel zu langsam gestartete Impfprogramm endlich Tempo aufnahm und sie einen Termin bekam , dokumentierte Samuels ihre erste Impfung auf Facebook .',
#   'opinions': [{'Source': [['Samuels'], ['121:128']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnahm'], ['70:77']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Theater Christoph Marthaler hat für ein Bühnenstück Zitate von Christa Rigozzi zum Thema Apéro benutzt , ohne sie zu deklarieren .',
#   'opinions': [{'Source': [['Theater'], ['0:7']],
#     'Target': [[], []],
#     'Polar_expression': [['benutzt'], ['95:102']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Juan Carbuccia hat mit seinem Handy eine Stunde vor Eintreffen des Besuchers ein Video aufgenommen .',
#   'opinions': [{'Source': [['Juan'], ['0:4']],
#     'Target': [[], []],
#     'Polar_expression': [['aufgenommen'], ['87:98']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'In ersten Reaktionen plädierten am Sonntag allerdings auch die Gegner von « 7 statt 9 » für Effizienzverbesserungen in der Stadtverwaltung .',
#   'opinions': [{'Source': [['Gegner'], ['63:69']],
#     'Target': [['Effizienzverbesserungen'], ['92:115']],
#     'Polar_expression': [['plädierten'], ['21:31']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Schulden seien « gratis » , also dürfe der Staat bedenkenlos Geld für Hilfen und Investitionen aufnehmen .',
#   'opinions': [{'Source': [['Staat'], ['43:48']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': '( red ) Corona Japans Ministerpräsident Shinzo Abe hat zinslose Kredite für Firmen angekündigt , die von der Coronavirus-Epidemie betroffen sind .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['22:39']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['83:94']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'Die Frau habe gezielt auf den am Boden liegenden , wehrlosen Mann geschossen .',
#   'opinions': [{'Source': [['Frau'], ['4:8']],
#     'Target': [['Mann'], ['61:65']],
#     'Polar_expression': [['geschossen'], ['66:76']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Journalisten schliesslich überschätzen die Rhetorik notorisch .',
#   'opinions': [{'Source': [['Journalisten'], ['0:12']],
#     'Target': [['Rhetorik'], ['43:51']],
#     'Polar_expression': [['überschätzen'], ['26:38']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Nun , im zweiten Teil , widmet sich das Gericht den sieben Privatklägern und den Zeugen .',
#   'opinions': [{'Source': [['Gericht'], ['40:47']],
#     'Target': [['Privatklägern'], ['59:72']],
#     'Polar_expression': [['widmet'], ['24:30']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Und schliesslich stellen sich bei Negativzinsen ungewöhnliche Rechtsfragen .',
#   'opinions': [{'Source': [['Rechtsfragen'], ['62:74']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Mirko Salvi , der Mann aus Yverdon , stellt sich seit letztem Donnerstag einer neuen Herausforderung .',
#   'opinions': [{'Source': [['Mirko'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'Obergösgen SO – Am Donnerstagabend überfiel ein 49-jähriger Italiener mit einem gezückten Messer ein Detailhandelsgeschäft und erbeutete mehrere Hundert Franken .',
#   'opinions': [{'Source': [['Italiener'], ['60:69']],
#     'Target': [['Detailhandelsgeschäft'], ['101:122']],
#     'Polar_expression': [['überfiel'], ['35:43']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Thomas Bach , der Chef des Internationalen Olympischen Komitees , hat sich bei einem Mann ganz besonders für die Siege bei den Olympischen Spielen zu bedanken : bei Japans Ministerpräsidenten Yoshihide Suga .',
#   'opinions': [{'Source': [['Thomas'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['bedanken'], ['150:158']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Insgesamt hat die iranische Regierung in der vergangenen Woche rund 85 000 Gefangene vorübergehend aus den Gefängnissen entlassen .',
#   'opinions': [{'Source': [['Regierung'], ['28:37']],
#     'Target': [[], []],
#     'Polar_expression': [['entlassen'], ['120:129']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Die Zürcher Volkswirtschaftsdirektorin sorgt sich aber nicht in erster Linie um die Touristen , sondern um die Zürcher Geschäfte , denen wegen des Sonntagsverkaufsverbots Einnahmen entgehen .',
#   'opinions': [{'Source': [['Volkswirtschaftsdirektorin'], ['12:38']],
#     'Target': [['Touristen'], ['84:93']],
#     'Polar_expression': [['sorgt'], ['39:44']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Damit diskreditiert Fasel den ganzen Eishockey-Sport .',
#   'opinions': [{'Source': [['Fasel'], ['20:25']],
#     'Target': [['Eishockey'], ['37:46']],
#     'Polar_expression': [['diskreditiert'], ['6:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'Nach dem Treffen am vergangenen Dienstag wurden die vier Menschenrechtler zunächst von der regimetreuen Presse als « Verräter » oder « ausländische Agenten » beschimpft .',
#   'opinions': [{'Source': [['Menschenrechtler'], ['57:73']],
#     'Target': [[], []],
#     'Polar_expression': [['beschimpft'], ['158:168']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Der pakistanische Ministerpräsident Imran Khan hatte die Freilassung am Donnerstag in einer Rede vor dem Parlament in Islamabad angekündigt .',
#   'opinions': [{'Source': [['Ministerpräsident'], ['18:35']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['128:139']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'Stephanie Erne ... spielt ebenfalls in Luzern und hat eine 80-Prozent-Stelle als Spezialistin für Bewegungs- und Gesundheitsförderung – daneben gilt ihr Engagement dem FI9-Verein .',
#   'opinions': [{'Source': [['Engagement'], ['153:163']],
#     'Target': [['Verein'], ['172:178']],
#     'Polar_expression': [['gilt'], ['144:148']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Der Kanton hat eine Untersuchung angekündigt .',
#   'opinions': [{'Source': [['Kanton'], ['4:10']],
#     'Target': [['Untersuchung'], ['20:32']],
#     'Polar_expression': [['angekündigt'], ['33:44']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': 'Zwar ist im Gesetzestext nirgendwo von Impfungen die Rede , und der Bund hat die Verdächtigungen immer zurückgewiesen .',
#   'opinions': [{'Source': [['Bund'], ['68:72']],
#     'Target': [['Verdächtigungen'], ['81:96']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Gemäss Informationen der Tessiner Kantonspolizei stürzte die 30-Jährige mehrere Meter in die Tiefe .',
#   'opinions': [{'Source': [['Jährige'], ['64:71']],
#     'Target': [[], []],
#     'Polar_expression': [['stürzte'], ['49:56']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'Polemik Am 6. Juni will die Schweizer Kulturszene den Neustart wagen .',
#   'opinions': [{'Source': [['Kulturszene'], ['38:49']],
#     'Target': [['Neustart'], ['54:62']],
#     'Polar_expression': [['wagen'], ['63:68']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': 'Eine unabhängige Aufsichtskommission ; schärfere Datenschutzbestimmung ; die Möglichkeit für den Bund , sich an Anbietern eines digitalen Passes zu beteiligen – immer zeigte sich dasselbe Muster : Eine klare bürgerliche Mehrheit stellte sich gegen die Empfehlung Keller-Sutters , die zusammen mit den Linken die Variante des Ständerats unterstützte .',
#   'opinions': [{'Source': [['Mehrheit'], ['220:228']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Bei den Männern triumphiert Rudy von Berg ( USA ) in 3 : 42 : 17 ähnlich überlegen wie Ryf .',
#   'opinions': [{'Source': [['Rudy'], ['28:32']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': 'Die Walliser jubeln im Cornaredo nach den beiden Lugano-Schockern .',
#   'opinions': [{'Source': [['Walliser'], ['4:12']],
#     'Target': [['Lugano'], ['49:55']],
#     'Polar_expression': [['jubeln'], ['13:19']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Die grösste Partei im Parlament , Ennahda , warf dem Präsidenten einen « Putsch gegen die Revolution und die Verfassung » vor – eine Referenz auf den Arabischen Frühling 2011 , als die Tunesier den langjährigen Diktator Zine al-Abedine Ben Ali gestürzt hatten .',
#   'opinions': [{'Source': [['Tunesier'], ['185:193']],
#     'Target': [['Präsidenten'], ['53:64']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'Er sprach von der Enttäuschung über die Niederlage , YB habe zwei Unaufmerksamkeiten ausgenutzt , aber Klose fand , dass es der FCB « nicht so schlecht gemacht und gut verteidigt » habe .',
#   'opinions': [{'Source': [['YB'], ['53:55']],
#     'Target': [['Unaufmerksamkeiten'], ['66:84']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': '« Interventionen beim Umweltminister führten lediglich zu netten Floskeln . » Man gewinnt den Eindruck , selbst von Helfern versuche die Regierung möglichst viel Geld abzupressen .',
#   'opinions': [{'Source': [['Regierung'], ['137:146']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Der Betrieb musste , abgesehen vom Gastrobereich , ohnehin aufrechterhalten bleiben .',
#   'opinions': [{'Source': [['Betrieb'], ['4:11']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Obschon ihre Schönheit wie eh und je betört : In den riesigen Sälen der stilvollen alten Hotelpaläste und stuckübersäten Villen stellt sich statt des früheren Schwelgens immer öfter die bange Frage ein , wer für die Bewahrung all der historischen Pracht aufkommen kann .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Bewahrung'], ['216:225']],
#     'Polar_expression': [['aufkommen'], ['254:263']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Thelesklaf nennt ein Beispiel : Eine Bank dürfe einen Verdacht zwar an die MROS weiterleiten , nicht aber an eine andere Bank .',
#   'opinions': [{'Source': [['Bank'], ['37:41']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Daraufhin beschwerte sich die Frau beim Presserat .',
#   'opinions': [{'Source': [['Frau'], ['30:34']],
#     'Target': [['Presserat'], ['40:49']],
#     'Polar_expression': [['beschwerte'], ['10:20']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Thomas Fuster · Das World Economic Forum ( WEF ) sorgt sich um Davos .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Davos'], ['63:68']],
#     'Polar_expression': [['sorgt'], ['49:54']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Anscheinend will oder kann der Casino-Boss das Thema doch nicht ganz totschweigen .',
#   'opinions': [{'Source': [['Boss'], ['38:42']],
#     'Target': [['Thema'], ['47:52']],
#     'Polar_expression': [['totschweigen'], ['69:81']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'Schliesslich hat Netflix für dieses Jahr bereits achtzig Eigenproduktionen angekündigt , die meisten davon werden in dem mit Amerika und Asien vergleichsweise weniger starken Markt Europa nicht die Lichtspielhäuser erreichen .',
#   'opinions': [{'Source': [['Netflix'], ['17:24']],
#     'Target': [['Lichtspielhäuser'], ['198:214']],
#     'Polar_expression': [['erreichen'], ['215:224']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Mit ihrem Positionsbezug stellt sich die Bundesrätin auch gegen eine Aufforderung von Donald Trump .',
#   'opinions': [{'Source': [['Bundesrätin'], ['41:52']],
#     'Target': [['Aufforderung'], ['69:81']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'Aber in einer Zeit , in der Medien unter dem Druck stehen , Nachrichten möglichst rasch online zu veröffentlichen , und keine Zeit für tiefgreifendere Analysen bleibt , führt eine schönfärberische Kommunikationspolitik zu Verzerrungen – in der Öffentlichkeit entsteht ein Bild , das die Realität nur ungenau spiegelt .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['entsteht'], ['259:267']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'Und für einmal übertreibt der Präsident mit dieser Aussage nicht .',
#   'opinions': [{'Source': [['Präsident'], ['30:39']],
#     'Target': [['Aussage'], ['51:58']],
#     'Polar_expression': [['übertreibt'], ['15:25']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'Gemäss ersten Erkenntnissen brach auch der Funkkontakt ab .',
#   'opinions': [{'Source': [['Funkkontakt'], ['43:54']],
#     'Target': [[], []],
#     'Polar_expression': [['brach'], ['28:33']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Auf der anderen Seite freut sich Federer bei der ganzen Routine im Tour-Kalender auf ein neues Kapitel : « Key Biscayne war schön , lässig , hatte Geschichte .',
#   'opinions': [{'Source': [['Federer'], ['33:40']],
#     'Target': [['Kapitel'], ['95:102']],
#     'Polar_expression': [['freut'], ['22:27']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Auf Dauer könne Russland die internationale Isolation aber nicht durchhalten .',
#   'opinions': [{'Source': [['Russland'], ['16:24']],
#     'Target': [['Isolation'], ['44:53']],
#     'Polar_expression': [['durchhalten'], ['65:76']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': 'Einsichtig : FCB-Youngster Sebastiano Esposito hat sich vor versammelter Mannschaft für sein Verhalten entschuldigt .',
#   'opinions': [{'Source': [['Youngster'], ['17:26']],
#     'Target': [['Verhalten'], ['93:102']],
#     'Polar_expression': [['entschuldigt'], ['103:115']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Dass sich Cesla Amarelle und Silvia Steiner für den Austausch einsetzen , hat auch persönliche Gründe .',
#   'opinions': [{'Source': [['Cesla'], ['10:15']],
#     'Target': [['Austausch'], ['52:61']],
#     'Polar_expression': [['einsetzen'], ['62:71']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'Auch weil London Steuerprivilegien abschafft , zieht es vermögende Russen in die Schweiz .',
#   'opinions': [{'Source': [['London'], ['10:16']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': 'In der vergangenen Woche hatten Exxon-Mobil und Chevron deutliche Produktionssteigerungen im texanischen Permian Basin angekündigt .',
#   'opinions': [{'Source': [['Mobil'], ['38:43']],
#     'Target': [['Produktionssteigerungen'], ['66:89']],
#     'Polar_expression': [['angekündigt'], ['119:130']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Die vom Bankier Claudio Segré gegründete Stiftung widmet sich dem Schutz der Biodiversität .',
#   'opinions': [{'Source': [['Stiftung'], ['41:49']],
#     'Target': [['Schutz'], ['66:72']],
#     'Polar_expression': [['widmet'], ['50:56']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Der grosse Handelsbilanzüberschuss der Schweiz bei Medikamenten missfällt der Administration von Donald Trump .',
#   'opinions': [{'Source': [['Handelsbilanzüberschuss'], ['11:34']],
#     'Target': [['Administration'], ['78:92']],
#     'Polar_expression': [['missfällt'], ['64:73']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'Langsam aber stellte sich im Land der Durchhalteparolen eine neue Lust am Essen – und an dessen Zubereitung – ein : ein Prozess , der in den fünfziger Jahren begann und in den Achtzigern so richtig in Schwung kam .',
#   'opinions': [{'Source': [['Lust'], ['66:70']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'Bisher hatten sich die Vereinigten Staaten mit Verkäufen von Angriffswaffen zurückgehalten , um China nicht zu reizen .',
#   'opinions': [{'Source': [['Vereinigten Staaten'], ['23:42']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'Chefärzte nutzen ihre Position aus , um sich zu bereichern .',
#   'opinions': [{'Source': [['Chefärzte'], ['0:9']],
#     'Target': [['Position'], ['22:30']],
#     'Polar_expression': [['nutzen'], ['10:16']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Damit verfügen die Konservativen seit anderthalb Jahren über eine klarere Mehrheit im neunköpfigen Gremium , weil Kavanaugh den moderaten Konservativen Anthony Kennedy ersetzte , der als Zünglein an der Waage oft auch den progressiven Richtern zu einer Mehrheit verholfen hatte .',
#   'opinions': [{'Source': [['Kavanaugh'], ['114:123']],
#     'Target': [[], []],
#     'Polar_expression': [['ersetzte'], ['168:176']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Diesem Trend scheint sich jetzt der Verlegerverband zusehends anzupassen , gemäss dem Motto : Wenn schon gefördert wird , dann wollen wir auch teilhaben .',
#   'opinions': [{'Source': [['Verlegerverband'], ['36:51']],
#     'Target': [['Trend'], ['7:12']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': '« Wir haben ihn mithilfe eines Defibrillator-Einsatzes zurückbekommen » , sagte Boesen , « und das relativ schnell . » Offenbar genügte eine einzige Defibrillation , um den Sportler vor dem Tod zu bewahren .',
#   'opinions': [{'Source': [['Defibrillation'], ['149:163']],
#     'Target': [['Tod'], ['190:193']],
#     'Polar_expression': [['bewahren'], ['197:205']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'Nur dem Vater fehlte immer noch das begehrte rote Büchlein .',
#   'opinions': [{'Source': [['Büchlein'], ['50:58']],
#     'Target': [['Vater'], ['8:13']],
#     'Polar_expression': [['fehlte'], ['14:20']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Mehrere Regionalspitäler haben die monetären Fehlanreize bereits aus ihren Vergütungssystemen entfernt .',
#   'opinions': [{'Source': [['Regionalspitäler'], ['8:24']],
#     'Target': [['Vergütungssystemen'], ['75:93']],
#     'Polar_expression': [['entfernt'], ['94:102']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Der Code wird zu einer Sprachgewalt , deren Grammatik unseren Alltag prägt .',
#   'opinions': [{'Source': [['Code'], ['4:8']],
#     'Target': [['Alltag'], ['62:68']],
#     'Polar_expression': [['prägt'], ['69:74']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'sak . · Zwischen 1998 und 2001 ermordete die weissrussische Spezialeinheit Sobr rund dreissig Menschen .',
#   'opinions': [{'Source': [['Spezialeinheit'], ['60:74']],
#     'Target': [['Menschen'], ['94:102']],
#     'Polar_expression': [['ermordete'], ['31:40']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': '100000 zusätzliche Menschen soll die Stadt Zürich in den nächsten gut zwanzig Jahren aufnehmen .',
#   'opinions': [{'Source': [['Stadt'], ['37:42']],
#     'Target': [[], []],
#     'Polar_expression': [['aufnehmen'], ['85:94']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Damit ist La Scintilla das einzige Originalklang-Ensemble , dessen Mitglieder sich nicht ausschliesslich der historisch informierten Musizierpraxis widmen , sondern auch im « normalen » Opernbetrieb mitmachen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Musizierpraxis'], ['133:147']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Für ein Ja plädierte in Bern dann allerdings einzig die an der Universität Zürich lehrende Politologin Elham Manea .',
#   'opinions': [{'Source': [['Politologin'], ['91:102']],
#     'Target': [['Ja'], ['8:10']],
#     'Polar_expression': [['plädierte'], ['11:20']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Der Aktienkurs schoss bis Mitte Juni auf mehr als 400 Pence .',
#   'opinions': [{'Source': [['Aktienkurs'], ['4:14']],
#     'Target': [['Pence'], ['54:59']],
#     'Polar_expression': [['schoss'], ['15:21']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Eben wurde von der Wohngemeinschaft erwogen , das freie Zimmer einem Flüchtling zu vermieten , da stellt sich Doro , die Pragmatikerin , in der Mitte der Küche auf und feuert : « Ich hasse arabische Männer !',
#   'opinions': [{'Source': [['Doro'], ['110:114']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': 'Nun , nach seiner Verurteilung und dem Bekanntwerden der Grüsel-Vorwürfe , sorgt sich Fäh um die Zukunft des Sternen : « Ich befürchte , wir verkraften das nicht .',
#   'opinions': [{'Source': [['Fäh'], ['86:89']],
#     'Target': [['Zukunft'], ['97:104']],
#     'Polar_expression': [['sorgt'], ['75:80']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Damit rückt der angekündigte , grund \xad - legende Strategiewechsel in weite Ferne : Ursprünglich wollte der Bundesrat im zweiten Teil der Energiewende die Förderbeiträge sukzessive abschaffen und stattdessen ein Lenkungssystem einführen .',
#   'opinions': [{'Source': [['Bundesrat'], ['107:116']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Alfredo Binda dominierte in den 1920er-Jahren den Giro derart , dass die Organisatoren ihren eigenen Landsmann bestachen .',
#   'opinions': [{'Source': [['Organisatoren'], ['73:86']],
#     'Target': [['Landsmann'], ['101:110']],
#     'Polar_expression': [['bestachen'], ['111:120']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Ich kann Ihnen versichern , dass Roche immer mit hohem Augenmass Medikamentenpreise festlegt .',
#   'opinions': [{'Source': [['Roche'], ['33:38']],
#     'Target': [['Medikamentenpreise'], ['65:83']],
#     'Polar_expression': [['festlegt'], ['84:92']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Seit Anfang des Jahres haben die Behörden weitere 13 Versuche registriert , 7 Boote erreichten die englische Küste .',
#   'opinions': [{'Source': [['Boote'], ['78:83']],
#     'Target': [['Küste'], ['109:114']],
#     'Polar_expression': [['erreichten'], ['84:94']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': '( sda / afp ) · Das Parlament in Rumänien hat der Minderheitsregierung des neuen rumänischen Ministerpräsidenten Ludovic Orban am Montag das Vertrauen ausgesprochen .',
#   'opinions': [{'Source': [['Parlament'], ['20:29']],
#     'Target': [['Minderheitsregierung'], ['50:70']],
#     'Polar_expression': [['ausgesprochen'], ['151:164']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Andere Gespräche widmen sich der Pandemie , Krankheit und Körper oder der Berührbarkeit durch klassische Musik .',
#   'opinions': [{'Source': [['Gespräche'], ['7:16']],
#     'Target': [['Pandemie'], ['33:41']],
#     'Polar_expression': [['widmen'], ['17:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'So hat Mueller herausgefunden , dass Trumps ehemaliger Wahlkampfleiter Paul Manafort als Lobbyist früher zig Millionen Dollar verdient , aber nicht versteuert hat .',
#   'opinions': [{'Source': [['Wahlkampfleiter'], ['55:70']],
#     'Target': [[], []],
#     'Polar_expression': [['verdient'], ['126:134']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': 'Deshalb nutzen viele Mediziner 5-ALA , das kaum Nebenwirkungen hat , zum Beispiel auch am Berner Inselspital – jedoch einzig bei höchstgradig bösartigen Hirntumoren ( Glioblastom ) .',
#   'opinions': [{'Source': [['Mediziner'], ['21:30']],
#     'Target': [['ALA'], ['33:36']],
#     'Polar_expression': [['nutzen'], ['8:14']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Macron hatte eine Million Corona-Tests pro Woche angekündigt .',
#   'opinions': [{'Source': [['Macron'], ['0:6']],
#     'Target': [[], []],
#     'Polar_expression': [['angekündigt'], ['49:60']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': 'Kein Wunder , widmete sich Charles Darwin der Tiergruppe wähend acht Jahren seines Forscherlebens .',
#   'opinions': [{'Source': [['Charles'], ['27:34']],
#     'Target': [['Tiergruppe'], ['46:56']],
#     'Polar_expression': [['widmete'], ['14:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Sondern : In der komplexen Sportart Eishockey stellen sich viele Automatismen , die perfekte Abstimmung beispielsweise im Power- und Boxplay , hauptsächlich mit vielen Spieleinsätzen ein .',
#   'opinions': [{'Source': [['Automatismen'], ['65:77']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Einen Tag nach der Kabinenpredigt siegt Bern gegen Servette ( 3 : 2 n. V. ) erstmals nach drei Pleiten .',
#   'opinions': [{'Source': [['Bern'], ['40:44']],
#     'Target': [['Servette'], ['51:59']],
#     'Polar_expression': [['siegt'], ['34:39']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Auch Becir Omeragic fehlte mit einer Knieverletzung am Anfang der Saison .',
#   'opinions': [{'Source': [['Becir'], ['5:10']],
#     'Target': [['Anfang'], ['55:61']],
#     'Polar_expression': [['fehlte'], ['20:26']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Nicht nur Boris Becker traut Nadal zu , dass er den Rekord bald allein hält .',
#   'opinions': [{'Source': [['Boris'], ['10:15']],
#     'Target': [['Nadal'], ['29:34']],
#     'Polar_expression': [['traut'], ['23:28']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': '« Eine hundertprozentige Garantie gibt es nie . » Auch flächendeckendes Testen werde das Virus nicht zum Aussterben bringen , mahnt Krismer .',
#   'opinions': [{'Source': [['Testen'], ['72:78']],
#     'Target': [[], []],
#     'Polar_expression': [['bringen'], ['116:123']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': 'Bei fairen Präsidentschafts- und Parlamentswahlen muss der Staatschef um den Sieg fürchten .',
#   'opinions': [{'Source': [['Staatschef'], ['59:69']],
#     'Target': [['Sieg'], ['77:81']],
#     'Polar_expression': [['fürchten'], ['82:90']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'Doch nun wachsen die Zweifel , nachdem das saudische Regime die Tötung des Journalisten Jamal Khashoggi eingeräumt hat .',
#   'opinions': [{'Source': [['Regime'], ['53:59']],
#     'Target': [['Tötung'], ['64:70']],
#     'Polar_expression': [['eingeräumt'], ['104:114']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'Die SBB entschuldigen sich für die Umstände .',
#   'opinions': [{'Source': [['SBB'], ['4:7']],
#     'Target': [['Umstände'], ['35:43']],
#     'Polar_expression': [['entschuldigen'], ['8:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Zwar hat Easyjet Flüge nach Berlin aufgenommen und fliegt die Strecke bis zu sechsmal täglich .',
#   'opinions': [{'Source': [['Easyjet'], ['9:16']],
#     'Target': [[], []],
#     'Polar_expression': [['aufgenommen'], ['35:46']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': 'Der Ausdruck « Negrita » ( « kleiner schwarzer Mensch » ) hatte dem uruguayischen Fussballstar Edison Cavani kürzlich eine Geldstrafe wegen Rassismus eingebracht .',
#   'opinions': [{'Source': [['Ausdruck'], ['4:12']],
#     'Target': [['Fussballstar'], ['82:94']],
#     'Polar_expression': [['eingebracht'], ['150:161']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Sie ergänzt : « Ein Körper muss nicht perfekt sein , um schön zu sein . » Hochschwanger freute sich Sara Leutenegger im Oktober auf die Geburt .',
#   'opinions': [{'Source': [['Sara'], ['100:104']],
#     'Target': [['Geburt'], ['136:142']],
#     'Polar_expression': [['freute'], ['88:94']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'Ghosn hat über seinen Anwalt einen Medienbericht zurückgewiesen , wonach er 2008 einen Verlust aus Wertpapiergeschäften auf Nissan übertragen haben soll .',
#   'opinions': [{'Source': [['Ghosn'], ['0:5']],
#     'Target': [[], []],
#     'Polar_expression': [['zurückgewiesen'], ['49:63']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Drei Tage später entliess YB den CEO Niedermaier , es gab Parolen des Aufbruchs .',
#   'opinions': [{'Source': [['YB'], ['26:28']],
#     'Target': [['CEO'], ['33:36']],
#     'Polar_expression': [['entliess'], ['17:25']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'sho . · 2017 entliess der Gemeinderat Maschwanden gleichzeitig mit der Baubewilligung für zwei Ersatzbauten und einen Neubau ein Gehöft aus dem 19. Jahrhundert am Dorfrand aus dem kommunalen Schutzinventar .',
#   'opinions': [{'Source': [['Gemeinderat'], ['26:37']],
#     'Target': [[], []],
#     'Polar_expression': [['entliess'], ['13:21']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'Bei diesem Training orientiere man sich am Militär , das solche Übungen einsetze , damit die Soldaten besser mit schwierigen Situationen umgehen könnten .',
#   'opinions': [{'Source': [['Soldaten'], ['93:101']],
#     'Target': [['Situationen'], ['125:136']],
#     'Polar_expression': [['umgehen'], ['137:144']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'Im « Goldenen Handschuh » tut ein Mann alles , um Frauen zu zerstören .',
#   'opinions': [{'Source': [['Mann'], ['34:38']],
#     'Target': [['Frauen'], ['50:56']],
#     'Polar_expression': [['zerstören'], ['60:69']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Agnes Merz , Goldau Sehr gut , dass sich jetzt auch Petra Gössi als FDP-Chefin für den Klimaschutz einsetzt .',
#   'opinions': [{'Source': [['Petra'], ['52:57']],
#     'Target': [['Klimaschutz'], ['87:98']],
#     'Polar_expression': [['einsetzt'], ['99:107']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Die Unternehmen suchen nach Wegen , um sich für den demografischen Wandel zu wappnen , und stellen sich auf die veränderten Anforderungen der nachrückenden Generation ein .',
#   'opinions': [{'Source': [['Unternehmen'], ['4:15']],
#     'Target': [['Wandel'], ['67:73']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Während es bei den Offsets also eine « Kantonsrebellion » gab , hat sich die ständerätliche Kommission beim Rest der Vorlage hinter den Bundesrat gestellt .',
#   'opinions': [{'Source': [['Kommission'], ['92:102']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Janssen lässt denn auch seine Studenten nichts am Zeichentisch entwerfen , sondern stellt Fragen nach der gesellschaftlichen Relevanz der Architektur .',
#   'opinions': [{'Source': [['Janssen'], ['0:7']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Die Operation dauerte laut amerikanischen Medien acht Stunden , das transplantierte Herz habe seitdem seine Arbeit aufgenommen , dem Patienten gehe es gut .',
#   'opinions': [{'Source': [['Herz'], ['84:88']],
#     'Target': [['Arbeit'], ['108:114']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Darin verliebt sich ein 16-Jähriger in einen Rockmusiker , dem er bis zur Selbstaufgabe folgt .',
#   'opinions': [{'Source': [['Jähriger'], ['27:35']],
#     'Target': [['Rockmusiker'], ['45:56']],
#     'Polar_expression': [['verliebt'], ['6:14']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Yvonne Bozdag , Waltershausen ( D ) Trump wird Europa noch ins Chaos stürzen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['stürzen'], ['69:76']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Es lief erst die fünfte Minute , Englands Coach Gareth Southgate ballte kurz die Faust und stellte sich wieder unter das Dach der Spielerbank .',
#   'opinions': [{'Source': [['Coach'], ['42:47']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'Solothurn und Basel hatten am Dienstag ebenfalls schärfere Regeln angekündigt .',
#   'opinions': [{'Source': [['Solothurn'], ['0:9']],
#     'Target': [['Regeln'], ['59:65']],
#     'Polar_expression': [['angekündigt'], ['66:77']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Chinesische Staatsmedien haben Vorwürfe der US-Regierung über eine Vertuschung in der Corona-Krise und den Ursprung des Virus als « grundlose Beschuldigungen » zurückgewiesen .',
#   'opinions': [{'Source': [['Staatsmedien'], ['12:24']],
#     'Target': [[], []],
#     'Polar_expression': [['zurückgewiesen'], ['160:174']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '126',
#   'text': 'Doch die langwierige Jagd nach der Krone prägte seine Karriere .',
#   'opinions': [{'Source': [['Jagd'], ['21:25']],
#     'Target': [['Karriere'], ['54:62']],
#     'Polar_expression': [['prägte'], ['41:47']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '127',
#   'text': 'Vergleicht man nur die Zahl der Neuimmatrikulationen , so ist der Rückgang noch viel stärker : Diesen Herbst haben 43 % weniger Ausländer neu ein Studium in den USA aufgenommen als im Vorjahr .',
#   'opinions': [{'Source': [['Ausländer'], ['128:137']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '128',
#   'text': 'Die bedrängten Juden hätten sich der Zwangstaufe widersetzt und so ein leuchtendes Beispiel für die Heiligung des göttlichen Namens gegeben .',
#   'opinions': [{'Source': [['Juden'], ['15:20']],
#     'Target': [['Zwangstaufe'], ['37:48']],
#     'Polar_expression': [['widersetzt'], ['49:59']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '129',
#   'text': 'Zahlreiche Staaten , darunter die USA , aber auch die EU haben nun Sanktionen gegen Russland angekündigt oder schon verhängt .',
#   'opinions': [{'Source': [['Staaten'], ['11:18']],
#     'Target': [['Sanktionen'], ['67:77']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '130',
#   'text': 'Das Attentat galt laut Wasiri einem Stützpunkt der 111 .',
#   'opinions': [{'Source': [['Attentat'], ['4:12']],
#     'Target': [['Stützpunkt'], ['36:46']],
#     'Polar_expression': [['galt'], ['13:17']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '131',
#   'text': 'Und viele Frauenrechtlerinnen stellen sich trotz der Unterdrückung Andersdenkender hinter den Kurs des Kronprinzen .',
#   'opinions': [{'Source': [['Frauenrechtlerinnen'], ['10:29']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '132',
#   'text': 'Viktor Orban aus Ungarn freut sich auch sehr über Meloni , weil sich ja jetzt mit Freunden in Rom die Europäische Union verändern lasse .',
#   'opinions': [{'Source': [['Viktor'], ['0:6']],
#     'Target': [['Meloni'], ['50:56']],
#     'Polar_expression': [['freut'], ['24:29']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '133',
#   'text': 'Ein amerikanischer Vergeltungsschlag mit Drohnen tötete wiederum 150 Al-Shabab-Kämpfer .',
#   'opinions': [{'Source': [['Vergeltungsschlag'], ['19:36']],
#     'Target': [['Kämpfer'], ['79:86']],
#     'Polar_expression': [['tötete'], ['49:55']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '134',
#   'text': 'Dieser eindeutige Machtmissbrauch galt damals ohne Zweifel als Impeachment-würdig .',
#   'opinions': [{'Source': [['Machtmissbrauch'], ['18:33']],
#     'Target': [[], []],
#     'Polar_expression': [['galt'], ['34:38']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '135',
# ...
#   'opinions': [{'Source': [['Chefarzt'], ['153:161']],
#     'Target': [['Spitälern'], ['39:48']],
#     'Polar_expression': [['gelten'], ['21:27']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': '« Das ist einfach nur geil » , freut sich Nelson Ferreira nach der Partie über den zweiten Finaleinzug in der Vereinsgeschichte des FC Thun .',
#   'opinions': [{'Source': [['Nelson'], ['42:48']],
#     'Target': [['Finaleinzug'], ['91:102']],
#     'Polar_expression': [['freut'], ['31:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Das WM-Quartier der Nationalmannschaft musste er einen Tag vor WM-Beginn durch die Hintertür verlassen , weil dem Verbandschef Luis Rubiales seine ungeschickt mitgeteilte Einigung mit Real Madrid für die Zeit nach dem Turnier missfiel .',
#   'opinions': [{'Source': [['Einigung'], ['171:179']],
#     'Target': [['Verbandschef'], ['114:126']],
#     'Polar_expression': [['missfiel'], ['226:234']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Ausser dem republikanischen Senator Ted Cruz solidarisierte sich kaum eine bekannte Persönlichkeit mit den Truckern .',
#   'opinions': [{'Source': [['Persönlichkeit'], ['84:98']],
#     'Target': [['Truckern'], ['107:115']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Der Wirtschaftsverband Economiesuisse stellt sich auf spürbare Auswirkungen ein , auch für die Schweiz .',
#   'opinions': [{'Source': [['Wirtschaftsverband'], ['4:22']],
#     'Target': [['Auswirkungen'], ['63:75']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Für jede Generation stellt sich aufs Neue die Herausforderung , herauszufinden , welches Spiel gerade gespielt wird .',
#   'opinions': [{'Source': [['Herausforderung'], ['46:61']],
#     'Target': [['Generation'], ['9:19']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'In der gegenwärtigen Diskurs-Unkultur diffamieren kulturell orientierungslose Linksliberale gern um die Bewahrung der Freiheit kämpfende Liberal-Konservative .',
#   'opinions': [{'Source': [['Liberal'], ['137:144']],
#     'Target': [['Bewahrung'], ['104:113']],
#     'Polar_expression': [['kämpfende'], ['127:136']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Einige Kirchenleute fürchten sich offenbar vor einer Gestalt wie Locher – sie werfen ihm vor , dass er seinen Laden nicht im Griff habe oder dass er machtbesessen und narzisstisch sei .',
#   'opinions': [{'Source': [['Kirchenleute'], ['7:19']],
#     'Target': [['Gestalt'], ['53:60']],
#     'Polar_expression': [['fürchten'], ['20:28']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Das Obergericht stellt sich in seinem schriftlichen Urteil zunächst gegen die Ansicht der Verteidigung , wonach keine verwertbaren Beweise vorlägen .',
#   'opinions': [{'Source': [['Obergericht'], ['4:15']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Das Trauma von München Vor 50 Jahren spazierten acht Terroristen ins olympische Dorf , um Juden zu ermorden .',
#   'opinions': [{'Source': [['Trauma'], ['4:10']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Vor zweieinhalb Wochen aber stürzte Becciu über die vielen Ungereimtheiten seines Handelns – etwa beim Kauf einer Luxusimmobilie in London , bei seinen üppigen Zuwendungen für seine drei Brüder und für eine mysteriöse 39 Jahre alte Sardin .',
#   'opinions': [{'Source': [['Becciu'], ['36:42']],
#     'Target': [['Ungereimtheiten'], ['59:74']],
#     'Polar_expression': [['stürzte'], ['28:35']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Das Departement von Umweltministerin Simonetta Sommaruga will die Berechnungsmethodik so anpassen , dass das Problem der Verzerrungen verschwindet und sicher keine Autos mehr in der Kategorie A sind , deren Ausstoss höher ist als der CO2-Zielwert des Bundes .',
#   'opinions': [{'Source': [['Problem'], ['109:116']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': 'Die Spanier verhafteten sechs Chinesen , drei Spanier und drei Marokkaner .',
#   'opinions': [{'Source': [['Spanier'], ['4:11']],
#     'Target': [['Chinesen'], ['30:38']],
#     'Polar_expression': [['verhafteten'], ['12:23']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Der Australier stellt sich zum Aufschlag bereit , hat dabei zwei Bälle in der Hand – wie es Tennisprofis oft tun , bevor sie sich für einen der beiden entscheiden , der dann auf die andere Netzseite gepeitscht werden soll .',
#   'opinions': [{'Source': [['Australier'], ['4:14']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Pa Modou hatte fast die ganze Rückrunde verletzt gefehlt , ihn plagten Rückenprobleme , der FCZ glaubte , es gehe nicht mehr weiter mit ihm .',
#   'opinions': [{'Source': [['Pa'], ['0:2']],
#     'Target': [['Rückrunde'], ['30:39']],
#     'Polar_expression': [['verletzt'], ['40:48']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Berlin treibt mit aller Macht das Projekt der russisch-deutschen Gaspipeline Nord Stream 2 durch die Ostsee voran , obwohl die direkt betroffenen Anrainer wie die baltischen Staaten und Polen , aber auch Frankreich und die USA dagegen opponieren .',
#   'opinions': [{'Source': [['Anrainer'], ['146:154']],
#     'Target': [[], []],
#     'Polar_expression': [['opponieren'], ['235:245']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Als Star wurde Manson mehrfach verklagt , von früheren Bandmitgliedern und Hotelbesitzern .',
#   'opinions': [{'Source': [['Manson'], ['15:21']],
#     'Target': [[], []],
#     'Polar_expression': [['verklagt'], ['31:39']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Vor allem der Umstand , dass der Vertreter der Volksrepublik China , Botschafter Zhang Jun , ebenfalls klare Worte fand , ist bemerkenswert : « Es ist nun Zeit für eine Entspannung , für diplomatische Aktivitäten und für einen Dialog » , wird Zhang Jun zitiert .',
#   'opinions': [{'Source': [['Vertreter'], ['33:42']],
#     'Target': [[], []],
#     'Polar_expression': [['fand'], ['115:119']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Zweitens konnten Firmen zur Sicherung ihrer Liquidität ( nicht ihrer Solvenz ) bereits günstige , staatlich garantierte Covid-19-Kredite aufnehmen , die bei Bedarf neu aufgelegt werden könnten .',
#   'opinions': [{'Source': [['Firmen'], ['17:23']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Michelle Hunziker hat sich für einen rassistischen Auftritt in einer italienischen Satireshow entschuldigt .',
#   'opinions': [{'Source': [['Michelle'], ['0:8']],
#     'Target': [['Auftritt'], ['51:59']],
#     'Polar_expression': [['entschuldigt'], ['94:106']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Insgesamt stellen sich am Sonntag , 4. März , 1054 Zürcherinnen und Zürcher zur Wahl in den Gemeinderat .',
#   'opinions': [{'Source': [['Zürcherinnen'], ['51:63']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Deshalb überfällt Sali Hafez nun eine Bank .',
#   'opinions': [{'Source': [['Sali'], ['18:22']],
#     'Target': [['Bank'], ['38:42']],
#     'Polar_expression': [['überfällt'], ['8:17']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Zwei Mittzwanziger stellen sich vorne an den Bühnenrand und machen genau das , was ihr « Medium » nicht wollte : Sie zeigen Schritte vor und versuchen die Zuschauer zu animieren , ihnen nachzutanzen .',
#   'opinions': [{'Source': [['Mittzwanziger'], ['5:18']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Spätere Sultane lösten dieses Problem , indem sie in vielen Tavernen einen Mitarbeiter des Geheimdiensts postierten .',
#   'opinions': [{'Source': [['Sultane'], ['8:15']],
#     'Target': [['Problem'], ['30:37']],
#     'Polar_expression': [['lösten'], ['16:22']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Und es ist auch klar , dass eine Neubaustrecke zwischen Lausanne und Genf viele Probleme lösen würde .',
#   'opinions': [{'Source': [['Neubaustrecke'], ['33:46']],
#     'Target': [['Probleme'], ['80:88']],
#     'Polar_expression': [['lösen'], ['89:94']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Die dann aber nach wenigen Monaten resigniert die Kündigung eingereicht hätten .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Kündigung'], ['50:59']],
#     'Polar_expression': [['eingereicht'], ['60:71']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Schliesslich hat das Parlament erstmals eine Spezialkommission eingesetzt , die sich nur mit dem Flugplatz Dübendorf befasst .',
#   'opinions': [{'Source': [['Parlament'], ['21:30']],
#     'Target': [['Spezialkommission'], ['45:62']],
#     'Polar_expression': [['eingesetzt'], ['63:73']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Jüngst verdeutlichte Scania seine Abkehr vom derzeitigen Wasserstoff-Hype und gab Gründe für die Strategieverschiebung an .',
#   'opinions': [{'Source': [['Scania'], ['21:27']],
#     'Target': [['Abkehr'], ['34:40']],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Freiwilligenarbeit findet Zulauf , wo Freiwillige ihre eigenen Ideen einbringen und selbst gestaltend aktiv werden können – also nicht mehr zwingend in organisatorischen Struktur von Nonprofitorganisationen .',
#   'opinions': [{'Source': [['Freiwillige'], ['0:11']],
#     'Target': [['Ideen'], ['63:68']],
#     'Polar_expression': [['einbringen'], ['69:79']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Qiaos schwedischer Verteidiger , Henrik Olsson Lilja , schloss jedoch einen fairen Prozess a priori aus , weil sein Mandant im chinesischen Fernsehen bereits vorverurteilt worden sei .',
#   'opinions': [{'Source': [['Verteidiger'], ['19:30']],
#     'Target': [['Prozess'], ['83:90']],
#     'Polar_expression': [['schloss'], ['55:62']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Dieser Fund löste einen längeren Austausch zwischen der Bundesregierung und Vertretern des ehemaligen Präsidenten aus .',
#   'opinions': [{'Source': [['Fund'], ['7:11']],
#     'Target': [['Austausch'], ['33:42']],
#     'Polar_expression': [['löste'], ['12:17']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Auch die Ärztekammer , das Parlament der Schweizer Ärzteschaft , hat es kürzlich abgelehnt , liberalisierte Richtlinien zur Suizidhilfe in ihre Standesordnung aufzunehmen .',
#   'opinions': [{'Source': [['Ärztekammer'], ['9:20']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'Im Jahr 2010 gewann Bridges einen Oscar als bester Hauptdarsteller für « Crazy Heart » .',
#   'opinions': [{'Source': [['Bridges'], ['20:27']],
#     'Target': [['Crazy'], ['73:78']],
#     'Polar_expression': [['gewann'], ['13:19']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Gottstein musste sich später für den Wutausbruch entschuldigen .',
#   'opinions': [{'Source': [['Gottstein'], ['0:9']],
#     'Target': [['Wutausbruch'], ['37:48']],
#     'Polar_expression': [['entschuldigen'], ['49:62']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Von 1932 bis 1934 gings plötzlich in die entgegengesetzte Richtung , da machte die Raubkatze immer angsteinflössendere Fratzen , gab immer noch wildere Geräusche von sich ... was dann 1935 ironisch gebrochen wurde , indem man Groucho , Chico und Harpo Marx den Löwen nachahmen liess ( wobei Harpo dafür eine Hupe benutzte ) .',
#   'opinions': [{'Source': [['Raubkatze'], ['83:92']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Spieler wurden unlängst getauscht , ein zusätzlicher Ausländer eben erst verpflichtet , Etienne Froidevaux , dem ehemaligen Captain , wurde beschieden , er könne sich einen neuen Arbeitgeber suchen .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Viele Arbeiter fürchten sich vor Kürzungen und einer Privatisierung .',
#   'opinions': [{'Source': [['Arbeiter'], ['6:14']],
#     'Target': [['Kürzungen'], ['33:42']],
#     'Polar_expression': [['fürchten'], ['15:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Diesen Anhängern eines harten Brexit missfällt vor allem der Backstop im EU-Austrittsvertrag .',
#   'opinions': [{'Source': [['Backstop'], ['61:69']],
#     'Target': [['Anhängern'], ['7:16']],
#     'Polar_expression': [['missfällt'], ['37:46']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Sanktionen gegen Russen Die Kantone haben sich bei Wirtschaftsminister Guy Parmelin beschwert , sie seien nicht gut genug darüber informiert worden , welche Rolle sie bei den Sanktionen zu spielen haben .',
#   'opinions': [{'Source': [['Kantone'], ['28:35']],
#     'Target': [[], []],
#     'Polar_expression': [['beschwert'], ['84:93']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Soll der Arbeiter die Weiche so stellen , dass fünf Menschen sterben , oder so , dass einer stirbt ?',
#   'opinions': [{'Source': [['Arbeiter'], ['9:17']],
#     'Target': [[], []],
#     'Polar_expression': [[], []],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'Aber dann kam uns in den Sinn , dass in den letzten Monaten am Morgen häufig unsere Zeitung im Briefkasten fehlte .',
#   'opinions': [{'Source': [['Zeitung'], ['84:91']],
#     'Target': [['Briefkasten'], ['95:106']],
#     'Polar_expression': [['fehlte'], ['107:113']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'MARCO GARCIA , BUBIKON ZH Diesen Jugendlichen fehlt die führende Hand der Eltern und des Staats .',
#   'opinions': [{'Source': [['Hand'], ['65:69']],
#     'Target': [['Jugendlichen'], ['33:45']],
#     'Polar_expression': [['fehlt'], ['46:51']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': 'Die Täter überfielen dort ein Pokerturnier und erbeuteten rund 250 000 Euro .',
#   'opinions': [{'Source': [['Täter'], ['4:9']],
#     'Target': [['Pokerturnier'], ['30:42']],
#     'Polar_expression': [['überfielen'], ['10:20']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  ...]

# %%
# evaluate the polar expression performance
print("test accuracy: {:.3f}".format(accuracy_score(gold_polarities, preds_full_label_text)))

print(classification_report(gold_polarities, preds_full_label_text))
# Out:
# test accuracy: 0.572
#               precision    recall  f1-score   support
#
#     Negative       0.78      0.44      0.56      1774
#      Neutral       0.48      0.86      0.62      1792
#     Positive       0.67      0.41      0.51      1757
#
#     accuracy                           0.57      5323
#    macro avg       0.64      0.57      0.56      5323
# weighted avg       0.64      0.57      0.56      5323

# %%
with open(DATADEST, "w", encoding="utf-8") as f:
    json.dump(out_data_w_entities_and_rel, f)

# %%
!(source ~/envs/perin-venv/bin/activate && cd ../../external_repos/direct_parsing_to_sent_graph/evaluation && python evaluate_single_dataset.py ../../../etl/data/processed/Perin_Preprocessing/01_test.json ../../../etl/data/processed/ORL_RE_Inference/01_test.json)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Source F1: 0.731
# Target F1: 0.604
# Expression F1: 0.800
# Unlabeled Sentiment Tuple F1: 0.406
# Sentiment Tuple F1: 0.278
# {
#   "source/f1": 0.7309854154541209,
#   "target/f1": 0.6041468349975422,
#   "expression/f1": 0.8002938109452079,
#   "sentiment_tuple/unlabeled_f1": 0.4057627563970956,
#   "sentiment_tuple/precision": 0.2773361480266674,
#   "sentiment_tuple/recall": 0.27955722159168617,
#   "sentiment_tuple/f1": 0.278442255623941
# }
#
# [0.7309854154541209, 0.6041468349975422, 0.8002938109452079, 0.4057627563970956, 0.2773361480266674, 0.27955722159168617, 0.278442255623941]
