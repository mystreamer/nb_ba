# %% [markdown]
# ## ReadGoldStandard
#
# Script to read GoldStandard in the folder `pro_con_500`.

# %%
# IMPORTS
import pandas as pd
import json
import os

# %%
# makedirs if not exist
os.makedirs("../../etl/data/intermediate/ReadGoldStandard", exist_ok=True)

# %%
FILENAMES = ["annotator1.conll", "annotator2.conll", "annotator3.conll"]
RAW_DATA_FOLDER_PATH = f"../../etl/data/raw/pro_con_500"

EXPORT_PATH = "../../etl/data/intermediate/ReadGoldStandard/pro_con_500.csv"

# %%
x = """
neff4
c4,5
c1,51
"""

for y in x.split("\n"):
    if re.match(r"([a-z]{1}\d+?\,\d+?)", y):
        print(y)
# Out:
# c4,5
# c1,51

# %%
# sents,rels={},{}
# c=0

def read_conll_file(filepath):
    """Read CoNLL formatted file and add annotations."""
    sents=[]
    anns=[]
    sent=[]
    ann=[]
    with open(filepath,"r") as f:
        for line in f:
            if line[0]=='#' or line.strip()=='' or re.match('^\d$', line):
                sents.append(sent) if sent else None
                anns.append(ann) if sent else None
                sent = []
                ann = []
                continue
            # then start counting
            if line.startswith(tuple('0123456789')):
                sent.append(line)
            elif re.match(r"([a-z]{1}\d+?\,\d+?)", line):
                ann.append(line.strip().strip(","))
    return sents, anns

            # from IPython.core.debugger import Pdb; Pdb().set_trace()

            #if c>9000: # nur fürs testen, dann weg
            #    break

# %%
def postprocess_sentence(sent):
    """Preprocess the sentence"""
    tokens = []
    for line in sent:
        tokens.append(line.split("\t")[1])
    # print(tokens)
    return tokens

def postprocess_ann(ann):
    """Convert the textual annotations into a structured form"""
    if ann:
        rels = []
        for rel in ann:
            try:
                rel_type = rel[0:1]
                fro_m, to = rel[1:].split(",")
                rels.append((rel_type, fro_m, to))
            except Exception as e:
                print(f"Rel: {rel}")
        return rels
    return []

# %%
keys = ["annotator1", "annotator2", "annotator3"]
dataset = {}

# read in all the data
for key, fname in zip(keys, FILENAMES):
    s, a = read_conll_file(f"{RAW_DATA_FOLDER_PATH}/{fname}")
    s_clean = list(map(postprocess_sentence, s))
    a_clean = list(map(postprocess_ann, a))
    dataset.update({key: [s_clean, a_clean]})

# %%
dataset
# Out:
# {'annotator1': [[['Dabei',
#     'machte',
#     'er',
#     'sich',
#     'primär',
#     'für',
#     'Ausgabenkürzungen',
#     'stark',
#     ',',
#     'während',
#     'er',
#     'von',
#     'Steuererhöhungen',
#     'abriet',
#     '.'],
#    ['Bundesrätin',
#     'Calmy-Rey',
#     'ist',
#     'allerdings',
#     'der',
#     'Einladung',
#     'zum',
#     'Gipfeltreffen',
#     'nicht',
#     'gefolgt',
#     ',',
#     'und',
#     'einige',
#     'CEO',
#     'haben',
#     'ihre',
#     'Teilnahme',
#     'ebenfalls',
#     'kurzfristig',
#     'abgesagt',
#     '.'],
#    ['Das',
#     'Bundesgericht',
#     'hat',
#     'eine',
#     'staatsrechtliche',
#     'Beschwerde',
#     'der',
#     'SVP',
#     'des',
#     'Kantons',
#     'Zürich',
#     'abgewiesen',
#     '.'],
#    ['Generell',
#     'ortet',
#     'Zeuske',
#     'denn',
#     'auch',
#     'die',
#     'Krise',
#     'Kubas',
#     'zuerst',
#     'in',
#     'dem',
#     'herrschenden',
#     'absurden',
#     'und',
#     'ineffizienten',
#     'Wirtschaftssystem',
#     ',',
#     'das',
#     'jegliche',
#     'Eigeninitiative',
#     'abwürgt',
#     '.'],
#    ['In',
#     'einer',
#     'Videoaufzeichnung',
#     'hat',
#     'der',
#     'tschetschenische',
#     'Rebellenführer',
#     'Aslan',
#     'Maschadow',
#     'eine',
#     'Intensivierung',
#     'der',
#     'Kämpfe',
#     'auf',
#     'fremdem',
#     'Territorium',
#     'angekündigt',
#     'und',
#     'dem',
#     'nächsten',
#     'Regierungschef',
#     'die',
#     'sofortige',
#     'Ermordung',
#     'angedroht',
#     '.'],
#    ['Hofstetter',
#     'wirft',
#     'im',
#     'Interview',
#     'den',
#     'Gewerkschaften',
#     'vor',
#     ',',
#     'sie',
#     'wollen',
#     'die',
#     'Branche',
#     'anschwärzen',
#     '.'],
#    ['Dass',
#     'der',
#     'an',
#     'der',
#     'Rotmeerküste',
#     'und',
#     'an',
#     'der',
#     'Grenze',
#     'zu',
#     'Eritrea',
#     'operierende',
#     'Beja',
#     'Congress',
#     'ausgerechnet',
#     'jetzt',
#     'Unruhen',
#     'anzettelt',
#     ',',
#     'ist',
#     'kein',
#     'Zufall',
#     '.'],
#    ['Das',
#     'Volk',
#     'hat',
#     'mehrfach',
#     'gegen',
#     'die',
#     'ungebremste',
#     'Schuldenspirale',
#     'aufbegehrt',
#     '-',
#     'unmissverständlich',
#     '.'],
#    ['Sie',
#     'wollen',
#     'dem',
#     'Vertragspaket',
#     'integral',
#     'zustimmen',
#     'und',
#     'allfällige',
#     'Unannehmlichkeiten',
#     'durch',
#     'Anpassungen',
#     'des',
#     'inländischen',
#     'Rechts',
#     'ausbügeln',
#     '.'],
#    ['Sarkozy',
#     'kündigte',
#     'auch',
#     'bescheidene',
#     'Prämien',
#     'für',
#     'die',
#     'Mitarbeiter',
#     'von',
#     'Arbeitsgruppen',
#     'an',
#     ',',
#     'die',
#     'sich',
#     'durch',
#     'besonders',
#     'gute',
#     'Resultate',
#     'und',
#     'Effizienz',
#     'auszeichneten',
#     '.'],
#    ['Zuvor',
#     'hatte',
#     'er',
#     'bereits',
#     'eine',
#     'Ministerin',
#     ',',
#     'die',
#     'ihre',
#     'Familie',
#     'unrechtmässig',
#     'begünstigt',
#     'hatte',
#     ',',
#     'in',
#     'die',
#     'Wüste',
#     'geschickt',
#     '.'],
#    ['Die',
#     'Verbandsspitze',
#     'beharrte',
#     'indes',
#     'darauf',
#     ',',
#     'die',
#     'Endrunde',
#     'abzuwarten',
#     'und',
#     'erst',
#     'danach',
#     'zu',
#     'verhandeln',
#     '.'],
#    ['Und',
#     'damit',
#     'belügt',
#     'man',
#     'erneut',
#     'eine',
#     'Generation',
#     ',',
#     'die',
#     'das',
#     'Kriegsende',
#     'und',
#     'die',
#     'Schrecken',
#     'dieser',
#     'Zeit',
#     'nicht',
#     'selbst',
#     'erlebt',
#     'hat',
#     '.'],
#    ['Der',
#     'Regierungschef',
#     'beriet',
#     'am',
#     'Mittwoch',
#     'mehr',
#     'als',
#     'drei',
#     'Stunden',
#     'mit',
#     'dem',
#     'Auswärtigen',
#     'und',
#     'dem',
#     'Verteidigungsausschuss',
#     'des',
#     'Parlaments',
#     'über',
#     'seinen',
#     'Plan',
#     '.'],
#    ['Den',
#     'Wechsel',
#     'von',
#     'der',
#     '«',
#     'Aargauer',
#     'Zeitung',
#     '»',
#     'zur',
#     'NZZ',
#     'hat',
#     'die',
#     'Chauffeuse',
#     'nie',
#     'bereut',
#     ',',
#     'denn',
#     'das',
#     'Arbeitsklima',
#     'sei',
#     'hier',
#     'deutlich',
#     'besser',
#     '.'],
#    ['Grasser',
#     'beschädige',
#     'nicht',
#     'nur',
#     'die',
#     'Beziehungen',
#     'mit',
#     'anderen',
#     'EU-Mitgliedstaaten',
#     ',',
#     'sondern',
#     'auch',
#     'den',
#     'Ruf',
#     'Österreichs',
#     'innerhalb',
#     'Europas',
#     '.'],
#    ['«',
#     'Ja',
#     ',',
#     'ich',
#     'habe',
#     'meine',
#     'Firma',
#     'beschissen',
#     '»',
#     ',',
#     'sagte',
#     'der',
#     'Angeklagte',
#     '.'],
#    ['Es',
#     'besticht',
#     'durch',
#     'eine',
#     'Genauigkeit',
#     'der',
#     'Wirklichkeitsbeobachtung',
#     'und',
#     'eine',
#     'hohe',
#     'Kunst',
#     'der',
#     'begrifflichen',
#     'Differenzierung',
#     '.'],
#    ['Einen',
#     'weiteren',
#     'Mittäter',
#     'bestrafte',
#     'die',
#     'Jugendkammer',
#     'mit',
#     '80',
#     'Stunden',
#     'gemeinnütziger',
#     'Arbeit',
#     '.'],
#    ['Die',
#     'Migration',
#     'bewirkt',
#     ',',
#     'dass',
#     'auch',
#     'die',
#     'schweizerische',
#     'Gesellschaft',
#     'heute',
#     'hochgradig',
#     'multikulturell',
#     'zusammengesetzt',
#     'ist',
#     '.'],
#    ['Die',
#     'Schweizer',
#     'Experten',
#     'ihrerseits',
#     'bewundern',
#     'ausdrücklich',
#     'die',
#     'Lernfähigkeit',
#     'und',
#     'den',
#     'Fleiss',
#     'der',
#     'Nordkoreaner',
#     '.'],
#    ['Der',
#     'Votant',
#     'bezweifelt',
#     ',',
#     'dass',
#     'es',
#     'sinnvoll',
#     'ist',
#     ',',
#     'die',
#     'Gewinnausschüttungen',
#     'vollumfänglich',
#     'an',
#     'den',
#     'Bund',
#     'und',
#     'die',
#     'Kantone',
#     'zu',
#     'leiten',
#     '.'],
#    ['Der',
#     'Sicherheitsrat',
#     'hat',
#     'Ende',
#     'April',
#     'die',
#     'Entsendung',
#     'einer',
#     '8000',
#     'Mann',
#     'starken',
#     'Blauhelm-Truppe',
#     'für',
#     'Haiti',
#     'gebilligt',
#     '.'],
#    ['Der',
#     'Schnee',
#     'blockiert',
#     'den',
#     'Zugang',
#     'zu',
#     'den',
#     'Berghütten',
#     '.'],
#    ['Er',
#     'dämonisiert',
#     'den',
#     'Monarchen',
#     'jedoch',
#     'nicht',
#     ',',
#     'sondern',
#     'schildert',
#     'ihn',
#     'vielmehr',
#     'als',
#     'zwar',
#     'intelligenten',
#     'Menschen',
#     ',',
#     'aber',
#     'auch',
#     'als',
#     '«',
#     'eine',
#     'ängstliche',
#     ',',
#     'zur',
#     'Panik',
#     'neigende',
#     'Gestalt',
#     '»',
#     '.'],
#    ['Jim',
#     'Crace',
#     ',',
#     'dessen',
#     'Bücher',
#     'viele',
#     'Leser',
#     'deprimieren',
#     ',',
#     'wirkt',
#     'wie',
#     'der',
#     'heiterste',
#     'Mensch',
#     'auf',
#     'Erden',
#     '.'],
#    ['Qualitativ',
#     'können',
#     'es',
#     'die',
#     'kolumbianischen',
#     'Rosen',
#     'heute',
#     'mit',
#     'den',
#     'ecuadorianischen',
#     'aufnehmen',
#     ',',
#     'die',
#     'auf',
#     'den',
#     'internationalen',
#     'Märkten',
#     'praktisch',
#     'dominieren',
#     '.'],
#    ['«',
#     'Aber',
#     'ich',
#     'ekele',
#     'mich',
#     'doch',
#     'vor',
#     'ihm',
#     '»',
#     ',',
#     'rief',
#     'Shahla',
#     'verzweifelt',
#     'aus',
#     '.'],
#    ['Zudem',
#     'entlarvt',
#     'die',
#     'Autorin',
#     'werdende',
#     'Mütter',
#     'als',
#     'kleine',
#     'Egoistinnen',
#     ',',
#     'die',
#     'sich',
#     'mit',
#     'dem',
#     'Kind',
#     'zuerst',
#     'einmal',
#     '«',
#     'selbst',
#     'ein',
#     'Geschenk',
#     '»',
#     'machen',
#     '.'],
#    ['Bezirksanwalt',
#     'Böhler',
#     'entlässt',
#     'den',
#     'nicht',
#     'geständigen',
#     'Dominikaner',
#     'aus',
#     'der',
#     'Polizeihaft',
#     'und',
#     'wird',
#     'beim',
#     'Einzelrichter',
#     'Anklage',
#     'erheben',
#     '.'],
#    ['Am',
#     'Ende',
#     'des',
#     'dreieinhalbstündigen',
#     'Prozesses',
#     'entschuldigte',
#     'sich',
#     'Sivits',
#     'beim',
#     'irakischen',
#     'Volk',
#     'und',
#     'bei',
#     'den',
#     'Gefangenen',
#     '.'],
#    ['Didier',
#     'Cuche',
#     'erleidet',
#     'Kreuzbandriss',
#     'und',
#     'fällt',
#     'für',
#     'die',
#     'Ski-WM',
#     'in',
#     'Bormio',
#     'aus',
#     '.'],
#    ['Eindringlich',
#     'ermahnt',
#     'die',
#     'Mutter',
#     'sie',
#     'noch',
#     'einmal',
#     ',',
#     'bloss',
#     'keinen',
#     'Fehler',
#     'zu',
#     'machen',
#     '.'],
#    ['Den',
#     'noch',
#     'vakanten',
#     'Sitz',
#     'im',
#     'Gemeinderat',
#     'eroberte',
#     'Urs',
#     'Gassmann',
#     '(',
#     'neu',
#     ')',
#     ',',
#     'der',
#     'von',
#     'einem',
#     'ad',
#     'hoc',
#     'gegründeten',
#     'Komitee',
#     'portiert',
#     'worden',
#     'war',
#     '.'],
#    ['Am',
#     'Sonntag',
#     'erschütterten',
#     'mehrere',
#     'Explosionen',
#     'die',
#     'Innenstadt',
#     'von',
#     'Bagdad',
#     '.'],
#    ['Die',
#     'Angreifer',
#     'feuerten',
#     'in',
#     'mindestens',
#     'zehn',
#     'Salven',
#     'Granaten',
#     'auf',
#     'den',
#     'Stützpunkt',
#     'einer',
#     'Versorgungseinheit',
#     'ab',
#     '.'],
#    ['Dann', 'flucht', 'er', 'wieder', 'über', 'die', 'neuen', 'Zeiten', '.'],
#    ['In',
#     'einer',
#     'Talkshow',
#     'giftete',
#     'am',
#     'Sonntag',
#     'der',
#     'Publizist',
#     'Arnulf',
#     'Baring',
#     'heftig',
#     'gegen',
#     'alle',
#     ',',
#     'die',
#     'nicht',
#     'seiner',
#     'ausgesprochen',
#     'realpolitischen',
#     'Meinung',
#     'waren',
#     '.'],
#    ['Doris',
#     'Fiala',
#     'gratulierte',
#     'ihrem',
#     'Nachfolger',
#     'und',
#     'rief',
#     'zur',
#     'Zusammenarbeit',
#     'zwischen',
#     'Stadt',
#     'und',
#     'Kanton',
#     'auf',
#     '.'],
#    ['Noch',
#     'jetzt',
#     'ist',
#     'sie',
#     'empört',
#     'über',
#     'ein',
#     'Mädchen',
#     ',',
#     'das',
#     'sie',
#     'wegen',
#     'ihrer',
#     'roten',
#     'Haare',
#     'hänselte',
#     '.'],
#    ['Die',
#     'Opposition',
#     'sprach',
#     'von',
#     'Bürgerkriegszustand',
#     ',',
#     'während',
#     'Präsident',
#     'Musharraf',
#     'die',
#     'Ereignisse',
#     'herunterspielte',
#     '.'],
#    ['Dass',
#     'Christian',
#     'Lindner',
#     'den',
#     'Bettel',
#     'einfach',
#     'hinschmeisst',
#     ',',
#     'ist',
#     'ein',
#     'Symptom',
#     'dafür',
#     ',',
#     'wie',
#     'tief',
#     'die',
#     'FDP',
#     'in',
#     'der',
#     'Krise',
#     'steckt',
#     '.'],
#    ['Er',
#     'inspirierte',
#     'mit',
#     'seiner',
#     'Arbeit',
#     'Generationen',
#     'von',
#     'Fotografen',
#     '.'],
#    ['Microsoft', 'klagt', 'gegen', 'die', 'EU-Kommission', '.'],
#    ['Der',
#     'Privatsektor',
#     'lechzt',
#     'ebenfalls',
#     'nach',
#     'ausländischem',
#     'Engagement',
#     '.'],
#    ['Auch',
#     'die',
#     'Schaffung',
#     'von',
#     'Arbeitsplätzen',
#     'legitimiert',
#     'nicht',
#     'die',
#     'Ausschaltung',
#     'demokratischer',
#     'Rechte',
#     '.'],
#    ['Er',
#     'leugnet',
#     'auch',
#     'nicht',
#     ',',
#     'dass',
#     'er',
#     'für',
#     'den',
#     'Tod',
#     'von',
#     'so',
#     'manchem',
#     'verantwortlich',
#     'ist',
#     '.'],
#    ['Der',
#     'Präsident',
#     'von',
#     'Serbien-Montenegro',
#     'lobte',
#     'Kroatiens',
#     'Bemühungen',
#     'um',
#     'EU-Mitgliedschaft',
#     '.'],
#    ['Inzwischen',
#     'missioniert',
#     'er',
#     'für',
#     'jene',
#     ',',
#     'die',
#     'ihm',
#     'den',
#     'Rückgewinn',
#     'von',
#     'mehr',
#     'Lebensqualität',
#     'ermöglicht',
#     'haben',
#     ':',
#     'die',
#     'Schweizer',
#     'Firma',
#     'Phonak',
#     '.'],
#    ['Das',
#     'hohe',
#     'Tempo',
#     'der',
#     'Sieger',
#     'nervte',
#     'den',
#     'SCB',
#     ',',
#     'der',
#     'allein',
#     'im',
#     'Startdrittel',
#     '16',
#     'Strafminuten',
#     'kassierte',
#     '.'],
#    ['Tessiner', 'Journalisten', 'kritisieren', 'Zeitungen', '.'],
#    ['Strafgericht', 'kritisiert', 'Blochers', 'Entscheid', '.'],
#    ['Parlamentarier', 'kritisieren', 'Lombardi', '.'],
#    ['Ausländerkommission', 'kritisiert', 'Statistik', '.'],
#    ['Kerry', 'kritisiert', 'die', 'Aussenpolitik', 'der', 'US-Regierung', '.'],
#    ['Rambert',
#     'kritisierte',
#     ',',
#     'dass',
#     'mit',
#     'der',
#     '«',
#     'Fotoshow',
#     '»',
#     'geradezu',
#     'lehrbuchhaft',
#     'gegen',
#     'alle',
#     'Regeln',
#     'einer',
#     'Einvernahme',
#     'verstossen',
#     'worden',
#     'sei',
#     '.'],
#    ['Sie',
#     'kritisierten',
#     ',',
#     'dass',
#     'von',
#     'den',
#     'beiden',
#     'geplanten',
#     'Berufsbildungszentren',
#     'für',
#     'Gesundheitsberufe',
#     'nur',
#     'eines',
#     'vom',
#     'Kanton',
#     'selber',
#     'geführt',
#     'werden',
#     'soll',
#     '.'],
#    ['Kollegger',
#     'kritisierte',
#     'ferner',
#     ',',
#     'dass',
#     'in',
#     'Geschäftsführung',
#     'und',
#     'Verwaltungsrat',
#     'der',
#     'Bahn',
#     'kaum',
#     'Personen',
#     'mit',
#     'einem',
#     'Marketing-Hintergrund',
#     'vertreten',
#     'seien',
#     '.'],
#    ['Unabhängige',
#     'serbische',
#     'Medien',
#     'kritisierten',
#     ',',
#     'dass',
#     'Kostunica',
#     'seine',
#     'Anhänger',
#     'nicht',
#     'unmissverständlich',
#     'aufforderte',
#     ',',
#     'für',
#     'Tadic',
#     'zu',
#     'stimmen',
#     '.'],
#    ['Die',
#     'Unterzeichner',
#     'kritisieren',
#     'aber',
#     ',',
#     'dass',
#     'Rumantsch',
#     'Grischun',
#     'in',
#     'der',
#     'Schule',
#     'zur',
#     'einzigen',
#     'Schriftsprache',
#     'werden',
#     'soll',
#     '.'],
#    ['Aktienanalysten',
#     'und',
#     'Fondsmanager',
#     ',',
#     'die',
#     'den',
#     'Post-Vorstand',
#     'in',
#     'den',
#     'vergangenen',
#     'Wochen',
#     'immer',
#     'wieder',
#     'für',
#     'seine',
#     'Preisvorstellung',
#     'kritisiert',
#     'hatten',
#     ',',
#     'räumten',
#     'der',
#     'Aktie',
#     'gute',
#     'Kurschancen',
#     'ein',
#     '.'],
#    ['Die',
#     '29',
#     '000',
#     'Unterzeichner',
#     'kritisieren',
#     'die',
#     'Reservationspflicht',
#     'für',
#     'den',
#     'Veloverlad',
#     'in',
#     'den',
#     'Intercity-Neigezügen',
#     '.'],
#    ['«',
#     'Seiler',
#     '»',
#     ',',
#     'findet',
#     'der',
#     'Freiburger',
#     'CVP-Ständerat',
#     'Urs',
#     'Schwaller',
#     ',',
#     '«',
#     'ist',
#     'sehr',
#     'kooperationswillig',
#     '.',
#     '»',
#     '-',
#     '«',
#     'Kooperationsbesessen',
#     '»',
#     ',',
#     'korrigiert',
#     'der',
#     'Zürcher',
#     'SVP-Nationalrat',
#     'Hans',
#     'Fehr',
#     ',',
#     'der',
#     'keine',
#     'Gelegenheit',
#     'auslässt',
#     ',',
#     'Schmid',
#     'für',
#     'den',
#     'Armee-Leitsatz',
#     '«',
#     'Sicherheit',
#     'durch',
#     'Kooperation',
#     '»',
#     'zu',
#     'kritisieren',
#     '.'],
#    ['Doch',
#     'diesen',
#     'Einwand',
#     ',',
#     'dass',
#     'es',
#     'für',
#     'eine',
#     'Grundsatzdebatte',
#     ',',
#     'ob',
#     'die',
#     'Türkei',
#     'überhaupt',
#     'ein',
#     'europäisches',
#     'Land',
#     'sei',
#     ',',
#     'eh',
#     'zu',
#     'spät',
#     'ist',
#     ',',
#     'wollen',
#     'Warner',
#     'wie',
#     'Fischler',
#     'oder',
#     'sein',
#     'niederländischer',
#     'Kollege',
#     'Frits',
#     'Bolkestein',
#     'nicht',
#     'akzeptieren',
#     ':',
#     '«',
#     'Sollten',
#     'wir',
#     'nach',
#     'einer',
#     'tief',
#     'greifenden',
#     'Analyse',
#     'Zweifel',
#     'haben',
#     ',',
#     'müssen',
#     'wir',
#     'das',
#     'Risiko',
#     'ignorieren',
#     ',',
#     'für',
#     'diese',
#     'Ehrlichkeit',
#     'kritisiert',
#     'zu',
#     'werden',
#     '»',
#     ',',
#     'so',
#     'Fischler',
#     '.'],
#    ['Die',
#     'Minister',
#     'nutzen',
#     'das',
#     'gestrige',
#     'Treffen',
#     'auch',
#     'dazu',
#     ',',
#     'ihren',
#     'französischen',
#     'Kollegen',
#     'Nicolas',
#     'Sarkozy',
#     'für',
#     'sein',
#     'unabgesprochenes',
#     'Vorgehen',
#     'angesichts',
#     'des',
#     'steigenden',
#     'Ölpreises',
#     'zu',
#     'kritisieren',
#     '.'],
#    ['Dieser',
#     'wissenschaftliche',
#     'Ansatz',
#     'scheiterte',
#     'zwar',
#     ',',
#     'dennoch',
#     'sind',
#     'seine',
#     'Verdienste',
#     'für',
#     'die',
#     'ethnographische',
#     'Museumsgeschichte',
#     'gross',
#     '.'],
#    ['Bemühungen',
#     'für',
#     'aussergerichtliche',
#     'Einigungen',
#     'scheiterten',
#     'bisher',
#     '.'],
#    ['Auch', 'eine', 'weitere', 'Nachfrage', 'scheitert', 'kläglich', '.'],
#    ['Unzählige',
#     'Vermittlungsversuche',
#     'nahezu',
#     'sämtlicher',
#     'westafrikanischer',
#     'Staatschefs',
#     'scheiterten',
#     '.'],
#    ['Wieder', 'scheitert', 'eine', 'mögliche', 'Liebe', '.'],
#    ['Die',
#     'Einführung',
#     'von',
#     'EU-weit',
#     'gültigen',
#     'Regeln',
#     'scheiterte',
#     'am',
#     'Freitag',
#     'in',
#     'Luxemburg',
#     'am',
#     'Widerstand',
#     'von',
#     'zehn',
#     'Ländern',
#     '.'],
#    ['-',
#     'Die',
#     'Kommerzialisierung',
#     'der',
#     'Privatkopie',
#     'scheiterte',
#     'bisher',
#     'am',
#     'Fehlen',
#     'technischer',
#     'Kontrollmöglichkeiten',
#     'und',
#     'am',
#     'politischen',
#     'Widerstand',
#     'anderer',
#     'Interessengruppen',
#     '.'],
#    ['Der', 'FC', 'Thun', 'im', 'UI-Cup', 'an', 'Hamburg', 'gescheitert', '.'],
#    ['Der',
#     'Genfer',
#     'Tour-Pro',
#     'Julien',
#     'Clément',
#     'scheiterte',
#     'am',
#     'Cut',
#     ',',
#     'den',
#     'zwei',
#     'Schweizer',
#     'überstanden',
#     ',',
#     'Marc',
#     'Chatelain',
#     'und',
#     'Amateur',
#     'Nicolas',
#     'Sulzer',
#     '.'],
#    ['Vor',
#     'vier',
#     'Jahren',
#     'scheiterte',
#     'die',
#     'SP',
#     'deutlich',
#     'mit',
#     'einer',
#     'Initiative',
#     'für',
#     'eine',
#     '100-prozentige',
#     'Ausschöpfung',
#     ':',
#     '58',
#     'Prozent',
#     'des',
#     'Stimmvolkes',
#     'sagten',
#     'Nein',
#     '.'],
#    ['Das', 'lokale', 'Gewerbe', 'profitiert', '.'],
#    ['Der', 'Konsum', 'profitiert', 'mehr', 'als', 'der', 'Fiskus', '.'],
#    ['Profitiert',
#     'hat',
#     'auch',
#     'die',
#     'Umwelt',
#     ':',
#     'Die',
#     'Abgase',
#     'haben',
#     'sich',
#     'um',
#     '12',
#     '%',
#     'reduziert',
#     ',',
#     'es',
#     'gibt',
#     '5',
#     '%',
#     'weniger',
#     'Unfälle',
#     ',',
#     'und',
#     'die',
#     'Bevölkerung',
#     'ist',
#     'mit',
#     'dem',
#     'System',
#     'mehrheitlich',
#     'zufrieden',
#     '.'],
#    ['Die', 'Bauern', 'können', 'profitieren', '.'],
#    ['Hertha', 'vermag', 'nicht', 'zu', 'profitieren', '.'],
#    ['Hotels',
#     'und',
#     'Gewerbe',
#     'profitieren',
#     'von',
#     'den',
#     'vielen',
#     'Besuchern',
#     '.'],
#    ['Die',
#     'Stadt',
#     'habe',
#     'in',
#     'vielen',
#     'Bereichen',
#     'von',
#     'der',
#     'Weltausstellung',
#     'profitiert',
#     '.'],
#    ['Schätzungsweise',
#     '70',
#     'Mio.',
#     'Arbeitnehmer',
#     'in',
#     'den',
#     'USA',
#     'profitieren',
#     'denn',
#     'auch',
#     'gemäss',
#     'Branchenangaben',
#     'vom',
#     'Schutz',
#     ',',
#     'den',
#     'HMO-orientierte',
#     'Betriebskrankenkassen',
#     'sowohl',
#     'ihnen',
#     'als',
#     'auch',
#     'ihren',
#     'Familienangehörigen',
#     'offerieren',
#     '.'],
#    ['Basel',
#     'kann',
#     'dabei',
#     'von',
#     'einer',
#     'langen',
#     'caritativen',
#     'Tradition',
#     'profitieren',
#     '.'],
#    ['Bankwerte',
#     'profitierten',
#     'laut',
#     'Händlern',
#     'von',
#     'positiven',
#     'Analytikerkommentaren',
#     '.'],
#    ['Sechs',
#     'Minister',
#     'aus',
#     'dem',
#     'Hariri-Block',
#     'beschuldigten',
#     'Syrien',
#     'als',
#     'Anstifter',
#     'der',
#     'Unruhen',
#     'und',
#     'verlangten',
#     'eine',
#     'offizielle',
#     'Klage',
#     'Libanons',
#     'bei',
#     'der',
#     'Uno',
#     'gegen',
#     'das',
#     'Nachbarland',
#     '.'],
#    ['Früherer',
#     'Terrorexperte',
#     'Bushs',
#     'beschuldigt',
#     'das',
#     'Weisse',
#     'Haus',
#     '.'],
#    ['Später',
#     'beschuldigte',
#     'die',
#     'SEC',
#     'die',
#     'Börse',
#     'der',
#     'mangelnden',
#     'Aufsicht',
#     '.'],
#    ['Drei',
#     'der',
#     'Soldaten',
#     'werden',
#     'des',
#     'Totschlags',
#     'beschuldigt',
#     '.'],
#    ['Die',
#     'Regierung',
#     'beschuldigt',
#     '-',
#     'wie',
#     'immer',
#     'in',
#     'solchen',
#     'Fällen',
#     '-',
#     'Produzenten',
#     'und',
#     'Händler',
#     'der',
#     'Spekulation',
#     'zulasten',
#     'des',
#     'armen',
#     'Volkes',
#     '.'],
#    ['Das',
#     'Nürnberger',
#     'Oberlandesgericht',
#     'beschuldigt',
#     'die',
#     'drei',
#     'ehemaligen',
#     'Militärs',
#     'für',
#     'die',
#     'Tötung',
#     'der',
#     'deutschen',
#     'Soziologin',
#     'und',
#     'Theologiestudentin',
#     'Elisabeth',
#     'Käsemann',
#     'und',
#     'des',
#     'Münchner',
#     'Studenten',
#     'Manfred',
#     'Zieschank',
#     'während',
#     'der',
#     'Militärdiktatur',
#     'von',
#     '1976',
#     'bis',
#     '1983',
#     '.'],
#    ['6',
#     'Frauen',
#     'beschuldigen',
#     'den',
#     'Konzern',
#     ',',
#     'dass',
#     'sie',
#     'schlechter',
#     'bezahlt',
#     'worden',
#     'seien',
#     'als',
#     'ihre',
#     'männlichen',
#     'Kollegen',
#     'und',
#     'geringere',
#     'Aufstiegschancen',
#     'gehabt',
#     'hätten',
#     '.'],
#    ['Die',
#     'Armee',
#     'beschuldigt',
#     'al-Jil',
#     ',',
#     'ein',
#     'Propagandainstrument',
#     'der',
#     'Hamas',
#     'zu',
#     'sein',
#     '.'],
#    ['Das',
#     'Wahlkampfteam',
#     'der',
#     'Demokraten',
#     'beschuldigt',
#     'die',
#     'Gruppe',
#     '«',
#     'Swift',
#     'Boat',
#     'Veterans',
#     'For',
#     'Truth',
#     '»',
#     ',',
#     'ihre',
#     'Fernsehkampagne',
#     'rechtswidrig',
#     'mit',
#     'Bushs',
#     'Republikanern',
#     'abgestimmt',
#     'zu',
#     'haben',
#     '.'],
#    ['Die',
#     'Steuerbehörden',
#     'beschuldigen',
#     'Menem',
#     ',',
#     '600',
#     '000',
#     'Dollar',
#     'auf',
#     'einem',
#     'Konto',
#     'in',
#     'der',
#     'Schweiz',
#     'nicht',
#     'deklariert',
#     'zu',
#     'haben',
#     '.'],
#    ['Die',
#     'wichtigste',
#     'Politikerin',
#     'Argentiniens',
#     ',',
#     'die',
#     'Frau',
#     'des',
#     'Präsidenten',
#     ',',
#     'hat',
#     'dessen',
#     'Vorgänger',
#     'beschuldigt',
#     ',',
#     'eine',
#     'Verschwörung',
#     'zur',
#     'Destabilisierung',
#     'der',
#     'Regierung',
#     'angezettelt',
#     'zu',
#     'haben',
#     '.'],
#    ['Ferner',
#     'beschuldigte',
#     'Litwinenko',
#     'den',
#     'FSB',
#     'auch',
#     ',',
#     'die',
#     'Bombenanschläge',
#     'von',
#     '1999',
#     'gegen',
#     'Wohnblöcke',
#     'in',
#     'Moskau',
#     'organisiert',
#     'zu',
#     'haben',
#     ',',
#     'denen',
#     '300',
#     'Personen',
#     'zum',
#     'Opfer',
#     'fielen',
#     '.'],
#    ['Nationalrat',
#     'billigt',
#     'Parallelimporte',
#     'patentgeschützter',
#     'Güter',
#     '.'],
#    ['Der', 'Nationalrat', 'billigt', 'Parallelimporte', '.'],
#    ['Spaniens',
#     'Parlament',
#     'billigt',
#     'Solbes',
#     "'",
#     'revidiertes',
#     'Budget',
#     '.'],
#    ['EU-Parlament', 'billigt', 'den', 'Vertrag', 'von', 'Lissabon', '.'],
#    ['Gül', 'billigt', 'die', 'Aufhebung', 'des', 'Kopftuchverbots', '.'],
#    ['In',
#     'einem',
#     'nächsten',
#     'Schritt',
#     'wird',
#     'der',
#     'Grosse',
#     'Rat',
#     'das',
#     'Thema',
#     'behandeln',
#     '.'],
#    ['Zurückhaltend', 'behandelt', 'wurden', 'Energiewerte', '.'],
#    ['Man', 'behandelt', 'uns', 'wie', 'Dreck', '!'],
#    ['Leute',
#     ',',
#     'die',
#     'lächeln',
#     ',',
#     'werden',
#     'bevorzugt',
#     'behandelt',
#     '.'],
#    ['Die',
#     'Wirtschaft',
#     'hat',
#     'kein',
#     'Interesse',
#     'daran',
#     ',',
#     'Frauen',
#     'schlechter',
#     'zu',
#     'behandeln',
#     'als',
#     'Männer',
#     '.'],
#    ['Somit',
#     'erhöht',
#     'ein',
#     'gut',
#     'diversifiziertes',
#     'Portefeuille',
#     'die',
#     'Rendite',
#     'für',
#     'den',
#     'Investor',
#     '.'],
#    ['Auch',
#     'die',
#     'Nachfrage',
#     'aus',
#     'der',
#     'Industrie',
#     '(',
#     'vor',
#     'allem',
#     'der',
#     'Elektronik',
#     ')',
#     'erhöhte',
#     'sich',
#     '.'],
#    ['UBS', 'erhöht', 'Zinsen', 'für', 'Kassenobligationen', '.'],
#    ['Die', 'Frauen', 'feiern', '.'],
#    ['Das', 'Theater', 'am', 'Stadtgarten', 'feiert', '.'],
#    ['Die',
#     'Privatschule',
#     'Minerva',
#     'feiert',
#     'ihr',
#     '100-jähriges',
#     'Bestehen',
#     '.'],
#    ['Erfolgreiche',
#     'Jungunternehmer',
#     'werden',
#     'von',
#     'den',
#     'Medien',
#     'gefeiert',
#     ',',
#     'wobei',
#     'dieses',
#     'Lob',
#     'auch',
#     'eine',
#     'ideologische',
#     'Komponente',
#     'hat',
#     '.'],
#    ['In',
#     'der',
#     'arabischen',
#     'Welt',
#     'wurde',
#     'Zaidi',
#     'für',
#     'den',
#     'Schuhwurf',
#     'wie',
#     'ein',
#     'Held',
#     'gefeiert',
#     '.'],
#    ['Vor',
#     'ein',
#     'paar',
#     'Wochen',
#     'noch',
#     'feierten',
#     'sie',
#     'sich',
#     'dafür',
#     ',',
#     'dass',
#     'sie',
#     'auf',
#     'einer',
#     'Mitgliederversammlung',
#     'den',
#     'HSV',
#     'für',
#     'Investoren',
#     'öffneten',
#     '.'],
#    ['Und',
#     'es',
#     'feiert',
#     'ihn',
#     'dafür',
#     ',',
#     'dass',
#     'er',
#     'den',
#     'Begriff',
#     '«',
#     'virtuelle',
#     'Realität',
#     '»',
#     'in',
#     'die',
#     'Welt',
#     'getragen',
#     'hat',
#     '.'],
#    ['In',
#     'den',
#     'siebziger',
#     'Jahren',
#     'des',
#     'letzten',
#     'Jahrhunderts',
#     'wurden',
#     'verschiedene',
#     'Schweizer',
#     'Städte',
#     'auf',
#     'das',
#     'Problem',
#     'aufmerksam',
#     'und',
#     'förderten',
#     'aktiv',
#     ',',
#     'dass',
#     'Höfe',
#     'nicht',
#     'nur',
#     'Autos',
#     ',',
#     'sondern',
#     'auch',
#     'Spielplätze',
#     'und',
#     'originelle',
#     'Freiräume',
#     'beherbergten',
#     '.'],
#    ['Ich',
#     'förderte',
#     'ja',
#     ',',
#     'dass',
#     'Martina',
#     'sich',
#     'den',
#     'Reitsport',
#     'zum',
#     'Hobby',
#     'machte',
#     '.'],
#    ['Die',
#     'lokale',
#     'Abwertung',
#     'des',
#     'Rubels',
#     'förderte',
#     'die',
#     'Dollar-Haltung',
#     '.'],
#    ['Labelprogramme',
#     'und',
#     'Direktzahlungen',
#     'haben',
#     'dies',
#     'noch',
#     'gefördert',
#     '.'],
#    ['Die',
#     'Gesellschaft',
#     'um',
#     'uns',
#     'herum',
#     'fördert',
#     'das',
#     'allerdings',
#     'oft',
#     'nicht',
#     '.'],
#    ['Sie',
#     'fördert',
#     'auch',
#     'die',
#     'Ausbreitung',
#     'maoistischer',
#     'Ideen',
#     '.'],
#    ['«',
#     'Jia',
#     'mas',
#     '»',
#     ',',
#     'prosit',
#     ',',
#     'man',
#     'geniesst',
#     'und',
#     'hat',
#     'Zeit',
#     ',',
#     'die',
#     'Speisekarte',
#     'zu',
#     'studieren',
#     '-',
#     'und',
#     'dabei',
#     'ein',
#     'wenig',
#     'Griechisch',
#     'zu',
#     'lernen',
#     '.'],
#    ['Nicht',
#     'mehr',
#     'täglich',
#     'früh',
#     'am',
#     'Morgen',
#     'pendeln',
#     'zu',
#     'müssen',
#     ',',
#     'geniesse',
#     'ich',
#     'als',
#     'Privileg',
#     '.'],
#    ['Die',
#     'englischen',
#     'Fussballer',
#     'geniessen',
#     'grosse',
#     'Unterstützung',
#     '.'],
#    ['Aber',
#     'wir',
#     'möchten',
#     'diese',
#     'späte',
#     'Wiedergeburt',
#     'geniessen',
#     'und',
#     'sie',
#     'an',
#     'unsere',
#     'Kinder',
#     'weitergeben',
#     '.'],
#    ['Nein',
#     ',',
#     'die',
#     'SAS-Angestellten',
#     'geniessen',
#     'ihre',
#     'Ferien',
#     '!'],
#    ['Man',
#     'geniesst',
#     'es',
#     ',',
#     'die',
#     'Voodoo-',
#     'Puppe',
#     'zu',
#     'sein',
#     ',',
#     'denn',
#     'diese',
#     'Nadelstiche',
#     'verursachen',
#     'süsse',
#     'Schmerzen',
#     '.'],
#    ['Sie', 'leiden', 'jetzt', '.'],
#    ['Ihr',
#     'Image',
#     'leidet',
#     ',',
#     'seit',
#     'Untersuchungen',
#     'in',
#     'den',
#     '80er-Jahren',
#     'zeigten',
#     ',',
#     'dass',
#     'ihre',
#     'Areale',
#     'oft',
#     'Schwermetallgehalte',
#     'aufwiesen',
#     ',',
#     'bei',
#     'denen',
#     'die',
#     'Bodenfruchtbarkeit',
#     'gefährdet',
#     'ist',
#     '.'],
#    ['Auch',
#     'die',
#     'preisliche',
#     'Konkurrenzfähigkeit',
#     'der',
#     'italienischen',
#     'Unternehmen',
#     'hat',
#     'gelitten',
#     '.'],
#    ['Heime',
#     'müssen',
#     'sparen',
#     ':',
#     'Die',
#     'Betreuung',
#     'der',
#     'Behinderten',
#     'leidet',
#     'massiv',
#     '.'],
#    ['Mit',
#     'anderen',
#     'Worten',
#     ':',
#     'Ein',
#     'Fünftel',
#     'der',
#     'Bevölkerung',
#     'leidet',
#     'Hunger',
#     '.'],
#    ['Vierzig',
#     'Jahre',
#     'lang',
#     'hat',
#     'der',
#     'Mann',
#     'Qualen',
#     'gelitten',
#     '.'],
#    ['Auch',
#     'wir',
#     'dürfen',
#     'an',
#     'Menschen',
#     ',',
#     'die',
#     'Not',
#     'leiden',
#     ',',
#     'nicht',
#     'vorbeigehen',
#     '.'],
#    [')',
#     'ganz',
#     'alte',
#     'Leute',
#     ',',
#     'deren',
#     'Lebensschifflein',
#     'wahrscheinlich',
#     'mehrmals',
#     'Schiffbruch',
#     'gelitten',
#     'hat',
#     ',',
#     'bevor',
#     'es',
#     'im',
#     'Hafen',
#     'von',
#     'Kappel',
#     'einlief',
#     '(',
#     '.'],
#    ['Ich',
#     'bin',
#     '36',
#     'Jahre',
#     'alt',
#     'und',
#     'leide',
#     'seit',
#     'meiner',
#     'Kindheit',
#     'an',
#     'Depressionen',
#     'und',
#     'Zwängen',
#     '.'],
#    ['Parlamentarier',
#     'leiden',
#     'unter',
#     'Stress',
#     'und',
#     'Bewegungsmangel',
#     '.'],
#    ['Die',
#     'Staatsbanken',
#     'leiden',
#     'nach',
#     'Ansicht',
#     'von',
#     'Chinaexperten',
#     'noch',
#     'immer',
#     'unter',
#     'Korruption',
#     'und',
#     'Missmanagement',
#     '.'],
#    ['Familien',
#     'litten',
#     'heute',
#     'unter',
#     'dem',
#     'modernen',
#     'Individualismus',
#     ',',
#     'dem',
#     'Trend',
#     'zur',
#     'Unverbindlichkeit',
#     'und',
#     'einem',
#     'fortschreitenden',
#     'Werteverlust',
#     ',',
#     'sagte',
#     'Christa',
#     'Leonhard',
#     'von',
#     'der',
#     'SSF',
#     '.'],
#    ['Viele',
#     'Menschen',
#     'leiden',
#     'heute',
#     'darunter',
#     ',',
#     'dass',
#     'sie',
#     'in',
#     'einer',
#     'globalisierten',
#     'Wirtschaft',
#     'nur',
#     'noch',
#     'als',
#     'Kostenfaktoren',
#     'wahrgenommen',
#     'werden',
#     '.'],
#    ['Zeuskes',
#     'Studie',
#     'leidet',
#     'darunter',
#     ',',
#     'dass',
#     'Autor',
#     'und',
#     'Lektorat',
#     'die',
#     'Stoffmenge',
#     'nicht',
#     'strafften',
#     'und',
#     'sinnvoll',
#     'strukturierten',
#     '.'],
#    ['Wie',
#     'andere',
#     'Gemeinden',
#     'leidet',
#     'Winterthur',
#     'zudem',
#     'daran',
#     ',',
#     'dass',
#     'es',
#     'keine',
#     'Erbschafts-',
#     'und',
#     'Handänderungssteuern',
#     'mehr',
#     'gibt',
#     'und',
#     'dass',
#     'Kanton',
#     'und',
#     'Bund',
#     'vermehrt',
#     'Aufgaben',
#     'auf',
#     'die',
#     'Gemeinden',
#     'übertragen',
#     '.'],
#    ['Aber',
#     'das',
#     'Land',
#     'leidet',
#     'darunter',
#     ',',
#     'dass',
#     'es',
#     'während',
#     'Jahrzehnten',
#     'von',
#     'Kleptokraten',
#     'regiert',
#     'wurde',
#     '.'],
#    ['Walser',
#     'leidet',
#     'darunter',
#     ',',
#     'als',
#     'Deutscher',
#     'unausweichlich',
#     'zu',
#     'den',
#     'Tätern',
#     'zu',
#     'gehören',
#     '.'],
#    ['Ich',
#     'habe',
#     'auch',
#     'miterlebt',
#     ',',
#     'wie',
#     'er',
#     'daran',
#     'litt',
#     ',',
#     'in',
#     'den',
#     '70er-Jahren',
#     'mit',
#     'seinen',
#     'Beschuldigungen',
#     'übermarcht',
#     'zu',
#     'haben',
#     '-',
#     'zum',
#     'Nachteil',
#     'auch',
#     'seiner',
#     'nächsten',
#     'Angehörigen',
#     '.'],
#    ['Aber',
#     'manchmal',
#     'leidet',
#     'Kuba',
#     'darunter',
#     ',',
#     'nur',
#     'aufs',
#     'politische',
#     'reduziert',
#     'zu',
#     'werden',
#     '.'],
#    ['Mitarbeiter',
#     'leiden',
#     'darunter',
#     ',',
#     'immer',
#     'erreichbar',
#     'zu',
#     'sein',
#     '.'],
#    ['Auch', 'Deutschland', 'profitiert', '.'],
#    ['Auch', 'die', 'Forschung', 'profitiert', '.'],
#    ['Telekom', 'Austria', 'profitiert', 'von', 'Sondereffekten', '.'],
#    ['Er',
#     'profitierte',
#     'davon',
#     ',',
#     'dass',
#     'auch',
#     'die',
#     'unmittelbare',
#     'Konkurrenz',
#     'suboptimal',
#     'spielte',
#     ',',
#     'und',
#     'entschied',
#     'letztlich',
#     'das',
#     'Play-off',
#     'gegen',
#     'die',
#     'Amerikaner',
#     'Justin',
#     'Leonard',
#     'und',
#     'Chris',
#     'DiMarco',
#     'dank',
#     'Birdie',
#     'am',
#     'ersten',
#     'Loch',
#     'für',
#     'sich',
#     '.'],
#    ['Die',
#     'Banken-Gruppe',
#     'profitierte',
#     'davon',
#     ',',
#     'dass',
#     'es',
#     'erheblich',
#     'weniger',
#     'zweifelhafte',
#     'Kredite',
#     'gibt',
#     'als',
#     'im',
#     'vergangenen',
#     'Jahr',
#     '.'],
#    ['Langfristig',
#     'profitiere',
#     'Zürich',
#     'trotzdem',
#     'davon',
#     ',',
#     'Finanzzentrum',
#     'zu',
#     'sein',
#     '.'],
#    ['Alle',
#     'anderen',
#     'profitieren',
#     'davon',
#     ',',
#     'sich',
#     'an',
#     'den',
#     'Verhandlungstisch',
#     'zu',
#     'setzen',
#     '.'],
#    ['Mehrere', 'Gestaltungspläne', 'scheiterten', '.'],
#    ['Doch',
#     'die',
#     'Religionsgründung',
#     'des',
#     'Philosophenkönigs',
#     'scheiterte',
#     ',',
#     'Echnaton',
#     'und',
#     'sein',
#     'Gott',
#     'verfielen',
#     'der',
#     '«',
#     'damnatio',
#     'memoriae',
#     '»',
#     '.'],
#    ['Dieser',
#     'scheiterte',
#     'am',
#     'italienischen',
#     'Qualifier',
#     'Potito',
#     'Starace',
#     ',',
#     'Grand-',
#     'Slam-Neuling',
#     'aus',
#     'dem',
#     '202',
#     '.'],
#    ['Der',
#     'Deal',
#     'scheiterte',
#     'aber',
#     'nur',
#     'schon',
#     'daran',
#     ',',
#     'dass',
#     'mehrere',
#     'SP-Nationalräte',
#     'in',
#     'der',
#     'entscheidenden',
#     'Abstimmung',
#     'fehlten',
#     '.'],
#    ['Die',
#     'drei',
#     'Künstler',
#     'auf',
#     'der',
#     'Bühne',
#     'scheitern',
#     'daran',
#     ',',
#     'Kunst',
#     'zu',
#     'machen',
#     ',',
#     'von',
#     'der',
#     'sie',
#     'auch',
#     'leben',
#     'können',
#     '.'],
#    ['Das',
#     'konservative',
#     'Lager',
#     'scheiterte',
#     'aber',
#     'damit',
#     ',',
#     'diese',
#     'Vorgabe',
#     'im',
#     'Gesetz',
#     'direkt',
#     'zu',
#     'verankern',
#     '.'],
#    ['Palästinenser', 'töten', 'israelischen', 'Offizier', '.'],
#    ['Ist',
#     'ein',
#     'Parasit',
#     'etwa',
#     'zu',
#     'virulent',
#     ',',
#     'so',
#     'tötet',
#     'er',
#     'seinen',
#     'Wirt',
#     ',',
#     'bevor',
#     'er',
#     'auf',
#     'den',
#     'nächsten',
#     'Wirt',
#     'überwechseln',
#     'kann',
#     '-',
#     'und',
#     'reduziert',
#     'damit',
#     'seinen',
#     'eigenen',
#     'Erfolg',
#     '.'],
#    ['Auch', 'seine', 'Fans', 'veräppelt', 'er', 'gern', '.'],
#    ['Labour-Aktivistin',
#     'Armstrong',
#     'veräppelt',
#     'den',
#     'vermissten',
#     'Abgeordneten',
#     '.'],
#    ['Wie',
#     'Konsument',
#     'Bönis',
#     'Frau',
#     'von',
#     'Ikea',
#     'veräppelt',
#     'wurde',
#     '.'],
#    ['Gegenüber',
#     'der',
#     'letzten',
#     'Befragung',
#     'haben',
#     'sich',
#     'die',
#     'Werte',
#     'leicht',
#     'verbessert',
#     '.'],
#    ['Audi', 'verbessert', 'sich', 'operativ', '.'],
#    ['Ich', 'habe', 'meinen', 'Start', 'weiter', 'verbessert', '.'],
#    ['Axel-Springer-Verlag', 'verbessert', 'Ertragskraft', '.'],
#    ['Dennoch',
#     'verletzt',
#     'Deutschland',
#     'seither',
#     'die',
#     'Schallgrenze',
#     'Jahr',
#     'für',
#     'Jahr',
#     '.'],
#    ['«', 'Das', 'Projekt', 'verletzt', 'raumplanerische', 'Grundsätze', '.'],
#    ['Die', 'Polizistin', 'kam', 'zu', 'Fall', 'und', 'verletzte', 'sich', '.'],
#    ['In',
#     'dieser',
#     'Phase',
#     'verletzte',
#     'sich',
#     'der',
#     'Südamerikaner',
#     'an',
#     'der',
#     'Bauchmuskulatur',
#     '.'],
#    ['Haymon',
#     'verletzte',
#     'den',
#     'Thyrsus',
#     'an',
#     'der',
#     'Ferse',
#     ',',
#     'und',
#     'der',
#     'flüchtete',
#     'sich',
#     'ins',
#     'Karwendel',
#     '.'],
#    ['Denn',
#     'weil',
#     'ihm',
#     'ein',
#     'Unihockey-Schläger',
#     'einst',
#     'die',
#     'Nase',
#     'verletzte',
#     ',',
#     'schläft',
#     'Granit',
#     'etwas',
#     'unruhig',
#     '.'],
#    ['Während',
#     'einer',
#     'einzigen',
#     'Woche',
#     'habe',
#     'ich',
#     'es',
#     'geschafft',
#     ',',
#     'mir',
#     'sämtliche',
#     'Extremitäten',
#     'zu',
#     'verletzen',
#     '.'],
#    ['Dennoch',
#     'verurteile',
#     'Martin',
#     'Graf',
#     'klar',
#     ',',
#     'dass',
#     'die',
#     'Bilder',
#     'an',
#     'die',
#     'Medien',
#     'gelangt',
#     'seien',
#     '.'],
#    ['Scharf',
#     'verurteilte',
#     'Leuenberger',
#     ',',
#     'dass',
#     'das',
#     'Parlament',
#     'gegen',
#     'den',
#     'Willen',
#     'der',
#     'Landesregierung',
#     'und',
#     'auf',
#     'demokratiepolitisch',
#     'fragwürdige',
#     'Weise',
#     'den',
#     'Alpenschutzartikel',
#     'gelockert',
#     'habe',
#     '.'],
#    ['FDP-Fraktionspräsidentin',
#     'Gabi',
#     'Huber',
#     'verurteilte',
#     ',',
#     'wie',
#     'die',
#     'USA',
#     'das',
#     'Prinzip',
#     'Macht',
#     'vor',
#     'Recht',
#     'gesetzt',
#     'hätten',
#     '.'],
#    ['Abtreibungsgegner',
#     'verurteilten',
#     'die',
#     'Schaffung',
#     'der',
#     'Bank',
#     'und',
#     'bezeichneten',
#     'diese',
#     'als',
#     'eine',
#     'Lagerstätte',
#     'für',
#     'tote',
#     'Säuglinge',
#     '.'],
#    ['Bagdad', 'verurteilt', 'die', 'Anschläge', 'auf', 'Kirchen', '.'],
#    ['«',
#     'Ich',
#     'habe',
#     'sie',
#     'dafür',
#     'verurteilt',
#     ',',
#     'dass',
#     'sie',
#     'so',
#     'einen',
#     'Ort',
#     'aufsuchten',
#     '.'],
#    ['Das',
#     'Gericht',
#     'verurteilte',
#     'die',
#     'Schweiz',
#     ',',
#     'dem',
#     'Vater',
#     'eine',
#     'Genugtuung',
#     'von',
#     '15',
#     '000',
#     'Euro',
#     'zu',
#     'zahlen',
#     '.'],
#    ['Die',
#     'Schweiz',
#     'wurde',
#     'verurteilt',
#     ',',
#     'dem',
#     'Mann',
#     '3000',
#     'Euro',
#     'Genugtuung',
#     'und',
#     '4650',
#     'Euro',
#     'für',
#     'seine',
#     'Auslagen',
#     'zu',
#     'zahlen',
#     '.'],
#    ['Er',
#     'wurde',
#     'verurteilt',
#     ',',
#     'die',
#     'Jungen',
#     'in',
#     'sechs',
#     'Fällen',
#     'unsittlich',
#     'berührt',
#     'zu',
#     'haben',
#     '.'],
#    ['Graf',
#     'verurteile',
#     'es',
#     ',',
#     'dass',
#     'die',
#     'Bilder',
#     'den',
#     'Medien',
#     'zugespielt',
#     'worden',
#     'seien',
#     ',',
#     'und',
#     'sei',
#     'froh',
#     ',',
#     'dass',
#     'die',
#     'Staatsanwaltschaft',
#     'die',
#     'Sache',
#     'untersuche',
#     ',',
#     'lässt',
#     'Tommer',
#     'noch',
#     'ausrichten',
#     '.'],
#    ['Die',
#     'Exekutive',
#     'verzichtete',
#     'damals',
#     'weitsichtig',
#     ',',
#     'dies',
#     'vorzuschlagen',
#     '.'],
#    ['Der',
#     'Bundesrat',
#     'verzichtet',
#     'deshalb',
#     'auf',
#     'eine',
#     'Teilrevision',
#     'des',
#     'Lotteriegesetzes',
#     '.'],
#    ['Auch',
#     'hier',
#     'verzichtet',
#     'man',
#     'nicht',
#     'auf',
#     'den',
#     'Einstiegsschliff',
#     ',',
#     'obwohl',
#     'nicht',
#     'von',
#     'der',
#     'Universität',
#     'rekrutiert',
#     'wird',
#     ',',
#     'sondern',
#     'Leute',
#     'mit',
#     'Erfahrung',
#     'aus',
#     'den',
#     'Unternehmen',
#     'eingestellt',
#     'werden',
#     '.'],
#    ['Im',
#     'Gegenzug',
#     'verlangt',
#     'Nordkorea',
#     ',',
#     'dass',
#     'Darusman',
#     'darauf',
#     'verzichtet',
#     ',',
#     'dass',
#     'der',
#     'Bericht',
#     'der',
#     'Untersuchungskommission',
#     'an',
#     'den',
#     'ICC',
#     'weitergeleitet',
#     'wird',
#     '.'],
#    ['Sie',
#     'verzichtet',
#     'vorläufig',
#     'darauf',
#     ',',
#     'den',
#     'Damm',
#     'weiter',
#     'aufzustocken',
#     '.'],
#    ['Dennoch',
#     'habe',
#     'Bush',
#     'nicht',
#     'darauf',
#     'verzichtet',
#     ',',
#     'seine',
#     'wöchentliche',
#     'Radioansprache',
#     'aufzunehmen',
#     '.'],
#    ['Noch',
#     'im',
#     'letzten',
#     'Juni',
#     ',',
#     'als',
#     '2000',
#     'Männer',
#     'des',
#     'dissidenten',
#     'Colonel',
#     'Laurent',
#     'Nkunda',
#     'für',
#     'eine',
#     'Woche',
#     'Bukavu',
#     'besetzten',
#     ',',
#     'verzichteten',
#     'diese',
#     'nicht',
#     'darauf',
#     ',',
#     'die',
#     'Station',
#     'von',
#     'Tshivanga',
#     'zu',
#     'plündern',
#     '.'],
#    ['Zugleich',
#     'hat',
#     'das',
#     'CBoT',
#     'seine',
#     'Produktpalette',
#     'ausgebaut',
#     '.'],
#    ['In',
#     'Namibia',
#     'wird',
#     'die',
#     'maritime',
#     'Diamantenförderung',
#     'ausgebaut',
#     '.'],
#    ['Mit',
#     'viel',
#     'Geschick',
#     'hat',
#     'die',
#     'Unternehmerin',
#     'Giovanna',
#     'Furlanetto',
#     'die',
#     'italienische',
#     'Firma',
#     'Furla',
#     'zur',
#     'internationalen',
#     'Marke',
#     'ausgebaut',
#     '.'],
#    ['Ihr',
#     'Mobil',
#     'lässt',
#     'sich',
#     'aus',
#     'diesem',
#     'Grund',
#     'zu',
#     'einer',
#     'riesigen',
#     'Stehbar',
#     'ausbauen',
#     '.'],
#    ['Die',
#     'Tatsache',
#     ',',
#     'dass',
#     'Google',
#     'ausbaut',
#     ',',
#     'zeigt',
#     'die',
#     'hohe',
#     'Standortattraktivität',
#     'von',
#     'Stadt',
#     'und',
#     '\xad',
#     'Kanton',
#     'Zürich',
#     '.'],
#    ['Spielbankenkommission', 'bekämpft', 'illegale', 'Glücksspiele', '.'],
#    ['Befürworter',
#     'und',
#     'Gegner',
#     'einer',
#     'Koalition',
#     'mit',
#     'der',
#     'PDS',
#     'hielten',
#     'sich',
#     'die',
#     'Waage',
#     'und',
#     'bekämpften',
#     'ihre',
#     'innerparteilichen',
#     'Widersacher',
#     'hingebungsvoller',
#     'als',
#     'den',
#     'politischen',
#     'Gegner',
#     '.'],
#    ['Dazwischen',
#     'gilt',
#     'es',
#     ',',
#     'einen',
#     'plötzlichen',
#     'Brandausbruch',
#     'mit',
#     'enormer',
#     'Rauchentwicklung',
#     'zu',
#     'bekämpfen',
#     '.'],
#    ['Durch',
#     'steuerliche',
#     'Entlastungen',
#     'für',
#     'einkommensschwache',
#     'Familien',
#     'sowie',
#     'die',
#     'Einführung',
#     'der',
#     'Mutterschaftsversicherung',
#     'könnte',
#     'die',
#     'Armut',
#     'bei',
#     'den',
#     'Ursachen',
#     'bekämpft',
#     'werden',
#     '.'],
#    ['Hat', 'Ihnen', 'diese', 'Pause', 'sogar', 'geholfen', '?'],
#    ['Markus',
#     'hatte',
#     'Glück',
#     'im',
#     'Unglück',
#     ':',
#     'Seine',
#     'Eltern',
#     'halfen',
#     'ihm',
#     'aus',
#     'der',
#     'Patsche',
#     '.'],
#    ['Bewährung', 'hilft', 'vielfach', 'mehr', '.'],
#    ['Sein',
#     'Streben',
#     'nach',
#     'Perfektion',
#     'wurde',
#     'in',
#     'der',
#     'Werkstatt',
#     'des',
#     'Ausbildners',
#     'angestachelt',
#     ',',
#     'wo',
#     'er',
#     'bei',
#     'der',
#     'Herstellung',
#     'von',
#     'Heliogravüren',
#     'für',
#     'Portfolios',
#     'der',
#     'Fotoklassiker',
#     'Edward',
#     'Steichen',
#     'und',
#     'Paul',
#     'Strand',
#     'half',
#     '.'],
#    ['Charrouf',
#     'half',
#     'den',
#     'Frauen',
#     'dieser',
#     'Gegend',
#     ',',
#     'Kooperativen',
#     'zu',
#     'gründen',
#     ',',
#     'und',
#     'regte',
#     'ein',
#     'zeitgemässes',
#     'Marketing',
#     'an',
#     '.'],
#    ['Bücher',
#     'von',
#     'anderen',
#     'Betroffenen',
#     'können',
#     'helfen',
#     'zu',
#     'verstehen',
#     '.'],
#    ['Kanton', 'hilft', 'auch', ',', 'Weiher', 'zu', 'erhalten', '.'],
#    ['Auch',
#     'ihnen',
#     'war',
#     'nicht',
#     'entgangen',
#     ',',
#     'wie',
#     'sie',
#     'gekämpft',
#     'und',
#     'alles',
#     'gegeben',
#     'hatte',
#     '.'],
#    ['Johann',
#     'Vogel',
#     'hatte',
#     'kurz',
#     'nach',
#     'der',
#     'Pause',
#     'die',
#     'gelb-rote',
#     'Karte',
#     'gesehen',
#     ',',
#     'aber',
#     'ohne',
#     'den',
#     'bis',
#     'anhin',
#     'Besten',
#     'waren',
#     'die',
#     'Schweizer',
#     'viel',
#     'besser',
#     ',',
#     'sie',
#     'rückten',
#     'näher',
#     'zusammen',
#     ',',
#     'sie',
#     'waren',
#     'in',
#     'Unterzahl',
#     'gut',
#     'organisiert',
#     ',',
#     'sie',
#     'rannten',
#     'und',
#     'kämpften',
#     ',',
#     'wehrten',
#     'sich',
#     'verzweifelt',
#     ',',
#     'suchten',
#     'aber',
#     'auch',
#     'ihre',
#     'Möglichkeiten',
#     'nach',
#     'vorne',
#     '.'],
#    ['Ihr',
#     'wart',
#     'eine',
#     'Einheit',
#     ',',
#     'die',
#     'sich',
#     'tapfer',
#     'und',
#     'furchtlos',
#     'der',
#     'Übermacht',
#     'der',
#     'Holländer',
#     ',',
#     'Letten',
#     'und',
#     'B-Tschechen',
#     'stellte',
#     ',',
#     'ihr',
#     'habt',
#     'gekämpft',
#     'und',
#     'seid',
#     'so',
#     'schön',
#     'und',
#     'in',
#     'Ehren',
#     'untergegangen',
#     ',',
#     'dass',
#     'euch',
#     'von',
#     'all',
#     'den',
#     'Experten',
#     'von',
#     'ARD',
#     ',',
#     'ZDF',
#     'und',
#     'DSF',
#     'eigentlich',
#     'gar',
#     'niemand',
#     'böse',
#     'sein',
#     'konnte',
#     '.'],
#    ['Die',
#     'Stimmung',
#     'im',
#     'Bundesrat',
#     'ist',
#     'nicht',
#     'wesentlich',
#     'anders',
#     'als',
#     'in',
#     'den',
#     'Verwaltungsräten',
#     ',',
#     'in',
#     'denen',
#     'ich',
#     'früher',
#     'mitwirkte',
#     ':',
#     'Man',
#     'kämpft',
#     'engagiert',
#     '.'],
#    ['«',
#     'Er',
#     'läuft',
#     'viel',
#     ',',
#     'er',
#     'kämpft',
#     ',',
#     'er',
#     'ist',
#     'torgefährlich',
#     'und',
#     'voller',
#     'Energie',
#     '»',
#     ',',
#     'sagt',
#     'Trainer',
#     'Geiger',
#     'über',
#     'Spieler',
#     'Chihab',
#     '.'],
#    ['Als',
#     'Feministin',
#     'musste',
#     'frau',
#     'auch',
#     'um',
#     'die',
#     'Gleichstellungspolitik',
#     'kämpfen',
#     '.'],
#    ['Nirgendwo',
#     'kämpfen',
#     'Bush',
#     'und',
#     'Kerry',
#     'heftiger',
#     'um',
#     'die',
#     'Gunst',
#     'der',
#     'Wähler',
#     'als',
#     'in',
#     'Ohio',
#     '.'],
#    ['Und',
#     'er',
#     'wird',
#     'davon',
#     'profitieren',
#     'können',
#     ',',
#     'dass',
#     'alle',
#     ',',
#     'die',
#     'in',
#     'den',
#     'ersten',
#     'zehn',
#     'klassiert',
#     'sind',
#     ',',
#     'um',
#     'ihre',
#     'Positionen',
#     'kämpfen',
#     'werden',
#     '.'],
#    ['Seit',
#     '59',
#     'Jahren',
#     'kämpften',
#     'die',
#     'Frauen',
#     'für',
#     'die',
#     'Umsetzung',
#     'des',
#     'entsprechenden',
#     'Verfassungsauftrags',
#     '.'],
#    ['«',
#     'Wir',
#     'haben',
#     'nicht',
#     'Jahrzehnte',
#     'für',
#     'kürzere',
#     'Arbeitszeiten',
#     'gekämpft',
#     ',',
#     'um',
#     'diese',
#     'Errungenschaft',
#     'nun',
#     'an',
#     'die',
#     'Arbeitgeber',
#     'zu',
#     'verschenken',
#     '»',
#     ',',
#     'gab',
#     'sich',
#     'Renzo',
#     'Ambrosetti',
#     'von',
#     'der',
#     'Gewerkschaft',
#     'Smuv',
#     'kämpferisch',
#     '.'],
#    ['Frauen', 'kämpfen', 'gemeinsam', 'für', 'Mütter-Urlaub', '.'],
#    ['Ryanair',
#     'steht',
#     'an',
#     'der',
#     'Börse',
#     'zwar',
#     'besser',
#     'da',
#     ',',
#     'aber',
#     'auch',
#     'die',
#     'Iren',
#     'kämpfen',
#     'mit',
#     'sinkenden',
#     'Margen',
#     ',',
#     'verlangsamtem',
#     'Wachstum',
#     'und',
#     'gestiegenen',
#     'Kosten',
#     '.'],
#    ['Seit',
#     'Bossi',
#     'aber',
#     'mit',
#     'seinem',
#     'schwachen',
#     'Herz',
#     'kämpfte',
#     ',',
#     'entglitt',
#     'dem',
#     'ungelehrigen',
#     'König',
#     'das',
#     'Spiel',
#     'zusehends',
#     '.'],
#    ['Dilettantisch',
#     ',',
#     'überfordert',
#     ',',
#     'schlecht',
#     'ausgebildet',
#     ':',
#     'Die',
#     'Schulpflege',
#     'kämpft',
#     'mit',
#     'einem',
#     'Imageproblem',
#     '-',
#     'nicht',
#     'erst',
#     'seit',
#     'dem',
#     'Selbstmord',
#     'des',
#     'Affoltemer',
#     'Primarlehrers',
#     '.'],
#    ['Bauern', 'kämpfen', 'gegen', 'Autolobby', '.'],
#    ['-',
#     'Hunderte',
#     'Feuerwehrleute',
#     'haben',
#     'am',
#     'Montag',
#     'gegen',
#     'Waldbrände',
#     'in',
#     'Südeuropa',
#     'gekämpft',
#     '.'],
#    ['Ich',
#     'kämpfe',
#     'seit',
#     'Jahren',
#     'dafür',
#     ',',
#     'dass',
#     'man',
#     'in',
#     'der',
#     'Schweiz',
#     'mit',
#     'dem',
#     'Preisniveau',
#     'runtergeht',
#     '.'],
#    ['Sie',
#     'haben',
#     'vehement',
#     'dagegen',
#     'gekämpft',
#     ',',
#     'dass',
#     'das',
#     'Personal',
#     'bis',
#     '1',
#     'Uhr',
#     'nachts',
#     'eingesetzt',
#     'werden',
#     'darf',
#     '.'],
#    ['Nun',
#     'kämpft',
#     'Lembergs',
#     'dagegen',
#     ',',
#     'dass',
#     'die',
#     'lettische',
#     'Staatsanwaltschaft',
#     'die',
#     'Schweiz',
#     'um',
#     'Rechtshilfe',
#     'bittet',
#     '.'],
#    ['«',
#     'Jede',
#     'Partei',
#     'kämpft',
#     'doch',
#     'darum',
#     ',',
#     'in',
#     'der',
#     'Regierung',
#     'vertreten',
#     'zu',
#     'sein',
#     ',',
#     'damit',
#     'sie',
#     'dort',
#     'ihre',
#     'Meinung',
#     'einbringen',
#     'kann',
#     '.',
#     '»',
#     'Sich',
#     'nach',
#     'Amtsantritt',
#     'von',
#     'der',
#     'Partei',
#     'lösen',
#     'zu',
#     'wollen',
#     ',',
#     'zeuge',
#     'von',
#     'einem',
#     'weltfremden',
#     'Politikverständnis',
#     '.'],
#    ['Die',
#     'bisher',
#     'dominierenden',
#     'Gruppen',
#     'der',
#     'religiösen',
#     'Schiiten',
#     'und',
#     'Kurden',
#     'werden',
#     'aber',
#     'darum',
#     'kämpfen',
#     ',',
#     'möglichst',
#     'viel',
#     'von',
#     'ihrem',
#     'Einfluss',
#     'zu',
#     'retten',
#     '.'],
#    ['Im',
# ...
#    ['Die',
#     'Regierung',
#     'verteidigte',
#     'sich',
#     'mit',
#     'Haushaltüberlegungen',
#     '.'],
#    ['Auf',
#     'den',
#     'reifen',
#     'Märkten',
#     'verteidigt',
#     'die',
#     'Firma',
#     'ihre',
#     'Stellung',
#     'mit',
#     'Innovationen',
#     '.'],
#    ['Die',
#     'Behörden',
#     'selbst',
#     'allerdings',
#     'mussten',
#     'sich',
#     'am',
#     'Mittwoch',
#     'gegen',
#     'den',
#     'Vorwurf',
#     'der',
#     'Inkompetenz',
#     'verteidigen',
#     '.'],
#    ['Rahner',
#     'bleibt',
#     'an',
#     'diesem',
#     'Punkt',
#     'unklar',
#     ',',
#     'verteidigt',
#     'aber',
#     'die',
#     'menschliche',
#     'Freiheit',
#     'gegen',
#     'reduktionistische',
#     'Anthropologien',
#     '.'],
#    ['Geringste',
#     'Leitungsengpässe',
#     ',',
#     'entstanden',
#     'durch',
#     'nicht',
#     'realisierte',
#     'Investitionen',
#     ',',
#     'verschlechtern',
#     'die',
#     'Stromqualität',
#     '.'],
#    ['Eine',
#     'Verwahrung',
#     'würde',
#     'die',
#     'Prognose',
#     'für',
#     'den',
#     'Angeklagten',
#     'verschlechtern',
#     '.'],
#    ['Die',
#     'Maturitätsreform',
#     'hat',
#     'diese',
#     'Situation',
#     'weiter',
#     'verschlechtert',
#     '.'],
#    ['Die',
#     'Geschäftslage',
#     'des',
#     'hoch',
#     'verschuldeten',
#     'Kanaltunnel-Betreibers',
#     'Eurotunnel',
#     'hat',
#     'sich',
#     'weiter',
#     'verschlechtert',
#     '.'],
#    ['Der',
#     'Bau',
#     'der',
#     'ersten',
#     'Wohnungen',
#     'verläuft',
#     'schleppend',
#     ',',
#     'da',
#     'die',
#     'Wirtschaftslage',
#     'sich',
#     'verschlechtert',
#     'hat',
#     'und',
#     'der',
#     'Wohnungsmarkt',
#     'seit',
#     'einiger',
#     'Zeit',
#     'stagniert',
#     '.'],
#    ['Für',
#     'die',
#     'betroffene',
#     'Bevölkerung',
#     'habe',
#     'sich',
#     'Lebensqualität',
#     'infolge',
#     'der',
#     'zunehmenden',
#     'Lärm-',
#     'und',
#     'Abgasbelastung',
#     'erheblich',
#     'verschlechtert',
#     '.'],
#    ['Offenbar',
#     'ist',
#     'Quattrones',
#     'Ehefrau',
#     'seit',
#     'einigen',
#     'Jahren',
#     'krank',
#     ',',
#     'und',
#     'ihr',
#     'Zustand',
#     'verschlechtere',
#     'sich',
#     'wegen',
#     'des',
#     'Prozesses',
#     'weiter',
#     '.'],
#    ['Die',
#     'fiskalpolitische',
#     'Disziplin',
#     'verschlechterte',
#     'sich',
#     'um',
#     '4',
#     '%',
#     'des',
#     'BIP',
#     '.'],
#    ['Für',
#     'viele',
#     'verschlechterte',
#     'sich',
#     'die',
#     'ohnehin',
#     'schwache',
#     'Jahresperformance',
#     'nochmals',
#     '.'],
#    ['Durch',
#     'die',
#     'Ausgliederung',
#     'der',
#     'Spedition',
#     'der',
#     'Bruno',
#     'Piatti',
#     'werden',
#     'die',
#     'Arbeitsbedingungen',
#     'laut',
#     'Gewerkschaftsangaben',
#     'deutlich',
#     'verschlechtert',
#     '.'],
#    ['Die',
#     'Rekurrenten',
#     'bemängeln',
#     'die',
#     'Anzahl',
#     'der',
#     'Parkplätze',
#     'und',
#     'das',
#     'Fehlen',
#     'einer',
#     'Umweltverträglichkeitsprüfung',
#     '.'],
#    ['\n']],
#   [[('p', '3', '7'), ('c', '11', '13')],
#    [('c', '1', '8'), ('c', '14', '17')],
#    [('c', '2', '6')],
#    [('c', '3', '16'), ('c', '16', '30')],
#    [('c', '7', '21'), ('p', '7', '13')],
#    [('c', '1', '6')],
#    [('p', '14', '17')],
#    [('c', '2', '8')],
#    [],
#    [('p', '1', '8')],
#    [('c', '3', '6'), ('p', '6', '10')],
#    [],
#    [('c', '4', '7')],
#    [],
#    [('p', '13', '2'), ('p', '13', '10')],
#    [('c', '1', '6'), ('c', '1', '14')],
#    [('c', '13', '7')],
#    [],
#    [('c', '6', '3')],
#    [],
#    [('p', '3', '8'), ('p', '3', '11')],
#    [('c', '2', '15'), ('c', '2', '18')],
#    [('p', '2', '7'), ('p', '2', '14')],
#    [],
#    [],
#    [('c', '5', '7')],
#    [],
#    [('c', '3', '8')],
#    [('c', '4', '6')],
#    [('c', '1', '7')],
#    [],
#    [],
#    [],
#    [('p', '20', '14')],
#    [('c', '5', '7')],
#    [('c', '2', '11')],
#    [('c', '3', '8')],
#    [('c', '8', '13')],
#    [('p', '1', '5'), ('p', '1', '9')],
#    [('c', '4', '8'), ('c', '10', '11')],
#    [],
#    [],
#    [('p', '1', '6')],
#    [('c', '1', '5')],
#    [('p', '2', '7')],
#    [],
#    [('p', '7', '10')],
#    [('p', '2', '7')],
#    [('p', '3', '5'), ('p', '7', '8')],
#    [],
#    [('c', '2', '4')],
#    [('c', '1', '4')],
#    [('c', '1', '3')],
#    [('c', '1', '3')],
#    [('c', '1', '4'), ('c', '1', '6')],
#    [('c', '1', '8'), ('p', '1', '14')],
#    [],
#    [],
#    [('c', '3', '7'), ('p', '3', '15')],
#    [('c', '2', '7')],
#    [('c', '1', '7'), ('c', '3', '7'), ('c', '5', '16'), ('p', '5', '22')],
#    [('c', '4', '7')],
#    [('p', '8', '2'), ('c', '26', '2'), ('c', '30', '35'), ('c', '30', '38')],
#    [('c', '26', '3'),
#     ('c', '28', '3'),
#     ('c', '32', '3'),
#     ('c', '3', '9'),
#     ('c', '26', '9'),
#     ('c', '28', '9'),
#     ('c', '32', '9')],
#    [('c', '2', '12'), ('c', '2', '18'), ('c', '2', '22')],
#    [('p', '10', '14')],
#    [],
#    [],
#    [],
#    [],
#    [('c', '16', '2'), ('c', '16', '6'), ('p', '16', '13')],
#    [('c', '17', '3'),
#     ('c', '17', '5'),
#     ('p', '17', '15'),
#     ('c', '15', '3'),
#     ('c', '15', '5')],
#    [('c', '2', '7')],
#    [('c', '3', '8')],
#    [('p', '6', '14'),
#     ('c', '19', '10'),
#     ('c', '17', '10'),
#     ('c', '19', '6'),
#     ('c', '17', '6')],
#    [],
#    [],
#    [('p', '25', '29')],
#    [],
#    [],
#    [('p', '8', '1'), ('p', '8', '3')],
#    [('p', '9', '2')],
#    [('p', '14', '4'), ('p', '18', '20'), ('p', '18', '24')],
#    [('p', '8', '1')],
#    [('p', '1', '7')],
#    [('c', '2', '7'), ('c', '2', '11'), ('c', '2', '23')],
#    [('c', '2', '7')],
#    [('c', '4', '6'), ('c', '4', '9')],
#    [],
#    [('c', '2', '11'),
#     ('c', '2', '13'),
#     ('p', '2', '19'),
#     ('c', '15', '19'),
#     ('c', '11', '19'),
#     ('c', '13', '19')],
#    [('c', '3', '8'), ('c', '8', '14'), ('c', '8', '16'), ('c', '8', '22')],
#    [('c', '2', '5')],
#    [('c', '2', '4'),
#     ('p', '4', '7'),
#     ('p', '4', '9'),
#     ('c', '2', '7'),
#     ('c', '2', '9')],
#    [('c', '2', '7'),
#     ('c', '4', '7'),
#     ('p', '7', '21'),
#     ('c', '2', '21'),
#     ('c', '4', '21')],
#    [('c', '2', '4')],
#    [('c', '3', '13'),
#     ('p', '13', '17'),
#     ('c', '13', '21'),
#     ('c', '19', '21'),
#     ('p', '3', '21'),
#     ('c', '3', '19')],
#    [('c', '3', '5'), ('c', '9', '13'), ('c', '9', '15'), ('c', '9', '22')],
#    [('p', '1', '3'), ('p', '1', '5')],
#    [('p', '2', '4')],
#    [('p', '2', '4'), ('p', '2', '7')],
#    [('p', '1', '4'), ('p', '1', '6')],
#    [('p', '1', '4'), ('c', '1', '6')],
#    [('p', '8', '10')],
#    [],
#    [('c', '1', '3')],
#    [],
#    [],
#    [('p', '6', '8'), ('p', '6', '11')],
#    [],
#    [],
#    [],
#    [],
#    [('p', '2', '7')],
#    [('p', '6', '2')],
#    [],
#    [('p', '7', '8')],
#    [('p', '2', '4')],
#    [('p', '11', '28'), ('p', '11', '31')],
#    [('p', '6', '9'), ('p', '1', '6'), ('p', '1', '9')],
#    [('p', '3', '8')],
#    [('p', '1', '5'), ('p', '3', '5')],
#    [('c', '2', '7')],
#    [('p', '1', '5'), ('p', '1', '7')],
#    [],
#    [],
#    [('p', '6', '3')],
#    [('p', '2', '6')],
#    [],
#    [('p', '1', '16')],
#    [],
#    [('c', '16', '22'), ('c', '6', '2')],
#    [],
#    [],
#    [('c', '6', '10'), ('c', '8', '10')],
#    [('c', '6', '7')],
#    [('c', '7', '8')],
#    [('c', '7', '10')],
#    [('c', '1', '12'), ('c', '1', '14')],
#    [('c', '1', '4'), ('c', '1', '6')],
#    [('c', '2', '11'), ('c', '2', '13')],
#    [('c', '1', '7'), ('c', '1', '10'), ('c', '1', '12'), ('c', '1', '16')],
#    [('c', '2', '12')],
#    [('c', '2', '7'), ('c', '2', '9')],
#    [('c', '5', '19'), ('c', '5', '21')],
#    [('c', '3', '12')],
#    [('c', '1', '10')],
#    [('c', '7', '16'), ('c', '7', '26'), ('c', '16', '26')],
#    [],
#    [],
#    [],
#    [],
#    [('p', '1', '5')],
#    [('p', '27', '1')],
#    [],
#    [('p', '3', '7')],
#    [],
#    [],
#    [('p', '5', '3'), ('c', '15', '8'), ('c', '15', '11')],
#    [('c', '5', '1')],
#    [],
#    [],
#    [],
#    [('c', '1', '4')],
#    [('c', '10', '12'), ('c', '10', '28')],
#    [('p', '3', '5'), ('c', '5', '3')],
#    [('c', '1', '6')],
#    [('c', '6', '4')],
#    [],
#    [],
#    [('p', '1', '4')],
#    [('p', '1', '3')],
#    [('c', '3', '6')],
#    [('c', '3', '6')],
#    [],
#    [],
#    [],
#    [('c', '5', '8'), ('c', '5', '12')],
#    [],
#    [],
#    [('c', '3', '7'),
#     ('c', '7', '12'),
#     ('c', '7', '19'),
#     ('p', '3', '19'),
#     ('p', '12', '19')],
#    [('c', '1', '8'), ('c', '1', '10')],
#    [('c', '1', '4'), ('c', '1', '6')],
#    [('c', '1', '4'), ('p', '1', '6'), ('c', '4', '6')],
#    [('c', '2', '4'), ('c', '2', '12'), ('p', '4', '12')],
#    [('c', '2', '5'), ('p', '2', '8')],
#    [],
#    [],
#    [('c', '1', '3'), ('p', '1', '20')],
#    [],
#    [],
#    [],
#    [('c', '4', '18')],
#    [],
#    [],
#    [('c', '8', '17'), ('c', '11', '17'), ('c', '21', '26'), ('c', '21', '28')],
#    [],
#    [],
#    [('p', '6', '11')],
#    [],
#    [('p', '5', '13'), ('p', '5', '16'), ('p', '5', '17')],
#    [('c', '1', '4')],
#    [('p', '1', '5'),
#     ('c', '3', '5'),
#     ('p', '1', '8'),
#     ('c', '3', '8'),
#     ('c', '1', '17'),
#     ('c', '3', '17')],
#    [],
#    [('p', '3', '6'), ('c', '3', '14'), ('c', '9', '14'), ('c', '11', '14')],
#    [],
#    [('p', '8', '1')],
#    [],
#    [('p', '14', '17'),
#     ('p', '14', '19'),
#     ('p', '14', '23'),
#     ('p', '14', '25'),
#     ('p', '14', '28'),
#     ('p', '2', '4')],
#    [('p', '1', '4'), ('p', '1', '8'), ('p', '1', '16')],
#    [],
#    [('p', '1', '5')],
#    [],
#    [('c', '21', '18')],
#    [('c', '6', '12'), ('c', '6', '14'), ('c', '6', '16'), ('c', '6', '18')],
#    [('c', '16', '15')],
#    [('p', '18', '21')],
#    [],
#    [('c', '3', '5'), ('c', '5', '3')],
#    [],
#    [('p', '6', '9'), ('p', '6', '12')],
#    [('c', '24', '17'), ('c', '28', '17'), ('p', '2', '8')],
#    [('p', '1', '5')],
#    [('c', '13', '17'), ('p', '13', '20'), ('c', '13', '23')],
#    [('c', '2', '7')],
#    [('c', '9', '13')],
#    [('c', '1', '4')],
#    [('c', '3', '8'), ('c', '8', '10')],
#    [('c', '1', '14')],
#    [('p', '1', '9')],
#    [('c', '3', '9')],
#    [('p', '3', '10')],
#    [('p', '4', '19')],
#    [('p', '9', '15')],
#    [('p', '4', '10')],
#    [('p', '2', '14')],
#    [('c', '2', '11'), ('c', '4', '11')],
#    [('c', '1', '9')],
#    [('c', '5', '1'), ('c', '7', '1'), ('p', '9', '26')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('p', '2', '8')],
#    [('c', '3', '10')],
#    [('c', '1', '7'), ('c', '4', '7')],
#    [('c', '2', '7'), ('c', '4', '7'), ('c', '2', '9'), ('c', '4', '9')],
#    [('c', '1', '4'),
#     ('c', '1', '7'),
#     ('p', '1', '9'),
#     ('c', '1', '12'),
#     ('c', '12', '9'),
#     ('c', '4', '9')],
#    [('c', '1', '4'), ('c', '1', '8'), ('c', '1', '16')],
#    [('c', '1', '4'), ('c', '1', '8'), ('p', '4', '8')],
#    [('c', '13', '11'),
#     ('c', '13', '16'),
#     ('p', '13', '19'),
#     ('c', '11', '19'),
#     ('p', '11', '16')],
#    [('c', '3', '6'),
#     ('c', '3', '9'),
#     ('c', '3', '14'),
#     ('p', '6', '14'),
#     ('p', '9', '14')],
#    [('c', '4', '6'), ('c', '4', '8'), ('c', '4', '10')],
#    [('c', '2', '11'), ('p', '2', '9')],
#    [('c', '1', '9'), ('c', '1', '14')],
#    [('c', '1', '6'), ('c', '1', '21'), ('c', '1', '23')],
#    [('c', '2', '10')],
#    [('c', '1', '6')],
#    [('c', '2', '8')],
#    [('c', '1', '3')],
#    [('c', '1', '7')],
#    [('p', '3', '7'),
#     ('p', '3', '9'),
#     ('c', '13', '7'),
#     ('c', '13', '9'),
#     ('c', '13', '3')],
#    [('c', '1', '4')],
#    [('c', '2', '5')],
#    [('c', '1', '4')],
#    [('c', '3', '6')],
#    [('c', '2', '5'), ('c', '2', '7')],
#    [('c', '4', '7'),
#     ('c', '4', '10'),
#     ('c', '7', '14'),
#     ('c', '10', '14'),
#     ('p', '4', '14')],
#    [('c', '1', '5'), ('c', '1', '7')],
#    [('c', '3', '7'), ('c', '3', '9'), ('c', '3', '16'), ('p', '7', '16')],
#    [],
#    [],
#    [],
#    [],
#    [('c', '2', '7')],
#    [('c', '10', '12'), ('c', '2', '6'), ('c', '2', '10')],
#    [('c', '1', '5')],
#    [('c', '1', '9')],
#    [('c', '3', '8')],
#    [],
#    [('c', '3', '5')],
#    [('c', '3', '5')],
#    [('p', '1', '3'), ('p', '3', '1'), ('p', '13', '15'), ('p', '15', '18')],
#    [('c', '1', '5')],
#    [('c', '1', '12')],
#    [],
#    [('c', '1', '6'), ('c', '28', '25')],
#    [('c', '4', '7')],
#    [('c', '1', '6')],
#    [],
#    [('c', '5', '13'), ('c', '5', '11')],
#    [],
#    [],
#    [('p', '1', '3')],
#    [('p', '1', '9'), ('p', '1', '12')],
#    [('p', '9', '2'), ('p', '2', '5')],
#    [('p', '9', '11'), ('p', '9', '13'), ('c', '13', '17'), ('c', '5', '17')],
#    [('p', '1', '5'), ('p', '1', '7')],
#    [('p', '1', '4')],
#    [('p', '4', '10')],
#    [('p', '7', '5')],
#    [('p', '2', '8')],
#    [],
#    [('p', '16', '18')],
#    [],
#    [],
#    [('c', '2', '5')],
#    [('c', '1', '6'), ('c', '1', '9')],
#    [('c', '1', '6')],
#    [('c', '1', '4')],
#    [],
#    [('c', '7', '9'), ('c', '7', '12'), ('c', '7', '19')],
#    [],
#    [],
#    [],
#    [('c', '1', '3')],
#    [('c', '2', '5')],
#    [('c', '2', '7')],
#    [],
#    [('c', '3', '8')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('c', '4', '6')],
#    [('c', '2', '6')],
#    [],
#    [('c', '1', '3')],
#    [('c', '2', '5')],
#    [('c', '6', '9')],
#    [('c', '12', '2'), ('c', '12', '8')],
#    [('c', '2', '6')],
#    [('c', '2', '10')],
#    [('c', '1', '9')],
#    [('c', '5', '15'), ('p', '5', '12'), ('p', '5', '7')],
#    [('c', '1', '4'), ('c', '1', '6'), ('c', '8', '13')],
#    [('c', '2', '7')],
#    [('c', '2', '15'), ('c', '8', '15')],
#    [],
#    [('c', '3', '10')],
#    [('c', '2', '7'), ('p', '11', '14')],
#    [('c', '8', '2'), ('c', '11', '2')],
#    [('c', '5', '3'), ('p', '5', '15')],
#    [('c', '2', '6')],
#    [('c', '2', '8'), ('c', '2', '10')],
#    [('c', '1', '3')],
#    [('c', '1', '4'), ('p', '10', '14'), ('p', '10', '16')],
#    [('c', '6', '9')],
#    [('p', '6', '9'), ('c', '6', '13')],
#    [],
#    [('c', '2', '7')],
#    [('c', '3', '5')],
#    [('p', '1', '7'), ('c', '1', '21')],
#    [('c', '6', '2')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('p', '2', '6'), ('p', '2', '10'), ('p', '6', '10')],
#    [],
#    [],
#    [],
#    [('c', '4', '5'), ('c', '12', '14')],
#    [('p', '4', '12')],
#    [],
#    [],
#    [],
#    [],
#    [('p', '10', '12')],
#    [('c', '3', '8'), ('p', '3', '12')],
#    [('c', '1', '18'), ('p', '1', '22')],
#    [('c', '4', '8'), ('c', '6', '8'), ('p', '4', '14')],
#    [('c', '8', '13')],
#    [('c', '2', '9')],
#    [('c', '1', '12')],
#    [('c', '3', '9')],
#    [('c', '9', '15')],
#    [('p', '1', '3')],
#    [],
#    [('p', '13', '15')],
#    [('p', '1', '4')],
#    [],
#    [('p', '4', '7')],
#    [],
#    [],
#    [('p', '1', '4')],
#    [('p', '2', '17')],
#    [('p', '1', '5')],
#    [],
#    [],
#    [('c', '1', '4'), ('p', '1', '10'), ('c', '10', '4')],
#    [('c', '2', '5'), ('p', '11', '24')],
#    [('p', '1', '4'), ('p', '1', '5'), ('p', '1', '13')],
#    [],
#    [('c', '1', '17')],
#    [('p', '10', '12')],
#    [],
#    [],
#    [('p', '1', '6'), ('p', '1', '9')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('c', '1', '4')],
#    [],
#    [],
#    [('c', '3', '6'), ('c', '3', '8'), ('p', '3', '26')],
#    [],
#    [],
#    [],
#    [('c', '4', '3')],
#    [('c', '1', '4')],
#    [],
#    [],
#    [('c', '4', '7')],
#    [('p', '4', '7')],
#    [('p', '2', '8')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('p', '3', '8')],
#    [('p', '1', '5')],
#    [],
#    [],
#    [],
#    [('c', '23', '10')],
#    [],
#    [('p', '3', '10')],
#    [],
#    [],
#    [('c', '5', '11')],
#    [],
#    [],
#    [],
#    [('c', '1', '3')],
#    [],
#    [],
#    [],
#    [],
#    [('p', '6', '12')],
#    [('p', '1', '7')],
#    [('p', '1', '12'), ('p', '1', '14'), ('p', '1', '19')],
#    [('p', '7', '11')],
#    [('p', '1', '10')],
#    [('p', '1', '15'), ('p', '21', '44')],
#    [],
#    [('p', '3', '6')],
#    [('c', '7', '13')],
#    [('c', '1', '5')],
#    [('c', '1', '4'), ('c', '1', '7')],
#    [('c', '4', '7'), ('c', '4', '9'), ('c', '3', '12'), ('c', '3', '14')],
#    [('c', '2', '7')],
#    [('c', '2', '9')],
#    [],
#    [('c', '10', '7')],
#    [],
#    [('c', '2', '7')],
#    [('c', '4', '1')],
#    [('c', '3', '7')],
#    [('c', '2', '4'), ('p', '7', '9')],
#    [('p', '8', '11')],
#    [('p', '3', '7'), ('p', '3', '11')],
#    [('p', '2', '5'), ('c', '2', '8')],
#    [('p', '1', '3')],
#    [],
#    [('p', '1', '6'), ('p', '1', '9')],
#    [],
#    [],
#    [],
#    [],
#    [('c', '2', '11'), ('c', '2', '13')],
#    [('p', '1', '12'), ('c', '1', '15')],
#    [],
#    [('c', '2', '5'), ('c', '2', '8')],
#    [('c', '2', '5')],
#    [],
#    [],
#    [('c', '11', '7'), ('c', '13', '7')],
#    [('c', '17', '12')],
#    [],
#    [],
#    [('c', '3', '11')],
#    [('c', '2', '4'), ('c', '2', '10')],
#    []]]}

# %% [markdown]
# ### Merge the different annotations into a single dataset
#
# The current strategy is to intersect all of them!
#
# ==> So our gold standard only exists of **attitude relations** where everybody agrees.

# %%
# abc
dataset.items()
# Out:
# dict_items([('annotator1', [[['Dabei', 'machte', 'er', 'sich', 'primär', 'für', 'Ausgabenkürzungen', 'stark', ',', 'während', 'er', 'von', 'Steuererhöhungen', 'abriet', '.'], ['Bundesrätin', 'Calmy-Rey', 'ist', 'allerdings', 'der', 'Einladung', 'zum', 'Gipfeltreffen', 'nicht', 'gefolgt', ',', 'und', 'einige', 'CEO', 'haben', 'ihre', 'Teilnahme', 'ebenfalls', 'kurzfristig', 'abgesagt', '.'], ['Das', 'Bundesgericht', 'hat', 'eine', 'staatsrechtliche', 'Beschwerde', 'der', 'SVP', 'des', 'Kantons', 'Zürich', 'abgewiesen', '.'], ['Generell', 'ortet', 'Zeuske', 'denn', 'auch', 'die', 'Krise', 'Kubas', 'zuerst', 'in', 'dem', 'herrschenden', 'absurden', 'und', 'ineffizienten', 'Wirtschaftssystem', ',', 'das', 'jegliche', 'Eigeninitiative', 'abwürgt', '.'], ['In', 'einer', 'Videoaufzeichnung', 'hat', 'der', 'tschetschenische', 'Rebellenführer', 'Aslan', 'Maschadow', 'eine', 'Intensivierung', 'der', 'Kämpfe', 'auf', 'fremdem', 'Territorium', 'angekündigt', 'und', 'dem', 'nächsten', 'Regierungschef', 'die', 'sofortige', 'Ermordung', 'angedroht', '.'], ['Hofstetter', 'wirft', 'im', 'Interview', 'den', 'Gewerkschaften', 'vor', ',', 'sie', 'wollen', 'die', 'Branche', 'anschwärzen', '.'], ['Dass', 'der', 'an', 'der', 'Rotmeerküste', 'und', 'an', 'der', 'Grenze', 'zu', 'Eritrea', 'operierende', 'Beja', 'Congress', 'ausgerechnet', 'jetzt', 'Unruhen', 'anzettelt', ',', 'ist', 'kein', 'Zufall', '.'], ['Das', 'Volk', 'hat', 'mehrfach', 'gegen', 'die', 'ungebremste', 'Schuldenspirale', 'aufbegehrt', '-', 'unmissverständlich', '.'], ['Sie', 'wollen', 'dem', 'Vertragspaket', 'integral', 'zustimmen', 'und', 'allfällige', 'Unannehmlichkeiten', 'durch', 'Anpassungen', 'des', 'inländischen', 'Rechts', 'ausbügeln', '.'], ['Sarkozy', 'kündigte', 'auch', 'bescheidene', 'Prämien', 'für', 'die', 'Mitarbeiter', 'von', 'Arbeitsgruppen', 'an', ',', 'die', 'sich', 'durch', 'besonders', 'gute', 'Resultate', 'und', 'Effizienz', 'auszeichneten', '.'], ['Zuvor', 'hatte', 'er', 'bereits', 'eine', 'Ministerin', ',', 'die', 'ihre', 'Familie', 'unrechtmässig', 'begünstigt', 'hatte', ',', 'in', 'die', 'Wüste', 'geschickt', '.'], ['Die', 'Verbandsspitze', 'beharrte', 'indes', 'darauf', ',', 'die', 'Endrunde', 'abzuwarten', 'und', 'erst', 'danach', 'zu', 'verhandeln', '.'], ['Und', 'damit', 'belügt', 'man', 'erneut', 'eine', 'Generation', ',', 'die', 'das', 'Kriegsende', 'und', 'die', 'Schrecken', 'dieser', 'Zeit', 'nicht', 'selbst', 'erlebt', 'hat', '.'], ['Der', 'Regierungschef', 'beriet', 'am', 'Mittwoch', 'mehr', 'als', 'drei', 'Stunden', 'mit', 'dem', 'Auswärtigen', 'und', 'dem', 'Verteidigungsausschuss', 'des', 'Parlaments', 'über', 'seinen', 'Plan', '.'], ['Den', 'Wechsel', 'von', 'der', '«', 'Aargauer', 'Zeitung', '»', 'zur', 'NZZ', 'hat', 'die', 'Chauffeuse', 'nie', 'bereut', ',', 'denn', 'das', 'Arbeitsklima', 'sei', 'hier', 'deutlich', 'besser', '.'], ['Grasser', 'beschädige', 'nicht', 'nur', 'die', 'Beziehungen', 'mit', 'anderen', 'EU-Mitgliedstaaten', ',', 'sondern', 'auch', 'den', 'Ruf', 'Österreichs', 'innerhalb', 'Europas', '.'], ['«', 'Ja', ',', 'ich', 'habe', 'meine', 'Firma', 'beschissen', '»', ',', 'sagte', 'der', 'Angeklagte', '.'], ['Es', 'besticht', 'durch', 'eine', 'Genauigkeit', 'der', 'Wirklichkeitsbeobachtung', 'und', 'eine', 'hohe', 'Kunst', 'der', 'begrifflichen', 'Differenzierung', '.'], ['Einen', 'weiteren', 'Mittäter', 'bestrafte', 'die', 'Jugendkammer', 'mit', '80', 'Stunden', 'gemeinnütziger', 'Arbeit', '.'], ['Die', 'Migration', 'bewirkt', ',', 'dass', 'auch', 'die', 'schweizerische', 'Gesellschaft', 'heute', 'hochgradig', 'multikulturell', 'zusammengesetzt', 'ist', '.'], ['Die', 'Schweizer', 'Experten', 'ihrerseits', 'bewundern', 'ausdrücklich', 'die', 'Lernfähigkeit', 'und', 'den', 'Fleiss', 'der', 'Nordkoreaner', '.'], ['Der', 'Votant', 'bezweifelt', ',', 'dass', 'es', 'sinnvoll', 'ist', ',', 'die', 'Gewinnausschüttungen', 'vollumfänglich', 'an', 'den', 'Bund', 'und', 'die', 'Kantone', 'zu', 'leiten', '.'], ['Der', 'Sicherheitsrat', 'h ...

# %%
gold_standard = []
gs_sents = []
gs_anns = []

data=dataset["annotator1"]
sents = data[0]
anns = data[1]

for i, sent, ann in zip(range(0, len(sents)), sents,anns):
    sent = " ".join(sent)
    # print(sent)
    gs_sents.append(sent)
    print(f"Annotation length before intersection: { len(ann) }")
    ann = list(set(ann)
         .intersection(dataset["annotator2"][1][i])
         .intersection(dataset["annotator3"][1][i])
        )
    print(f"Annotation length after intersection: { len(ann) }")
    gs_anns.append(ann)
   

gold_standard=[gs_sents, gs_anns]
# Out:
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 4
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 4
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 3
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 3
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 3
# Annotation length after intersection: 1
# Annotation length before intersection: 4
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 3
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 4
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 3
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 4
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 3
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 4
# Annotation length after intersection: 3
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 4
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 5
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 4
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 4
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 4
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 3
# Annotation length after intersection: 3
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 3
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 3
# Annotation length after intersection: 2
# Annotation length before intersection: 3
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 3
# Annotation length after intersection: 3
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 4
# Annotation length after intersection: 3
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 3
# Annotation length after intersection: 3
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 3
# Annotation length after intersection: 1
# Annotation length before intersection: 4
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 1
# Annotation length before intersection: 2
# Annotation length after intersection: 2
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0
# Annotation length before intersection: 1
# Annotation length after intersection: 0
# Annotation length before intersection: 0
# Annotation length after intersection: 0

# %%
gold_standard
# Out:
# [['Dabei machte er sich primär für Ausgabenkürzungen stark , während er von Steuererhöhungen abriet .',
#   'Bundesrätin Calmy-Rey ist allerdings der Einladung zum Gipfeltreffen nicht gefolgt , und einige CEO haben ihre Teilnahme ebenfalls kurzfristig abgesagt .',
#   'Das Bundesgericht hat eine staatsrechtliche Beschwerde der SVP des Kantons Zürich abgewiesen .',
#   'Generell ortet Zeuske denn auch die Krise Kubas zuerst in dem herrschenden absurden und ineffizienten Wirtschaftssystem , das jegliche Eigeninitiative abwürgt .',
#   'In einer Videoaufzeichnung hat der tschetschenische Rebellenführer Aslan Maschadow eine Intensivierung der Kämpfe auf fremdem Territorium angekündigt und dem nächsten Regierungschef die sofortige Ermordung angedroht .',
#   'Hofstetter wirft im Interview den Gewerkschaften vor , sie wollen die Branche anschwärzen .',
#   'Dass der an der Rotmeerküste und an der Grenze zu Eritrea operierende Beja Congress ausgerechnet jetzt Unruhen anzettelt , ist kein Zufall .',
#   'Das Volk hat mehrfach gegen die ungebremste Schuldenspirale aufbegehrt - unmissverständlich .',
#   'Sie wollen dem Vertragspaket integral zustimmen und allfällige Unannehmlichkeiten durch Anpassungen des inländischen Rechts ausbügeln .',
#   'Sarkozy kündigte auch bescheidene Prämien für die Mitarbeiter von Arbeitsgruppen an , die sich durch besonders gute Resultate und Effizienz auszeichneten .',
#   'Zuvor hatte er bereits eine Ministerin , die ihre Familie unrechtmässig begünstigt hatte , in die Wüste geschickt .',
#   'Die Verbandsspitze beharrte indes darauf , die Endrunde abzuwarten und erst danach zu verhandeln .',
#   'Und damit belügt man erneut eine Generation , die das Kriegsende und die Schrecken dieser Zeit nicht selbst erlebt hat .',
#   'Der Regierungschef beriet am Mittwoch mehr als drei Stunden mit dem Auswärtigen und dem Verteidigungsausschuss des Parlaments über seinen Plan .',
#   'Den Wechsel von der « Aargauer Zeitung » zur NZZ hat die Chauffeuse nie bereut , denn das Arbeitsklima sei hier deutlich besser .',
#   'Grasser beschädige nicht nur die Beziehungen mit anderen EU-Mitgliedstaaten , sondern auch den Ruf Österreichs innerhalb Europas .',
#   '« Ja , ich habe meine Firma beschissen » , sagte der Angeklagte .',
#   'Es besticht durch eine Genauigkeit der Wirklichkeitsbeobachtung und eine hohe Kunst der begrifflichen Differenzierung .',
#   'Einen weiteren Mittäter bestrafte die Jugendkammer mit 80 Stunden gemeinnütziger Arbeit .',
#   'Die Migration bewirkt , dass auch die schweizerische Gesellschaft heute hochgradig multikulturell zusammengesetzt ist .',
#   'Die Schweizer Experten ihrerseits bewundern ausdrücklich die Lernfähigkeit und den Fleiss der Nordkoreaner .',
#   'Der Votant bezweifelt , dass es sinnvoll ist , die Gewinnausschüttungen vollumfänglich an den Bund und die Kantone zu leiten .',
#   'Der Sicherheitsrat hat Ende April die Entsendung einer 8000 Mann starken Blauhelm-Truppe für Haiti gebilligt .',
#   'Der Schnee blockiert den Zugang zu den Berghütten .',
#   'Er dämonisiert den Monarchen jedoch nicht , sondern schildert ihn vielmehr als zwar intelligenten Menschen , aber auch als « eine ängstliche , zur Panik neigende Gestalt » .',
#   'Jim Crace , dessen Bücher viele Leser deprimieren , wirkt wie der heiterste Mensch auf Erden .',
#   'Qualitativ können es die kolumbianischen Rosen heute mit den ecuadorianischen aufnehmen , die auf den internationalen Märkten praktisch dominieren .',
#   '« Aber ich ekele mich doch vor ihm » , rief Shahla verzweifelt aus .',
#   'Zudem entlarvt die Autorin werdende Mütter als kleine Egoistinnen , die sich mit dem Kind zuerst einmal « selbst ein Geschenk » machen .',
#   'Bezirksanwalt Böhler entlässt den nicht geständigen Dominikaner aus der Polizeihaft und wird beim Einzelrichter Anklage erheben .',
#   'Am Ende des dreieinhalbstündigen Prozesses entschuldigte sich Sivits beim irakischen Volk und bei den Gefangenen .',
#   'Didier Cuche erleidet Kreuzbandriss und fällt für die Ski-WM in Bormio aus .',
#   'Eindringlich ermahnt die Mutter sie noch einmal , bloss keinen Fehler zu machen .',
#   'Den noch vakanten Sitz im Gemeinderat eroberte Urs Gassmann ( neu ) , der von einem ad hoc gegründeten Komitee portiert worden war .',
#   'Am Sonntag erschütterten mehrere Explosionen die Innenstadt von Bagdad .',
#   'Die Angreifer feuerten in mindestens zehn Salven Granaten auf den Stützpunkt einer Versorgungseinheit ab .',
#   'Dann flucht er wieder über die neuen Zeiten .',
#   'In einer Talkshow giftete am Sonntag der Publizist Arnulf Baring heftig gegen alle , die nicht seiner ausgesprochen realpolitischen Meinung waren .',
#   'Doris Fiala gratulierte ihrem Nachfolger und rief zur Zusammenarbeit zwischen Stadt und Kanton auf .',
#   'Noch jetzt ist sie empört über ein Mädchen , das sie wegen ihrer roten Haare hänselte .',
#   'Die Opposition sprach von Bürgerkriegszustand , während Präsident Musharraf die Ereignisse herunterspielte .',
#   'Dass Christian Lindner den Bettel einfach hinschmeisst , ist ein Symptom dafür , wie tief die FDP in der Krise steckt .',
#   'Er inspirierte mit seiner Arbeit Generationen von Fotografen .',
#   'Microsoft klagt gegen die EU-Kommission .',
#   'Der Privatsektor lechzt ebenfalls nach ausländischem Engagement .',
#   'Auch die Schaffung von Arbeitsplätzen legitimiert nicht die Ausschaltung demokratischer Rechte .',
#   'Er leugnet auch nicht , dass er für den Tod von so manchem verantwortlich ist .',
#   'Der Präsident von Serbien-Montenegro lobte Kroatiens Bemühungen um EU-Mitgliedschaft .',
#   'Inzwischen missioniert er für jene , die ihm den Rückgewinn von mehr Lebensqualität ermöglicht haben : die Schweizer Firma Phonak .',
#   'Das hohe Tempo der Sieger nervte den SCB , der allein im Startdrittel 16 Strafminuten kassierte .',
#   'Tessiner Journalisten kritisieren Zeitungen .',
#   'Strafgericht kritisiert Blochers Entscheid .',
#   'Parlamentarier kritisieren Lombardi .',
#   'Ausländerkommission kritisiert Statistik .',
#   'Kerry kritisiert die Aussenpolitik der US-Regierung .',
#   'Rambert kritisierte , dass mit der « Fotoshow » geradezu lehrbuchhaft gegen alle Regeln einer Einvernahme verstossen worden sei .',
#   'Sie kritisierten , dass von den beiden geplanten Berufsbildungszentren für Gesundheitsberufe nur eines vom Kanton selber geführt werden soll .',
#   'Kollegger kritisierte ferner , dass in Geschäftsführung und Verwaltungsrat der Bahn kaum Personen mit einem Marketing-Hintergrund vertreten seien .',
#   'Unabhängige serbische Medien kritisierten , dass Kostunica seine Anhänger nicht unmissverständlich aufforderte , für Tadic zu stimmen .',
#   'Die Unterzeichner kritisieren aber , dass Rumantsch Grischun in der Schule zur einzigen Schriftsprache werden soll .',
#   'Aktienanalysten und Fondsmanager , die den Post-Vorstand in den vergangenen Wochen immer wieder für seine Preisvorstellung kritisiert hatten , räumten der Aktie gute Kurschancen ein .',
#   'Die 29 000 Unterzeichner kritisieren die Reservationspflicht für den Veloverlad in den Intercity-Neigezügen .',
#   '« Seiler » , findet der Freiburger CVP-Ständerat Urs Schwaller , « ist sehr kooperationswillig . » - « Kooperationsbesessen » , korrigiert der Zürcher SVP-Nationalrat Hans Fehr , der keine Gelegenheit auslässt , Schmid für den Armee-Leitsatz « Sicherheit durch Kooperation » zu kritisieren .',
#   'Doch diesen Einwand , dass es für eine Grundsatzdebatte , ob die Türkei überhaupt ein europäisches Land sei , eh zu spät ist , wollen Warner wie Fischler oder sein niederländischer Kollege Frits Bolkestein nicht akzeptieren : « Sollten wir nach einer tief greifenden Analyse Zweifel haben , müssen wir das Risiko ignorieren , für diese Ehrlichkeit kritisiert zu werden » , so Fischler .',
#   'Die Minister nutzen das gestrige Treffen auch dazu , ihren französischen Kollegen Nicolas Sarkozy für sein unabgesprochenes Vorgehen angesichts des steigenden Ölpreises zu kritisieren .',
#   'Dieser wissenschaftliche Ansatz scheiterte zwar , dennoch sind seine Verdienste für die ethnographische Museumsgeschichte gross .',
#   'Bemühungen für aussergerichtliche Einigungen scheiterten bisher .',
#   'Auch eine weitere Nachfrage scheitert kläglich .',
#   'Unzählige Vermittlungsversuche nahezu sämtlicher westafrikanischer Staatschefs scheiterten .',
#   'Wieder scheitert eine mögliche Liebe .',
#   'Die Einführung von EU-weit gültigen Regeln scheiterte am Freitag in Luxemburg am Widerstand von zehn Ländern .',
#   '- Die Kommerzialisierung der Privatkopie scheiterte bisher am Fehlen technischer Kontrollmöglichkeiten und am politischen Widerstand anderer Interessengruppen .',
#   'Der FC Thun im UI-Cup an Hamburg gescheitert .',
#   'Der Genfer Tour-Pro Julien Clément scheiterte am Cut , den zwei Schweizer überstanden , Marc Chatelain und Amateur Nicolas Sulzer .',
#   'Vor vier Jahren scheiterte die SP deutlich mit einer Initiative für eine 100-prozentige Ausschöpfung : 58 Prozent des Stimmvolkes sagten Nein .',
#   'Das lokale Gewerbe profitiert .',
#   'Der Konsum profitiert mehr als der Fiskus .',
#   'Profitiert hat auch die Umwelt : Die Abgase haben sich um 12 % reduziert , es gibt 5 % weniger Unfälle , und die Bevölkerung ist mit dem System mehrheitlich zufrieden .',
#   'Die Bauern können profitieren .',
#   'Hertha vermag nicht zu profitieren .',
#   'Hotels und Gewerbe profitieren von den vielen Besuchern .',
#   'Die Stadt habe in vielen Bereichen von der Weltausstellung profitiert .',
#   'Schätzungsweise 70 Mio. Arbeitnehmer in den USA profitieren denn auch gemäss Branchenangaben vom Schutz , den HMO-orientierte Betriebskrankenkassen sowohl ihnen als auch ihren Familienangehörigen offerieren .',
#   'Basel kann dabei von einer langen caritativen Tradition profitieren .',
#   'Bankwerte profitierten laut Händlern von positiven Analytikerkommentaren .',
#   'Sechs Minister aus dem Hariri-Block beschuldigten Syrien als Anstifter der Unruhen und verlangten eine offizielle Klage Libanons bei der Uno gegen das Nachbarland .',
#   'Früherer Terrorexperte Bushs beschuldigt das Weisse Haus .',
#   'Später beschuldigte die SEC die Börse der mangelnden Aufsicht .',
#   'Drei der Soldaten werden des Totschlags beschuldigt .',
#   'Die Regierung beschuldigt - wie immer in solchen Fällen - Produzenten und Händler der Spekulation zulasten des armen Volkes .',
#   'Das Nürnberger Oberlandesgericht beschuldigt die drei ehemaligen Militärs für die Tötung der deutschen Soziologin und Theologiestudentin Elisabeth Käsemann und des Münchner Studenten Manfred Zieschank während der Militärdiktatur von 1976 bis 1983 .',
#   '6 Frauen beschuldigen den Konzern , dass sie schlechter bezahlt worden seien als ihre männlichen Kollegen und geringere Aufstiegschancen gehabt hätten .',
#   'Die Armee beschuldigt al-Jil , ein Propagandainstrument der Hamas zu sein .',
#   'Das Wahlkampfteam der Demokraten beschuldigt die Gruppe « Swift Boat Veterans For Truth » , ihre Fernsehkampagne rechtswidrig mit Bushs Republikanern abgestimmt zu haben .',
#   'Die Steuerbehörden beschuldigen Menem , 600 000 Dollar auf einem Konto in der Schweiz nicht deklariert zu haben .',
#   'Die wichtigste Politikerin Argentiniens , die Frau des Präsidenten , hat dessen Vorgänger beschuldigt , eine Verschwörung zur Destabilisierung der Regierung angezettelt zu haben .',
#   'Ferner beschuldigte Litwinenko den FSB auch , die Bombenanschläge von 1999 gegen Wohnblöcke in Moskau organisiert zu haben , denen 300 Personen zum Opfer fielen .',
#   'Nationalrat billigt Parallelimporte patentgeschützter Güter .',
#   'Der Nationalrat billigt Parallelimporte .',
#   "Spaniens Parlament billigt Solbes ' revidiertes Budget .",
#   'EU-Parlament billigt den Vertrag von Lissabon .',
#   'Gül billigt die Aufhebung des Kopftuchverbots .',
#   'In einem nächsten Schritt wird der Grosse Rat das Thema behandeln .',
#   'Zurückhaltend behandelt wurden Energiewerte .',
#   'Man behandelt uns wie Dreck !',
#   'Leute , die lächeln , werden bevorzugt behandelt .',
#   'Die Wirtschaft hat kein Interesse daran , Frauen schlechter zu behandeln als Männer .',
#   'Somit erhöht ein gut diversifiziertes Portefeuille die Rendite für den Investor .',
#   'Auch die Nachfrage aus der Industrie ( vor allem der Elektronik ) erhöhte sich .',
#   'UBS erhöht Zinsen für Kassenobligationen .',
#   'Die Frauen feiern .',
#   'Das Theater am Stadtgarten feiert .',
#   'Die Privatschule Minerva feiert ihr 100-jähriges Bestehen .',
#   'Erfolgreiche Jungunternehmer werden von den Medien gefeiert , wobei dieses Lob auch eine ideologische Komponente hat .',
#   'In der arabischen Welt wurde Zaidi für den Schuhwurf wie ein Held gefeiert .',
#   'Vor ein paar Wochen noch feierten sie sich dafür , dass sie auf einer Mitgliederversammlung den HSV für Investoren öffneten .',
#   'Und es feiert ihn dafür , dass er den Begriff « virtuelle Realität » in die Welt getragen hat .',
#   'In den siebziger Jahren des letzten Jahrhunderts wurden verschiedene Schweizer Städte auf das Problem aufmerksam und förderten aktiv , dass Höfe nicht nur Autos , sondern auch Spielplätze und originelle Freiräume beherbergten .',
#   'Ich förderte ja , dass Martina sich den Reitsport zum Hobby machte .',
#   'Die lokale Abwertung des Rubels förderte die Dollar-Haltung .',
#   'Labelprogramme und Direktzahlungen haben dies noch gefördert .',
#   'Die Gesellschaft um uns herum fördert das allerdings oft nicht .',
#   'Sie fördert auch die Ausbreitung maoistischer Ideen .',
#   '« Jia mas » , prosit , man geniesst und hat Zeit , die Speisekarte zu studieren - und dabei ein wenig Griechisch zu lernen .',
#   'Nicht mehr täglich früh am Morgen pendeln zu müssen , geniesse ich als Privileg .',
#   'Die englischen Fussballer geniessen grosse Unterstützung .',
#   'Aber wir möchten diese späte Wiedergeburt geniessen und sie an unsere Kinder weitergeben .',
#   'Nein , die SAS-Angestellten geniessen ihre Ferien !',
#   'Man geniesst es , die Voodoo- Puppe zu sein , denn diese Nadelstiche verursachen süsse Schmerzen .',
#   'Sie leiden jetzt .',
#   'Ihr Image leidet , seit Untersuchungen in den 80er-Jahren zeigten , dass ihre Areale oft Schwermetallgehalte aufwiesen , bei denen die Bodenfruchtbarkeit gefährdet ist .',
#   'Auch die preisliche Konkurrenzfähigkeit der italienischen Unternehmen hat gelitten .',
#   'Heime müssen sparen : Die Betreuung der Behinderten leidet massiv .',
#   'Mit anderen Worten : Ein Fünftel der Bevölkerung leidet Hunger .',
#   'Vierzig Jahre lang hat der Mann Qualen gelitten .',
#   'Auch wir dürfen an Menschen , die Not leiden , nicht vorbeigehen .',
#   ') ganz alte Leute , deren Lebensschifflein wahrscheinlich mehrmals Schiffbruch gelitten hat , bevor es im Hafen von Kappel einlief ( .',
#   'Ich bin 36 Jahre alt und leide seit meiner Kindheit an Depressionen und Zwängen .',
#   'Parlamentarier leiden unter Stress und Bewegungsmangel .',
#   'Die Staatsbanken leiden nach Ansicht von Chinaexperten noch immer unter Korruption und Missmanagement .',
#   'Familien litten heute unter dem modernen Individualismus , dem Trend zur Unverbindlichkeit und einem fortschreitenden Werteverlust , sagte Christa Leonhard von der SSF .',
#   'Viele Menschen leiden heute darunter , dass sie in einer globalisierten Wirtschaft nur noch als Kostenfaktoren wahrgenommen werden .',
#   'Zeuskes Studie leidet darunter , dass Autor und Lektorat die Stoffmenge nicht strafften und sinnvoll strukturierten .',
#   'Wie andere Gemeinden leidet Winterthur zudem daran , dass es keine Erbschafts- und Handänderungssteuern mehr gibt und dass Kanton und Bund vermehrt Aufgaben auf die Gemeinden übertragen .',
#   'Aber das Land leidet darunter , dass es während Jahrzehnten von Kleptokraten regiert wurde .',
#   'Walser leidet darunter , als Deutscher unausweichlich zu den Tätern zu gehören .',
#   'Ich habe auch miterlebt , wie er daran litt , in den 70er-Jahren mit seinen Beschuldigungen übermarcht zu haben - zum Nachteil auch seiner nächsten Angehörigen .',
#   'Aber manchmal leidet Kuba darunter , nur aufs politische reduziert zu werden .',
#   'Mitarbeiter leiden darunter , immer erreichbar zu sein .',
#   'Auch Deutschland profitiert .',
#   'Auch die Forschung profitiert .',
#   'Telekom Austria profitiert von Sondereffekten .',
#   'Er profitierte davon , dass auch die unmittelbare Konkurrenz suboptimal spielte , und entschied letztlich das Play-off gegen die Amerikaner Justin Leonard und Chris DiMarco dank Birdie am ersten Loch für sich .',
#   'Die Banken-Gruppe profitierte davon , dass es erheblich weniger zweifelhafte Kredite gibt als im vergangenen Jahr .',
#   'Langfristig profitiere Zürich trotzdem davon , Finanzzentrum zu sein .',
#   'Alle anderen profitieren davon , sich an den Verhandlungstisch zu setzen .',
#   'Mehrere Gestaltungspläne scheiterten .',
#   'Doch die Religionsgründung des Philosophenkönigs scheiterte , Echnaton und sein Gott verfielen der « damnatio memoriae » .',
#   'Dieser scheiterte am italienischen Qualifier Potito Starace , Grand- Slam-Neuling aus dem 202 .',
#   'Der Deal scheiterte aber nur schon daran , dass mehrere SP-Nationalräte in der entscheidenden Abstimmung fehlten .',
#   'Die drei Künstler auf der Bühne scheitern daran , Kunst zu machen , von der sie auch leben können .',
#   'Das konservative Lager scheiterte aber damit , diese Vorgabe im Gesetz direkt zu verankern .',
#   'Palästinenser töten israelischen Offizier .',
#   'Ist ein Parasit etwa zu virulent , so tötet er seinen Wirt , bevor er auf den nächsten Wirt überwechseln kann - und reduziert damit seinen eigenen Erfolg .',
#   'Auch seine Fans veräppelt er gern .',
#   'Labour-Aktivistin Armstrong veräppelt den vermissten Abgeordneten .',
#   'Wie Konsument Bönis Frau von Ikea veräppelt wurde .',
#   'Gegenüber der letzten Befragung haben sich die Werte leicht verbessert .',
#   'Audi verbessert sich operativ .',
#   'Ich habe meinen Start weiter verbessert .',
#   'Axel-Springer-Verlag verbessert Ertragskraft .',
#   'Dennoch verletzt Deutschland seither die Schallgrenze Jahr für Jahr .',
#   '« Das Projekt verletzt raumplanerische Grundsätze .',
#   'Die Polizistin kam zu Fall und verletzte sich .',
#   'In dieser Phase verletzte sich der Südamerikaner an der Bauchmuskulatur .',
#   'Haymon verletzte den Thyrsus an der Ferse , und der flüchtete sich ins Karwendel .',
#   'Denn weil ihm ein Unihockey-Schläger einst die Nase verletzte , schläft Granit etwas unruhig .',
#   'Während einer einzigen Woche habe ich es geschafft , mir sämtliche Extremitäten zu verletzen .',
#   'Dennoch verurteile Martin Graf klar , dass die Bilder an die Medien gelangt seien .',
#   'Scharf verurteilte Leuenberger , dass das Parlament gegen den Willen der Landesregierung und auf demokratiepolitisch fragwürdige Weise den Alpenschutzartikel gelockert habe .',
#   'FDP-Fraktionspräsidentin Gabi Huber verurteilte , wie die USA das Prinzip Macht vor Recht gesetzt hätten .',
#   'Abtreibungsgegner verurteilten die Schaffung der Bank und bezeichneten diese als eine Lagerstätte für tote Säuglinge .',
#   'Bagdad verurteilt die Anschläge auf Kirchen .',
#   '« Ich habe sie dafür verurteilt , dass sie so einen Ort aufsuchten .',
#   'Das Gericht verurteilte die Schweiz , dem Vater eine Genugtuung von 15 000 Euro zu zahlen .',
#   'Die Schweiz wurde verurteilt , dem Mann 3000 Euro Genugtuung und 4650 Euro für seine Auslagen zu zahlen .',
#   'Er wurde verurteilt , die Jungen in sechs Fällen unsittlich berührt zu haben .',
#   'Graf verurteile es , dass die Bilder den Medien zugespielt worden seien , und sei froh , dass die Staatsanwaltschaft die Sache untersuche , lässt Tommer noch ausrichten .',
#   'Die Exekutive verzichtete damals weitsichtig , dies vorzuschlagen .',
#   'Der Bundesrat verzichtet deshalb auf eine Teilrevision des Lotteriegesetzes .',
#   'Auch hier verzichtet man nicht auf den Einstiegsschliff , obwohl nicht von der Universität rekrutiert wird , sondern Leute mit Erfahrung aus den Unternehmen eingestellt werden .',
#   'Im Gegenzug verlangt Nordkorea , dass Darusman darauf verzichtet , dass der Bericht der Untersuchungskommission an den ICC weitergeleitet wird .',
#   'Sie verzichtet vorläufig darauf , den Damm weiter aufzustocken .',
#   'Dennoch habe Bush nicht darauf verzichtet , seine wöchentliche Radioansprache aufzunehmen .',
#   'Noch im letzten Juni , als 2000 Männer des dissidenten Colonel Laurent Nkunda für eine Woche Bukavu besetzten , verzichteten diese nicht darauf , die Station von Tshivanga zu plündern .',
#   'Zugleich hat das CBoT seine Produktpalette ausgebaut .',
#   'In Namibia wird die maritime Diamantenförderung ausgebaut .',
#   'Mit viel Geschick hat die Unternehmerin Giovanna Furlanetto die italienische Firma Furla zur internationalen Marke ausgebaut .',
#   'Ihr Mobil lässt sich aus diesem Grund zu einer riesigen Stehbar ausbauen .',
#   'Die Tatsache , dass Google ausbaut , zeigt die hohe Standortattraktivität von Stadt und \xad Kanton Zürich .',
#   'Spielbankenkommission bekämpft illegale Glücksspiele .',
#   'Befürworter und Gegner einer Koalition mit der PDS hielten sich die Waage und bekämpften ihre innerparteilichen Widersacher hingebungsvoller als den politischen Gegner .',
#   'Dazwischen gilt es , einen plötzlichen Brandausbruch mit enormer Rauchentwicklung zu bekämpfen .',
#   'Durch steuerliche Entlastungen für einkommensschwache Familien sowie die Einführung der Mutterschaftsversicherung könnte die Armut bei den Ursachen bekämpft werden .',
#   'Hat Ihnen diese Pause sogar geholfen ?',
#   'Markus hatte Glück im Unglück : Seine Eltern halfen ihm aus der Patsche .',
#   'Bewährung hilft vielfach mehr .',
#   'Sein Streben nach Perfektion wurde in der Werkstatt des Ausbildners angestachelt , wo er bei der Herstellung von Heliogravüren für Portfolios der Fotoklassiker Edward Steichen und Paul Strand half .',
#   'Charrouf half den Frauen dieser Gegend , Kooperativen zu gründen , und regte ein zeitgemässes Marketing an .',
#   'Bücher von anderen Betroffenen können helfen zu verstehen .',
#   'Kanton hilft auch , Weiher zu erhalten .',
#   'Auch ihnen war nicht entgangen , wie sie gekämpft und alles gegeben hatte .',
#   'Johann Vogel hatte kurz nach der Pause die gelb-rote Karte gesehen , aber ohne den bis anhin Besten waren die Schweizer viel besser , sie rückten näher zusammen , sie waren in Unterzahl gut organisiert , sie rannten und kämpften , wehrten sich verzweifelt , suchten aber auch ihre Möglichkeiten nach vorne .',
#   'Ihr wart eine Einheit , die sich tapfer und furchtlos der Übermacht der Holländer , Letten und B-Tschechen stellte , ihr habt gekämpft und seid so schön und in Ehren untergegangen , dass euch von all den Experten von ARD , ZDF und DSF eigentlich gar niemand böse sein konnte .',
#   'Die Stimmung im Bundesrat ist nicht wesentlich anders als in den Verwaltungsräten , in denen ich früher mitwirkte : Man kämpft engagiert .',
#   '« Er läuft viel , er kämpft , er ist torgefährlich und voller Energie » , sagt Trainer Geiger über Spieler Chihab .',
#   'Als Feministin musste frau auch um die Gleichstellungspolitik kämpfen .',
#   'Nirgendwo kämpfen Bush und Kerry heftiger um die Gunst der Wähler als in Ohio .',
#   'Und er wird davon profitieren können , dass alle , die in den ersten zehn klassiert sind , um ihre Positionen kämpfen werden .',
#   'Seit 59 Jahren kämpften die Frauen für die Umsetzung des entsprechenden Verfassungsauftrags .',
#   '« Wir haben nicht Jahrzehnte für kürzere Arbeitszeiten gekämpft , um diese Errungenschaft nun an die Arbeitgeber zu verschenken » , gab sich Renzo Ambrosetti von der Gewerkschaft Smuv kämpferisch .',
#   'Frauen kämpfen gemeinsam für Mütter-Urlaub .',
#   'Ryanair steht an der Börse zwar besser da , aber auch die Iren kämpfen mit sinkenden Margen , verlangsamtem Wachstum und gestiegenen Kosten .',
#   'Seit Bossi aber mit seinem schwachen Herz kämpfte , entglitt dem ungelehrigen König das Spiel zusehends .',
#   'Dilettantisch , überfordert , schlecht ausgebildet : Die Schulpflege kämpft mit einem Imageproblem - nicht erst seit dem Selbstmord des Affoltemer Primarlehrers .',
#   'Bauern kämpfen gegen Autolobby .',
#   '- Hunderte Feuerwehrleute haben am Montag gegen Waldbrände in Südeuropa gekämpft .',
#   'Ich kämpfe seit Jahren dafür , dass man in der Schweiz mit dem Preisniveau runtergeht .',
#   'Sie haben vehement dagegen gekämpft , dass das Personal bis 1 Uhr nachts eingesetzt werden darf .',
#   'Nun kämpft Lembergs dagegen , dass die lettische Staatsanwaltschaft die Schweiz um Rechtshilfe bittet .',
#   '« Jede Partei kämpft doch darum , in der Regierung vertreten zu sein , damit sie dort ihre Meinung einbringen kann . » Sich nach Amtsantritt von der Partei lösen zu wollen , zeuge von einem weltfremden Politikverständnis .',
#   'Die bisher dominierenden Gruppen der religiösen Schiiten und Kurden werden aber darum kämpfen , möglichst viel von ihrem Einfluss zu retten .',
#   'Im Zwiegespräch mit ihrem ausgestopften Papagei Lulu hält sie Rückschau und kämpft um ihr Recht , bis zu ihrem Tod in der Mägdekammer bleiben zu dürfen .',
#   'So kämpften die Männchen darum , mit dem ältesten Weibchen der Gruppe Sex haben zu dürfen .',
#   'Denn sie kämpfen seit Jahren darum , einen Teil der Nationalbankgewinne in die AHV zu leiten .',
#   'Insbesondere Calmy-Rey und Deiss kämpfen dafür , nicht die ganze Last tragen zu müssen .',
#   'Sie kämpft an vorderster Front dafür , preistreibende Handelshemmnisse zu beseitigen .',
#   'Dies geschah gegen den Willen des Parlaments , das in den Achtziger- und Neunzigerjahren mehrfach mit Resolutionen und vor dem Europäischen Gerichtshof um sein grundsätzliches Recht kämpfte , seinen Tagungsort selbst zu bestimmen .',
#   'Der Gegenvorschlag korrigiert diesen Mangel .',
#   'Die USA korrigieren ihren Terrorismus-Bericht .',
#   'Er korrigierte die alten Pläne .',
#   'Verwaltungsgericht korrigiert Fahrtenzahl nach unten , lockert aber Parkplatzverordnung .',
#   'Im Übrigen sind die Absatzprognosen für das ganze Jahr nach oben korrigiert worden .',
#   'Die US-Ökonomen der UBS haben deshalb die Wachstumsaussichten nach oben korrigiert .',
#   '- Der Chef des grössten Schweizer Lebensversicherers hat die Anhebung des BVG-Mindestzinses von 2,25 auf 2,5 % scharf kritisiert .',
#   'Die Uno und Amnesty International kritisieren diese scharf .',
#   'Die Kommissionen beider Kammern kritisierten die Legislaturplanung des Bundesrates und verlangen entsprechende Korrekturen .',
#   'AI kritisiert die Schweiz erneut wegen Misshandlungen von Ausländern durch die Polizei .',
#   'Er hatte das Management und den bisherigen Verwaltungsrat im Wirtschaftsmagazin « Bilanz » wegen des Umgangs mit der Buchhaltungs- und Vertrauenskrise ungewöhnlich scharf kritisiert .',
#   'Curuvija hatte den Diktator wegen seiner abenteuerlichen Politik kritisiert .',
#   'So reist er nach Moskau , zu Wladimir Putin , den alle Seiten wegen des Vorgehens gegen den Ölkonzern Jukos kritisieren .',
#   'Der Waldshuter Landrat Wütz kritisiert Unique und den Kanton Zürich wegen der geplanten Nordausrichtung des Flughafens .',
#   'Andererseits kritisiert die GPK den Umgang von Klinikdirektor und Professor Günter Burg mit ebendiesen Mängeln und mit interner Kritik .',
#   'Sunnitische Geistliche kritisierten scharf , dass auch mehrere Moscheen unter Beschuss genommen worden seien .',
#   'General-Motors-Europachef Fritz Henderson kritisierte , dass der europäische Zweig des US-Autobauers seit 1999 Verluste einfahre .',
#   'Sie kritisieren , dass es ihnen auch vier Jahre nach der Aussetzung des Embargos wirtschaftlich noch nicht besser geht und Willkür und Rechtsunsicherheit allgegenwärtig sind .',
#   'Ein Delegierter kritisierte , dass es keine Alternative zu Bortoluzzi gebe .',
#   'Amnesty International kritisiert , dass Taser zugelassen bleiben .',
#   'Die Anwälte der Khulumani-Klage kritisierten , dass Richter John Prizzo für alle Kläger gleich entschieden hat .',
#   'Wir kritisieren das sogar , weil immer noch zu viel reguliert wird .',
#   'Slobodan Milosevic kritisierte gestern Dienstag die Richter , weil sie für sein Plädoyer vier Stunden Zeit vorgesehen hätten .',
#   'Die von Finanzminister Hans Eichel beschlossenen Vorschläge zur Veräusserung von Guthaben kritisierte Wiegard , weil sie genauso belastend wirkten wie eine Neuverschuldung .',
#   'Er kritisierte den Präsidenten scharf , weil dieser dem Willen des Volkes nicht gefolgt sei .',
#   'Die Opposition kritisierte die Regierung , weil sie nicht genügend Mittel für den Kampf gegen den Schnee mobilisiert habe .',
#   'Güler kritisiert die Regierung , weil sie das Problem nicht anpacke .',
#   'Die Schweizerische Flüchtlingshilfe kritisiert den Plan , abgewiesene Asylbewerber in einer unterirdischen Militärunterkunft einzuquartieren .',
#   'Die Hilfswerke kritisieren die Absicht des Bundesrats , staatsnahe Dienstleistungen weiter liberalisieren zu wollen .',
#   '- Der Berner Regierungsrat kritisiert den Entscheid des Zürcher Regierungsrates , die interkantonale Vereinbarung zur Spitzenmedizin abzulehnen .',
#   'Bayern München hat die Pläne des Bezahlfernsehsenders Premiere kritisiert , die Champions-League-Spiele des deutschen Meisters ab Sommer 2006 nur noch im Bezahlfernsehen zu zeigen .',
#   'Mehrfach hat Hupac-Direktor Bernhard Kunz die Absicht des Bundesamtes für Verkehr kritisiert , die Rollende Autobahn auszubauen .',
#   'Er sah , wie Röthlin litt , sah die ersehnte Zeit unter 2 : 10 Stunden in Gefahr und versuchte ihm akustisch Beine zu machen .',
#   'Dort , wo Tiere ganz offensichtlich leiden .',
#   '« Palästinensische Flüchtlinge leiden jetzt » .',
#   'Das englische Herz leidet wieder einmal .',
#   'Die Darbietung litt unter der schwachen Tagesform mehrerer Schlüsselspieler .',
#   'Die Uhrenindustrie litt unter der Lungenkrankheit Sars und dem Krieg im Irak und erholte sich erst in der zweiten Jahreshälfte .',
#   'Er litt an der Verballhornung , gab sich in seiner schon recht wohl gediehenen Eitelkeit als moderner Rasengladiator gekränkt .',
#   '« Ich leide seit 2 Monaten an einer Hüftverletzung .',
#   '« Der Film leidet an einem typischen Metallica-Syndrom .',
#   'Die Frau leidet stark darunter , dass ihr Mann nicht mehr lebt .',
#   'Früher litt man noch Hunger .',
#   'Zwölf Tage litt er Todesängste .',
#   'Ambühl und Olsson können sich gut leiden , nicht nur weil der Schwede den Bündner mit seiner Brillenmarke ausrüstet .',
#   'Ich kann dieses analytische Kunstgelaber nicht leiden .',
#   'Sie sehen nur noch das Resultat und leiden daran , diesen Gestus ahistorisch und somit leer wiederholen zu müssen .',
#   'Wie alle Landesring-Politiker litt sie darunter , ständig darauf untersucht zu werden , ob sie nun ins linke oder rechte Lager gehöre .',
#   'Taiwan leidet still unter der Schizophrenie , ein souveräner demokratischer Staat zu sein , aber nicht offen als solcher behandelt zu werden , weil es die Pekinger Diktatur nicht zulässt .',
#   'Dennoch leiden die beiden unter der Vorstellung , Haus und Boden aufzugeben .',
#   'Viele leiden , wenn die Pollen zu fliegen beginnen .',
#   'Jugendliche leiden , wenn sie einseitig erzogen wurden .',
#   'Zuletzt leidet nämlich der Steuerzahler , wenn angesichts der impliziten Staatsgarantie übermässige Risiken eingegangen werden .',
#   'Sobald man verliert , leiden die Automatismen .',
#   'Es ist aber auch das früheste Beispiel dafür , dass die Musik fast immer leidet , wenn mit Reed die Ambition durchgeht : Das geteilte Berlin war ihm die Metapher für die Zerrissenheit des Menschen und seines Liebens .',
#   'Schweiz unterstützt Balkan-Dialog .',
#   'Er unterstützt insbesondere , dass als Ergänzung zur Leerkassettenabgabe auch eine Abgabe auf Vervielfältigungsgeräte vorgesehen ist .',
#   'Dass er in die Politik ging , unterstützte ich hundertprozentig .',
#   'Am Dienstag hat der Regierungsrat mitgeteilt , dass er den Entscheid des Verkehrsrats unterstützt , das Gipfelischiff aus dem Angebot des Zürcher Verkehrsverbunds zu streichen ( TA vom 4.',
#   'Das wiederum verbessert die Diversifikation eines Portfolios .',
#   'Swiss verbessert die Auslastung weiter .',
#   'Und diese beiden Parteien zogen nach und verbesserten ihre Frauenvertretung : die FDP besonders im Ständerat und in den Kantonsregierungen , die CVP bei den jüngsten Nationalratswahlen',
#   'Am stärksten verbessert hat sich die Ukraine von 2,2 auf 2,6 Punkte .',
#   'Die Eingabehilfen des Internet Explorer verbessern die Lesbarkeit von Websites , indem Schriften vergrössert und mit optimaler Farbgestaltung angezeigt werden .',
#   'Fazit der Runde : Es sei dringend nötig , die Ausbildung der Lehrkräfte zu verbessern , damit sie in der Lage sind , Homosexualität im Unterricht zu thematisieren .',
#   'Man bereitet sich vor , indem man in den Proben wirklich hart probt , und man verbessert sich , indem man nach den Auftritten eine Stärken-Schwächen-Analyse macht .',
#   'Unternehmen mit Konzentration auf dem heimischen Markt , etwa Einzelhändler , verbuchten auch starke Kursgewinne .',
#   'Mehr Online-Anzeigen verbuchten auch die Gruppen Büro und Verwaltung sowie Verkauf und Kundenberatung .',
#   'Das IKRK verurteilt solche Verbrechen vorbehaltlos .',
#   'Amnesty International verurteilt den « Anti-Terror-Feldzug » der USA .',
#   'Oppositionsführer Francesco Rutelli verurteilte die Tat .',
#   'Wir verurteilen diese Anschläge aufs Schärfste .',
#   'Die Bluttat wurde weltweit verurteilt .',
#   'In der ersten Instanz hatte die Untersuchungsbehörde den Briten , die Frau vom anderen Seilende und einen jungen Waadtländer zu bedingten Gefängnisstrafen verurteilt .',
#   'Der 52-jährige ehemalige Produktionsleiter der Apotheke im Berner Inselspital wurde deshalb zu einer Gefängnisstrafe von 20 Tagen auf Bewährung verurteilt .',
#   'Dieser wurde zu einer bedingten Gefängnisstrafe von 15 Tagen verurteilt .',
#   'In Dänemark wurde eine Firma zu einer Busse von 3000 Franken verurteilt , 30 Franken pro verschickter Werbemail .',
#   'Es verurteilte ihn wegen fahrlässiger Tötung , aber nur wegen fahrlässigen Fahrens im angetrunkenen Zustand .',
#   'Das Gericht verurteilte den Mann wegen schwerer räuberischer Erpressung und Geiselnahme .',
#   'Das Gericht in Chambéry verurteilte den 68-Jährigen am Donnerstag wegen Betrugs und Komplizenschaft bei der Ausübung illegaler medizinischer Tätigkeit , wie die Agentur AFP berichtet .',
#   '« Blick » -Journalistin verurteilt .',
#   'Für 15 Prozent der Befragten gehört der Preisüberwacher abgeschafft .',
#   'Ausweise 1952 abgeschafft .',
#   'Erbschaftssteuer teilweise abgeschafft .',
#   'Der Künstler ist damit alles andere als abgeschafft .',
#   '- Die allgemeine Volksinitiative soll nicht umgesetzt , sondern abgeschafft werden .',
#   'Emissionsabgabe soll abgeschafft werden .',
#   'Daher will der Bundesrat die Lex Koller ganz abschaffen .',
#   'Die SVP will die Deutschschweizer EDK abschaffen .',
#   'Bei einem Übergang zu einem Kontingentsystem sollten « flankierende Massnahmen » der Personenfreizügigkeit wieder abgeschafft werden .',
#   'Kommission will Prämien für Kinder abschaffen .',
#   'Die Liga hat das Penaltyschiessen im Playoff auf diese Saison hin abgeschafft .',
#   'Nach dem Entscheid des Adliswiler Gemeinderates würden die Leistungen auf den 1. Juni 2008 abgeschafft .',
#   'Das Amt wurde nach dem Sturz der Osmanen durch den türkischen Staat 1924 abgeschafft .',
#   'Die Volksinitiative will den obligatorischen Sexualkundeunterricht für Kinder unter 12 Jahren abschaffen .',
#   'Die Diskussion zeigt zudem einmal mehr , dass der Medikamentenverkauf beim Arzt abgeschafft werden sollte , dann können Arzt und Apotheker zum Wohle des Patienten zusammenarbeiten .',
#   'Sie beseitigen keinen Tyrannen , sondern ein glücklicheres Doppel ihrer selbst .',
#   'Im Gegenzug wollen die WTO-Mitglieder ihren Unternehmern den Zugang zum russischen Markt sichern und Wettbewerbsverzerrungen beseitigen .',
#   'Sie beseitigt alle Beschleunigungs- und Bewegungshindernisse : Hindernis ist , was der Akzeleration im Wege steht .',
#   'Die Vorlagen sind dazu bestimmt , Unzulänglichkeiten zu beseitigen .',
#   'Durch den Druck in Deutschland und den Aufbau eines Vertriebsnetzes mit Frühzustellung konnte dieser Missstand beseitigt werden .',
#   'Die Ursachen und Probleme der allgemeinen Abzockerei werden mittels Offenlegung der Toplöhne nicht beseitigt .',
#   'Der neue Katalysator kann so über 90 Prozent der Stickoxide aus den Abgasen beseitigen .',
#   'Der Bundesrat hat vorgeschlagen , diesen Unfug im Rahmen des Entlastungsprogramms für den Bundeshaushalt zu beseitigen .',
#   'Diese Nachteile lassen sich indes mit neuen Techniken , insbesondere Partikelfiltern , weitgehend beseitigen .',
#   'Viele dieser Mängel hat Gudrun Honke , die Lektorin des Peter-Hammer-Verlags , für die Neuausgabe beseitigt .',
#   'Doch Diogenes habe das dreiste Ansinnen zurückgewiesen .',
#   'Das Kasinounternehmen Mandalay Resort Group hat das Übernahmeangebot des Rivalen MGM Mirage erwartungsgemäss zurückgewiesen .',
#   'Speicherhersteller haben Vorwürfe eines kartellähnlichen Verhaltens zurückgewiesen .',
#   'Berlusconi hat die Vorwürfe stets zurückgewiesen und erklärt , er habe nur im Interesse des Landes interveniert .',
#   'Von einer Sprecherin des chinesischen Aussenministeriums wurde diese Annahme als gegenstandslos zurückgewiesen .',
#   'Im Frühling 2003 ist der Rat auf die Vorlage eingetreten , hat sie aber zur nochmaligen Prüfung an die Kommission zurückgewiesen .',
#   'Das Budget soll zur Überarbeitung an den Regierungsrat zurückgewiesen werden .',
#   'Der Senat in Madrid hat das Budget der Regierung Zapatero für das kommende Jahr an das Abgeordnetenhaus zurückgewiesen .',
#   'Zunächst habe man den Fall an das Gericht zurückgewiesen , so Claude Janiak .',
#   'Michail Chodorkowski , der Gründer der Erdölgesellschaft Yukos und prominenteste Häftling Russlands , hat am Freitag alle gegen ihn erhobenen Vorwürfe als absurd zurückgewiesen und sich als Opfer einer politischen Machtdemonstration bezeichnet .',
#   'Dieses Urteil wurde seinerseits vom Kassationsgericht aufgehoben und der Fall ans Obergericht zurückgewiesen .',
#   'Ansprüche von SP und SVP zurückgewiesen .',
#   'Bericht an den Ausschuss zurückgewiesen .',
#   'Einspruch Janukowitschs in Kiew zurückgewiesen .',
#   'Militär und Krieg : Das scheinen verstaubte Angelegenheiten zu sein , die auf den waffenstarrenden Geist des 19. Jahrhunderts zurückweisen .',
#   'Nach finanziell erfolgreichen Jahren dürfte der Verein die Jubiläumsausgabe - 30 Jahre - allerdings mit einem Minus in der Rechnung abschliessen .',
#   'Der Stadtrat möchte mit der Baugenossenschaft Wogeno Zürich einen Baurechtsvertrag über ein 6680 Quadratmeter grosses Areal in Schwamendingen abschliessen .',
#   'Sie sind auf Spenden angewiesen und müssen mit 171 Gemeinden einzelne Verträge abschliessen .',
#   'Damit werden sie das Turnier im schlechtesten Fall im geteilten neunten Rang abschliessen .',
#   'Künftig wird ein Berufsoffizier-Pilot seine Ausbildung mit einem Bachelor-of-Science-in-Aviation- Grad abschliessen .',
#   'Im Irak wollen viele davon freilich nichts wissen - hier will man das Kapitel Saddam so schnell wie möglich abschliessen .',
#   'So konnte die IBU für die Vierjahresperiode 2006 bis 2010 einen TV-Vertrag über 40 Millionen Euro abschliessen .',
#   'Der Abrissbagger , der die Filmdokumente gewöhnlich abschliesst , gibt ihnen freilich auch einen epischen Anstrich .',
#   'Die Regierung wolle anscheinend noch hängige Verfahren abschliessen .',
#   'Kopfschüttelnd beobachtet der Bauer von gegenüber , wie wir die gemieteten Velos abschliessen .',
#   'Was ausserdem viele nicht wissen : Auch rezeptfreie Mittel können Schaden anrichten .',
#   'Als der Fall nach drei Jahren aufflog , hatte er einen Schaden von über 37 Millionen Franken angerichtet .',
#   'Fast 4000 Katyuscha-Raketen seien bisher auf die Siedlungen niedergegangen und hätten Schäden angerichtet .',
#   'Unbekannte haben gemäss einer Meldung des Lokalradios Energy Zürich über das letzte Wochenende auf dem Zürcher « Egocity » -Areal einen Schaden von gegen 70 000 Franken angerichtet .',
#   'Am Sonntag hatten Rebellen der LRA ein Flüchtlingslager in Norduganda angegriffen und ein Blutbad angerichtet .',
#   'Die Liberaldemokraten hatten nicht teilgenommen und der Tory-Parteiführer Howard hatte sich vom Unternehmen distanziert .',
#   'Andere Demokraten distanzierten sich sofort von dieser unvorsichtigen Anschuldigung .',
#   'Mergermarket war aber offensichtlich daran gelegen , sich selbst von dieser Geschichte zu distanzieren .',
#   'Danach distanzierte er sich glaubwürdig von den undemokratischen Machenschaften Richard Nixons .',
#   'Im am Montag präsentierten Bericht distanziert sich die Expertenkommission Zimmerli jedoch grösstenteils von den Sanktionsplänen der EBK .',
#   'Ich werde sie ehren » , schrieb er .',
#   'Ebenfalls geehrt werden die « Weltfussballerin des Jahres » die « Nationaltrainer des Jahres » sowie der Schütze des schönsten Tores 2012 ( Puskas Award ) .',
#   'Ausschlaggebend für sie war , dass die Auszeichnung Menschen ehrt , « die das Land vorwärtsbringen » .',
#   'Belgien hat die Rettungskräfte geehrt , die beim Carunglück im Wallis vor rund einem Jahr im Einsatz standen .',
#   'Geehrt wurden Niklaus Helbling von der Gruppe Mass & Fieber und Ali Asghar Dashti von Don Quixote Teheran .',
#   'Im Oktober wird Quincy Jones seinen Freund Claude mit einem Event in New York ehren .',
#   'Der in Berlin lebende Autor wurde für seine « sprachliche Genauigkeit » geehrt .',
#   'Vater Phil Mulloy hatte in der Frühzeit von MTV Logos für den Musiksender gestaltet - am vorletzten Fantoche-Festival in Baden wurde er mit einer Werkschau geehrt .',
#   'Locarno ehrt den Monte Verità mit Literaturtagen .',
#   'Der Spielfilm « Hitchcock » , ein biografischer Versuch des Engländers Sacha Gervasi , ehrt den Meister durch Respekt vor seiner Maxime .',
#   'Arafat akzeptiert den jüdischen Charakter Israels .',
#   'Aus diesem Grund seien die grossen Unterschiede zwischen den Wahlkreisen nicht akzeptiert worden .',
#   'Medizinjournale akzeptieren nur noch registrierte Studien .',
#   'Muff wollte die Verfügung zunächst nicht akzeptieren und legte Einsprache ein .',
#   'Das Panel akzeptierte den EU-Einwand nicht , dass dank einer Fussnote eine zusätzliche Menge von jährlich 1,6 Mio. t Zucker für den subventionierten Export verfügbar sei .',
#   'Sie sprachen dem Präsidenten Sondervollmachten zu und akzeptieren , dass dieser mit Dekreten regiert .',
#   'Beiderseits des Rheins hat man akzeptiert , dass sich das bilaterale Verhältnis verändert hat .',
#   'Arendt konnte und wollte nicht akzeptieren , dass kulturelle und ethnische Nationen nichts anderes seien als Illusionen .',
#   'Zeitungen und andere Publikationen müssten allerdings akzeptieren , dass Medienfreiheit mit Verantwortung einhergehe .',
#   'Viele Israeli können nicht akzeptieren , dass das Leid der Juden das der Palästinenser nicht ausradiert .',
#   'Auch das Schild im Innenraum aufzuhängen , würde er akzeptieren .',
#   'Sie akzeptiert somit , spezielle Einstellhallen für die Abfallentsorgung bauen zu müssen .',
#   'Er hat akzeptiert , nie mehr laufen zu können .',
#   'Bei der Versteigerung einer Anleihe haben die Investoren akzeptiert , für ihre neuen Staatspapiere quasi eine Gebühr von 0,0029 % zu zahlen .',
#   'Viele von ihnen akzeptieren nicht , ihre Post erst um zwei Uhr nachmittags zu erhalten .',
#   'Subprime-Krise belastet stärker als Naturkatastrophen .',
#   'Hurrikanschäden und die Auswirkungen der Finanzkrise belasten zusätzlich .',
#   'Die am Vortag bekanntgegebene Kapitalerhöhung belastete .',
#   'Auch der Untergang der BP-Plattform im Golf von Mexiko belastete , wobei der Versicherer hier mit Aufwendungen im niedrigen dreistelligen Millionenbereich rechnet .',
#   'Der starke Franken belastet .',
#   'Wie Gick ausführte , belasten die Liegenschaften im Finanzvermögen die laufende Rechnung jährlich mit über 8 Millionen Franken .',
#   'Die russische Aussenpolitik belastet sich mit unnötigen Selbstunfällen .',
#   'Der harte Winter belastet das Budget mit einem zusätzlichen Betrag von 2,3 Millionen Franken .',
#   "Marino lässt die Mannschaft konsequent in 3 : 4 : 3-Formation spielen , was besonders die zentralen Mittelfeldspieler D ' Agostino und Inler mit Defensivaufgaben belastet .",
#   'Kerviel belastet das Management mit der Behauptung , es habe von seinen Spekulationen und Vertuschungen gewusst , die Verluste von 4,9 Mrd. € zur Folge hatten .',
#   'Ihn belastet auch , dass er wegen der Schichtarbeit am Wochenende auf seine Prüfungen lernen muss .',
#   'Aber es belastete mich , dass man nicht auf der menschlichen Ebene kommunizierte .',
#   'Dass der Fed-Vorsitzende zugleich die Entwicklung der Inflation als seine grösste Sorge bezeichnete , belastete den Markt stärker , als sein verhalten optimistisches Bild vom US-Wachstum die Stimmung aufhellen konnte .',
#   'Ihn belastet nun aber auch , dass die Abteilung , die er so viele Jahre mitgeführt hat , tief in den Libor-Skandal verstrickt ist - die schwerste Altlast der Deutschen Bank .',
#   'Es belastet ihn sichtlich , dass der Blutzoll unter japanischen Kollegen hoch war .',
#   'Die Ablieferung des gesamten Abfalls belastete er dann der Gemeinde .',
#   'Gleichzeitig belastete ihm Postfinance je 20 Franken für die Mahnung und die Sperrung seines Kontos .',
#   'Sie belasten dem Kunden quartalsweise eine Gebühr .',
#   'Der Dekonsolidierungsverlust von 0,4 Mio. Fr. wurde der Rechnung des ersten Semesters belastet .',
#   'Beides wurde dem Investment Banking belastet .',
#   'Auch das Schweizer Fernsehen berücksichtigt diese Erkenntnis .',
#   'Oft berücksichtigt der Staat die teuerste Offerte , was der Korruption Tür und Tor öffnet .',
#   'Das Übereinkommen berücksichtigt aber auch die wirtschaftlichen Interessen der Reeder .',
#   'Nach seiner Ansicht haben die Finanzmärkte diese Spannungen nicht genügend berücksichtigt .',
#   'Die erstmals überhaupt erhobenen Zahlen berücksichtigen nur Unternehmen , die ihre Tätigkeit in der Schweiz vollständig eingestellt haben .',
#   'Das zweite Argument berücksichtigt , dass immer mehr japanische Unternehmen ihre Produktionsstätten ins Ausland verlagern .',
#   'Die ARK berücksichtigte , dass neue Beweismittel vorgebracht wurden .',
#   'Die Verstärkung des Netzes berücksichtigt auch , dass das EWZ den Bau eines neuen Unterwerks Waldegg ab etwa 2018 plant .',
#   'Die Kritiker von rechts berücksichtigen aber nicht , dass die Anreizeffekte des Privateigentums keine Präferenzen erzeugen .',
#   'Er gewichtet inzwischen gruppeninterne Prozesse stärker und berücksichtigt nicht mehr , ob dem Innenverteidiger Johan Djourou Wettkampfpraxis fehlt .',
#   'Doch in der Berufung konnte sie sich durchsetzen .',
#   'SEC hat hohe Geldbussen durchgesetzt .',
#   'SVP kann sich nicht durchsetzen .',
#   'Die republikanische Mehrheit im Repräsentantenhaus hat eine Änderung der politischen Standesregeln durchgesetzt .',
#   'Mölzer will den Wiener FPÖ-Chef Strache als neuen Parteichef durchsetzen .',
#   'Andreu hatte sich in einer internationalen Ausschreibung gegen 68 Mitbewerber durchgesetzt und trotz kontroverser Diskussion in den Medien und der Öffentlichkeit den Zuschlag für das Prestigeprojekt erhalten .',
#   'Der 77-jährige Adamkus hatte sich Ende Juni in einer Stichwahl gegen die frühere Ministerpräsidentin Kazimira Prunskiene durchgesetzt .',
#   'In Florida konnte sich dagegen der Republikaner Mel Martinez nach langem Warten knapp durchsetzen .',
#   'Aber man muss auch daran erinnern , dass die Finanzierung der Investitionen für den öffentlichen Verkehr gegen den Widerstand der stärksten politischen Kraft Zürichs durchgesetzt werden musste und dass dafür andere politische Kräfte auch in Zürich einen Preis bezahlt haben .',
#   'FDP , SVP und CVP hatten sich mit ihren Vorstössen erfolgreich durchgesetzt .',
#   'Hier will er durchsetzen , dass die AHV für Personen mit tieferen Einkommen 80 Prozent des vorangegangenen Lohnes entspricht .',
#   'Denn mithilfe des Abkommens konnte der Diktator durchsetzen , dass das dem Deutschen Reich zugestandene Gebiet den gesamten Ring der tschechischen Befestigungsanlagen einschloss .',
#   'Bei Exit hat man eben durchgesetzt , dass keine Ausländer mehr begleitet werden .',
#   'Im Klartext hat der Bundesrat durchgesetzt , dass ganz grosse Akquisitionen ausgeschlossen sind .',
#   'Der Konzern will durchsetzen , dass das Krebsmittel Glivec vom indischen Patentamt einen Patentschutz erhält .',
#   'Bei ihr hatte der aus der Grafschaft Dorset im Südwesten Englands stammende Bauernsohn zwei Jahre studiert und derweil durchgesetzt , Musiker zu werden .',
#   'Weil er den Lokalhelden David Aebischer nicht engagiert hat , wird Monsieur Directeur angefeindet .',
#   'Kloten engagiert Jeff Halpern .',
#   'Parallel zur publizistischen Karriere engagierte sich Fritschi auch politisch .',
#   'Er engagierte sich vielfältig .',
#   'Sowohl Frauen wie auch Männer engagieren sich ehrenamtlich , aber es gibt Unterschiede .',
#   'IOK engagiert sich im Kampf gegen Aids .',
#   'In der nationalen Politik engagierte er sich mit Erfolg für die Einführung des Anti-Rassismus-Gesetzes .',
#   'Uglow engagiert sich landesweit für die Abstinenz .',
#   'Sie heiratete jung , gebar drei Kinder , engagierte sich in Kirche und Gesellschaft - und blieb ihrer Heimatstadt treu .',
#   'Wie nie zuvor engagierten sich die Medien weltweit bei den US-Wahlen und versuchten die US- Innenpolitik - auch mit Wahlempfehlungen - zur Weltinnenpolitik zu erklären .',
#   'Wir engagieren uns , dass künftig das Fest für alle stattfindet ! » Markus Arnold , Präsident der CVP des Kantons Zürich .',
#   'Das ist Lebensqualität . » Deshalb hat er sich engagiert , dass die Richterswiler Fontäne wieder spritzt , deshalb fährt er mit seinem Bus durch Richterswil und verkauft Brot und Milch vor den Haustüren , deshalb hat er einen Vorschlag eingereicht für den Kreisel an der Zugerstrasse .',
#   'Schliesslich wurde er engagiert , mit acht Studenten eine Dozenten-Imitationsshow für die 150 Jahr-Feier der ETH aufzuführen .',
#   'Sofort engagierte sie sich , Neuankömmlingen dieses Wissen weiterzugeben .',
#   'Letzterer kündigte in München an , Deutschland werde sich stärker engagieren , Konflikte vor der Haustür Europas einzudämmen , bevor militärisches Eingreifen nötig werde .',
#   'Sie gefährdet die journalistische Unabhängigkeit .',
#   'Korruption gefährdet die Erfolge des baltischen Staates .',
#   'Die stagnierende britische Wirtschaft gefährdet das Ziel der Defizitbeseitigung und den Zusammenhalt der Koalitionsregierung .',
#   'Der Ausbau des Fahrplans gefährdet die Sicherheit .',
#   'Die Halbierung der Geburtenzahlen seit 1994 gefährdet die Existenz von Schulen , und die Post reduziert ihre Dienststellen .',
#   'Aufgrund der bisherigen Vorbereitung und der Routine scheinen Hollenstein und Grossmann am meisten gefährdet , dem letzten Cut zum Opfer zu fallen .',
#   'Bekanntlich sind Leute wie er , die gern vom Teufel sprechen , besonders gefährdet , von diesem hinters Licht geführt zu werden .',
#   'Einer konnte verhaftet werden , der andere flüchtete .',
#   'Die Polizei verhaftete wenig später zwei Tatverdächtige .',
#   'Er wurde von Stadtpolizisten verhaftet .',
#   'Die serbische Polizei hatte mehrere Dutzend Personen verhaftet , Drogenlabors ausgehoben und grosse Mengen Betäubungsmittel beschlagnahmt .',
#   'Die Polizei verhaftet ihn , und man lässt ihn anschliessend wieder frei .',
#   'Doch der Entscheid war umstritten : Mehrere Gutachten verteidigten den Tyrannenmord .',
#   'Die meisten Israeli verteidigen sowohl die Aktion als auch deren Zeitpunkt .',
#   'Die Regierung verteidigt ihren Schritt , ihrer Kollegin einen wesentlichen Teil der Kompetenzen entzogen zu haben , und die Tessiner Freisinnigen stehen vor wichtigen Entscheidungen .',
#   'Bundesrat verteidigt Abgabe von Taschenmunition .',
#   'Stadtrat Martin Vollenwyder verteidigt sich .',
#   'Er lobte das « pragmatische Vorgehen » der Regierung und verteidigte auch , dass der Kantonsrat nur informiert , aber nicht befragt wurde .',
#   'Dass er durchaus europäischen Weitblick hat , bewies Regierungschef Schüssel , indem er vehement verteidigt hat , dass Österreich künftig einen höheren EU Nettobeitrag leisten muss .',
#   '( ap ) Der amerikanische Wirtschaftswissenschafter Jeffrey Sachs , ein Berater des Uno-Generalsekretärs Annan , hat die afrikanischen Länder aufgefordert , ihre Interessen gegenüber den Industrienationen offensiv zu verteidigen .',
#   'Die Regierung verteidigte sich mit Haushaltüberlegungen .',
#   'Auf den reifen Märkten verteidigt die Firma ihre Stellung mit Innovationen .',
#   'Die Behörden selbst allerdings mussten sich am Mittwoch gegen den Vorwurf der Inkompetenz verteidigen .',
#   'Rahner bleibt an diesem Punkt unklar , verteidigt aber die menschliche Freiheit gegen reduktionistische Anthropologien .',
#   'Geringste Leitungsengpässe , entstanden durch nicht realisierte Investitionen , verschlechtern die Stromqualität .',
#   'Eine Verwahrung würde die Prognose für den Angeklagten verschlechtern .',
#   'Die Maturitätsreform hat diese Situation weiter verschlechtert .',
#   'Die Geschäftslage des hoch verschuldeten Kanaltunnel-Betreibers Eurotunnel hat sich weiter verschlechtert .',
#   'Der Bau der ersten Wohnungen verläuft schleppend , da die Wirtschaftslage sich verschlechtert hat und der Wohnungsmarkt seit einiger Zeit stagniert .',
#   'Für die betroffene Bevölkerung habe sich Lebensqualität infolge der zunehmenden Lärm- und Abgasbelastung erheblich verschlechtert .',
#   'Offenbar ist Quattrones Ehefrau seit einigen Jahren krank , und ihr Zustand verschlechtere sich wegen des Prozesses weiter .',
#   'Die fiskalpolitische Disziplin verschlechterte sich um 4 % des BIP .',
#   'Für viele verschlechterte sich die ohnehin schwache Jahresperformance nochmals .',
#   'Durch die Ausgliederung der Spedition der Bruno Piatti werden die Arbeitsbedingungen laut Gewerkschaftsangaben deutlich verschlechtert .',
#   'Die Rekurrenten bemängeln die Anzahl der Parkplätze und das Fehlen einer Umweltverträglichkeitsprüfung .',
#   '\n'],
#  [[('p', '3', '7'), ('c', '11', '13')],
#   [('c', '14', '17')],
#   [('c', '2', '6')],
#   [('c', '3', '16')],
#   [('c', '7', '21')],
#   [('c', '1', '6')],
#   [],
#   [('c', '2', '8')],
#   [],
#   [('p', '1', '8')],
#   [('c', '3', '6')],
#   [],
#   [('c', '4', '7')],
#   [],
#   [('p', '13', '10')],
#   [],
#   [],
#   [],
#   [('c', '6', '3')],
#   [],
#   [('p', '3', '8'), ('p', '3', '11')],
#   [],
#   [('p', '2', '7')],
#   [],
#   [],
#   [],
#   [],
#   [('c', '3', '8')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '20', '14')],
#   [],
#   [('c', '2', '11')],
#   [('c', '3', '8')],
#   [('c', '8', '13')],
#   [('p', '1', '5')],
#   [('c', '4', '8'), ('c', '10', '11')],
#   [],
#   [],
#   [],
#   [('c', '1', '5')],
#   [('p', '2', '7')],
#   [],
#   [],
#   [('p', '2', '7')],
#   [('p', '7', '8')],
#   [],
#   [('c', '2', '4')],
#   [],
#   [('c', '1', '3')],
#   [('c', '1', '3')],
#   [('c', '1', '4'), ('c', '1', '6')],
#   [('p', '1', '14'), ('c', '1', '8')],
#   [],
#   [],
#   [('p', '3', '15'), ('c', '3', '7')],
#   [],
#   [],
#   [('c', '4', '7')],
#   [],
#   [],
#   [('c', '2', '12'), ('c', '2', '18')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '16', '6')],
#   [],
#   [],
#   [],
#   [('c', '17', '10')],
#   [],
#   [],
#   [('p', '25', '29')],
#   [],
#   [],
#   [],
#   [],
#   [('p', '18', '24'), ('p', '18', '20')],
#   [],
#   [],
#   [('c', '2', '7')],
#   [],
#   [('c', '4', '6')],
#   [],
#   [('p', '2', '19'), ('c', '2', '13'), ('c', '2', '11')],
#   [('c', '3', '8')],
#   [('c', '2', '5')],
#   [('c', '2', '9'), ('c', '2', '4')],
#   [('c', '2', '7')],
#   [('c', '2', '4')],
#   [],
#   [('c', '3', '5')],
#   [('p', '1', '3')],
#   [],
#   [('p', '2', '7')],
#   [('p', '1', '4')],
#   [('c', '1', '6'), ('p', '1', '4')],
#   [],
#   [],
#   [('c', '1', '3')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '6', '2')],
#   [],
#   [],
#   [('p', '2', '4')],
#   [('p', '11', '28'), ('p', '11', '31')],
#   [],
#   [],
#   [],
#   [],
#   [('p', '1', '7'), ('p', '1', '5')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '1', '4')],
#   [],
#   [('c', '5', '3')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '3', '6')],
#   [('c', '3', '6')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '1', '10'), ('c', '1', '8')],
#   [('c', '1', '4'), ('c', '1', '6')],
#   [('c', '1', '4')],
#   [('c', '2', '4')],
#   [('c', '2', '5')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '1', '4')],
#   [('c', '3', '17'), ('c', '1', '17')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '1', '8'), ('p', '1', '16'), ('p', '1', '4')],
#   [],
#   [('p', '1', '5')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '6', '9')],
#   [('p', '2', '8')],
#   [('p', '1', '5')],
#   [('c', '13', '17')],
#   [],
#   [],
#   [('c', '1', '4')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '1', '9')],
#   [('p', '9', '26')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '4', '7')],
#   [('c', '2', '7')],
#   [('c', '1', '4'), ('c', '1', '7')],
#   [('c', '1', '8')],
#   [('c', '1', '4'), ('c', '1', '8')],
#   [],
#   [],
#   [('c', '4', '6')],
#   [],
#   [],
#   [('c', '1', '21'), ('c', '1', '23')],
#   [('c', '2', '10')],
#   [('c', '1', '6')],
#   [('c', '2', '8')],
#   [],
#   [('c', '1', '7')],
#   [('c', '13', '9'), ('c', '13', '7')],
#   [('c', '1', '4')],
#   [('c', '2', '5')],
#   [('c', '1', '4')],
#   [('c', '3', '6')],
#   [('c', '2', '7'), ('c', '2', '5')],
#   [('c', '4', '7'), ('c', '4', '10'), ('p', '4', '14')],
#   [],
#   [('c', '3', '9'), ('c', '3', '7')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '1', '5')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '1', '3')],
#   [('c', '1', '5')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '1', '3')],
#   [('p', '1', '12')],
#   [],
#   [('p', '9', '11'), ('p', '9', '13'), ('c', '13', '17')],
#   [],
#   [],
#   [('p', '4', '10')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '2', '5')],
#   [('c', '1', '9'), ('c', '1', '6')],
#   [('c', '1', '6')],
#   [('c', '1', '4')],
#   [],
#   [('c', '7', '9'), ('c', '7', '12'), ('c', '7', '19')],
#   [],
#   [],
#   [],
#   [('c', '1', '3')],
#   [('c', '2', '5')],
#   [('c', '2', '7')],
#   [],
#   [('c', '3', '8')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '4', '6')],
#   [('c', '2', '6')],
#   [],
#   [('c', '1', '3')],
#   [('c', '2', '5')],
#   [],
#   [],
#   [('c', '2', '6')],
#   [],
#   [],
#   [('c', '5', '15')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '2', '7')],
#   [],
#   [],
#   [],
#   [('c', '2', '10'), ('c', '2', '8')],
#   [],
#   [('c', '1', '4')],
#   [],
#   [('p', '6', '9')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '4', '8')],
#   [('c', '8', '13')],
#   [('c', '2', '9')],
#   [],
#   [('c', '3', '9')],
#   [('c', '9', '15')],
#   [('p', '1', '3')],
#   [],
#   [],
#   [('p', '1', '4')],
#   [],
#   [('p', '4', '7')],
#   [],
#   [],
#   [('p', '1', '4')],
#   [],
#   [('p', '1', '5')],
#   [],
#   [],
#   [('p', '1', '10'), ('c', '1', '4')],
#   [('c', '2', '5')],
#   [('p', '1', '4')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '1', '6')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '1', '4')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '4', '3')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '2', '8')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '3', '8')],
#   [('p', '1', '5')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '5', '11')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('p', '6', '12')],
#   [('p', '1', '7')],
#   [('p', '1', '14'), ('p', '1', '12')],
#   [],
#   [],
#   [],
#   [],
#   [('p', '3', '6')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [('c', '2', '7')],
#   [],
#   [],
#   [('c', '2', '4')],
#   [],
#   [('p', '3', '7'), ('p', '3', '11')],
#   [('c', '2', '8')],
#   [('p', '1', '3')],
#   [],
#   [('p', '1', '6'), ('p', '1', '9')],
#   [],
#   [],
#   [],
#   [],
#   [('c', '2', '11')],
#   [('c', '1', '15'), ('p', '1', '12')],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []]]

# %%
# df = pd.DataFrame(sent_list).rename(columns={0: "content"})

# %%
# df

# %%
# df.to_csv(EXPORT_PATH, sep="\t")

# %% [markdown]
# ### Generate Inferred Relations
#
# Are all these relations inferred?
#
# Sometimes the source is 0, which hints at a **passive construction**.
#
# **Ignore** holderless and targetless constructions currently!!!

# %%
rels = []
sents_list = gold_standard[0]
rels_list = gold_standard[1]

for i, s, r in zip(range(len(sents_list)), sents_list, rels_list):
    # split sentence
    tokens = s.split(" ")
    for rel in r:
        arg1_head = tokens[int(rel[1]) - 1]
        arg2_head = tokens[int(rel[2]) - 1]
        rel_type = "pro" if rel[0]=="p" else "con"

        ### TODO => how do we extract this.
        # get the charspans of the verbs, heads and phrases
        charspan_arg1_head = s.find(arg1_head)
        charspan_arg2_head = s.find(arg2_head)
        
        verb_form_dummy=tokens[-1]
        charspan_verb_form_dummy = s.find(verb_form_dummy)

        rels.append({
                        "doc_id": i,
                        "verb_form": verb_form_dummy,
                        "verb_form_start": charspan_verb_form_dummy,
                        "verb_form_end": charspan_verb_form_dummy + len(verb_form_dummy),
                        "verb_lemma": None,
                        "arg1": None,
                        "arg1_start": None,
                        "arg1_end": None,
                        "arg1_pos": None,
                        "arg1_head": arg1_head,
                        "arg1_head_start": charspan_arg1_head,
                        "arg1_head_end": charspan_arg1_head + len(arg1_head),
                        "arg2": None,
                        "arg2_start": None,
                        "arg2_end": None,
                        "arg2_pos": None,
                        "arg2_head": arg2_head,
                        "arg2_head_start": charspan_arg2_head,
                        "arg2_head_end": charspan_arg2_head + len(arg2_head),
                        "rel_type": rel_type,
                        "pred_serial": None,
                        "full_sentence_text": s,
        })

# %%
rels
# Out:
# [{'doc_id': 0,
#   'verb_form': '.',
#   'verb_form_start': 97,
#   'verb_form_end': 98,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'er',
#   'arg1_head_start': 13,
#   'arg1_head_end': 15,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Ausgabenkürzungen',
#   'arg2_head_start': 32,
#   'arg2_head_end': 49,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Dabei machte er sich primär für Ausgabenkürzungen stark , während er von Steuererhöhungen abriet .'},
#  {'doc_id': 0,
#   'verb_form': '.',
#   'verb_form_start': 97,
#   'verb_form_end': 98,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'er',
#   'arg1_head_start': 13,
#   'arg1_head_end': 15,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Steuererhöhungen',
#   'arg2_head_start': 73,
#   'arg2_head_end': 89,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Dabei machte er sich primär für Ausgabenkürzungen stark , während er von Steuererhöhungen abriet .'},
#  {'doc_id': 1,
#   'verb_form': '.',
#   'verb_form_start': 152,
#   'verb_form_end': 153,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'CEO',
#   'arg1_head_start': 96,
#   'arg1_head_end': 99,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Teilnahme',
#   'arg2_head_start': 111,
#   'arg2_head_end': 120,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Bundesrätin Calmy-Rey ist allerdings der Einladung zum Gipfeltreffen nicht gefolgt , und einige CEO haben ihre Teilnahme ebenfalls kurzfristig abgesagt .'},
#  {'doc_id': 2,
#   'verb_form': '.',
#   'verb_form_start': 93,
#   'verb_form_end': 94,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Bundesgericht',
#   'arg1_head_start': 4,
#   'arg1_head_end': 17,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Beschwerde',
#   'arg2_head_start': 44,
#   'arg2_head_end': 54,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Bundesgericht hat eine staatsrechtliche Beschwerde der SVP des Kantons Zürich abgewiesen .'},
#  {'doc_id': 3,
#   'verb_form': '.',
#   'verb_form_start': 159,
#   'verb_form_end': 160,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Zeuske',
#   'arg1_head_start': 15,
#   'arg1_head_end': 21,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Wirtschaftssystem',
#   'arg2_head_start': 102,
#   'arg2_head_end': 119,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Generell ortet Zeuske denn auch die Krise Kubas zuerst in dem herrschenden absurden und ineffizienten Wirtschaftssystem , das jegliche Eigeninitiative abwürgt .'},
#  {'doc_id': 4,
#   'verb_form': '.',
#   'verb_form_start': 216,
#   'verb_form_end': 217,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Rebellenführer',
#   'arg1_head_start': 52,
#   'arg1_head_end': 66,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Regierungschef',
#   'arg2_head_start': 167,
#   'arg2_head_end': 181,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'In einer Videoaufzeichnung hat der tschetschenische Rebellenführer Aslan Maschadow eine Intensivierung der Kämpfe auf fremdem Territorium angekündigt und dem nächsten Regierungschef die sofortige Ermordung angedroht .'},
#  {'doc_id': 5,
#   'verb_form': '.',
#   'verb_form_start': 90,
#   'verb_form_end': 91,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Hofstetter',
#   'arg1_head_start': 0,
#   'arg1_head_end': 10,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Gewerkschaften',
#   'arg2_head_start': 34,
#   'arg2_head_end': 48,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Hofstetter wirft im Interview den Gewerkschaften vor , sie wollen die Branche anschwärzen .'},
#  {'doc_id': 7,
#   'verb_form': '.',
#   'verb_form_start': 92,
#   'verb_form_end': 93,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Volk',
#   'arg1_head_start': 4,
#   'arg1_head_end': 8,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Schuldenspirale',
#   'arg2_head_start': 44,
#   'arg2_head_end': 59,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Volk hat mehrfach gegen die ungebremste Schuldenspirale aufbegehrt - unmissverständlich .'},
#  {'doc_id': 9,
#   'verb_form': '.',
#   'verb_form_start': 154,
#   'verb_form_end': 155,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sarkozy',
#   'arg1_head_start': 0,
#   'arg1_head_end': 7,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Mitarbeiter',
#   'arg2_head_start': 50,
#   'arg2_head_end': 61,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sarkozy kündigte auch bescheidene Prämien für die Mitarbeiter von Arbeitsgruppen an , die sich durch besonders gute Resultate und Effizienz auszeichneten .'},
#  {'doc_id': 10,
#   'verb_form': '.',
#   'verb_form_start': 114,
#   'verb_form_end': 115,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'er',
#   'arg1_head_start': 12,
#   'arg1_head_end': 14,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Ministerin',
#   'arg2_head_start': 28,
#   'arg2_head_end': 38,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Zuvor hatte er bereits eine Ministerin , die ihre Familie unrechtmässig begünstigt hatte , in die Wüste geschickt .'},
#  {'doc_id': 12,
#   'verb_form': '.',
#   'verb_form_start': 119,
#   'verb_form_end': 120,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'man',
#   'arg1_head_start': 17,
#   'arg1_head_end': 20,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Generation',
#   'arg2_head_start': 33,
#   'arg2_head_end': 43,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Und damit belügt man erneut eine Generation , die das Kriegsende und die Schrecken dieser Zeit nicht selbst erlebt hat .'},
#  {'doc_id': 14,
#   'verb_form': '.',
#   'verb_form_start': 128,
#   'verb_form_end': 129,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Chauffeuse',
#   'arg1_head_start': 57,
#   'arg1_head_end': 67,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'NZZ',
#   'arg2_head_start': 45,
#   'arg2_head_end': 48,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Den Wechsel von der « Aargauer Zeitung » zur NZZ hat die Chauffeuse nie bereut , denn das Arbeitsklima sei hier deutlich besser .'},
#  {'doc_id': 18,
#   'verb_form': '.',
#   'verb_form_start': 88,
#   'verb_form_end': 89,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Jugendkammer',
#   'arg1_head_start': 38,
#   'arg1_head_end': 50,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Mittäter',
#   'arg2_head_start': 15,
#   'arg2_head_end': 23,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Einen weiteren Mittäter bestrafte die Jugendkammer mit 80 Stunden gemeinnütziger Arbeit .'},
#  {'doc_id': 20,
#   'verb_form': '.',
#   'verb_form_start': 107,
#   'verb_form_end': 108,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Experten',
#   'arg1_head_start': 14,
#   'arg1_head_end': 22,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Lernfähigkeit',
#   'arg2_head_start': 61,
#   'arg2_head_end': 74,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Schweizer Experten ihrerseits bewundern ausdrücklich die Lernfähigkeit und den Fleiss der Nordkoreaner .'},
#  {'doc_id': 20,
#   'verb_form': '.',
#   'verb_form_start': 107,
#   'verb_form_end': 108,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Experten',
#   'arg1_head_start': 14,
#   'arg1_head_end': 22,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Fleiss',
#   'arg2_head_start': 83,
#   'arg2_head_end': 89,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Schweizer Experten ihrerseits bewundern ausdrücklich die Lernfähigkeit und den Fleiss der Nordkoreaner .'},
#  {'doc_id': 22,
#   'verb_form': '.',
#   'verb_form_start': 109,
#   'verb_form_end': 110,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sicherheitsrat',
#   'arg1_head_start': 4,
#   'arg1_head_end': 18,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Entsendung',
#   'arg2_head_start': 38,
#   'arg2_head_end': 48,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Der Sicherheitsrat hat Ende April die Entsendung einer 8000 Mann starken Blauhelm-Truppe für Haiti gebilligt .'},
#  {'doc_id': 27,
#   'verb_form': '.',
#   'verb_form_start': 67,
#   'verb_form_end': 68,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'ich',
#   'arg1_head_start': 7,
#   'arg1_head_end': 10,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'ihm',
#   'arg2_head_start': 31,
#   'arg2_head_end': 34,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': '« Aber ich ekele mich doch vor ihm » , rief Shahla verzweifelt aus .'},
#  {'doc_id': 33,
#   'verb_form': '.',
#   'verb_form_start': 131,
#   'verb_form_end': 132,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Komitee',
#   'arg1_head_start': 103,
#   'arg1_head_end': 110,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'der',
#   'arg2_head_start': 32,
#   'arg2_head_end': 35,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Den noch vakanten Sitz im Gemeinderat eroberte Urs Gassmann ( neu ) , der von einem ad hoc gegründeten Komitee portiert worden war .'},
#  {'doc_id': 35,
#   'verb_form': '.',
#   'verb_form_start': 105,
#   'verb_form_end': 106,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Angreifer',
#   'arg1_head_start': 4,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Stützpunkt',
#   'arg2_head_start': 66,
#   'arg2_head_end': 76,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Angreifer feuerten in mindestens zehn Salven Granaten auf den Stützpunkt einer Versorgungseinheit ab .'},
#  {'doc_id': 36,
#   'verb_form': '.',
#   'verb_form_start': 44,
#   'verb_form_end': 45,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'er',
#   'arg1_head_start': 12,
#   'arg1_head_end': 14,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Zeiten',
#   'arg2_head_start': 37,
#   'arg2_head_end': 43,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Dann flucht er wieder über die neuen Zeiten .'},
#  {'doc_id': 37,
#   'verb_form': '.',
#   'verb_form_start': 146,
#   'verb_form_end': 147,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Publizist',
#   'arg1_head_start': 41,
#   'arg1_head_end': 50,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'alle',
#   'arg2_head_start': 78,
#   'arg2_head_end': 82,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'In einer Talkshow giftete am Sonntag der Publizist Arnulf Baring heftig gegen alle , die nicht seiner ausgesprochen realpolitischen Meinung waren .'},
#  {'doc_id': 38,
#   'verb_form': '.',
#   'verb_form_start': 99,
#   'verb_form_end': 100,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Doris',
#   'arg1_head_start': 0,
#   'arg1_head_end': 5,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Nachfolger',
#   'arg2_head_start': 30,
#   'arg2_head_end': 40,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Doris Fiala gratulierte ihrem Nachfolger und rief zur Zusammenarbeit zwischen Stadt und Kanton auf .'},
#  {'doc_id': 39,
#   'verb_form': '.',
#   'verb_form_start': 86,
#   'verb_form_end': 87,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'sie',
#   'arg1_head_start': 15,
#   'arg1_head_end': 18,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Mädchen',
#   'arg2_head_start': 35,
#   'arg2_head_end': 42,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Noch jetzt ist sie empört über ein Mädchen , das sie wegen ihrer roten Haare hänselte .'},
#  {'doc_id': 39,
#   'verb_form': '.',
#   'verb_form_start': 86,
#   'verb_form_end': 87,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'das',
#   'arg1_head_start': 45,
#   'arg1_head_end': 48,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'sie',
#   'arg2_head_start': 15,
#   'arg2_head_end': 18,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Noch jetzt ist sie empört über ein Mädchen , das sie wegen ihrer roten Haare hänselte .'},
#  {'doc_id': 43,
#   'verb_form': '.',
#   'verb_form_start': 40,
#   'verb_form_end': 41,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Microsoft',
#   'arg1_head_start': 0,
#   'arg1_head_end': 9,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'EU-Kommission',
#   'arg2_head_start': 26,
#   'arg2_head_end': 39,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Microsoft klagt gegen die EU-Kommission .'},
#  {'doc_id': 44,
#   'verb_form': '.',
#   'verb_form_start': 64,
#   'verb_form_end': 65,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Privatsektor',
#   'arg1_head_start': 4,
#   'arg1_head_end': 16,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Engagement',
#   'arg2_head_start': 53,
#   'arg2_head_end': 63,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Der Privatsektor lechzt ebenfalls nach ausländischem Engagement .'},
#  {'doc_id': 47,
#   'verb_form': '.',
#   'verb_form_start': 85,
#   'verb_form_end': 86,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Präsident',
#   'arg1_head_start': 4,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Bemühungen',
#   'arg2_head_start': 53,
#   'arg2_head_end': 63,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Der Präsident von Serbien-Montenegro lobte Kroatiens Bemühungen um EU-Mitgliedschaft .'},
#  {'doc_id': 48,
#   'verb_form': '.',
#   'verb_form_start': 130,
#   'verb_form_end': 131,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'die',
#   'arg1_head_start': 37,
#   'arg1_head_end': 40,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'ihm',
#   'arg2_head_start': 41,
#   'arg2_head_end': 44,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Inzwischen missioniert er für jene , die ihm den Rückgewinn von mehr Lebensqualität ermöglicht haben : die Schweizer Firma Phonak .'},
#  {'doc_id': 50,
#   'verb_form': '.',
#   'verb_form_start': 44,
#   'verb_form_end': 45,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Journalisten',
#   'arg1_head_start': 9,
#   'arg1_head_end': 21,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Zeitungen',
#   'arg2_head_start': 34,
#   'arg2_head_end': 43,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Tessiner Journalisten kritisieren Zeitungen .'},
#  {'doc_id': 52,
#   'verb_form': '.',
#   'verb_form_start': 36,
#   'verb_form_end': 37,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Parlamentarier',
#   'arg1_head_start': 0,
#   'arg1_head_end': 14,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Lombardi',
#   'arg2_head_start': 27,
#   'arg2_head_end': 35,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Parlamentarier kritisieren Lombardi .'},
#  {'doc_id': 53,
#   'verb_form': '.',
#   'verb_form_start': 41,
#   'verb_form_end': 42,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Ausländerkommission',
#   'arg1_head_start': 0,
#   'arg1_head_end': 19,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Statistik',
#   'arg2_head_start': 31,
#   'arg2_head_end': 40,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Ausländerkommission kritisiert Statistik .'},
#  {'doc_id': 54,
#   'verb_form': '.',
#   'verb_form_start': 52,
#   'verb_form_end': 53,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Kerry',
#   'arg1_head_start': 0,
#   'arg1_head_end': 5,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Aussenpolitik',
#   'arg2_head_start': 21,
#   'arg2_head_end': 34,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Kerry kritisiert die Aussenpolitik der US-Regierung .'},
#  {'doc_id': 54,
#   'verb_form': '.',
#   'verb_form_start': 52,
#   'verb_form_end': 53,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Kerry',
#   'arg1_head_start': 0,
#   'arg1_head_end': 5,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'US-Regierung',
#   'arg2_head_start': 39,
#   'arg2_head_end': 51,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Kerry kritisiert die Aussenpolitik der US-Regierung .'},
#  {'doc_id': 55,
#   'verb_form': '.',
#   'verb_form_start': 128,
#   'verb_form_end': 129,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Rambert',
#   'arg1_head_start': 0,
#   'arg1_head_end': 7,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Regeln',
#   'arg2_head_start': 81,
#   'arg2_head_end': 87,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Rambert kritisierte , dass mit der « Fotoshow » geradezu lehrbuchhaft gegen alle Regeln einer Einvernahme verstossen worden sei .'},
#  {'doc_id': 55,
#   'verb_form': '.',
#   'verb_form_start': 128,
#   'verb_form_end': 129,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Rambert',
#   'arg1_head_start': 0,
#   'arg1_head_end': 7,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Fotoshow',
#   'arg2_head_start': 37,
#   'arg2_head_end': 45,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Rambert kritisierte , dass mit der « Fotoshow » geradezu lehrbuchhaft gegen alle Regeln einer Einvernahme verstossen worden sei .'},
#  {'doc_id': 58,
#   'verb_form': '.',
#   'verb_form_start': 134,
#   'verb_form_end': 135,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Medien',
#   'arg1_head_start': 22,
#   'arg1_head_end': 28,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Tadic',
#   'arg2_head_start': 117,
#   'arg2_head_end': 122,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Unabhängige serbische Medien kritisierten , dass Kostunica seine Anhänger nicht unmissverständlich aufforderte , für Tadic zu stimmen .'},
#  {'doc_id': 58,
#   'verb_form': '.',
#   'verb_form_start': 134,
#   'verb_form_end': 135,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Medien',
#   'arg1_head_start': 22,
#   'arg1_head_end': 28,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Kostunica',
#   'arg2_head_start': 49,
#   'arg2_head_end': 58,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Unabhängige serbische Medien kritisierten , dass Kostunica seine Anhänger nicht unmissverständlich aufforderte , für Tadic zu stimmen .'},
#  {'doc_id': 61,
#   'verb_form': '.',
#   'verb_form_start': 108,
#   'verb_form_end': 109,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Unterzeichner',
#   'arg1_head_start': 11,
#   'arg1_head_end': 24,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Reservationspflicht',
#   'arg2_head_start': 41,
#   'arg2_head_end': 60,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die 29 000 Unterzeichner kritisieren die Reservationspflicht für den Veloverlad in den Intercity-Neigezügen .'},
#  {'doc_id': 64,
#   'verb_form': '.',
#   'verb_form_start': 184,
#   'verb_form_end': 185,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Minister',
#   'arg1_head_start': 4,
#   'arg1_head_end': 12,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Kollegen',
#   'arg2_head_start': 73,
#   'arg2_head_end': 81,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Minister nutzen das gestrige Treffen auch dazu , ihren französischen Kollegen Nicolas Sarkozy für sein unabgesprochenes Vorgehen angesichts des steigenden Ölpreises zu kritisieren .'},
#  {'doc_id': 64,
#   'verb_form': '.',
#   'verb_form_start': 184,
#   'verb_form_end': 185,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Minister',
#   'arg1_head_start': 4,
#   'arg1_head_end': 12,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Vorgehen',
#   'arg2_head_start': 124,
#   'arg2_head_end': 132,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Minister nutzen das gestrige Treffen auch dazu , ihren französischen Kollegen Nicolas Sarkozy für sein unabgesprochenes Vorgehen angesichts des steigenden Ölpreises zu kritisieren .'},
#  {'doc_id': 70,
#   'verb_form': '.',
#   'verb_form_start': 109,
#   'verb_form_end': 110,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Ländern',
#   'arg1_head_start': 101,
#   'arg1_head_end': 108,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Regeln',
#   'arg2_head_start': 36,
#   'arg2_head_end': 42,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Einführung von EU-weit gültigen Regeln scheiterte am Freitag in Luxemburg am Widerstand von zehn Ländern .'},
#  {'doc_id': 74,
#   'verb_form': '.',
#   'verb_form_start': 142,
#   'verb_form_end': 143,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Prozent',
#   'arg1_head_start': 106,
#   'arg1_head_end': 113,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Initiative',
#   'arg2_head_start': 53,
#   'arg2_head_end': 63,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Vor vier Jahren scheiterte die SP deutlich mit einer Initiative für eine 100-prozentige Ausschöpfung : 58 Prozent des Stimmvolkes sagten Nein .'},
#  {'doc_id': 77,
#   'verb_form': '.',
#   'verb_form_start': 167,
#   'verb_form_end': 168,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Bevölkerung',
#   'arg1_head_start': 113,
#   'arg1_head_end': 124,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'System',
#   'arg2_head_start': 137,
#   'arg2_head_end': 143,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Profitiert hat auch die Umwelt : Die Abgase haben sich um 12 % reduziert , es gibt 5 % weniger Unfälle , und die Bevölkerung ist mit dem System mehrheitlich zufrieden .'},
#  {'doc_id': 82,
#   'verb_form': '.',
#   'verb_form_start': 22,
#   'verb_form_end': 23,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Betriebskrankenkassen',
#   'arg1_head_start': 126,
#   'arg1_head_end': 147,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Familienangehörigen',
#   'arg2_head_start': 176,
#   'arg2_head_end': 195,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Schätzungsweise 70 Mio. Arbeitnehmer in den USA profitieren denn auch gemäss Branchenangaben vom Schutz , den HMO-orientierte Betriebskrankenkassen sowohl ihnen als auch ihren Familienangehörigen offerieren .'},
#  {'doc_id': 82,
#   'verb_form': '.',
#   'verb_form_start': 22,
#   'verb_form_end': 23,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Betriebskrankenkassen',
#   'arg1_head_start': 126,
#   'arg1_head_end': 147,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'ihnen',
#   'arg2_head_start': 155,
#   'arg2_head_end': 160,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Schätzungsweise 70 Mio. Arbeitnehmer in den USA profitieren denn auch gemäss Branchenangaben vom Schutz , den HMO-orientierte Betriebskrankenkassen sowohl ihnen als auch ihren Familienangehörigen offerieren .'},
#  {'doc_id': 85,
#   'verb_form': '.',
#   'verb_form_start': 163,
#   'verb_form_end': 164,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Minister',
#   'arg1_head_start': 6,
#   'arg1_head_end': 14,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Syrien',
#   'arg2_head_start': 50,
#   'arg2_head_end': 56,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Sechs Minister aus dem Hariri-Block beschuldigten Syrien als Anstifter der Unruhen und verlangten eine offizielle Klage Libanons bei der Uno gegen das Nachbarland .'},
#  {'doc_id': 87,
#   'verb_form': '.',
#   'verb_form_start': 62,
#   'verb_form_end': 63,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'SEC',
#   'arg1_head_start': 24,
#   'arg1_head_end': 27,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Börse',
#   'arg2_head_start': 32,
#   'arg2_head_end': 37,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Später beschuldigte die SEC die Börse der mangelnden Aufsicht .'},
#  {'doc_id': 89,
#   'verb_form': '.',
#   'verb_form_start': 124,
#   'verb_form_end': 125,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Regierung',
#   'arg1_head_start': 4,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Volkes',
#   'arg2_head_start': 117,
#   'arg2_head_end': 123,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Regierung beschuldigt - wie immer in solchen Fällen - Produzenten und Händler der Spekulation zulasten des armen Volkes .'},
#  {'doc_id': 89,
#   'verb_form': '.',
#   'verb_form_start': 124,
#   'verb_form_end': 125,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Regierung',
#   'arg1_head_start': 4,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Händler',
#   'arg2_head_start': 74,
#   'arg2_head_end': 81,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Regierung beschuldigt - wie immer in solchen Fällen - Produzenten und Händler der Spekulation zulasten des armen Volkes .'},
#  {'doc_id': 89,
#   'verb_form': '.',
#   'verb_form_start': 124,
#   'verb_form_end': 125,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Regierung',
#   'arg1_head_start': 4,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Produzenten',
#   'arg2_head_start': 58,
#   'arg2_head_end': 69,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Regierung beschuldigt - wie immer in solchen Fällen - Produzenten und Händler der Spekulation zulasten des armen Volkes .'},
#  {'doc_id': 90,
#   'verb_form': '.',
#   'verb_form_start': 247,
#   'verb_form_end': 248,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Oberlandesgericht',
#   'arg1_head_start': 15,
#   'arg1_head_end': 32,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Militärs',
#   'arg2_head_start': 65,
#   'arg2_head_end': 73,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Nürnberger Oberlandesgericht beschuldigt die drei ehemaligen Militärs für die Tötung der deutschen Soziologin und Theologiestudentin Elisabeth Käsemann und des Münchner Studenten Manfred Zieschank während der Militärdiktatur von 1976 bis 1983 .'},
#  {'doc_id': 91,
#   'verb_form': '.',
#   'verb_form_start': 151,
#   'verb_form_end': 152,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Frauen',
#   'arg1_head_start': 2,
#   'arg1_head_end': 8,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Konzern',
#   'arg2_head_start': 26,
#   'arg2_head_end': 33,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': '6 Frauen beschuldigen den Konzern , dass sie schlechter bezahlt worden seien als ihre männlichen Kollegen und geringere Aufstiegschancen gehabt hätten .'},
#  {'doc_id': 92,
#   'verb_form': '.',
#   'verb_form_start': 74,
#   'verb_form_end': 75,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Armee',
#   'arg1_head_start': 4,
#   'arg1_head_end': 9,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Hamas',
#   'arg2_head_start': 60,
#   'arg2_head_end': 65,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Armee beschuldigt al-Jil , ein Propagandainstrument der Hamas zu sein .'},
#  {'doc_id': 92,
#   'verb_form': '.',
#   'verb_form_start': 74,
#   'verb_form_end': 75,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Armee',
#   'arg1_head_start': 4,
#   'arg1_head_end': 9,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'al-Jil',
#   'arg2_head_start': 22,
#   'arg2_head_end': 28,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Armee beschuldigt al-Jil , ein Propagandainstrument der Hamas zu sein .'},
#  {'doc_id': 93,
#   'verb_form': '.',
#   'verb_form_start': 170,
#   'verb_form_end': 171,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Wahlkampfteam',
#   'arg1_head_start': 4,
#   'arg1_head_end': 17,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Gruppe',
#   'arg2_head_start': 49,
#   'arg2_head_end': 55,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Wahlkampfteam der Demokraten beschuldigt die Gruppe « Swift Boat Veterans For Truth » , ihre Fernsehkampagne rechtswidrig mit Bushs Republikanern abgestimmt zu haben .'},
#  {'doc_id': 94,
#   'verb_form': '.',
#   'verb_form_start': 112,
#   'verb_form_end': 113,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Steuerbehörden',
#   'arg1_head_start': 4,
#   'arg1_head_end': 18,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Menem',
#   'arg2_head_start': 32,
#   'arg2_head_end': 37,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Steuerbehörden beschuldigen Menem , 600 000 Dollar auf einem Konto in der Schweiz nicht deklariert zu haben .'},
#  {'doc_id': 96,
#   'verb_form': '.',
#   'verb_form_start': 161,
#   'verb_form_end': 162,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Litwinenko',
#   'arg1_head_start': 20,
#   'arg1_head_end': 30,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'FSB',
#   'arg2_head_start': 35,
#   'arg2_head_end': 38,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Ferner beschuldigte Litwinenko den FSB auch , die Bombenanschläge von 1999 gegen Wohnblöcke in Moskau organisiert zu haben , denen 300 Personen zum Opfer fielen .'},
#  {'doc_id': 97,
#   'verb_form': '.',
#   'verb_form_start': 60,
#   'verb_form_end': 61,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Nationalrat',
#   'arg1_head_start': 0,
#   'arg1_head_end': 11,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Parallelimporte',
#   'arg2_head_start': 20,
#   'arg2_head_end': 35,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Nationalrat billigt Parallelimporte patentgeschützter Güter .'},
#  {'doc_id': 99,
#   'verb_form': '.',
#   'verb_form_start': 55,
#   'verb_form_end': 56,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Parlament',
#   'arg1_head_start': 9,
#   'arg1_head_end': 18,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Budget',
#   'arg2_head_start': 48,
#   'arg2_head_end': 54,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': "Spaniens Parlament billigt Solbes ' revidiertes Budget ."},
#  {'doc_id': 100,
#   'verb_form': '.',
#   'verb_form_start': 46,
#   'verb_form_end': 47,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'EU-Parlament',
#   'arg1_head_start': 0,
#   'arg1_head_end': 12,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Vertrag',
#   'arg2_head_start': 25,
#   'arg2_head_end': 32,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'EU-Parlament billigt den Vertrag von Lissabon .'},
#  {'doc_id': 101,
#   'verb_form': '.',
#   'verb_form_start': 46,
#   'verb_form_end': 47,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Gül',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Kopftuchverbots',
#   'arg2_head_start': 30,
#   'arg2_head_end': 45,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Gül billigt die Aufhebung des Kopftuchverbots .'},
#  {'doc_id': 101,
#   'verb_form': '.',
#   'verb_form_start': 46,
#   'verb_form_end': 47,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Gül',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Aufhebung',
#   'arg2_head_start': 16,
#   'arg2_head_end': 25,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Gül billigt die Aufhebung des Kopftuchverbots .'},
#  {'doc_id': 104,
#   'verb_form': '!',
#   'verb_form_start': 28,
#   'verb_form_end': 29,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Man',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'uns',
#   'arg2_head_start': 14,
#   'arg2_head_end': 17,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Man behandelt uns wie Dreck !'},
#  {'doc_id': 113,
#   'verb_form': '.',
#   'verb_form_start': 117,
#   'verb_form_end': 118,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Medien',
#   'arg1_head_start': 44,
#   'arg1_head_end': 50,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Jungunternehmer',
#   'arg2_head_start': 13,
#   'arg2_head_end': 28,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Erfolgreiche Jungunternehmer werden von den Medien gefeiert , wobei dieses Lob auch eine ideologische Komponente hat .'},
#  {'doc_id': 116,
#   'verb_form': '.',
#   'verb_form_start': 94,
#   'verb_form_end': 95,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'es',
#   'arg1_head_start': 4,
#   'arg1_head_end': 6,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'ihn',
#   'arg2_head_start': 14,
#   'arg2_head_end': 17,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Und es feiert ihn dafür , dass er den Begriff « virtuelle Realität » in die Welt getragen hat .'},
#  {'doc_id': 117,
#   'verb_form': '.',
#   'verb_form_start': 226,
#   'verb_form_end': 227,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Städte',
#   'arg1_head_start': 79,
#   'arg1_head_end': 85,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Spielplätze',
#   'arg2_head_start': 176,
#   'arg2_head_end': 187,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'In den siebziger Jahren des letzten Jahrhunderts wurden verschiedene Schweizer Städte auf das Problem aufmerksam und förderten aktiv , dass Höfe nicht nur Autos , sondern auch Spielplätze und originelle Freiräume beherbergten .'},
#  {'doc_id': 117,
#   'verb_form': '.',
#   'verb_form_start': 226,
#   'verb_form_end': 227,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Städte',
#   'arg1_head_start': 79,
#   'arg1_head_end': 85,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Freiräume',
#   'arg2_head_start': 203,
#   'arg2_head_end': 212,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'In den siebziger Jahren des letzten Jahrhunderts wurden verschiedene Schweizer Städte auf das Problem aufmerksam und förderten aktiv , dass Höfe nicht nur Autos , sondern auch Spielplätze und originelle Freiräume beherbergten .'},
#  {'doc_id': 122,
#   'verb_form': '.',
#   'verb_form_start': 52,
#   'verb_form_end': 53,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sie',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Ideen',
#   'arg2_head_start': 46,
#   'arg2_head_end': 51,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sie fördert auch die Ausbreitung maoistischer Ideen .'},
#  {'doc_id': 122,
#   'verb_form': '.',
#   'verb_form_start': 52,
#   'verb_form_end': 53,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sie',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Ausbreitung',
#   'arg2_head_start': 21,
#   'arg2_head_end': 32,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sie fördert auch die Ausbreitung maoistischer Ideen .'},
#  {'doc_id': 162,
#   'verb_form': '.',
#   'verb_form_start': 42,
#   'verb_form_end': 43,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Palästinenser',
#   'arg1_head_start': 0,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Offizier',
#   'arg2_head_start': 33,
#   'arg2_head_end': 41,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Palästinenser töten israelischen Offizier .'},
#  {'doc_id': 164,
#   'verb_form': '.',
#   'verb_form_start': 34,
#   'verb_form_end': 35,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'er',
#   'arg1_head_start': 17,
#   'arg1_head_end': 19,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Fans',
#   'arg2_head_start': 11,
#   'arg2_head_end': 15,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Auch seine Fans veräppelt er gern .'},
#  {'doc_id': 171,
#   'verb_form': '.',
#   'verb_form_start': 68,
#   'verb_form_end': 69,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Deutschland',
#   'arg1_head_start': 17,
#   'arg1_head_end': 28,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Schallgrenze',
#   'arg2_head_start': 41,
#   'arg2_head_end': 53,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Dennoch verletzt Deutschland seither die Schallgrenze Jahr für Jahr .'},
#  {'doc_id': 172,
#   'verb_form': '.',
#   'verb_form_start': 50,
#   'verb_form_end': 51,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Projekt',
#   'arg1_head_start': 6,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Grundsätze',
#   'arg2_head_start': 39,
#   'arg2_head_end': 49,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': '« Das Projekt verletzt raumplanerische Grundsätze .'},
#  {'doc_id': 180,
#   'verb_form': '.',
#   'verb_form_start': 105,
#   'verb_form_end': 106,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'FDP-Fraktionspräsidentin',
#   'arg1_head_start': 0,
#   'arg1_head_end': 24,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Prinzip',
#   'arg2_head_start': 66,
#   'arg2_head_end': 73,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'FDP-Fraktionspräsidentin Gabi Huber verurteilte , wie die USA das Prinzip Macht vor Recht gesetzt hätten .'},
#  {'doc_id': 180,
#   'verb_form': '.',
#   'verb_form_start': 105,
#   'verb_form_end': 106,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'FDP-Fraktionspräsidentin',
#   'arg1_head_start': 0,
#   'arg1_head_end': 24,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'USA',
#   'arg2_head_start': 58,
#   'arg2_head_end': 61,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'FDP-Fraktionspräsidentin Gabi Huber verurteilte , wie die USA das Prinzip Macht vor Recht gesetzt hätten .'},
#  {'doc_id': 181,
#   'verb_form': '.',
#   'verb_form_start': 117,
#   'verb_form_end': 118,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Abtreibungsgegner',
#   'arg1_head_start': 0,
#   'arg1_head_end': 17,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Schaffung',
#   'arg2_head_start': 35,
#   'arg2_head_end': 44,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Abtreibungsgegner verurteilten die Schaffung der Bank und bezeichneten diese als eine Lagerstätte für tote Säuglinge .'},
#  {'doc_id': 181,
#   'verb_form': '.',
#   'verb_form_start': 117,
#   'verb_form_end': 118,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Abtreibungsgegner',
#   'arg1_head_start': 0,
#   'arg1_head_end': 17,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Bank',
#   'arg2_head_start': 49,
#   'arg2_head_end': 53,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Abtreibungsgegner verurteilten die Schaffung der Bank und bezeichneten diese als eine Lagerstätte für tote Säuglinge .'},
#  {'doc_id': 182,
#   'verb_form': '.',
#   'verb_form_start': 44,
#   'verb_form_end': 45,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Bagdad',
#   'arg1_head_start': 0,
#   'arg1_head_end': 6,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Anschläge',
#   'arg2_head_start': 22,
#   'arg2_head_end': 31,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Bagdad verurteilt die Anschläge auf Kirchen .'},
#  {'doc_id': 183,
#   'verb_form': '.',
#   'verb_form_start': 67,
#   'verb_form_end': 68,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Ich',
#   'arg1_head_start': 2,
#   'arg1_head_end': 5,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'sie',
#   'arg2_head_start': 11,
#   'arg2_head_end': 14,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': '« Ich habe sie dafür verurteilt , dass sie so einen Ort aufsuchten .'},
#  {'doc_id': 184,
#   'verb_form': '.',
#   'verb_form_start': 90,
#   'verb_form_end': 91,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Gericht',
#   'arg1_head_start': 4,
#   'arg1_head_end': 11,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Schweiz',
#   'arg2_head_start': 28,
#   'arg2_head_end': 35,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Gericht verurteilte die Schweiz , dem Vater eine Genugtuung von 15 000 Euro zu zahlen .'},
#  {'doc_id': 200,
#   'verb_form': '.',
#   'verb_form_start': 53,
#   'verb_form_end': 54,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Spielbankenkommission',
#   'arg1_head_start': 0,
#   'arg1_head_end': 21,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Glücksspiele',
#   'arg2_head_start': 40,
#   'arg2_head_end': 52,
# ...
#   'arg2_head_end': 41,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Arafat akzeptiert den jüdischen Charakter Israels .'},
#  {'doc_id': 392,
#   'verb_form': '.',
#   'verb_form_start': 78,
#   'verb_form_end': 79,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Muff',
#   'arg1_head_start': 0,
#   'arg1_head_end': 4,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Einsprache',
#   'arg2_head_start': 63,
#   'arg2_head_end': 73,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Muff wollte die Verfügung zunächst nicht akzeptieren und legte Einsprache ein .'},
#  {'doc_id': 392,
#   'verb_form': '.',
#   'verb_form_start': 78,
#   'verb_form_end': 79,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Muff',
#   'arg1_head_start': 0,
#   'arg1_head_end': 4,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Verfügung',
#   'arg2_head_start': 16,
#   'arg2_head_end': 25,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Muff wollte die Verfügung zunächst nicht akzeptieren und legte Einsprache ein .'},
#  {'doc_id': 393,
#   'verb_form': '.',
#   'verb_form_start': 113,
#   'verb_form_end': 114,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Panel',
#   'arg1_head_start': 4,
#   'arg1_head_end': 9,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'EU-Einwand',
#   'arg2_head_start': 26,
#   'arg2_head_end': 36,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Panel akzeptierte den EU-Einwand nicht , dass dank einer Fussnote eine zusätzliche Menge von jährlich 1,6 Mio. t Zucker für den subventionierten Export verfügbar sei .'},
#  {'doc_id': 394,
#   'verb_form': '.',
#   'verb_form_start': 101,
#   'verb_form_end': 102,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sie',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Präsidenten',
#   'arg2_head_start': 17,
#   'arg2_head_end': 28,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sie sprachen dem Präsidenten Sondervollmachten zu und akzeptieren , dass dieser mit Dekreten regiert .'},
#  {'doc_id': 400,
#   'verb_form': '.',
#   'verb_form_start': 89,
#   'verb_form_end': 90,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sie',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Einstellhallen',
#   'arg2_head_start': 33,
#   'arg2_head_end': 47,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sie akzeptiert somit , spezielle Einstellhallen für die Abfallentsorgung bauen zu müssen .'},
#  {'doc_id': 413,
#   'verb_form': '.',
#   'verb_form_start': 138,
#   'verb_form_end': 139,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Kerviel',
#   'arg1_head_start': 0,
#   'arg1_head_end': 7,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Management',
#   'arg2_head_start': 21,
#   'arg2_head_end': 31,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Kerviel belastet das Management mit der Behauptung , es habe von seinen Spekulationen und Vertuschungen gewusst , die Verluste von 4,9 Mrd. € zur Folge hatten .'},
#  {'doc_id': 420,
#   'verb_form': '.',
#   'verb_form_start': 100,
#   'verb_form_end': 101,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Postfinance',
#   'arg1_head_start': 27,
#   'arg1_head_end': 38,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'ihm',
#   'arg2_head_start': 23,
#   'arg2_head_end': 26,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Gleichzeitig belastete ihm Postfinance je 20 Franken für die Mahnung und die Sperrung seines Kontos .'},
#  {'doc_id': 426,
#   'verb_form': '.',
#   'verb_form_start': 86,
#   'verb_form_end': 87,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Übereinkommen',
#   'arg1_head_start': 4,
#   'arg1_head_end': 17,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Interessen',
#   'arg2_head_start': 64,
#   'arg2_head_end': 74,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Das Übereinkommen berücksichtigt aber auch die wirtschaftlichen Interessen der Reeder .'},
#  {'doc_id': 437,
#   'verb_form': '.',
#   'verb_form_start': 112,
#   'verb_form_end': 113,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Mehrheit',
#   'arg1_head_start': 20,
#   'arg1_head_end': 28,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Änderung',
#   'arg2_head_start': 60,
#   'arg2_head_end': 68,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Die republikanische Mehrheit im Repräsentantenhaus hat eine Änderung der politischen Standesregeln durchgesetzt .'},
#  {'doc_id': 438,
#   'verb_form': '.',
#   'verb_form_start': 73,
#   'verb_form_end': 74,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Mölzer',
#   'arg1_head_start': 0,
#   'arg1_head_end': 6,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'FPÖ-Chef',
#   'arg2_head_start': 23,
#   'arg2_head_end': 31,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Mölzer will den Wiener FPÖ-Chef Strache als neuen Parteichef durchsetzen .'},
#  {'doc_id': 447,
#   'verb_form': '.',
#   'verb_form_start': 96,
#   'verb_form_end': 97,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Bundesrat',
#   'arg1_head_start': 20,
#   'arg1_head_end': 29,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Akquisitionen',
#   'arg2_head_start': 62,
#   'arg2_head_end': 75,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Im Klartext hat der Bundesrat durchgesetzt , dass ganz grosse Akquisitionen ausgeschlossen sind .'},
#  {'doc_id': 456,
#   'verb_form': '.',
#   'verb_form_start': 103,
#   'verb_form_end': 104,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'er',
#   'arg1_head_start': 4,
#   'arg1_head_end': 6,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Einführung',
#   'arg2_head_start': 64,
#   'arg2_head_end': 74,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'In der nationalen Politik engagierte er sich mit Erfolg für die Einführung des Anti-Rassismus-Gesetzes .'},
#  {'doc_id': 457,
#   'verb_form': '.',
#   'verb_form_start': 50,
#   'verb_form_end': 51,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Uglow',
#   'arg1_head_start': 0,
#   'arg1_head_end': 5,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Abstinenz',
#   'arg2_head_start': 40,
#   'arg2_head_end': 49,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Uglow engagiert sich landesweit für die Abstinenz .'},
#  {'doc_id': 458,
#   'verb_form': '.',
#   'verb_form_start': 119,
#   'verb_form_end': 120,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sie',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Gesellschaft',
#   'arg2_head_start': 71,
#   'arg2_head_end': 83,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sie heiratete jung , gebar drei Kinder , engagierte sich in Kirche und Gesellschaft - und blieb ihrer Heimatstadt treu .'},
#  {'doc_id': 458,
#   'verb_form': '.',
#   'verb_form_start': 119,
#   'verb_form_end': 120,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Sie',
#   'arg1_head_start': 0,
#   'arg1_head_end': 3,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Kirche',
#   'arg2_head_start': 60,
#   'arg2_head_end': 66,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sie heiratete jung , gebar drei Kinder , engagierte sich in Kirche und Gesellschaft - und blieb ihrer Heimatstadt treu .'},
#  {'doc_id': 463,
#   'verb_form': '.',
#   'verb_form_start': 73,
#   'verb_form_end': 74,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'sie',
#   'arg1_head_start': 18,
#   'arg1_head_end': 21,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Neuankömmlingen',
#   'arg2_head_start': 29,
#   'arg2_head_end': 44,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Sofort engagierte sie sich , Neuankömmlingen dieses Wissen weiterzugeben .'},
#  {'doc_id': 473,
#   'verb_form': '.',
#   'verb_form_start': 56,
#   'verb_form_end': 57,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Polizei',
#   'arg1_head_start': 4,
#   'arg1_head_end': 11,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Tatverdächtige',
#   'arg2_head_start': 41,
#   'arg2_head_end': 55,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Polizei verhaftete wenig später zwei Tatverdächtige .'},
#  {'doc_id': 476,
#   'verb_form': '.',
#   'verb_form_start': 72,
#   'verb_form_end': 73,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Polizei',
#   'arg1_head_start': 4,
#   'arg1_head_end': 11,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'ihn',
#   'arg2_head_start': 22,
#   'arg2_head_end': 25,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Polizei verhaftet ihn , und man lässt ihn anschliessend wieder frei .'},
#  {'doc_id': 478,
#   'verb_form': '.',
#   'verb_form_start': 75,
#   'verb_form_end': 76,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Israeli',
#   'arg1_head_start': 12,
#   'arg1_head_end': 19,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Aktion',
#   'arg2_head_start': 43,
#   'arg2_head_end': 49,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Die meisten Israeli verteidigen sowohl die Aktion als auch deren Zeitpunkt .'},
#  {'doc_id': 478,
#   'verb_form': '.',
#   'verb_form_start': 75,
#   'verb_form_end': 76,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Israeli',
#   'arg1_head_start': 12,
#   'arg1_head_end': 19,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Zeitpunkt',
#   'arg2_head_start': 65,
#   'arg2_head_end': 74,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Die meisten Israeli verteidigen sowohl die Aktion als auch deren Zeitpunkt .'},
#  {'doc_id': 479,
#   'verb_form': '.',
#   'verb_form_start': 182,
#   'verb_form_end': 183,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Regierung',
#   'arg1_head_start': 4,
#   'arg1_head_end': 13,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Kollegin',
#   'arg2_head_start': 47,
#   'arg2_head_end': 55,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Regierung verteidigt ihren Schritt , ihrer Kollegin einen wesentlichen Teil der Kompetenzen entzogen zu haben , und die Tessiner Freisinnigen stehen vor wichtigen Entscheidungen .'},
#  {'doc_id': 480,
#   'verb_form': '.',
#   'verb_form_start': 48,
#   'verb_form_end': 49,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Bundesrat',
#   'arg1_head_start': 0,
#   'arg1_head_end': 9,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Abgabe',
#   'arg2_head_start': 21,
#   'arg2_head_end': 27,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Bundesrat verteidigt Abgabe von Taschenmunition .'},
#  {'doc_id': 482,
#   'verb_form': '.',
#   'verb_form_start': 138,
#   'verb_form_end': 139,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Er',
#   'arg1_head_start': 0,
#   'arg1_head_end': 2,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Vorgehen',
#   'arg2_head_start': 28,
#   'arg2_head_end': 36,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Er lobte das « pragmatische Vorgehen » der Regierung und verteidigte auch , dass der Kantonsrat nur informiert , aber nicht befragt wurde .'},
#  {'doc_id': 482,
#   'verb_form': '.',
#   'verb_form_start': 138,
#   'verb_form_end': 139,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Er',
#   'arg1_head_start': 0,
#   'arg1_head_end': 2,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Regierung',
#   'arg2_head_start': 43,
#   'arg2_head_end': 52,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Er lobte das « pragmatische Vorgehen » der Regierung und verteidigte auch , dass der Kantonsrat nur informiert , aber nicht befragt wurde .'},
#  {'doc_id': 487,
#   'verb_form': '.',
#   'verb_form_start': 102,
#   'verb_form_end': 103,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Behörden',
#   'arg1_head_start': 4,
#   'arg1_head_end': 12,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Vorwurf',
#   'arg2_head_start': 66,
#   'arg2_head_end': 73,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Die Behörden selbst allerdings mussten sich am Mittwoch gegen den Vorwurf der Inkompetenz verteidigen .'},
#  {'doc_id': 488,
#   'verb_form': '.',
#   'verb_form_start': 119,
#   'verb_form_end': 120,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Rahner',
#   'arg1_head_start': 0,
#   'arg1_head_end': 6,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Anthropologien',
#   'arg2_head_start': 104,
#   'arg2_head_end': 118,
#   'rel_type': 'con',
#   'pred_serial': None,
#   'full_sentence_text': 'Rahner bleibt an diesem Punkt unklar , verteidigt aber die menschliche Freiheit gegen reduktionistische Anthropologien .'},
#  {'doc_id': 488,
#   'verb_form': '.',
#   'verb_form_start': 119,
#   'verb_form_end': 120,
#   'verb_lemma': None,
#   'arg1': None,
#   'arg1_start': None,
#   'arg1_end': None,
#   'arg1_pos': None,
#   'arg1_head': 'Rahner',
#   'arg1_head_start': 0,
#   'arg1_head_end': 6,
#   'arg2': None,
#   'arg2_start': None,
#   'arg2_end': None,
#   'arg2_pos': None,
#   'arg2_head': 'Freiheit',
#   'arg2_head_start': 71,
#   'arg2_head_end': 79,
#   'rel_type': 'pro',
#   'pred_serial': None,
#   'full_sentence_text': 'Rahner bleibt an diesem Punkt unklar , verteidigt aber die menschliche Freiheit gegen reduktionistische Anthropologien .'}]

# %%
df = pd.DataFrame(rels)

# %%
df
# Out:
#      doc_id verb_form  verb_form_start  verb_form_end verb_lemma  arg1  \
# 0         0         .               97             98       None  None
# 1         0         .               97             98       None  None
# 2         1         .              152            153       None  None
# 3         2         .               93             94       None  None
# 4         3         .              159            160       None  None
# ..      ...       ...              ...            ...        ...   ...
# 185     482         .              138            139       None  None
# 186     482         .              138            139       None  None
# 187     487         .              102            103       None  None
# 188     488         .              119            120       None  None
# 189     488         .              119            120       None  None
#
#     arg1_start arg1_end arg1_pos      arg1_head  ...  arg2  arg2_start  \
# 0         None     None     None             er  ...  None        None
# 1         None     None     None             er  ...  None        None
# 2         None     None     None            CEO  ...  None        None
# 3         None     None     None  Bundesgericht  ...  None        None
# 4         None     None     None         Zeuske  ...  None        None
# ..         ...      ...      ...            ...  ...   ...         ...
# 185       None     None     None             Er  ...  None        None
# 186       None     None     None             Er  ...  None        None
# 187       None     None     None       Behörden  ...  None        None
# 188       None     None     None         Rahner  ...  None        None
# 189       None     None     None         Rahner  ...  None        None
#
#     arg2_end arg2_pos          arg2_head arg2_head_start arg2_head_end  \
# 0       None     None  Ausgabenkürzungen              32            49
# 1       None     None   Steuererhöhungen              73            89
# 2       None     None          Teilnahme             111           120
# 3       None     None         Beschwerde              44            54
# 4       None     None  Wirtschaftssystem             102           119
# ..       ...      ...                ...             ...           ...
# 185     None     None           Vorgehen              28            36
# 186     None     None          Regierung              43            52
# 187     None     None            Vorwurf              66            73
# 188     None     None     Anthropologien             104           118
# 189     None     None           Freiheit              71            79
#
#      rel_type  pred_serial                                 full_sentence_text
# 0         pro         None  Dabei machte er sich primär für Ausgabenkürzun...
# 1         con         None  Dabei machte er sich primär für Ausgabenkürzun...
# 2         con         None  Bundesrätin Calmy-Rey ist allerdings der Einla...
# 3         con         None  Das Bundesgericht hat eine staatsrechtliche Be...
# 4         con         None  Generell ortet Zeuske denn auch die Krise Kuba...
# ..        ...          ...                                                ...
# 185       pro         None  Er lobte das « pragmatische Vorgehen » der Reg...
# 186       pro         None  Er lobte das « pragmatische Vorgehen » der Reg...
# 187       con         None  Die Behörden selbst allerdings mussten sich am...
# 188       con         None  Rahner bleibt an diesem Punkt unklar , verteid...
# 189       pro         None  Rahner bleibt an diesem Punkt unklar , verteid...
#
# [190 rows x 22 columns]

# %%
df.to_csv(EXPORT_PATH)
