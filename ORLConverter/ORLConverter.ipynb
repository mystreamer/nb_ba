# %% [markdown]
# ## ORLConverter
#
# This converts files from the SSA-Format (PERIN-Format) to the format for the Opinion-Role-Labeller (incl. masked Polar-Expression).

# %%
# imports
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GroupShuffleSplit
import numpy as np
import os
import pandas as pd
import json
import uuid

# %%
# makedirs if not exist
os.makedirs("../../etl/data/processed/ORLConverter", exist_ok=True)

# %%
os.makedirs("../../etl/data/raw/ORLConverter", exist_ok=True)

# %%
# parameters
# Input data in SSA format (in JSON)
INPUT_DATA_SSA_TRAIN="../../etl/data/processed/Perin_Preprocessing/01_train.json"
INPUT_DATA_SSA_VAL="../../etl/data/processed/Perin_Preprocessing/01_val.json"
INPUT_DATA_SSA_TEST="../../etl/data/processed/Perin_Preprocessing/01_test.json"

ORL_OUTPUT_PATH_TRAIN="../../etl/data/processed/ORLConverter/01_train_orl.txt"
ORL_OUTPUT_PATH_VAL="../../etl/data/processed/ORLConverter/01_val_orl.txt"
ORL_OUTPUT_PATH_TEST="../../etl/data/processed/ORLConverter/01_test_orl.txt"

RANDOM_STATE=42

# %%
def read_json(INP_FILE):
    with open(INP_FILE, encoding="utf-8") as f:
        data = json.load(f)
        return data

ssa_data_train = read_json(INPUT_DATA_SSA_TRAIN)
ssa_data_val = read_json(INPUT_DATA_SSA_VAL)
ssa_data_test = read_json(INPUT_DATA_SSA_TEST)

# %%
def list_to_file(sents, filepath):
    with open(filepath, 'w') as f:
        for item in sents:
            f.write("%s" % (item + "\n"))

# %%
# validate the correctness of the parsing
ssa_data_train[0]['opinions'][0]['Source'][0][0]
# Out:
# 'Oberländische'

# %%
# check input format
ssa_data_train
# Out:
# [{'sent_id': '0',
#   'text': 'Im Kanton Bern etwa haben die Organisatoren des Emmentalischen bereits versichert , das Fest auch unter Ausschluss der Öffentlichkeit durchzuführen , das Oberländische findet ohne Zuschauer auf dem Brünigpass statt .',
#   'opinions': [{'Source': [['Oberländische'], ['154:167']],
#     'Target': [['Brünigpass'], ['198:208']],
#     'Polar_expression': [['findet'], ['168:174']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '1',
#   'text': 'Ende 2016 hatten die SBB das Projekt angekündigt , mit einem Drittel der Wohnungen im gemeinnützigen Segment .',
#   'opinions': [{'Source': [['SBB'], ['21:24']],
#     'Target': [['Projekt'], ['29:36']],
#     'Polar_expression': [['angekündigt'], ['37:48']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '2',
#   'text': 'Knapp ein Vierteljahrhundert später wirken diese Vorstellungen naiv .',
#   'opinions': [{'Source': [['Vorstellungen'], ['49:62']],
#     'Target': [['naiv'], ['63:67']],
#     'Polar_expression': [['wirken'], ['36:42']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '3',
#   'text': 'Der Grinch raubt ja keine Getränkeladen aus .',
#   'opinions': [{'Source': [['Grinch'], ['4:10']],
#     'Target': [['Getränkeladen'], ['26:39']],
#     'Polar_expression': [['raubt'], ['11:16']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '4',
#   'text': 'Die Orban-Regierung unterstellt dem amerikanischen Milliardär George Soros , die Einwanderung von Muslimen nach Europa bewusst zu organisieren und zu finanzieren , etwa durch die Unterstützung von NGO .',
#   'opinions': [{'Source': [['Orban-Regierung'], ['4:19']],
#     'Target': [['Milliardär'], ['51:61']],
#     'Polar_expression': [['unterstellt'], ['20:31']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '5',
#   'text': 'In Spanien geschieht es im Schnitt einmal pro Woche , in Frankreich alle drei Tage , in Russland noch öfter : Eine Frau wird von einem Mann aus ihrem Umfeld getötet .',
#   'opinions': [{'Source': [['Mann'], ['135:139']],
#     'Target': [['Frau'], ['115:119']],
#     'Polar_expression': [['getötet'], ['157:164']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '6',
#   'text': 'Und das , obwohl das Gericht laut Gesetz nur « ausnahmsweise » bei Härtefällen von einer Ausschaffung absehen darf .',
#   'opinions': [{'Source': [['Gericht'], ['21:28']],
#     'Target': [['Ausschaffung'], ['89:101']],
#     'Polar_expression': [['absehen'], ['102:109']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '7',
#   'text': 'Die Verteidigung plädierte für Freisprüche .',
#   'opinions': [{'Source': [['Verteidigung'], ['4:16']],
#     'Target': [['Freisprüche'], ['31:42']],
#     'Polar_expression': [['plädierte'], ['17:26']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '8',
#   'text': 'Über Corona wundert man sich kaum mehr , und laut Management muss sich die globale Fangemeinde nicht sorgen um ihre BTS-Stars .',
#   'opinions': [{'Source': [['Fangemeinde'], ['83:94']],
#     'Target': [['BTS-Stars'], ['116:125']],
#     'Polar_expression': [['sorgen'], ['101:107']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '9',
#   'text': 'Nun erklärt der Mittelfeldspieler seine Gründe für den Abgang und schiesst dabei scharf auf den neuen FCA-Trainer Stephan Keller .',
#   'opinions': [{'Source': [['Mittelfeldspieler'], ['16:33']],
#     'Target': [['FCA-Trainer'], ['102:113']],
#     'Polar_expression': [['schiesst'], ['66:74']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '10',
#   'text': 'So soll der Hollywood-Star bei Castings seine Macht ausgenutzt und jungen Frauen mit vielversprechenden Rollenangeboten gelockt haben .',
#   'opinions': [{'Source': [['Hollywood-Star'], ['12:26']],
#     'Target': [['Macht'], ['46:51']],
#     'Polar_expression': [['ausgenutzt'], ['52:62']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '11',
#   'text': '70 Prozent entstehen aus dem höheren Zeitbedarf , den Pendler , Lieferanten und Reisende für ihre Fahrten aufwenden müssen , 24 Prozent aus staubedingten Unfällen , der Rest sind höhere Umwelt- , Klima- und Energiekosten .',
#   'opinions': [{'Source': [['Prozent'], ['3:10']],
#     'Target': [['Zeitbedarf'], ['37:47']],
#     'Polar_expression': [['entstehen'], ['11:20']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '12',
#   'text': 'Selina trifft acht Mal nicht und stürzt vom 30. auf den 43.',
#   'opinions': [{'Source': [['Selina'], ['0:6']],
#     'Target': [['30.'], ['44:47']],
#     'Polar_expression': [['stürzt'], ['33:39']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '13',
#   'text': 'Der Fall Swisscom zeigt , woran die Postfinance-Pläne des Bundesrates kranken .',
#   'opinions': [{'Source': [['Postfinance-Pläne'], ['36:53']],
#     'Target': [['woran'], ['26:31']],
#     'Polar_expression': [['kranken'], ['70:77']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '14',
#   'text': 'Gleichzeitig wurden Aden und weitere Teile des Südens vor wenigen Tagen von heftigen Überschwemmungen heimgesucht .',
#   'opinions': [{'Source': [['Überschwemmungen'], ['85:101']],
#     'Target': [['Aden'], ['20:24']],
#     'Polar_expression': [['heimgesucht'], ['102:113']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '15',
#   'text': 'Schliesslich kann Recycling Abhängigkeiten entschärfen .',
#   'opinions': [{'Source': [['Recycling'], ['18:27']],
#     'Target': [['Abhängigkeiten'], ['28:42']],
#     'Polar_expression': [['entschärfen'], ['43:54']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '16',
#   'text': 'Man muss aber nicht weit in die Vergangenheit schauen , um zu sehen , welche Risiken von extrem hohen Staatsschulden ausgehen .',
#   'opinions': [{'Source': [['Risiken'], ['77:84']],
#     'Target': [['Staatsschulden'], ['102:116']],
#     'Polar_expression': [['ausgehen'], ['117:125']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '17',
#   'text': 'Nordirlands Unionisten sträuben sich weiter gegen jede künftige Form administrativer Kontrollen zwischen der Provinz und Grossbritannien .',
#   'opinions': [{'Source': [['Unionisten'], ['12:22']],
#     'Target': [['Form'], ['64:68']],
#     'Polar_expression': [['sträuben'], ['23:31']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '18',
#   'text': 'Im Mai solidarisierten sich mehrere mutmassliche GC-Anhänger mit Sprayern , die vor einer Kontrolle geflüchtet waren .',
#   'opinions': [{'Source': [['GC-Anhänger'], ['49:60']],
#     'Target': [['Sprayern'], ['65:73']],
#     'Polar_expression': [['solidarisierten'], ['7:22']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '19',
#   'text': 'Doch Iran habe die wirtschaftlichen Gewinne durch die Aufhebung der Sanktionen dazu benutzt , um das Budget der Revolutionswächter zu erhöhen und die Unterstützung für ausländische Milizen zu verstärken .',
#   'opinions': [{'Source': [['Iran'], ['5:9']],
#     'Target': [['Gewinne'], ['36:43']],
#     'Polar_expression': [['benutzt'], ['84:91']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '20',
#   'text': 'Psychologie Menschen ertragen Berührungen unterschiedlich gut .',
#   'opinions': [{'Source': [['Psychologie'], ['0:11']],
#     'Target': [['Berührungen'], ['30:41']],
#     'Polar_expression': [['ertragen'], ['21:29']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '21',
#   'text': 'Ich google also : « Grosser Frühlings-Sale » , wirbt der Brillenladen im Internet .',
#   'opinions': [{'Source': [['Brillenladen'], ['57:69']],
#     'Target': [['Internet'], ['73:81']],
#     'Polar_expression': [['wirbt'], ['47:52']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '22',
#   'text': 'Giorgio Merlani brach seine Ferien ab und fuhr am Sonntag zurück nach Bellinzona .',
#   'opinions': [{'Source': [['Giorgio'], ['0:7']],
#     'Target': [['Ferien'], ['28:34']],
#     'Polar_expression': [['brach'], ['16:21']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '23',
#   'text': 'Weltstar Ronaldo kann in Bern zunächst glänzen und Gegenspieler Camada abschütteln – doch am Ende muss er mit einer Niederlage leben .',
#   'opinions': [{'Source': [['Weltstar'], ['0:8']],
#     'Target': [['Bern'], ['25:29']],
#     'Polar_expression': [['glänzen'], ['39:46']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '24',
#   'text': 'Dass er sich in das sowohl menschlich als auch fachlich erfahrenere Mädchen nicht Hals über Kopf verliebt hätte , ist ausgeschlossen .',
#   'opinions': [{'Source': [['Hals'], ['82:86']],
#     'Target': [['Mädchen'], ['68:75']],
#     'Polar_expression': [['verliebt'], ['97:105']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '25',
#   'text': 'Tencent streitet die Vorwürfe zwar ab .',
#   'opinions': [{'Source': [['Tencent'], ['0:7']],
#     'Target': [['Vorwürfe'], ['21:29']],
#     'Polar_expression': [['streitet'], ['8:16']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '26',
#   'text': 'Und siehe da , ein Kalb stürzte den Hang hinunter , ein anderes wollte nicht trinken .',
#   'opinions': [{'Source': [['Kalb'], ['19:23']],
#     'Target': [['Hang'], ['36:40']],
#     'Polar_expression': [['stürzte'], ['24:31']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '27',
#   'text': 'Nach seinen Worten bedeutet dies , dass die rigorosen Massnahmen greifen : Ausgangssperre , abgesehen von Arztbesuchen , dem Kauf von Lebensmitteln und Medikamenten ; erlaubt sind auch Fahrten zur Pflege von Angehörigen .',
#   'opinions': [{'Source': [['Ausgangssperre'], ['75:89']],
#     'Target': [['Arztbesuchen'], ['106:118']],
#     'Polar_expression': [['abgesehen'], ['92:101']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '28',
#   'text': 'Und vor einem Monat verliert die Schweiz im Nations-League-Spiel im Estadio Alfredo di Stefano in Madrid nach einem Fehlpass von Goalie Yann Sommer 0 : 1.',
#   'opinions': [{'Source': [['Schweiz'], ['33:40']],
#     'Target': [['Fehlpass'], ['116:124']],
#     'Polar_expression': [['verliert'], ['20:28']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '29',
#   'text': 'Vielerorts sind die Zuwächse so gewaltig , dass die durchschnittliche monatliche Hypothekenbelastung trotz Niedrigzinsen ständig steigt und Familien kaum noch bezahlbare Angebote finden .',
#   'opinions': [{'Source': [['Familien'], ['140:148']],
#     'Target': [['Angebote'], ['170:178']],
#     'Polar_expression': [['finden'], ['179:185']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '30',
#   'text': 'Wegen Platzmangels musste die PUK auf den Stationen für Erwachsene minderjährige Patienten aufnehmen .',
#   'opinions': [{'Source': [['PUK'], ['30:33']],
#     'Target': [['Patienten'], ['81:90']],
#     'Polar_expression': [['aufnehmen'], ['91:100']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '31',
#   'text': 'Wiemer wirkt an einer neuen Initiative mit , die den Namen « Seismology and Earthquake Engineering Research Infrastructure Alliance for Europe » ( Sera ) trägt .',
#   'opinions': [{'Source': [['Wiemer'], ['0:6']],
#     'Target': [['Initiative'], ['28:38']],
#     'Polar_expression': [['wirkt'], ['7:12']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '32',
#   'text': 'Die Stadtpräsidentin Corine Mauch wendet sich an die aufgewühlte Menge und versichert , Zürich sei bereit , Flüchtlinge aufzunehmen und ihnen hier ein sicheres Leben zu ermöglichen .',
#   'opinions': [{'Source': [['Zürich'], ['88:94']],
#     'Target': [['Flüchtlinge'], ['108:119']],
#     'Polar_expression': [['aufzunehmen'], ['120:131']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '33',
#   'text': 'Der kantonale Baudirektor Markus Kägi hat an der Pressekonferenz vom Freitag nun einen beachtlichen Rabatt angekündigt : Weil es ja auch im Interesse des Kantons liege , die Bojenplätze zu verlegen , komme man den Betreibern entgegen .',
#   'opinions': [{'Source': [['Baudirektor'], ['14:25']],
#     'Target': [['Rabatt'], ['100:106']],
#     'Polar_expression': [['angekündigt'], ['107:118']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '34',
#   'text': 'Entsprechend hat Sony zwei neue Smartphones für Anfang April angekündigt : das Xperia XZ 2 ( 850 Franken ) und das XZ 2 Compact ( 650 Franken ) .',
#   'opinions': [{'Source': [['Sony'], ['17:21']],
#     'Target': [['Smartphones'], ['32:43']],
#     'Polar_expression': [['angekündigt'], ['61:72']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '35',
#   'text': 'Die Anführer der sieben grössten demokratischen Industriestaaten – Deutschland , Frankreich , Grossbritannien , Italien , Japan , Kanada und USA – widmen sich dabei vor allem dem Ukraine-Krieg und den Sanktionen gegen Russland .',
#   'opinions': [{'Source': [['Anführer'], ['4:12']],
#     'Target': [['Ukraine-Krieg'], ['179:192']],
#     'Polar_expression': [['widmen'], ['147:153']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '36',
#   'text': 'Robert Habeck hat in Davos versprochen , sich in der EU für die Schweiz einzusetzen .',
#   'opinions': [{'Source': [['Robert'], ['0:6']],
#     'Target': [['Schweiz'], ['64:71']],
#     'Polar_expression': [['einzusetzen'], ['72:83']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '37',
#   'text': 'So werden etwa Spieler des jüdischen Fussballklubs Hakoah Zürich regelmässig von den Gegnern beschimpft – etwa , dass die Juden den Schiedsrichter gekauft hätten .',
#   'opinions': [{'Source': [['Gegnern'], ['85:92']],
#     'Target': [['Spieler'], ['15:22']],
#     'Polar_expression': [['beschimpft'], ['93:103']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '38',
#   'text': 'Sánchez hatte im Juni 2018 die Umbettung der sterblichen Überreste Francos auf den Friedhof des Madrider Aussenbezirks El Pardo angekündigt , wo bereits dessen Witwe nach ihrem Tod 1988 begraben wurde .',
#   'opinions': [{'Source': [['Sánchez'], ['0:7']],
#     'Target': [['Umbettung'], ['31:40']],
#     'Polar_expression': [['angekündigt'], ['128:139']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '39',
#   'text': 'Politischer Einfluss entsteht aber nicht nur aus quantitativer Vertretung .',
#   'opinions': [{'Source': [['Einfluss'], ['12:20']],
#     'Target': [['Vertretung'], ['63:73']],
#     'Polar_expression': [['entsteht'], ['21:29']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '40',
#   'text': 'Gleichentags findet in Yongpyong der Männer-Slalom statt .',
#   'opinions': [{'Source': [['Männer-Slalom'], ['37:50']],
#     'Target': [['Yongpyong'], ['23:32']],
#     'Polar_expression': [['findet'], ['13:19']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '41',
#   'text': 'Andreas Flütsch Die Aktien des Milchverarbeiters Hochdorf stürzten gestern an der Börse zeitweise bis zu 20 Prozent ab und lagen am Abend 14 Prozent im Minus .',
#   'opinions': [{'Source': [['Aktien'], ['20:26']],
#     'Target': [['zu'], ['102:104']],
#     'Polar_expression': [['stürzten'], ['58:66']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '42',
#   'text': 'Den 30-Jährigen , der vor einer Beinoperation 29-mal getroffen hatte , dürfte ein Albtraum heimgesucht haben : Tampa Bay holt endlich den Titel und er ist nicht dabei .',
#   'opinions': [{'Source': [['Albtraum'], ['82:90']],
#     'Target': [['30-Jährigen'], ['4:15']],
#     'Polar_expression': [['heimgesucht'], ['91:102']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '43',
#   'text': 'Die deutsche Comedyszene solidarisiert sich mit den Opfern .',
#   'opinions': [{'Source': [['Comedyszene'], ['13:24']],
#     'Target': [['Opfern'], ['52:58']],
#     'Polar_expression': [['solidarisiert'], ['25:38']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '44',
#   'text': 'FCZ-Fans konnten sich in der Abstiegssaison 2016 / 17 in den Stadiönli der Challenge-League-Clubs oder beim jüngsten Cupmatch auf der Zürcher Allmend gegen den FC Red Star von diesem Phänomen überzeugen .',
#   'opinions': [{'Source': [['FCZ-Fans'], ['0:8']],
#     'Target': [['Phänomen'], ['183:191']],
#     'Polar_expression': [['überzeugen'], ['192:202']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '45',
#   'text': 'Der Whistleblower werde seine Arbeit ab sofort wieder aufnehmen .',
#   'opinions': [{'Source': [['Whistleblower'], ['4:17']],
#     'Target': [['Arbeit'], ['30:36']],
#     'Polar_expression': [['aufnehmen'], ['54:63']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '46',
#   'text': 'Bereits am Vortag hatte der Conf-Future 0,11 Prozentpunkte verloren .',
#   'opinions': [{'Source': [['Conf-Future'], ['28:39']],
#     'Target': [['Bereits'], ['0:7']],
#     'Polar_expression': [['verloren'], ['59:67']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '47',
#   'text': 'Um den langjährigen Ministerpräsidenten zu stürzen , haben sich sechs Parteien – von Mitte links bis zur rechtsextremen Jobbik – zum Bündnis « Mindenki Magyarorszaga Mozgalom » ( Ungarn gehört jedem ) zusammengeschlossen .',
#   'opinions': [{'Source': [['Parteien'], ['70:78']],
#     'Target': [['Ministerpräsidenten'], ['20:39']],
#     'Polar_expression': [['stürzen'], ['43:50']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '48',
#   'text': 'Der Veranstalter brach die Summerslide am Samstag frühzeitig ab .',
#   'opinions': [{'Source': [['Veranstalter'], ['4:16']],
#     'Target': [['Summerslide'], ['27:38']],
#     'Polar_expression': [['brach'], ['17:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '49',
#   'text': 'Der Höhenflug der PSG-Token dürfte auch Messi selbst erfreuen .',
#   'opinions': [{'Source': [['Höhenflug'], ['4:13']],
#     'Target': [['Messi'], ['40:45']],
#     'Polar_expression': [['erfreuen'], ['53:61']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '50',
#   'text': 'Zwar entstand bereits in den 1860er-Jahren neben einer republikanischen auch eine abolitionistische Bewegung – nicht zuletzt auf Druck des Auslands .',
#   'opinions': [{'Source': [['Bewegung'], ['100:108']],
#     'Target': [['nicht'], ['111:116']],
#     'Polar_expression': [['entstand'], ['5:13']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '51',
#   'text': 'Trotzdem streiten die Kritiker bis heute die Redlichkeit seines Protests ab .',
#   'opinions': [{'Source': [['Kritiker'], ['22:30']],
#     'Target': [['Redlichkeit'], ['45:56']],
#     'Polar_expression': [['streiten'], ['9:17']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '52',
#   'text': 'Damit wird im Landeanflug die Leistung geregelt , wobei durch die Motoraussetzer auch ein ungewöhnliches Fluggeräusch entsteht .',
#   'opinions': [{'Source': [['Fluggeräusch'], ['105:117']],
#     'Target': [['Motoraussetzer'], ['66:80']],
#     'Polar_expression': [['entsteht'], ['118:126']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '53',
#   'text': 'So entstand die Firma mit dem Namen Phee , dem griechischen Wort für Seegras .',
#   'opinions': [{'Source': [['Firma'], ['16:21']],
#     'Target': [['Namen'], ['30:35']],
#     'Polar_expression': [['entstand'], ['3:11']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '54',
#   'text': 'Die Konzernführung hat aus den Problemen im US-Geschäft , die durch Umsatzeinbussen in der Vermarktung von Schlössern für Bancomaten \xad sowie unzureichende Erträge in der \xad Serviceorganisation verschärft worden waren , die Konsequenzen gezogen .',
#   'opinions': [{'Source': [['Konzernführung'], ['4:18']],
#     'Target': [['Konsequenzen'], ['222:234']],
#     'Polar_expression': [['gezogen'], ['235:242']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '55',
#   'text': 'Es entsteht eine neue Kombination der Genomsegmente der zwei Viren , und dementsprechend kann daraus ein Virus mit neuen Eigenschaften entstehen .',
#   'opinions': [{'Source': [['Virus'], ['105:110']],
#     'Target': [['Eigenschaften'], ['121:134']],
#     'Polar_expression': [['entstehen'], ['135:144']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '56',
#   'text': 'Jahrzehntelang kam das Böse vor allem aus dem Ostblock ; Bond verführte eine junge Frau nach der anderen , und Homosexualität galt in dieser Männerwelt als Tabu .',
#   'opinions': [{'Source': [['Homosexualität'], ['111:125']],
#     'Target': [['Männerwelt'], ['141:151']],
#     'Polar_expression': [['galt'], ['126:130']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '57',
#   'text': 'Statt an den Swiss Indoors aufzuschlagen , bricht Stan Wawrinka ( 33 ) die Saison vorzeitig ab .',
#   'opinions': [{'Source': [['Stan'], ['50:54']],
#     'Target': [['Saison'], ['75:81']],
#     'Polar_expression': [['bricht'], ['43:49']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '58',
#   'text': 'Die dicken Mauern der sakralen Bauten sorgen für tiefe Raumtemperaturen .',
#   'opinions': [{'Source': [['Mauern'], ['11:17']],
#     'Target': [['Raumtemperaturen'], ['55:71']],
#     'Polar_expression': [['sorgen'], ['38:44']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '59',
#   'text': 'Eine Hälfte von ihnen sollte in der Studie ihre bisherigen Ernährungsgewohnheiten beibehalten ( Kontrollgruppe ) , während die andere Hälfte angehalten wurde , vier Wochen lang alternierend immer einen Tag normal zu essen und den darauffolgenden Tag keine Kalorien zu sich zu nehmen , und zwar weder in fester noch in flüssiger Form .',
#   'opinions': [{'Source': [['Hälfte'], ['5:11']],
#     'Target': [['Ernährungsgewohnheiten'], ['59:81']],
#     'Polar_expression': [['beibehalten'], ['82:93']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '60',
#   'text': 'Der Schritt erfolgt einen Tag nachdem Bulgariens Generalstaatsanwaltschaft gegen sechs russische Staatsbürger Ermittlungen wegen Verstrickungen in eine Reihe von Unfällen zwischen 2011 und 2020 in Lager- und Produktionsstätten der bulgarischen Rüstungsindustrie aufgenommen hat .',
#   'opinions': [{'Source': [['Generalstaatsanwaltschaft'], ['49:74']],
#     'Target': [['Ermittlungen'], ['110:122']],
#     'Polar_expression': [['aufgenommen'], ['262:273']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '61',
#   'text': 'In der liberal regierten Stadt fand traditionell die zentrale Feier statt .',
#   'opinions': [{'Source': [['Feier'], ['62:67']],
#     'Target': [['Stadt'], ['25:30']],
#     'Polar_expression': [['fand'], ['31:35']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '62',
#   'text': 'Nach 9 / 11 stürzte Ende 2001 eine von den USA angeführte Militärkoalition die Taliban , weil diese der Kaida von Usama bin Ladin Unterschlupf gewährt hatten .',
#   'opinions': [{'Source': [['Militärkoalition'], ['58:74']],
#     'Target': [['Taliban'], ['79:86']],
#     'Polar_expression': [['stürzte'], ['12:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '63',
#   'text': 'Dort widmete sich Albert Neukom der Konstruktion und dem Bau von leistungsfähigen Segelflugzeugen .',
#   'opinions': [{'Source': [['Albert'], ['18:24']],
#     'Target': [['Konstruktion'], ['36:48']],
#     'Polar_expression': [['widmete'], ['5:12']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '64',
#   'text': 'Möglicherweise galt der Beschuss einem nahe gelegenen Eisenbahndepot .',
#   'opinions': [{'Source': [['Beschuss'], ['24:32']],
#     'Target': [['Eisenbahndepot'], ['54:68']],
#     'Polar_expression': [['galt'], ['15:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '65',
#   'text': 'Die jüngsten Wahlerfolge bestärkten die Partei in ihren klaren Positionen .',
#   'opinions': [{'Source': [['Wahlerfolge'], ['13:24']],
#     'Target': [['Partei'], ['40:46']],
#     'Polar_expression': [['bestärkten'], ['25:35']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '66',
#   'text': 'Zwar entschuldigte sich Meyer umgehend öffentlich und auch persönlich bei Andrea Blum .',
#   'opinions': [{'Source': [['Meyer'], ['24:29']],
#     'Target': [['Andrea'], ['74:80']],
#     'Polar_expression': [['entschuldigte'], ['5:18']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '67',
#   'text': 'Delivery Hero brüstet sich mit 150 000 Restaurantpartnern weltweit , Just Eat sich mit 80 000 .',
#   'opinions': [{'Source': [['Delivery'], ['0:8']],
#     'Target': [['Restaurantpartnern'], ['39:57']],
#     'Polar_expression': [['brüstet'], ['14:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '68',
#   'text': 'Stephanie Erne ... spielt ebenfalls in Luzern und hat eine 80-Prozent-Stelle als Spezialistin für Bewegungs- und Gesundheitsförderung – daneben gilt ihr Engagement dem FI9-Verein .',
#   'opinions': [{'Source': [['Engagement'], ['153:163']],
#     'Target': [['FI9-Verein'], ['168:178']],
#     'Polar_expression': [['gilt'], ['144:148']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '69',
#   'text': 'Unter dem chinesischen Besitzer Geely hat Volvo seine globale Präsenz ausgebaut und weiss eine starke Infrastruktur im Rücken .',
#   'opinions': [{'Source': [['Volvo'], ['42:47']],
#     'Target': [['Präsenz'], ['62:69']],
#     'Polar_expression': [['ausgebaut'], ['70:79']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '70',
#   'text': 'Konkurrenten wie Patek Philippe und Zenith zogen daraufhin nach .',
#   'opinions': [{'Source': [['Konkurrenten'], ['0:12']],
#     'Target': [['daraufhin'], ['49:58']],
#     'Polar_expression': [['zogen'], ['43:48']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '71',
#   'text': 'Und natürlich verlockt die strenge Klosterdisziplin – Kuttenzwang , Aufstehen um 5.10 Uhr , paranoide Überwachung und Unterdrückung von allem , was auch nur aus der Ferne nach Sexualität riecht – zu fantasievollen Ausweichs- und Ausbruchsversuchen .',
#   'opinions': [{'Source': [['Klosterdisziplin'], ['35:51']],
#     'Target': [['Kuttenzwang'], ['54:65']],
#     'Polar_expression': [['verlockt'], ['14:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '72',
#   'text': 'Wir sehen alle , wie China und wie – anders , als wir meinen – der Westen damit umgeht .',
#   'opinions': [{'Source': [['Westen'], ['67:73']],
#     'Target': [['damit'], ['74:79']],
#     'Polar_expression': [['umgeht'], ['80:86']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '73',
#   'text': 'Drahos plädierte dagegen für eine bedingungslose Westorientierung des Landes , die EU- und die Nato-Mitgliedschaft stellte er nie infrage .',
#   'opinions': [{'Source': [['Drahos'], ['0:6']],
#     'Target': [['Westorientierung'], ['49:65']],
#     'Polar_expression': [['plädierte'], ['7:16']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '74',
#   'text': 'Voraussichtlich in der Sommersession soll die Vorlage dann vom Nationalrat behandelt werden , wie die SPK am Dienstag mitteilte .',
#   'opinions': [{'Source': [['Vorlage'], ['46:53']],
#     'Target': [['Nationalrat'], ['63:74']],
#     'Polar_expression': [['behandelt'], ['75:84']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '75',
#   'text': 'Vor knapp hundert \xad Jahren galt Kep-sur-Mer wegen seiner grandiosen Lage quasi als Saint-Tropez der Tropen .',
#   'opinions': [{'Source': [['Kep-sur-Mer'], ['32:43']],
#     'Target': [['Lage'], ['68:72']],
#     'Polar_expression': [['galt'], ['27:31']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '76',
#   'text': 'Der britische Sieger der Tour de France vermochte in dieser Saison noch nicht zu überzeugen .',
#   'opinions': [{'Source': [['Sieger'], ['14:20']],
#     'Target': [['Saison'], ['60:66']],
#     'Polar_expression': [['überzeugen'], ['81:91']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '77',
#   'text': 'Das Quartett triumphierte im Rennen der Juniorinnen über viermal 3,3 Kilometer 4,9 Sekunden vor den USA und 14,2 Sekunden vor Schweden .',
#   'opinions': [{'Source': [['Quartett'], ['4:12']],
#     'Target': [['Schweden'], ['126:134']],
#     'Polar_expression': [['triumphierte'], ['13:25']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '78',
#   'text': 'Der Argentinier überrumpelte sein in dieser Saison zuvor tadelloses Gegenüber , den Italiener Maurizio Sarri , indem er den offensiv eingestellten Dele Alli auf den zurückhängenden italienischen Spielmacher Jorginho ansetzte , um dessen Einfluss zu neutralisieren .',
#   'opinions': [{'Source': [['Argentinier'], ['4:15']],
#     'Target': [['Gegenüber'], ['68:77']],
#     'Polar_expression': [['überrumpelte'], ['16:28']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '79',
#   'text': 'Patrice Siegrist Mit der letzten Folie verdeutlichte Simon Dinkel von der Stadtzürcher Fachstelle für Gleichstellung noch einmal , wie gross die Unterschiede zwischen Frauen und Männern sind .',
#   'opinions': [{'Source': [['Patrice'], ['0:7']],
#     'Target': [['Simon'], ['53:58']],
#     'Polar_expression': [['verdeutlichte'], ['39:52']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '80',
#   'text': 'In Form von sogenannten Phasing-inund Supercredit-Bestimmungen für die Jahre 2020 bis 2022 gilt eine stufenweise Anrechnung der Fahrzeugflotte , die 2021 noch zehn und 2022 noch fünf Prozent der Fahrzeuge von der CO2-Berechnung ausschliesst .',
#   'opinions': [{'Source': [['Anrechnung'], ['113:123']],
#     'Target': [['Form'], ['3:7']],
#     'Polar_expression': [['gilt'], ['91:95']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '81',
#   'text': 'Im Gazastreifen hat Gantz sogar ein härteres Durchgreifen angekündigt .',
#   'opinions': [{'Source': [['Gantz'], ['20:25']],
#     'Target': [['Durchgreifen'], ['45:57']],
#     'Polar_expression': [['angekündigt'], ['58:69']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '82',
#   'text': 'Die KI-Bauchspeicheldrüse ist vernetzt mit anderen natürlich-künstlichen Entitäten , und in diesem Netz findet eine neuartige Evolution statt .',
#   'opinions': [{'Source': [['Evolution'], ['126:135']],
#     'Target': [['Netz'], ['99:103']],
#     'Polar_expression': [['findet'], ['104:110']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '83',
#   'text': 'Kommentar : Diesen Poker kann keiner gewinnen Seite 11 Reflexe : Das Nadelöhr hat an Bedeutung verloren Seite 38 A. R. · Die Blockierung der Strasse von Hormuz ist ein Schreckensszenario , das bei Krisen in der Golfregion regelmässig zu Sorgen Anlass gibt .',
#   'opinions': [{'Source': [['Nadelöhr'], ['69:77']],
#     'Target': [['Bedeutung'], ['85:94']],
#     'Polar_expression': [['verloren'], ['95:103']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '84',
#   'text': 'Italien hat diese Lotterie-Veranstaltung verdient gewonnen .',
#   'opinions': [{'Source': [['Italien'], ['0:7']],
#     'Target': [['Lotterie-Veranstaltung'], ['18:40']],
#     'Polar_expression': [['verdient'], ['41:49']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '85',
#   'text': 'Deutschland hat 100 Milliarden Sonderschulden für die Bundeswehr angekündigt , Japan eine Verdoppelung seines Verteidigungsetats , und China einen Anstieg um sieben Prozent .',
#   'opinions': [{'Source': [['Deutschland'], ['0:11']],
#     'Target': [['Milliarden'], ['20:30']],
#     'Polar_expression': [['angekündigt'], ['65:76']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '86',
#   'text': 'Doch nach einigen Aufräumarbeiten , Bekenntnissen und Umbauten widmete sich der neue Verfassungsschutz-Chef Hans-Georg Maassen bald hauptsächlich der Abwehr des islamistischen Terrors und verlor die Rechtsextremisten wieder aus dem Auge .',
#   'opinions': [{'Source': [['Verfassungsschutz-Chef'], ['85:107']],
#     'Target': [['Abwehr'], ['150:156']],
#     'Polar_expression': [['widmete'], ['63:70']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '87',
#   'text': 'Man kann jetzt den Menschen sagen , die ihren Urlaub planen wollen , dass sie das natürlich machen können . » Doch im nächsten Atemzug appellierte der 59-Jährige an die Menschen , « jetzt nicht aus dem Kreis heraus in andere Kreise zu fahren .',
#   'opinions': [{'Source': [['59-Jährige'], ['151:161']],
#     'Target': [['Menschen'], ['19:27']],
#     'Polar_expression': [['appellierte'], ['135:146']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '88',
#   'text': 'Insbesondere warnt die FAA in einem Bulletin vor Angriffen durch militante Rebellen , die vom Boden aus mit relativ einfachen Waffen hantieren .',
#   'opinions': [{'Source': [['FAA'], ['23:26']],
#     'Target': [['Rebellen'], ['75:83']],
#     'Polar_expression': [['warnt'], ['13:18']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '89',
#   'text': 'Da die Lehrerin bereits mit Eltern Kontakt aufgenommen und sich medial geäussert habe , sei die Antwort auf beide Fragen : Nein .',
#   'opinions': [{'Source': [['Lehrerin'], ['7:15']],
#     'Target': [['Kontakt'], ['35:42']],
#     'Polar_expression': [['aufgenommen'], ['43:54']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '90',
#   'text': 'Drohgebärden – 100 % China hat ein « grossflächiges , wichtiges Militärmanöver » angekündigt .',
#   'opinions': [{'Source': [['Militärmanöver'], ['64:78']],
#     'Target': [['%'], ['19:20']],
#     'Polar_expression': [['angekündigt'], ['81:92']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '91',
#   'text': 'Nicht nur der Bildschirm , sondern das ganze Gerät funktioniere – abgesehen von der Ladebuchse – nach wie vor einwandfrei .',
#   'opinions': [{'Source': [['Bildschirm'], ['14:24']],
#     'Target': [['Ladebuchse'], ['84:94']],
#     'Polar_expression': [['abgesehen'], ['66:75']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'},
#    {'Source': [['Bildschirm'], ['14:24']],
#     'Target': [['Ladebuchse'], ['84:94']],
#     'Polar_expression': [['abgesehen'], ['66:75']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '92',
#   'text': 'Schon im Sommer 2020 hatten zudem die Emirate und Bahrain in einem historischen Schritt diplomatische Beziehungen mit Israel aufgenommen .',
#   'opinions': [{'Source': [['Emirate'], ['38:45']],
#     'Target': [['Beziehungen'], ['102:113']],
#     'Polar_expression': [['aufgenommen'], ['125:136']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '93',
#   'text': 'Die Kantonspolizei hat Abklärungen zur Unfallursache aufgenommen .',
#   'opinions': [{'Source': [['Kantonspolizei'], ['4:18']],
#     'Target': [['Abklärungen'], ['23:34']],
#     'Polar_expression': [['aufgenommen'], ['53:64']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '94',
#   'text': 'Die bronzene Suffragistin – im Gegensatz zu den Suffragetten plädierte deren historisches Vorbild für Gewaltverzicht – ist eine Mahnerin , die von Worten lebt .',
#   'opinions': [{'Source': [['Vorbild'], ['90:97']],
#     'Target': [['Gegensatz'], ['31:40']],
#     'Polar_expression': [['plädierte'], ['61:70']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '95',
#   'text': 'Deshalb muss Peking den Geist Hongkongs langfristig zerstören .',
#   'opinions': [{'Source': [['Peking'], ['13:19']],
#     'Target': [['Geist'], ['24:29']],
#     'Polar_expression': [['zerstören'], ['52:61']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '96',
#   'text': 'Das Boot sei beim Aufprall zerschellt , die bislang bekannten 29 Insassen ins 15 Grad kalte Wasser gestürzt .',
#   'opinions': [{'Source': [['Boot'], ['4:8']],
#     'Target': [['Insassen'], ['65:73']],
#     'Polar_expression': [['gestürzt'], ['99:107']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '97',
#   'text': '‹ Er war krank , es ist etwas , das er schon länger mit sich herumschleppte › , sagte der Kanadier . » 2011 : « Derbyfieber » 2008 : « Blindenbacher legte nach mehreren Tagen mit hohem Fieber erst am Matchtag fest , die Reise nach Genf mitzumachen . » 2005 : « Nicht mehr dabei war in der Schlussphase auch der erkrankte Claudio Micheli , er wird in der zweiten Partie aber ebenfalls wieder spielen . » 2002 : « Sulander litt am Sonntag tatsächlich unter einer Magen-Darm-Grippe und rund 39 Grad Fieber . » 2001 : « In Zürich geniesst man die Rückkehr des Playoff-Fiebers , das die Regionvor einem Jahr erfasst und die Mannschaft zum Titel getragen hat . » 2000 : « Micheli erbte den Silberhelm des obersten Skorers vom erkrankten Peter Jaks .',
#   'opinions': [{'Source': [['Sulander'], ['412:420']],
#     'Target': [['Magen-Darm-Grippe'], ['461:478']],
#     'Polar_expression': [['litt'], ['421:425']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '98',
#   'text': 'Im Bezirk Fresno County stürzte ein Helikopter bei Löscharbeiten ab , der Pilot kam ums Leben .',
#   'opinions': [{'Source': [['Helikopter'], ['36:46']],
#     'Target': [['Löscharbeiten'], ['51:64']],
#     'Polar_expression': [['stürzte'], ['24:31']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '99',
#   'text': 'Die Auszeichnung belohnt jeweils den besten Erstlingsfilm .',
#   'opinions': [{'Source': [['Auszeichnung'], ['4:16']],
#     'Target': [['Erstlingsfilm'], ['44:57']],
#     'Polar_expression': [['belohnt'], ['17:24']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '100',
#   'text': 'Der Zugang zu einem angemieteten Schliessfach finde immer in Begleitung von Personal statt – und zwar bis zum Schliessfach , ab dann hätten die Kunden Diskretion , sagt Andreas Hablützel , Chef des Edelmetallhändlers .',
#   'opinions': [{'Source': [['Zugang'], ['4:10']],
#     'Target': [['zum'], ['106:109']],
#     'Polar_expression': [['finde'], ['46:51']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '101',
#   'text': 'Messerattacke in Deutschland In der Innenstadt von Würzburg hat ein 24-jähriger Mann mindestens drei Menschen getötet und weitere verletzt , darunter ein kleiner Bub .',
#   'opinions': [{'Source': [['Mann'], ['80:84']],
#     'Target': [['Menschen'], ['101:109']],
#     'Polar_expression': [['getötet'], ['110:117']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '102',
#   'text': 'Dort hat der über 70-jährige Hans Stöckli seinen Rücktritt angekündigt .',
#   'opinions': [{'Source': [['Stöckli'], ['34:41']],
#     'Target': [['Rücktritt'], ['49:58']],
#     'Polar_expression': [['angekündigt'], ['59:70']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '103',
#   'text': 'Doch wie sorgen die Bäcker dafür , dass der Kuchen im Sinne der Kunden und volkswirtschaftlich sinnvoll verteilt wird , der Ofen nicht überhitzt und dem Unterhalt nach wie vor Priorität gegeben wird ?',
#   'opinions': [{'Source': [['Ofen'], ['124:128']],
#     'Target': [['Bäcker'], ['20:26']],
#     'Polar_expression': [['sorgen'], ['9:15']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '104',
#   'text': 'Verständlicherweise brach unter den anderen G-7-Ländern nicht gerade Jubel ob Trumps Vorstoss aus .',
#   'opinions': [{'Source': [['Jubel'], ['69:74']],
#     'Target': [['G-7-Ländern'], ['44:55']],
#     'Polar_expression': [['brach'], ['20:25']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '105',
#   'text': 'Der brasilianische Präsident entliess den Chef der Bundespolizei .',
#   'opinions': [{'Source': [['Präsident'], ['19:28']],
#     'Target': [['Chef'], ['42:46']],
#     'Polar_expression': [['entliess'], ['29:37']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '106',
#   'text': 'Gesundheitsdirektorin Natalie Rickli ( SVP ) sieht es ebenso : « Für den Rückgang der Fallzahlen war der Reputationsverlust mitverantwortlich . » Auch Rickli benutzte die Gelegenheit für eine Rüge an die Spitalleitung : « Da fehlt ihr die nötige selbstkritische Sicht . » Die Gesundheitsdirektorin ist zuversichtlich , dass es in Zukunft besser wird .',
#   'opinions': [{'Source': [['Rickli'], ['30:36']],
#     'Target': [['Gelegenheit'], ['171:182']],
#     'Polar_expression': [['benutzte'], ['158:166']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '107',
#   'text': 'Seine Konzentration gilt einem umkämpften Ballwechsel .',
#   'opinions': [{'Source': [['Konzentration'], ['6:19']],
#     'Target': [['Ballwechsel'], ['42:53']],
#     'Polar_expression': [['gilt'], ['20:24']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '108',
#   'text': 'Seine überhastete Reformpolitik löste einen Bürgerkrieg aus , der verdeutlichte , wie schwach nach wie vor die Machtbasis des Staates war .',
#   'opinions': [{'Source': [['Reformpolitik'], ['18:31']],
#     'Target': [['Bürgerkrieg'], ['44:55']],
#     'Polar_expression': [['löste'], ['32:37']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '109',
#   'text': 'Und Papst Franziskus wird folglich auch nicht müde , das Geld zu verdammen , es zum « Misthaufen des Teufels » zu reden und als Spaltpilz zu brandmarken , der die Menschen gegeneinander aufbringe .',
#   'opinions': [{'Source': [['Papst'], ['4:9']],
#     'Target': [['Geld'], ['57:61']],
#     'Polar_expression': [['verdammen'], ['65:74']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '110',
#   'text': 'Einzelne Kantone warnen zudem vor einer Art « Managerbonus » .',
#   'opinions': [{'Source': [['Kantone'], ['9:16']],
#     'Target': [['Art'], ['40:43']],
#     'Polar_expression': [['warnen'], ['17:23']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '111',
#   'text': 'und Duterte-Carpio werden verhindern , dass die \xad Philippinen aus den Fehlern der Vergangenheit lernen .',
#   'opinions': [{'Source': [['\xad'], ['48:49']],
#     'Target': [['Fehlern'], ['70:77']],
#     'Polar_expression': [['lernen'], ['96:102']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '112',
#   'text': 'Solche Alternativen zu finden , setzt ein Denken im Konjunktiv voraus .',
#   'opinions': [{'Source': [['Denken'], ['42:48']],
#     'Target': [['Alternativen'], ['7:19']],
#     'Polar_expression': [['finden'], ['23:29']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '113',
#   'text': 'Joe Biden ( 77 ) , schon bei der chaotischen Vorwahl in Iowa nur gerade Vierter , hat nun am Dienstag auch in New Hampshire eine Schlappe erlitten .',
#   'opinions': [{'Source': [['Schlappe'], ['129:137']],
#     'Target': [['New'], ['110:113']],
#     'Polar_expression': [['erlitten'], ['138:146']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '114',
#   'text': 'David Göttler aus Deutschland und der spanische Speed-Bergsteiger Kílian Jornet brachen vergangenes Jahr ihren maskenfreien Gipfelversuch auf dem Südsattel in etwa 8000 Metern Höhe ab .',
#   'opinions': [{'Source': [['David'], ['0:5']],
#     'Target': [['Gipfelversuch'], ['124:137']],
#     'Polar_expression': [['brachen'], ['80:87']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '115',
#   'text': 'Und so kommt es , dass die Verantwortlichen im Falle eines Unfalls Klagen befürchten müssten .',
#   'opinions': [{'Source': [['Verantwortlichen'], ['27:43']],
#     'Target': [['Falle'], ['47:52']],
#     'Polar_expression': [['befürchten'], ['74:84']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '116',
#   'text': 'Robert Habeck gilt bei den deutschen Grünen als das grösste Talent seit Joschka Fischer .',
#   'opinions': [{'Source': [['Robert'], ['0:6']],
#     'Target': [['Joschka'], ['72:79']],
#     'Polar_expression': [['gilt'], ['14:18']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '117',
#   'text': 'Die Uno-Generalversammlung wählt die nichtständigen Mit \xad glieder jeweils für zwei Jahre und achtet dabei auf eine angemessene geografische Verteilung .',
#   'opinions': [{'Source': [['Uno-Generalversammlung'], ['4:26']],
#     'Target': [['Verteilung'], ['140:150']],
#     'Polar_expression': [['achtet'], ['93:99']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '118',
#   'text': 'Allgemein schreibt es aber : « Fedpol prüft Unmutsbekundungen und Drohungen , die uns von Schutzpersonen oder deren Entourage gemeldet werden . » Am Donnerstagabend rechtfertigte Dudli am Telefon seine « Feuer frei ! » -Aufforderung .',
#   'opinions': [{'Source': [['Dudli'], ['179:184']],
#     'Target': [['Telefon'], ['188:195']],
#     'Polar_expression': [['rechtfertigte'], ['165:178']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '119',
#   'text': 'Die Sitzungen finden in ausbruchsicheren Räumen statt .',
#   'opinions': [{'Source': [['Sitzungen'], ['4:13']],
#     'Target': [['Räumen'], ['41:47']],
#     'Polar_expression': [['finden'], ['14:20']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '120',
#   'text': 'Und Misstritte gegen Aussenseiter gab es nicht mehr , aber : Zwei Big Points vergaben die Schweizer , im EM-Achtelfinal 2016 gegen Polen und im letzten WM-Qualifikationsspiel gegen Portugal , als Ronaldo zwar nur ein Teil war von Portugal und kein Tor schoss , aber die Schweizer verloren 0 : 2 , was zum Umweg über die Barrage führte .',
#   'opinions': [{'Source': [['Schweizer'], ['90:99']],
#     'Target': [['0'], ['121:122']],
#     'Polar_expression': [['verloren'], ['280:288']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '121',
#   'text': 'Da Anleger stärker auf dieses Thema achten als früher , kommt es auch häufiger zu markanten Kursrückgängen .',
#   'opinions': [{'Source': [['Anleger'], ['3:10']],
#     'Target': [['Thema'], ['30:35']],
#     'Polar_expression': [['achten'], ['36:42']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '122',
#   'text': 'Lachappelle entschuldigte sich bei der Raiffeisen-Gruppe , aber auch bei seinem ehemaligen Arbeitgeber , der Basler Kantonalbank .',
#   'opinions': [{'Source': [['Lachappelle'], ['0:11']],
#     'Target': [['Arbeitgeber'], ['91:102']],
#     'Polar_expression': [['entschuldigte'], ['12:25']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '123',
#   'text': 'Der deutsche Bundespräsident Frank-Walter Steinmeier soll sich vor dem Parlament in Namibia entschuldigen , in den nächsten Jahrzehnten will Deutschland 1,1 Milliarden Euro für soziale Projekte ausgeben .',
#   'opinions': [{'Source': [['Bundespräsident'], ['13:28']],
#     'Target': [['Namibia'], ['84:91']],
#     'Polar_expression': [['entschuldigen'], ['92:105']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '124',
#   'text': 'Dass es nicht mehr um alles ging , hatten bereits die Goalienominationen erahnen lassen : Die Zürcher schonten Lukas Flüeler nach dessen starkem Comeback vom Vorabend , und weil Joni Ortio verletzt fehlte , gaben sie Daniel Guntern die zweite Einsatzchance von Anfang an .',
#   'opinions': [{'Source': [['Zürcher'], ['94:101']],
#     'Target': [['Lukas'], ['111:116']],
#     'Polar_expression': [['schonten'], ['102:110']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '125',
#   'text': 'Anita K. stürzte vom obersten Balkon zehn Meter in die Tiefe .',
#   'opinions': [{'Source': [['Anita'], ['0:5']],
# ...
#   'opinions': [{'Source': [['Corona-Krise'], ['14:26']],
#     'Target': [['China'], ['34:39']],
#     'Polar_expression': [['stürzt'], ['27:33']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '957',
#   'text': 'Und in diesen Zeiten haben die Menschen allen Grund , sich um ihren Arbeitsplatz zu sorgen .',
#   'opinions': [{'Source': [['Menschen'], ['31:39']],
#     'Target': [['Arbeitsplatz'], ['68:80']],
#     'Polar_expression': [['sorgen'], ['84:90']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '958',
#   'text': 'Dies könne dazu führen , dass Gläubiger kleinerer Banken stärker geschont würden als solche von grösseren Häusern , monierte der Minister .',
#   'opinions': [{'Source': [['Gläubiger'], ['30:39']],
#     'Target': [['Häusern'], ['106:113']],
#     'Polar_expression': [['geschont'], ['65:73']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '959',
#   'text': 'Die Mehrheit gönnt dem Paar seine neue Freiheit .',
#   'opinions': [{'Source': [['Mehrheit'], ['4:12']],
#     'Target': [['Paar'], ['23:27']],
#     'Polar_expression': [['gönnt'], ['13:18']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '960',
#   'text': 'Christus werde alle Gottlosen ins Verderben stürzen .',
#   'opinions': [{'Source': [['Christus'], ['0:8']],
#     'Target': [['Gottlosen'], ['20:29']],
#     'Polar_expression': [['stürzen'], ['44:51']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '961',
#   'text': 'Aber dann kam der mörderische Samstag in El Paso , an dem ein junger Mann mit einem Sturmgewehr loszog , um Mexikaner zu töten .',
#   'opinions': [{'Source': [['Mann'], ['69:73']],
#     'Target': [['Mexikaner'], ['108:117']],
#     'Polar_expression': [['töten'], ['121:126']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '962',
#   'text': 'Mit Umsicht , Energie und Geduld sorgten die Benediktiner in den folgenden siebenhundert Jahren für die wirtschaftliche und kulturelle Entwicklung der Region .',
#   'opinions': [{'Source': [['Benediktiner'], ['45:57']],
#     'Target': [['Entwicklung'], ['135:146']],
#     'Polar_expression': [['sorgten'], ['33:40']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '963',
#   'text': 'Doch eine Queen verdient eine ordentliche Antwort .',
#   'opinions': [{'Source': [['Queen'], ['10:15']],
#     'Target': [['Antwort'], ['42:49']],
#     'Polar_expression': [['verdient'], ['16:24']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '964',
#   'text': 'Die Schweiz hat wegen des Geldes die Autokraten bzw. ihre Gelder aus Afrika und aus dem Fernen Osten aufgenommen und nun später die Superreichen aus Russland .',
#   'opinions': [{'Source': [['Schweiz'], ['4:11']],
#     'Target': [['Autokraten'], ['37:47']],
#     'Polar_expression': [['aufgenommen'], ['101:112']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '965',
#   'text': 'Die Positanesi hatten während des Faschismus verfolgte Schriftsteller , Komponisten und Maler bei sich aufgenommen .',
#   'opinions': [{'Source': [['Positanesi'], ['4:14']],
#     'Target': [['Schriftsteller'], ['55:69']],
#     'Polar_expression': [['aufgenommen'], ['103:114']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '966',
#   'text': 'Ausserdem lässt die Infrastruktur in Lugano zu wünschen übrig : Das marode Stadion bremst die Euphorie im Klub .',
#   'opinions': [{'Source': [['Infrastruktur'], ['20:33']],
#     'Target': [['Lugano'], ['37:43']],
#     'Polar_expression': [['wünschen'], ['47:55']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '967',
#   'text': 'Im laufenden Jahr sind bisher zwölf Frauen von ihrem Partner oder einem männlichen Familienmitglied getötet worden .',
#   'opinions': [{'Source': [['Partner'], ['53:60']],
#     'Target': [['Frauen'], ['36:42']],
#     'Polar_expression': [['getötet'], ['100:107']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '968',
#   'text': 'Seine Hauptaufgabe , sagte Parscale dem Fernsehsender CBS , sei es gewesen , einen Weg zu finden , mit dem Trump gegen die finanziell besser ausgestattete Kampagne Hillary Clintons bestehen könnte .',
#   'opinions': [{'Source': [['Hauptaufgabe'], ['6:18']],
#     'Target': [['Weg'], ['83:86']],
#     'Polar_expression': [['finden'], ['90:96']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '969',
#   'text': '« Sehr viel weniger Fahrzeuge werden die Strasse benutzen » , sagt er .',
#   'opinions': [{'Source': [['Fahrzeuge'], ['20:29']],
#     'Target': [['Strasse'], ['41:48']],
#     'Polar_expression': [['benutzen'], ['49:57']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '970',
#   'text': 'Trump zerstört mit seinem Verhalten insbesondere das historische transatlantische Bündnis zwischen den USA und Europa , was sich katastrophal auswirken kann .',
#   'opinions': [{'Source': [['Trump'], ['0:5']],
#     'Target': [['Bündnis'], ['82:89']],
#     'Polar_expression': [['zerstört'], ['6:14']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '971',
#   'text': 'Und nicht zuletzt schonen Kompostierer nicht nur die Umwelt , sondern auch ihr Portemonnaie : Wer seine Grünabfälle nicht einfach entsorgt , gibt weniger Geld aus für Kehrichtgebühren und für den Kauf von Dünger .',
#   'opinions': [{'Source': [['Kompostierer'], ['26:38']],
#     'Target': [['Umwelt'], ['53:59']],
#     'Polar_expression': [['schonen'], ['18:25']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '972',
#   'text': 'Tagelang hatte eine Überflutung in den Gängen das Vordringen der Rettungskräfte behindert .',
#   'opinions': [{'Source': [['Überflutung'], ['20:31']],
#     'Target': [['Vordringen'], ['50:60']],
#     'Polar_expression': [['behindert'], ['80:89']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '973',
#   'text': 'Andrea de Cesaris zerstört in seiner Karriere 19 Chassis komplett , 1982 hat er 20 Unfälle – in 16 Rennen .',
#   'opinions': [{'Source': [['Andrea'], ['0:6']],
#     'Target': [['Chassis'], ['49:56']],
#     'Polar_expression': [['zerstört'], ['18:26']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '974',
#   'text': 'Neben dem Kongo haben Mitarbeiter von Gunvor auch Beamte in der Elfenbeinküste bestochen .',
#   'opinions': [{'Source': [['Mitarbeiter'], ['22:33']],
#     'Target': [['Beamte'], ['50:56']],
#     'Polar_expression': [['bestochen'], ['79:88']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '975',
#   'text': 'Die zweite widmet sich der Zeit nach den Anschlägen von 9 / 11 , wo sich Fox News und dessen CEO zu Stichwortgebern für die Bush-Administration aufschwingen .',
#   'opinions': [{'Source': [['zweite'], ['4:10']],
#     'Target': [['Zeit'], ['27:31']],
#     'Polar_expression': [['widmet'], ['11:17']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '976',
#   'text': 'Und als Silvan Widmer sich deswegen beschwert , geht Serey seinem ehemaligen Mitspieler an den Kragen und wird vom Platz gestellt .',
#   'opinions': [{'Source': [['Mitspieler'], ['77:87']],
#     'Target': [['deswegen'], ['27:35']],
#     'Polar_expression': [['beschwert'], ['36:45']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '977',
#   'text': 'Weiter habe sich der Verwaltungsrat bei Peter Goerke entschuldigt .',
#   'opinions': [{'Source': [['Verwaltungsrat'], ['21:35']],
#     'Target': [['Peter'], ['40:45']],
#     'Polar_expression': [['entschuldigt'], ['53:65']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '978',
#   'text': 'Die Valoren des Personalvermittlers Adecco und des Industriekonzerns ABB zogen um 0,8 % an .',
#   'opinions': [{'Source': [['Valoren'], ['4:11']],
#     'Target': [['%'], ['86:87']],
#     'Polar_expression': [['zogen'], ['73:78']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '979',
#   'text': 'Diese riesige Summe setzt sich aus Liquidität , Einnahmen aus geplanten Devestitionen und Fremdmitteln zusammen , welche die Konzerne nach Einschätzung der Marktbeobachter bei Bedarf aufnehmen könnten .',
#   'opinions': [{'Source': [['Konzerne'], ['125:133']],
#     'Target': [['Marktbeobachter'], ['156:171']],
#     'Polar_expression': [['aufnehmen'], ['183:192']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '980',
#   'text': 'Daher bricht fast jeder dritte Patient die Teilnahme an einem solchen Versuch ab .',
#   'opinions': [{'Source': [['Patient'], ['31:38']],
#     'Target': [['Teilnahme'], ['43:52']],
#     'Polar_expression': [['bricht'], ['6:12']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '981',
#   'text': 'Auf der Bahn mitten in Basel , in der Hitze , pfeift Clarence Callender – nächste Runde .',
#   'opinions': [{'Source': [['Clarence'], ['53:61']],
#     'Target': [['Bahn'], ['8:12']],
#     'Polar_expression': [['pfeift'], ['46:52']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '982',
#   'text': 'Das Interview findet per Videocall statt – kurz bevor er wieder zur offiziellen Auszählung der Wahlleute-Stimmen muss , die bei der Belagerung nur unterbrochen wurde .',
#   'opinions': [{'Source': [['Interview'], ['4:13']],
#     'Target': [['Videocall'], ['25:34']],
#     'Polar_expression': [['findet'], ['14:20']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '983',
#   'text': 'Trump hatte im September einen Friedensplan für den Nahen Osten binnen « zwei , drei oder vier Monaten » angekündigt .',
#   'opinions': [{'Source': [['Trump'], ['0:5']],
#     'Target': [['Friedensplan'], ['31:43']],
#     'Polar_expression': [['angekündigt'], ['105:116']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '984',
#   'text': 'Indiens Wille , die Quad wiederzubeleben , ist bemerkenswert .',
#   'opinions': [{'Source': [['Wille'], ['8:13']],
#     'Target': [['Quad'], ['20:24']],
#     'Polar_expression': [['wiederzubeleben'], ['25:40']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '985',
#   'text': 'Eishockey Der Noch-Leader verliert gegen den SC Bern1 : 4 , obschon er 40 Minuten lang klar überlegen ist .',
#   'opinions': [{'Source': [['Eishockey'], ['0:9']],
#     'Target': [['SC'], ['45:47']],
#     'Polar_expression': [['verliert'], ['26:34']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '986',
#   'text': 'Lorenzo Petrò Sturmtief Burglind hat dem Adliswiler Stadthaus schlimm zugesetzt .',
#   'opinions': [{'Source': [['Lorenzo'], ['0:7']],
#     'Target': [['Adliswiler'], ['41:51']],
#     'Polar_expression': [['zugesetzt'], ['70:79']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '987',
#   'text': 'Giovanni Enrico Bucher auf dem Flughafen Genf , aufgenommen am 23. Januar 1971.Photopress-Archiv / Keystone Jede Woche beleuchtet die NZZ ein historisches Ereignis .',
#   'opinions': [{'Source': [['Giovanni'], ['0:8']],
#     'Target': [['Bucher'], ['16:22']],
#     'Polar_expression': [['aufgenommen'], ['48:59']],
#     'Polarity': 'Positive',
#     'Intensity': 'Average'}]},
#  {'sent_id': '988',
#   'text': 'Unmittelbar entlastend wirkt eine Eintrittsgebühr jedoch nur , wenn sie mit einer Kontingentierung der Besucher einhergeht .',
#   'opinions': [{'Source': [['Eintrittsgebühr'], ['34:49']],
#     'Target': [['entlastend'], ['12:22']],
#     'Polar_expression': [['wirkt'], ['23:28']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '989',
#   'text': 'So hat es Japan bislang gehalten , wo die Regierung immer wieder vor dem Aufenthalt in geschlossenen Räumen , grossen Menschengruppen und geringer Distanz zu anderen gewarnt hat , aber weniger restriktiv dagegen vorgegangen ist als viele Länder in Europa .',
#   'opinions': [{'Source': [['Regierung'], ['42:51']],
#     'Target': [['Aufenthalt'], ['73:83']],
#     'Polar_expression': [['gewarnt'], ['166:173']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '990',
#   'text': 'Was ich sagen kann : Im Supermarktbereich haben wir die Rentabilitätsziele übertroffen , aber andere Aktivitäten , etwa die Gastronomie , haben unter der Covid-19-Krise stark gelitten .',
#   'opinions': [{'Source': [['Aktivitäten'], ['101:112']],
#     'Target': [['Covid-19-Krise'], ['154:168']],
#     'Polar_expression': [['gelitten'], ['175:183']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '991',
#   'text': 'Wenn Illa künftig Präsident in Katalonien wird , hat Sánchez von dort nicht mehr allzu viel Ärger zu befürchten .',
#   'opinions': [{'Source': [['Sánchez'], ['53:60']],
#     'Target': [['Ärger'], ['92:97']],
#     'Polar_expression': [['befürchten'], ['101:111']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '992',
#   'text': 'Abes Nachfolger , Regierungschef Fumio Kishida ( 64 ) , brach sofort seinen Wahlkampf im Norden Japans ab und machte sich im Hubschrauber auf den Weg zurück nach Tokio .',
#   'opinions': [{'Source': [['Nachfolger'], ['5:15']],
#     'Target': [['Wahlkampf'], ['76:85']],
#     'Polar_expression': [['brach'], ['56:61']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '993',
#   'text': 'Seit Jahren benutzt Asad die humanitäre Hilfe als Druckmittel , um die Aufständischen in belagerten Gebieten in die Knie zu zwingen .',
#   'opinions': [{'Source': [['Asad'], ['20:24']],
#     'Target': [['Hilfe'], ['40:45']],
#     'Polar_expression': [['benutzt'], ['12:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '994',
#   'text': 'Die Lösungsansätze sind allerdings verschieden : — Der radikalste Ansatz ist zugleich jener , der als einziger kaum Chancen hat : Die SP will , dass der Staat die gesamte Betreuung für alle Kinder im Vorschulalter bezahlt , abgesehen von der Verpflegung .',
#   'opinions': [{'Source': [['Staat'], ['153:158']],
#     'Target': [['Verpflegung'], ['242:253']],
#     'Polar_expression': [['abgesehen'], ['224:233']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '995',
#   'text': 'Im November 2008 richteten zehn pakistanische Terroristen in der indischen Wirtschaftsmetropole ein Blutbad an und töteten über 160 Menschen .',
#   'opinions': [{'Source': [['Terroristen'], ['46:57']],
#     'Target': [['Menschen'], ['132:140']],
#     'Polar_expression': [['töteten'], ['115:122']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '996',
#   'text': 'Die Zahl der Geburten brach seinerzeit innerhalb weniger Jahre auf bis zu ein Drittel ein und erholte sich davon nur mässig .',
#   'opinions': [{'Source': [['Zahl'], ['4:8']],
#     'Target': [['bis'], ['67:70']],
#     'Polar_expression': [['brach'], ['22:27']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '997',
#   'text': 'An einer Demonstration der Massnahmengegner bricht ein bekannter Journalist eines gebührenfinanzierten Mediums ein Gespräch abrupt ab , als er erfährt , dass sein Gegenüber geimpft ist .',
#   'opinions': [{'Source': [['Journalist'], ['65:75']],
#     'Target': [['Gespräch'], ['115:123']],
#     'Polar_expression': [['bricht'], ['44:50']],
#     'Polarity': 'Negative',
#     'Intensity': 'Average'}]},
#  {'sent_id': '998',
#   'text': 'In den Verhandlungen mit Berlin hat Bern einen Text vorgeschlagen , der sich an die deutschen Abkommen mit Österreich und Dänemark anlehnt .',
#   'opinions': [{'Source': [['Bern'], ['36:40']],
#     'Target': [['Text'], ['47:51']],
#     'Polar_expression': [['vorgeschlagen'], ['52:65']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  {'sent_id': '999',
#   'text': 'Der Mann leide an Schizophrenie und sei deshalb leichtgradig vermindert schuldfähig .',
#   'opinions': [{'Source': [['Mann'], ['4:8']],
#     'Target': [['Schizophrenie'], ['18:31']],
#     'Polar_expression': [['leide'], ['9:14']],
#     'Polarity': 'Neutral',
#     'Intensity': 'Average'}]},
#  ...]

# %%
def convert_ssa_to_orl(data: list):
    output = []
    for i, sent_dict in enumerate(data):
        # validate that...
        # has 1 opinion
        sent = sent_dict["text"]
        try:
            assert len(sent_dict['opinions']) == 1, "Sentences for annotation can currently only contain a single opinion."
            for opinion in sent_dict['opinions']:
                for k, v in opinion.items():
                    # print(k, v)
                    pass
                # from IPython.core.debugger import Pdb; Pdb().set_trace()
                # for each opinion we mask the holder
                source_s = int(opinion["Source"][1][0].split(":")[0])
                source_e = int(opinion["Source"][1][0].split(":")[1])
                # for each opinion we mask the target
                target_s = int(opinion["Target"][1][0].split(":")[0])
                target_e = int(opinion["Target"][1][0].split(":")[1])
                # replace polar expression
                pexp_s = int(opinion["Polar_expression"][1][0].split(":")[0])
                pexp_e = int(opinion["Polar_expression"][1][0].split(":")[1])

                masked1 = "".join((sent[:source_s],"HOLDER",sent[source_e:]))
                
                if source_s > target_s:
                    lendiff1 = 0
                else: 
                    # print("Trigger " + str(i))
                    lendiff1 = len(masked1) - len(sent)

                masked2 = "".join((masked1[:target_s + lendiff1],"TARGET",masked1[target_e + lendiff1:]))
                masked_no_s = "".join((sent[:target_s],"TARGET",sent[target_e:]))
                
                if target_s > pexp_s and source_s > pexp_s:
                    lendiff2 = 0
                elif target_s > pexp_s and source_s < pexp_s:
                    lendiff2 = len(masked1) - len(sent)
                elif target_s < pexp_s and source_s < pexp_s:
                    lendiff2 = len(masked2) - len(sent)
                elif target_s < pexp_s and source_s > pexp_s:
                    lendiff2 = len(masked_no_s) - len(sent)
                else:
                    lendiff2 = 0

                masked3 = "".join((masked2[:pexp_s + lendiff2],"PEXP",masked2[pexp_e + lendiff2:]))
                
                # add CLS and SEP tokens to both sides
                sent = "[CLS] " + sent + " [SEP]"
                masked = "[CLS] " + masked3 + " [SEP]"
                
                # print(sent)
                # print(masked)
                
                # verify correctness
                assert masked.find(" HOLDER ") != -1 and masked.find(" TARGET ") != -1 and masked.find(" PEXP ") != -1, "Something went wrong with HTP-replacement."
                
                assert target_s != source_s or target_s != pexp_s or source_s != target_s, "Skipping, because inconclusive start/end."
        except Exception as e:
            print(f"Skipped converting to ORL, {e}, example {i}")
            continue
        output.append(masked)
        output.append(sent)
    return output

# %%
"Hello World...".find("kllk")
# Out:
# -1

# %%
orl_data_train = convert_ssa_to_orl(ssa_data_train)
# Out:
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 91
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 120
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 166
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 180
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 244
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 342
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 398
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 405
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 524
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 683
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 691
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 836
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 883
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 925
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 941
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 942
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1024
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1338
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1506
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1599
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1729
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1792
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2044
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2079
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2157
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2212
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2390
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2533
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2534
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2544
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2616
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2620
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2703
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2889
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3565
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3614
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3640
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3703
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3771
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3898
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4007
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4145
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4316
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4440
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4492
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4515
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4696
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4913
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4923
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4963
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5024
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5148
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5578
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5625
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5702
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5779
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5782
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5800
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5981
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6085
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6137
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6270
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 6321
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6350
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 6418
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6536
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6561
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 6636
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6651
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6716
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6748
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 6886
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6896
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 6926
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 7000
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 7001
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 7062
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 7100
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 7165
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 7406
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 7587
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 7625
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 7851
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 7862
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 8106
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8197
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8283
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8528
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8565
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8571
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8671
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 8770
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 8905
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 9063
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 9092
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 9300
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 9358
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 9440
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10060
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10102
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 10307
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10430
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 10520
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10616
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10630
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 10668
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10701
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 10794
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10842
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10853
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 10982
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 10997
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11041
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11117
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11290
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11456
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11480
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 11500
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11556
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 11771
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11774
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 11779
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 11811
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 11906
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12088
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12321
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12330
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12343
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12414
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12439
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12482
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12507
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12581
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12758
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12816
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12848
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12905
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12911
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 12950
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 12968
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 13028
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 13145
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 13492
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 13771
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 13966
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14006
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 14156
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14231
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 14345
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14359
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14391
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 14398
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14407
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 14635
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14837
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14871
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 14873
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 14994
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15059
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15106
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15259
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15284
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15379
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15383
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15434
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15471
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15551
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15664
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15744
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15771
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15824
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 15896
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 15997
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16037
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16076
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16104
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 16145
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16419
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 16441
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16511
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16588
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16591
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 16603
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 16641
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 16650
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 17492
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 17494
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 17579
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 17621
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 17882
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 17920
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 18094
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 18117
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 18127
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 18472
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 18524
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 18659
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 18760
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 18776
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 18826
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 18890
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 18925
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 19045
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 19121
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 19169
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 19175
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 19346
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 19430
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 19519
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 20050
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 20102
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 20254
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 20309
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 20333
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 20463
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 20593
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 20716
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 20787
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 20811
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 21037
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 21054
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 21066
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 21165
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 21284
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 21337
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 21384
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 21495
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 21601

# %%
orl_data_val = convert_ssa_to_orl(ssa_data_val)
# Out:
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 39
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 89
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 349
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 415
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 737
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 874
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 936
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 958
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1121
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1506
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1677
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1835
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1951
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1978
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2105
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2181
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2373
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2398
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2436
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2504
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2586
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2598
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2829
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3097
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3119
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3235
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3734
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3765
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3813
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3903
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4243
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4277
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4366
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4422
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4612
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4698
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4848
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5107
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5219
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5295
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5529
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5693
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 6128
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6173
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6337
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6382
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6411
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6509
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6532
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6686
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6706

# %%
orl_data_test = convert_ssa_to_orl(ssa_data_test)
# Out:
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 13
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 205
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 455
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 460
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 774
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1103
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1269
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1336
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 1684
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 1984
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2032
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2068
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2199
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2240
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2323
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2354
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2361
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 2434
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2786
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2793
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2824
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 2999
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3299
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3677
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3689
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3746
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 3756
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 3873
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4037
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4073
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4107
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4172
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4215
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4454
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4535
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4556
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4562
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4633
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4690
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4705
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4748
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4835
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 4872
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4928
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 4984
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5046
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5296
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5406
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5408
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 5606
# Skipped converting to ORL, Sentences for annotation can currently only contain a single opinion., example 5610
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6251
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6254
# Skipped converting to ORL, Something went wrong with HTP-replacement., example 6495

# %%
orl_data_train
# Out:
# ['[CLS] Im Kanton Bern etwa haben die Organisatoren des Emmentalischen bereits versichert , das Fest auch unter Ausschluss der Öffentlichkeit durchzuführen , das HOLDER PEXP ohne Zuschauer auf dem TARGET statt . [SEP]',
#  '[CLS] Im Kanton Bern etwa haben die Organisatoren des Emmentalischen bereits versichert , das Fest auch unter Ausschluss der Öffentlichkeit durchzuführen , das Oberländische findet ohne Zuschauer auf dem Brünigpass statt . [SEP]',
#  '[CLS] Ende 2016 hatten die HOLDER das TARGET PEXP , mit einem Drittel der Wohnungen im gemeinnützigen Segment . [SEP]',
#  '[CLS] Ende 2016 hatten die SBB das Projekt angekündigt , mit einem Drittel der Wohnungen im gemeinnützigen Segment . [SEP]',
#  '[CLS] Knapp ein Vierteljahrhundert später PEXP diese HOLDER TARGET . [SEP]',
#  '[CLS] Knapp ein Vierteljahrhundert später wirken diese Vorstellungen naiv . [SEP]',
#  '[CLS] Der HOLDER PEXP ja keine TARGET aus . [SEP]',
#  '[CLS] Der Grinch raubt ja keine Getränkeladen aus . [SEP]',
#  '[CLS] Die HOLDER PEXP dem amerikanischen TARGET George Soros , die Einwanderung von Muslimen nach Europa bewusst zu organisieren und zu finanzieren , etwa durch die Unterstützung von NGO . [SEP]',
#  '[CLS] Die Orban-Regierung unterstellt dem amerikanischen Milliardär George Soros , die Einwanderung von Muslimen nach Europa bewusst zu organisieren und zu finanzieren , etwa durch die Unterstützung von NGO . [SEP]',
#  '[CLS] In Spanien geschieht es im Schnitt einmal pro Woche , in Frankreich alle drei Tage , in Russland noch öfter : Eine TARGET wird von einem HOLDER aus ihrem Umfeld PEXP . [SEP]',
#  '[CLS] In Spanien geschieht es im Schnitt einmal pro Woche , in Frankreich alle drei Tage , in Russland noch öfter : Eine Frau wird von einem Mann aus ihrem Umfeld getötet . [SEP]',
#  '[CLS] Und das , obwohl das HOLDER laut Gesetz nur « ausnahmsweise » bei Härtefällen von einer TARGET PEXP darf . [SEP]',
#  '[CLS] Und das , obwohl das Gericht laut Gesetz nur « ausnahmsweise » bei Härtefällen von einer Ausschaffung absehen darf . [SEP]',
#  '[CLS] Die HOLDER PEXP für TARGET . [SEP]',
#  '[CLS] Die Verteidigung plädierte für Freisprüche . [SEP]',
#  '[CLS] Über Corona wundert man sich kaum mehr , und laut Management muss sich die globale HOLDER nicht PEXP um ihre TARGET . [SEP]',
#  '[CLS] Über Corona wundert man sich kaum mehr , und laut Management muss sich die globale Fangemeinde nicht sorgen um ihre BTS-Stars . [SEP]',
#  '[CLS] Nun erklärt der HOLDER seine Gründe für den Abgang und PEXP dabei scharf auf den neuen TARGET Stephan Keller . [SEP]',
#  '[CLS] Nun erklärt der Mittelfeldspieler seine Gründe für den Abgang und schiesst dabei scharf auf den neuen FCA-Trainer Stephan Keller . [SEP]',
#  '[CLS] So soll der HOLDER bei Castings seine TARGET PEXP und jungen Frauen mit vielversprechenden Rollenangeboten gelockt haben . [SEP]',
#  '[CLS] So soll der Hollywood-Star bei Castings seine Macht ausgenutzt und jungen Frauen mit vielversprechenden Rollenangeboten gelockt haben . [SEP]',
#  '[CLS] 70 HOLDER PEXP aus dem höheren TARGET , den Pendler , Lieferanten und Reisende für ihre Fahrten aufwenden müssen , 24 Prozent aus staubedingten Unfällen , der Rest sind höhere Umwelt- , Klima- und Energiekosten . [SEP]',
#  '[CLS] 70 Prozent entstehen aus dem höheren Zeitbedarf , den Pendler , Lieferanten und Reisende für ihre Fahrten aufwenden müssen , 24 Prozent aus staubedingten Unfällen , der Rest sind höhere Umwelt- , Klima- und Energiekosten . [SEP]',
#  '[CLS] HOLDER trifft acht Mal nicht und PEXP vom TARGET auf den 43. [SEP]',
#  '[CLS] Selina trifft acht Mal nicht und stürzt vom 30. auf den 43. [SEP]',
#  '[CLS] Der Fall Swisscom zeigt , TARGET die HOLDER des Bundesrates PEXP . [SEP]',
#  '[CLS] Der Fall Swisscom zeigt , woran die Postfinance-Pläne des Bundesrates kranken . [SEP]',
#  '[CLS] Gleichzeitig wurden TARGET und weitere Teile des Südens vor wenigen Tagen von heftigen HOLDER PEXP . [SEP]',
#  '[CLS] Gleichzeitig wurden Aden und weitere Teile des Südens vor wenigen Tagen von heftigen Überschwemmungen heimgesucht . [SEP]',
#  '[CLS] Schliesslich kann HOLDER TARGET PEXP . [SEP]',
#  '[CLS] Schliesslich kann Recycling Abhängigkeiten entschärfen . [SEP]',
#  '[CLS] Man muss aber nicht weit in die Vergangenheit schauen , um zu sehen , welche HOLDER von extrem hohen TARGET PEXP . [SEP]',
#  '[CLS] Man muss aber nicht weit in die Vergangenheit schauen , um zu sehen , welche Risiken von extrem hohen Staatsschulden ausgehen . [SEP]',
#  '[CLS] Nordirlands HOLDER PEXP sich weiter gegen jede künftige TARGET administrativer Kontrollen zwischen der Provinz und Grossbritannien . [SEP]',
#  '[CLS] Nordirlands Unionisten sträuben sich weiter gegen jede künftige Form administrativer Kontrollen zwischen der Provinz und Grossbritannien . [SEP]',
#  '[CLS] Im Mai PEXP sich mehrere mutmassliche HOLDER mit TARGET , die vor einer Kontrolle geflüchtet waren . [SEP]',
#  '[CLS] Im Mai solidarisierten sich mehrere mutmassliche GC-Anhänger mit Sprayern , die vor einer Kontrolle geflüchtet waren . [SEP]',
#  '[CLS] Doch HOLDER habe die wirtschaftlichen TARGET durch die Aufhebung der Sanktionen dazu PEXP , um das Budget der Revolutionswächter zu erhöhen und die Unterstützung für ausländische Milizen zu verstärken . [SEP]',
#  '[CLS] Doch Iran habe die wirtschaftlichen Gewinne durch die Aufhebung der Sanktionen dazu benutzt , um das Budget der Revolutionswächter zu erhöhen und die Unterstützung für ausländische Milizen zu verstärken . [SEP]',
#  '[CLS] HOLDER Menschen PEXP TARGET unterschiedlich gut . [SEP]',
#  '[CLS] Psychologie Menschen ertragen Berührungen unterschiedlich gut . [SEP]',
#  '[CLS] Ich google also : « Grosser Frühlings-Sale » , PEXP der HOLDER im TARGET . [SEP]',
#  '[CLS] Ich google also : « Grosser Frühlings-Sale » , wirbt der Brillenladen im Internet . [SEP]',
#  '[CLS] HOLDER Merlani PEXP seine TARGET ab und fuhr am Sonntag zurück nach Bellinzona . [SEP]',
#  '[CLS] Giorgio Merlani brach seine Ferien ab und fuhr am Sonntag zurück nach Bellinzona . [SEP]',
#  '[CLS] HOLDER Ronaldo kann in TARGET zunächst PEXP und Gegenspieler Camada abschütteln – doch am Ende muss er mit einer Niederlage leben . [SEP]',
#  '[CLS] Weltstar Ronaldo kann in Bern zunächst glänzen und Gegenspieler Camada abschütteln – doch am Ende muss er mit einer Niederlage leben . [SEP]',
#  '[CLS] Dass er sich in das sowohl menschlich als auch fachlich erfahrenere TARGET nicht HOLDER über Kopf PEXP hätte , ist ausgeschlossen . [SEP]',
#  '[CLS] Dass er sich in das sowohl menschlich als auch fachlich erfahrenere Mädchen nicht Hals über Kopf verliebt hätte , ist ausgeschlossen . [SEP]',
#  '[CLS] HOLDER PEXP die TARGET zwar ab . [SEP]',
#  '[CLS] Tencent streitet die Vorwürfe zwar ab . [SEP]',
#  '[CLS] Und siehe da , ein HOLDER PEXP den TARGET hinunter , ein anderes wollte nicht trinken . [SEP]',
#  '[CLS] Und siehe da , ein Kalb stürzte den Hang hinunter , ein anderes wollte nicht trinken . [SEP]',
#  '[CLS] Nach seinen Worten bedeutet dies , dass die rigorosen Massnahmen greifen : HOLDER , PEXP von TARGET , dem Kauf von Lebensmitteln und Medikamenten ; erlaubt sind auch Fahrten zur Pflege von Angehörigen . [SEP]',
#  '[CLS] Nach seinen Worten bedeutet dies , dass die rigorosen Massnahmen greifen : Ausgangssperre , abgesehen von Arztbesuchen , dem Kauf von Lebensmitteln und Medikamenten ; erlaubt sind auch Fahrten zur Pflege von Angehörigen . [SEP]',
#  '[CLS] Und vor einem Monat PEXP die HOLDER im Nations-League-Spiel im Estadio Alfredo di Stefano in Madrid nach einem TARGET von Goalie Yann Sommer 0 : 1. [SEP]',
#  '[CLS] Und vor einem Monat verliert die Schweiz im Nations-League-Spiel im Estadio Alfredo di Stefano in Madrid nach einem Fehlpass von Goalie Yann Sommer 0 : 1. [SEP]',
#  '[CLS] Vielerorts sind die Zuwächse so gewaltig , dass die durchschnittliche monatliche Hypothekenbelastung trotz Niedrigzinsen ständig steigt und HOLDER kaum noch bezahlbare TARGET PEXP . [SEP]',
#  '[CLS] Vielerorts sind die Zuwächse so gewaltig , dass die durchschnittliche monatliche Hypothekenbelastung trotz Niedrigzinsen ständig steigt und Familien kaum noch bezahlbare Angebote finden . [SEP]',
#  '[CLS] Wegen Platzmangels musste die HOLDER auf den Stationen für Erwachsene minderjährige TARGET PEXP . [SEP]',
#  '[CLS] Wegen Platzmangels musste die PUK auf den Stationen für Erwachsene minderjährige Patienten aufnehmen . [SEP]',
#  '[CLS] HOLDER PEXP an einer neuen TARGET mit , die den Namen « Seismology and Earthquake Engineering Research Infrastructure Alliance for Europe » ( Sera ) trägt . [SEP]',
#  '[CLS] Wiemer wirkt an einer neuen Initiative mit , die den Namen « Seismology and Earthquake Engineering Research Infrastructure Alliance for Europe » ( Sera ) trägt . [SEP]',
#  '[CLS] Die Stadtpräsidentin Corine Mauch wendet sich an die aufgewühlte Menge und versichert , HOLDER sei bereit , TARGET PEXP und ihnen hier ein sicheres Leben zu ermöglichen . [SEP]',
#  '[CLS] Die Stadtpräsidentin Corine Mauch wendet sich an die aufgewühlte Menge und versichert , Zürich sei bereit , Flüchtlinge aufzunehmen und ihnen hier ein sicheres Leben zu ermöglichen . [SEP]',
#  '[CLS] Der kantonale HOLDER Markus Kägi hat an der Pressekonferenz vom Freitag nun einen beachtlichen TARGET PEXP : Weil es ja auch im Interesse des Kantons liege , die Bojenplätze zu verlegen , komme man den Betreibern entgegen . [SEP]',
#  '[CLS] Der kantonale Baudirektor Markus Kägi hat an der Pressekonferenz vom Freitag nun einen beachtlichen Rabatt angekündigt : Weil es ja auch im Interesse des Kantons liege , die Bojenplätze zu verlegen , komme man den Betreibern entgegen . [SEP]',
#  '[CLS] Entsprechend hat HOLDER zwei neue TARGET für Anfang April PEXP : das Xperia XZ 2 ( 850 Franken ) und das XZ 2 Compact ( 650 Franken ) . [SEP]',
#  '[CLS] Entsprechend hat Sony zwei neue Smartphones für Anfang April angekündigt : das Xperia XZ 2 ( 850 Franken ) und das XZ 2 Compact ( 650 Franken ) . [SEP]',
#  '[CLS] Die HOLDER der sieben grössten demokratischen Industriestaaten – Deutschland , Frankreich , Grossbritannien , Italien , Japan , Kanada und USA – PEXP sich dabei vor allem dem TARGET und den Sanktionen gegen Russland . [SEP]',
#  '[CLS] Die Anführer der sieben grössten demokratischen Industriestaaten – Deutschland , Frankreich , Grossbritannien , Italien , Japan , Kanada und USA – widmen sich dabei vor allem dem Ukraine-Krieg und den Sanktionen gegen Russland . [SEP]',
#  '[CLS] HOLDER Habeck hat in Davos versprochen , sich in der EU für die TARGET PEXP . [SEP]',
#  '[CLS] Robert Habeck hat in Davos versprochen , sich in der EU für die Schweiz einzusetzen . [SEP]',
#  '[CLS] So werden etwa TARGET des jüdischen Fussballklubs Hakoah Zürich regelmässig von den HOLDER PEXP – etwa , dass die Juden den Schiedsrichter gekauft hätten . [SEP]',
#  '[CLS] So werden etwa Spieler des jüdischen Fussballklubs Hakoah Zürich regelmässig von den Gegnern beschimpft – etwa , dass die Juden den Schiedsrichter gekauft hätten . [SEP]',
#  '[CLS] HOLDER hatte im Juni 2018 die TARGET der sterblichen Überreste Francos auf den Friedhof des Madrider Aussenbezirks El Pardo PEXP , wo bereits dessen Witwe nach ihrem Tod 1988 begraben wurde . [SEP]',
#  '[CLS] Sánchez hatte im Juni 2018 die Umbettung der sterblichen Überreste Francos auf den Friedhof des Madrider Aussenbezirks El Pardo angekündigt , wo bereits dessen Witwe nach ihrem Tod 1988 begraben wurde . [SEP]',
#  '[CLS] Politischer HOLDER PEXP aber nicht nur aus quantitativer TARGET . [SEP]',
#  '[CLS] Politischer Einfluss entsteht aber nicht nur aus quantitativer Vertretung . [SEP]',
#  '[CLS] Gleichentags PEXP in TARGET der HOLDER statt . [SEP]',
#  '[CLS] Gleichentags findet in Yongpyong der Männer-Slalom statt . [SEP]',
#  '[CLS] Andreas Flütsch Die HOLDER des Milchverarbeiters Hochdorf PEXP gestern an der Börse zeitweise bis TARGET 20 Prozent ab und lagen am Abend 14 Prozent im Minus . [SEP]',
#  '[CLS] Andreas Flütsch Die Aktien des Milchverarbeiters Hochdorf stürzten gestern an der Börse zeitweise bis zu 20 Prozent ab und lagen am Abend 14 Prozent im Minus . [SEP]',
#  '[CLS] Den TARGET , der vor einer Beinoperation 29-mal getroffen hatte , dürfte ein HOLDER PEXP haben : Tampa Bay holt endlich den Titel und er ist nicht dabei . [SEP]',
#  '[CLS] Den 30-Jährigen , der vor einer Beinoperation 29-mal getroffen hatte , dürfte ein Albtraum heimgesucht haben : Tampa Bay holt endlich den Titel und er ist nicht dabei . [SEP]',
#  '[CLS] Die deutsche HOLDER PEXP sich mit den TARGET . [SEP]',
#  '[CLS] Die deutsche Comedyszene solidarisiert sich mit den Opfern . [SEP]',
#  '[CLS] HOLDER konnten sich in der Abstiegssaison 2016 / 17 in den Stadiönli der Challenge-League-Clubs oder beim jüngsten Cupmatch auf der Zürcher Allmend gegen den FC Red Star von diesem TARGET PEXP . [SEP]',
#  '[CLS] FCZ-Fans konnten sich in der Abstiegssaison 2016 / 17 in den Stadiönli der Challenge-League-Clubs oder beim jüngsten Cupmatch auf der Zürcher Allmend gegen den FC Red Star von diesem Phänomen überzeugen . [SEP]',
#  '[CLS] Der HOLDER werde seine TARGET ab sofort wieder PEXP . [SEP]',
#  '[CLS] Der Whistleblower werde seine Arbeit ab sofort wieder aufnehmen . [SEP]',
#  '[CLS] TARGET am Vortag hatte der HOLDER 0,11 Prozentpunkte PEXP . [SEP]',
#  '[CLS] Bereits am Vortag hatte der Conf-Future 0,11 Prozentpunkte verloren . [SEP]',
#  '[CLS] Um den langjährigen TARGET zu PEXP , haben sich sechs HOLDER – von Mitte links bis zur rechtsextremen Jobbik – zum Bündnis « Mindenki Magyarorszaga Mozgalom » ( Ungarn gehört jedem ) zusammengeschlossen . [SEP]',
#  '[CLS] Um den langjährigen Ministerpräsidenten zu stürzen , haben sich sechs Parteien – von Mitte links bis zur rechtsextremen Jobbik – zum Bündnis « Mindenki Magyarorszaga Mozgalom » ( Ungarn gehört jedem ) zusammengeschlossen . [SEP]',
#  '[CLS] Der HOLDER PEXP die TARGET am Samstag frühzeitig ab . [SEP]',
#  '[CLS] Der Veranstalter brach die Summerslide am Samstag frühzeitig ab . [SEP]',
#  '[CLS] Der HOLDER der PSG-Token dürfte auch TARGET selbst PEXP . [SEP]',
#  '[CLS] Der Höhenflug der PSG-Token dürfte auch Messi selbst erfreuen . [SEP]',
#  '[CLS] Zwar PEXP bereits in den 1860er-Jahren neben einer republikanischen auch eine abolitionistische HOLDER – TARGET zuletzt auf Druck des Auslands . [SEP]',
#  '[CLS] Zwar entstand bereits in den 1860er-Jahren neben einer republikanischen auch eine abolitionistische Bewegung – nicht zuletzt auf Druck des Auslands . [SEP]',
#  '[CLS] Trotzdem PEXP die HOLDER bis heute die TARGET seines Protests ab . [SEP]',
#  '[CLS] Trotzdem streiten die Kritiker bis heute die Redlichkeit seines Protests ab . [SEP]',
#  '[CLS] Damit wird im Landeanflug die Leistung geregelt , wobei durch die TARGET auch ein ungewöhnliches HOLDER PEXP . [SEP]',
#  '[CLS] Damit wird im Landeanflug die Leistung geregelt , wobei durch die Motoraussetzer auch ein ungewöhnliches Fluggeräusch entsteht . [SEP]',
#  '[CLS] So PEXP die HOLDER mit dem TARGET Phee , dem griechischen Wort für Seegras . [SEP]',
#  '[CLS] So entstand die Firma mit dem Namen Phee , dem griechischen Wort für Seegras . [SEP]',
#  '[CLS] Die HOLDER hat aus den Problemen im US-Geschäft , die durch Umsatzeinbussen in der Vermarktung von Schlössern für Bancomaten \xad sowie unzureichende Erträge in der \xad Serviceorganisation verschärft worden waren , die TARGET PEXP . [SEP]',
#  '[CLS] Die Konzernführung hat aus den Problemen im US-Geschäft , die durch Umsatzeinbussen in der Vermarktung von Schlössern für Bancomaten \xad sowie unzureichende Erträge in der \xad Serviceorganisation verschärft worden waren , die Konsequenzen gezogen . [SEP]',
#  '[CLS] Es entsteht eine neue Kombination der Genomsegmente der zwei Viren , und dementsprechend kann daraus ein HOLDER mit neuen TARGET PEXP . [SEP]',
#  '[CLS] Es entsteht eine neue Kombination der Genomsegmente der zwei Viren , und dementsprechend kann daraus ein Virus mit neuen Eigenschaften entstehen . [SEP]',
#  '[CLS] Jahrzehntelang kam das Böse vor allem aus dem Ostblock ; Bond verführte eine junge Frau nach der anderen , und HOLDER PEXP in dieser TARGET als Tabu . [SEP]',
#  '[CLS] Jahrzehntelang kam das Böse vor allem aus dem Ostblock ; Bond verführte eine junge Frau nach der anderen , und Homosexualität galt in dieser Männerwelt als Tabu . [SEP]',
#  '[CLS] Statt an den Swiss Indoors aufzuschlagen , PEXP HOLDER Wawrinka ( 33 ) die TARGET vorzeitig ab . [SEP]',
#  '[CLS] Statt an den Swiss Indoors aufzuschlagen , bricht Stan Wawrinka ( 33 ) die Saison vorzeitig ab . [SEP]',
#  '[CLS] Die dicken HOLDER der sakralen Bauten PEXP für tiefe TARGET . [SEP]',
#  '[CLS] Die dicken Mauern der sakralen Bauten sorgen für tiefe Raumtemperaturen . [SEP]',
#  '[CLS] Eine HOLDER von ihnen sollte in der Studie ihre bisherigen TARGET PEXP ( Kontrollgruppe ) , während die andere Hälfte angehalten wurde , vier Wochen lang alternierend immer einen Tag normal zu essen und den darauffolgenden Tag keine Kalorien zu sich zu nehmen , und zwar weder in fester noch in flüssiger Form . [SEP]',
#  '[CLS] Eine Hälfte von ihnen sollte in der Studie ihre bisherigen Ernährungsgewohnheiten beibehalten ( Kontrollgruppe ) , während die andere Hälfte angehalten wurde , vier Wochen lang alternierend immer einen Tag normal zu essen und den darauffolgenden Tag keine Kalorien zu sich zu nehmen , und zwar weder in fester noch in flüssiger Form . [SEP]',
#  '[CLS] Der Schritt erfolgt einen Tag nachdem Bulgariens HOLDER gegen sechs russische Staatsbürger TARGET wegen Verstrickungen in eine Reihe von Unfällen zwischen 2011 und 2020 in Lager- und Produktionsstätten der bulgarischen Rüstungsindustrie PEXP hat . [SEP]',
#  '[CLS] Der Schritt erfolgt einen Tag nachdem Bulgariens Generalstaatsanwaltschaft gegen sechs russische Staatsbürger Ermittlungen wegen Verstrickungen in eine Reihe von Unfällen zwischen 2011 und 2020 in Lager- und Produktionsstätten der bulgarischen Rüstungsindustrie aufgenommen hat . [SEP]',
#  '[CLS] In der liberal regierten TARGET PEXP traditionell die zentrale HOLDER statt . [SEP]',
#  '[CLS] In der liberal regierten Stadt fand traditionell die zentrale Feier statt . [SEP]',
#  '[CLS] Nach 9 / 11 PEXP Ende 2001 eine von den USA angeführte HOLDER die TARGET , weil diese der Kaida von Usama bin Ladin Unterschlupf gewährt hatten . [SEP]',
#  '[CLS] Nach 9 / 11 stürzte Ende 2001 eine von den USA angeführte Militärkoalition die Taliban , weil diese der Kaida von Usama bin Ladin Unterschlupf gewährt hatten . [SEP]',
#  '[CLS] Dort PEXP sich HOLDER Neukom der TARGET und dem Bau von leistungsfähigen Segelflugzeugen . [SEP]',
#  '[CLS] Dort widmete sich Albert Neukom der Konstruktion und dem Bau von leistungsfähigen Segelflugzeugen . [SEP]',
#  '[CLS] Möglicherweise PEXP der HOLDER einem nahe gelegenen TARGET . [SEP]',
#  '[CLS] Möglicherweise galt der Beschuss einem nahe gelegenen Eisenbahndepot . [SEP]',
#  '[CLS] Die jüngsten HOLDER PEXP die TARGET in ihren klaren Positionen . [SEP]',
#  '[CLS] Die jüngsten Wahlerfolge bestärkten die Partei in ihren klaren Positionen . [SEP]',
#  '[CLS] Zwar PEXP sich HOLDER umgehend öffentlich und auch persönlich bei TARGET Blum . [SEP]',
#  '[CLS] Zwar entschuldigte sich Meyer umgehend öffentlich und auch persönlich bei Andrea Blum . [SEP]',
#  '[CLS] HOLDER Hero PEXP sich mit 150 000 TARGET weltweit , Just Eat sich mit 80 000 . [SEP]',
#  '[CLS] Delivery Hero brüstet sich mit 150 000 Restaurantpartnern weltweit , Just Eat sich mit 80 000 . [SEP]',
#  '[CLS] Stephanie Erne ... spielt ebenfalls in Luzern und hat eine 80-Prozent-Stelle als Spezialistin für Bewegungs- und Gesundheitsförderung – daneben PEXP ihr HOLDER dem TARGET . [SEP]',
#  '[CLS] Stephanie Erne ... spielt ebenfalls in Luzern und hat eine 80-Prozent-Stelle als Spezialistin für Bewegungs- und Gesundheitsförderung – daneben gilt ihr Engagement dem FI9-Verein . [SEP]',
#  '[CLS] Unter dem chinesischen Besitzer Geely hat HOLDER seine globale TARGET PEXP und weiss eine starke Infrastruktur im Rücken . [SEP]',
#  '[CLS] Unter dem chinesischen Besitzer Geely hat Volvo seine globale Präsenz ausgebaut und weiss eine starke Infrastruktur im Rücken . [SEP]',
#  '[CLS] HOLDER wie Patek Philippe und Zenith PEXP TARGET nach . [SEP]',
#  '[CLS] Konkurrenten wie Patek Philippe und Zenith zogen daraufhin nach . [SEP]',
#  '[CLS] Und natürlich PEXP die strenge HOLDER – TARGET , Aufstehen um 5.10 Uhr , paranoide Überwachung und Unterdrückung von allem , was auch nur aus der Ferne nach Sexualität riecht – zu fantasievollen Ausweichs- und Ausbruchsversuchen . [SEP]',
#  '[CLS] Und natürlich verlockt die strenge Klosterdisziplin – Kuttenzwang , Aufstehen um 5.10 Uhr , paranoide Überwachung und Unterdrückung von allem , was auch nur aus der Ferne nach Sexualität riecht – zu fantasievollen Ausweichs- und Ausbruchsversuchen . [SEP]',
#  '[CLS] Wir sehen alle , wie China und wie – anders , als wir meinen – der HOLDER TARGET PEXP . [SEP]',
#  '[CLS] Wir sehen alle , wie China und wie – anders , als wir meinen – der Westen damit umgeht . [SEP]',
#  '[CLS] HOLDER PEXP dagegen für eine bedingungslose TARGET des Landes , die EU- und die Nato-Mitgliedschaft stellte er nie infrage . [SEP]',
#  '[CLS] Drahos plädierte dagegen für eine bedingungslose Westorientierung des Landes , die EU- und die Nato-Mitgliedschaft stellte er nie infrage . [SEP]',
#  '[CLS] Voraussichtlich in der Sommersession soll die HOLDER dann vom TARGET PEXP werden , wie die SPK am Dienstag mitteilte . [SEP]',
#  '[CLS] Voraussichtlich in der Sommersession soll die Vorlage dann vom Nationalrat behandelt werden , wie die SPK am Dienstag mitteilte . [SEP]',
#  '[CLS] Vor knapp hundert \xad Jahren PEXP HOLDER wegen seiner grandiosen TARGET quasi als Saint-Tropez der Tropen . [SEP]',
#  '[CLS] Vor knapp hundert \xad Jahren galt Kep-sur-Mer wegen seiner grandiosen Lage quasi als Saint-Tropez der Tropen . [SEP]',
#  '[CLS] Der britische HOLDER der Tour de France vermochte in dieser TARGET noch nicht zu PEXP . [SEP]',
#  '[CLS] Der britische Sieger der Tour de France vermochte in dieser Saison noch nicht zu überzeugen . [SEP]',
#  '[CLS] Das HOLDER PEXP im Rennen der Juniorinnen über viermal 3,3 Kilometer 4,9 Sekunden vor den USA und 14,2 Sekunden vor TARGET . [SEP]',
#  '[CLS] Das Quartett triumphierte im Rennen der Juniorinnen über viermal 3,3 Kilometer 4,9 Sekunden vor den USA und 14,2 Sekunden vor Schweden . [SEP]',
#  '[CLS] Der HOLDER PEXP sein in dieser Saison zuvor tadelloses TARGET , den Italiener Maurizio Sarri , indem er den offensiv eingestellten Dele Alli auf den zurückhängenden italienischen Spielmacher Jorginho ansetzte , um dessen Einfluss zu neutralisieren . [SEP]',
#  '[CLS] Der Argentinier überrumpelte sein in dieser Saison zuvor tadelloses Gegenüber , den Italiener Maurizio Sarri , indem er den offensiv eingestellten Dele Alli auf den zurückhängenden italienischen Spielmacher Jorginho ansetzte , um dessen Einfluss zu neutralisieren . [SEP]',
#  '[CLS] HOLDER Siegrist Mit der letzten Folie PEXP TARGET Dinkel von der Stadtzürcher Fachstelle für Gleichstellung noch einmal , wie gross die Unterschiede zwischen Frauen und Männern sind . [SEP]',
#  '[CLS] Patrice Siegrist Mit der letzten Folie verdeutlichte Simon Dinkel von der Stadtzürcher Fachstelle für Gleichstellung noch einmal , wie gross die Unterschiede zwischen Frauen und Männern sind . [SEP]',
#  '[CLS] In TARGET von sogenannten Phasing-inund Supercredit-Bestimmungen für die Jahre 2020 bis 2022 PEXP eine stufenweise HOLDER der Fahrzeugflotte , die 2021 noch zehn und 2022 noch fünf Prozent der Fahrzeuge von der CO2-Berechnung ausschliesst . [SEP]',
#  '[CLS] In Form von sogenannten Phasing-inund Supercredit-Bestimmungen für die Jahre 2020 bis 2022 gilt eine stufenweise Anrechnung der Fahrzeugflotte , die 2021 noch zehn und 2022 noch fünf Prozent der Fahrzeuge von der CO2-Berechnung ausschliesst . [SEP]',
#  '[CLS] Im Gazastreifen hat HOLDER sogar ein härteres TARGET PEXP . [SEP]',
#  '[CLS] Im Gazastreifen hat Gantz sogar ein härteres Durchgreifen angekündigt . [SEP]',
#  '[CLS] Die KI-Bauchspeicheldrüse ist vernetzt mit anderen natürlich-künstlichen Entitäten , und in diesem TARGET PEXP eine neuartige HOLDER statt . [SEP]',
#  '[CLS] Die KI-Bauchspeicheldrüse ist vernetzt mit anderen natürlich-künstlichen Entitäten , und in diesem Netz findet eine neuartige Evolution statt . [SEP]',
#  '[CLS] Kommentar : Diesen Poker kann keiner gewinnen Seite 11 Reflexe : Das HOLDER hat an TARGET PEXP Seite 38 A. R. · Die Blockierung der Strasse von Hormuz ist ein Schreckensszenario , das bei Krisen in der Golfregion regelmässig zu Sorgen Anlass gibt . [SEP]',
#  '[CLS] Kommentar : Diesen Poker kann keiner gewinnen Seite 11 Reflexe : Das Nadelöhr hat an Bedeutung verloren Seite 38 A. R. · Die Blockierung der Strasse von Hormuz ist ein Schreckensszenario , das bei Krisen in der Golfregion regelmässig zu Sorgen Anlass gibt . [SEP]',
#  '[CLS] HOLDER hat diese TARGET PEXP gewonnen . [SEP]',
#  '[CLS] Italien hat diese Lotterie-Veranstaltung verdient gewonnen . [SEP]',
#  '[CLS] HOLDER hat 100 TARGET Sonderschulden für die Bundeswehr PEXP , Japan eine Verdoppelung seines Verteidigungsetats , und China einen Anstieg um sieben Prozent . [SEP]',
#  '[CLS] Deutschland hat 100 Milliarden Sonderschulden für die Bundeswehr angekündigt , Japan eine Verdoppelung seines Verteidigungsetats , und China einen Anstieg um sieben Prozent . [SEP]',
#  '[CLS] Doch nach einigen Aufräumarbeiten , Bekenntnissen und Umbauten PEXP sich der neue HOLDER Hans-Georg Maassen bald hauptsächlich der TARGET des islamistischen Terrors und verlor die Rechtsextremisten wieder aus dem Auge . [SEP]',
#  '[CLS] Doch nach einigen Aufräumarbeiten , Bekenntnissen und Umbauten widmete sich der neue Verfassungsschutz-Chef Hans-Georg Maassen bald hauptsächlich der Abwehr des islamistischen Terrors und verlor die Rechtsextremisten wieder aus dem Auge . [SEP]',
#  '[CLS] Man kann jetzt den TARGET sagen , die ihren Urlaub planen wollen , dass sie das natürlich machen können . » Doch im nächsten Atemzug PEXP der HOLDER an die Menschen , « jetzt nicht aus dem Kreis heraus in andere Kreise zu fahren . [SEP]',
#  '[CLS] Man kann jetzt den Menschen sagen , die ihren Urlaub planen wollen , dass sie das natürlich machen können . » Doch im nächsten Atemzug appellierte der 59-Jährige an die Menschen , « jetzt nicht aus dem Kreis heraus in andere Kreise zu fahren . [SEP]',
#  '[CLS] Insbesondere PEXP die HOLDER in einem Bulletin vor Angriffen durch militante TARGET , die vom Boden aus mit relativ einfachen Waffen hantieren . [SEP]',
#  '[CLS] Insbesondere warnt die FAA in einem Bulletin vor Angriffen durch militante Rebellen , die vom Boden aus mit relativ einfachen Waffen hantieren . [SEP]',
#  '[CLS] Da die HOLDER bereits mit Eltern TARGET PEXP und sich medial geäussert habe , sei die Antwort auf beide Fragen : Nein . [SEP]',
#  '[CLS] Da die Lehrerin bereits mit Eltern Kontakt aufgenommen und sich medial geäussert habe , sei die Antwort auf beide Fragen : Nein . [SEP]',
#  '[CLS] Drohgebärden – 100 TARGET China hat ein « grossflächiges , wichtiges HOLDER » PEXP . [SEP]',
#  '[CLS] Drohgebärden – 100 % China hat ein « grossflächiges , wichtiges Militärmanöver » angekündigt . [SEP]',
#  '[CLS] Schon im Sommer 2020 hatten zudem die HOLDER und Bahrain in einem historischen Schritt diplomatische TARGET mit Israel PEXP . [SEP]',
#  '[CLS] Schon im Sommer 2020 hatten zudem die Emirate und Bahrain in einem historischen Schritt diplomatische Beziehungen mit Israel aufgenommen . [SEP]',
#  '[CLS] Die HOLDER hat TARGET zur Unfallursache PEXP . [SEP]',
#  '[CLS] Die Kantonspolizei hat Abklärungen zur Unfallursache aufgenommen . [SEP]',
#  '[CLS] Die bronzene Suffragistin – im TARGET zu den Suffragetten PEXP deren historisches HOLDER für Gewaltverzicht – ist eine Mahnerin , die von Worten lebt . [SEP]',
#  '[CLS] Die bronzene Suffragistin – im Gegensatz zu den Suffragetten plädierte deren historisches Vorbild für Gewaltverzicht – ist eine Mahnerin , die von Worten lebt . [SEP]',
#  '[CLS] Deshalb muss HOLDER den TARGET Hongkongs langfristig PEXP . [SEP]',
#  '[CLS] Deshalb muss Peking den Geist Hongkongs langfristig zerstören . [SEP]',
#  '[CLS] Das HOLDER sei beim Aufprall zerschellt , die bislang bekannten 29 TARGET ins 15 Grad kalte Wasser PEXP . [SEP]',
#  '[CLS] Das Boot sei beim Aufprall zerschellt , die bislang bekannten 29 Insassen ins 15 Grad kalte Wasser gestürzt . [SEP]',
#  '[CLS] ‹ Er war krank , es ist etwas , das er schon länger mit sich herumschleppte › , sagte der Kanadier . » 2011 : « Derbyfieber » 2008 : « Blindenbacher legte nach mehreren Tagen mit hohem Fieber erst am Matchtag fest , die Reise nach Genf mitzumachen . » 2005 : « Nicht mehr dabei war in der Schlussphase auch der erkrankte Claudio Micheli , er wird in der zweiten Partie aber ebenfalls wieder spielen . » 2002 : « HOLDER PEXP am Sonntag tatsächlich unter einer TARGET und rund 39 Grad Fieber . » 2001 : « In Zürich geniesst man die Rückkehr des Playoff-Fiebers , das die Regionvor einem Jahr erfasst und die Mannschaft zum Titel getragen hat . » 2000 : « Micheli erbte den Silberhelm des obersten Skorers vom erkrankten Peter Jaks . [SEP]',
#  '[CLS] ‹ Er war krank , es ist etwas , das er schon länger mit sich herumschleppte › , sagte der Kanadier . » 2011 : « Derbyfieber » 2008 : « Blindenbacher legte nach mehreren Tagen mit hohem Fieber erst am Matchtag fest , die Reise nach Genf mitzumachen . » 2005 : « Nicht mehr dabei war in der Schlussphase auch der erkrankte Claudio Micheli , er wird in der zweiten Partie aber ebenfalls wieder spielen . » 2002 : « Sulander litt am Sonntag tatsächlich unter einer Magen-Darm-Grippe und rund 39 Grad Fieber . » 2001 : « In Zürich geniesst man die Rückkehr des Playoff-Fiebers , das die Regionvor einem Jahr erfasst und die Mannschaft zum Titel getragen hat . » 2000 : « Micheli erbte den Silberhelm des obersten Skorers vom erkrankten Peter Jaks . [SEP]',
#  '[CLS] Im Bezirk Fresno County PEXP ein HOLDER bei TARGET ab , der Pilot kam ums Leben . [SEP]',
#  '[CLS] Im Bezirk Fresno County stürzte ein Helikopter bei Löscharbeiten ab , der Pilot kam ums Leben . [SEP]',
#  '[CLS] Die HOLDER PEXP jeweils den besten TARGET . [SEP]',
#  '[CLS] Die Auszeichnung belohnt jeweils den besten Erstlingsfilm . [SEP]',
#  '[CLS] Der HOLDER zu einem angemieteten Schliessfach PEXP immer in Begleitung von Personal statt – und zwar bis TARGET Schliessfach , ab dann hätten die Kunden Diskretion , sagt Andreas Hablützel , Chef des Edelmetallhändlers . [SEP]',
#  '[CLS] Der Zugang zu einem angemieteten Schliessfach finde immer in Begleitung von Personal statt – und zwar bis zum Schliessfach , ab dann hätten die Kunden Diskretion , sagt Andreas Hablützel , Chef des Edelmetallhändlers . [SEP]',
#  '[CLS] Messerattacke in Deutschland In der Innenstadt von Würzburg hat ein 24-jähriger HOLDER mindestens drei TARGET PEXP und weitere verletzt , darunter ein kleiner Bub . [SEP]',
#  '[CLS] Messerattacke in Deutschland In der Innenstadt von Würzburg hat ein 24-jähriger Mann mindestens drei Menschen getötet und weitere verletzt , darunter ein kleiner Bub . [SEP]',
#  '[CLS] Dort hat der über 70-jährige Hans HOLDER seinen TARGET PEXP . [SEP]',
#  '[CLS] Dort hat der über 70-jährige Hans Stöckli seinen Rücktritt angekündigt . [SEP]',
#  '[CLS] Doch wie PEXP die TARGET dafür , dass der Kuchen im Sinne der Kunden und volkswirtschaftlich sinnvoll verteilt wird , der HOLDER nicht überhitzt und dem Unterhalt nach wie vor Priorität gegeben wird ? [SEP]',
#  '[CLS] Doch wie sorgen die Bäcker dafür , dass der Kuchen im Sinne der Kunden und volkswirtschaftlich sinnvoll verteilt wird , der Ofen nicht überhitzt und dem Unterhalt nach wie vor Priorität gegeben wird ? [SEP]',
#  '[CLS] Verständlicherweise PEXP unter den anderen TARGET nicht gerade HOLDER ob Trumps Vorstoss aus . [SEP]',
#  '[CLS] Verständlicherweise brach unter den anderen G-7-Ländern nicht gerade Jubel ob Trumps Vorstoss aus . [SEP]',
#  '[CLS] Der brasilianische HOLDER PEXP den TARGET der Bundespolizei . [SEP]',
#  '[CLS] Der brasilianische Präsident entliess den Chef der Bundespolizei . [SEP]',
#  '[CLS] Gesundheitsdirektorin Natalie HOLDER ( SVP ) sieht es ebenso : « Für den Rückgang der Fallzahlen war der Reputationsverlust mitverantwortlich . » Auch Rickli PEXP die TARGET für eine Rüge an die Spitalleitung : « Da fehlt ihr die nötige selbstkritische Sicht . » Die Gesundheitsdirektorin ist zuversichtlich , dass es in Zukunft besser wird . [SEP]',
#  '[CLS] Gesundheitsdirektorin Natalie Rickli ( SVP ) sieht es ebenso : « Für den Rückgang der Fallzahlen war der Reputationsverlust mitverantwortlich . » Auch Rickli benutzte die Gelegenheit für eine Rüge an die Spitalleitung : « Da fehlt ihr die nötige selbstkritische Sicht . » Die Gesundheitsdirektorin ist zuversichtlich , dass es in Zukunft besser wird . [SEP]',
#  '[CLS] Seine HOLDER PEXP einem umkämpften TARGET . [SEP]',
#  '[CLS] Seine Konzentration gilt einem umkämpften Ballwechsel . [SEP]',
#  '[CLS] Seine überhastete HOLDER PEXP einen TARGET aus , der verdeutlichte , wie schwach nach wie vor die Machtbasis des Staates war . [SEP]',
#  '[CLS] Seine überhastete Reformpolitik löste einen Bürgerkrieg aus , der verdeutlichte , wie schwach nach wie vor die Machtbasis des Staates war . [SEP]',
#  '[CLS] Und HOLDER Franziskus wird folglich auch nicht müde , das TARGET zu PEXP , es zum « Misthaufen des Teufels » zu reden und als Spaltpilz zu brandmarken , der die Menschen gegeneinander aufbringe . [SEP]',
#  '[CLS] Und Papst Franziskus wird folglich auch nicht müde , das Geld zu verdammen , es zum « Misthaufen des Teufels » zu reden und als Spaltpilz zu brandmarken , der die Menschen gegeneinander aufbringe . [SEP]',
#  '[CLS] Einzelne HOLDER PEXP zudem vor einer TARGET « Managerbonus » . [SEP]',
#  '[CLS] Einzelne Kantone warnen zudem vor einer Art « Managerbonus » . [SEP]',
#  '[CLS] und Duterte-Carpio werden verhindern , dass die HOLDER Philippinen aus den TARGET der Vergangenheit PEXP . [SEP]',
#  '[CLS] und Duterte-Carpio werden verhindern , dass die \xad Philippinen aus den Fehlern der Vergangenheit lernen . [SEP]',
#  '[CLS] Solche TARGET zu PEXP , setzt ein HOLDER im Konjunktiv voraus . [SEP]',
#  '[CLS] Solche Alternativen zu finden , setzt ein Denken im Konjunktiv voraus . [SEP]',
#  '[CLS] Joe Biden ( 77 ) , schon bei der chaotischen Vorwahl in Iowa nur gerade Vierter , hat nun am Dienstag auch in TARGET Hampshire eine HOLDER PEXP . [SEP]',
#  '[CLS] Joe Biden ( 77 ) , schon bei der chaotischen Vorwahl in Iowa nur gerade Vierter , hat nun am Dienstag auch in New Hampshire eine Schlappe erlitten . [SEP]',
#  '[CLS] HOLDER Göttler aus Deutschland und der spanische Speed-Bergsteiger Kílian Jornet PEXP vergangenes Jahr ihren maskenfreien TARGET auf dem Südsattel in etwa 8000 Metern Höhe ab . [SEP]',
#  '[CLS] David Göttler aus Deutschland und der spanische Speed-Bergsteiger Kílian Jornet brachen vergangenes Jahr ihren maskenfreien Gipfelversuch auf dem Südsattel in etwa 8000 Metern Höhe ab . [SEP]',
#  '[CLS] Und so kommt es , dass die HOLDER im TARGET eines Unfalls Klagen PEXP müssten . [SEP]',
#  '[CLS] Und so kommt es , dass die Verantwortlichen im Falle eines Unfalls Klagen befürchten müssten . [SEP]',
#  '[CLS] HOLDER Habeck PEXP bei den deutschen Grünen als das grösste Talent seit TARGET Fischer . [SEP]',
#  '[CLS] Robert Habeck gilt bei den deutschen Grünen als das grösste Talent seit Joschka Fischer . [SEP]',
#  '[CLS] Die HOLDER wählt die nichtständigen Mit \xad glieder jeweils für zwei Jahre und PEXP dabei auf eine angemessene geografische TARGET . [SEP]',
#  '[CLS] Die Uno-Generalversammlung wählt die nichtständigen Mit \xad glieder jeweils für zwei Jahre und achtet dabei auf eine angemessene geografische Verteilung . [SEP]',
#  '[CLS] Allgemein schreibt es aber : « Fedpol prüft Unmutsbekundungen und Drohungen , die uns von Schutzpersonen oder deren Entourage gemeldet werden . » Am Donnerstagabend PEXP HOLDER am TARGET seine « Feuer frei ! » -Aufforderung . [SEP]',
#  '[CLS] Allgemein schreibt es aber : « Fedpol prüft Unmutsbekundungen und Drohungen , die uns von Schutzpersonen oder deren Entourage gemeldet werden . » Am Donnerstagabend rechtfertigte Dudli am Telefon seine « Feuer frei ! » -Aufforderung . [SEP]',
#  '[CLS] Die HOLDER PEXP in ausbruchsicheren TARGET statt . [SEP]',
#  '[CLS] Die Sitzungen finden in ausbruchsicheren Räumen statt . [SEP]',
#  '[CLS] Da HOLDER stärker auf dieses TARGET PEXP als früher , kommt es auch häufiger zu markanten Kursrückgängen . [SEP]',
#  '[CLS] Da Anleger stärker auf dieses Thema achten als früher , kommt es auch häufiger zu markanten Kursrückgängen . [SEP]',
#  '[CLS] HOLDER PEXP sich bei der Raiffeisen-Gruppe , aber auch bei seinem ehemaligen TARGET , der Basler Kantonalbank . [SEP]',
#  '[CLS] Lachappelle entschuldigte sich bei der Raiffeisen-Gruppe , aber auch bei seinem ehemaligen Arbeitgeber , der Basler Kantonalbank . [SEP]',
#  '[CLS] Der deutsche HOLDER Frank-Walter Steinmeier soll sich vor dem Parlament in TARGET PEXP , in den nächsten Jahrzehnten will Deutschland 1,1 Milliarden Euro für soziale Projekte ausgeben . [SEP]',
#  '[CLS] Der deutsche Bundespräsident Frank-Walter Steinmeier soll sich vor dem Parlament in Namibia entschuldigen , in den nächsten Jahrzehnten will Deutschland 1,1 Milliarden Euro für soziale Projekte ausgeben . [SEP]',
#  '[CLS] Dass es nicht mehr um alles ging , hatten bereits die Goalienominationen erahnen lassen : Die HOLDER PEXP TARGET Flüeler nach dessen starkem Comeback vom Vorabend , und weil Joni Ortio verletzt fehlte , gaben sie Daniel Guntern die zweite Einsatzchance von Anfang an . [SEP]',
#  '[CLS] Dass es nicht mehr um alles ging , hatten bereits die Goalienominationen erahnen lassen : Die Zürcher schonten Lukas Flüeler nach dessen starkem Comeback vom Vorabend , und weil Joni Ortio verletzt fehlte , gaben sie Daniel Guntern die zweite Einsatzchance von Anfang an . [SEP]',
#  '[CLS] HOLDER K. PEXP vom obersten Balkon zehn TARGET in die Tiefe . [SEP]',
#  '[CLS] Anita K. stürzte vom obersten Balkon zehn Meter in die Tiefe . [SEP]',
#  '[CLS] Nach der Ankündigung des Bundesprogramms PEXP die erste HOLDER der Banken denn auch nicht der TARGET der KMU , die Covid-Gelder zurückzuzahlen , sondern der Beanspruchung ihrer liquiden Mittel . [SEP]',
#  '[CLS] Nach der Ankündigung des Bundesprogramms galt die erste Sorge der Banken denn auch nicht der Fähigkeit der KMU , die Covid-Gelder zurückzuzahlen , sondern der Beanspruchung ihrer liquiden Mittel . [SEP]',
#  '[CLS] Der Hintergrund : Tags zuvor hatte der HOLDER Twitter seine TARGET für einen milliardenschweren Börsengang PEXP . [SEP]',
#  '[CLS] Der Hintergrund : Tags zuvor hatte der Kurznachrichtendienst Twitter seine Pläne für einen milliardenschweren Börsengang angekündigt . [SEP]',
#  '[CLS] HANS BECK , UTZENSTORF BE Die HOLDER PEXP sich jahrelang gegen erneuerbare TARGET . [SEP]',
#  '[CLS] HANS BECK , UTZENSTORF BE Die SVP sträubte sich jahrelang gegen erneuerbare Energien . [SEP]',
#  '[CLS] HOLDER Pesonen PEXP TARGET , spielt mit viel Risiko , etwas gedankenlos und nonchalant . [SEP]',
#  '[CLS] Harri Pesonen wirkt ausgelaugt , spielt mit viel Risiko , etwas gedankenlos und nonchalant . [SEP]',
#  '[CLS] HOLDER haben gegen diesen Plan aber mehrere TARGET rechtliche Schritte PEXP . [SEP]',
#  '[CLS] Begreiflicherweise haben gegen diesen Plan aber mehrere Verbände rechtliche Schritte angekündigt . [SEP]',
#  '[CLS] Der HOLDER aber hat ein fast unerschütterliches TARGET PEXP . [SEP]',
#  '[CLS] Der Postauto-Skandal aber hat ein fast unerschütterliches Vertrauen zerstört . [SEP]',
#  '[CLS] « Aber man kann nicht beides haben : eine antirassistische Stadt und rassistische Zeichen an den Häusern . » Das HOLDER Vo da werde sich weiterhin für deren TARGET PEXP . [SEP]',
#  '[CLS] « Aber man kann nicht beides haben : eine antirassistische Stadt und rassistische Zeichen an den Häusern . » Das Kollektiv Vo da werde sich weiterhin für deren Entfernung einsetzen . [SEP]',
#  '[CLS] Denn der radikale und politische HOLDER PEXP sich vermutlich nie mit unserer westlichen TARGET . [SEP]',
#  '[CLS] Denn der radikale und politische Islam verträgt sich vermutlich nie mit unserer westlichen Lebensweise . [SEP]',
#  '[CLS] Abstimmung Zu grosse Befugnisse für Polizei : HOLDER PEXP vor dem TARGET . [SEP]',
#  '[CLS] Abstimmung Zu grosse Befugnisse für Polizei : Experten warnen vor dem Antiterrorgesetz . [SEP]',
#  '[CLS] In keinem anderen Land wäre diese Koinzidenz der Rede wert ; hier jedoch , wo die HOLDER des jeweiligen Hof- und Staatsoperndirektors seit den Tagen Gustav Mahlers und Herbert von Karajans mindestens die gleiche öffentliche TARGET PEXP wie diejenige des gerade am nahen Ballhausplatz waltenden Kanzlers , wird solch ein Jubiläum wiederum selbst zum Politikum : zu einer Demonstration des Beharrungs- und Überlebenswillens , mag es ringsherum auch noch so puffen und knallen . [SEP]',
#  '[CLS] In keinem anderen Land wäre diese Koinzidenz der Rede wert ; hier jedoch , wo die Amtsführung des jeweiligen Hof- und Staatsoperndirektors seit den Tagen Gustav Mahlers und Herbert von Karajans mindestens die gleiche öffentliche Aufmerksamkeit geniesst wie diejenige des gerade am nahen Ballhausplatz waltenden Kanzlers , wird solch ein Jubiläum wiederum selbst zum Politikum : zu einer Demonstration des Beharrungs- und Überlebenswillens , mag es ringsherum auch noch so puffen und knallen . [SEP]',
#  '[CLS] Werner Enz · Die meisten internationalen HOLDER haben inzwischen die TARGET ihrer China-Flüge bis Ende März PEXP . [SEP]',
#  '[CLS] Werner Enz · Die meisten internationalen Fluggesellschaften haben inzwischen die Einstellung ihrer China-Flüge bis Ende März angekündigt . [SEP]',
#  '[CLS] Zwei läppische HOLDER vermögen das TARGET nicht grundsätzlich zu PEXP . [SEP]',
#  '[CLS] Zwei läppische Fehltritte vermögen das Selbstverständnis nicht grundsätzlich zu erschüttern . [SEP]',
#  '[CLS] Die HOLDER PEXP vor einem « lebensgefährlichen TARGET und Überschwemmungen von historischem Ausmass » . [SEP]',
#  '[CLS] Die Behörden warnten vor einem « lebensgefährlichen Sturm und Überschwemmungen von historischem Ausmass » . [SEP]',
#  '[CLS] Nebst Gewalt von und an Polizeiangehörigen müssten sie Reizthemen wie das Racial Profiling untersuchen und die Frage beantworten , ob die HOLDER TARGET PEXP . [SEP]',
#  '[CLS] Nebst Gewalt von und an Polizeiangehörigen müssten sie Reizthemen wie das Racial Profiling untersuchen und die Frage beantworten , ob die Aufzeichnungen deeskalierend wirken . [SEP]',
#  '[CLS] Der stark geschützte Landwirtschaftssektor geriet in helle Aufregung , weil der HOLDER in einer agrarpolitischen Gesamtschau eine weitere TARGET der Märkte PEXP und einen Abbau des Grenzschutzes um 30 bis 50 Prozent als Ziel deklariert hatte . [SEP]',
#  '[CLS] Der stark geschützte Landwirtschaftssektor geriet in helle Aufregung , weil der Bundesrat in einer agrarpolitischen Gesamtschau eine weitere Öffnung der Märkte angekündigt und einen Abbau des Grenzschutzes um 30 bis 50 Prozent als Ziel deklariert hatte . [SEP]',
#  '[CLS] HOLDER Regula Rytz PEXP ergänzend für einen gesetzlich verankerten TARGET und Korrekturmassnahmen bei verfehlten Zielen für den Stickstoffverbrauch sowie den Einsatz chemisch-synthetischer Pestizide . [SEP]',
#  '[CLS] Grünen-Präsidentin Regula Rytz plädiert ergänzend für einen gesetzlich verankerten Absenkpfad und Korrekturmassnahmen bei verfehlten Zielen für den Stickstoffverbrauch sowie den Einsatz chemisch-synthetischer Pestizide . [SEP]',
#  '[CLS] Nachdem der langjährige HOLDER Joseph Blatter seinen TARGET PEXP hatte , gab Platini seine Kandidatur für die Nachfolge bekannt . [SEP]',
#  '[CLS] Nachdem der langjährige Präsident Joseph Blatter seinen Rücktritt angekündigt hatte , gab Platini seine Kandidatur für die Nachfolge bekannt . [SEP]',
#  '[CLS] Die Vereinigten Arabischen HOLDER ( VAE ) hätten TARGET und dessen Familie « aus humanitären Gründen » PEXP , liess das Aussenministerium in Abu Dhabi gestern verlauten . [SEP]',
#  '[CLS] Die Vereinigten Arabischen Emirate ( VAE ) hätten Ghani und dessen Familie « aus humanitären Gründen » aufgenommen , liess das Aussenministerium in Abu Dhabi gestern verlauten . [SEP]',
#  '[CLS] Dummerweise PEXP die HOLDER der Grünliberalen am selben TARGET statt . [SEP]',
#  '[CLS] Dummerweise fand die Delegiertenversammlung der Grünliberalen am selben Tag statt . [SEP]',
#  '[CLS] Der HOLDER PEXP diese TARGET jedoch ab . [SEP]',
#  '[CLS] Der Gesamtregierungsrat streitet diese Vorwürfe jedoch ab . [SEP]',
#  '[CLS] Jon Mettler Das aus China stammende HOLDER PEXP die Schweizer TARGET in eine der grössten Krisen seit der Nachkriegszeit . [SEP]',
#  '[CLS] Jon Mettler Das aus China stammende Coronavirus stürzt die Schweizer Uhrenindustrie in eine der grössten Krisen seit der Nachkriegszeit . [SEP]',
#  '[CLS] Welche Pflanzen und Tiere dort lebten und was sie ässen – auch da ist HOLDER gut vorbereitet und PEXP allein rund vierzig TARGET . [SEP]',
#  '[CLS] Welche Pflanzen und Tiere dort lebten und was sie ässen – auch da ist Scheuchzer gut vorbereitet und nennt allein rund vierzig Insektenarten . [SEP]',
#  '[CLS] Das belgische HOLDER prallte an der Lombardei-Rundfahrt in eine Brückenmauer und PEXP TARGET mehrere Meter in die Tiefe . [SEP]',
#  '[CLS] Das belgische Supertalent prallte an der Lombardei-Rundfahrt in eine Brückenmauer und stürzte kopfvoran mehrere Meter in die Tiefe . [SEP]',
#  '[CLS] Denn was die Tour de France mittlerweile fast jedes Jahr praktiziert , macht nun auch die MLB : HOLDER Grand Départ PEXP im TARGET statt – im Falle der Baseballer in Japan . [SEP]',
#  '[CLS] Denn was die Tour de France mittlerweile fast jedes Jahr praktiziert , macht nun auch die MLB : Le Grand Départ findet im Ausland statt – im Falle der Baseballer in Japan . [SEP]',
#  '[CLS] Im Rahmen der Militäraktion « Morgengrauen » PEXP die israelische HOLDER auch den südlichen TARGET der Palästinenserorganisation Islamischer Dschihad ( PIJ ) , Chalid Mansur . [SEP]',
#  '[CLS] Im Rahmen der Militäraktion « Morgengrauen » tötete die israelische Armee auch den südlichen Kommandanten der Palästinenserorganisation Islamischer Dschihad ( PIJ ) , Chalid Mansur . [SEP]',
#  '[CLS] Das HOLDER bleibe , das ganze Rudel zu dezimieren , vor allem aber den besonders auffälligen TARGET PEXP , so der Kanton Graubünden . [SEP]',
#  '[CLS] Das Ziel bleibe , das ganze Rudel zu dezimieren , vor allem aber den besonders auffälligen Leitrüden abzuschiessen , so der Kanton Graubünden . [SEP]',
#  '[CLS] Es ist zu hoffen , dass das HOLDER den voraussetzungslosen TARGET der Lichtbilder – wie man Fotografien auch nennt – wieder aus dem Urheberrechtsgesetz PEXP . [SEP]',
#  '[CLS] Es ist zu hoffen , dass das Parlament den voraussetzungslosen Schutz der Lichtbilder – wie man Fotografien auch nennt – wieder aus dem Urheberrechtsgesetz entfernt . [SEP]',
#  '[CLS] Amsterdam – Mit drei Schüssen wurde ein TARGET in Amsterdam von der HOLDER PEXP . [SEP]',
#  '[CLS] Amsterdam – Mit drei Schüssen wurde ein Deutscher in Amsterdam von der Polizei getötet . [SEP]',
#  '[CLS] Einige HOLDER haben die TARGET PEXP , um sich noch mehr Macht zuzuschanzen , man kennt den Fall von Ungarn , auch die zentralasiatischen Staaten oder Indien waren in dieser Hinsicht recht bemerkenswert . [SEP]',
#  '[CLS] Einige Autokraten haben die Gelegenheit genutzt , um sich noch mehr Macht zuzuschanzen , man kennt den Fall von Ungarn , auch die zentralasiatischen Staaten oder Indien waren in dieser Hinsicht recht bemerkenswert . [SEP]',
#  '[CLS] Die HOLDER PEXP in einem TARGET von nur fünf Tagen statt . [SEP]',
#  '[CLS] Die Vernehmungen fanden in einem Zeitraum von nur fünf Tagen statt . [SEP]',
#  '[CLS] Die Erstberatungsstelle soll künftig immer darüber entscheiden , ob eine medizinische Behandlung nötig ist , ob sie durch den Hausarzt ausgeführt wird oder ob eine HOLDER an einen TARGET PEXP ist . [SEP]',
#  '[CLS] Die Erstberatungsstelle soll künftig immer darüber entscheiden , ob eine medizinische Behandlung nötig ist , ob sie durch den Hausarzt ausgeführt wird oder ob eine Überweisung an einen Spezialisten angezeigt ist . [SEP]',
#  '[CLS] HOLDER Grüter ( SVP ) , Präsident der Aussenpolitischen Kommission des Nationalrats , PEXP für grösstmögliche TARGET . [SEP]',
#  '[CLS] Franz Grüter ( SVP ) , Präsident der Aussenpolitischen Kommission des Nationalrats , plädiert für grösstmögliche Zurückhaltung . [SEP]',
# ...
#  '[CLS] Beide Klubs sind praktisch ohne Fans angereist , und ihnen fehlt ein HOLDER zur Schweiz , PEXP von ein paar obskuren TARGET , die einmal in der Nationalliga herumschwirrten und so wenig Spuren hinterliessen , dass sie allenfalls noch zur perfiden Antwort in einer Quizshow taugen würden . [SEP]',
#  '[CLS] Beide Klubs sind praktisch ohne Fans angereist , und ihnen fehlt ein Bezug zur Schweiz , abgesehen von ein paar obskuren Namen , die einmal in der Nationalliga herumschwirrten und so wenig Spuren hinterliessen , dass sie allenfalls noch zur perfiden Antwort in einer Quizshow taugen würden . [SEP]',
#  '[CLS] Von den US-Unternehmen waren sogar praktisch alle von den Massnahmen betroffen , 60 HOLDER mussten ihre TARGET PEXP . [SEP]',
#  '[CLS] Von den US-Unternehmen waren sogar praktisch alle von den Massnahmen betroffen , 60 Prozent mussten ihre Produktion einschränken . [SEP]',
#  '[CLS] Mitte April hatte HOLDER Ski den TARGET Markus Segessenmann PEXP , weniger als ein Jahr vor den Olympischen Spielen . [SEP]',
#  '[CLS] Mitte April hatte Swiss Ski den Disziplinenchef Markus Segessenmann entlassen , weniger als ein Jahr vor den Olympischen Spielen . [SEP]',
#  '[CLS] Berlin treibt mit aller Macht das Projekt der russisch-deutschen Gaspipeline Nord Stream 2 durch die Ostsee voran , obwohl die direkt betroffenen HOLDER wie die baltischen Staaten und Polen , aber auch Frankreich und die USA TARGET PEXP . [SEP]',
#  '[CLS] Berlin treibt mit aller Macht das Projekt der russisch-deutschen Gaspipeline Nord Stream 2 durch die Ostsee voran , obwohl die direkt betroffenen Anrainer wie die baltischen Staaten und Polen , aber auch Frankreich und die USA dagegen opponieren . [SEP]',
#  '[CLS] Jüngst hat ein HOLDER die TARGET öffentlich davor PEXP , sich über China kritisch zu äussern . [SEP]',
#  '[CLS] Jüngst hat ein OK-Mitglied die Athleten öffentlich davor gewarnt , sich über China kritisch zu äussern . [SEP]',
#  '[CLS] Neue TARGET gegen Covid-19 hat HOLDER am Donnerstag aber noch nicht PEXP , sondern nur erwogen . [SEP]',
#  '[CLS] Neue Massnahmen gegen Covid-19 hat Schwyz am Donnerstag aber noch nicht angekündigt , sondern nur erwogen . [SEP]',
#  '[CLS] Auch der HOLDER konnte seine vorausgegangenen TARGET PEXP : Gestern um 18 Uhr stand die Gemeinschaftswährung bei 1.1548 Franken , was einem Tagesgewinn von 0,7 Prozent entsprach . [SEP]',
#  '[CLS] Auch der Euro konnte seine vorausgegangenen Verluste eindämmen : Gestern um 18 Uhr stand die Gemeinschaftswährung bei 1.1548 Franken , was einem Tagesgewinn von 0,7 Prozent entsprach . [SEP]',
#  '[CLS] Die HOLDER PEXP im letzten TARGET statt und hätte erst in den kommenden Monaten publiziert werden sollen ; das Resultat liegt dieser Zeitung aber schon vor . [SEP]',
#  '[CLS] Die Befragung fand im letzten September statt und hätte erst in den kommenden Monaten publiziert werden sollen ; das Resultat liegt dieser Zeitung aber schon vor . [SEP]',
#  '[CLS] Jetzt muss die HOLDER mit den TARGET PEXP . » Die Bürgermeisterin London Breed ist jedoch zuversichtlich , dass die Angestellten nach der Pandemie zurückkehren werden . [SEP]',
#  '[CLS] Jetzt muss die Stadt mit den Konsequenzen umgehen . » Die Bürgermeisterin London Breed ist jedoch zuversichtlich , dass die Angestellten nach der Pandemie zurückkehren werden . [SEP]',
#  '[CLS] Anfang Jahr war tonnenweise HOLDER vom Himmel gefallen und PEXP für TARGET in den südwestlichen Alpen . [SEP]',
#  '[CLS] Anfang Jahr war tonnenweise Weiss vom Himmel gefallen und sorgte für Rekord-Schneemengen in den südwestlichen Alpen . [SEP]',
#  '[CLS] Die HOLDER Traber hat noch drei weitere TARGET aus Estermanns Beritt PEXP : Newberry Cleverleaf , Cantini della Caccia und Trendsetter . [SEP]',
#  '[CLS] Die Luzernerin Traber hat noch drei weitere Wallache aus Estermanns Beritt entfernt : Newberry Cleverleaf , Cantini della Caccia und Trendsetter . [SEP]',
#  '[CLS] Der HOLDER hat grosse TARGET PEXP , in Affoltern , Oerlikon , Schwamendingen , Albisrieden , Altstetten . [SEP]',
#  '[CLS] Der Stadtrat hat grosse Aufzonungen angekündigt , in Affoltern , Oerlikon , Schwamendingen , Albisrieden , Altstetten . [SEP]',
#  '[CLS] Sein unehelicher HOLDER Edmund PEXP auf TARGET und Sitte , die ihn zum Bankert und Aussenseiter stempeln . [SEP]',
#  '[CLS] Sein unehelicher Sohn Edmund pfeift auf Tradition und Sitte , die ihn zum Bankert und Aussenseiter stempeln . [SEP]',
#  '[CLS] Und wie wahrscheinlich ist dies : dass ein HOLDER aus dem Greyerzerland sich Ende des 18. Jahrhunderts in eine reiche TARGET PEXP und sie trotz scheinbar unüberwindlicher Hindernisse nach mehreren Trennungen auch bekommt , wobei das Schicksal in Gestalt des französischen Königs die Hände im Spiel hat . [SEP]',
#  '[CLS] Und wie wahrscheinlich ist dies : dass ein Hirtenjunge aus dem Greyerzerland sich Ende des 18. Jahrhunderts in eine reiche Bauerntochter verliebt und sie trotz scheinbar unüberwindlicher Hindernisse nach mehreren Trennungen auch bekommt , wobei das Schicksal in Gestalt des französischen Königs die Hände im Spiel hat . [SEP]',
#  '[CLS] HOLDER PEXP für einen ehrlichen TARGET der aussichtslosen Beitrittsgespräche . [SEP]',
#  '[CLS] Skeptiker plädieren für einen ehrlichen Abbruch der aussichtslosen Beitrittsgespräche . [SEP]',
#  '[CLS] Die HOLDER , denen nach unspezifischen Frühsymptomen wie Fieber , Kopf- , Rücken- und Gliederschmerzen sowie Abgeschlagenheit die charakteristischen Pusteln im Gesicht und am Körper folgen , haben verschiedene TARGET bereits vor Jahrtausenden PEXP . [SEP]',
#  '[CLS] Die Pocken , denen nach unspezifischen Frühsymptomen wie Fieber , Kopf- , Rücken- und Gliederschmerzen sowie Abgeschlagenheit die charakteristischen Pusteln im Gesicht und am Körper folgen , haben verschiedene Kulturen bereits vor Jahrtausenden heimgesucht . [SEP]',
#  '[CLS] Denn Victorias HOLDER Dan Andrews hatte kurz nach Mittag den nächsten TARGET PEXP , von 23.59 Uhr bis Mittwochmitternacht . [SEP]',
#  '[CLS] Denn Victorias Premierminister Dan Andrews hatte kurz nach Mittag den nächsten Lockdown angekündigt , von 23.59 Uhr bis Mittwochmitternacht . [SEP]',
#  '[CLS] So auch an jenem Tag , als der HOLDER die TARGET PEXP . [SEP]',
#  '[CLS] So auch an jenem Tag , als der Mann die Frau tötete . [SEP]',
#  '[CLS] Im Gegenteil : Einerseits kann der grosse Bedarf im Zayanderud-Becken trotzdem nicht gedeckt werden , andererseits PEXP das umgeleitete HOLDER im Süden am TARGET des Karun , wo Feuchtgebiete austrocknen , Sandstürme zunehmen und sich folglich die Ressentiments der mehrheitlich arabischen Bewohner der Provinz Khuzestan auf die Zentralregierung verstärken . [SEP]',
#  '[CLS] Im Gegenteil : Einerseits kann der grosse Bedarf im Zayanderud-Becken trotzdem nicht gedeckt werden , andererseits fehlt das umgeleitete Wasser im Süden am Unterlauf des Karun , wo Feuchtgebiete austrocknen , Sandstürme zunehmen und sich folglich die Ressentiments der mehrheitlich arabischen Bewohner der Provinz Khuzestan auf die Zentralregierung verstärken . [SEP]',
#  '[CLS] Weil das neue HOLDER den TARGET teilweise PEXP , erwischt es jetzt nicht nur die restlichen zehn Prozent . [SEP]',
#  '[CLS] Weil das neue Virus den Immunschutz teilweise umgeht , erwischt es jetzt nicht nur die restlichen zehn Prozent . [SEP]',
#  '[CLS] Schon HOLDER PEXP Leonardos « TARGET » , die sanften Übergänge . [SEP]',
#  '[CLS] Schon Zeitgenossen rühmten Leonardos « sfumato » , die sanften Übergänge . [SEP]',
#  '[CLS] HOLDER Lazaros Christodoulopoulos PEXP wie im Hinspiel zwei TARGET . [SEP]',
#  '[CLS] Stürmer Lazaros Christodoulopoulos schiesst wie im Hinspiel zwei Tore . [SEP]',
#  '[CLS] Ihre grösste HOLDER PEXP ihrem TARGET , der seit 28 Jahren in einem türkischen Gefängnis sitzt . [SEP]',
#  '[CLS] Ihre grösste Sorge gilt ihrem Bruder , der seit 28 Jahren in einem türkischen Gefängnis sitzt . [SEP]',
#  '[CLS] Mengs plötzliches HOLDER hatte weltweit für TARGET PEXP . [SEP]',
#  '[CLS] Mengs plötzliches Verschwinden hatte weltweit für Aufsehen gesorgt . [SEP]',
#  '[CLS] Gekippt wurde neben dem von seiner islamisch-konservativen Regierung PEXP « HOLDER » auch die TARGET . [SEP]',
#  '[CLS] Gekippt wurde neben dem von seiner islamisch-konservativen Regierung propagierten « Untreue-Artikel » auch die Todesstrafe . [SEP]',
#  '[CLS] Umgekehrt PEXP dem TARGET aber auch die nötige HOLDER , um auf den letzten Metern vor dem GC-Tor einigermassen aussichtsreiche Situationen zu schaffen . [SEP]',
#  '[CLS] Umgekehrt fehlte dem FCZ aber auch die nötige Präzision , um auf den letzten Metern vor dem GC-Tor einigermassen aussichtsreiche Situationen zu schaffen . [SEP]',
#  '[CLS] Der Plan sieht vor , dass auf 52 000 Quadratmetern ein HOLDER und ein künstlicher See mit einem TARGET PEXP sollen . [SEP]',
#  '[CLS] Der Plan sieht vor , dass auf 52 000 Quadratmetern ein Park und ein künstlicher See mit einem Wellengenerator entstehen sollen . [SEP]',
#  '[CLS] TARGET wird von seinem HOLDER und seinem Rennstall des folgenden Jahres PEXP , er kassiert sechs Rennen Sperre und einen achtmonatigen Lizenzentzug . [SEP]',
#  '[CLS] Fenati wird von seinem damaligen und seinem Rennstall des folgenden Jahres entlassen , er kassiert sechs Rennen Sperre und einen achtmonatigen Lizenzentzug . [SEP]',
#  '[CLS] Die « HOLDER » zwischen einem Spinnrocken in der Spinnstube und einer Atomrakete in der Rüstkammer könnte , von der TARGET einmal PEXP , geringer ja kaum sein . [SEP]',
#  '[CLS] Die « Ähnlichkeit » zwischen einem Spinnrocken in der Spinnstube und einer Atomrakete in der Rüstkammer könnte , von der Spindelform einmal abgesehen , geringer ja kaum sein . [SEP]',
#  '[CLS] Auch habe die HOLDER aus La Chaux-de-Fonds , die in Lausanne attackiert wurde , seines Wissens nie öffentliche TARGET PEXP . [SEP]',
#  '[CLS] Auch habe die Gruppe aus La Chaux-de-Fonds , die in Lausanne attackiert wurde , seines Wissens nie öffentliche Einrichtungen zerstört . [SEP]',
#  '[CLS] In 46 Runden der Swiss-League-Qualifikation PEXP die HOLDER nur acht TARGET nach 60 Minuten . [SEP]',
#  '[CLS] In 46 Runden der Swiss-League-Qualifikation verloren die Lakers nur acht Mal nach 60 Minuten . [SEP]',
#  '[CLS] « Das bedeutet , dass die HOLDER TARGET PEXP » , wird dazu einer der Klinikdirektoren zitiert . [SEP]',
#  '[CLS] « Das bedeutet , dass die Impfung wunderbar wirkt » , wird dazu einer der Klinikdirektoren zitiert . [SEP]',
#  '[CLS] Der 68-jährige HOLDER PEXP leichte TARGET . [SEP]',
#  '[CLS] Der 68-jährige Velofahrer erlitt leichte Verletzungen . [SEP]',
#  '[CLS] Erstmals in der Geschichte der Zweiten Republik könnte das HOLDER gar den TARGET PEXP . [SEP]',
#  '[CLS] Erstmals in der Geschichte der Zweiten Republik könnte das Parlament gar den Kanzler stürzen . [SEP]',
#  '[CLS] Theoretisch haben die HOLDER die Möglichkeit , nach Ablauf des Züchtungsverbots Ende 2021 das TARGET wieder PEXP . [SEP]',
#  '[CLS] Theoretisch haben die Nerzzüchter die Möglichkeit , nach Ablauf des Züchtungsverbots Ende 2021 das Gewerbe wieder aufzunehmen . [SEP]',
#  '[CLS] Auch das HOLDER PEXP für eine malerische TARGET an diesen Winterspielen in Südkorea . [SEP]',
#  '[CLS] Auch das Meer sorgt für eine malerische Kulisse an diesen Winterspielen in Südkorea . [SEP]',
#  '[CLS] Mit den beiden Abgängen PEXP der HOLDER auf einen TARGET zwei seiner drei Dreisterngeneräle . [SEP]',
#  '[CLS] Mit den beiden Abgängen verliert der Bund auf einen Schlag zwei seiner drei Dreisterngeneräle . [SEP]',
#  '[CLS] Die HOLDER wurden von kurdischen TARGET und Linksradikalen PEXP , die sich mit ihnen solidarisiert hatten . [SEP]',
#  '[CLS] Die Taten wurden von kurdischen Extremisten und Linksradikalen verübt , die sich mit ihnen solidarisiert hatten . [SEP]',
#  '[CLS] Insbesondere das HOLDER über die Nachrichtendienste PEXP chinesische TARGET in ein arges Dilemma . [SEP]',
#  '[CLS] Insbesondere das Gesetz über die Nachrichtendienste stürzt chinesische Unternehmen in ein arges Dilemma . [SEP]',
#  '[CLS] So schlecht also liefen die HOLDER doch nicht in Lissabon , PEXP TARGET , wenn man nur alles ineinander verrechnete . [SEP]',
#  '[CLS] So schlecht also liefen die Dinge doch nicht in Lissabon , fand Voltaire , wenn man nur alles ineinander verrechnete . [SEP]',
#  '[CLS] Ihre HOLDER mochte künstlerische TARGET PEXP . [SEP]',
#  '[CLS] Ihre Imitation mochte künstlerische Defizite aufweisen . [SEP]',
#  '[CLS] Als Special Event PEXP am Dienstag , 29. Mai , abends eine HOLDER mit TARGET Paltén statt , der ersten Frau , die Iran zu Fuss durchlaufen hat ; dazu läuft die Dokumentation « Alone through Iran » . [SEP]',
#  '[CLS] Als Special Event findet am Dienstag , 29. Mai , abends eine Podiumsdiskussion mit Kristina Paltén statt , der ersten Frau , die Iran zu Fuss durchlaufen hat ; dazu läuft die Dokumentation « Alone through Iran » . [SEP]',
#  '[CLS] Die im Buch beschriebenen HOLDER PEXP sich alle einem TARGET . [SEP]',
#  '[CLS] Die im Buch beschriebenen Gärten widmen sich alle einem Thema . [SEP]',
#  '[CLS] In TARGET , welche die jüngsten Mustervorschriften ( Muken 2014 ) bereits umgesetzt haben , PEXP weiterreichende HOLDER . [SEP]',
#  '[CLS] In Kantonen , welche die jüngsten Mustervorschriften ( Muken 2014 ) bereits umgesetzt haben , gelten weiterreichende Bestimmungen . [SEP]',
#  '[CLS] Das HOLDER von Trainer Stefano Pioli PEXP am TARGET beim Champions-League-Achtelfinalisten Atalanta mit 0 : 5 und wird zum Jahreswechsel nur Tabellenplatz elf belegen . [SEP]',
#  '[CLS] Das Team von Trainer Stefano Pioli verlor am Samstag beim Champions-League-Achtelfinalisten Atalanta mit 0 : 5 und wird zum Jahreswechsel nur Tabellenplatz elf belegen . [SEP]',
#  '[CLS] Nach 34 Jahren war das ein Ding der Unmöglichkeit , aber wahrscheinlich hatten nicht wenige Schweden so etwas erwartet von diesem Tag , den das grösste HOLDER des Landes , « Aftonbladet » , gestern TARGET auf seiner Webseite als « historisch » PEXP hatte . [SEP]',
#  '[CLS] Nach 34 Jahren war das ein Ding der Unmöglichkeit , aber wahrscheinlich hatten nicht wenige Schweden so etwas erwartet von diesem Tag , den das grösste Boulevardblatt des Landes , « Aftonbladet » , gestern Morgen auf seiner Webseite als « historisch » angekündigt hatte . [SEP]',
#  '[CLS] In enger Abstimmung mit Verbündeten in Europa , mit Kanada und mit der Ukraine hat HOLDER am Montagmorgen ( Ortszeit ) mit einer Erklärung des Weissen Hauses die TARGET von Dutzenden von russischen Spionen PEXP . [SEP]',
#  '[CLS] In enger Abstimmung mit Verbündeten in Europa , mit Kanada und mit der Ukraine hat Washington am Montagmorgen ( Ortszeit ) mit einer Erklärung des Weissen Hauses die Ausweisung von Dutzenden von russischen Spionen angekündigt . [SEP]',
#  '[CLS] Die HOLDER Salome Grisard PEXP in diesem Zusammenhang in der Gestaltung für mehr « TARGET auf Dichte » . [SEP]',
#  '[CLS] Die Architektin Salome Grisard plädiert in diesem Zusammenhang in der Gestaltung für mehr « Lust auf Dichte » . [SEP]',
#  '[CLS] Dass Ministerpräsidentin Dancila nun ein Referendum über Straferhöhungen bei Gewaltverbrechen vorschlägt , nachdem ihre HOLDER die TARGET immer nur PEXP hat , entbehrt nicht der Ironie . [SEP]',
#  '[CLS] Dass Ministerpräsidentin Dancila nun ein Referendum über Straferhöhungen bei Gewaltverbrechen vorschlägt , nachdem ihre Regierung die Strafverfolgung immer nur behindert hat , entbehrt nicht der Ironie . [SEP]',
#  '[CLS] Die neue EU-Behörde mit Sitz in Luxemburg , die korrupten Politikern und kriminellen Geschäftsleuten europaweit das HOLDER legen soll , hat an diesem Dienstag nach fast vierjähriger Vorbereitungszeit ihre TARGET PEXP . [SEP]',
#  '[CLS] Die neue EU-Behörde mit Sitz in Luxemburg , die korrupten Politikern und kriminellen Geschäftsleuten europaweit das Handwerk legen soll , hat an diesem Dienstag nach fast vierjähriger Vorbereitungszeit ihre Tätigkeit aufgenommen . [SEP]',
#  '[CLS] Dass die HOLDER in Belgien tatsächlich das Potenzial hat , TARGET zu PEXP , zeigte sich 2018 . [SEP]',
#  '[CLS] Dass die Migrationspolitik in Belgien tatsächlich das Potenzial hat , Regierungen zu stürzen , zeigte sich 2018 . [SEP]',
#  ...]

# %%
# save as txt file
list_to_file(orl_data_train, ORL_OUTPUT_PATH_TRAIN)
list_to_file(orl_data_val, ORL_OUTPUT_PATH_VAL)
list_to_file(orl_data_test, ORL_OUTPUT_PATH_TEST)
